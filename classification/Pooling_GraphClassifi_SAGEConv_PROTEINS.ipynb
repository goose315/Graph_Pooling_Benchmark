# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
import torch
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected, AddSelfLoops
from torch_geometric.utils import to_dense_adj
import os
import torch
import torch_geometric.transforms as T
from torch_geometric.datasets import TUDataset
from torch_geometric.utils import degree

# %%
torch.manual_seed(42)
torch.cuda.manual_seed(42)
torch.cuda.manual_seed_all(42)
import numpy as np
np.random.seed(42)
import random
random.seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.loader import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from sklearn.model_selection import KFold
from torch_geometric.nn import global_mean_pool
import psutil
import warnings
warnings.filterwarnings('ignore')
import statistics

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, TopKPooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch


data_path = "/data/zeyu/Pooling"  # Adjust path as needed
max_nodes = 150


dataset_sparse = TUDataset(root=data_path, name="PROTEINS", pre_filter=lambda data: data.num_nodes <= max_nodes, use_node_attr=True)
dataset_sparse = dataset_sparse.shuffle()

dataset_size = len(dataset_sparse)
train_size = int(dataset_size * 0.7)
val_size = int(dataset_size * 0.15)
test_size = dataset_size - train_size - val_size

train_dataset = dataset_sparse[:train_size]
val_dataset = dataset_sparse[train_size:train_size+val_size]
test_dataset = dataset_sparse[train_size+val_size:]

train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
valid_loader = DataLoader(val_dataset, batch_size=256, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)
# Out:
# /home/user/anaconda3/envs/CG-ODE/lib/python3.9/site-packages/torch_geometric/data/dataset.py:158: UserWarning: The `pre_filter` argument differs from the one used in the pre-processed version of this dataset. If you want to make use of another pre-fitering technique, make sure to delete '{self.processed_dir}' first
#   warnings.warn(
# /home/user/anaconda3/envs/CG-ODE/lib/python3.9/site-packages/torch_geometric/deprecation.py:12: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)

# %% [markdown]
# ## TopKPooling with HierarchicalGCN (2019)

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, TopKPooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch

class HierarchicalGCN_TOPK(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_TOPK, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool1 = TopKPooling(hidden_channels, ratio=0.5)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool2 = TopKPooling(hidden_channels, ratio=0.5)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, _, batch, _, _ = self.pool1(x, edge_index, batch=batch)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, _, batch, _, _ = self.pool2(x, edge_index, batch=batch)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_TOPK(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_TOPK(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.7302, Val Acc: 0.3554, Test Acc: 0.3810
# Seed: 42, Epoch: 002, Loss: 0.7153, Val Acc: 0.3916, Test Acc: 0.4226
# Seed: 42, Epoch: 003, Loss: 0.7026, Val Acc: 0.4819, Test Acc: 0.5536
# Seed: 42, Epoch: 004, Loss: 0.6791, Val Acc: 0.5904, Test Acc: 0.6786
# Seed: 42, Epoch: 005, Loss: 0.6604, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 42, Epoch: 006, Loss: 0.6488, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 007, Loss: 0.6644, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 42, Epoch: 008, Loss: 0.6578, Val Acc: 0.6566, Test Acc: 0.7381
# Seed: 42, Epoch: 009, Loss: 0.6513, Val Acc: 0.6566, Test Acc: 0.7560
# Seed: 42, Epoch: 010, Loss: 0.6540, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 011, Loss: 0.6612, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 42, Epoch: 012, Loss: 0.6424, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 42, Epoch: 013, Loss: 0.6368, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 42, Epoch: 014, Loss: 0.6353, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 015, Loss: 0.6344, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 42, Epoch: 016, Loss: 0.6435, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 42, Epoch: 017, Loss: 0.6329, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 42, Epoch: 018, Loss: 0.6402, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 42, Epoch: 019, Loss: 0.6464, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 020, Loss: 0.6523, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 021, Loss: 0.6598, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 022, Loss: 0.6550, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 023, Loss: 0.6592, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 024, Loss: 0.6575, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 025, Loss: 0.6612, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 026, Loss: 0.6424, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 027, Loss: 0.6550, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 028, Loss: 0.6552, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 029, Loss: 0.6515, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 030, Loss: 0.6610, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 42, Epoch: 031, Loss: 0.6586, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 032, Loss: 0.6507, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 033, Loss: 0.6434, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 42, Epoch: 034, Loss: 0.6413, Val Acc: 0.7289, Test Acc: 0.6905
# Seed: 42, Epoch: 035, Loss: 0.6443, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 42, Epoch: 036, Loss: 0.6391, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 42, Epoch: 037, Loss: 0.6383, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 42, Epoch: 038, Loss: 0.6308, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 42, Epoch: 039, Loss: 0.6348, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 42, Epoch: 040, Loss: 0.6422, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 42, Epoch: 041, Loss: 0.6392, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 42, Epoch: 042, Loss: 0.6368, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 42, Epoch: 043, Loss: 0.6323, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 42, Epoch: 044, Loss: 0.6435, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 42, Epoch: 045, Loss: 0.6407, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 046, Loss: 0.6368, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 047, Loss: 0.6455, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 048, Loss: 0.6447, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 42, Epoch: 049, Loss: 0.6489, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 050, Loss: 0.6582, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 051, Loss: 0.6700, Val Acc: 0.6566, Test Acc: 0.7560
# Seed: 42, Epoch: 052, Loss: 0.6648, Val Acc: 0.6566, Test Acc: 0.7619
# Seed: 42, Epoch: 053, Loss: 0.6715, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 054, Loss: 0.6681, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 42, Epoch: 055, Loss: 0.6649, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 056, Loss: 0.6606, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 057, Loss: 0.6619, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 058, Loss: 0.6614, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 42, Epoch: 059, Loss: 0.6594, Val Acc: 0.6807, Test Acc: 0.7857
# Seed: 42, Epoch: 060, Loss: 0.6647, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 061, Loss: 0.6640, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 42, Epoch: 062, Loss: 0.6578, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 42, Epoch: 063, Loss: 0.6528, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 42, Epoch: 064, Loss: 0.6510, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 42, Epoch: 065, Loss: 0.6463, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 066, Loss: 0.6393, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 067, Loss: 0.6392, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 068, Loss: 0.6402, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 069, Loss: 0.6312, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 070, Loss: 0.6223, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 071, Loss: 0.6280, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 072, Loss: 0.6246, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 42, Epoch: 073, Loss: 0.6227, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 42, Epoch: 074, Loss: 0.6296, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 42, Epoch: 075, Loss: 0.6240, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 076, Loss: 0.6142, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 077, Loss: 0.6130, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 078, Loss: 0.6194, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 079, Loss: 0.6115, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 080, Loss: 0.6190, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 081, Loss: 0.6142, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 42, Epoch: 082, Loss: 0.6250, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 083, Loss: 0.6169, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 42, Epoch: 084, Loss: 0.6175, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 085, Loss: 0.6259, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 086, Loss: 0.6260, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 087, Loss: 0.6241, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 088, Loss: 0.6326, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 089, Loss: 0.6268, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 42, Epoch: 090, Loss: 0.6324, Val Acc: 0.7048, Test Acc: 0.7917
# Seed: 42, Epoch: 091, Loss: 0.6357, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 42, Epoch: 092, Loss: 0.6322, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 42, Epoch: 093, Loss: 0.6236, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 094, Loss: 0.6203, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 42, Epoch: 095, Loss: 0.6170, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 42, Epoch: 096, Loss: 0.6089, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 097, Loss: 0.6145, Val Acc: 0.7169, Test Acc: 0.6905
# Seed: 42, Epoch: 098, Loss: 0.6039, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 42, Epoch: 099, Loss: 0.6063, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 100, Loss: 0.6088, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 101, Loss: 0.6034, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 102, Loss: 0.5987, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 42, Epoch: 103, Loss: 0.6119, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 42, Epoch: 104, Loss: 0.5923, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 105, Loss: 0.5947, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 42, Epoch: 106, Loss: 0.5886, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 107, Loss: 0.5938, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 42, Epoch: 108, Loss: 0.5901, Val Acc: 0.7349, Test Acc: 0.7798
# Seed: 42, Epoch: 109, Loss: 0.6064, Val Acc: 0.7289, Test Acc: 0.7798
# Seed: 42, Epoch: 110, Loss: 0.6185, Val Acc: 0.7349, Test Acc: 0.7857
# Seed: 42, Epoch: 111, Loss: 0.6029, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 42, Epoch: 112, Loss: 0.6160, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 42, Epoch: 113, Loss: 0.5914, Val Acc: 0.7349, Test Acc: 0.7857
# Seed: 42, Epoch: 114, Loss: 0.6174, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 115, Loss: 0.6139, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 116, Loss: 0.6122, Val Acc: 0.7349, Test Acc: 0.7857
# Seed: 42, Epoch: 117, Loss: 0.6197, Val Acc: 0.7349, Test Acc: 0.7798
# Seed: 42, Epoch: 118, Loss: 0.6139, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 119, Loss: 0.6028, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 42, Epoch: 120, Loss: 0.6042, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 121, Loss: 0.6021, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 122, Loss: 0.5941, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 42, Epoch: 123, Loss: 0.5960, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 42, Epoch: 124, Loss: 0.5994, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 42, Epoch: 125, Loss: 0.5988, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 42, Epoch: 126, Loss: 0.6003, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 42, Epoch: 127, Loss: 0.5836, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 128, Loss: 0.5854, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 129, Loss: 0.5866, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 130, Loss: 0.5943, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 42, Epoch: 131, Loss: 0.6248, Val Acc: 0.7530, Test Acc: 0.7798
# Seed: 42, Epoch: 132, Loss: 0.5946, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 42, Epoch: 133, Loss: 0.5929, Val Acc: 0.7470, Test Acc: 0.7024
# Seed: 42, Epoch: 134, Loss: 0.5953, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 135, Loss: 0.5946, Val Acc: 0.7349, Test Acc: 0.7857
# Seed: 42, Epoch: 136, Loss: 0.6038, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 42, Epoch: 137, Loss: 0.6087, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 138, Loss: 0.5991, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 139, Loss: 0.5971, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 42, Epoch: 140, Loss: 0.5983, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 141, Loss: 0.5882, Val Acc: 0.7169, Test Acc: 0.6905
# Seed: 42, Epoch: 142, Loss: 0.5945, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 42, Epoch: 143, Loss: 0.5969, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 42, Epoch: 144, Loss: 0.5915, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 42, Epoch: 145, Loss: 0.6600, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 42, Epoch: 146, Loss: 0.6446, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 42, Epoch: 147, Loss: 0.6180, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 42, Epoch: 148, Loss: 0.6030, Val Acc: 0.7289, Test Acc: 0.6845
# Seed: 42, Epoch: 149, Loss: 0.6143, Val Acc: 0.7590, Test Acc: 0.7024
# Seed: 42, Epoch: 150, Loss: 0.6058, Val Acc: 0.7229, Test Acc: 0.6786
# Seed: 42, Epoch: 151, Loss: 0.6460, Val Acc: 0.7289, Test Acc: 0.6369
# Seed: 42, Epoch: 152, Loss: 0.6421, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 42, Epoch: 153, Loss: 0.6121, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 42, Epoch: 154, Loss: 0.6257, Val Acc: 0.7048, Test Acc: 0.6845
# Seed: 42, Epoch: 155, Loss: 0.6234, Val Acc: 0.7169, Test Acc: 0.6905
# Seed: 42, Epoch: 156, Loss: 0.6337, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 42, Epoch: 157, Loss: 0.6159, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 42, Epoch: 158, Loss: 0.6227, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 42, Epoch: 159, Loss: 0.6195, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 42, Epoch: 160, Loss: 0.6232, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 161, Loss: 0.6190, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 42, Epoch: 162, Loss: 0.6195, Val Acc: 0.7169, Test Acc: 0.6964
# Seed: 42, Epoch: 163, Loss: 0.6180, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 42, Epoch: 164, Loss: 0.6130, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 42, Epoch: 165, Loss: 0.6108, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 166, Loss: 0.6118, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 167, Loss: 0.6062, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 42, Epoch: 168, Loss: 0.6029, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 169, Loss: 0.5987, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 170, Loss: 0.5935, Val Acc: 0.7590, Test Acc: 0.7440
# Seed: 42, Epoch: 171, Loss: 0.5934, Val Acc: 0.7651, Test Acc: 0.7381
# Seed: 42, Epoch: 172, Loss: 0.5800, Val Acc: 0.7530, Test Acc: 0.7143
# Seed: 42, Epoch: 173, Loss: 0.5908, Val Acc: 0.7470, Test Acc: 0.7262
# Seed: 42, Epoch: 174, Loss: 0.5777, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 42, Epoch: 175, Loss: 0.5833, Val Acc: 0.7651, Test Acc: 0.7024
# Seed: 42, Epoch: 176, Loss: 0.5993, Val Acc: 0.6084, Test Acc: 0.6548
# Seed: 42, Epoch: 177, Loss: 0.8243, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 42, Epoch: 178, Loss: 0.6092, Val Acc: 0.7289, Test Acc: 0.6786
# Seed: 42, Epoch: 179, Loss: 0.6110, Val Acc: 0.6928, Test Acc: 0.6548
# Seed: 42, Epoch: 180, Loss: 0.6141, Val Acc: 0.6747, Test Acc: 0.6488
# Seed: 42, Epoch: 181, Loss: 0.6176, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 42, Epoch: 182, Loss: 0.6201, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 42, Epoch: 183, Loss: 0.6189, Val Acc: 0.6747, Test Acc: 0.6488
# Seed: 42, Epoch: 184, Loss: 0.6148, Val Acc: 0.6988, Test Acc: 0.6429
# Seed: 42, Epoch: 185, Loss: 0.6206, Val Acc: 0.6988, Test Acc: 0.6667
# Seed: 42, Epoch: 186, Loss: 0.6136, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 42, Epoch: 187, Loss: 0.6101, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 42, Epoch: 188, Loss: 0.6055, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 189, Loss: 0.6155, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 190, Loss: 0.6175, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 191, Loss: 0.6182, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 192, Loss: 0.6196, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 193, Loss: 0.6136, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 194, Loss: 0.5972, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 195, Loss: 0.5956, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 196, Loss: 0.5961, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 197, Loss: 0.5923, Val Acc: 0.7530, Test Acc: 0.7083
# Seed: 42, Epoch: 198, Loss: 0.5922, Val Acc: 0.7410, Test Acc: 0.7202
# Seed: 42, Epoch: 199, Loss: 0.5983, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 200, Loss: 0.5943, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 43, Epoch: 001, Loss: 0.7120, Val Acc: 0.3916, Test Acc: 0.4345
# Seed: 43, Epoch: 002, Loss: 0.6932, Val Acc: 0.5602, Test Acc: 0.6071
# Seed: 43, Epoch: 003, Loss: 0.6744, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 43, Epoch: 004, Loss: 0.6569, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 005, Loss: 0.6342, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 43, Epoch: 006, Loss: 0.6144, Val Acc: 0.6867, Test Acc: 0.6369
# Seed: 43, Epoch: 007, Loss: 0.6242, Val Acc: 0.6928, Test Acc: 0.6429
# Seed: 43, Epoch: 008, Loss: 0.6212, Val Acc: 0.6747, Test Acc: 0.6607
# Seed: 43, Epoch: 009, Loss: 0.6267, Val Acc: 0.6928, Test Acc: 0.6786
# Seed: 43, Epoch: 010, Loss: 0.6208, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 43, Epoch: 011, Loss: 0.6260, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 012, Loss: 0.6332, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 013, Loss: 0.6242, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 014, Loss: 0.6451, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 015, Loss: 0.6418, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 016, Loss: 0.6377, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 43, Epoch: 017, Loss: 0.6510, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 43, Epoch: 018, Loss: 0.6601, Val Acc: 0.6446, Test Acc: 0.7619
# Seed: 43, Epoch: 019, Loss: 0.6506, Val Acc: 0.6446, Test Acc: 0.7619
# Seed: 43, Epoch: 020, Loss: 0.6480, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 021, Loss: 0.6541, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 022, Loss: 0.6370, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 023, Loss: 0.6485, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 024, Loss: 0.6464, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 43, Epoch: 025, Loss: 0.6439, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 026, Loss: 0.6234, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 43, Epoch: 027, Loss: 0.6314, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 028, Loss: 0.6209, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 43, Epoch: 029, Loss: 0.6273, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 43, Epoch: 030, Loss: 0.6147, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 031, Loss: 0.6222, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 032, Loss: 0.6267, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 033, Loss: 0.6327, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 43, Epoch: 034, Loss: 0.6285, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 43, Epoch: 035, Loss: 0.6275, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 43, Epoch: 036, Loss: 0.6243, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 43, Epoch: 037, Loss: 0.6297, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 43, Epoch: 038, Loss: 0.6351, Val Acc: 0.6566, Test Acc: 0.7440
# Seed: 43, Epoch: 039, Loss: 0.6329, Val Acc: 0.6627, Test Acc: 0.7679
# Seed: 43, Epoch: 040, Loss: 0.6477, Val Acc: 0.6566, Test Acc: 0.7738
# Seed: 43, Epoch: 041, Loss: 0.6484, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 43, Epoch: 042, Loss: 0.6364, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 043, Loss: 0.6179, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 044, Loss: 0.6156, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 045, Loss: 0.6133, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 046, Loss: 0.6139, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 047, Loss: 0.6100, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 048, Loss: 0.6098, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 049, Loss: 0.6142, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 43, Epoch: 050, Loss: 0.6110, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 43, Epoch: 051, Loss: 0.5951, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 052, Loss: 0.6038, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 053, Loss: 0.6073, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 43, Epoch: 054, Loss: 0.6185, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 43, Epoch: 055, Loss: 0.6319, Val Acc: 0.6506, Test Acc: 0.7381
# Seed: 43, Epoch: 056, Loss: 0.6412, Val Acc: 0.6506, Test Acc: 0.7262
# Seed: 43, Epoch: 057, Loss: 0.6423, Val Acc: 0.6566, Test Acc: 0.7202
# Seed: 43, Epoch: 058, Loss: 0.6515, Val Acc: 0.6566, Test Acc: 0.7500
# Seed: 43, Epoch: 059, Loss: 0.6416, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 43, Epoch: 060, Loss: 0.6391, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 061, Loss: 0.6304, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 43, Epoch: 062, Loss: 0.6309, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 063, Loss: 0.6326, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 43, Epoch: 064, Loss: 0.6338, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 43, Epoch: 065, Loss: 0.6304, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 066, Loss: 0.6250, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 067, Loss: 0.6268, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 068, Loss: 0.6313, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 43, Epoch: 069, Loss: 0.6255, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 43, Epoch: 070, Loss: 0.6230, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 071, Loss: 0.6172, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 072, Loss: 0.6173, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 073, Loss: 0.6112, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 074, Loss: 0.6166, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 43, Epoch: 075, Loss: 0.6210, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 076, Loss: 0.6244, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 43, Epoch: 077, Loss: 0.6120, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 078, Loss: 0.6174, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 43, Epoch: 079, Loss: 0.6126, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 43, Epoch: 080, Loss: 0.6096, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 081, Loss: 0.6091, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 082, Loss: 0.6053, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 083, Loss: 0.6173, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 43, Epoch: 084, Loss: 0.6173, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 43, Epoch: 085, Loss: 0.6139, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 086, Loss: 0.6160, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 087, Loss: 0.6087, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 088, Loss: 0.6027, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 089, Loss: 0.6051, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 43, Epoch: 090, Loss: 0.6153, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 43, Epoch: 091, Loss: 0.6012, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 092, Loss: 0.5986, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 43, Epoch: 093, Loss: 0.6005, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 094, Loss: 0.5933, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 095, Loss: 0.5890, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 096, Loss: 0.5875, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 097, Loss: 0.5799, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 098, Loss: 0.5855, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 099, Loss: 0.5868, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 43, Epoch: 100, Loss: 0.6055, Val Acc: 0.6627, Test Acc: 0.7679
# Seed: 43, Epoch: 101, Loss: 0.6135, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 102, Loss: 0.5997, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 43, Epoch: 103, Loss: 0.6421, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 43, Epoch: 104, Loss: 0.6339, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 43, Epoch: 105, Loss: 0.6103, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 43, Epoch: 106, Loss: 0.6069, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 107, Loss: 0.5955, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 108, Loss: 0.5976, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 109, Loss: 0.5830, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 110, Loss: 0.6027, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 43, Epoch: 111, Loss: 0.6002, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 112, Loss: 0.6022, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 113, Loss: 0.5952, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 43, Epoch: 114, Loss: 0.5957, Val Acc: 0.6687, Test Acc: 0.7083
# Seed: 43, Epoch: 115, Loss: 0.5858, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 43, Epoch: 116, Loss: 0.6303, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 117, Loss: 0.5947, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 118, Loss: 0.5911, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 43, Epoch: 119, Loss: 0.5922, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 120, Loss: 0.5939, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 121, Loss: 0.5916, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 122, Loss: 0.5930, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 43, Epoch: 123, Loss: 0.5855, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 43, Epoch: 124, Loss: 0.5861, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 43, Epoch: 125, Loss: 0.5832, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 43, Epoch: 126, Loss: 0.5788, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 43, Epoch: 127, Loss: 0.5809, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 128, Loss: 0.5844, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 129, Loss: 0.5822, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 130, Loss: 0.5890, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 43, Epoch: 131, Loss: 0.5950, Val Acc: 0.7229, Test Acc: 0.7857
# Seed: 43, Epoch: 132, Loss: 0.6071, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 43, Epoch: 133, Loss: 0.6168, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 43, Epoch: 134, Loss: 0.6121, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 43, Epoch: 135, Loss: 0.5911, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 136, Loss: 0.5839, Val Acc: 0.6687, Test Acc: 0.6964
# Seed: 43, Epoch: 137, Loss: 0.5908, Val Acc: 0.6807, Test Acc: 0.6786
# Seed: 43, Epoch: 138, Loss: 0.5932, Val Acc: 0.6687, Test Acc: 0.6905
# Seed: 43, Epoch: 139, Loss: 0.5840, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 140, Loss: 0.5918, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 141, Loss: 0.5958, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 43, Epoch: 142, Loss: 0.5887, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 143, Loss: 0.5928, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 144, Loss: 0.5945, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 145, Loss: 0.6021, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 43, Epoch: 146, Loss: 0.6130, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 43, Epoch: 147, Loss: 0.5837, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 43, Epoch: 148, Loss: 0.5828, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 43, Epoch: 149, Loss: 0.5748, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 43, Epoch: 150, Loss: 0.5815, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 43, Epoch: 151, Loss: 0.5644, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 43, Epoch: 152, Loss: 0.5885, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 153, Loss: 0.5817, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 154, Loss: 0.5940, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 43, Epoch: 155, Loss: 0.5995, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 43, Epoch: 156, Loss: 0.5974, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 157, Loss: 0.5910, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 158, Loss: 0.5865, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 43, Epoch: 159, Loss: 0.5867, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 43, Epoch: 160, Loss: 0.5866, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 161, Loss: 0.6019, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 162, Loss: 0.6071, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 43, Epoch: 163, Loss: 0.6106, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 43, Epoch: 164, Loss: 0.6111, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 43, Epoch: 165, Loss: 0.5927, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 43, Epoch: 166, Loss: 0.5891, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 167, Loss: 0.5826, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 168, Loss: 0.5921, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 169, Loss: 0.5895, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 170, Loss: 0.5825, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 43, Epoch: 171, Loss: 0.5892, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 43, Epoch: 172, Loss: 0.5800, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 173, Loss: 0.5828, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 174, Loss: 0.5815, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 175, Loss: 0.5828, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 43, Epoch: 176, Loss: 0.5854, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 43, Epoch: 177, Loss: 0.5843, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 43, Epoch: 178, Loss: 0.5880, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 179, Loss: 0.5886, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 43, Epoch: 180, Loss: 0.5847, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 181, Loss: 0.5893, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 182, Loss: 0.5814, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 43, Epoch: 183, Loss: 0.5897, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 184, Loss: 0.5827, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 43, Epoch: 185, Loss: 0.5793, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 43, Epoch: 186, Loss: 0.5799, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 43, Epoch: 187, Loss: 0.5713, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 43, Epoch: 188, Loss: 0.5819, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 43, Epoch: 189, Loss: 0.5775, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 43, Epoch: 190, Loss: 0.5766, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 191, Loss: 0.5751, Val Acc: 0.7289, Test Acc: 0.7857
# Seed: 43, Epoch: 192, Loss: 0.5876, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 193, Loss: 0.5751, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 43, Epoch: 194, Loss: 0.5785, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 195, Loss: 0.5797, Val Acc: 0.7229, Test Acc: 0.7857
# Seed: 43, Epoch: 196, Loss: 0.5803, Val Acc: 0.7229, Test Acc: 0.7857
# Seed: 43, Epoch: 197, Loss: 0.5759, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 43, Epoch: 198, Loss: 0.5658, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 199, Loss: 0.5717, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 200, Loss: 0.5683, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 44, Epoch: 001, Loss: 0.6953, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 002, Loss: 0.6846, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 003, Loss: 0.6725, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 004, Loss: 0.6580, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 005, Loss: 0.6465, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 006, Loss: 0.6500, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 007, Loss: 0.6450, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 008, Loss: 0.6443, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 009, Loss: 0.6385, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 010, Loss: 0.6404, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 011, Loss: 0.6336, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 012, Loss: 0.6342, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 013, Loss: 0.6284, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 014, Loss: 0.6355, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 015, Loss: 0.6247, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 44, Epoch: 016, Loss: 0.6362, Val Acc: 0.6566, Test Acc: 0.6131
# Seed: 44, Epoch: 017, Loss: 0.6274, Val Acc: 0.6687, Test Acc: 0.6369
# Seed: 44, Epoch: 018, Loss: 0.6366, Val Acc: 0.6928, Test Acc: 0.6369
# Seed: 44, Epoch: 019, Loss: 0.6391, Val Acc: 0.6928, Test Acc: 0.6369
# Seed: 44, Epoch: 020, Loss: 0.6263, Val Acc: 0.6928, Test Acc: 0.6369
# Seed: 44, Epoch: 021, Loss: 0.6318, Val Acc: 0.6988, Test Acc: 0.6369
# Seed: 44, Epoch: 022, Loss: 0.6293, Val Acc: 0.6988, Test Acc: 0.6429
# Seed: 44, Epoch: 023, Loss: 0.6319, Val Acc: 0.6988, Test Acc: 0.6667
# Seed: 44, Epoch: 024, Loss: 0.6272, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 44, Epoch: 025, Loss: 0.6406, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 026, Loss: 0.6345, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 027, Loss: 0.6373, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 028, Loss: 0.6417, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 44, Epoch: 029, Loss: 0.6339, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 030, Loss: 0.6420, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 031, Loss: 0.6438, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 032, Loss: 0.6443, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 033, Loss: 0.6442, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 034, Loss: 0.6368, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 035, Loss: 0.6356, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 44, Epoch: 036, Loss: 0.6360, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 44, Epoch: 037, Loss: 0.6290, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 038, Loss: 0.6310, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 44, Epoch: 039, Loss: 0.6271, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 040, Loss: 0.6445, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 041, Loss: 0.6287, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 042, Loss: 0.6261, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 043, Loss: 0.6231, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 044, Loss: 0.6258, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 045, Loss: 0.6189, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 046, Loss: 0.6409, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 047, Loss: 0.6469, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 44, Epoch: 048, Loss: 0.6455, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 44, Epoch: 049, Loss: 0.6410, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 44, Epoch: 050, Loss: 0.6334, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 44, Epoch: 051, Loss: 0.6225, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 44, Epoch: 052, Loss: 0.6205, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 44, Epoch: 053, Loss: 0.6230, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 054, Loss: 0.6112, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 055, Loss: 0.6186, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 44, Epoch: 056, Loss: 0.6264, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 44, Epoch: 057, Loss: 0.6251, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 44, Epoch: 058, Loss: 0.6168, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 44, Epoch: 059, Loss: 0.6142, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 44, Epoch: 060, Loss: 0.6156, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 44, Epoch: 061, Loss: 0.6120, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 062, Loss: 0.6133, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 063, Loss: 0.6168, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 064, Loss: 0.6183, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 065, Loss: 0.6144, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 066, Loss: 0.6252, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 067, Loss: 0.6194, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 068, Loss: 0.6279, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 069, Loss: 0.6230, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 070, Loss: 0.6228, Val Acc: 0.7349, Test Acc: 0.7143
# Seed: 44, Epoch: 071, Loss: 0.6226, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 44, Epoch: 072, Loss: 0.6184, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 073, Loss: 0.6073, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 074, Loss: 0.6078, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 075, Loss: 0.6057, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 076, Loss: 0.5998, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 077, Loss: 0.6052, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 078, Loss: 0.6014, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 44, Epoch: 079, Loss: 0.5988, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 080, Loss: 0.6036, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 081, Loss: 0.6006, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 082, Loss: 0.5947, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 083, Loss: 0.5910, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 44, Epoch: 084, Loss: 0.6010, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 085, Loss: 0.5955, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 086, Loss: 0.5953, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 087, Loss: 0.5918, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 44, Epoch: 088, Loss: 0.5962, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 089, Loss: 0.5988, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 090, Loss: 0.6003, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 091, Loss: 0.6056, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 092, Loss: 0.6091, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 093, Loss: 0.6089, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 094, Loss: 0.6106, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 095, Loss: 0.6104, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 096, Loss: 0.6173, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 097, Loss: 0.6156, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 098, Loss: 0.6181, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 099, Loss: 0.6060, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 100, Loss: 0.6062, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 101, Loss: 0.6002, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 44, Epoch: 102, Loss: 0.5931, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 103, Loss: 0.6132, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 44, Epoch: 104, Loss: 0.6155, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 105, Loss: 0.6221, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 106, Loss: 0.6263, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 107, Loss: 0.6136, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 108, Loss: 0.6093, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 109, Loss: 0.6138, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 110, Loss: 0.6026, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 111, Loss: 0.6028, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 44, Epoch: 112, Loss: 0.6057, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 44, Epoch: 113, Loss: 0.6046, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 114, Loss: 0.6037, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 115, Loss: 0.6007, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 116, Loss: 0.6004, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 117, Loss: 0.5969, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 44, Epoch: 118, Loss: 0.5927, Val Acc: 0.6928, Test Acc: 0.6786
# Seed: 44, Epoch: 119, Loss: 0.5968, Val Acc: 0.6928, Test Acc: 0.6845
# Seed: 44, Epoch: 120, Loss: 0.5896, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 44, Epoch: 121, Loss: 0.5987, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 122, Loss: 0.5992, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 123, Loss: 0.6021, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 44, Epoch: 124, Loss: 0.6114, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 44, Epoch: 125, Loss: 0.6006, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 44, Epoch: 126, Loss: 0.6021, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 127, Loss: 0.6115, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 44, Epoch: 128, Loss: 0.6038, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 44, Epoch: 129, Loss: 0.6030, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 44, Epoch: 130, Loss: 0.6028, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 44, Epoch: 131, Loss: 0.6079, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 44, Epoch: 132, Loss: 0.6011, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 133, Loss: 0.5994, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 134, Loss: 0.6020, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 135, Loss: 0.5917, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 136, Loss: 0.5919, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 44, Epoch: 137, Loss: 0.5878, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 138, Loss: 0.5884, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 139, Loss: 0.5953, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 140, Loss: 0.5984, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 44, Epoch: 141, Loss: 0.6049, Val Acc: 0.6566, Test Acc: 0.7560
# Seed: 44, Epoch: 142, Loss: 0.6045, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 143, Loss: 0.5962, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 144, Loss: 0.5949, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 145, Loss: 0.5922, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 146, Loss: 0.5918, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 147, Loss: 0.6147, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 44, Epoch: 148, Loss: 0.6096, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 149, Loss: 0.6034, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 150, Loss: 0.6036, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 44, Epoch: 151, Loss: 0.5996, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 44, Epoch: 152, Loss: 0.5980, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 44, Epoch: 153, Loss: 0.5937, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 154, Loss: 0.6032, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 155, Loss: 0.5943, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 156, Loss: 0.5972, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 157, Loss: 0.6011, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 44, Epoch: 158, Loss: 0.6037, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 44, Epoch: 159, Loss: 0.6050, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 44, Epoch: 160, Loss: 0.6110, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 44, Epoch: 161, Loss: 0.5967, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 162, Loss: 0.6010, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 44, Epoch: 163, Loss: 0.5910, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 164, Loss: 0.5887, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 44, Epoch: 165, Loss: 0.5854, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 166, Loss: 0.5841, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 167, Loss: 0.5913, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 168, Loss: 0.5872, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 169, Loss: 0.5811, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 170, Loss: 0.5795, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 171, Loss: 0.5860, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 172, Loss: 0.5856, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 173, Loss: 0.5821, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 44, Epoch: 174, Loss: 0.5826, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 175, Loss: 0.5908, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 176, Loss: 0.5939, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 177, Loss: 0.5859, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 178, Loss: 0.5935, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 179, Loss: 0.5906, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 180, Loss: 0.5842, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 181, Loss: 0.5935, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 44, Epoch: 182, Loss: 0.6127, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 44, Epoch: 183, Loss: 0.5992, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 44, Epoch: 184, Loss: 0.5816, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 185, Loss: 0.5796, Val Acc: 0.7289, Test Acc: 0.7083
# Early stopping at epoch 185 for seed 44
# Seed: 45, Epoch: 001, Loss: 0.6974, Val Acc: 0.6024, Test Acc: 0.6667
# Seed: 45, Epoch: 002, Loss: 0.6810, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 003, Loss: 0.6723, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 45, Epoch: 004, Loss: 0.6527, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 45, Epoch: 005, Loss: 0.6394, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 006, Loss: 0.6355, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 007, Loss: 0.6368, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 008, Loss: 0.6343, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 45, Epoch: 009, Loss: 0.6483, Val Acc: 0.6687, Test Acc: 0.6310
# Seed: 45, Epoch: 010, Loss: 0.6358, Val Acc: 0.6928, Test Acc: 0.6548
# Seed: 45, Epoch: 011, Loss: 0.6455, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 45, Epoch: 012, Loss: 0.6445, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 45, Epoch: 013, Loss: 0.6540, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 45, Epoch: 014, Loss: 0.6567, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 45, Epoch: 015, Loss: 0.6505, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 45, Epoch: 016, Loss: 0.6520, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 45, Epoch: 017, Loss: 0.6562, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 018, Loss: 0.6575, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 45, Epoch: 019, Loss: 0.6546, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 020, Loss: 0.6525, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 021, Loss: 0.6500, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 45, Epoch: 022, Loss: 0.6452, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 45, Epoch: 023, Loss: 0.6459, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 45, Epoch: 024, Loss: 0.6325, Val Acc: 0.7169, Test Acc: 0.6964
# Seed: 45, Epoch: 025, Loss: 0.6425, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 45, Epoch: 026, Loss: 0.6460, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 45, Epoch: 027, Loss: 0.6400, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 45, Epoch: 028, Loss: 0.6445, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 45, Epoch: 029, Loss: 0.6427, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 45, Epoch: 030, Loss: 0.6447, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 45, Epoch: 031, Loss: 0.6430, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 45, Epoch: 032, Loss: 0.6446, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 033, Loss: 0.6372, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 45, Epoch: 034, Loss: 0.6487, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 035, Loss: 0.6340, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 45, Epoch: 036, Loss: 0.6243, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 45, Epoch: 037, Loss: 0.6337, Val Acc: 0.7048, Test Acc: 0.6667
# Seed: 45, Epoch: 038, Loss: 0.6280, Val Acc: 0.6988, Test Acc: 0.6607
# Seed: 45, Epoch: 039, Loss: 0.6207, Val Acc: 0.7048, Test Acc: 0.6667
# Seed: 45, Epoch: 040, Loss: 0.6213, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 45, Epoch: 041, Loss: 0.6277, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 45, Epoch: 042, Loss: 0.6314, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 45, Epoch: 043, Loss: 0.6399, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 45, Epoch: 044, Loss: 0.6418, Val Acc: 0.6506, Test Acc: 0.7500
# Seed: 45, Epoch: 045, Loss: 0.6476, Val Acc: 0.6566, Test Acc: 0.7560
# Seed: 45, Epoch: 046, Loss: 0.6545, Val Acc: 0.6506, Test Acc: 0.7619
# Seed: 45, Epoch: 047, Loss: 0.6430, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 45, Epoch: 048, Loss: 0.6526, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 049, Loss: 0.6460, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 050, Loss: 0.6423, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 051, Loss: 0.6400, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 45, Epoch: 052, Loss: 0.6346, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 45, Epoch: 053, Loss: 0.6369, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 45, Epoch: 054, Loss: 0.6354, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 055, Loss: 0.6248, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 45, Epoch: 056, Loss: 0.6261, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 45, Epoch: 057, Loss: 0.6360, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 45, Epoch: 058, Loss: 0.6256, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 059, Loss: 0.6446, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 060, Loss: 0.6353, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 061, Loss: 0.6401, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 45, Epoch: 062, Loss: 0.6432, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 063, Loss: 0.6389, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 064, Loss: 0.6305, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 065, Loss: 0.6362, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 45, Epoch: 066, Loss: 0.6237, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 45, Epoch: 067, Loss: 0.6277, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 45, Epoch: 068, Loss: 0.6229, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 45, Epoch: 069, Loss: 0.6301, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 45, Epoch: 070, Loss: 0.6357, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 071, Loss: 0.6407, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 45, Epoch: 072, Loss: 0.6309, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 45, Epoch: 073, Loss: 0.6309, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 45, Epoch: 074, Loss: 0.6223, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 45, Epoch: 075, Loss: 0.6289, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 076, Loss: 0.6280, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 077, Loss: 0.6279, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 45, Epoch: 078, Loss: 0.6379, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 45, Epoch: 079, Loss: 0.6228, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 080, Loss: 0.6157, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 45, Epoch: 081, Loss: 0.6208, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 45, Epoch: 082, Loss: 0.6540, Val Acc: 0.6446, Test Acc: 0.7024
# Seed: 45, Epoch: 083, Loss: 0.6632, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 084, Loss: 0.6289, Val Acc: 0.6867, Test Acc: 0.6726
# Seed: 45, Epoch: 085, Loss: 0.6276, Val Acc: 0.6867, Test Acc: 0.6548
# Seed: 45, Epoch: 086, Loss: 0.6314, Val Acc: 0.6807, Test Acc: 0.6607
# Seed: 45, Epoch: 087, Loss: 0.6272, Val Acc: 0.6928, Test Acc: 0.6667
# Seed: 45, Epoch: 088, Loss: 0.6296, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 45, Epoch: 089, Loss: 0.6368, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 090, Loss: 0.6412, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 45, Epoch: 091, Loss: 0.6410, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 45, Epoch: 092, Loss: 0.6498, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 45, Epoch: 093, Loss: 0.6390, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 45, Epoch: 094, Loss: 0.6253, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 45, Epoch: 095, Loss: 0.6193, Val Acc: 0.7289, Test Acc: 0.6905
# Seed: 45, Epoch: 096, Loss: 0.6148, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 45, Epoch: 097, Loss: 0.6126, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 45, Epoch: 098, Loss: 0.6375, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 45, Epoch: 099, Loss: 0.6069, Val Acc: 0.6928, Test Acc: 0.6607
# Seed: 45, Epoch: 100, Loss: 0.6142, Val Acc: 0.6687, Test Acc: 0.6488
# ...
# Seed: 45, Epoch: 175, Loss: 0.5750, Val Acc: 0.7651, Test Acc: 0.7202
# Seed: 45, Epoch: 176, Loss: 0.5630, Val Acc: 0.7831, Test Acc: 0.7083
# Seed: 45, Epoch: 177, Loss: 0.5879, Val Acc: 0.7771, Test Acc: 0.7321
# Seed: 45, Epoch: 178, Loss: 0.5835, Val Acc: 0.7651, Test Acc: 0.7321
# Seed: 45, Epoch: 179, Loss: 0.5743, Val Acc: 0.7711, Test Acc: 0.7202
# Seed: 45, Epoch: 180, Loss: 0.5808, Val Acc: 0.7530, Test Acc: 0.7202
# Seed: 45, Epoch: 181, Loss: 0.5700, Val Acc: 0.7651, Test Acc: 0.7083
# Seed: 45, Epoch: 182, Loss: 0.5638, Val Acc: 0.7651, Test Acc: 0.6845
# Seed: 45, Epoch: 183, Loss: 0.5617, Val Acc: 0.7711, Test Acc: 0.6726
# Seed: 45, Epoch: 184, Loss: 0.5574, Val Acc: 0.7530, Test Acc: 0.7024
# Seed: 45, Epoch: 185, Loss: 0.5616, Val Acc: 0.7711, Test Acc: 0.7262
# Seed: 45, Epoch: 186, Loss: 0.5506, Val Acc: 0.7530, Test Acc: 0.6905
# Seed: 45, Epoch: 187, Loss: 0.5593, Val Acc: 0.7470, Test Acc: 0.6726
# Seed: 45, Epoch: 188, Loss: 0.5536, Val Acc: 0.7410, Test Acc: 0.6786
# Seed: 45, Epoch: 189, Loss: 0.5634, Val Acc: 0.7711, Test Acc: 0.6964
# Seed: 45, Epoch: 190, Loss: 0.5539, Val Acc: 0.7590, Test Acc: 0.7143
# Seed: 45, Epoch: 191, Loss: 0.7197, Val Acc: 0.6566, Test Acc: 0.6488
# Seed: 45, Epoch: 192, Loss: 0.6354, Val Acc: 0.7771, Test Acc: 0.7143
# Seed: 45, Epoch: 193, Loss: 0.5699, Val Acc: 0.7108, Test Acc: 0.6667
# Seed: 45, Epoch: 194, Loss: 0.5923, Val Acc: 0.7229, Test Acc: 0.6786
# Seed: 45, Epoch: 195, Loss: 0.6096, Val Acc: 0.6988, Test Acc: 0.6786
# Seed: 45, Epoch: 196, Loss: 0.6221, Val Acc: 0.6867, Test Acc: 0.6548
# Seed: 45, Epoch: 197, Loss: 0.6243, Val Acc: 0.6506, Test Acc: 0.6548
# Seed: 45, Epoch: 198, Loss: 0.6284, Val Acc: 0.6867, Test Acc: 0.6786
# Seed: 45, Epoch: 199, Loss: 0.6107, Val Acc: 0.7048, Test Acc: 0.6607
# Seed: 45, Epoch: 200, Loss: 0.6056, Val Acc: 0.6867, Test Acc: 0.6786
# Seed: 46, Epoch: 001, Loss: 0.6875, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 002, Loss: 0.6725, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 003, Loss: 0.6643, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 004, Loss: 0.6498, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 005, Loss: 0.6494, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 006, Loss: 0.6552, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 007, Loss: 0.6458, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 008, Loss: 0.6424, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 009, Loss: 0.6353, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 010, Loss: 0.6301, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 011, Loss: 0.6430, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 012, Loss: 0.6453, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 013, Loss: 0.6445, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 46, Epoch: 014, Loss: 0.6587, Val Acc: 0.6566, Test Acc: 0.7083
# Seed: 46, Epoch: 015, Loss: 0.6550, Val Acc: 0.6566, Test Acc: 0.7083
# Seed: 46, Epoch: 016, Loss: 0.6532, Val Acc: 0.6928, Test Acc: 0.6845
# Seed: 46, Epoch: 017, Loss: 0.6450, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 46, Epoch: 018, Loss: 0.6414, Val Acc: 0.6807, Test Acc: 0.6786
# Seed: 46, Epoch: 019, Loss: 0.6359, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 46, Epoch: 020, Loss: 0.6403, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 46, Epoch: 021, Loss: 0.6413, Val Acc: 0.6627, Test Acc: 0.6964
# Seed: 46, Epoch: 022, Loss: 0.6424, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 46, Epoch: 023, Loss: 0.6412, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 024, Loss: 0.6457, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 025, Loss: 0.6419, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 46, Epoch: 026, Loss: 0.6272, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 46, Epoch: 027, Loss: 0.6302, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 46, Epoch: 028, Loss: 0.6160, Val Acc: 0.6687, Test Acc: 0.7024
# Seed: 46, Epoch: 029, Loss: 0.6093, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 46, Epoch: 030, Loss: 0.6160, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 46, Epoch: 031, Loss: 0.6084, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 032, Loss: 0.6076, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 033, Loss: 0.6286, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 034, Loss: 0.6206, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 035, Loss: 0.5990, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 036, Loss: 0.6025, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 037, Loss: 0.6022, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 038, Loss: 0.5972, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 46, Epoch: 039, Loss: 0.6006, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 46, Epoch: 040, Loss: 0.6007, Val Acc: 0.7048, Test Acc: 0.7857
# Seed: 46, Epoch: 041, Loss: 0.6101, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 46, Epoch: 042, Loss: 0.6015, Val Acc: 0.7048, Test Acc: 0.7857
# Seed: 46, Epoch: 043, Loss: 0.6034, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 044, Loss: 0.6048, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 045, Loss: 0.6121, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 046, Loss: 0.6065, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 46, Epoch: 047, Loss: 0.6067, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 46, Epoch: 048, Loss: 0.6210, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 46, Epoch: 049, Loss: 0.6204, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 46, Epoch: 050, Loss: 0.6256, Val Acc: 0.7048, Test Acc: 0.7917
# Seed: 46, Epoch: 051, Loss: 0.6164, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 46, Epoch: 052, Loss: 0.6190, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 46, Epoch: 053, Loss: 0.6131, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 46, Epoch: 054, Loss: 0.5999, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 46, Epoch: 055, Loss: 0.6084, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 46, Epoch: 056, Loss: 0.6089, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 46, Epoch: 057, Loss: 0.6003, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 058, Loss: 0.6055, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 059, Loss: 0.6009, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 060, Loss: 0.5954, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 46, Epoch: 061, Loss: 0.6022, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 062, Loss: 0.5928, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 063, Loss: 0.6009, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 064, Loss: 0.5930, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 065, Loss: 0.5989, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 066, Loss: 0.6056, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 067, Loss: 0.6007, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 46, Epoch: 068, Loss: 0.5863, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 069, Loss: 0.5872, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 46, Epoch: 070, Loss: 0.5829, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 071, Loss: 0.5872, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 072, Loss: 0.5819, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 46, Epoch: 073, Loss: 0.5825, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 074, Loss: 0.5882, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 075, Loss: 0.5865, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 076, Loss: 0.5736, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 077, Loss: 0.5945, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 078, Loss: 0.6109, Val Acc: 0.6627, Test Acc: 0.7024
# Seed: 46, Epoch: 079, Loss: 0.6138, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 080, Loss: 0.6086, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 081, Loss: 0.5913, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 46, Epoch: 082, Loss: 0.6189, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 46, Epoch: 083, Loss: 0.5881, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 084, Loss: 0.5843, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 085, Loss: 0.5886, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 46, Epoch: 086, Loss: 0.5807, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 087, Loss: 0.5785, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 088, Loss: 0.5831, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 089, Loss: 0.5744, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 090, Loss: 0.5932, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 46, Epoch: 091, Loss: 0.5949, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 092, Loss: 0.6054, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 093, Loss: 0.5980, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 46, Epoch: 094, Loss: 0.5976, Val Acc: 0.6687, Test Acc: 0.6667
# Seed: 46, Epoch: 095, Loss: 0.6198, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 46, Epoch: 096, Loss: 0.5931, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 097, Loss: 0.6135, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 46, Epoch: 098, Loss: 0.5920, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 46, Epoch: 099, Loss: 0.5881, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 46, Epoch: 100, Loss: 0.5938, Val Acc: 0.6627, Test Acc: 0.7024
# Seed: 46, Epoch: 101, Loss: 0.5941, Val Acc: 0.6687, Test Acc: 0.7024
# Seed: 46, Epoch: 102, Loss: 0.5929, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 46, Epoch: 103, Loss: 0.5906, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 46, Epoch: 104, Loss: 0.6008, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 46, Epoch: 105, Loss: 0.5868, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 46, Epoch: 106, Loss: 0.5872, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 107, Loss: 0.5852, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 108, Loss: 0.5858, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 46, Epoch: 109, Loss: 0.5869, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 110, Loss: 0.5809, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 46, Epoch: 111, Loss: 0.5761, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 46, Epoch: 112, Loss: 0.5752, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 113, Loss: 0.5734, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 114, Loss: 0.5788, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 115, Loss: 0.5737, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 116, Loss: 0.5748, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 117, Loss: 0.5728, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 118, Loss: 0.5793, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 119, Loss: 0.5845, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 120, Loss: 0.5863, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 121, Loss: 0.5931, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 122, Loss: 0.5892, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 123, Loss: 0.5884, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 124, Loss: 0.5942, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 125, Loss: 0.5835, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 126, Loss: 0.5819, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 127, Loss: 0.5800, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 46, Epoch: 128, Loss: 0.5786, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 46, Epoch: 129, Loss: 0.5730, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 46, Epoch: 130, Loss: 0.5733, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 131, Loss: 0.5665, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 132, Loss: 0.5730, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 133, Loss: 0.5678, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 134, Loss: 0.5723, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 135, Loss: 0.5732, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 136, Loss: 0.5715, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 137, Loss: 0.5560, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 138, Loss: 0.5637, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 46, Epoch: 139, Loss: 0.5618, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 140, Loss: 0.5628, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 141, Loss: 0.5579, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 142, Loss: 0.5574, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 143, Loss: 0.5599, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 144, Loss: 0.5748, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 46, Epoch: 145, Loss: 0.5621, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 146, Loss: 0.5964, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 147, Loss: 0.6045, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 148, Loss: 0.6126, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 149, Loss: 0.6009, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 150, Loss: 0.5880, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 151, Loss: 0.5637, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 46, Epoch: 152, Loss: 0.5615, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 46, Epoch: 153, Loss: 0.5634, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 154, Loss: 0.5620, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 155, Loss: 0.5632, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 46, Epoch: 156, Loss: 0.5588, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 46, Epoch: 157, Loss: 0.5604, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 158, Loss: 0.5585, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 46, Epoch: 159, Loss: 0.5684, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 46, Epoch: 160, Loss: 0.5769, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 161, Loss: 0.5820, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 46, Epoch: 162, Loss: 0.6048, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 46, Epoch: 163, Loss: 0.6035, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 46, Epoch: 164, Loss: 0.5862, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 46, Epoch: 165, Loss: 0.5795, Val Acc: 0.7470, Test Acc: 0.7262
# Seed: 46, Epoch: 166, Loss: 0.5723, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 167, Loss: 0.5774, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 46, Epoch: 168, Loss: 0.5745, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 169, Loss: 0.5674, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 170, Loss: 0.5618, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 171, Loss: 0.5587, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 172, Loss: 0.5545, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 173, Loss: 0.5540, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 174, Loss: 0.5610, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 175, Loss: 0.5547, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 46, Epoch: 176, Loss: 0.5540, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 46, Epoch: 177, Loss: 0.5682, Val Acc: 0.7590, Test Acc: 0.7202
# Seed: 46, Epoch: 178, Loss: 0.5730, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 46, Epoch: 179, Loss: 0.5742, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 46, Epoch: 180, Loss: 0.5775, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 46, Epoch: 181, Loss: 0.5680, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 46, Epoch: 182, Loss: 0.5736, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 46, Epoch: 183, Loss: 0.5733, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 46, Epoch: 184, Loss: 0.5765, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 46, Epoch: 185, Loss: 0.5759, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 46, Epoch: 186, Loss: 0.5729, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 46, Epoch: 187, Loss: 0.5712, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 46, Epoch: 188, Loss: 0.5770, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 46, Epoch: 189, Loss: 0.5625, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 46, Epoch: 190, Loss: 0.5683, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 46, Epoch: 191, Loss: 0.5609, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 46, Epoch: 192, Loss: 0.5601, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 193, Loss: 0.5635, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 194, Loss: 0.5714, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 46, Epoch: 195, Loss: 0.5898, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 46, Epoch: 196, Loss: 0.5789, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 197, Loss: 0.5757, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 46, Epoch: 198, Loss: 0.5745, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 199, Loss: 0.5718, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 200, Loss: 0.5818, Val Acc: 0.6867, Test Acc: 0.7440
# Average Time: 16.95 seconds
# Var Time: 0.36 seconds
# Average Memory: 206.00 MB
# Average Best Val Acc: 0.7554
# Std Best Test Acc: 0.0236
# Average Test Acc: 0.7274

# %% [markdown]
# ## SAGPooling with HierarchicalGCN (2019)

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, SAGPooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch
from torch_geometric.nn import BatchNorm

class HierarchicalGCN_SAG(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_SAG, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool1 = SAGPooling(hidden_channels, ratio=0.5)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool2 = SAGPooling(hidden_channels, ratio=0.5)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, _, batch, _, _ = self.pool1(x, edge_index, None, batch)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, _, batch, _, _ = self.pool2(x, edge_index, None, batch)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_SAG(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_SAG(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6941, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 002, Loss: 0.6894, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 003, Loss: 0.6766, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 004, Loss: 0.6601, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 005, Loss: 0.6495, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 006, Loss: 0.6396, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 007, Loss: 0.6357, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 008, Loss: 0.6364, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 009, Loss: 0.6381, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 010, Loss: 0.6408, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 011, Loss: 0.6472, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 012, Loss: 0.6264, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 013, Loss: 0.6385, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 014, Loss: 0.6349, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 015, Loss: 0.6335, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 016, Loss: 0.6223, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 017, Loss: 0.6300, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 42, Epoch: 018, Loss: 0.6289, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 42, Epoch: 019, Loss: 0.6365, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 42, Epoch: 020, Loss: 0.6435, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 42, Epoch: 021, Loss: 0.6478, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 022, Loss: 0.6616, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 42, Epoch: 023, Loss: 0.6700, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 024, Loss: 0.6611, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 42, Epoch: 025, Loss: 0.6657, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 026, Loss: 0.6562, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 027, Loss: 0.6658, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 028, Loss: 0.6630, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 029, Loss: 0.6545, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 030, Loss: 0.6534, Val Acc: 0.6988, Test Acc: 0.6667
# Seed: 42, Epoch: 031, Loss: 0.6427, Val Acc: 0.6807, Test Acc: 0.6548
# Seed: 42, Epoch: 032, Loss: 0.6395, Val Acc: 0.6867, Test Acc: 0.6488
# Seed: 42, Epoch: 033, Loss: 0.6303, Val Acc: 0.6867, Test Acc: 0.6429
# Seed: 42, Epoch: 034, Loss: 0.6281, Val Acc: 0.6867, Test Acc: 0.6548
# Seed: 42, Epoch: 035, Loss: 0.6289, Val Acc: 0.6807, Test Acc: 0.6726
# Seed: 42, Epoch: 036, Loss: 0.6284, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 42, Epoch: 037, Loss: 0.6358, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 42, Epoch: 038, Loss: 0.6246, Val Acc: 0.6867, Test Acc: 0.6726
# Seed: 42, Epoch: 039, Loss: 0.6265, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 040, Loss: 0.6351, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 041, Loss: 0.6342, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 42, Epoch: 042, Loss: 0.6469, Val Acc: 0.6506, Test Acc: 0.7679
# Seed: 42, Epoch: 043, Loss: 0.6591, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 42, Epoch: 044, Loss: 0.6477, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 42, Epoch: 045, Loss: 0.6422, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 046, Loss: 0.6456, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 047, Loss: 0.6216, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 048, Loss: 0.6309, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 049, Loss: 0.6256, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 050, Loss: 0.6343, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 051, Loss: 0.6252, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 052, Loss: 0.6347, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 42, Epoch: 053, Loss: 0.6320, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 054, Loss: 0.6315, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 055, Loss: 0.6233, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 056, Loss: 0.6222, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 42, Epoch: 057, Loss: 0.6206, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 058, Loss: 0.6145, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 059, Loss: 0.6104, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 42, Epoch: 060, Loss: 0.6118, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 42, Epoch: 061, Loss: 0.6165, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 062, Loss: 0.6081, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 42, Epoch: 063, Loss: 0.6263, Val Acc: 0.6687, Test Acc: 0.7738
# Seed: 42, Epoch: 064, Loss: 0.6167, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 065, Loss: 0.6215, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 42, Epoch: 066, Loss: 0.6198, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 42, Epoch: 067, Loss: 0.6208, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 42, Epoch: 068, Loss: 0.6184, Val Acc: 0.6687, Test Acc: 0.7679
# Seed: 42, Epoch: 069, Loss: 0.6210, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 42, Epoch: 070, Loss: 0.6148, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 071, Loss: 0.6076, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 42, Epoch: 072, Loss: 0.6100, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 073, Loss: 0.6183, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 42, Epoch: 074, Loss: 0.6240, Val Acc: 0.6687, Test Acc: 0.7798
# Seed: 42, Epoch: 075, Loss: 0.6225, Val Acc: 0.6747, Test Acc: 0.7857
# Seed: 42, Epoch: 076, Loss: 0.6168, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 42, Epoch: 077, Loss: 0.6144, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 42, Epoch: 078, Loss: 0.6020, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 42, Epoch: 079, Loss: 0.6075, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 42, Epoch: 080, Loss: 0.5947, Val Acc: 0.6446, Test Acc: 0.7679
# Seed: 42, Epoch: 081, Loss: 0.5986, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 082, Loss: 0.6016, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 083, Loss: 0.6019, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 084, Loss: 0.6045, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 42, Epoch: 085, Loss: 0.6073, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 42, Epoch: 086, Loss: 0.6077, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 42, Epoch: 087, Loss: 0.6043, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 42, Epoch: 088, Loss: 0.5995, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 089, Loss: 0.5951, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 090, Loss: 0.6023, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 42, Epoch: 091, Loss: 0.5892, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 092, Loss: 0.5968, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 093, Loss: 0.5850, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 42, Epoch: 094, Loss: 0.5976, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 42, Epoch: 095, Loss: 0.6205, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 096, Loss: 0.5817, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 097, Loss: 0.5847, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 098, Loss: 0.5876, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 099, Loss: 0.5940, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 100, Loss: 0.5948, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 42, Epoch: 101, Loss: 0.6000, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 102, Loss: 0.6012, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 42, Epoch: 103, Loss: 0.6328, Val Acc: 0.6566, Test Acc: 0.7976
# Seed: 42, Epoch: 104, Loss: 0.6389, Val Acc: 0.6627, Test Acc: 0.7798
# Seed: 42, Epoch: 105, Loss: 0.6370, Val Acc: 0.6867, Test Acc: 0.7917
# Seed: 42, Epoch: 106, Loss: 0.6279, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 42, Epoch: 107, Loss: 0.6183, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 108, Loss: 0.6025, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 109, Loss: 0.6085, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 42, Epoch: 110, Loss: 0.5941, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 111, Loss: 0.6002, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 112, Loss: 0.5964, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 113, Loss: 0.5900, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 114, Loss: 0.5894, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 115, Loss: 0.5952, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 116, Loss: 0.5831, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 117, Loss: 0.5790, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 42, Epoch: 118, Loss: 0.5726, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 42, Epoch: 119, Loss: 0.5841, Val Acc: 0.6627, Test Acc: 0.7321
# Seed: 42, Epoch: 120, Loss: 0.6034, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 42, Epoch: 121, Loss: 0.5815, Val Acc: 0.6928, Test Acc: 0.7857
# Seed: 42, Epoch: 122, Loss: 0.6074, Val Acc: 0.6867, Test Acc: 0.7917
# Seed: 42, Epoch: 123, Loss: 0.6202, Val Acc: 0.6928, Test Acc: 0.7917
# Seed: 42, Epoch: 124, Loss: 0.6193, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 42, Epoch: 125, Loss: 0.6217, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 42, Epoch: 126, Loss: 0.6121, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 42, Epoch: 127, Loss: 0.6089, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 42, Epoch: 128, Loss: 0.6047, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 42, Epoch: 129, Loss: 0.5974, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 130, Loss: 0.5908, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 131, Loss: 0.5844, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 42, Epoch: 132, Loss: 0.5877, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 42, Epoch: 133, Loss: 0.5840, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 42, Epoch: 134, Loss: 0.5785, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 42, Epoch: 135, Loss: 0.5772, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 42, Epoch: 136, Loss: 0.5687, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 42, Epoch: 137, Loss: 0.5715, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 138, Loss: 0.5648, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 42, Epoch: 139, Loss: 0.5723, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 42, Epoch: 140, Loss: 0.5831, Val Acc: 0.6928, Test Acc: 0.7917
# Seed: 42, Epoch: 141, Loss: 0.5869, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 42, Epoch: 142, Loss: 0.5862, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 143, Loss: 0.5841, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 144, Loss: 0.5768, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 145, Loss: 0.5722, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 146, Loss: 0.5755, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 147, Loss: 0.5741, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 42, Epoch: 148, Loss: 0.5800, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 42, Epoch: 149, Loss: 0.5796, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 150, Loss: 0.5768, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 151, Loss: 0.5936, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 152, Loss: 0.5836, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 153, Loss: 0.5941, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 42, Epoch: 154, Loss: 0.6037, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 155, Loss: 0.6056, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 156, Loss: 0.6019, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 157, Loss: 0.5874, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 42, Epoch: 158, Loss: 0.5902, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 42, Epoch: 159, Loss: 0.5869, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 160, Loss: 0.6085, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 161, Loss: 0.6087, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 162, Loss: 0.6052, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 163, Loss: 0.5994, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 164, Loss: 0.5882, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 165, Loss: 0.5891, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 166, Loss: 0.5787, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 167, Loss: 0.5764, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 168, Loss: 0.5811, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 169, Loss: 0.5839, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 170, Loss: 0.5791, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 171, Loss: 0.5925, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 172, Loss: 0.5943, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 42, Epoch: 173, Loss: 0.5855, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 174, Loss: 0.5807, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 175, Loss: 0.5733, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 176, Loss: 0.5867, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 177, Loss: 0.5868, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 42, Epoch: 178, Loss: 0.5841, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 179, Loss: 0.5869, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 180, Loss: 0.5800, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 181, Loss: 0.5739, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 182, Loss: 0.5914, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 183, Loss: 0.5955, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 184, Loss: 0.5844, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 42, Epoch: 185, Loss: 0.5717, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 42, Epoch: 186, Loss: 0.5739, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 187, Loss: 0.5717, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 188, Loss: 0.5727, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 189, Loss: 0.5736, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 190, Loss: 0.5744, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 191, Loss: 0.5819, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 192, Loss: 0.5833, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 42, Epoch: 193, Loss: 0.5758, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 194, Loss: 0.5738, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 195, Loss: 0.5758, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 196, Loss: 0.5698, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 197, Loss: 0.5679, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 198, Loss: 0.5804, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 199, Loss: 0.5693, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 42, Epoch: 200, Loss: 0.5853, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 43, Epoch: 001, Loss: 0.6943, Val Acc: 0.6386, Test Acc: 0.6131
# Seed: 43, Epoch: 002, Loss: 0.6900, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 43, Epoch: 003, Loss: 0.6865, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 004, Loss: 0.6758, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 005, Loss: 0.6643, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 006, Loss: 0.6567, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 007, Loss: 0.6444, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 008, Loss: 0.6439, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 009, Loss: 0.6486, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 010, Loss: 0.6440, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 011, Loss: 0.6478, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 012, Loss: 0.6560, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 013, Loss: 0.6625, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 014, Loss: 0.6606, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 015, Loss: 0.6613, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 016, Loss: 0.6608, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 017, Loss: 0.6563, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 018, Loss: 0.6647, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 019, Loss: 0.6556, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 020, Loss: 0.6582, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 021, Loss: 0.6600, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 022, Loss: 0.6582, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 023, Loss: 0.6509, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 024, Loss: 0.6522, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 025, Loss: 0.6433, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 026, Loss: 0.6473, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 027, Loss: 0.6508, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 028, Loss: 0.6459, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 029, Loss: 0.6424, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 43, Epoch: 030, Loss: 0.6451, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 031, Loss: 0.6507, Val Acc: 0.6687, Test Acc: 0.6310
# Seed: 43, Epoch: 032, Loss: 0.6504, Val Acc: 0.6867, Test Acc: 0.6369
# Seed: 43, Epoch: 033, Loss: 0.6468, Val Acc: 0.6988, Test Acc: 0.6667
# Seed: 43, Epoch: 034, Loss: 0.6552, Val Acc: 0.7169, Test Acc: 0.6726
# Seed: 43, Epoch: 035, Loss: 0.6450, Val Acc: 0.6867, Test Acc: 0.6369
# Seed: 43, Epoch: 036, Loss: 0.6407, Val Acc: 0.6928, Test Acc: 0.6369
# Seed: 43, Epoch: 037, Loss: 0.6428, Val Acc: 0.6928, Test Acc: 0.6369
# Seed: 43, Epoch: 038, Loss: 0.6292, Val Acc: 0.6988, Test Acc: 0.6726
# Seed: 43, Epoch: 039, Loss: 0.6431, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 040, Loss: 0.6457, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 041, Loss: 0.6473, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 042, Loss: 0.6304, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 43, Epoch: 043, Loss: 0.6405, Val Acc: 0.6988, Test Acc: 0.6726
# Seed: 43, Epoch: 044, Loss: 0.6273, Val Acc: 0.6988, Test Acc: 0.6726
# Seed: 43, Epoch: 045, Loss: 0.6295, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 43, Epoch: 046, Loss: 0.6278, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 43, Epoch: 047, Loss: 0.6276, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 43, Epoch: 048, Loss: 0.6202, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 43, Epoch: 049, Loss: 0.6266, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 050, Loss: 0.6105, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 43, Epoch: 051, Loss: 0.6190, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 052, Loss: 0.6169, Val Acc: 0.7169, Test Acc: 0.7976
# Seed: 43, Epoch: 053, Loss: 0.6237, Val Acc: 0.6506, Test Acc: 0.6905
# Seed: 43, Epoch: 054, Loss: 0.6483, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 055, Loss: 0.6249, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 43, Epoch: 056, Loss: 0.6228, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 057, Loss: 0.6215, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 058, Loss: 0.6069, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 43, Epoch: 059, Loss: 0.6106, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 060, Loss: 0.6099, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 061, Loss: 0.6281, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 43, Epoch: 062, Loss: 0.6094, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 43, Epoch: 063, Loss: 0.6104, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 064, Loss: 0.6255, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 065, Loss: 0.6159, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 43, Epoch: 066, Loss: 0.6501, Val Acc: 0.5843, Test Acc: 0.6548
# Seed: 43, Epoch: 067, Loss: 0.6546, Val Acc: 0.5964, Test Acc: 0.6607
# Seed: 43, Epoch: 068, Loss: 0.6544, Val Acc: 0.6566, Test Acc: 0.7202
# Seed: 43, Epoch: 069, Loss: 0.6509, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 43, Epoch: 070, Loss: 0.6308, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 071, Loss: 0.6188, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 072, Loss: 0.6083, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 073, Loss: 0.6158, Val Acc: 0.7048, Test Acc: 0.6845
# Seed: 43, Epoch: 074, Loss: 0.6074, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 075, Loss: 0.6141, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 076, Loss: 0.6141, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 43, Epoch: 077, Loss: 0.6168, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 43, Epoch: 078, Loss: 0.6030, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 43, Epoch: 079, Loss: 0.6082, Val Acc: 0.7169, Test Acc: 0.7798
# Seed: 43, Epoch: 080, Loss: 0.6131, Val Acc: 0.7289, Test Acc: 0.7857
# Seed: 43, Epoch: 081, Loss: 0.6084, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 082, Loss: 0.6114, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 43, Epoch: 083, Loss: 0.6093, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 43, Epoch: 084, Loss: 0.6043, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 085, Loss: 0.6064, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 43, Epoch: 086, Loss: 0.6235, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 087, Loss: 0.6187, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 43, Epoch: 088, Loss: 0.6110, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 43, Epoch: 089, Loss: 0.6065, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 090, Loss: 0.5916, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 091, Loss: 0.5893, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 092, Loss: 0.5797, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 093, Loss: 0.5958, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 094, Loss: 0.5801, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 095, Loss: 0.5919, Val Acc: 0.7349, Test Acc: 0.7798
# Seed: 43, Epoch: 096, Loss: 0.5902, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 43, Epoch: 097, Loss: 0.6095, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 098, Loss: 0.6076, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 43, Epoch: 099, Loss: 0.5949, Val Acc: 0.7289, Test Acc: 0.7798
# Seed: 43, Epoch: 100, Loss: 0.5910, Val Acc: 0.7470, Test Acc: 0.7679
# Seed: 43, Epoch: 101, Loss: 0.5834, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 43, Epoch: 102, Loss: 0.5956, Val Acc: 0.7229, Test Acc: 0.7857
# Seed: 43, Epoch: 103, Loss: 0.6007, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 104, Loss: 0.6139, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 105, Loss: 0.5887, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 43, Epoch: 106, Loss: 0.6035, Val Acc: 0.7349, Test Acc: 0.7857
# Seed: 43, Epoch: 107, Loss: 0.5962, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 108, Loss: 0.5924, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 109, Loss: 0.5925, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 110, Loss: 0.5924, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 111, Loss: 0.5876, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 43, Epoch: 112, Loss: 0.5913, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 43, Epoch: 113, Loss: 0.5952, Val Acc: 0.7349, Test Acc: 0.7857
# Seed: 43, Epoch: 114, Loss: 0.5931, Val Acc: 0.7349, Test Acc: 0.7917
# Seed: 43, Epoch: 115, Loss: 0.5956, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 116, Loss: 0.5904, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 43, Epoch: 117, Loss: 0.5856, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 118, Loss: 0.5838, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 119, Loss: 0.5787, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 120, Loss: 0.5808, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 43, Epoch: 121, Loss: 0.5795, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 122, Loss: 0.5726, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 43, Epoch: 123, Loss: 0.5740, Val Acc: 0.7410, Test Acc: 0.7976
# Seed: 43, Epoch: 124, Loss: 0.5999, Val Acc: 0.7470, Test Acc: 0.7798
# Seed: 43, Epoch: 125, Loss: 0.5952, Val Acc: 0.7530, Test Acc: 0.7679
# Seed: 43, Epoch: 126, Loss: 0.6085, Val Acc: 0.7651, Test Acc: 0.7917
# Seed: 43, Epoch: 127, Loss: 0.5823, Val Acc: 0.7169, Test Acc: 0.6964
# Seed: 43, Epoch: 128, Loss: 0.5899, Val Acc: 0.7108, Test Acc: 0.6726
# Seed: 43, Epoch: 129, Loss: 0.5905, Val Acc: 0.7048, Test Acc: 0.6726
# Seed: 43, Epoch: 130, Loss: 0.5933, Val Acc: 0.7048, Test Acc: 0.6845
# Seed: 43, Epoch: 131, Loss: 0.5951, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 43, Epoch: 132, Loss: 0.5868, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 43, Epoch: 133, Loss: 0.5910, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 43, Epoch: 134, Loss: 0.5961, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 43, Epoch: 135, Loss: 0.6044, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 43, Epoch: 136, Loss: 0.5930, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 43, Epoch: 137, Loss: 0.5866, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 138, Loss: 0.5914, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 139, Loss: 0.5781, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 43, Epoch: 140, Loss: 0.5833, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 43, Epoch: 141, Loss: 0.5713, Val Acc: 0.7289, Test Acc: 0.8095
# Seed: 43, Epoch: 142, Loss: 0.5756, Val Acc: 0.7169, Test Acc: 0.7976
# Seed: 43, Epoch: 143, Loss: 0.5829, Val Acc: 0.7410, Test Acc: 0.7976
# Seed: 43, Epoch: 144, Loss: 0.5724, Val Acc: 0.7289, Test Acc: 0.7857
# Seed: 43, Epoch: 145, Loss: 0.5679, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 43, Epoch: 146, Loss: 0.5691, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 147, Loss: 0.5793, Val Acc: 0.7289, Test Acc: 0.7917
# Seed: 43, Epoch: 148, Loss: 0.5778, Val Acc: 0.7590, Test Acc: 0.7917
# Seed: 43, Epoch: 149, Loss: 0.6057, Val Acc: 0.7410, Test Acc: 0.7798
# Seed: 43, Epoch: 150, Loss: 0.5866, Val Acc: 0.7470, Test Acc: 0.7857
# Seed: 43, Epoch: 151, Loss: 0.5914, Val Acc: 0.7590, Test Acc: 0.7857
# Seed: 43, Epoch: 152, Loss: 0.6056, Val Acc: 0.7530, Test Acc: 0.7798
# Seed: 43, Epoch: 153, Loss: 0.5902, Val Acc: 0.7410, Test Acc: 0.7917
# Seed: 43, Epoch: 154, Loss: 0.5792, Val Acc: 0.7410, Test Acc: 0.7857
# Seed: 43, Epoch: 155, Loss: 0.5698, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 43, Epoch: 156, Loss: 0.5788, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 157, Loss: 0.5802, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 43, Epoch: 158, Loss: 0.5754, Val Acc: 0.7410, Test Acc: 0.7798
# Seed: 43, Epoch: 159, Loss: 0.5837, Val Acc: 0.7590, Test Acc: 0.7679
# Seed: 43, Epoch: 160, Loss: 0.5896, Val Acc: 0.7349, Test Acc: 0.7976
# Seed: 43, Epoch: 161, Loss: 0.5783, Val Acc: 0.7289, Test Acc: 0.7976
# Seed: 43, Epoch: 162, Loss: 0.5832, Val Acc: 0.7349, Test Acc: 0.7857
# Seed: 43, Epoch: 163, Loss: 0.6018, Val Acc: 0.7349, Test Acc: 0.7917
# Seed: 43, Epoch: 164, Loss: 0.5735, Val Acc: 0.7349, Test Acc: 0.6905
# Seed: 43, Epoch: 165, Loss: 0.5836, Val Acc: 0.7229, Test Acc: 0.6548
# Seed: 43, Epoch: 166, Loss: 0.5897, Val Acc: 0.7169, Test Acc: 0.6607
# Seed: 43, Epoch: 167, Loss: 0.5967, Val Acc: 0.7169, Test Acc: 0.6667
# Seed: 43, Epoch: 168, Loss: 0.5973, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 43, Epoch: 169, Loss: 0.5960, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 170, Loss: 0.5909, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 43, Epoch: 171, Loss: 0.6218, Val Acc: 0.7410, Test Acc: 0.7857
# Seed: 43, Epoch: 172, Loss: 0.6135, Val Acc: 0.7169, Test Acc: 0.8036
# Seed: 43, Epoch: 173, Loss: 0.6093, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 43, Epoch: 174, Loss: 0.6040, Val Acc: 0.7530, Test Acc: 0.7560
# Seed: 43, Epoch: 175, Loss: 0.5909, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 43, Epoch: 176, Loss: 0.5899, Val Acc: 0.7530, Test Acc: 0.7500
# Seed: 43, Epoch: 177, Loss: 0.5917, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 43, Epoch: 178, Loss: 0.5881, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 43, Epoch: 179, Loss: 0.5894, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 43, Epoch: 180, Loss: 0.5907, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 43, Epoch: 181, Loss: 0.5847, Val Acc: 0.7410, Test Acc: 0.7679
# Seed: 43, Epoch: 182, Loss: 0.5878, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 43, Epoch: 183, Loss: 0.5974, Val Acc: 0.7470, Test Acc: 0.8036
# Seed: 43, Epoch: 184, Loss: 0.5950, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 43, Epoch: 185, Loss: 0.6177, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 186, Loss: 0.6233, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 187, Loss: 0.6100, Val Acc: 0.7530, Test Acc: 0.7738
# Seed: 43, Epoch: 188, Loss: 0.5743, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 43, Epoch: 189, Loss: 0.5786, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 43, Epoch: 190, Loss: 0.5854, Val Acc: 0.7410, Test Acc: 0.7560
# Seed: 43, Epoch: 191, Loss: 0.5921, Val Acc: 0.7410, Test Acc: 0.7619
# Seed: 43, Epoch: 192, Loss: 0.6253, Val Acc: 0.7711, Test Acc: 0.7798
# Seed: 43, Epoch: 193, Loss: 0.5941, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 194, Loss: 0.5962, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 43, Epoch: 195, Loss: 0.5950, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 43, Epoch: 196, Loss: 0.5993, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 43, Epoch: 197, Loss: 0.6004, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 43, Epoch: 198, Loss: 0.5933, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 199, Loss: 0.5930, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 43, Epoch: 200, Loss: 0.5905, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 44, Epoch: 001, Loss: 0.6803, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 002, Loss: 0.6661, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 003, Loss: 0.6537, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 004, Loss: 0.6470, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 005, Loss: 0.6436, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 006, Loss: 0.6567, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 007, Loss: 0.6482, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 008, Loss: 0.6356, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 009, Loss: 0.6273, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 010, Loss: 0.6246, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 011, Loss: 0.6360, Val Acc: 0.6687, Test Acc: 0.6429
# Seed: 44, Epoch: 012, Loss: 0.6270, Val Acc: 0.6627, Test Acc: 0.6726
# Seed: 44, Epoch: 013, Loss: 0.6256, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 44, Epoch: 014, Loss: 0.6285, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 015, Loss: 0.6306, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 016, Loss: 0.6316, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 44, Epoch: 017, Loss: 0.6288, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 018, Loss: 0.6326, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 019, Loss: 0.6214, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 020, Loss: 0.6262, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 021, Loss: 0.6264, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 44, Epoch: 022, Loss: 0.6292, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 44, Epoch: 023, Loss: 0.6301, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 44, Epoch: 024, Loss: 0.6237, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 44, Epoch: 025, Loss: 0.6254, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 026, Loss: 0.6160, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 027, Loss: 0.6265, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 44, Epoch: 028, Loss: 0.6337, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 029, Loss: 0.6312, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 44, Epoch: 030, Loss: 0.6168, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 031, Loss: 0.6187, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 44, Epoch: 032, Loss: 0.6209, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 033, Loss: 0.6191, Val Acc: 0.6867, Test Acc: 0.6667
# Seed: 44, Epoch: 034, Loss: 0.6590, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 44, Epoch: 035, Loss: 0.6100, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 44, Epoch: 036, Loss: 0.6224, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 44, Epoch: 037, Loss: 0.6189, Val Acc: 0.7048, Test Acc: 0.6845
# Seed: 44, Epoch: 038, Loss: 0.6244, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 44, Epoch: 039, Loss: 0.6255, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 040, Loss: 0.6315, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 44, Epoch: 041, Loss: 0.6303, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 042, Loss: 0.6303, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 44, Epoch: 043, Loss: 0.6242, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 044, Loss: 0.6250, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 045, Loss: 0.6251, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 046, Loss: 0.6219, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 047, Loss: 0.6232, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 048, Loss: 0.6187, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 049, Loss: 0.6074, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 050, Loss: 0.6100, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 051, Loss: 0.6413, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 052, Loss: 0.6127, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 053, Loss: 0.6000, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 054, Loss: 0.6070, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 055, Loss: 0.6072, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 056, Loss: 0.6117, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 057, Loss: 0.6089, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 058, Loss: 0.6019, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 059, Loss: 0.6144, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 060, Loss: 0.6083, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 061, Loss: 0.6270, Val Acc: 0.6446, Test Acc: 0.7500
# Seed: 44, Epoch: 062, Loss: 0.6452, Val Acc: 0.6446, Test Acc: 0.7381
# Seed: 44, Epoch: 063, Loss: 0.6503, Val Acc: 0.6566, Test Acc: 0.7560
# Seed: 44, Epoch: 064, Loss: 0.6355, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 44, Epoch: 065, Loss: 0.6339, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 066, Loss: 0.6289, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 067, Loss: 0.6136, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 068, Loss: 0.6103, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 069, Loss: 0.5968, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 070, Loss: 0.5983, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 071, Loss: 0.5987, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 072, Loss: 0.6123, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 073, Loss: 0.6091, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 074, Loss: 0.5920, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 44, Epoch: 075, Loss: 0.5913, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 076, Loss: 0.6055, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 077, Loss: 0.5965, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 078, Loss: 0.5967, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 079, Loss: 0.6151, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 44, Epoch: 080, Loss: 0.6029, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 44, Epoch: 081, Loss: 0.6091, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 082, Loss: 0.6055, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 083, Loss: 0.5986, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 084, Loss: 0.5946, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 085, Loss: 0.5942, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 086, Loss: 0.5907, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 087, Loss: 0.5962, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 088, Loss: 0.5923, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 089, Loss: 0.5866, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 090, Loss: 0.5796, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 091, Loss: 0.5823, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 092, Loss: 0.5926, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 44, Epoch: 093, Loss: 0.6238, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 44, Epoch: 094, Loss: 0.5955, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 095, Loss: 0.5940, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 096, Loss: 0.5974, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 097, Loss: 0.5997, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 44, Epoch: 098, Loss: 0.5961, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 099, Loss: 0.5935, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 100, Loss: 0.5936, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 101, Loss: 0.5851, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 44, Epoch: 102, Loss: 0.5872, Val Acc: 0.6867, Test Acc: 0.7976
# Seed: 44, Epoch: 103, Loss: 0.6074, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 44, Epoch: 104, Loss: 0.5986, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 44, Epoch: 105, Loss: 0.5946, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 44, Epoch: 106, Loss: 0.6060, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 44, Epoch: 107, Loss: 0.6045, Val Acc: 0.6807, Test Acc: 0.7798
# Seed: 44, Epoch: 108, Loss: 0.6063, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 44, Epoch: 109, Loss: 0.5993, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 44, Epoch: 110, Loss: 0.6020, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 44, Epoch: 111, Loss: 0.5906, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 44, Epoch: 112, Loss: 0.5875, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 44, Epoch: 113, Loss: 0.5922, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 44, Epoch: 114, Loss: 0.5897, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 44, Epoch: 115, Loss: 0.5851, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 44, Epoch: 116, Loss: 0.5880, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 117, Loss: 0.5768, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 118, Loss: 0.5842, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 44, Epoch: 119, Loss: 0.5803, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 120, Loss: 0.5940, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 44, Epoch: 121, Loss: 0.6193, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 122, Loss: 0.6042, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 123, Loss: 0.5800, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 124, Loss: 0.5808, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 125, Loss: 0.5803, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 126, Loss: 0.5807, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 127, Loss: 0.5802, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 128, Loss: 0.5773, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 129, Loss: 0.5710, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 130, Loss: 0.5670, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 131, Loss: 0.5646, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 132, Loss: 0.5690, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 133, Loss: 0.5613, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 134, Loss: 0.5581, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 44, Epoch: 135, Loss: 0.5589, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 136, Loss: 0.5591, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 137, Loss: 0.5810, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 138, Loss: 0.5696, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 139, Loss: 0.5776, Val Acc: 0.6627, Test Acc: 0.7738
# Seed: 44, Epoch: 140, Loss: 0.5936, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 44, Epoch: 141, Loss: 0.5941, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 44, Epoch: 142, Loss: 0.5778, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 143, Loss: 0.5770, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 144, Loss: 0.5753, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 145, Loss: 0.5676, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 146, Loss: 0.5780, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 147, Loss: 0.5730, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 148, Loss: 0.5770, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 149, Loss: 0.5756, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 150, Loss: 0.5669, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 151, Loss: 0.5654, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 152, Loss: 0.5656, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 153, Loss: 0.5694, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 154, Loss: 0.5677, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 155, Loss: 0.5670, Val Acc: 0.7048, Test Acc: 0.7857
# Seed: 44, Epoch: 156, Loss: 0.5856, Val Acc: 0.7048, Test Acc: 0.7857
# Seed: 44, Epoch: 157, Loss: 0.5733, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 158, Loss: 0.5719, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 44, Epoch: 159, Loss: 0.5762, Val Acc: 0.7108, Test Acc: 0.7917
# Seed: 44, Epoch: 160, Loss: 0.5998, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 44, Epoch: 161, Loss: 0.5905, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 162, Loss: 0.5814, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 163, Loss: 0.5811, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 164, Loss: 0.5811, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 165, Loss: 0.5683, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 166, Loss: 0.5661, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 167, Loss: 0.5730, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 168, Loss: 0.5643, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 169, Loss: 0.5732, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 44, Epoch: 170, Loss: 0.5737, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 44, Epoch: 171, Loss: 0.5676, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 172, Loss: 0.5570, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 173, Loss: 0.5669, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 44, Epoch: 174, Loss: 0.5630, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 44, Epoch: 175, Loss: 0.5720, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 176, Loss: 0.5619, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 44, Epoch: 177, Loss: 0.5642, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 44, Epoch: 178, Loss: 0.5800, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 44, Epoch: 179, Loss: 0.5746, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 44, Epoch: 180, Loss: 0.5827, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 44, Epoch: 181, Loss: 0.5768, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 182, Loss: 0.5639, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 183, Loss: 0.5677, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 184, Loss: 0.5697, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 44, Epoch: 185, Loss: 0.5650, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 186, Loss: 0.5677, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 44, Epoch: 187, Loss: 0.5638, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 188, Loss: 0.5648, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 189, Loss: 0.5642, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 190, Loss: 0.5541, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 44, Epoch: 191, Loss: 0.5562, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 192, Loss: 0.5566, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 193, Loss: 0.5482, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 194, Loss: 0.5551, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 195, Loss: 0.5624, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 196, Loss: 0.5654, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 44, Epoch: 197, Loss: 0.5736, Val Acc: 0.7410, Test Acc: 0.7560
# Seed: 44, Epoch: 198, Loss: 0.5789, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 44, Epoch: 199, Loss: 0.5826, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 44, Epoch: 200, Loss: 0.5848, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 45, Epoch: 001, Loss: 0.6785, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 002, Loss: 0.6517, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 003, Loss: 0.6402, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 004, Loss: 0.6343, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 005, Loss: 0.6284, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 006, Loss: 0.6369, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 007, Loss: 0.6390, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 008, Loss: 0.6384, Val Acc: 0.6566, Test Acc: 0.6250
# Seed: 45, Epoch: 009, Loss: 0.6418, Val Acc: 0.6747, Test Acc: 0.6250
# Seed: 45, Epoch: 010, Loss: 0.6553, Val Acc: 0.6807, Test Acc: 0.6310
# Seed: 45, Epoch: 011, Loss: 0.6578, Val Acc: 0.6807, Test Acc: 0.6369
# Seed: 45, Epoch: 012, Loss: 0.6598, Val Acc: 0.6988, Test Acc: 0.6726
# Seed: 45, Epoch: 013, Loss: 0.6588, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 45, Epoch: 014, Loss: 0.6619, Val Acc: 0.7229, Test Acc: 0.6726
# Seed: 45, Epoch: 015, Loss: 0.6536, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 45, Epoch: 016, Loss: 0.6495, Val Acc: 0.7349, Test Acc: 0.7083
# Seed: 45, Epoch: 017, Loss: 0.6481, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 45, Epoch: 018, Loss: 0.6367, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 45, Epoch: 019, Loss: 0.6339, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 020, Loss: 0.6282, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 021, Loss: 0.6209, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 45, Epoch: 022, Loss: 0.6111, Val Acc: 0.6928, Test Acc: 0.6607
# Seed: 45, Epoch: 023, Loss: 0.6295, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 45, Epoch: 024, Loss: 0.6362, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 45, Epoch: 025, Loss: 0.6177, Val Acc: 0.6988, Test Acc: 0.6607
# Seed: 45, Epoch: 026, Loss: 0.6370, Val Acc: 0.6867, Test Acc: 0.6310
# Seed: 45, Epoch: 027, Loss: 0.6386, Val Acc: 0.6747, Test Acc: 0.6250
# Seed: 45, Epoch: 028, Loss: 0.6365, Val Acc: 0.6747, Test Acc: 0.6250
# Seed: 45, Epoch: 029, Loss: 0.6354, Val Acc: 0.6747, Test Acc: 0.6250
# Seed: 45, Epoch: 030, Loss: 0.6272, Val Acc: 0.6807, Test Acc: 0.6250
# Seed: 45, Epoch: 031, Loss: 0.6304, Val Acc: 0.6867, Test Acc: 0.6250
# Seed: 45, Epoch: 032, Loss: 0.6309, Val Acc: 0.6928, Test Acc: 0.6369
# Seed: 45, Epoch: 033, Loss: 0.6287, Val Acc: 0.6988, Test Acc: 0.6607
# Seed: 45, Epoch: 034, Loss: 0.6243, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 45, Epoch: 035, Loss: 0.6297, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 45, Epoch: 036, Loss: 0.6359, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 45, Epoch: 037, Loss: 0.6384, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 45, Epoch: 038, Loss: 0.6335, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 45, Epoch: 039, Loss: 0.6281, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 45, Epoch: 040, Loss: 0.6237, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 45, Epoch: 041, Loss: 0.6334, Val Acc: 0.6446, Test Acc: 0.7500
# Seed: 45, Epoch: 042, Loss: 0.6401, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 45, Epoch: 043, Loss: 0.6044, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 044, Loss: 0.6104, Val Acc: 0.6928, Test Acc: 0.6786
# Seed: 45, Epoch: 045, Loss: 0.6296, Val Acc: 0.6867, Test Acc: 0.6667
# Seed: 45, Epoch: 046, Loss: 0.6171, Val Acc: 0.6928, Test Acc: 0.6667
# Seed: 45, Epoch: 047, Loss: 0.6272, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 048, Loss: 0.6273, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 049, Loss: 0.6312, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 45, Epoch: 050, Loss: 0.6286, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 45, Epoch: 051, Loss: 0.6224, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 45, Epoch: 052, Loss: 0.6087, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 45, Epoch: 053, Loss: 0.5956, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 45, Epoch: 054, Loss: 0.6036, Val Acc: 0.7169, Test Acc: 0.7798
# Seed: 45, Epoch: 055, Loss: 0.5813, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 45, Epoch: 056, Loss: 0.5902, Val Acc: 0.6988, Test Acc: 0.6786
# Seed: 45, Epoch: 057, Loss: 0.6079, Val Acc: 0.6807, Test Acc: 0.6667
# Seed: 45, Epoch: 058, Loss: 0.6174, Val Acc: 0.6928, Test Acc: 0.6667
# Seed: 45, Epoch: 059, Loss: 0.6062, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 060, Loss: 0.6073, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 45, Epoch: 061, Loss: 0.6062, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 45, Epoch: 062, Loss: 0.6119, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 45, Epoch: 063, Loss: 0.5945, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 45, Epoch: 064, Loss: 0.6092, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 45, Epoch: 065, Loss: 0.5985, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 066, Loss: 0.6072, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 067, Loss: 0.6058, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 45, Epoch: 068, Loss: 0.6142, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 45, Epoch: 069, Loss: 0.6139, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 45, Epoch: 070, Loss: 0.6095, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 45, Epoch: 071, Loss: 0.6119, Val Acc: 0.6627, Test Acc: 0.7202
# Seed: 45, Epoch: 072, Loss: 0.6052, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 073, Loss: 0.6095, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 074, Loss: 0.6218, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 075, Loss: 0.6186, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 45, Epoch: 076, Loss: 0.6098, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 077, Loss: 0.6118, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 45, Epoch: 078, Loss: 0.6142, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 079, Loss: 0.6152, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 45, Epoch: 080, Loss: 0.6138, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 081, Loss: 0.6057, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 082, Loss: 0.6009, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 083, Loss: 0.6037, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 084, Loss: 0.6023, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 45, Epoch: 085, Loss: 0.5978, Val Acc: 0.6928, Test Acc: 0.7440
# ...
# Seed: 45, Epoch: 164, Loss: 0.5756, Val Acc: 0.6627, Test Acc: 0.7679
# Seed: 45, Epoch: 165, Loss: 0.5762, Val Acc: 0.6386, Test Acc: 0.7619
# Seed: 45, Epoch: 166, Loss: 0.5780, Val Acc: 0.6566, Test Acc: 0.7619
# Seed: 45, Epoch: 167, Loss: 0.5821, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 168, Loss: 0.5788, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 45, Epoch: 169, Loss: 0.5879, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 45, Epoch: 170, Loss: 0.6002, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 45, Epoch: 171, Loss: 0.6056, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 172, Loss: 0.6075, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 45, Epoch: 173, Loss: 0.6109, Val Acc: 0.6807, Test Acc: 0.7857
# Seed: 45, Epoch: 174, Loss: 0.6001, Val Acc: 0.6928, Test Acc: 0.7976
# Seed: 45, Epoch: 175, Loss: 0.5878, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 45, Epoch: 176, Loss: 0.5774, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 45, Epoch: 177, Loss: 0.5801, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 45, Epoch: 178, Loss: 0.5848, Val Acc: 0.6687, Test Acc: 0.7917
# Seed: 45, Epoch: 179, Loss: 0.5830, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 180, Loss: 0.6080, Val Acc: 0.6687, Test Acc: 0.7679
# Seed: 45, Epoch: 181, Loss: 0.6311, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 45, Epoch: 182, Loss: 0.5948, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 183, Loss: 0.5901, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 45, Epoch: 184, Loss: 0.5791, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 45, Epoch: 185, Loss: 0.5802, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 45, Epoch: 186, Loss: 0.5905, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 45, Epoch: 187, Loss: 0.5861, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 188, Loss: 0.5880, Val Acc: 0.7048, Test Acc: 0.7738
# Early stopping at epoch 188 for seed 45
# Seed: 46, Epoch: 001, Loss: 0.7099, Val Acc: 0.3976, Test Acc: 0.4702
# Seed: 46, Epoch: 002, Loss: 0.6992, Val Acc: 0.4819, Test Acc: 0.5476
# Seed: 46, Epoch: 003, Loss: 0.6819, Val Acc: 0.5241, Test Acc: 0.5893
# Seed: 46, Epoch: 004, Loss: 0.6782, Val Acc: 0.5602, Test Acc: 0.6131
# Seed: 46, Epoch: 005, Loss: 0.6775, Val Acc: 0.6265, Test Acc: 0.6667
# Seed: 46, Epoch: 006, Loss: 0.6665, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 46, Epoch: 007, Loss: 0.6607, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 008, Loss: 0.6370, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 46, Epoch: 009, Loss: 0.6392, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 46, Epoch: 010, Loss: 0.6328, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 46, Epoch: 011, Loss: 0.6255, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 46, Epoch: 012, Loss: 0.6222, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 46, Epoch: 013, Loss: 0.6201, Val Acc: 0.6807, Test Acc: 0.6726
# Seed: 46, Epoch: 014, Loss: 0.6419, Val Acc: 0.6807, Test Acc: 0.6488
# Seed: 46, Epoch: 015, Loss: 0.6270, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 46, Epoch: 016, Loss: 0.6193, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 017, Loss: 0.6375, Val Acc: 0.6627, Test Acc: 0.7440
# Seed: 46, Epoch: 018, Loss: 0.6505, Val Acc: 0.6446, Test Acc: 0.7381
# Seed: 46, Epoch: 019, Loss: 0.6371, Val Acc: 0.6627, Test Acc: 0.7381
# Seed: 46, Epoch: 020, Loss: 0.6489, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 46, Epoch: 021, Loss: 0.6371, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 46, Epoch: 022, Loss: 0.6298, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 023, Loss: 0.6264, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 024, Loss: 0.6250, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 025, Loss: 0.6241, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 46, Epoch: 026, Loss: 0.6203, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 027, Loss: 0.6200, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 46, Epoch: 028, Loss: 0.6202, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 029, Loss: 0.6223, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 030, Loss: 0.6298, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 46, Epoch: 031, Loss: 0.6256, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 46, Epoch: 032, Loss: 0.6335, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 46, Epoch: 033, Loss: 0.6275, Val Acc: 0.6566, Test Acc: 0.7619
# Seed: 46, Epoch: 034, Loss: 0.6374, Val Acc: 0.6687, Test Acc: 0.7679
# Seed: 46, Epoch: 035, Loss: 0.6341, Val Acc: 0.6446, Test Acc: 0.7619
# Seed: 46, Epoch: 036, Loss: 0.6391, Val Acc: 0.6446, Test Acc: 0.7619
# Seed: 46, Epoch: 037, Loss: 0.6330, Val Acc: 0.6687, Test Acc: 0.7679
# Seed: 46, Epoch: 038, Loss: 0.6277, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 039, Loss: 0.6109, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 040, Loss: 0.6174, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 041, Loss: 0.6173, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 042, Loss: 0.6140, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 043, Loss: 0.6375, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 46, Epoch: 044, Loss: 0.6112, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 46, Epoch: 045, Loss: 0.6190, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 046, Loss: 0.5992, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 047, Loss: 0.6119, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 048, Loss: 0.6089, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 049, Loss: 0.5995, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 46, Epoch: 050, Loss: 0.6005, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 46, Epoch: 051, Loss: 0.6272, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 46, Epoch: 052, Loss: 0.6275, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 053, Loss: 0.5989, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 46, Epoch: 054, Loss: 0.6036, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 46, Epoch: 055, Loss: 0.5996, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 46, Epoch: 056, Loss: 0.6059, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 46, Epoch: 057, Loss: 0.5982, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 46, Epoch: 058, Loss: 0.6136, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 46, Epoch: 059, Loss: 0.6087, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 060, Loss: 0.6286, Val Acc: 0.6687, Test Acc: 0.7738
# Seed: 46, Epoch: 061, Loss: 0.6297, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 46, Epoch: 062, Loss: 0.6295, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 46, Epoch: 063, Loss: 0.6182, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 064, Loss: 0.6140, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 065, Loss: 0.6038, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 066, Loss: 0.6103, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 067, Loss: 0.6011, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 46, Epoch: 068, Loss: 0.5947, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 069, Loss: 0.6016, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 46, Epoch: 070, Loss: 0.5971, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 071, Loss: 0.5915, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 46, Epoch: 072, Loss: 0.6060, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 073, Loss: 0.6046, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 46, Epoch: 074, Loss: 0.6001, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 075, Loss: 0.6183, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 076, Loss: 0.6098, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 46, Epoch: 077, Loss: 0.6025, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 46, Epoch: 078, Loss: 0.5940, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 079, Loss: 0.6056, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 080, Loss: 0.6039, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 081, Loss: 0.6004, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 46, Epoch: 082, Loss: 0.6165, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 46, Epoch: 083, Loss: 0.6282, Val Acc: 0.6687, Test Acc: 0.7738
# Seed: 46, Epoch: 084, Loss: 0.6116, Val Acc: 0.6566, Test Acc: 0.7798
# Seed: 46, Epoch: 085, Loss: 0.6231, Val Acc: 0.6687, Test Acc: 0.7738
# Seed: 46, Epoch: 086, Loss: 0.6217, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 46, Epoch: 087, Loss: 0.6128, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 088, Loss: 0.6071, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 089, Loss: 0.5986, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 090, Loss: 0.6032, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 46, Epoch: 091, Loss: 0.6021, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 46, Epoch: 092, Loss: 0.6110, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 093, Loss: 0.6186, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 46, Epoch: 094, Loss: 0.6268, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 46, Epoch: 095, Loss: 0.6323, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 46, Epoch: 096, Loss: 0.6197, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 097, Loss: 0.6208, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 098, Loss: 0.6063, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 46, Epoch: 099, Loss: 0.6069, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 46, Epoch: 100, Loss: 0.6002, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 46, Epoch: 101, Loss: 0.5936, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 102, Loss: 0.6001, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 103, Loss: 0.6125, Val Acc: 0.6506, Test Acc: 0.7560
# Seed: 46, Epoch: 104, Loss: 0.6772, Val Acc: 0.6084, Test Acc: 0.6369
# Seed: 46, Epoch: 105, Loss: 0.6695, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 46, Epoch: 106, Loss: 0.6175, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 107, Loss: 0.6271, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 108, Loss: 0.6096, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 46, Epoch: 109, Loss: 0.6064, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 110, Loss: 0.6001, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 111, Loss: 0.6104, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 112, Loss: 0.6028, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 113, Loss: 0.6055, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 114, Loss: 0.5955, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 115, Loss: 0.5904, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 116, Loss: 0.5934, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 117, Loss: 0.5908, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 118, Loss: 0.5861, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 119, Loss: 0.5889, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 120, Loss: 0.5843, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 121, Loss: 0.5842, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 46, Epoch: 122, Loss: 0.5911, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 123, Loss: 0.5841, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 124, Loss: 0.5864, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 125, Loss: 0.5773, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 126, Loss: 0.5799, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 46, Epoch: 127, Loss: 0.5736, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 128, Loss: 0.5830, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 129, Loss: 0.5871, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 130, Loss: 0.5786, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 131, Loss: 0.5955, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 132, Loss: 0.6011, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 46, Epoch: 133, Loss: 0.6055, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 134, Loss: 0.5997, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 46, Epoch: 135, Loss: 0.5880, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 46, Epoch: 136, Loss: 0.5873, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 46, Epoch: 137, Loss: 0.5809, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 46, Epoch: 138, Loss: 0.5850, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 46, Epoch: 139, Loss: 0.5829, Val Acc: 0.6687, Test Acc: 0.7083
# Seed: 46, Epoch: 140, Loss: 0.5881, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 141, Loss: 0.5940, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 142, Loss: 0.5872, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 46, Epoch: 143, Loss: 0.5979, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 46, Epoch: 144, Loss: 0.5990, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 46, Epoch: 145, Loss: 0.5995, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 46, Epoch: 146, Loss: 0.5906, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 147, Loss: 0.5954, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 148, Loss: 0.6006, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 149, Loss: 0.5872, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 150, Loss: 0.5863, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 46, Epoch: 151, Loss: 0.5813, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 152, Loss: 0.5834, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 153, Loss: 0.5899, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 46, Epoch: 154, Loss: 0.5796, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 46, Epoch: 155, Loss: 0.5795, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 46, Epoch: 156, Loss: 0.5762, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 157, Loss: 0.5843, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 46, Epoch: 158, Loss: 0.5851, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 159, Loss: 0.5903, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 160, Loss: 0.5875, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 46, Epoch: 161, Loss: 0.5925, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 46, Epoch: 162, Loss: 0.5782, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 46, Epoch: 163, Loss: 0.5953, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 164, Loss: 0.5993, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 165, Loss: 0.5891, Val Acc: 0.7169, Test Acc: 0.7798
# Seed: 46, Epoch: 166, Loss: 0.5978, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 167, Loss: 0.5963, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 46, Epoch: 168, Loss: 0.5891, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 169, Loss: 0.5963, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 170, Loss: 0.5963, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 171, Loss: 0.5806, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 172, Loss: 0.5840, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 46, Epoch: 173, Loss: 0.5826, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 46, Epoch: 174, Loss: 0.5764, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 46, Epoch: 175, Loss: 0.5771, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 176, Loss: 0.5741, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 46, Epoch: 177, Loss: 0.5809, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 46, Epoch: 178, Loss: 0.5761, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 179, Loss: 0.5904, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 180, Loss: 0.5990, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 181, Loss: 0.5913, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 182, Loss: 0.5791, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 183, Loss: 0.5930, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 184, Loss: 0.6067, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 185, Loss: 0.5909, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 186, Loss: 0.5816, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 187, Loss: 0.5852, Val Acc: 0.6627, Test Acc: 0.7321
# Seed: 46, Epoch: 188, Loss: 0.5777, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 46, Epoch: 189, Loss: 0.5816, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 46, Epoch: 190, Loss: 0.5731, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 46, Epoch: 191, Loss: 0.5672, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 46, Epoch: 192, Loss: 0.5750, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 46, Epoch: 193, Loss: 0.5693, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 194, Loss: 0.5632, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 195, Loss: 0.5735, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 196, Loss: 0.5685, Val Acc: 0.7410, Test Acc: 0.7560
# Seed: 46, Epoch: 197, Loss: 0.5841, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 46, Epoch: 198, Loss: 0.5799, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 46, Epoch: 199, Loss: 0.6062, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 200, Loss: 0.5945, Val Acc: 0.7289, Test Acc: 0.7381
# Average Time: 17.70 seconds
# Var Time: 0.16 seconds
# Average Memory: 206.00 MB
# Average Best Val Acc: 0.7458
# Std Best Test Acc: 0.0190
# Average Test Acc: 0.7571

# %% [markdown]
# ## ASAPooling with HierarchicalGCN (2020)

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, ASAPooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch
from torch_geometric.nn import BatchNorm

class HierarchicalGCN_ASA(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_ASA, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool1 = ASAPooling(hidden_channels, ratio=0.5)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool2 = ASAPooling(hidden_channels, ratio=0.5)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, _, batch, _ = self.pool1(x, edge_index, batch=batch)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, _, batch, _ = self.pool2(x, edge_index, batch=batch)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_ASA(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_ASA(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.7114, Val Acc: 0.3554, Test Acc: 0.3869
# Seed: 42, Epoch: 002, Loss: 0.7071, Val Acc: 0.3494, Test Acc: 0.3869
# Seed: 42, Epoch: 003, Loss: 0.7035, Val Acc: 0.3494, Test Acc: 0.3929
# Seed: 42, Epoch: 004, Loss: 0.7006, Val Acc: 0.3554, Test Acc: 0.3988
# Seed: 42, Epoch: 005, Loss: 0.6969, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 006, Loss: 0.6511, Val Acc: 0.6687, Test Acc: 0.6250
# Seed: 42, Epoch: 007, Loss: 0.6441, Val Acc: 0.6807, Test Acc: 0.6250
# Seed: 42, Epoch: 008, Loss: 0.6496, Val Acc: 0.6747, Test Acc: 0.6429
# Seed: 42, Epoch: 009, Loss: 0.6555, Val Acc: 0.6687, Test Acc: 0.6548
# Seed: 42, Epoch: 010, Loss: 0.6563, Val Acc: 0.6747, Test Acc: 0.6548
# Seed: 42, Epoch: 011, Loss: 0.6510, Val Acc: 0.6807, Test Acc: 0.6310
# Seed: 42, Epoch: 012, Loss: 0.6423, Val Acc: 0.6687, Test Acc: 0.6250
# Seed: 42, Epoch: 013, Loss: 0.6516, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 42, Epoch: 014, Loss: 0.6438, Val Acc: 0.6807, Test Acc: 0.6250
# Seed: 42, Epoch: 015, Loss: 0.6379, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 42, Epoch: 016, Loss: 0.6474, Val Acc: 0.6747, Test Acc: 0.6429
# Seed: 42, Epoch: 017, Loss: 0.6460, Val Acc: 0.6747, Test Acc: 0.6548
# Seed: 42, Epoch: 018, Loss: 0.6575, Val Acc: 0.6747, Test Acc: 0.6726
# Seed: 42, Epoch: 019, Loss: 0.6557, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 020, Loss: 0.6629, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 021, Loss: 0.6567, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 022, Loss: 0.6685, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 023, Loss: 0.6604, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 024, Loss: 0.6643, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 025, Loss: 0.6582, Val Acc: 0.6807, Test Acc: 0.6726
# Seed: 42, Epoch: 026, Loss: 0.6487, Val Acc: 0.6807, Test Acc: 0.6548
# Seed: 42, Epoch: 027, Loss: 0.6457, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 42, Epoch: 028, Loss: 0.6466, Val Acc: 0.6807, Test Acc: 0.6369
# Seed: 42, Epoch: 029, Loss: 0.6456, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 42, Epoch: 030, Loss: 0.6429, Val Acc: 0.6867, Test Acc: 0.6726
# Seed: 42, Epoch: 031, Loss: 0.6442, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 42, Epoch: 032, Loss: 0.6481, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 033, Loss: 0.6497, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 034, Loss: 0.6392, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 035, Loss: 0.6457, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 036, Loss: 0.6481, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 037, Loss: 0.6602, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 42, Epoch: 038, Loss: 0.6511, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 039, Loss: 0.6495, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 040, Loss: 0.6379, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 42, Epoch: 041, Loss: 0.6282, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 42, Epoch: 042, Loss: 0.6321, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 42, Epoch: 043, Loss: 0.6264, Val Acc: 0.6747, Test Acc: 0.6786
# Seed: 42, Epoch: 044, Loss: 0.6321, Val Acc: 0.6747, Test Acc: 0.6786
# Seed: 42, Epoch: 045, Loss: 0.6286, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 42, Epoch: 046, Loss: 0.6196, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 42, Epoch: 047, Loss: 0.6228, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 42, Epoch: 048, Loss: 0.6104, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 049, Loss: 0.6179, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 050, Loss: 0.6182, Val Acc: 0.6928, Test Acc: 0.6786
# Seed: 42, Epoch: 051, Loss: 0.6131, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 42, Epoch: 052, Loss: 0.6080, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 42, Epoch: 053, Loss: 0.6163, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 054, Loss: 0.6204, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 055, Loss: 0.6240, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 056, Loss: 0.6149, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 057, Loss: 0.6200, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 42, Epoch: 058, Loss: 0.6245, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 42, Epoch: 059, Loss: 0.6312, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 42, Epoch: 060, Loss: 0.6300, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 42, Epoch: 061, Loss: 0.6259, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 062, Loss: 0.6080, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 063, Loss: 0.6022, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 064, Loss: 0.5879, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 42, Epoch: 065, Loss: 0.5959, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 42, Epoch: 066, Loss: 0.5919, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 067, Loss: 0.5931, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 068, Loss: 0.5803, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 069, Loss: 0.5744, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 42, Epoch: 070, Loss: 0.5825, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 071, Loss: 0.5797, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 072, Loss: 0.5851, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 073, Loss: 0.5787, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 42, Epoch: 074, Loss: 0.5953, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 075, Loss: 0.6018, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 42, Epoch: 076, Loss: 0.5965, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 077, Loss: 0.6296, Val Acc: 0.6627, Test Acc: 0.6964
# Seed: 42, Epoch: 078, Loss: 0.6491, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 42, Epoch: 079, Loss: 0.6370, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 080, Loss: 0.6022, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 081, Loss: 0.5965, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 082, Loss: 0.5866, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 083, Loss: 0.6041, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 084, Loss: 0.5934, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 42, Epoch: 085, Loss: 0.6037, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 42, Epoch: 086, Loss: 0.6231, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 087, Loss: 0.6260, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 088, Loss: 0.6343, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 42, Epoch: 089, Loss: 0.6329, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 090, Loss: 0.6164, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 091, Loss: 0.6031, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 092, Loss: 0.5979, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 093, Loss: 0.5923, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 42, Epoch: 094, Loss: 0.5878, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 095, Loss: 0.5849, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 096, Loss: 0.5891, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 097, Loss: 0.5826, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 098, Loss: 0.5805, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 42, Epoch: 099, Loss: 0.5776, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 100, Loss: 0.5752, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 101, Loss: 0.5711, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 102, Loss: 0.5741, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 42, Epoch: 103, Loss: 0.5866, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 104, Loss: 0.6116, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 105, Loss: 0.6180, Val Acc: 0.6687, Test Acc: 0.6964
# Seed: 42, Epoch: 106, Loss: 0.6543, Val Acc: 0.5361, Test Acc: 0.5833
# Seed: 42, Epoch: 107, Loss: 0.7497, Val Acc: 0.4699, Test Acc: 0.5417
# Seed: 42, Epoch: 108, Loss: 0.7412, Val Acc: 0.5361, Test Acc: 0.5655
# Seed: 42, Epoch: 109, Loss: 0.7038, Val Acc: 0.5964, Test Acc: 0.6250
# Seed: 42, Epoch: 110, Loss: 0.6495, Val Acc: 0.6446, Test Acc: 0.6786
# Seed: 42, Epoch: 111, Loss: 0.6057, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 42, Epoch: 112, Loss: 0.5964, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 113, Loss: 0.5836, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 114, Loss: 0.5899, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 115, Loss: 0.5911, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 42, Epoch: 116, Loss: 0.5870, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 117, Loss: 0.5947, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 118, Loss: 0.5925, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 119, Loss: 0.5957, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 120, Loss: 0.5865, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 121, Loss: 0.5897, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 122, Loss: 0.5996, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 123, Loss: 0.5919, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 124, Loss: 0.5981, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 125, Loss: 0.5929, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 126, Loss: 0.5929, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 127, Loss: 0.5885, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 128, Loss: 0.5922, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 129, Loss: 0.5895, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 130, Loss: 0.5904, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 131, Loss: 0.5885, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 132, Loss: 0.5914, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 133, Loss: 0.5829, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 42, Epoch: 134, Loss: 0.5755, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 42, Epoch: 135, Loss: 0.5775, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 136, Loss: 0.5809, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 137, Loss: 0.5757, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 138, Loss: 0.5876, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 139, Loss: 0.5831, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 140, Loss: 0.5818, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 141, Loss: 0.5823, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 142, Loss: 0.5788, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 143, Loss: 0.5783, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 144, Loss: 0.5919, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 145, Loss: 0.5966, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 42, Epoch: 146, Loss: 0.5928, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 147, Loss: 0.5816, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 148, Loss: 0.5873, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 149, Loss: 0.5755, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 150, Loss: 0.5914, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 42, Epoch: 151, Loss: 0.5975, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 152, Loss: 0.5980, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 153, Loss: 0.5908, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 154, Loss: 0.5908, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 155, Loss: 0.5838, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 156, Loss: 0.5807, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 157, Loss: 0.5794, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 158, Loss: 0.5758, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 159, Loss: 0.5759, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 160, Loss: 0.5744, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 161, Loss: 0.5735, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 162, Loss: 0.5810, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 163, Loss: 0.5778, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 164, Loss: 0.5875, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 42, Epoch: 165, Loss: 0.5924, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 42, Epoch: 166, Loss: 0.5911, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 167, Loss: 0.5978, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 168, Loss: 0.6024, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 169, Loss: 0.5987, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 170, Loss: 0.5894, Val Acc: 0.7470, Test Acc: 0.7619
# Seed: 42, Epoch: 171, Loss: 0.5869, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 42, Epoch: 172, Loss: 0.5792, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 173, Loss: 0.5791, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 174, Loss: 0.5724, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 175, Loss: 0.5717, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 176, Loss: 0.5758, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 177, Loss: 0.5813, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 178, Loss: 0.5788, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 179, Loss: 0.5915, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 180, Loss: 0.5804, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 181, Loss: 0.5897, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 182, Loss: 0.5750, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 183, Loss: 0.5760, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 184, Loss: 0.5777, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 185, Loss: 0.5762, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 186, Loss: 0.5722, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 187, Loss: 0.5705, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 188, Loss: 0.5813, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 189, Loss: 0.5689, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 190, Loss: 0.5775, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 42, Epoch: 191, Loss: 0.5793, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 192, Loss: 0.5944, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 193, Loss: 0.6110, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 194, Loss: 0.5855, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 195, Loss: 0.5866, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 196, Loss: 0.5687, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 42, Epoch: 197, Loss: 0.5667, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 198, Loss: 0.5662, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 199, Loss: 0.5705, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 200, Loss: 0.5716, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 43, Epoch: 001, Loss: 0.6841, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 002, Loss: 0.6827, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 003, Loss: 0.6804, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 004, Loss: 0.6734, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 005, Loss: 0.6576, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 006, Loss: 0.6535, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 007, Loss: 0.6564, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 008, Loss: 0.6508, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 009, Loss: 0.6419, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 010, Loss: 0.6348, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 011, Loss: 0.6331, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 012, Loss: 0.6378, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 013, Loss: 0.6392, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 014, Loss: 0.6327, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 015, Loss: 0.6299, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 016, Loss: 0.6359, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 017, Loss: 0.6313, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 018, Loss: 0.6345, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 019, Loss: 0.6410, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 020, Loss: 0.6390, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 43, Epoch: 021, Loss: 0.6551, Val Acc: 0.6807, Test Acc: 0.6369
# Seed: 43, Epoch: 022, Loss: 0.6589, Val Acc: 0.6807, Test Acc: 0.6726
# Seed: 43, Epoch: 023, Loss: 0.6555, Val Acc: 0.6807, Test Acc: 0.6607
# Seed: 43, Epoch: 024, Loss: 0.6474, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 43, Epoch: 025, Loss: 0.6430, Val Acc: 0.6627, Test Acc: 0.6369
# Seed: 43, Epoch: 026, Loss: 0.6395, Val Acc: 0.6627, Test Acc: 0.6310
# Seed: 43, Epoch: 027, Loss: 0.6327, Val Acc: 0.6627, Test Acc: 0.6310
# Seed: 43, Epoch: 028, Loss: 0.6369, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 43, Epoch: 029, Loss: 0.6367, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 43, Epoch: 030, Loss: 0.6433, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 43, Epoch: 031, Loss: 0.6433, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 032, Loss: 0.6364, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 033, Loss: 0.6393, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 43, Epoch: 034, Loss: 0.6322, Val Acc: 0.6687, Test Acc: 0.6845
# Seed: 43, Epoch: 035, Loss: 0.6218, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 036, Loss: 0.6253, Val Acc: 0.6627, Test Acc: 0.7798
# Seed: 43, Epoch: 037, Loss: 0.6395, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 43, Epoch: 038, Loss: 0.6357, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 43, Epoch: 039, Loss: 0.6207, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 040, Loss: 0.6145, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 041, Loss: 0.6063, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 43, Epoch: 042, Loss: 0.6034, Val Acc: 0.6687, Test Acc: 0.6905
# Seed: 43, Epoch: 043, Loss: 0.6006, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 044, Loss: 0.6044, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 045, Loss: 0.6096, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 43, Epoch: 046, Loss: 0.6236, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 43, Epoch: 047, Loss: 0.6279, Val Acc: 0.6386, Test Acc: 0.7024
# Seed: 43, Epoch: 048, Loss: 0.6535, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 43, Epoch: 049, Loss: 0.6335, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 050, Loss: 0.6182, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 051, Loss: 0.6081, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 052, Loss: 0.6108, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 053, Loss: 0.6036, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 054, Loss: 0.6052, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 055, Loss: 0.6012, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 056, Loss: 0.6059, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 057, Loss: 0.6076, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 058, Loss: 0.5995, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 059, Loss: 0.6018, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 060, Loss: 0.5967, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 061, Loss: 0.6013, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 43, Epoch: 062, Loss: 0.6105, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 43, Epoch: 063, Loss: 0.6116, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 064, Loss: 0.6195, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 43, Epoch: 065, Loss: 0.6149, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 43, Epoch: 066, Loss: 0.6029, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 43, Epoch: 067, Loss: 0.6002, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 068, Loss: 0.5882, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 069, Loss: 0.5913, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 070, Loss: 0.5834, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 071, Loss: 0.5798, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 072, Loss: 0.5884, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 073, Loss: 0.5848, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 43, Epoch: 074, Loss: 0.5944, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 43, Epoch: 075, Loss: 0.5815, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 076, Loss: 0.5845, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 077, Loss: 0.5779, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 078, Loss: 0.5760, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 079, Loss: 0.5815, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 43, Epoch: 080, Loss: 0.5891, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 081, Loss: 0.5841, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 43, Epoch: 082, Loss: 0.5984, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 43, Epoch: 083, Loss: 0.6164, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 43, Epoch: 084, Loss: 0.6064, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 43, Epoch: 085, Loss: 0.6060, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 43, Epoch: 086, Loss: 0.6014, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 43, Epoch: 087, Loss: 0.6029, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 088, Loss: 0.5952, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 089, Loss: 0.5952, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 090, Loss: 0.5952, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 091, Loss: 0.5936, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 092, Loss: 0.5849, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 093, Loss: 0.5879, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 43, Epoch: 094, Loss: 0.5951, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 43, Epoch: 095, Loss: 0.6027, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 43, Epoch: 096, Loss: 0.5999, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 43, Epoch: 097, Loss: 0.6040, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 43, Epoch: 098, Loss: 0.6154, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 43, Epoch: 099, Loss: 0.6116, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 100, Loss: 0.5973, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 101, Loss: 0.5956, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 43, Epoch: 102, Loss: 0.5937, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 103, Loss: 0.6015, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 104, Loss: 0.6016, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 105, Loss: 0.5918, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 106, Loss: 0.5704, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 107, Loss: 0.5728, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 108, Loss: 0.5722, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 109, Loss: 0.5741, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 110, Loss: 0.5856, Val Acc: 0.3554, Test Acc: 0.4048
# Seed: 43, Epoch: 111, Loss: 0.8826, Val Acc: 0.3554, Test Acc: 0.3810
# Seed: 43, Epoch: 112, Loss: 0.8672, Val Acc: 0.3554, Test Acc: 0.3810
# Seed: 43, Epoch: 113, Loss: 0.8367, Val Acc: 0.3554, Test Acc: 0.3810
# Seed: 43, Epoch: 114, Loss: 0.8066, Val Acc: 0.3554, Test Acc: 0.3810
# Seed: 43, Epoch: 115, Loss: 0.7768, Val Acc: 0.3614, Test Acc: 0.3869
# Seed: 43, Epoch: 116, Loss: 0.7546, Val Acc: 0.3614, Test Acc: 0.4167
# Seed: 43, Epoch: 117, Loss: 0.7298, Val Acc: 0.3795, Test Acc: 0.4464
# Seed: 43, Epoch: 118, Loss: 0.7150, Val Acc: 0.4036, Test Acc: 0.5000
# Seed: 43, Epoch: 119, Loss: 0.7061, Val Acc: 0.4337, Test Acc: 0.5179
# Seed: 43, Epoch: 120, Loss: 0.6924, Val Acc: 0.4699, Test Acc: 0.5417
# Seed: 43, Epoch: 121, Loss: 0.6873, Val Acc: 0.5361, Test Acc: 0.6012
# Seed: 43, Epoch: 122, Loss: 0.6779, Val Acc: 0.5482, Test Acc: 0.6548
# Seed: 43, Epoch: 123, Loss: 0.6778, Val Acc: 0.5904, Test Acc: 0.6964
# Seed: 43, Epoch: 124, Loss: 0.6734, Val Acc: 0.6446, Test Acc: 0.6667
# Seed: 43, Epoch: 125, Loss: 0.6763, Val Acc: 0.6566, Test Acc: 0.7143
# Seed: 43, Epoch: 126, Loss: 0.6679, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 127, Loss: 0.6677, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 43, Epoch: 128, Loss: 0.6680, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 43, Epoch: 129, Loss: 0.6533, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 43, Epoch: 130, Loss: 0.6552, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 43, Epoch: 131, Loss: 0.6555, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 43, Epoch: 132, Loss: 0.6523, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 43, Epoch: 133, Loss: 0.6530, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 43, Epoch: 134, Loss: 0.6505, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 43, Epoch: 135, Loss: 0.6513, Val Acc: 0.7048, Test Acc: 0.6726
# Seed: 43, Epoch: 136, Loss: 0.6499, Val Acc: 0.6988, Test Acc: 0.6607
# Seed: 43, Epoch: 137, Loss: 0.6512, Val Acc: 0.6988, Test Acc: 0.6607
# Seed: 43, Epoch: 138, Loss: 0.6521, Val Acc: 0.7048, Test Acc: 0.6488
# Seed: 43, Epoch: 139, Loss: 0.6502, Val Acc: 0.6928, Test Acc: 0.6369
# Seed: 43, Epoch: 140, Loss: 0.6387, Val Acc: 0.6928, Test Acc: 0.6131
# Seed: 43, Epoch: 141, Loss: 0.6405, Val Acc: 0.6928, Test Acc: 0.6190
# Seed: 43, Epoch: 142, Loss: 0.6373, Val Acc: 0.6867, Test Acc: 0.6190
# Seed: 43, Epoch: 143, Loss: 0.6416, Val Acc: 0.6867, Test Acc: 0.6190
# Seed: 43, Epoch: 144, Loss: 0.6354, Val Acc: 0.6928, Test Acc: 0.6250
# Seed: 43, Epoch: 145, Loss: 0.6428, Val Acc: 0.6807, Test Acc: 0.6310
# Seed: 43, Epoch: 146, Loss: 0.6444, Val Acc: 0.6867, Test Acc: 0.6429
# Seed: 43, Epoch: 147, Loss: 0.6346, Val Acc: 0.6867, Test Acc: 0.6786
# Seed: 43, Epoch: 148, Loss: 0.6368, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 43, Epoch: 149, Loss: 0.6355, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 43, Epoch: 150, Loss: 0.6326, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 151, Loss: 0.6297, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 152, Loss: 0.6360, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 153, Loss: 0.6276, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 154, Loss: 0.6358, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 155, Loss: 0.6416, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 156, Loss: 0.6529, Val Acc: 0.5602, Test Acc: 0.6012
# Seed: 43, Epoch: 157, Loss: 0.6895, Val Acc: 0.4518, Test Acc: 0.5476
# Seed: 43, Epoch: 158, Loss: 0.6910, Val Acc: 0.4518, Test Acc: 0.5417
# Seed: 43, Epoch: 159, Loss: 0.6936, Val Acc: 0.4699, Test Acc: 0.5417
# Seed: 43, Epoch: 160, Loss: 0.6876, Val Acc: 0.5482, Test Acc: 0.6429
# Seed: 43, Epoch: 161, Loss: 0.6863, Val Acc: 0.6446, Test Acc: 0.7143
# Seed: 43, Epoch: 162, Loss: 0.6770, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 163, Loss: 0.6715, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 43, Epoch: 164, Loss: 0.6669, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 165, Loss: 0.6636, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 166, Loss: 0.6698, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 167, Loss: 0.6627, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 168, Loss: 0.6655, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 169, Loss: 0.6578, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 170, Loss: 0.6602, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 171, Loss: 0.6574, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 172, Loss: 0.6581, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 173, Loss: 0.6580, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 174, Loss: 0.6503, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 175, Loss: 0.6535, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 176, Loss: 0.6542, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 177, Loss: 0.6577, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 178, Loss: 0.6522, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 179, Loss: 0.6525, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 180, Loss: 0.6494, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 181, Loss: 0.6464, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 182, Loss: 0.6442, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 183, Loss: 0.6515, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 184, Loss: 0.6463, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 185, Loss: 0.6473, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 186, Loss: 0.6441, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 187, Loss: 0.6409, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 188, Loss: 0.6377, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 189, Loss: 0.6392, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 190, Loss: 0.6430, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 191, Loss: 0.6400, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 192, Loss: 0.6383, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 193, Loss: 0.6415, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 194, Loss: 0.6327, Val Acc: 0.6928, Test Acc: 0.6190
# Seed: 43, Epoch: 195, Loss: 0.6386, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 43, Epoch: 196, Loss: 0.6313, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 43, Epoch: 197, Loss: 0.6372, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 43, Epoch: 198, Loss: 0.6364, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 43, Epoch: 199, Loss: 0.6397, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 43, Epoch: 200, Loss: 0.6354, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 44, Epoch: 001, Loss: 0.6917, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 002, Loss: 0.6892, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 003, Loss: 0.6824, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 004, Loss: 0.6577, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 005, Loss: 0.6314, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 006, Loss: 0.6268, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 007, Loss: 0.6453, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 008, Loss: 0.6345, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 009, Loss: 0.6302, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 010, Loss: 0.6451, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 011, Loss: 0.6466, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 012, Loss: 0.6521, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 013, Loss: 0.6551, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 014, Loss: 0.6535, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 015, Loss: 0.6504, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 016, Loss: 0.6517, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 017, Loss: 0.6507, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 018, Loss: 0.6482, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 44, Epoch: 019, Loss: 0.6544, Val Acc: 0.6747, Test Acc: 0.6190
# Seed: 44, Epoch: 020, Loss: 0.6588, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 44, Epoch: 021, Loss: 0.6611, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 44, Epoch: 022, Loss: 0.6536, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 44, Epoch: 023, Loss: 0.6531, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 44, Epoch: 024, Loss: 0.6477, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 44, Epoch: 025, Loss: 0.6465, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 44, Epoch: 026, Loss: 0.6397, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 44, Epoch: 027, Loss: 0.6409, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 44, Epoch: 028, Loss: 0.6368, Val Acc: 0.6807, Test Acc: 0.6369
# Seed: 44, Epoch: 029, Loss: 0.6343, Val Acc: 0.6807, Test Acc: 0.6369
# Seed: 44, Epoch: 030, Loss: 0.6342, Val Acc: 0.6807, Test Acc: 0.6667
# Seed: 44, Epoch: 031, Loss: 0.6388, Val Acc: 0.6747, Test Acc: 0.6786
# Seed: 44, Epoch: 032, Loss: 0.6395, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 033, Loss: 0.6461, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 034, Loss: 0.6444, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 035, Loss: 0.6496, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 036, Loss: 0.6513, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 44, Epoch: 037, Loss: 0.6450, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 44, Epoch: 038, Loss: 0.6423, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 44, Epoch: 039, Loss: 0.6418, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 040, Loss: 0.6371, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 44, Epoch: 041, Loss: 0.6406, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 042, Loss: 0.6353, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 44, Epoch: 043, Loss: 0.6402, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 44, Epoch: 044, Loss: 0.6393, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 44, Epoch: 045, Loss: 0.6415, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 44, Epoch: 046, Loss: 0.6385, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 44, Epoch: 047, Loss: 0.6396, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 44, Epoch: 048, Loss: 0.6428, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 049, Loss: 0.6432, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 050, Loss: 0.6509, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 051, Loss: 0.6376, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 44, Epoch: 052, Loss: 0.6427, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 053, Loss: 0.6391, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 054, Loss: 0.6348, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 055, Loss: 0.6361, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 056, Loss: 0.6409, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 44, Epoch: 057, Loss: 0.6452, Val Acc: 0.6627, Test Acc: 0.7679
# Seed: 44, Epoch: 058, Loss: 0.6508, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 44, Epoch: 059, Loss: 0.6449, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 060, Loss: 0.6465, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 061, Loss: 0.6366, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 062, Loss: 0.6346, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 063, Loss: 0.6289, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 44, Epoch: 064, Loss: 0.6274, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 44, Epoch: 065, Loss: 0.6210, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 44, Epoch: 066, Loss: 0.6195, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 067, Loss: 0.6149, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 44, Epoch: 068, Loss: 0.6221, Val Acc: 0.7169, Test Acc: 0.6964
# Seed: 44, Epoch: 069, Loss: 0.6128, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 44, Epoch: 070, Loss: 0.6186, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 071, Loss: 0.6316, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 44, Epoch: 072, Loss: 0.6269, Val Acc: 0.6627, Test Acc: 0.7738
# Seed: 44, Epoch: 073, Loss: 0.6601, Val Acc: 0.6386, Test Acc: 0.6964
# Seed: 44, Epoch: 074, Loss: 0.6535, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 44, Epoch: 075, Loss: 0.6331, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 076, Loss: 0.6306, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 077, Loss: 0.6269, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 44, Epoch: 078, Loss: 0.6239, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 44, Epoch: 079, Loss: 0.6252, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 080, Loss: 0.6233, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 081, Loss: 0.6064, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 44, Epoch: 082, Loss: 0.6104, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 44, Epoch: 083, Loss: 0.6090, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 44, Epoch: 084, Loss: 0.6047, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 085, Loss: 0.6096, Val Acc: 0.6988, Test Acc: 0.6786
# Seed: 44, Epoch: 086, Loss: 0.6114, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 44, Epoch: 087, Loss: 0.6118, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 088, Loss: 0.6102, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 44, Epoch: 089, Loss: 0.6364, Val Acc: 0.6687, Test Acc: 0.7798
# Seed: 44, Epoch: 090, Loss: 0.6200, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 091, Loss: 0.6168, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 44, Epoch: 092, Loss: 0.6130, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 44, Epoch: 093, Loss: 0.6095, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 44, Epoch: 094, Loss: 0.6052, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 095, Loss: 0.6044, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 44, Epoch: 096, Loss: 0.5999, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 097, Loss: 0.5975, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 098, Loss: 0.5997, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 099, Loss: 0.5995, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 100, Loss: 0.5992, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 101, Loss: 0.5915, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 102, Loss: 0.5967, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 44, Epoch: 103, Loss: 0.5924, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 44, Epoch: 104, Loss: 0.5925, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 44, Epoch: 105, Loss: 0.5895, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 44, Epoch: 106, Loss: 0.5927, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 44, Epoch: 107, Loss: 0.5877, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 108, Loss: 0.5708, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 109, Loss: 0.5859, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 110, Loss: 0.5967, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 44, Epoch: 111, Loss: 0.5924, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 112, Loss: 0.6086, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 113, Loss: 0.5907, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 44, Epoch: 114, Loss: 0.5783, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 44, Epoch: 115, Loss: 0.5742, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 116, Loss: 0.5673, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 117, Loss: 0.5688, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 44, Epoch: 118, Loss: 0.5746, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 44, Epoch: 119, Loss: 0.5745, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 44, Epoch: 120, Loss: 0.5664, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 121, Loss: 0.5864, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 44, Epoch: 122, Loss: 0.6352, Val Acc: 0.6446, Test Acc: 0.7381
# Seed: 44, Epoch: 123, Loss: 0.6264, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 124, Loss: 0.5871, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 44, Epoch: 125, Loss: 0.5881, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 126, Loss: 0.5880, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 127, Loss: 0.5785, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 128, Loss: 0.5865, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 129, Loss: 0.5834, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 130, Loss: 0.5809, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 131, Loss: 0.5850, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 44, Epoch: 132, Loss: 0.5795, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 44, Epoch: 133, Loss: 0.6067, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 134, Loss: 0.6067, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 135, Loss: 0.5863, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 136, Loss: 0.5901, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 44, Epoch: 137, Loss: 0.5916, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 44, Epoch: 138, Loss: 0.5947, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 44, Epoch: 139, Loss: 0.5956, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 44, Epoch: 140, Loss: 0.5932, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 44, Epoch: 141, Loss: 0.6035, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 142, Loss: 0.6144, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 143, Loss: 0.6095, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 144, Loss: 0.5933, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 44, Epoch: 145, Loss: 0.5972, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 146, Loss: 0.5855, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 147, Loss: 0.5847, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 148, Loss: 0.5884, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 44, Epoch: 149, Loss: 0.5833, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 150, Loss: 0.5915, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 151, Loss: 0.6036, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 152, Loss: 0.6031, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 153, Loss: 0.5835, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 154, Loss: 0.6033, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 44, Epoch: 155, Loss: 0.5943, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 44, Epoch: 156, Loss: 0.5887, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 44, Epoch: 157, Loss: 0.5832, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 158, Loss: 0.5738, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 44, Epoch: 159, Loss: 0.5809, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 44, Epoch: 160, Loss: 0.5712, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 161, Loss: 0.5823, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 44, Epoch: 162, Loss: 0.5937, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 44, Epoch: 163, Loss: 0.5935, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 44, Epoch: 164, Loss: 0.5718, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 165, Loss: 0.5700, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 166, Loss: 0.5713, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 167, Loss: 0.5812, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 168, Loss: 0.5694, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 169, Loss: 0.5636, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 170, Loss: 0.5643, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 171, Loss: 0.5635, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 44, Epoch: 172, Loss: 0.5750, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 173, Loss: 0.5742, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 44, Epoch: 174, Loss: 0.5725, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 175, Loss: 0.5643, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 176, Loss: 0.5635, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 177, Loss: 0.5577, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 178, Loss: 0.5586, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 179, Loss: 0.5524, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 180, Loss: 0.5643, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 181, Loss: 0.5576, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 182, Loss: 0.5462, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 183, Loss: 0.5530, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 184, Loss: 0.5569, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 44, Epoch: 185, Loss: 0.5493, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 44, Epoch: 186, Loss: 0.5608, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 44, Epoch: 187, Loss: 0.5687, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 188, Loss: 0.5591, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 44, Epoch: 189, Loss: 0.5660, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 44, Epoch: 190, Loss: 0.5623, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 191, Loss: 0.5678, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 192, Loss: 0.5653, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 193, Loss: 0.5853, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 194, Loss: 0.5777, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 44, Epoch: 195, Loss: 0.5653, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 196, Loss: 0.5656, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 197, Loss: 0.5666, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 198, Loss: 0.5687, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 199, Loss: 0.5735, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 200, Loss: 0.5658, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 001, Loss: 0.6988, Val Acc: 0.3795, Test Acc: 0.4107
# Seed: 45, Epoch: 002, Loss: 0.6887, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 003, Loss: 0.6555, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 004, Loss: 0.6324, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 005, Loss: 0.6286, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 006, Loss: 0.6239, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 007, Loss: 0.6270, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 008, Loss: 0.6219, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 009, Loss: 0.6278, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 010, Loss: 0.6206, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 45, Epoch: 011, Loss: 0.6338, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 45, Epoch: 012, Loss: 0.6417, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 45, Epoch: 013, Loss: 0.6553, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 014, Loss: 0.6642, Val Acc: 0.6687, Test Acc: 0.7917
# Seed: 45, Epoch: 015, Loss: 0.6676, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 45, Epoch: 016, Loss: 0.6609, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 017, Loss: 0.6620, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 018, Loss: 0.6501, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 45, Epoch: 019, Loss: 0.6525, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 45, Epoch: 020, Loss: 0.6546, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 45, Epoch: 021, Loss: 0.6494, Val Acc: 0.6747, Test Acc: 0.6786
# Seed: 45, Epoch: 022, Loss: 0.6306, Val Acc: 0.6928, Test Acc: 0.6726
# Seed: 45, Epoch: 023, Loss: 0.6340, Val Acc: 0.6867, Test Acc: 0.6726
# Seed: 45, Epoch: 024, Loss: 0.6244, Val Acc: 0.6807, Test Acc: 0.6548
# Seed: 45, Epoch: 025, Loss: 0.6242, Val Acc: 0.6928, Test Acc: 0.6726
# Seed: 45, Epoch: 026, Loss: 0.6251, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 45, Epoch: 027, Loss: 0.6425, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 45, Epoch: 028, Loss: 0.6382, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 45, Epoch: 029, Loss: 0.6306, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 45, Epoch: 030, Loss: 0.6495, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 45, Epoch: 031, Loss: 0.6479, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 45, Epoch: 032, Loss: 0.6407, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 033, Loss: 0.6353, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 45, Epoch: 034, Loss: 0.6272, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 035, Loss: 0.6284, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 45, Epoch: 036, Loss: 0.6231, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 45, Epoch: 037, Loss: 0.6210, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 038, Loss: 0.6203, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 039, Loss: 0.6174, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 040, Loss: 0.6167, Val Acc: 0.6747, Test Acc: 0.8036
# Seed: 45, Epoch: 041, Loss: 0.6232, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 45, Epoch: 042, Loss: 0.6243, Val Acc: 0.6747, Test Acc: 0.7917
# Seed: 45, Epoch: 043, Loss: 0.6214, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 45, Epoch: 044, Loss: 0.6243, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 45, Epoch: 045, Loss: 0.6243, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 45, Epoch: 046, Loss: 0.6229, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 047, Loss: 0.6217, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 45, Epoch: 048, Loss: 0.6025, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 45, Epoch: 049, Loss: 0.6001, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 45, Epoch: 050, Loss: 0.6055, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 45, Epoch: 051, Loss: 0.6072, Val Acc: 0.6386, Test Acc: 0.6667
# Seed: 45, Epoch: 052, Loss: 0.6497, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 45, Epoch: 053, Loss: 0.6181, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 45, Epoch: 054, Loss: 0.6026, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 45, Epoch: 055, Loss: 0.5931, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 45, Epoch: 056, Loss: 0.6063, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 45, Epoch: 057, Loss: 0.5988, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 45, Epoch: 058, Loss: 0.6161, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 059, Loss: 0.6150, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 45, Epoch: 060, Loss: 0.6237, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 45, Epoch: 061, Loss: 0.6108, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 45, Epoch: 062, Loss: 0.6087, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 063, Loss: 0.6008, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 064, Loss: 0.6017, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 45, Epoch: 065, Loss: 0.6065, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 45, Epoch: 066, Loss: 0.6033, Val Acc: 0.6807, Test Acc: 0.7798
# Seed: 45, Epoch: 067, Loss: 0.6113, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 068, Loss: 0.6093, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 45, Epoch: 069, Loss: 0.6304, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 45, Epoch: 070, Loss: 0.6314, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 45, Epoch: 071, Loss: 0.6227, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 45, Epoch: 072, Loss: 0.6205, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 45, Epoch: 073, Loss: 0.6095, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 45, Epoch: 074, Loss: 0.6159, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 075, Loss: 0.5898, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 076, Loss: 0.5930, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 45, Epoch: 077, Loss: 0.5882, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 078, Loss: 0.5875, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 45, Epoch: 079, Loss: 0.5981, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 080, Loss: 0.5986, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 081, Loss: 0.5902, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 082, Loss: 0.5983, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 083, Loss: 0.5869, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 45, Epoch: 084, Loss: 0.5890, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 085, Loss: 0.5923, Val Acc: 0.7229, Test Acc: 0.7619
# ...
# Seed: 45, Epoch: 175, Loss: 0.5881, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 45, Epoch: 176, Loss: 0.5847, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 45, Epoch: 177, Loss: 0.5843, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 45, Epoch: 178, Loss: 0.5933, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 45, Epoch: 179, Loss: 0.5876, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 45, Epoch: 180, Loss: 0.5882, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 45, Epoch: 181, Loss: 0.5868, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 45, Epoch: 182, Loss: 0.5786, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 45, Epoch: 183, Loss: 0.5844, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 45, Epoch: 184, Loss: 0.5822, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 45, Epoch: 185, Loss: 0.5908, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 45, Epoch: 186, Loss: 0.5831, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 45, Epoch: 187, Loss: 0.5809, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 188, Loss: 0.5818, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 189, Loss: 0.5830, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 190, Loss: 0.5906, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 45, Epoch: 191, Loss: 0.5966, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 45, Epoch: 192, Loss: 0.6122, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 45, Epoch: 193, Loss: 0.5980, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 45, Epoch: 194, Loss: 0.5890, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 195, Loss: 0.5882, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 196, Loss: 0.5860, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 45, Epoch: 197, Loss: 0.5793, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 45, Epoch: 198, Loss: 0.5820, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 199, Loss: 0.5710, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 200, Loss: 0.5724, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 001, Loss: 0.6849, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 002, Loss: 0.6838, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 003, Loss: 0.6833, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 004, Loss: 0.6833, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 005, Loss: 0.6832, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 006, Loss: 0.6828, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 007, Loss: 0.6826, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 008, Loss: 0.6828, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 009, Loss: 0.6825, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 010, Loss: 0.6821, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 011, Loss: 0.6821, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 012, Loss: 0.6816, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 013, Loss: 0.6810, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 014, Loss: 0.6804, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 015, Loss: 0.6802, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 016, Loss: 0.6791, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 017, Loss: 0.6789, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 018, Loss: 0.6776, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 019, Loss: 0.6771, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 020, Loss: 0.6771, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 021, Loss: 0.6758, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 022, Loss: 0.6755, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 023, Loss: 0.6747, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 024, Loss: 0.6727, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 025, Loss: 0.6747, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 026, Loss: 0.6722, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 027, Loss: 0.6725, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 028, Loss: 0.6705, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 029, Loss: 0.6685, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 030, Loss: 0.6693, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 031, Loss: 0.6679, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 032, Loss: 0.6641, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 033, Loss: 0.6656, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 034, Loss: 0.6649, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 035, Loss: 0.6608, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 036, Loss: 0.6622, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 037, Loss: 0.6625, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 038, Loss: 0.6573, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 039, Loss: 0.6590, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 040, Loss: 0.6562, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 041, Loss: 0.6544, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 042, Loss: 0.6525, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 043, Loss: 0.6554, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 044, Loss: 0.6572, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 045, Loss: 0.6533, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 046, Loss: 0.6553, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 047, Loss: 0.6548, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 048, Loss: 0.6576, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 049, Loss: 0.6585, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 050, Loss: 0.6553, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 051, Loss: 0.6509, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 052, Loss: 0.6530, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 053, Loss: 0.6526, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 054, Loss: 0.6488, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 055, Loss: 0.6526, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 056, Loss: 0.6434, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 057, Loss: 0.6488, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 058, Loss: 0.6464, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 059, Loss: 0.6520, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 060, Loss: 0.6498, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 46, Epoch: 061, Loss: 0.6536, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 46, Epoch: 062, Loss: 0.6559, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 063, Loss: 0.6401, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 064, Loss: 0.6557, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 065, Loss: 0.6486, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 46, Epoch: 066, Loss: 0.6427, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 46, Epoch: 067, Loss: 0.6442, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 068, Loss: 0.6562, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 46, Epoch: 069, Loss: 0.6475, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 070, Loss: 0.6523, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 071, Loss: 0.6501, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 072, Loss: 0.6517, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 073, Loss: 0.6567, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 074, Loss: 0.6499, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 075, Loss: 0.6518, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 46, Epoch: 076, Loss: 0.6503, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 46, Epoch: 077, Loss: 0.6542, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 46, Epoch: 078, Loss: 0.6498, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 46, Epoch: 079, Loss: 0.6464, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 46, Epoch: 080, Loss: 0.6432, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 081, Loss: 0.6469, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 082, Loss: 0.6529, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 083, Loss: 0.6365, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 084, Loss: 0.6428, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 085, Loss: 0.6421, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 086, Loss: 0.6409, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 087, Loss: 0.6400, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 088, Loss: 0.6364, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 089, Loss: 0.6381, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 090, Loss: 0.6409, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 091, Loss: 0.6415, Val Acc: 0.7108, Test Acc: 0.6190
# Seed: 46, Epoch: 092, Loss: 0.6337, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 46, Epoch: 093, Loss: 0.6435, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 094, Loss: 0.6368, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 095, Loss: 0.6359, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 096, Loss: 0.6369, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 097, Loss: 0.6371, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 098, Loss: 0.6376, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 099, Loss: 0.6380, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 100, Loss: 0.6284, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 101, Loss: 0.6332, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 46, Epoch: 102, Loss: 0.6387, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 46, Epoch: 103, Loss: 0.6436, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 104, Loss: 0.6332, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 105, Loss: 0.6452, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 106, Loss: 0.6410, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 107, Loss: 0.6335, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 108, Loss: 0.6375, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 109, Loss: 0.6409, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 110, Loss: 0.6455, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 111, Loss: 0.6361, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 112, Loss: 0.6488, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 113, Loss: 0.6437, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 114, Loss: 0.6408, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 115, Loss: 0.6429, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 116, Loss: 0.6478, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 117, Loss: 0.6458, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 118, Loss: 0.6432, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 119, Loss: 0.6446, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 120, Loss: 0.6381, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 121, Loss: 0.6524, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 122, Loss: 0.6382, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 123, Loss: 0.6415, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 124, Loss: 0.6466, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 125, Loss: 0.6389, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 126, Loss: 0.6348, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 127, Loss: 0.6379, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 128, Loss: 0.6327, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 129, Loss: 0.6249, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 130, Loss: 0.6336, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 131, Loss: 0.6380, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 132, Loss: 0.6328, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 133, Loss: 0.6289, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 134, Loss: 0.6320, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 135, Loss: 0.6319, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 136, Loss: 0.6232, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 137, Loss: 0.6280, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 138, Loss: 0.6284, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 139, Loss: 0.6270, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 140, Loss: 0.6177, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 141, Loss: 0.6224, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 142, Loss: 0.6319, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 143, Loss: 0.6123, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 144, Loss: 0.6220, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 145, Loss: 0.6196, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 146, Loss: 0.6268, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 147, Loss: 0.6213, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 148, Loss: 0.6244, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 149, Loss: 0.6283, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 150, Loss: 0.6311, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 151, Loss: 0.6310, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 152, Loss: 0.6255, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 153, Loss: 0.6227, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 154, Loss: 0.6284, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 155, Loss: 0.6197, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 156, Loss: 0.6266, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 157, Loss: 0.6296, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 158, Loss: 0.6251, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 159, Loss: 0.6290, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 160, Loss: 0.6338, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 161, Loss: 0.6380, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 162, Loss: 0.6270, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 163, Loss: 0.6291, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 164, Loss: 0.6290, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 165, Loss: 0.6258, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 166, Loss: 0.6320, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 167, Loss: 0.6315, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 168, Loss: 0.6285, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 169, Loss: 0.6361, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 170, Loss: 0.6323, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 171, Loss: 0.6236, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 172, Loss: 0.6332, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 173, Loss: 0.6322, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 174, Loss: 0.6369, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 175, Loss: 0.6392, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 176, Loss: 0.6366, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 177, Loss: 0.6315, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 178, Loss: 0.6304, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 179, Loss: 0.6362, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 180, Loss: 0.6317, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 181, Loss: 0.6353, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 182, Loss: 0.6336, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 183, Loss: 0.6304, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 184, Loss: 0.6298, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 185, Loss: 0.6258, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 186, Loss: 0.6313, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 187, Loss: 0.6207, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 188, Loss: 0.6253, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 189, Loss: 0.6322, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 190, Loss: 0.6318, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 191, Loss: 0.6310, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 192, Loss: 0.6349, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 193, Loss: 0.6307, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 194, Loss: 0.6354, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 195, Loss: 0.6368, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 196, Loss: 0.6351, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 197, Loss: 0.6306, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 198, Loss: 0.6342, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 199, Loss: 0.6352, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 200, Loss: 0.6361, Val Acc: 0.7410, Test Acc: 0.7262
# Average Time: 599.52 seconds
# Var Time: 786.01 seconds
# Average Memory: 488.00 MB
# Average Best Val Acc: 0.7422
# Std Best Test Acc: 0.0218
# Average Test Acc: 0.7345

# %% [markdown]
# ## PANPooling with HierarchicalGCN (2020)

# %%
from torch_geometric.utils.num_nodes import maybe_num_nodes
from torch_sparse import spspmm
from torch_sparse import coalesce
from torch_sparse import eye
from torch.nn import Parameter
from torch_scatter import scatter_add
from torch_scatter import scatter_max

class PANPooling(torch.nn.Module):
    r""" General Graph pooling layer based on PAN, which can work with all layers.
    """
    def __init__(self, in_channels, ratio=0.5, pan_pool_weight=None, min_score=None, multiplier=1,
                 nonlinearity=torch.tanh, filter_size=3, panpool_filter_weight=None):
        super(PANPooling, self).__init__()

        self.in_channels = in_channels
        self.ratio = ratio
        self.min_score = min_score
        self.multiplier = multiplier
        self.nonlinearity = nonlinearity

        self.filter_size = filter_size
        if panpool_filter_weight is None:
            self.panpool_filter_weight = torch.nn.Parameter(0.5 * torch.ones(filter_size), requires_grad=True)

        self.transform = Parameter(torch.ones(in_channels), requires_grad=True)

        if pan_pool_weight is None:
            #self.weight = torch.tensor([0.7, 0.3], device=self.transform.device)
            self.pan_pool_weight = torch.nn.Parameter(0.5 * torch.ones(2), requires_grad=True)
        else:
            self.pan_pool_weight = pan_pool_weight

    def forward(self, x, edge_index, M=None, batch=None, num_nodes=None):

        """"""
        if batch is None:
            batch = edge_index.new_zeros(x.size(0))

        # Path integral
        num_nodes = maybe_num_nodes(edge_index, num_nodes)
        edge_index, edge_weight = self.panentropy_sparse(edge_index, num_nodes)

        # weighted degree
        num_nodes = x.size(0)
        degree = torch.zeros(num_nodes, device=edge_index.device)
        degree = scatter_add(edge_weight, edge_index[0], out=degree)

        # linear transform
        xtransform = torch.matmul(x, self.transform)

        # aggregate score
        x_transform_norm = xtransform #/ xtransform.norm(p=2, dim=-1)
        degree_norm = degree #/ degree.norm(p=2, dim=-1)
        score = self.pan_pool_weight[0] * x_transform_norm + self.pan_pool_weight[1] * degree_norm

        if self.min_score is None:
            score = self.nonlinearity(score)
        else:
            score = softmax(score, batch)

        perm = self.topk(score, self.ratio, batch, self.min_score)
        x = x[perm] * score[perm].view(-1, 1)
        x = self.multiplier * x if self.multiplier != 1 else x

        batch = batch[perm]
        edge_index, edge_weight = self.filter_adj(edge_index, edge_weight, perm, num_nodes=score.size(0))

        return x, edge_index, edge_weight, batch, perm, score[perm]

    def topk(self, x, ratio, batch, min_score=None, tol=1e-7):

        if min_score is not None:
            # Make sure that we do not drop all nodes in a graph.
            scores_max = scatter_max(x, batch)[0][batch] - tol
            scores_min = scores_max.clamp(max=min_score)

            perm = torch.nonzero(x > scores_min).view(-1)
        else:
            num_nodes = scatter_add(batch.new_ones(x.size(0)), batch, dim=0)
            batch_size, max_num_nodes = num_nodes.size(0), num_nodes.max().item()

            cum_num_nodes = torch.cat(
                [num_nodes.new_zeros(1),
                 num_nodes.cumsum(dim=0)[:-1]], dim=0)

            index = torch.arange(batch.size(0), dtype=torch.long, device=x.device)
            index = (index - cum_num_nodes[batch]) + (batch * max_num_nodes)

            dense_x = x.new_full((batch_size * max_num_nodes, ), -2)
            dense_x[index] = x
            dense_x = dense_x.view(batch_size, max_num_nodes)

            _, perm = dense_x.sort(dim=-1, descending=True)

            perm = perm + cum_num_nodes.view(-1, 1)
            perm = perm.view(-1)

            k = (ratio * num_nodes.to(torch.float)).ceil().to(torch.long)
            mask = [
                torch.arange(k[i], dtype=torch.long, device=x.device) +
                i * max_num_nodes for i in range(batch_size)
            ]
            mask = torch.cat(mask, dim=0)

            perm = perm[mask]

        return perm

    def filter_adj(self, edge_index, edge_weight, perm, num_nodes=None):

        num_nodes = maybe_num_nodes(edge_index, num_nodes)

        mask = perm.new_full((num_nodes, ), -1)
        i = torch.arange(perm.size(0), dtype=torch.long, device=perm.device)
        mask[perm] = i

        row, col = edge_index
        row, col = mask[row], mask[col]
        mask = (row >= 0) & (col >= 0)
        row, col = row[mask], col[mask]

        if edge_weight is not None:
            edge_weight = edge_weight[mask]

        return torch.stack([row, col], dim=0), edge_weight

    def panentropy_sparse(self, edge_index, num_nodes):

        edge_value = torch.ones(edge_index.size(1), device=edge_index.device)
        edge_index, edge_value = coalesce(edge_index, edge_value, num_nodes, num_nodes)

        # iteratively add weighted matrix power
        pan_index, pan_value = eye(num_nodes, device=edge_index.device)
        indextmp = pan_index.clone().to(edge_index.device)
        valuetmp = pan_value.clone().to(edge_index.device)

        pan_value = self.panpool_filter_weight[0] * pan_value

        for i in range(self.filter_size - 1):
            #indextmp, valuetmp = coalesce(indextmp, valuetmp, num_nodes, num_nodes)
            indextmp, valuetmp = spspmm(indextmp, valuetmp, edge_index, edge_value, num_nodes, num_nodes, num_nodes)
            valuetmp = valuetmp * self.panpool_filter_weight[i+1]
            indextmp, valuetmp = coalesce(indextmp, valuetmp, num_nodes, num_nodes)
            pan_index = torch.cat((pan_index, indextmp), 1)
            pan_value = torch.cat((pan_value, valuetmp))

        return coalesce(pan_index, pan_value, num_nodes, num_nodes, op='add')

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, ASAPooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch
from torch_geometric.nn import BatchNorm

class HierarchicalGCN_PAN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_PAN, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool1 = PANPooling(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool2 = PANPooling(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, _, batch, perm, score_perm = self.pool1(x, edge_index, batch=batch, M=None)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, _, batch, perm, score_perm = self.pool2(x, edge_index, batch=batch, M=None)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_PAN(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_PAN(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6897, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 002, Loss: 0.6751, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 003, Loss: 0.6685, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 004, Loss: 0.6642, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 005, Loss: 0.6521, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 006, Loss: 0.6471, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 007, Loss: 0.6536, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 008, Loss: 0.6543, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 009, Loss: 0.6517, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 010, Loss: 0.6542, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 011, Loss: 0.6577, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 012, Loss: 0.6489, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 013, Loss: 0.6521, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 014, Loss: 0.6505, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 015, Loss: 0.6398, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 016, Loss: 0.6464, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 017, Loss: 0.6378, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 42, Epoch: 018, Loss: 0.6405, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 42, Epoch: 019, Loss: 0.6436, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 42, Epoch: 020, Loss: 0.6487, Val Acc: 0.6687, Test Acc: 0.6667
# Seed: 42, Epoch: 021, Loss: 0.6519, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 42, Epoch: 022, Loss: 0.6487, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 023, Loss: 0.6591, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 42, Epoch: 024, Loss: 0.6538, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 025, Loss: 0.6490, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 026, Loss: 0.6462, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 027, Loss: 0.6423, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 028, Loss: 0.6464, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 029, Loss: 0.6475, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 030, Loss: 0.6450, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 42, Epoch: 031, Loss: 0.6524, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 42, Epoch: 032, Loss: 0.6503, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 033, Loss: 0.6436, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 42, Epoch: 034, Loss: 0.6382, Val Acc: 0.6627, Test Acc: 0.6905
# Seed: 42, Epoch: 035, Loss: 0.6363, Val Acc: 0.6566, Test Acc: 0.6786
# Seed: 42, Epoch: 036, Loss: 0.6318, Val Acc: 0.6627, Test Acc: 0.6905
# Seed: 42, Epoch: 037, Loss: 0.6321, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 42, Epoch: 038, Loss: 0.6347, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 42, Epoch: 039, Loss: 0.6452, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 040, Loss: 0.6460, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 041, Loss: 0.6434, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 042, Loss: 0.6427, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 043, Loss: 0.6471, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 42, Epoch: 044, Loss: 0.6348, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 42, Epoch: 045, Loss: 0.6302, Val Acc: 0.6687, Test Acc: 0.6905
# Seed: 42, Epoch: 046, Loss: 0.6274, Val Acc: 0.6566, Test Acc: 0.6786
# Seed: 42, Epoch: 047, Loss: 0.6217, Val Acc: 0.6687, Test Acc: 0.6905
# Seed: 42, Epoch: 048, Loss: 0.6246, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 42, Epoch: 049, Loss: 0.6205, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 42, Epoch: 050, Loss: 0.6263, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 42, Epoch: 051, Loss: 0.6289, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 052, Loss: 0.6313, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 053, Loss: 0.6389, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 42, Epoch: 054, Loss: 0.6309, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 055, Loss: 0.6340, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 42, Epoch: 056, Loss: 0.6297, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 057, Loss: 0.6330, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 42, Epoch: 058, Loss: 0.6218, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 42, Epoch: 059, Loss: 0.6314, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 060, Loss: 0.6288, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 42, Epoch: 061, Loss: 0.6276, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 062, Loss: 0.6338, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 063, Loss: 0.6307, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 064, Loss: 0.6235, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 42, Epoch: 065, Loss: 0.6212, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 066, Loss: 0.6157, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 42, Epoch: 067, Loss: 0.6151, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 068, Loss: 0.6136, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 069, Loss: 0.6189, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 070, Loss: 0.6103, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 42, Epoch: 071, Loss: 0.6126, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 072, Loss: 0.6256, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 073, Loss: 0.6217, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 074, Loss: 0.6171, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 42, Epoch: 075, Loss: 0.6104, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 076, Loss: 0.6189, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 077, Loss: 0.6107, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 078, Loss: 0.6105, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 42, Epoch: 079, Loss: 0.6134, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 42, Epoch: 080, Loss: 0.6154, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 081, Loss: 0.6213, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 42, Epoch: 082, Loss: 0.6362, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 083, Loss: 0.6461, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 084, Loss: 0.6414, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 085, Loss: 0.6413, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 086, Loss: 0.6303, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 087, Loss: 0.6314, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 088, Loss: 0.6272, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 089, Loss: 0.6301, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 42, Epoch: 090, Loss: 0.6276, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 091, Loss: 0.6301, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 092, Loss: 0.6335, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 093, Loss: 0.6341, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 094, Loss: 0.6309, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 095, Loss: 0.6247, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 096, Loss: 0.6354, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 097, Loss: 0.6278, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 098, Loss: 0.6213, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 099, Loss: 0.6275, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 100, Loss: 0.6201, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 101, Loss: 0.6175, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 102, Loss: 0.6093, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 103, Loss: 0.6138, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 104, Loss: 0.6082, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 105, Loss: 0.6089, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 106, Loss: 0.6061, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 107, Loss: 0.6095, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 108, Loss: 0.6009, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 109, Loss: 0.5925, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 110, Loss: 0.6050, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 111, Loss: 0.5944, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 112, Loss: 0.5964, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 113, Loss: 0.5882, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 42, Epoch: 114, Loss: 0.5928, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 115, Loss: 0.5940, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 116, Loss: 0.5915, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 117, Loss: 0.5990, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 118, Loss: 0.6019, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 119, Loss: 0.6004, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 120, Loss: 0.6108, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 121, Loss: 0.5965, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 122, Loss: 0.6073, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 123, Loss: 0.6085, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 42, Epoch: 124, Loss: 0.5996, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 42, Epoch: 125, Loss: 0.5946, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 126, Loss: 0.5921, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 127, Loss: 0.5918, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 42, Epoch: 128, Loss: 0.5864, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 42, Epoch: 129, Loss: 0.5904, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 130, Loss: 0.5841, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 131, Loss: 0.5845, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 132, Loss: 0.5874, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 42, Epoch: 133, Loss: 0.5842, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 134, Loss: 0.5773, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 135, Loss: 0.5941, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 136, Loss: 0.5743, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 137, Loss: 0.5806, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 138, Loss: 0.5727, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 42, Epoch: 139, Loss: 0.5691, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 42, Epoch: 140, Loss: 0.5832, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 141, Loss: 0.5995, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 42, Epoch: 142, Loss: 0.6029, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 143, Loss: 0.5955, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 42, Epoch: 144, Loss: 0.6153, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 42, Epoch: 145, Loss: 0.5947, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 146, Loss: 0.6075, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 42, Epoch: 147, Loss: 0.6045, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 148, Loss: 0.5861, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 149, Loss: 0.5980, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 150, Loss: 0.6003, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 151, Loss: 0.5862, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 152, Loss: 0.5921, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 153, Loss: 0.5885, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 154, Loss: 0.5828, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 155, Loss: 0.5855, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 42, Epoch: 156, Loss: 0.5847, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 157, Loss: 0.5905, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 158, Loss: 0.5926, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 159, Loss: 0.5878, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 160, Loss: 0.5819, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 161, Loss: 0.5817, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 162, Loss: 0.5757, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 163, Loss: 0.5895, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 164, Loss: 0.6048, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 42, Epoch: 165, Loss: 0.6175, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 166, Loss: 0.6052, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 42, Epoch: 167, Loss: 0.6018, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 168, Loss: 0.5814, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 169, Loss: 0.5921, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 170, Loss: 0.5808, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 171, Loss: 0.5892, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 172, Loss: 0.5859, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 173, Loss: 0.5946, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 174, Loss: 0.5809, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 175, Loss: 0.5846, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 176, Loss: 0.5832, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 177, Loss: 0.6052, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 178, Loss: 0.6099, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 179, Loss: 0.6053, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 180, Loss: 0.5923, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 181, Loss: 0.5993, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 182, Loss: 0.5994, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 183, Loss: 0.6084, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 184, Loss: 0.6020, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 185, Loss: 0.5934, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 186, Loss: 0.5992, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 187, Loss: 0.5982, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 188, Loss: 0.6045, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 189, Loss: 0.6025, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 190, Loss: 0.6033, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 191, Loss: 0.5962, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 192, Loss: 0.5937, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 193, Loss: 0.5944, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 194, Loss: 0.5911, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 195, Loss: 0.5913, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 196, Loss: 0.5964, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 197, Loss: 0.5902, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 198, Loss: 0.5926, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 199, Loss: 0.5869, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 200, Loss: 0.5848, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 001, Loss: 0.6910, Val Acc: 0.6265, Test Acc: 0.7560
# Seed: 43, Epoch: 002, Loss: 0.6727, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 43, Epoch: 003, Loss: 0.6452, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 43, Epoch: 004, Loss: 0.6292, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 005, Loss: 0.6267, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 006, Loss: 0.6629, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 007, Loss: 0.6312, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 43, Epoch: 008, Loss: 0.6373, Val Acc: 0.6566, Test Acc: 0.6250
# Seed: 43, Epoch: 009, Loss: 0.6184, Val Acc: 0.6747, Test Acc: 0.6607
# Seed: 43, Epoch: 010, Loss: 0.6300, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 43, Epoch: 011, Loss: 0.6418, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 43, Epoch: 012, Loss: 0.6441, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 013, Loss: 0.6395, Val Acc: 0.6506, Test Acc: 0.7560
# Seed: 43, Epoch: 014, Loss: 0.6487, Val Acc: 0.6566, Test Acc: 0.7619
# Seed: 43, Epoch: 015, Loss: 0.6541, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 43, Epoch: 016, Loss: 0.6532, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 43, Epoch: 017, Loss: 0.6563, Val Acc: 0.6566, Test Acc: 0.7560
# Seed: 43, Epoch: 018, Loss: 0.6610, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 43, Epoch: 019, Loss: 0.6587, Val Acc: 0.6566, Test Acc: 0.7679
# Seed: 43, Epoch: 020, Loss: 0.6634, Val Acc: 0.6446, Test Acc: 0.7500
# Seed: 43, Epoch: 021, Loss: 0.6696, Val Acc: 0.6386, Test Acc: 0.7440
# Seed: 43, Epoch: 022, Loss: 0.6679, Val Acc: 0.6506, Test Acc: 0.7500
# Seed: 43, Epoch: 023, Loss: 0.6583, Val Acc: 0.6446, Test Acc: 0.7619
# Seed: 43, Epoch: 024, Loss: 0.6635, Val Acc: 0.6687, Test Acc: 0.7679
# Seed: 43, Epoch: 025, Loss: 0.6542, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 43, Epoch: 026, Loss: 0.6527, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 027, Loss: 0.6484, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 028, Loss: 0.6391, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 43, Epoch: 029, Loss: 0.6433, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 43, Epoch: 030, Loss: 0.6453, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 43, Epoch: 031, Loss: 0.6415, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 032, Loss: 0.6359, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 033, Loss: 0.6468, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 034, Loss: 0.6414, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 035, Loss: 0.6351, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 43, Epoch: 036, Loss: 0.6351, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 037, Loss: 0.6251, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 038, Loss: 0.6167, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 039, Loss: 0.6278, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 040, Loss: 0.6218, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 43, Epoch: 041, Loss: 0.6217, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 43, Epoch: 042, Loss: 0.6132, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 043, Loss: 0.6179, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 044, Loss: 0.6241, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 045, Loss: 0.6165, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 046, Loss: 0.6321, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 047, Loss: 0.6296, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 43, Epoch: 048, Loss: 0.6205, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 43, Epoch: 049, Loss: 0.6368, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 43, Epoch: 050, Loss: 0.6457, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 43, Epoch: 051, Loss: 0.6366, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 43, Epoch: 052, Loss: 0.6360, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 053, Loss: 0.6404, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 054, Loss: 0.6303, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 055, Loss: 0.6394, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 056, Loss: 0.6373, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 057, Loss: 0.6339, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 43, Epoch: 058, Loss: 0.6210, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 059, Loss: 0.6224, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 43, Epoch: 060, Loss: 0.6153, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 43, Epoch: 061, Loss: 0.6173, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 43, Epoch: 062, Loss: 0.6039, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 063, Loss: 0.6152, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 064, Loss: 0.6142, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 065, Loss: 0.6275, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 43, Epoch: 066, Loss: 0.6255, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 067, Loss: 0.6251, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 068, Loss: 0.6212, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 43, Epoch: 069, Loss: 0.6256, Val Acc: 0.6687, Test Acc: 0.7738
# Seed: 43, Epoch: 070, Loss: 0.6260, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 43, Epoch: 071, Loss: 0.6211, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 072, Loss: 0.6293, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 073, Loss: 0.6229, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 074, Loss: 0.6141, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 43, Epoch: 075, Loss: 0.6172, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 43, Epoch: 076, Loss: 0.6076, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 43, Epoch: 077, Loss: 0.6062, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 078, Loss: 0.6117, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 079, Loss: 0.6041, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 43, Epoch: 080, Loss: 0.6057, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 081, Loss: 0.5965, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 082, Loss: 0.5994, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 083, Loss: 0.5890, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 084, Loss: 0.5946, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 085, Loss: 0.6048, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 43, Epoch: 086, Loss: 0.6162, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 087, Loss: 0.6220, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 088, Loss: 0.6270, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 43, Epoch: 089, Loss: 0.6174, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 43, Epoch: 090, Loss: 0.6346, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 43, Epoch: 091, Loss: 0.6195, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 092, Loss: 0.6176, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 093, Loss: 0.6112, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 094, Loss: 0.6170, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 095, Loss: 0.6184, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 096, Loss: 0.6205, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 43, Epoch: 097, Loss: 0.6173, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 098, Loss: 0.6139, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 099, Loss: 0.6069, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 100, Loss: 0.6150, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 101, Loss: 0.6084, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 102, Loss: 0.6084, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 103, Loss: 0.6149, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 104, Loss: 0.6093, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 105, Loss: 0.6083, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 106, Loss: 0.6105, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 107, Loss: 0.6153, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 108, Loss: 0.6162, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 109, Loss: 0.6070, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 43, Epoch: 110, Loss: 0.6091, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 111, Loss: 0.6059, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 112, Loss: 0.6066, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 113, Loss: 0.6044, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 114, Loss: 0.6028, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 115, Loss: 0.6129, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 43, Epoch: 116, Loss: 0.6070, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 117, Loss: 0.6073, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 118, Loss: 0.6065, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 119, Loss: 0.6074, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 120, Loss: 0.6009, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 121, Loss: 0.6000, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 122, Loss: 0.6094, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 123, Loss: 0.6001, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 124, Loss: 0.5996, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 125, Loss: 0.5992, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 126, Loss: 0.5941, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 127, Loss: 0.5927, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 128, Loss: 0.5915, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 129, Loss: 0.5855, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 130, Loss: 0.5901, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 131, Loss: 0.5898, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 132, Loss: 0.5808, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 43, Epoch: 133, Loss: 0.6099, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 43, Epoch: 134, Loss: 0.6016, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 43, Epoch: 135, Loss: 0.6149, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 43, Epoch: 136, Loss: 0.6053, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 43, Epoch: 137, Loss: 0.5982, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 138, Loss: 0.5942, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 43, Epoch: 139, Loss: 0.5935, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 140, Loss: 0.5950, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 141, Loss: 0.5925, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 43, Epoch: 142, Loss: 0.6162, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 43, Epoch: 143, Loss: 0.6125, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 144, Loss: 0.6092, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 145, Loss: 0.6020, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 146, Loss: 0.5932, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 43, Epoch: 147, Loss: 0.5917, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 148, Loss: 0.5962, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 43, Epoch: 149, Loss: 0.6024, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 150, Loss: 0.5986, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 151, Loss: 0.5870, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 152, Loss: 0.6006, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 153, Loss: 0.5855, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 154, Loss: 0.5901, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 155, Loss: 0.5878, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 156, Loss: 0.5903, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 157, Loss: 0.5876, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 43, Epoch: 158, Loss: 0.5856, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 159, Loss: 0.5904, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 160, Loss: 0.5944, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 161, Loss: 0.5832, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 162, Loss: 0.5930, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 163, Loss: 0.6046, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 164, Loss: 0.6030, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 165, Loss: 0.5972, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 166, Loss: 0.5964, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 167, Loss: 0.5873, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 168, Loss: 0.5791, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 169, Loss: 0.5859, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 170, Loss: 0.5826, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 171, Loss: 0.5836, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 43, Epoch: 172, Loss: 0.5982, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 173, Loss: 0.6001, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 174, Loss: 0.5885, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 175, Loss: 0.5945, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 43, Epoch: 176, Loss: 0.5925, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 43, Epoch: 177, Loss: 0.5997, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 43, Epoch: 178, Loss: 0.6001, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 179, Loss: 0.5798, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 43, Epoch: 180, Loss: 0.5858, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 181, Loss: 0.5773, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 182, Loss: 0.5766, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 183, Loss: 0.5707, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 184, Loss: 0.5986, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 185, Loss: 0.5787, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 186, Loss: 0.5939, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 187, Loss: 0.5893, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 188, Loss: 0.5778, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 189, Loss: 0.5759, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 190, Loss: 0.5755, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 191, Loss: 0.5802, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 43, Epoch: 192, Loss: 0.5970, Val Acc: 0.6627, Test Acc: 0.7738
# Seed: 43, Epoch: 193, Loss: 0.6282, Val Acc: 0.6446, Test Acc: 0.7440
# Seed: 43, Epoch: 194, Loss: 0.6424, Val Acc: 0.6446, Test Acc: 0.7321
# Seed: 43, Epoch: 195, Loss: 0.6042, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 196, Loss: 0.5851, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 43, Epoch: 197, Loss: 0.6091, Val Acc: 0.6627, Test Acc: 0.6429
# Seed: 43, Epoch: 198, Loss: 0.6331, Val Acc: 0.6627, Test Acc: 0.6429
# Seed: 43, Epoch: 199, Loss: 0.6071, Val Acc: 0.6747, Test Acc: 0.6488
# Seed: 43, Epoch: 200, Loss: 0.6196, Val Acc: 0.6747, Test Acc: 0.6667
# Seed: 44, Epoch: 001, Loss: 0.6987, Val Acc: 0.6265, Test Acc: 0.7321
# Seed: 44, Epoch: 002, Loss: 0.6632, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 44, Epoch: 003, Loss: 0.6428, Val Acc: 0.6627, Test Acc: 0.6667
# Seed: 44, Epoch: 004, Loss: 0.6333, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 44, Epoch: 005, Loss: 0.6381, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 006, Loss: 0.6313, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 44, Epoch: 007, Loss: 0.6454, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 008, Loss: 0.6408, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 44, Epoch: 009, Loss: 0.6449, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 44, Epoch: 010, Loss: 0.6403, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 011, Loss: 0.6436, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 012, Loss: 0.6346, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 013, Loss: 0.6416, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 014, Loss: 0.6587, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 44, Epoch: 015, Loss: 0.6534, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 44, Epoch: 016, Loss: 0.6521, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 44, Epoch: 017, Loss: 0.6464, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 018, Loss: 0.6421, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 019, Loss: 0.6409, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 020, Loss: 0.6426, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 44, Epoch: 021, Loss: 0.6353, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 022, Loss: 0.6393, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 44, Epoch: 023, Loss: 0.6355, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 024, Loss: 0.6295, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 44, Epoch: 025, Loss: 0.6329, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 44, Epoch: 026, Loss: 0.6275, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 44, Epoch: 027, Loss: 0.6223, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 44, Epoch: 028, Loss: 0.6300, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 44, Epoch: 029, Loss: 0.6266, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 44, Epoch: 030, Loss: 0.6170, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 44, Epoch: 031, Loss: 0.6228, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 44, Epoch: 032, Loss: 0.6303, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 44, Epoch: 033, Loss: 0.6115, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 034, Loss: 0.6324, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 44, Epoch: 035, Loss: 0.6410, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 44, Epoch: 036, Loss: 0.6369, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 037, Loss: 0.6320, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 44, Epoch: 038, Loss: 0.6428, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 039, Loss: 0.6379, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 44, Epoch: 040, Loss: 0.6364, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 44, Epoch: 041, Loss: 0.6249, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 042, Loss: 0.6234, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 043, Loss: 0.6168, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 044, Loss: 0.6151, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 045, Loss: 0.6085, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 046, Loss: 0.6170, Val Acc: 0.6687, Test Acc: 0.7024
# Seed: 44, Epoch: 047, Loss: 0.6051, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 44, Epoch: 048, Loss: 0.6226, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 049, Loss: 0.6063, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 050, Loss: 0.6220, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 44, Epoch: 051, Loss: 0.6206, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 052, Loss: 0.6042, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 053, Loss: 0.6121, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 44, Epoch: 054, Loss: 0.6103, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 44, Epoch: 055, Loss: 0.6156, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 44, Epoch: 056, Loss: 0.6108, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 057, Loss: 0.6316, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 44, Epoch: 058, Loss: 0.6248, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 059, Loss: 0.6299, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 060, Loss: 0.6290, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 061, Loss: 0.6182, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 062, Loss: 0.6293, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 063, Loss: 0.6328, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 064, Loss: 0.6348, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 065, Loss: 0.6359, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 44, Epoch: 066, Loss: 0.6250, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 44, Epoch: 067, Loss: 0.6248, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 068, Loss: 0.6251, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 44, Epoch: 069, Loss: 0.6303, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 070, Loss: 0.6305, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 44, Epoch: 071, Loss: 0.6331, Val Acc: 0.6446, Test Acc: 0.7143
# Seed: 44, Epoch: 072, Loss: 0.6699, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 44, Epoch: 073, Loss: 0.6384, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 44, Epoch: 074, Loss: 0.6368, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 075, Loss: 0.6310, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 076, Loss: 0.6333, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 077, Loss: 0.6210, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 078, Loss: 0.6344, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 079, Loss: 0.6398, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 080, Loss: 0.6392, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 081, Loss: 0.6338, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 082, Loss: 0.6290, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 083, Loss: 0.6223, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 084, Loss: 0.6195, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 085, Loss: 0.6247, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 086, Loss: 0.6147, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 087, Loss: 0.6150, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 088, Loss: 0.6224, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 089, Loss: 0.6211, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 090, Loss: 0.6128, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 091, Loss: 0.6102, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 44, Epoch: 092, Loss: 0.6100, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 093, Loss: 0.6065, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 094, Loss: 0.6068, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 095, Loss: 0.6141, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 096, Loss: 0.6143, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 44, Epoch: 097, Loss: 0.6127, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 098, Loss: 0.6218, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 44, Epoch: 099, Loss: 0.6152, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 100, Loss: 0.6209, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 101, Loss: 0.6148, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 102, Loss: 0.6175, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 103, Loss: 0.6143, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 104, Loss: 0.6122, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 105, Loss: 0.6021, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 106, Loss: 0.6052, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 107, Loss: 0.5986, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 108, Loss: 0.5965, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 109, Loss: 0.6017, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 110, Loss: 0.5993, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 111, Loss: 0.5982, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 112, Loss: 0.6010, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 113, Loss: 0.5985, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 114, Loss: 0.5930, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 115, Loss: 0.5891, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 116, Loss: 0.5941, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 117, Loss: 0.5958, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 118, Loss: 0.5935, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 44, Epoch: 119, Loss: 0.5893, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 44, Epoch: 120, Loss: 0.5936, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 121, Loss: 0.6019, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 122, Loss: 0.6008, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 123, Loss: 0.6099, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 124, Loss: 0.6013, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 125, Loss: 0.6001, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 126, Loss: 0.6040, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 127, Loss: 0.6069, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 128, Loss: 0.6116, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 129, Loss: 0.6081, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 130, Loss: 0.6133, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 131, Loss: 0.6017, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 132, Loss: 0.6037, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 133, Loss: 0.6006, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 134, Loss: 0.5910, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 135, Loss: 0.6124, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 136, Loss: 0.6139, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 137, Loss: 0.6194, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 138, Loss: 0.6047, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 139, Loss: 0.6011, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 140, Loss: 0.5992, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 141, Loss: 0.6138, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 142, Loss: 0.5949, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 143, Loss: 0.5920, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 144, Loss: 0.5997, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 145, Loss: 0.6002, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 146, Loss: 0.6059, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 147, Loss: 0.6038, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 148, Loss: 0.5992, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 149, Loss: 0.5944, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 150, Loss: 0.5910, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 151, Loss: 0.5941, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 152, Loss: 0.5893, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 153, Loss: 0.6040, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 154, Loss: 0.5979, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 155, Loss: 0.6031, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 156, Loss: 0.6147, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 157, Loss: 0.6048, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 158, Loss: 0.6010, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 44, Epoch: 159, Loss: 0.6061, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 160, Loss: 0.5982, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 161, Loss: 0.5997, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 162, Loss: 0.6016, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 163, Loss: 0.6042, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 164, Loss: 0.6021, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 165, Loss: 0.5994, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 166, Loss: 0.6050, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 167, Loss: 0.5926, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 168, Loss: 0.5907, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 169, Loss: 0.5936, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 170, Loss: 0.5886, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 171, Loss: 0.5895, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 172, Loss: 0.5885, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 173, Loss: 0.6078, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 174, Loss: 0.6083, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 175, Loss: 0.5880, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 44, Epoch: 176, Loss: 0.5905, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 177, Loss: 0.5937, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 178, Loss: 0.5888, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 179, Loss: 0.6145, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 180, Loss: 0.6074, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 181, Loss: 0.5971, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 182, Loss: 0.6010, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 183, Loss: 0.5981, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 184, Loss: 0.6008, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 185, Loss: 0.5964, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 186, Loss: 0.6034, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 187, Loss: 0.5967, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 188, Loss: 0.6003, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 189, Loss: 0.6047, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 190, Loss: 0.6162, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 191, Loss: 0.6064, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 192, Loss: 0.6119, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 193, Loss: 0.5935, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 194, Loss: 0.5987, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 195, Loss: 0.5965, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 196, Loss: 0.5905, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 197, Loss: 0.5901, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 198, Loss: 0.5910, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 199, Loss: 0.5973, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 200, Loss: 0.5891, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 45, Epoch: 001, Loss: 0.6882, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 002, Loss: 0.6736, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 003, Loss: 0.6582, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 004, Loss: 0.6442, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 005, Loss: 0.6400, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 006, Loss: 0.6406, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 007, Loss: 0.6401, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 008, Loss: 0.6425, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 009, Loss: 0.6497, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 010, Loss: 0.6446, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 011, Loss: 0.6482, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 012, Loss: 0.6540, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 013, Loss: 0.6547, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 014, Loss: 0.6506, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 015, Loss: 0.6577, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 016, Loss: 0.6506, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 45, Epoch: 017, Loss: 0.6607, Val Acc: 0.6687, Test Acc: 0.6905
# Seed: 45, Epoch: 018, Loss: 0.6689, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 45, Epoch: 019, Loss: 0.6658, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 020, Loss: 0.6721, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 021, Loss: 0.6664, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 45, Epoch: 022, Loss: 0.6665, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 023, Loss: 0.6647, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 024, Loss: 0.6628, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 025, Loss: 0.6614, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 026, Loss: 0.6556, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 45, Epoch: 027, Loss: 0.6519, Val Acc: 0.6687, Test Acc: 0.6905
# Seed: 45, Epoch: 028, Loss: 0.6481, Val Acc: 0.6687, Test Acc: 0.6786
# Seed: 45, Epoch: 029, Loss: 0.6482, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 030, Loss: 0.6436, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 45, Epoch: 031, Loss: 0.6458, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 032, Loss: 0.6508, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 033, Loss: 0.6449, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 45, Epoch: 034, Loss: 0.6438, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 035, Loss: 0.6524, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 036, Loss: 0.6480, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 45, Epoch: 037, Loss: 0.6454, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 038, Loss: 0.6432, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 45, Epoch: 039, Loss: 0.6428, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 040, Loss: 0.6357, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 041, Loss: 0.6387, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 45, Epoch: 042, Loss: 0.6324, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 043, Loss: 0.6367, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 45, Epoch: 044, Loss: 0.6357, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 045, Loss: 0.6391, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 046, Loss: 0.6361, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 047, Loss: 0.6343, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 048, Loss: 0.6323, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 45, Epoch: 049, Loss: 0.6381, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 050, Loss: 0.6404, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 45, Epoch: 051, Loss: 0.6351, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 45, Epoch: 052, Loss: 0.6345, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 45, Epoch: 053, Loss: 0.6308, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 45, Epoch: 054, Loss: 0.6280, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 45, Epoch: 055, Loss: 0.6282, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 45, Epoch: 056, Loss: 0.6164, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 057, Loss: 0.6246, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 058, Loss: 0.6245, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 45, Epoch: 059, Loss: 0.6276, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 060, Loss: 0.6263, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 061, Loss: 0.6312, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 45, Epoch: 062, Loss: 0.6330, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 063, Loss: 0.6311, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 064, Loss: 0.6361, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 45, Epoch: 065, Loss: 0.6261, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 45, Epoch: 066, Loss: 0.6301, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 45, Epoch: 067, Loss: 0.6185, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 068, Loss: 0.6130, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 069, Loss: 0.6214, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 070, Loss: 0.6174, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 071, Loss: 0.6048, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 45, Epoch: 072, Loss: 0.6057, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 45, Epoch: 073, Loss: 0.6096, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 45, Epoch: 074, Loss: 0.6097, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 45, Epoch: 075, Loss: 0.6186, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 076, Loss: 0.6207, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 45, Epoch: 077, Loss: 0.6305, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 45, Epoch: 078, Loss: 0.6351, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 45, Epoch: 079, Loss: 0.6212, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 45, Epoch: 080, Loss: 0.6367, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 45, Epoch: 081, Loss: 0.6282, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 082, Loss: 0.6258, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 083, Loss: 0.6206, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 45, Epoch: 084, Loss: 0.6154, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 45, Epoch: 085, Loss: 0.6166, Val Acc: 0.6928, Test Acc: 0.7143
# ...
# Seed: 45, Epoch: 175, Loss: 0.5930, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 45, Epoch: 176, Loss: 0.5971, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 45, Epoch: 177, Loss: 0.5920, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 45, Epoch: 178, Loss: 0.5960, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 45, Epoch: 179, Loss: 0.5934, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 180, Loss: 0.6089, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 45, Epoch: 181, Loss: 0.6038, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 45, Epoch: 182, Loss: 0.6058, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 183, Loss: 0.6126, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 45, Epoch: 184, Loss: 0.5994, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 185, Loss: 0.5969, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 45, Epoch: 186, Loss: 0.5949, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 187, Loss: 0.5863, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 45, Epoch: 188, Loss: 0.5883, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 189, Loss: 0.5924, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 45, Epoch: 190, Loss: 0.5934, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 191, Loss: 0.5969, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 45, Epoch: 192, Loss: 0.6101, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 45, Epoch: 193, Loss: 0.5985, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 45, Epoch: 194, Loss: 0.6014, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 45, Epoch: 195, Loss: 0.5933, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 45, Epoch: 196, Loss: 0.5956, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 45, Epoch: 197, Loss: 0.5974, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 45, Epoch: 198, Loss: 0.5855, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 45, Epoch: 199, Loss: 0.5856, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 45, Epoch: 200, Loss: 0.5852, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 001, Loss: 0.6823, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 002, Loss: 0.6697, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 003, Loss: 0.6529, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 004, Loss: 0.6416, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 005, Loss: 0.6427, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 006, Loss: 0.6419, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 007, Loss: 0.6455, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 008, Loss: 0.6489, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 009, Loss: 0.6568, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 010, Loss: 0.6501, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 011, Loss: 0.6525, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 012, Loss: 0.6550, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 013, Loss: 0.6530, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 014, Loss: 0.6554, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 015, Loss: 0.6586, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 016, Loss: 0.6537, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 017, Loss: 0.6516, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 018, Loss: 0.6512, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 019, Loss: 0.6477, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 020, Loss: 0.6450, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 46, Epoch: 021, Loss: 0.6441, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 46, Epoch: 022, Loss: 0.6397, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 46, Epoch: 023, Loss: 0.6448, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 46, Epoch: 024, Loss: 0.6309, Val Acc: 0.6687, Test Acc: 0.6488
# Seed: 46, Epoch: 025, Loss: 0.6331, Val Acc: 0.6687, Test Acc: 0.6667
# Seed: 46, Epoch: 026, Loss: 0.6397, Val Acc: 0.6747, Test Acc: 0.6667
# Seed: 46, Epoch: 027, Loss: 0.6378, Val Acc: 0.6747, Test Acc: 0.6667
# Seed: 46, Epoch: 028, Loss: 0.6321, Val Acc: 0.6747, Test Acc: 0.6726
# Seed: 46, Epoch: 029, Loss: 0.6272, Val Acc: 0.6807, Test Acc: 0.6786
# Seed: 46, Epoch: 030, Loss: 0.6200, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 46, Epoch: 031, Loss: 0.6240, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 46, Epoch: 032, Loss: 0.6206, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 46, Epoch: 033, Loss: 0.6153, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 46, Epoch: 034, Loss: 0.6233, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 46, Epoch: 035, Loss: 0.6354, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 036, Loss: 0.6242, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 037, Loss: 0.6341, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 038, Loss: 0.6477, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 039, Loss: 0.6329, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 040, Loss: 0.6302, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 041, Loss: 0.6246, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 46, Epoch: 042, Loss: 0.6209, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 043, Loss: 0.6329, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 044, Loss: 0.6356, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 46, Epoch: 045, Loss: 0.6372, Val Acc: 0.6566, Test Acc: 0.7321
# Seed: 46, Epoch: 046, Loss: 0.6578, Val Acc: 0.6446, Test Acc: 0.7262
# Seed: 46, Epoch: 047, Loss: 0.6533, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 048, Loss: 0.6481, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 049, Loss: 0.6350, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 050, Loss: 0.6308, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 051, Loss: 0.6285, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 052, Loss: 0.6270, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 053, Loss: 0.6288, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 054, Loss: 0.6275, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 055, Loss: 0.6289, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 056, Loss: 0.6340, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 057, Loss: 0.6351, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 058, Loss: 0.6280, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 059, Loss: 0.6300, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 060, Loss: 0.6191, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 061, Loss: 0.6101, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 062, Loss: 0.6194, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 063, Loss: 0.6081, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 064, Loss: 0.6052, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 065, Loss: 0.6135, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 066, Loss: 0.6161, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 067, Loss: 0.6020, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 068, Loss: 0.6077, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 46, Epoch: 069, Loss: 0.6042, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 070, Loss: 0.6010, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 071, Loss: 0.6025, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 072, Loss: 0.6037, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 46, Epoch: 073, Loss: 0.6080, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 074, Loss: 0.5981, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 075, Loss: 0.6012, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 46, Epoch: 076, Loss: 0.6079, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 077, Loss: 0.6196, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 078, Loss: 0.6042, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 079, Loss: 0.6027, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 080, Loss: 0.6144, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 46, Epoch: 081, Loss: 0.6102, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 46, Epoch: 082, Loss: 0.6134, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 083, Loss: 0.6078, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 084, Loss: 0.6092, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 085, Loss: 0.6116, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 086, Loss: 0.6053, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 087, Loss: 0.6081, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 088, Loss: 0.6139, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 089, Loss: 0.6050, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 090, Loss: 0.6155, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 091, Loss: 0.6093, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 092, Loss: 0.6036, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 093, Loss: 0.6087, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 094, Loss: 0.5981, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 095, Loss: 0.5983, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 096, Loss: 0.6049, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 46, Epoch: 097, Loss: 0.5933, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 46, Epoch: 098, Loss: 0.5971, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 46, Epoch: 099, Loss: 0.5940, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 100, Loss: 0.5944, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 101, Loss: 0.5937, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 102, Loss: 0.5929, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 103, Loss: 0.5960, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 46, Epoch: 104, Loss: 0.6058, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 105, Loss: 0.5971, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 106, Loss: 0.5954, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 107, Loss: 0.5890, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 108, Loss: 0.5957, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 46, Epoch: 109, Loss: 0.6011, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 110, Loss: 0.6230, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 46, Epoch: 111, Loss: 0.6429, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 112, Loss: 0.6434, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 113, Loss: 0.6109, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 114, Loss: 0.6051, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 115, Loss: 0.5951, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 46, Epoch: 116, Loss: 0.5962, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 117, Loss: 0.6044, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 46, Epoch: 118, Loss: 0.5906, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 119, Loss: 0.6070, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 120, Loss: 0.6132, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 46, Epoch: 121, Loss: 0.6127, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 122, Loss: 0.6249, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 123, Loss: 0.6146, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 124, Loss: 0.6133, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 46, Epoch: 125, Loss: 0.6014, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 126, Loss: 0.5998, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 127, Loss: 0.6030, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 128, Loss: 0.6141, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 129, Loss: 0.6007, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 130, Loss: 0.6252, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 131, Loss: 0.6280, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 132, Loss: 0.6295, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 133, Loss: 0.6220, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 134, Loss: 0.6127, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 46, Epoch: 135, Loss: 0.5992, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 136, Loss: 0.6132, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 137, Loss: 0.6032, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 138, Loss: 0.5968, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 139, Loss: 0.5927, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 140, Loss: 0.5958, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 141, Loss: 0.5963, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 142, Loss: 0.5869, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 143, Loss: 0.5860, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 144, Loss: 0.5856, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 46, Epoch: 145, Loss: 0.5849, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 146, Loss: 0.5962, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 46, Epoch: 147, Loss: 0.5903, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 148, Loss: 0.5839, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 149, Loss: 0.5841, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 150, Loss: 0.5908, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 151, Loss: 0.5883, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 152, Loss: 0.5927, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 153, Loss: 0.6134, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 154, Loss: 0.6162, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 155, Loss: 0.6122, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 156, Loss: 0.6161, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 46, Epoch: 157, Loss: 0.5929, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 158, Loss: 0.5870, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 159, Loss: 0.5874, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 160, Loss: 0.5900, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 46, Epoch: 161, Loss: 0.5915, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 162, Loss: 0.6000, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 163, Loss: 0.5949, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 164, Loss: 0.6039, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 46, Epoch: 165, Loss: 0.5942, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 166, Loss: 0.5895, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 167, Loss: 0.5877, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 168, Loss: 0.5898, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 169, Loss: 0.5807, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 170, Loss: 0.5862, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 171, Loss: 0.5790, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 172, Loss: 0.5835, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 173, Loss: 0.5804, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 174, Loss: 0.5756, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 175, Loss: 0.5789, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 176, Loss: 0.5889, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 46, Epoch: 177, Loss: 0.5841, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 178, Loss: 0.6076, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 179, Loss: 0.6067, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 180, Loss: 0.5952, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 181, Loss: 0.5945, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 182, Loss: 0.5870, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 183, Loss: 0.5746, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 184, Loss: 0.5781, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 185, Loss: 0.5793, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 186, Loss: 0.5788, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 187, Loss: 0.5805, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 188, Loss: 0.5835, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 189, Loss: 0.5904, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 190, Loss: 0.5765, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 191, Loss: 0.5850, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 46, Epoch: 192, Loss: 0.5800, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 193, Loss: 0.5875, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 46, Epoch: 194, Loss: 0.6120, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 46, Epoch: 195, Loss: 0.5928, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 196, Loss: 0.5865, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 197, Loss: 0.5885, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 198, Loss: 0.5800, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 199, Loss: 0.5899, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 200, Loss: 0.5889, Val Acc: 0.6988, Test Acc: 0.7560
# Average Time: 55.52 seconds
# Var Time: 0.67 seconds
# Average Memory: 210.00 MB
# Average Best Val Acc: 0.7277
# Std Best Test Acc: 0.0138
# Average Test Acc: 0.7369

# %% [markdown]
# ## CoPooling with HierarchicalGCN (2023)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Parameter
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.nn.conv.gcn_conv import gcn_norm
from torch_geometric.utils import add_remaining_self_loops, to_dense_adj, add_self_loops
from typing import Callable, Optional, Union
from torch_sparse import coalesce, transpose
from torch_scatter import scatter
from torch import Tensor
def cumsum(x: Tensor, dim: int = 0) -> Tensor:
    r"""Returns the cumulative sum of elements of :obj:`x`.
    In contrast to :meth:`torch.cumsum`, prepends the output with zero.

    Args:
        x (torch.Tensor): The input tensor.
        dim (int, optional): The dimension to do the operation over.
            (default: :obj:`0`)

    Example:
        >>> x = torch.tensor([2, 4, 1])
        >>> cumsum(x)
        tensor([0, 2, 6, 7])

    """
    size = x.size()[:dim] + (x.size(dim) + 1, ) + x.size()[dim + 1:]
    out = x.new_empty(size)

    out.narrow(dim, 0, 1).zero_()
    torch.cumsum(x, dim=dim, out=out.narrow(dim, 1, x.size(dim)))

    return out

def maybe_num_nodes(edge_index, num_nodes=None):
    if num_nodes is not None:
        return num_nodes
    elif isinstance(edge_index, Tensor):
        return int(edge_index.max()) + 1 if edge_index.numel() > 0 else 0
    else:
        return max(edge_index.size(0), edge_index.size(1))

def maybe_num_nodes(edge_index, num_nodes=None):
    if num_nodes is not None:
        return num_nodes
    elif isinstance(edge_index, Tensor):
        return int(edge_index.max()) + 1 if edge_index.numel() > 0 else 0
    else:
        return max(edge_index.size(0), edge_index.size(1))

def filter_adj(edge_index, edge_attr, perm, num_nodes=None):
    num_nodes = maybe_num_nodes(edge_index, num_nodes)

    mask = perm.new_full((num_nodes, ), -1)
    i = torch.arange(perm.size(0), dtype=torch.long, device=perm.device)
    mask[perm] = i

    row, col = edge_index
    row, col = mask[row], mask[col]
    mask = (row >= 0) & (col >= 0)
    row, col = row[mask], col[mask]

    if edge_attr is not None:
        edge_attr = edge_attr[mask]

    return torch.stack([row, col], dim=0), edge_attr

def topk(
    x: Tensor,
    ratio: Optional[Union[float, int]],
    batch: Tensor,
    min_score: Optional[float] = None,
    tol: float = 1e-7,
) -> Tensor:
    if min_score is not None:
        # Make sure that we do not drop all nodes in a graph.
        scores_max = scatter(x, batch, reduce='max')[batch] - tol
        scores_min = scores_max.clamp(max=min_score)

        perm = (x > scores_min).nonzero().view(-1)
        return perm

    if ratio is not None:
        num_nodes = scatter(batch.new_ones(x.size(0)), batch, reduce='sum')

        if ratio >= 1:
            k = num_nodes.new_full((num_nodes.size(0), ), int(ratio))
        else:
            k = (float(ratio) * num_nodes.to(x.dtype)).ceil().to(torch.long)

        x, x_perm = torch.sort(x.view(-1), descending=True)
        batch = batch[x_perm]
        batch, batch_perm = torch.sort(batch, descending=False, stable=True)

        arange = torch.arange(x.size(0), dtype=torch.long, device=x.device)
        ptr = cumsum(num_nodes)
        batched_arange = arange - ptr[batch]
        mask = batched_arange < k[batch]

        return x_perm[batch_perm[mask]]

    raise ValueError("At least one of the 'ratio' and 'min_score' parameters "
                     "must be specified")

class GPR_prop(MessagePassing):
    '''
    propagation class for GPR_GNN
    '''

    def __init__(self, K, alpha, Init, Gamma=None, bias=True, **kwargs):
        super(GPR_prop, self).__init__(aggr='add', **kwargs)
        self.K = K
        self.Init = Init
        self.alpha = alpha

        assert Init in ['SGC', 'PPR', 'NPPR', 'Random', 'WS']
        if Init == 'SGC':
            # SGC-like
            TEMP = 0.0*np.ones(K+1)
            TEMP[alpha] = 1.0
        elif Init == 'PPR':
            # PPR-like
            TEMP = alpha*(1-alpha)**np.arange(K+1)
            TEMP[-1] = (1-alpha)**K
        elif Init == 'NPPR':
            # Negative PPR
            TEMP = (alpha)**np.arange(K+1)
            TEMP = TEMP/np.sum(np.abs(TEMP))
        elif Init == 'Random':
            # Random
            bound = np.sqrt(3/(K+1))
            TEMP = np.random.uniform(-bound, bound, K+1)
            TEMP = TEMP/np.sum(np.abs(TEMP))
        elif Init == 'WS':
            # Specify Gamma
            TEMP = Gamma

        self.temp = Parameter(torch.tensor(TEMP))

    def reset_parameters(self):
        torch.nn.init.zeros_(self.temp)
        for k in range(self.K+1):
            self.temp.data[k] = self.alpha*(1-self.alpha)**k
        self.temp.data[-1] = (1-self.alpha)**self.K

    def forward(self, x, edge_index, edge_weight=None):
        edge_index, norm = gcn_norm(
            edge_index, edge_weight, num_nodes=x.size(0), dtype=x.dtype)

        hidden = x*(self.temp[0])
        for k in range(self.K):
            x = self.propagate(edge_index, x=x, norm=norm)
            gamma = self.temp[k+1]
            hidden = hidden + gamma*x
        return hidden

    def message(self, x_j, norm):
        return norm.view(-1, 1) * x_j

    def __repr__(self):
        return '{}(K={}, temp={})'.format(self.__class__.__name__, self.K,
                                           self.temp)


class NodeInformationScore(MessagePassing):
    def __init__(self, improved=False, cached=False, **kwargs):
        super(NodeInformationScore, self).__init__(aggr='add', **kwargs)

        self.improved = improved
        self.cached = cached
        self.cached_result = None
        self.cached_num_edges = None

    @staticmethod
    def norm(edge_index, num_nodes, edge_weight, dtype=None):
        if edge_weight is None:
            edge_weight = torch.ones((edge_index.size(1),), dtype=dtype, device=edge_index.device)

        edge_index, edge_weight = add_remaining_self_loops(edge_index, edge_weight, 0, num_nodes) # in case all the edges are removed

        edge_index = edge_index.type(torch.long)
        row, col = edge_index
        # print(row, col)
        # print(edge_weight.shape, row.shape, num_nodes)
        deg = scatter_add(edge_weight, row, dim=0, dim_size=num_nodes)
        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0

        # row, col = edge_index
        expand_deg = torch.zeros((edge_weight.size(0),), dtype=dtype, device=edge_index.device)
        expand_deg[-num_nodes:] = torch.ones((num_nodes,), dtype=dtype, device=edge_index.device)

        return edge_index, expand_deg - deg_inv_sqrt[row] * edge_weight * deg_inv_sqrt[col]

    def forward(self, x, edge_index, edge_weight):
        if self.cached and self.cached_result is not None:
            if edge_index.size(1) != self.cached_num_edges:
                raise RuntimeError(
                    'Cached {} number of edges, but found {}'.format(self.cached_num_edges, edge_index.size(1)))

        if not self.cached or self.cached_result is None:
            self.cached_num_edges = edge_index.size(1)
            edge_index, norm = self.norm(edge_index, x.size(0), edge_weight, x.dtype)
            self.cached_result = edge_index, norm

        edge_index, norm = self.cached_result

        return self.propagate(edge_index, x=x, norm=norm)

    def message(self, x_j, norm):
        return norm.view(-1, 1) * x_j

    def update(self, aggr_out):
        return aggr_out

class graph_attention(torch.nn.Module):
    # reference: https://github.com/gordicaleksa/pytorch-GAT/blob/39c8f0ee634477033e8b1a6e9a6da3c7ed71bbd1/models/definitions/GAT.py#L324
    src_nodes_dim = 0  # position of source nodes in edge index
    trg_nodes_dim = 1  # position of target nodes in edge index

    nodes_dim = 0      # node dimension/axis
    head_dim = 1       # attention head dimension/axis

    def __init__(self, num_in_features, num_out_features, num_of_heads, dropout_prob=0.6, log_attention_weights=False):
        super().__init__()

        # Saving these as we'll need them in forward propagation in children layers (imp1/2/3)
        self.num_of_heads = num_of_heads
        self.num_out_features = num_out_features
        #
        # Trainable weights: linear projection matrix (denoted as "W" in the paper), attention target/source
        # (denoted as "a" in the paper) and bias (not mentioned in the paper but present in the official GAT repo)
        #

        # You can treat this one matrix as num_of_heads independent W matrices
        self.linear_proj = nn.Linear(num_in_features, num_of_heads * num_out_features, bias=False)

        # After we concatenate target node (node i) and source node (node j) we apply the additive scoring function
        # which gives us un-normalized score "e". Here we split the "a" vector - but the semantics remain the same.

        # Basically instead of doing [x, y] (concatenation, x/y are node feature vectors) and dot product with "a"
        # we instead do a dot product between x and "a_left" and y and "a_right" and we sum them up
        self.scoring_fn_target = nn.Parameter(torch.Tensor(1, num_of_heads, num_out_features))
        self.scoring_fn_source = nn.Parameter(torch.Tensor(1, num_of_heads, num_out_features))

        self.init_params()

    def init_params(self):
        """
        The reason we're using Glorot (aka Xavier uniform) initialization is because it's a default TF initialization:
            https://stackoverflow.com/questions/37350131/what-is-the-default-variable-initializer-in-tensorflow
        The original repo was developed in TensorFlow (TF) and they used the default initialization.
        Feel free to experiment - there may be better initializations depending on your problem.
        """
        nn.init.xavier_uniform_(self.linear_proj.weight)
        nn.init.xavier_uniform_(self.scoring_fn_target)
        nn.init.xavier_uniform_(self.scoring_fn_source)

    def forward(self, x, edge_index):
        #
        # Step 1: Linear Projection + regularization
        #

        in_nodes_features = x  # unpack data
        num_of_nodes = in_nodes_features.shape[self.nodes_dim]

        # shape = (N, FIN) * (FIN, NH*FOUT) -> (N, NH, FOUT) where NH - number of heads, FOUT - num of output features
        # We project the input node features into NH independent output features (one for each attention head)
        nodes_features_proj = self.linear_proj(in_nodes_features).view(-1, self.num_of_heads, self.num_out_features)

        #
        # Step 2: Edge attention calculation
        #

        # Apply the scoring function (* represents element-wise (a.k.a. Hadamard) product)
        # shape = (N, NH, FOUT) * (1, NH, FOUT) -> (N, NH, 1) -> (N, NH) because sum squeezes the last dimension
        # Optimization note: torch.sum() is as performant as .sum() in my experiments
        scores_source = (nodes_features_proj * self.scoring_fn_source).sum(dim=-1)
        scores_target = (nodes_features_proj * self.scoring_fn_target).sum(dim=-1)

        # We simply copy (lift) the scores for source/target nodes based on the edge index. Instead of preparing all
        # the possible combinations of scores we just prepare those that will actually be used and those are defined
        # by the edge index.
        # scores shape = (E, NH), nodes_features_proj_lifted shape = (E, NH, FOUT), E - number of edges in the graph
        scores_source_lifted, scores_target_lifted, nodes_features_proj_lifted = self.lift(scores_source, scores_target, nodes_features_proj, edge_index)
        scores_per_edge = scores_source_lifted + scores_target_lifted

        return torch.sigmoid(scores_per_edge)

    def lift(self, scores_source, scores_target, nodes_features_matrix_proj, edge_index):
        """
        Lifts i.e. duplicates certain vectors depending on the edge index.
        One of the tensor dims goes from N -> E (that's where the "lift" comes from).
        """
        src_nodes_index = edge_index[self.src_nodes_dim]
        trg_nodes_index = edge_index[self.trg_nodes_dim]

        # Using index_select is faster than "normal" indexing (scores_source[src_nodes_index]) in PyTorch!
        scores_source = scores_source.index_select(self.nodes_dim, src_nodes_index)
        scores_target = scores_target.index_select(self.nodes_dim, trg_nodes_index)
        nodes_features_matrix_proj_lifted = nodes_features_matrix_proj.index_select(self.nodes_dim, src_nodes_index)

        return scores_source, scores_target, nodes_features_matrix_proj_lifted



class CoPooling(torch.nn.Module):
    # reference for GAT code: https://github.com/PetarV-/GAT
    # reference for generalized pagerank code: https://github.com/jianhao2016/GPRGNN
    def __init__(self, ratio=0.5, K=0.05, edge_ratio=0.6, nhid=64, alpha=0.1, Init='Random', Gamma=None):
        super(CoPooling, self).__init__()
        self.ratio = ratio
        self.calc_information_score = NodeInformationScore()
        self.edge_ratio = edge_ratio

        self.prop1 = GPR_prop(K, alpha, Init, Gamma)

        score_dim = 32
        self.G_att = graph_attention(num_in_features=nhid, num_out_features=score_dim, num_of_heads=1)

        self.weight = Parameter(torch.Tensor(2*nhid, nhid))
        nn.init.xavier_uniform_(self.weight.data)
        self.bias = Parameter(torch.Tensor(nhid))
        nn.init.zeros_(self.bias.data)

        self.reset_parameters()

    def reset_parameters(self):
        nn.init.xavier_uniform_(self.weight.data)
        nn.init.zeros_(self.bias.data)
        self.prop1.reset_parameters()
        self.G_att.init_params()

    def forward(self, x, edge_index, edge_attr, batch=None, nodes_index=None, node_attr=None):
        if batch is None:
            batch = edge_index.new_zeros(x.size(0))
        ori_batch = batch.clone()
        device = x.device
        num_nodes = x.shape[0]

        # cut edges based on scores
        x_cut = self.prop1(x, edge_index) # run generalized pagerank to update features

        attention = self.G_att(x_cut, edge_index) # get the attention weights after sigmoid
        attention = attention.sum(dim=1) #sum the weights on head dim
        edge_index, attention = add_self_loops(edge_index, attention, 1.0, num_nodes) # add self loops in case no edges

        # to get a systemitic adj matrix
        edge_index_t, attention_t = transpose(edge_index, attention, num_nodes, num_nodes)
        edge_tmp = torch.cat((edge_index, edge_index_t), 1)
        att_tmp = torch.cat((attention, attention_t),0)
        edge_index, attention = coalesce(edge_tmp, att_tmp, num_nodes, num_nodes, 'mean')

        attention_np = attention.cpu().data.numpy()
        cut_val = np.percentile(attention_np, int(100*(1-self.edge_ratio))) # this is for keep the top edge_ratio edges
        attention = attention * (attention >= cut_val) # keep the edge_ratio higher weights of edges

        kep_idx = attention > 0.0
        cut_edge_index, cut_edge_attr = edge_index[:, kep_idx], attention[kep_idx]

        # Graph Pooling based on nodes
        x_information_score = self.calc_information_score(x, cut_edge_index, cut_edge_attr)
        score = torch.sum(torch.abs(x_information_score), dim=1)
        perm = topk(score, self.ratio, batch)
        x_topk = x[perm]
        batch = batch[perm]
        if nodes_index is not None:
            nodes_index = nodes_index[perm]

        if node_attr is not None:
            node_attr = node_attr[perm]
        if cut_edge_index is not None or cut_edge_index.nelement() != 0:
            induced_edge_index, induced_edge_attr = filter_adj(cut_edge_index, cut_edge_attr, perm, num_nodes=num_nodes)
        else:
            print('All edges are cut!')
            induced_edge_index, induced_edge_attr = cut_edge_index, cut_edge_attr

        # update node features
        attention_dense = (to_dense_adj(cut_edge_index, edge_attr=cut_edge_attr, max_num_nodes=num_nodes)).squeeze()
        x = F.relu(torch.matmul(torch.cat((x_topk, torch.matmul(attention_dense[perm],x)), 1), self.weight) + self.bias)

        return x, induced_edge_index, perm, induced_edge_attr, batch, nodes_index, node_attr, attention_dense

# %%
import torch
import torch.nn.functional as F
from torch_geometric.datasets import TUDataset
from torch_geometric.data import DataLoader,Data
from torch_geometric.nn import GCNConv
from torch.utils.data import random_split
import os
import os.path as osp
import argparse
import warnings

import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, EdgePooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch
from torch_geometric.nn import BatchNorm


class HierarchicalGCN_CoPooling(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_CoPooling, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)
        self.pool1 = CoPooling(ratio=0.5, K=1, edge_ratio=0.6, nhid=64, alpha=0.1, Init='Random', Gamma=1.0)
        self.pool2 = CoPooling(ratio=0.5, K=1, edge_ratio=0.6, nhid=64, alpha=0.1, Init='Random', Gamma=1.0)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        batch_size = int(batch.max() + 1)

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, perm, _, batch, _, _, _ = self.pool1(x, edge_index, edge_attr=None, batch=batch)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, perm, _, batch, _, _, _  = self.pool2(x, edge_index, edge_attr=None, batch=batch)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_CoPooling(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_CoPooling(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6912, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 002, Loss: 0.6809, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 003, Loss: 0.6751, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 004, Loss: 0.6730, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 005, Loss: 0.6708, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 006, Loss: 0.6618, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 007, Loss: 0.6529, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 008, Loss: 0.6381, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 009, Loss: 0.6214, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 010, Loss: 0.6270, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 011, Loss: 0.6439, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 012, Loss: 0.6468, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 013, Loss: 0.6548, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 014, Loss: 0.6557, Val Acc: 0.6807, Test Acc: 0.6250
# Seed: 42, Epoch: 015, Loss: 0.6573, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 016, Loss: 0.6413, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 42, Epoch: 017, Loss: 0.6219, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 018, Loss: 0.6241, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 42, Epoch: 019, Loss: 0.6146, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 42, Epoch: 020, Loss: 0.6158, Val Acc: 0.7108, Test Acc: 0.6786
# Seed: 42, Epoch: 021, Loss: 0.6310, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 42, Epoch: 022, Loss: 0.6305, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 023, Loss: 0.6256, Val Acc: 0.7108, Test Acc: 0.6607
# Seed: 42, Epoch: 024, Loss: 0.6229, Val Acc: 0.6928, Test Acc: 0.6667
# Seed: 42, Epoch: 025, Loss: 0.6211, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 42, Epoch: 026, Loss: 0.6231, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 42, Epoch: 027, Loss: 0.6212, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 028, Loss: 0.6460, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 029, Loss: 0.6560, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 030, Loss: 0.6580, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 031, Loss: 0.6530, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 032, Loss: 0.6514, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 42, Epoch: 033, Loss: 0.6527, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 034, Loss: 0.6480, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 035, Loss: 0.6445, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 036, Loss: 0.6311, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 42, Epoch: 037, Loss: 0.6280, Val Acc: 0.7048, Test Acc: 0.6667
# Seed: 42, Epoch: 038, Loss: 0.6177, Val Acc: 0.7108, Test Acc: 0.6607
# Seed: 42, Epoch: 039, Loss: 0.6138, Val Acc: 0.7229, Test Acc: 0.6905
# Seed: 42, Epoch: 040, Loss: 0.6241, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 041, Loss: 0.6287, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 042, Loss: 0.6391, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 043, Loss: 0.6394, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 044, Loss: 0.6348, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 42, Epoch: 045, Loss: 0.6398, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 046, Loss: 0.6270, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 047, Loss: 0.6145, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 048, Loss: 0.6135, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 049, Loss: 0.6180, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 050, Loss: 0.6108, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 051, Loss: 0.6063, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 052, Loss: 0.6026, Val Acc: 0.6988, Test Acc: 0.6786
# Seed: 42, Epoch: 053, Loss: 0.5987, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 054, Loss: 0.5961, Val Acc: 0.6627, Test Acc: 0.7440
# Seed: 42, Epoch: 055, Loss: 0.5960, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 42, Epoch: 056, Loss: 0.6043, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 057, Loss: 0.6161, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 42, Epoch: 058, Loss: 0.5945, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 059, Loss: 0.5927, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 42, Epoch: 060, Loss: 0.5898, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 42, Epoch: 061, Loss: 0.5901, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 062, Loss: 0.5959, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 42, Epoch: 063, Loss: 0.5847, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 064, Loss: 0.6014, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 42, Epoch: 065, Loss: 0.5990, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 066, Loss: 0.6080, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 067, Loss: 0.6094, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 42, Epoch: 068, Loss: 0.6015, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 42, Epoch: 069, Loss: 0.5998, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 070, Loss: 0.5889, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 42, Epoch: 071, Loss: 0.5868, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 42, Epoch: 072, Loss: 0.5840, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 42, Epoch: 073, Loss: 0.5910, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 42, Epoch: 074, Loss: 0.5919, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 075, Loss: 0.5966, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 42, Epoch: 076, Loss: 0.5996, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 42, Epoch: 077, Loss: 0.6024, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 42, Epoch: 078, Loss: 0.5902, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 42, Epoch: 079, Loss: 0.5847, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 080, Loss: 0.5667, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 42, Epoch: 081, Loss: 0.5778, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 082, Loss: 0.5668, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 42, Epoch: 083, Loss: 0.5764, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 084, Loss: 0.5772, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 42, Epoch: 085, Loss: 0.5955, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 42, Epoch: 086, Loss: 0.5918, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 087, Loss: 0.6452, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 088, Loss: 0.6412, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 089, Loss: 0.6437, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 090, Loss: 0.6175, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 091, Loss: 0.6159, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 42, Epoch: 092, Loss: 0.6098, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 093, Loss: 0.6024, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 42, Epoch: 094, Loss: 0.5984, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 42, Epoch: 095, Loss: 0.6036, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 096, Loss: 0.5926, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 42, Epoch: 097, Loss: 0.6003, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 42, Epoch: 098, Loss: 0.5948, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 099, Loss: 0.5986, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 42, Epoch: 100, Loss: 0.5925, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 42, Epoch: 101, Loss: 0.5995, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 42, Epoch: 102, Loss: 0.5959, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 42, Epoch: 103, Loss: 0.5944, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 42, Epoch: 104, Loss: 0.5928, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 105, Loss: 0.5926, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 42, Epoch: 106, Loss: 0.5809, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 42, Epoch: 107, Loss: 0.5834, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 42, Epoch: 108, Loss: 0.5761, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 42, Epoch: 109, Loss: 0.5845, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 42, Epoch: 110, Loss: 0.5834, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 111, Loss: 0.5858, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 42, Epoch: 112, Loss: 0.5758, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 42, Epoch: 113, Loss: 0.5790, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 42, Epoch: 114, Loss: 0.5838, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 115, Loss: 0.5950, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 116, Loss: 0.5989, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 117, Loss: 0.5958, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 118, Loss: 0.5934, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 119, Loss: 0.5921, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 42, Epoch: 120, Loss: 0.5884, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 121, Loss: 0.5865, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 42, Epoch: 122, Loss: 0.5856, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 123, Loss: 0.5937, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 124, Loss: 0.5973, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 42, Epoch: 125, Loss: 0.5924, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 42, Epoch: 126, Loss: 0.5835, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 42, Epoch: 127, Loss: 0.5850, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 42, Epoch: 128, Loss: 0.5909, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 129, Loss: 0.6005, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 130, Loss: 0.6070, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 131, Loss: 0.5981, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 42, Epoch: 132, Loss: 0.5866, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 133, Loss: 0.5839, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 42, Epoch: 134, Loss: 0.5754, Val Acc: 0.7169, Test Acc: 0.6786
# Seed: 42, Epoch: 135, Loss: 0.5713, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 42, Epoch: 136, Loss: 0.5746, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 42, Epoch: 137, Loss: 0.5634, Val Acc: 0.6928, Test Acc: 0.6845
# Seed: 42, Epoch: 138, Loss: 0.5810, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 42, Epoch: 139, Loss: 0.6254, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 140, Loss: 0.5755, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 42, Epoch: 141, Loss: 0.5690, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 42, Epoch: 142, Loss: 0.5709, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 143, Loss: 0.5780, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 42, Epoch: 144, Loss: 0.5728, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 42, Epoch: 145, Loss: 0.5843, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 42, Epoch: 146, Loss: 0.5875, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 42, Epoch: 147, Loss: 0.5883, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 42, Epoch: 148, Loss: 0.5878, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 149, Loss: 0.5734, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 150, Loss: 0.5689, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 151, Loss: 0.5825, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 152, Loss: 0.5788, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 153, Loss: 0.6094, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 154, Loss: 0.6286, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 42, Epoch: 155, Loss: 0.6277, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 156, Loss: 0.6039, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 157, Loss: 0.6058, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 158, Loss: 0.5948, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 159, Loss: 0.5922, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 42, Epoch: 160, Loss: 0.5796, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 161, Loss: 0.5825, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 162, Loss: 0.5776, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 163, Loss: 0.5743, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 164, Loss: 0.5747, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 165, Loss: 0.5722, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 166, Loss: 0.5727, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 42, Epoch: 167, Loss: 0.5789, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 168, Loss: 0.5720, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 169, Loss: 0.5744, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 170, Loss: 0.5802, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 171, Loss: 0.5836, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 42, Epoch: 172, Loss: 0.5866, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 173, Loss: 0.5796, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 42, Epoch: 174, Loss: 0.5760, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 175, Loss: 0.5791, Val Acc: 0.6807, Test Acc: 0.7262
# Early stopping at epoch 175 for seed 42
# Seed: 43, Epoch: 001, Loss: 0.6941, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 002, Loss: 0.6523, Val Acc: 0.6807, Test Acc: 0.6429
# Seed: 43, Epoch: 003, Loss: 0.6305, Val Acc: 0.6747, Test Acc: 0.6488
# Seed: 43, Epoch: 004, Loss: 0.6314, Val Acc: 0.7048, Test Acc: 0.6667
# Seed: 43, Epoch: 005, Loss: 0.6438, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 006, Loss: 0.6508, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 007, Loss: 0.6529, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 008, Loss: 0.6457, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 009, Loss: 0.6458, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 43, Epoch: 010, Loss: 0.6386, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 43, Epoch: 011, Loss: 0.6453, Val Acc: 0.7108, Test Acc: 0.6786
# Seed: 43, Epoch: 012, Loss: 0.6453, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 013, Loss: 0.6512, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 014, Loss: 0.6384, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 015, Loss: 0.6464, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 016, Loss: 0.6469, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 017, Loss: 0.6466, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 018, Loss: 0.6509, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 019, Loss: 0.6412, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 020, Loss: 0.6502, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 021, Loss: 0.6473, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 022, Loss: 0.6458, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 023, Loss: 0.6295, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 024, Loss: 0.6244, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 025, Loss: 0.6272, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 026, Loss: 0.6237, Val Acc: 0.7048, Test Acc: 0.6845
# Seed: 43, Epoch: 027, Loss: 0.6178, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 028, Loss: 0.6232, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 029, Loss: 0.6305, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 030, Loss: 0.6288, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 43, Epoch: 031, Loss: 0.6236, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 43, Epoch: 032, Loss: 0.6301, Val Acc: 0.6627, Test Acc: 0.7321
# Seed: 43, Epoch: 033, Loss: 0.6288, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 43, Epoch: 034, Loss: 0.6649, Val Acc: 0.6627, Test Acc: 0.6905
# Seed: 43, Epoch: 035, Loss: 0.6471, Val Acc: 0.6627, Test Acc: 0.6905
# Seed: 43, Epoch: 036, Loss: 0.6569, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 037, Loss: 0.6305, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 038, Loss: 0.6222, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 43, Epoch: 039, Loss: 0.6125, Val Acc: 0.7048, Test Acc: 0.6667
# Seed: 43, Epoch: 040, Loss: 0.6193, Val Acc: 0.7048, Test Acc: 0.6667
# Seed: 43, Epoch: 041, Loss: 0.6094, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 042, Loss: 0.6129, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 43, Epoch: 043, Loss: 0.6192, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 43, Epoch: 044, Loss: 0.6171, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 045, Loss: 0.6188, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 046, Loss: 0.6171, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 047, Loss: 0.6208, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 048, Loss: 0.6116, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 049, Loss: 0.6091, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 050, Loss: 0.6122, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 051, Loss: 0.6038, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 052, Loss: 0.6096, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 053, Loss: 0.6103, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 054, Loss: 0.6018, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 055, Loss: 0.6077, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 43, Epoch: 056, Loss: 0.6199, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 43, Epoch: 057, Loss: 0.6082, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 058, Loss: 0.6080, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 059, Loss: 0.6047, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 060, Loss: 0.5930, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 43, Epoch: 061, Loss: 0.5967, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 062, Loss: 0.5877, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 43, Epoch: 063, Loss: 0.5950, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 064, Loss: 0.5915, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 43, Epoch: 065, Loss: 0.6110, Val Acc: 0.6627, Test Acc: 0.7321
# Seed: 43, Epoch: 066, Loss: 0.6020, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 067, Loss: 0.6037, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 068, Loss: 0.6166, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 069, Loss: 0.6074, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 43, Epoch: 070, Loss: 0.6189, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 43, Epoch: 071, Loss: 0.6207, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 43, Epoch: 072, Loss: 0.6100, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 073, Loss: 0.5835, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 074, Loss: 0.5885, Val Acc: 0.7229, Test Acc: 0.6726
# Seed: 43, Epoch: 075, Loss: 0.5983, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 076, Loss: 0.6059, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 077, Loss: 0.6184, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 078, Loss: 0.6248, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 43, Epoch: 079, Loss: 0.6423, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 080, Loss: 0.6324, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 081, Loss: 0.6134, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 082, Loss: 0.6048, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 43, Epoch: 083, Loss: 0.5965, Val Acc: 0.7229, Test Acc: 0.6845
# Seed: 43, Epoch: 084, Loss: 0.5994, Val Acc: 0.7410, Test Acc: 0.6905
# Seed: 43, Epoch: 085, Loss: 0.5873, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 43, Epoch: 086, Loss: 0.5914, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 087, Loss: 0.5882, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 088, Loss: 0.5915, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 089, Loss: 0.5949, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 090, Loss: 0.5927, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 091, Loss: 0.6045, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 092, Loss: 0.6010, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 093, Loss: 0.5856, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 094, Loss: 0.5831, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 43, Epoch: 095, Loss: 0.5753, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 096, Loss: 0.5771, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 097, Loss: 0.5861, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 43, Epoch: 098, Loss: 0.5995, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 099, Loss: 0.5951, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 100, Loss: 0.5844, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 43, Epoch: 101, Loss: 0.5865, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 43, Epoch: 102, Loss: 0.5736, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 43, Epoch: 103, Loss: 0.5743, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 43, Epoch: 104, Loss: 0.5870, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 43, Epoch: 105, Loss: 0.6026, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 43, Epoch: 106, Loss: 0.6377, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 43, Epoch: 107, Loss: 0.6359, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 108, Loss: 0.6122, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 43, Epoch: 109, Loss: 0.6093, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 43, Epoch: 110, Loss: 0.5954, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 111, Loss: 0.5881, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 112, Loss: 0.5816, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 113, Loss: 0.5822, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 43, Epoch: 114, Loss: 0.5668, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 43, Epoch: 115, Loss: 0.5705, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 43, Epoch: 116, Loss: 0.5752, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 43, Epoch: 117, Loss: 0.6045, Val Acc: 0.6687, Test Acc: 0.7083
# Seed: 43, Epoch: 118, Loss: 0.6204, Val Acc: 0.6566, Test Acc: 0.6905
# Seed: 43, Epoch: 119, Loss: 0.6351, Val Acc: 0.6687, Test Acc: 0.6964
# Seed: 43, Epoch: 120, Loss: 0.6308, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 121, Loss: 0.6179, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 43, Epoch: 122, Loss: 0.5948, Val Acc: 0.7048, Test Acc: 0.6726
# Seed: 43, Epoch: 123, Loss: 0.6126, Val Acc: 0.6988, Test Acc: 0.6607
# Seed: 43, Epoch: 124, Loss: 0.5994, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 125, Loss: 0.5915, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 126, Loss: 0.5886, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 43, Epoch: 127, Loss: 0.5825, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 128, Loss: 0.5816, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 129, Loss: 0.5874, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 130, Loss: 0.5829, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 43, Epoch: 131, Loss: 0.5808, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 43, Epoch: 132, Loss: 0.5854, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 133, Loss: 0.5847, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 43, Epoch: 134, Loss: 0.5798, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 135, Loss: 0.5810, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 136, Loss: 0.5784, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 137, Loss: 0.5747, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 138, Loss: 0.5682, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 43, Epoch: 139, Loss: 0.5658, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 140, Loss: 0.5683, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 141, Loss: 0.5690, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 142, Loss: 0.5697, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 43, Epoch: 143, Loss: 0.5788, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 43, Epoch: 144, Loss: 0.5716, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 145, Loss: 0.5632, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 146, Loss: 0.5708, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 147, Loss: 0.5789, Val Acc: 0.6566, Test Acc: 0.7321
# Seed: 43, Epoch: 148, Loss: 0.6006, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 43, Epoch: 149, Loss: 0.6157, Val Acc: 0.6627, Test Acc: 0.7202
# Seed: 43, Epoch: 150, Loss: 0.6035, Val Acc: 0.6627, Test Acc: 0.7440
# Seed: 43, Epoch: 151, Loss: 0.5812, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 152, Loss: 0.5872, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 153, Loss: 0.5840, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 154, Loss: 0.5729, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 155, Loss: 0.5790, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 43, Epoch: 156, Loss: 0.5842, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 43, Epoch: 157, Loss: 0.5863, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 43, Epoch: 158, Loss: 0.5723, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 159, Loss: 0.5644, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 160, Loss: 0.5669, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 161, Loss: 0.5648, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 162, Loss: 0.5872, Val Acc: 0.6687, Test Acc: 0.6964
# Seed: 43, Epoch: 163, Loss: 0.6004, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 43, Epoch: 164, Loss: 0.6044, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 43, Epoch: 165, Loss: 0.5882, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 43, Epoch: 166, Loss: 0.5776, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 43, Epoch: 167, Loss: 0.5729, Val Acc: 0.7108, Test Acc: 0.6726
# Seed: 43, Epoch: 168, Loss: 0.5778, Val Acc: 0.6988, Test Acc: 0.6548
# Seed: 43, Epoch: 169, Loss: 0.5773, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 170, Loss: 0.5668, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 43, Epoch: 171, Loss: 0.5638, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 172, Loss: 0.5624, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 173, Loss: 0.5756, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 174, Loss: 0.5666, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 175, Loss: 0.5752, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 43, Epoch: 176, Loss: 0.5691, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 177, Loss: 0.5734, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 178, Loss: 0.5748, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 43, Epoch: 179, Loss: 0.5798, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 43, Epoch: 180, Loss: 0.5724, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 181, Loss: 0.5737, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 43, Epoch: 182, Loss: 0.5694, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 43, Epoch: 183, Loss: 0.5666, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 43, Epoch: 184, Loss: 0.5782, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 185, Loss: 0.5708, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 186, Loss: 0.5551, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 187, Loss: 0.5726, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 43, Epoch: 188, Loss: 0.5634, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 43, Epoch: 189, Loss: 0.5875, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 43, Epoch: 190, Loss: 0.5984, Val Acc: 0.6506, Test Acc: 0.7083
# Seed: 43, Epoch: 191, Loss: 0.6230, Val Acc: 0.6446, Test Acc: 0.7024
# Seed: 43, Epoch: 192, Loss: 0.6028, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 43, Epoch: 193, Loss: 0.5917, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 43, Epoch: 194, Loss: 0.5709, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 195, Loss: 0.5684, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 196, Loss: 0.5675, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 43, Epoch: 197, Loss: 0.5725, Val Acc: 0.7169, Test Acc: 0.6726
# Seed: 43, Epoch: 198, Loss: 0.5751, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 43, Epoch: 199, Loss: 0.5694, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 43, Epoch: 200, Loss: 0.5697, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 001, Loss: 0.6710, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 44, Epoch: 002, Loss: 0.7088, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 44, Epoch: 003, Loss: 0.6115, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 44, Epoch: 004, Loss: 0.6544, Val Acc: 0.6325, Test Acc: 0.6369
# Seed: 44, Epoch: 005, Loss: 0.6702, Val Acc: 0.6687, Test Acc: 0.6905
# Seed: 44, Epoch: 006, Loss: 0.6642, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 007, Loss: 0.6438, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 44, Epoch: 008, Loss: 0.6577, Val Acc: 0.6627, Test Acc: 0.6726
# Seed: 44, Epoch: 009, Loss: 0.6548, Val Acc: 0.6687, Test Acc: 0.7083
# Seed: 44, Epoch: 010, Loss: 0.6480, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 44, Epoch: 011, Loss: 0.6228, Val Acc: 0.6566, Test Acc: 0.7143
# Seed: 44, Epoch: 012, Loss: 0.6258, Val Acc: 0.6446, Test Acc: 0.6845
# Seed: 44, Epoch: 013, Loss: 0.6471, Val Acc: 0.6566, Test Acc: 0.6250
# Seed: 44, Epoch: 014, Loss: 0.6747, Val Acc: 0.5783, Test Acc: 0.6429
# Seed: 44, Epoch: 015, Loss: 0.6736, Val Acc: 0.5843, Test Acc: 0.6548
# Seed: 44, Epoch: 016, Loss: 0.6694, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 44, Epoch: 017, Loss: 0.6637, Val Acc: 0.6627, Test Acc: 0.6905
# Seed: 44, Epoch: 018, Loss: 0.6522, Val Acc: 0.6627, Test Acc: 0.7381
# Seed: 44, Epoch: 019, Loss: 0.6389, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 020, Loss: 0.6246, Val Acc: 0.6867, Test Acc: 0.6726
# Seed: 44, Epoch: 021, Loss: 0.6206, Val Acc: 0.6867, Test Acc: 0.6726
# Seed: 44, Epoch: 022, Loss: 0.6212, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 44, Epoch: 023, Loss: 0.6196, Val Acc: 0.6386, Test Acc: 0.7500
# Seed: 44, Epoch: 024, Loss: 0.6349, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 44, Epoch: 025, Loss: 0.6454, Val Acc: 0.6627, Test Acc: 0.6964
# Seed: 44, Epoch: 026, Loss: 0.6358, Val Acc: 0.6566, Test Acc: 0.7202
# Seed: 44, Epoch: 027, Loss: 0.6463, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 44, Epoch: 028, Loss: 0.6520, Val Acc: 0.6627, Test Acc: 0.7202
# Seed: 44, Epoch: 029, Loss: 0.6376, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 44, Epoch: 030, Loss: 0.6439, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 44, Epoch: 031, Loss: 0.6470, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 44, Epoch: 032, Loss: 0.6485, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 033, Loss: 0.6447, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 44, Epoch: 034, Loss: 0.6630, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 44, Epoch: 035, Loss: 0.6567, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 036, Loss: 0.6487, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 44, Epoch: 037, Loss: 0.6360, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 44, Epoch: 038, Loss: 0.6378, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 44, Epoch: 039, Loss: 0.6367, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 44, Epoch: 040, Loss: 0.6255, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 041, Loss: 0.6251, Val Acc: 0.6566, Test Acc: 0.7500
# Seed: 44, Epoch: 042, Loss: 0.6182, Val Acc: 0.6627, Test Acc: 0.7381
# Seed: 44, Epoch: 043, Loss: 0.6265, Val Acc: 0.6506, Test Acc: 0.7381
# Seed: 44, Epoch: 044, Loss: 0.6168, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 44, Epoch: 045, Loss: 0.6200, Val Acc: 0.6446, Test Acc: 0.7560
# Seed: 44, Epoch: 046, Loss: 0.6219, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 44, Epoch: 047, Loss: 0.6267, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 048, Loss: 0.6282, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 44, Epoch: 049, Loss: 0.6340, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 44, Epoch: 050, Loss: 0.6376, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 44, Epoch: 051, Loss: 0.6341, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 052, Loss: 0.6198, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 053, Loss: 0.6305, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 054, Loss: 0.6304, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 44, Epoch: 055, Loss: 0.6220, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 44, Epoch: 056, Loss: 0.6199, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 44, Epoch: 057, Loss: 0.6165, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 058, Loss: 0.6187, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 059, Loss: 0.6194, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 060, Loss: 0.6012, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 44, Epoch: 061, Loss: 0.6045, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 44, Epoch: 062, Loss: 0.5967, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 063, Loss: 0.6001, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 44, Epoch: 064, Loss: 0.6026, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 065, Loss: 0.6063, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 44, Epoch: 066, Loss: 0.6058, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 067, Loss: 0.6211, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 068, Loss: 0.6331, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 069, Loss: 0.6137, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 070, Loss: 0.6050, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 071, Loss: 0.5933, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 072, Loss: 0.6019, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 073, Loss: 0.6023, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 074, Loss: 0.6013, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 075, Loss: 0.6079, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 076, Loss: 0.6082, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 077, Loss: 0.5975, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 078, Loss: 0.6074, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 079, Loss: 0.5951, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 080, Loss: 0.6176, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 081, Loss: 0.6099, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 082, Loss: 0.6252, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 083, Loss: 0.6347, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 084, Loss: 0.6401, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 085, Loss: 0.6210, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 086, Loss: 0.6073, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 087, Loss: 0.6001, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 088, Loss: 0.6021, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 44, Epoch: 089, Loss: 0.5893, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 090, Loss: 0.5951, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 44, Epoch: 091, Loss: 0.6020, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 44, Epoch: 092, Loss: 0.5993, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 093, Loss: 0.6263, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 094, Loss: 0.6172, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 095, Loss: 0.6184, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 096, Loss: 0.6202, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 097, Loss: 0.6097, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 098, Loss: 0.6135, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 099, Loss: 0.6097, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 100, Loss: 0.6073, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 101, Loss: 0.5958, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 102, Loss: 0.6073, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 103, Loss: 0.6005, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 104, Loss: 0.6030, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 105, Loss: 0.6025, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 106, Loss: 0.6025, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 44, Epoch: 107, Loss: 0.5946, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 108, Loss: 0.5993, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 109, Loss: 0.5936, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 110, Loss: 0.5916, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 111, Loss: 0.5891, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 112, Loss: 0.5941, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 113, Loss: 0.5905, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 114, Loss: 0.5798, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 115, Loss: 0.5877, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 116, Loss: 0.5937, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 117, Loss: 0.5849, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 118, Loss: 0.5919, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 44, Epoch: 119, Loss: 0.5879, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 44, Epoch: 120, Loss: 0.5855, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 121, Loss: 0.5861, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 122, Loss: 0.5867, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 123, Loss: 0.5805, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 124, Loss: 0.5870, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 125, Loss: 0.5845, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 126, Loss: 0.5814, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 44, Epoch: 127, Loss: 0.5800, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 128, Loss: 0.5789, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 129, Loss: 0.5824, Val Acc: 0.7349, Test Acc: 0.7143
# Seed: 44, Epoch: 130, Loss: 0.5825, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 131, Loss: 0.5936, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 132, Loss: 0.6073, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 133, Loss: 0.6266, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 44, Epoch: 134, Loss: 0.6074, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 135, Loss: 0.6003, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 44, Epoch: 136, Loss: 0.5973, Val Acc: 0.7289, Test Acc: 0.6905
# Seed: 44, Epoch: 137, Loss: 0.6026, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 44, Epoch: 138, Loss: 0.5853, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 44, Epoch: 139, Loss: 0.5943, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 140, Loss: 0.5993, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 141, Loss: 0.5982, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 142, Loss: 0.5890, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 143, Loss: 0.5828, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 144, Loss: 0.5937, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 145, Loss: 0.5824, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 146, Loss: 0.5923, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 147, Loss: 0.5989, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 148, Loss: 0.6053, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 149, Loss: 0.6065, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 150, Loss: 0.5919, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 44, Epoch: 151, Loss: 0.5873, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 44, Epoch: 152, Loss: 0.5915, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 153, Loss: 0.5882, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 154, Loss: 0.5845, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 155, Loss: 0.6044, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 44, Epoch: 156, Loss: 0.6104, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 157, Loss: 0.6054, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 158, Loss: 0.5944, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 159, Loss: 0.5866, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 44, Epoch: 160, Loss: 0.5813, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 44, Epoch: 161, Loss: 0.5772, Val Acc: 0.7289, Test Acc: 0.6905
# Seed: 44, Epoch: 162, Loss: 0.5824, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 44, Epoch: 163, Loss: 0.5850, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 164, Loss: 0.6169, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 165, Loss: 0.6391, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 166, Loss: 0.6214, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 167, Loss: 0.6004, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 44, Epoch: 168, Loss: 0.5952, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 169, Loss: 0.5922, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 44, Epoch: 170, Loss: 0.5891, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 44, Epoch: 171, Loss: 0.5848, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 44, Epoch: 172, Loss: 0.5860, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 44, Epoch: 173, Loss: 0.5798, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 174, Loss: 0.5876, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 44, Epoch: 175, Loss: 0.5931, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 44, Epoch: 176, Loss: 0.5898, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 177, Loss: 0.5953, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 178, Loss: 0.6027, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 179, Loss: 0.5956, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 180, Loss: 0.5902, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 44, Epoch: 181, Loss: 0.5888, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 44, Epoch: 182, Loss: 0.5914, Val Acc: 0.6928, Test Acc: 0.6845
# Seed: 44, Epoch: 183, Loss: 0.5901, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 184, Loss: 0.5915, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 185, Loss: 0.6010, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 44, Epoch: 186, Loss: 0.5969, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 44, Epoch: 187, Loss: 0.5933, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 44, Epoch: 188, Loss: 0.5849, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 189, Loss: 0.5845, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 190, Loss: 0.5865, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 191, Loss: 0.5879, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 44, Epoch: 192, Loss: 0.5989, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 44, Epoch: 193, Loss: 0.5942, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 44, Epoch: 194, Loss: 0.5934, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 44, Epoch: 195, Loss: 0.5931, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 44, Epoch: 196, Loss: 0.5784, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 44, Epoch: 197, Loss: 0.5750, Val Acc: 0.6687, Test Acc: 0.6905
# Seed: 44, Epoch: 198, Loss: 0.5715, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 44, Epoch: 199, Loss: 0.5714, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 44, Epoch: 200, Loss: 0.5694, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 45, Epoch: 001, Loss: 0.6679, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 002, Loss: 0.6350, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 003, Loss: 0.6331, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 004, Loss: 0.6308, Val Acc: 0.6446, Test Acc: 0.6786
# Seed: 45, Epoch: 005, Loss: 0.6514, Val Acc: 0.6566, Test Acc: 0.7083
# Seed: 45, Epoch: 006, Loss: 0.6560, Val Acc: 0.6627, Test Acc: 0.7143
# Seed: 45, Epoch: 007, Loss: 0.6626, Val Acc: 0.6627, Test Acc: 0.7202
# Seed: 45, Epoch: 008, Loss: 0.6654, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 45, Epoch: 009, Loss: 0.6704, Val Acc: 0.6627, Test Acc: 0.6964
# Seed: 45, Epoch: 010, Loss: 0.6671, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 45, Epoch: 011, Loss: 0.6558, Val Acc: 0.6627, Test Acc: 0.6845
# Seed: 45, Epoch: 012, Loss: 0.6412, Val Acc: 0.6325, Test Acc: 0.7202
# Seed: 45, Epoch: 013, Loss: 0.6327, Val Acc: 0.6506, Test Acc: 0.7202
# Seed: 45, Epoch: 014, Loss: 0.6265, Val Acc: 0.6506, Test Acc: 0.7083
# Seed: 45, Epoch: 015, Loss: 0.6186, Val Acc: 0.6566, Test Acc: 0.7143
# Seed: 45, Epoch: 016, Loss: 0.6254, Val Acc: 0.6627, Test Acc: 0.7024
# Seed: 45, Epoch: 017, Loss: 0.6294, Val Acc: 0.6687, Test Acc: 0.7024
# Seed: 45, Epoch: 018, Loss: 0.6297, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 45, Epoch: 019, Loss: 0.6257, Val Acc: 0.6687, Test Acc: 0.6964
# Seed: 45, Epoch: 020, Loss: 0.6251, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 45, Epoch: 021, Loss: 0.6233, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 45, Epoch: 022, Loss: 0.6300, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 45, Epoch: 023, Loss: 0.6167, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 45, Epoch: 024, Loss: 0.6226, Val Acc: 0.6566, Test Acc: 0.7024
# Seed: 45, Epoch: 025, Loss: 0.6209, Val Acc: 0.6627, Test Acc: 0.7024
# Seed: 45, Epoch: 026, Loss: 0.6154, Val Acc: 0.6506, Test Acc: 0.7024
# Seed: 45, Epoch: 027, Loss: 0.6240, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 45, Epoch: 028, Loss: 0.6073, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 45, Epoch: 029, Loss: 0.6320, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 45, Epoch: 030, Loss: 0.6392, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 45, Epoch: 031, Loss: 0.6475, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 45, Epoch: 032, Loss: 0.6427, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 45, Epoch: 033, Loss: 0.6441, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 45, Epoch: 034, Loss: 0.6422, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 45, Epoch: 035, Loss: 0.6296, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 45, Epoch: 036, Loss: 0.6210, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 45, Epoch: 037, Loss: 0.6105, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 45, Epoch: 038, Loss: 0.6298, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 039, Loss: 0.6249, Val Acc: 0.6747, Test Acc: 0.7143
# Seed: 45, Epoch: 040, Loss: 0.6399, Val Acc: 0.6627, Test Acc: 0.6905
# Seed: 45, Epoch: 041, Loss: 0.6438, Val Acc: 0.6627, Test Acc: 0.7202
# Seed: 45, Epoch: 042, Loss: 0.6370, Val Acc: 0.6627, Test Acc: 0.7024
# Seed: 45, Epoch: 043, Loss: 0.6406, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 45, Epoch: 044, Loss: 0.6323, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 45, Epoch: 045, Loss: 0.6242, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 45, Epoch: 046, Loss: 0.6178, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 047, Loss: 0.6224, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 048, Loss: 0.6254, Val Acc: 0.6566, Test Acc: 0.7024
# Seed: 45, Epoch: 049, Loss: 0.6389, Val Acc: 0.6506, Test Acc: 0.6667
# Seed: 45, Epoch: 050, Loss: 0.6523, Val Acc: 0.6446, Test Acc: 0.6786
# Seed: 45, Epoch: 051, Loss: 0.6486, Val Acc: 0.6386, Test Acc: 0.6786
# Seed: 45, Epoch: 052, Loss: 0.6468, Val Acc: 0.6446, Test Acc: 0.6905
# Seed: 45, Epoch: 053, Loss: 0.6490, Val Acc: 0.6566, Test Acc: 0.6786
# Seed: 45, Epoch: 054, Loss: 0.6303, Val Acc: 0.6687, Test Acc: 0.7083
# Seed: 45, Epoch: 055, Loss: 0.6235, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 45, Epoch: 056, Loss: 0.6156, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 057, Loss: 0.6095, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 45, Epoch: 058, Loss: 0.6089, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 45, Epoch: 059, Loss: 0.6094, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 060, Loss: 0.6107, Val Acc: 0.6627, Test Acc: 0.7440
# Seed: 45, Epoch: 061, Loss: 0.6019, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 062, Loss: 0.6067, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 45, Epoch: 063, Loss: 0.5999, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 45, Epoch: 064, Loss: 0.5994, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 45, Epoch: 065, Loss: 0.6118, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 066, Loss: 0.6212, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 45, Epoch: 067, Loss: 0.6104, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 45, Epoch: 068, Loss: 0.6293, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 45, Epoch: 069, Loss: 0.6286, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 45, Epoch: 070, Loss: 0.6197, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 45, Epoch: 071, Loss: 0.6178, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 45, Epoch: 072, Loss: 0.6227, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 45, Epoch: 073, Loss: 0.6156, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 074, Loss: 0.6102, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 45, Epoch: 075, Loss: 0.6092, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 45, Epoch: 076, Loss: 0.6032, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 45, Epoch: 077, Loss: 0.5970, Val Acc: 0.6627, Test Acc: 0.7024
# Seed: 45, Epoch: 078, Loss: 0.5977, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 45, Epoch: 079, Loss: 0.6235, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 080, Loss: 0.6128, Val Acc: 0.6566, Test Acc: 0.7262
# Seed: 45, Epoch: 081, Loss: 0.6285, Val Acc: 0.6506, Test Acc: 0.6786
# Seed: 45, Epoch: 082, Loss: 0.6255, Val Acc: 0.6627, Test Acc: 0.7381
# Seed: 45, Epoch: 083, Loss: 0.6318, Val Acc: 0.6627, Test Acc: 0.7321
# Seed: 45, Epoch: 084, Loss: 0.6274, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 45, Epoch: 085, Loss: 0.6265, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 086, Loss: 0.6175, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 087, Loss: 0.6111, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 45, Epoch: 088, Loss: 0.6085, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 45, Epoch: 089, Loss: 0.5949, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 45, Epoch: 090, Loss: 0.6141, Val Acc: 0.6747, Test Acc: 0.7024
# Seed: 45, Epoch: 091, Loss: 0.5984, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 45, Epoch: 092, Loss: 0.6105, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 45, Epoch: 093, Loss: 0.6200, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 45, Epoch: 094, Loss: 0.6256, Val Acc: 0.6566, Test Acc: 0.7202
# Seed: 45, Epoch: 095, Loss: 0.6186, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 45, Epoch: 096, Loss: 0.6128, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 45, Epoch: 097, Loss: 0.6047, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 45, Epoch: 098, Loss: 0.6090, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 45, Epoch: 099, Loss: 0.6004, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 45, Epoch: 100, Loss: 0.6082, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 45, Epoch: 101, Loss: 0.6121, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 45, Epoch: 102, Loss: 0.6049, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 45, Epoch: 103, Loss: 0.6252, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 45, Epoch: 104, Loss: 0.6121, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 45, Epoch: 105, Loss: 0.5987, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 45, Epoch: 106, Loss: 0.5939, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 45, Epoch: 107, Loss: 0.6004, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 108, Loss: 0.5945, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 109, Loss: 0.6078, Val Acc: 0.6024, Test Acc: 0.6845
# Seed: 45, Epoch: 110, Loss: 0.6935, Val Acc: 0.6928, Test Acc: 0.7083
# ...
# Seed: 45, Epoch: 175, Loss: 0.5894, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 45, Epoch: 176, Loss: 0.5934, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 45, Epoch: 177, Loss: 0.6049, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 178, Loss: 0.6002, Val Acc: 0.7169, Test Acc: 0.7917
# Seed: 45, Epoch: 179, Loss: 0.5977, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 45, Epoch: 180, Loss: 0.5882, Val Acc: 0.6928, Test Acc: 0.7857
# Seed: 45, Epoch: 181, Loss: 0.5919, Val Acc: 0.6807, Test Acc: 0.7917
# Seed: 45, Epoch: 182, Loss: 0.5845, Val Acc: 0.6988, Test Acc: 0.8036
# Seed: 45, Epoch: 183, Loss: 0.5912, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 45, Epoch: 184, Loss: 0.6451, Val Acc: 0.6807, Test Acc: 0.7798
# Seed: 45, Epoch: 185, Loss: 0.5998, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 45, Epoch: 186, Loss: 0.5736, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 187, Loss: 0.5777, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 45, Epoch: 188, Loss: 0.5789, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 45, Epoch: 189, Loss: 0.5766, Val Acc: 0.6928, Test Acc: 0.7976
# Seed: 45, Epoch: 190, Loss: 0.5810, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 45, Epoch: 191, Loss: 0.5982, Val Acc: 0.7169, Test Acc: 0.7857
# Seed: 45, Epoch: 192, Loss: 0.5938, Val Acc: 0.7349, Test Acc: 0.7917
# Seed: 45, Epoch: 193, Loss: 0.5896, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 45, Epoch: 194, Loss: 0.5724, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 195, Loss: 0.5757, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 45, Epoch: 196, Loss: 0.5819, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 45, Epoch: 197, Loss: 0.5954, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 45, Epoch: 198, Loss: 0.5924, Val Acc: 0.7289, Test Acc: 0.7976
# Seed: 45, Epoch: 199, Loss: 0.5859, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 45, Epoch: 200, Loss: 0.5837, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 46, Epoch: 001, Loss: 0.6814, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 002, Loss: 0.6480, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 003, Loss: 0.6358, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 004, Loss: 0.6429, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 005, Loss: 0.6357, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 006, Loss: 0.6337, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 007, Loss: 0.6367, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 46, Epoch: 008, Loss: 0.6407, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 46, Epoch: 009, Loss: 0.6544, Val Acc: 0.6506, Test Acc: 0.6071
# Seed: 46, Epoch: 010, Loss: 0.6572, Val Acc: 0.6506, Test Acc: 0.6071
# Seed: 46, Epoch: 011, Loss: 0.6439, Val Acc: 0.6506, Test Acc: 0.6131
# Seed: 46, Epoch: 012, Loss: 0.6221, Val Acc: 0.6627, Test Acc: 0.6131
# Seed: 46, Epoch: 013, Loss: 0.6291, Val Acc: 0.6807, Test Acc: 0.6310
# Seed: 46, Epoch: 014, Loss: 0.6205, Val Acc: 0.6687, Test Acc: 0.6786
# Seed: 46, Epoch: 015, Loss: 0.6289, Val Acc: 0.6566, Test Acc: 0.7143
# Seed: 46, Epoch: 016, Loss: 0.6332, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 017, Loss: 0.6393, Val Acc: 0.6566, Test Acc: 0.7262
# Seed: 46, Epoch: 018, Loss: 0.6349, Val Acc: 0.6566, Test Acc: 0.7143
# Seed: 46, Epoch: 019, Loss: 0.6541, Val Acc: 0.6627, Test Acc: 0.7321
# Seed: 46, Epoch: 020, Loss: 0.6545, Val Acc: 0.6506, Test Acc: 0.7143
# Seed: 46, Epoch: 021, Loss: 0.6660, Val Acc: 0.6506, Test Acc: 0.7083
# Seed: 46, Epoch: 022, Loss: 0.6641, Val Acc: 0.6627, Test Acc: 0.7321
# Seed: 46, Epoch: 023, Loss: 0.6555, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 46, Epoch: 024, Loss: 0.6519, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 46, Epoch: 025, Loss: 0.6439, Val Acc: 0.6627, Test Acc: 0.7202
# Seed: 46, Epoch: 026, Loss: 0.6352, Val Acc: 0.6566, Test Acc: 0.7024
# Seed: 46, Epoch: 027, Loss: 0.6237, Val Acc: 0.6446, Test Acc: 0.7024
# Seed: 46, Epoch: 028, Loss: 0.6100, Val Acc: 0.6506, Test Acc: 0.7083
# Seed: 46, Epoch: 029, Loss: 0.6185, Val Acc: 0.6506, Test Acc: 0.7083
# Seed: 46, Epoch: 030, Loss: 0.6155, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 031, Loss: 0.6214, Val Acc: 0.6506, Test Acc: 0.7381
# Seed: 46, Epoch: 032, Loss: 0.6319, Val Acc: 0.6566, Test Acc: 0.7024
# Seed: 46, Epoch: 033, Loss: 0.6355, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 46, Epoch: 034, Loss: 0.6553, Val Acc: 0.6627, Test Acc: 0.7143
# Seed: 46, Epoch: 035, Loss: 0.6526, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 46, Epoch: 036, Loss: 0.6526, Val Acc: 0.6446, Test Acc: 0.7083
# Seed: 46, Epoch: 037, Loss: 0.6442, Val Acc: 0.6506, Test Acc: 0.7143
# Seed: 46, Epoch: 038, Loss: 0.6405, Val Acc: 0.6627, Test Acc: 0.7143
# Seed: 46, Epoch: 039, Loss: 0.6331, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 46, Epoch: 040, Loss: 0.6245, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 46, Epoch: 041, Loss: 0.6275, Val Acc: 0.6506, Test Acc: 0.7381
# Seed: 46, Epoch: 042, Loss: 0.6213, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 043, Loss: 0.6342, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 46, Epoch: 044, Loss: 0.6309, Val Acc: 0.6627, Test Acc: 0.7321
# Seed: 46, Epoch: 045, Loss: 0.6332, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 046, Loss: 0.6329, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 46, Epoch: 047, Loss: 0.6247, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 46, Epoch: 048, Loss: 0.6232, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 46, Epoch: 049, Loss: 0.6111, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 050, Loss: 0.6142, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 051, Loss: 0.6104, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 46, Epoch: 052, Loss: 0.6085, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 053, Loss: 0.6239, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 054, Loss: 0.6248, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 055, Loss: 0.6243, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 46, Epoch: 056, Loss: 0.6291, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 46, Epoch: 057, Loss: 0.6272, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 46, Epoch: 058, Loss: 0.6169, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 46, Epoch: 059, Loss: 0.6166, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 060, Loss: 0.6119, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 46, Epoch: 061, Loss: 0.6111, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 46, Epoch: 062, Loss: 0.6087, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 063, Loss: 0.6087, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 46, Epoch: 064, Loss: 0.6124, Val Acc: 0.6627, Test Acc: 0.7143
# Seed: 46, Epoch: 065, Loss: 0.6114, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 46, Epoch: 066, Loss: 0.6067, Val Acc: 0.6687, Test Acc: 0.7083
# Seed: 46, Epoch: 067, Loss: 0.6025, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 46, Epoch: 068, Loss: 0.5960, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 069, Loss: 0.6052, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 070, Loss: 0.5930, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 46, Epoch: 071, Loss: 0.6047, Val Acc: 0.6506, Test Acc: 0.7143
# Seed: 46, Epoch: 072, Loss: 0.6268, Val Acc: 0.6506, Test Acc: 0.7202
# Seed: 46, Epoch: 073, Loss: 0.6273, Val Acc: 0.6627, Test Acc: 0.7202
# Seed: 46, Epoch: 074, Loss: 0.6409, Val Acc: 0.6446, Test Acc: 0.7024
# Seed: 46, Epoch: 075, Loss: 0.6394, Val Acc: 0.6566, Test Acc: 0.7024
# Seed: 46, Epoch: 076, Loss: 0.6320, Val Acc: 0.6506, Test Acc: 0.7202
# Seed: 46, Epoch: 077, Loss: 0.6328, Val Acc: 0.6506, Test Acc: 0.7143
# Seed: 46, Epoch: 078, Loss: 0.6321, Val Acc: 0.6627, Test Acc: 0.7143
# Seed: 46, Epoch: 079, Loss: 0.6285, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 46, Epoch: 080, Loss: 0.6193, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 46, Epoch: 081, Loss: 0.6137, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 46, Epoch: 082, Loss: 0.6080, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 083, Loss: 0.6184, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 084, Loss: 0.6148, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 085, Loss: 0.6191, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 46, Epoch: 086, Loss: 0.6076, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 46, Epoch: 087, Loss: 0.6140, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 46, Epoch: 088, Loss: 0.6084, Val Acc: 0.6687, Test Acc: 0.7679
# Seed: 46, Epoch: 089, Loss: 0.6120, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 46, Epoch: 090, Loss: 0.6097, Val Acc: 0.6627, Test Acc: 0.7738
# Seed: 46, Epoch: 091, Loss: 0.6075, Val Acc: 0.6687, Test Acc: 0.7679
# Seed: 46, Epoch: 092, Loss: 0.5984, Val Acc: 0.6687, Test Acc: 0.7738
# Seed: 46, Epoch: 093, Loss: 0.6011, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 46, Epoch: 094, Loss: 0.6062, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 095, Loss: 0.5991, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 46, Epoch: 096, Loss: 0.6038, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 097, Loss: 0.5971, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 098, Loss: 0.5929, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 099, Loss: 0.5900, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 100, Loss: 0.5889, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 46, Epoch: 101, Loss: 0.5911, Val Acc: 0.6627, Test Acc: 0.7679
# Seed: 46, Epoch: 102, Loss: 0.5965, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 103, Loss: 0.6057, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 46, Epoch: 104, Loss: 0.6018, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 46, Epoch: 105, Loss: 0.5865, Val Acc: 0.6627, Test Acc: 0.7798
# Seed: 46, Epoch: 106, Loss: 0.5855, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 107, Loss: 0.5867, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 108, Loss: 0.5866, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 46, Epoch: 109, Loss: 0.5980, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 46, Epoch: 110, Loss: 0.6125, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 46, Epoch: 111, Loss: 0.6029, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 46, Epoch: 112, Loss: 0.5963, Val Acc: 0.6807, Test Acc: 0.7798
# Seed: 46, Epoch: 113, Loss: 0.5829, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 46, Epoch: 114, Loss: 0.5945, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 115, Loss: 0.5808, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 116, Loss: 0.5923, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 117, Loss: 0.5858, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 46, Epoch: 118, Loss: 0.5990, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 119, Loss: 0.6023, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 46, Epoch: 120, Loss: 0.6027, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 121, Loss: 0.5935, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 122, Loss: 0.5824, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 123, Loss: 0.5947, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 124, Loss: 0.5925, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 46, Epoch: 125, Loss: 0.5865, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 126, Loss: 0.5737, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 46, Epoch: 127, Loss: 0.5794, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 128, Loss: 0.5757, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 46, Epoch: 129, Loss: 0.5750, Val Acc: 0.7048, Test Acc: 0.8036
# Seed: 46, Epoch: 130, Loss: 0.5681, Val Acc: 0.6988, Test Acc: 0.7917
# Seed: 46, Epoch: 131, Loss: 0.5708, Val Acc: 0.7108, Test Acc: 0.7976
# Seed: 46, Epoch: 132, Loss: 0.5806, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 46, Epoch: 133, Loss: 0.5976, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 46, Epoch: 134, Loss: 0.6009, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 135, Loss: 0.5952, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 46, Epoch: 136, Loss: 0.6040, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 137, Loss: 0.5967, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 46, Epoch: 138, Loss: 0.5828, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 46, Epoch: 139, Loss: 0.5747, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 46, Epoch: 140, Loss: 0.5736, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 141, Loss: 0.5744, Val Acc: 0.7048, Test Acc: 0.8095
# Seed: 46, Epoch: 142, Loss: 0.5815, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 143, Loss: 0.6047, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 46, Epoch: 144, Loss: 0.5975, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 145, Loss: 0.6003, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 146, Loss: 0.5927, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 46, Epoch: 147, Loss: 0.5834, Val Acc: 0.6988, Test Acc: 0.7917
# Seed: 46, Epoch: 148, Loss: 0.5756, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 46, Epoch: 149, Loss: 0.5779, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 150, Loss: 0.5816, Val Acc: 0.7048, Test Acc: 0.7857
# Seed: 46, Epoch: 151, Loss: 0.5811, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 46, Epoch: 152, Loss: 0.5701, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 153, Loss: 0.5678, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 46, Epoch: 154, Loss: 0.5798, Val Acc: 0.7169, Test Acc: 0.7917
# Seed: 46, Epoch: 155, Loss: 0.5728, Val Acc: 0.7048, Test Acc: 0.7857
# Seed: 46, Epoch: 156, Loss: 0.5653, Val Acc: 0.7289, Test Acc: 0.7857
# Seed: 46, Epoch: 157, Loss: 0.5817, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 46, Epoch: 158, Loss: 0.5873, Val Acc: 0.7169, Test Acc: 0.7798
# Seed: 46, Epoch: 159, Loss: 0.5979, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 46, Epoch: 160, Loss: 0.5891, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 46, Epoch: 161, Loss: 0.5770, Val Acc: 0.7470, Test Acc: 0.7917
# Seed: 46, Epoch: 162, Loss: 0.5811, Val Acc: 0.7410, Test Acc: 0.7857
# Seed: 46, Epoch: 163, Loss: 0.5846, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 46, Epoch: 164, Loss: 0.5754, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 165, Loss: 0.5867, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 166, Loss: 0.5835, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 167, Loss: 0.5837, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 168, Loss: 0.5803, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 169, Loss: 0.5780, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 46, Epoch: 170, Loss: 0.5719, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 46, Epoch: 171, Loss: 0.5720, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 172, Loss: 0.5691, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 46, Epoch: 173, Loss: 0.5683, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 46, Epoch: 174, Loss: 0.5721, Val Acc: 0.6988, Test Acc: 0.7917
# Seed: 46, Epoch: 175, Loss: 0.5695, Val Acc: 0.7410, Test Acc: 0.7857
# Seed: 46, Epoch: 176, Loss: 0.5742, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 177, Loss: 0.6126, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 178, Loss: 0.5678, Val Acc: 0.7169, Test Acc: 0.7798
# Seed: 46, Epoch: 179, Loss: 0.5829, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 46, Epoch: 180, Loss: 0.5682, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 181, Loss: 0.5645, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 182, Loss: 0.5789, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 183, Loss: 0.5822, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 184, Loss: 0.5660, Val Acc: 0.6988, Test Acc: 0.7917
# Seed: 46, Epoch: 185, Loss: 0.5638, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 46, Epoch: 186, Loss: 0.5706, Val Acc: 0.7108, Test Acc: 0.7917
# Seed: 46, Epoch: 187, Loss: 0.5668, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 46, Epoch: 188, Loss: 0.5772, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 189, Loss: 0.5796, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 190, Loss: 0.5670, Val Acc: 0.7108, Test Acc: 0.7976
# Seed: 46, Epoch: 191, Loss: 0.5716, Val Acc: 0.7229, Test Acc: 0.8036
# Seed: 46, Epoch: 192, Loss: 0.5703, Val Acc: 0.7229, Test Acc: 0.7917
# Seed: 46, Epoch: 193, Loss: 0.5738, Val Acc: 0.7289, Test Acc: 0.7917
# Seed: 46, Epoch: 194, Loss: 0.5724, Val Acc: 0.7229, Test Acc: 0.8036
# Seed: 46, Epoch: 195, Loss: 0.5729, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 46, Epoch: 196, Loss: 0.5742, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 46, Epoch: 197, Loss: 0.5798, Val Acc: 0.7169, Test Acc: 0.7976
# Seed: 46, Epoch: 198, Loss: 0.5716, Val Acc: 0.6928, Test Acc: 0.7917
# Seed: 46, Epoch: 199, Loss: 0.5552, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 200, Loss: 0.5604, Val Acc: 0.7169, Test Acc: 0.7679
# Average Time: 41.85 seconds
# Var Time: 5.16 seconds
# Average Memory: 3621.20 MB
# Average Best Val Acc: 0.7373
# Std Best Test Acc: 0.0454
# Average Test Acc: 0.7369

# %% [markdown]
# ## CGIPooling with HierarchicalGCN (2021)

# %%
from torch_scatter import scatter_add, scatter
from torch_geometric.nn.inits import uniform
from torch_geometric.nn.resolver import activation_resolver
from torch_geometric.nn import GCNConv, GATConv, LEConv, SAGEConv, GraphConv
from torch_geometric.nn import global_mean_pool as gap, global_max_pool as gmp

from dataclasses import dataclass
from typing import Optional

import torch
from torch import Tensor


@dataclass(init=False)
class SelectOutput:
    r"""The output of the :class:`Select` method, which holds an assignment
    from selected nodes to their respective cluster(s).

    Args:
        node_index (torch.Tensor): The indices of the selected nodes.
        num_nodes (int): The number of nodes.
        cluster_index (torch.Tensor): The indices of the clusters each node in
            :obj:`node_index` is assigned to.
        num_clusters (int): The number of clusters.
        weight (torch.Tensor, optional): A weight vector, denoting the strength
            of the assignment of a node to its cluster. (default: :obj:`None`)
    """
    node_index: Tensor
    num_nodes: int
    cluster_index: Tensor
    num_clusters: int
    weight: Optional[Tensor] = None

    def __init__(
        self,
        node_index: Tensor,
        num_nodes: int,
        cluster_index: Tensor,
        num_clusters: int,
        weight: Optional[Tensor] = None,
    ):
        if node_index.dim() != 1:
            raise ValueError(f"Expected 'node_index' to be one-dimensional "
                             f"(got {node_index.dim()} dimensions)")

        if cluster_index.dim() != 1:
            raise ValueError(f"Expected 'cluster_index' to be one-dimensional "
                             f"(got {cluster_index.dim()} dimensions)")

        if node_index.numel() != cluster_index.numel():
            raise ValueError(f"Expected 'node_index' and 'cluster_index' to "
                             f"hold the same number of values (got "
                             f"{node_index.numel()} and "
                             f"{cluster_index.numel()} values)")

        if weight is not None and weight.dim() != 1:
            raise ValueError(f"Expected 'weight' vector to be one-dimensional "
                             f"(got {weight.dim()} dimensions)")

        if weight is not None and weight.numel() != node_index.numel():
            raise ValueError(f"Expected 'weight' to hold {node_index.numel()} "
                             f"values (got {weight.numel()} values)")

        self.node_index = node_index
        self.num_nodes = num_nodes
        self.cluster_index = cluster_index
        self.num_clusters = num_clusters
        self.weight = weight




class Select(torch.nn.Module):
    r"""An abstract base class for implementing custom node selections as
    described in the `"Understanding Pooling in Graph Neural Networks"
    <https://arxiv.org/abs/1905.05178>`_ paper, which maps the nodes of an
    input graph to supernodes in the coarsened graph.

    Specifically, :class:`Select` returns a :class:`SelectOutput` output, which
    holds a (sparse) mapping :math:`\mathbf{C} \in {[0, 1]}^{N \times C}` that
    assigns selected nodes to one or more of :math:`C` super nodes.
    """
    def reset_parameters(self):
        r"""Resets all learnable parameters of the module."""
        pass

    def forward(self, *args, **kwargs) -> SelectOutput:
        raise NotImplementedError

    def __repr__(self) -> str:
        return f'{self.__class__.__name__}()'

def cumsum(x: Tensor, dim: int = 0) -> Tensor:
    r"""Returns the cumulative sum of elements of :obj:`x`.
    In contrast to :meth:`torch.cumsum`, prepends the output with zero.

    Args:
        x (torch.Tensor): The input tensor.
        dim (int, optional): The dimension to do the operation over.
            (default: :obj:`0`)

    Example:
        >>> x = torch.tensor([2, 4, 1])
        >>> cumsum(x)
        tensor([0, 2, 6, 7])

    """
    size = x.size()[:dim] + (x.size(dim) + 1, ) + x.size()[dim + 1:]
    out = x.new_empty(size)

    out.narrow(dim, 0, 1).zero_()
    torch.cumsum(x, dim=dim, out=out.narrow(dim, 1, x.size(dim)))

    return out

def maybe_num_nodes(edge_index, num_nodes=None):
    if num_nodes is not None:
        return num_nodes
    elif isinstance(edge_index, Tensor):
        return int(edge_index.max()) + 1 if edge_index.numel() > 0 else 0
    else:
        return max(edge_index.size(0), edge_index.size(1))

def maybe_num_nodes(edge_index, num_nodes=None):
    if num_nodes is not None:
        return num_nodes
    elif isinstance(edge_index, Tensor):
        return int(edge_index.max()) + 1 if edge_index.numel() > 0 else 0
    else:
        return max(edge_index.size(0), edge_index.size(1))

def filter_adj(edge_index, edge_attr, perm, num_nodes=None):
    num_nodes = maybe_num_nodes(edge_index, num_nodes)

    mask = perm.new_full((num_nodes, ), -1)
    i = torch.arange(perm.size(0), dtype=torch.long, device=perm.device)
    mask[perm] = i

    row, col = edge_index
    row, col = mask[row], mask[col]
    mask = (row >= 0) & (col >= 0)
    row, col = row[mask], col[mask]

    if edge_attr is not None:
        edge_attr = edge_attr[mask]

    return torch.stack([row, col], dim=0), edge_attr

def topk(
    x: Tensor,
    ratio: Optional[Union[float, int]],
    batch: Tensor,
    min_score: Optional[float] = None,
    tol: float = 1e-7,
) -> Tensor:
    if min_score is not None:
        # Make sure that we do not drop all nodes in a graph.
        scores_max = scatter(x, batch, reduce='max')[batch] - tol
        scores_min = scores_max.clamp(max=min_score)

        perm = (x > scores_min).nonzero().view(-1)
        return perm

    if ratio is not None:
        num_nodes = scatter(batch.new_ones(x.size(0)), batch, reduce='sum')

        if ratio >= 1:
            k = num_nodes.new_full((num_nodes.size(0), ), int(ratio))
        else:
            k = (float(ratio) * num_nodes.to(x.dtype)).ceil().to(torch.long)

        x, x_perm = torch.sort(x.view(-1), descending=True)
        batch = batch[x_perm]
        batch, batch_perm = torch.sort(batch, descending=False, stable=True)

        arange = torch.arange(x.size(0), dtype=torch.long, device=x.device)
        ptr = cumsum(num_nodes)
        batched_arange = arange - ptr[batch]
        mask = batched_arange < k[batch]

        return x_perm[batch_perm[mask]]

    raise ValueError("At least one of the 'ratio' and 'min_score' parameters "
                     "must be specified")

class Discriminator(torch.nn.Module):
    def __init__(self, in_channels):
        super(Discriminator, self).__init__()
        self.fc1 = nn.Linear(in_channels * 2, in_channels)
        self.fc2 = nn.Linear(in_channels, 1)

    def forward(self, x):
        x = F.leaky_relu(self.fc1(x), 0.2)
        x = F.sigmoid(self.fc2(x))
        return x


class CGIPool(torch.nn.Module):
    def __init__(self, in_channels, ratio=0.5, non_lin=torch.tanh):
        super(CGIPool, self).__init__()
        self.in_channels = in_channels
        self.ratio = ratio
        self.non_lin = non_lin
        self.hidden_dim = in_channels
        self.transform = GraphConv(in_channels, self.hidden_dim)
        self.pp_conv = GraphConv(self.hidden_dim, self.hidden_dim)
        self.np_conv = GraphConv(self.hidden_dim, self.hidden_dim)

        self.positive_pooling = GraphConv(self.hidden_dim, 1)
        self.negative_pooling = GraphConv(self.hidden_dim, 1)

        self.discriminator = Discriminator(self.hidden_dim)
        self.loss_fn = torch.nn.BCELoss()

    def forward(self, x, edge_index, edge_attr=None, batch=None):
        device = x.device  # 获取输入张量的设备信息

        if batch is None:
            batch = edge_index.new_zeros(x.size(0))

        x_transform = F.leaky_relu(self.transform(x, edge_index), 0.2)
        x_tp = F.leaky_relu(self.pp_conv(x, edge_index), 0.2)
        x_tn = F.leaky_relu(self.np_conv(x, edge_index), 0.2)
        s_pp = self.positive_pooling(x_tp, edge_index).squeeze()
        s_np = self.negative_pooling(x_tn, edge_index).squeeze()

        perm_positive = topk(s_pp, 1, batch)
        perm_negative = topk(s_np, 1, batch)
        x_pp = x_transform[perm_positive] * self.non_lin(s_pp[perm_positive]).view(-1, 1)
        x_np = x_transform[perm_negative] * self.non_lin(s_np[perm_negative]).view(-1, 1)

        x_pp_readout = gap(x_pp, batch[perm_positive])
        x_np_readout = gap(x_np, batch[perm_negative])
        x_readout = gap(x_transform, batch)

        positive_pair = torch.cat([x_pp_readout, x_readout], dim=1)
        negative_pair = torch.cat([x_np_readout, x_readout], dim=1)

        real = torch.ones(positive_pair.shape[0], device=device)  # 将张量移动到相应设备
        fake = torch.zeros(negative_pair.shape[0], device=device)  # 将张量移动到相应设备
        #real_loss = self.loss_fn(self.discriminator(positive_pair), real)
        #fake_loss = self.loss_fn(self.discriminator(negative_pair), fake)
        #discrimination_loss = (real_loss + fake_loss) / 2

        score = (s_pp - s_np)

        perm = topk(score, self.ratio, batch)
        x = x_transform[perm] * self.non_lin(score[perm]).view(-1, 1)
        batch = batch[perm]

        filter_edge_index, filter_edge_attr = filter_adj(edge_index, edge_attr, perm, num_nodes=score.size(0))
        return x, filter_edge_index, filter_edge_attr, batch, perm

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, SAGPooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch
from torch_geometric.nn import BatchNorm

class HierarchicalGCN_CGI(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_CGI, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool1 = CGIPool(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.pool2 = CGIPool(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, _, batch, perm = self.pool1(x, edge_index, None, batch)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, _, batch, perm= self.pool1(x, edge_index, None, batch)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)


num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_CGI(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_CGI(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6784, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 002, Loss: 0.6624, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 003, Loss: 0.6526, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 004, Loss: 0.6456, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 005, Loss: 0.6388, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 006, Loss: 0.6507, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 007, Loss: 0.6472, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 008, Loss: 0.6374, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 009, Loss: 0.6302, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 010, Loss: 0.6226, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 011, Loss: 0.6257, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 012, Loss: 0.6236, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 013, Loss: 0.6340, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 014, Loss: 0.6282, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 015, Loss: 0.6420, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 016, Loss: 0.6339, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 017, Loss: 0.6418, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 018, Loss: 0.6453, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 42, Epoch: 019, Loss: 0.6420, Val Acc: 0.7410, Test Acc: 0.6905
# Seed: 42, Epoch: 020, Loss: 0.6565, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 42, Epoch: 021, Loss: 0.6542, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 022, Loss: 0.6522, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 42, Epoch: 023, Loss: 0.6475, Val Acc: 0.7410, Test Acc: 0.6786
# Seed: 42, Epoch: 024, Loss: 0.6380, Val Acc: 0.7229, Test Acc: 0.6548
# Seed: 42, Epoch: 025, Loss: 0.6351, Val Acc: 0.7169, Test Acc: 0.6429
# Seed: 42, Epoch: 026, Loss: 0.6279, Val Acc: 0.7169, Test Acc: 0.6488
# Seed: 42, Epoch: 027, Loss: 0.6252, Val Acc: 0.7349, Test Acc: 0.6786
# Seed: 42, Epoch: 028, Loss: 0.6241, Val Acc: 0.7349, Test Acc: 0.6786
# Seed: 42, Epoch: 029, Loss: 0.6289, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 42, Epoch: 030, Loss: 0.6238, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 031, Loss: 0.6318, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 42, Epoch: 032, Loss: 0.6352, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 033, Loss: 0.6393, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 034, Loss: 0.6342, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 035, Loss: 0.6368, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 036, Loss: 0.6325, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 037, Loss: 0.6262, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 038, Loss: 0.6190, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 039, Loss: 0.6096, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 040, Loss: 0.6154, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 041, Loss: 0.6109, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 042, Loss: 0.6059, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 043, Loss: 0.6110, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 044, Loss: 0.5998, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 42, Epoch: 045, Loss: 0.6096, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 046, Loss: 0.5999, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 047, Loss: 0.5963, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 048, Loss: 0.6051, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 42, Epoch: 049, Loss: 0.6095, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 050, Loss: 0.6049, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 051, Loss: 0.6105, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 052, Loss: 0.6043, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 053, Loss: 0.6049, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 054, Loss: 0.5987, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 055, Loss: 0.6090, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 056, Loss: 0.6114, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 42, Epoch: 057, Loss: 0.6335, Val Acc: 0.6205, Test Acc: 0.7440
# Seed: 42, Epoch: 058, Loss: 0.6447, Val Acc: 0.5964, Test Acc: 0.7262
# Seed: 42, Epoch: 059, Loss: 0.6664, Val Acc: 0.6446, Test Acc: 0.7381
# Seed: 42, Epoch: 060, Loss: 0.6425, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 42, Epoch: 061, Loss: 0.6259, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 062, Loss: 0.6254, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 063, Loss: 0.6196, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 064, Loss: 0.6164, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 065, Loss: 0.6054, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 42, Epoch: 066, Loss: 0.6039, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 42, Epoch: 067, Loss: 0.6010, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 068, Loss: 0.5929, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 42, Epoch: 069, Loss: 0.5949, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 070, Loss: 0.5903, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 42, Epoch: 071, Loss: 0.5875, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 072, Loss: 0.5864, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 073, Loss: 0.5898, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 074, Loss: 0.5909, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 075, Loss: 0.5868, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 076, Loss: 0.5722, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 077, Loss: 0.5842, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 078, Loss: 0.6088, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 42, Epoch: 079, Loss: 0.6294, Val Acc: 0.6627, Test Acc: 0.7440
# Seed: 42, Epoch: 080, Loss: 0.6128, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 081, Loss: 0.5938, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 082, Loss: 0.6051, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 42, Epoch: 083, Loss: 0.6166, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 084, Loss: 0.6160, Val Acc: 0.6747, Test Acc: 0.7976
# Seed: 42, Epoch: 085, Loss: 0.5994, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 42, Epoch: 086, Loss: 0.6052, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 087, Loss: 0.5988, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 42, Epoch: 088, Loss: 0.5871, Val Acc: 0.7229, Test Acc: 0.6786
# Seed: 42, Epoch: 089, Loss: 0.5834, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 42, Epoch: 090, Loss: 0.5809, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 091, Loss: 0.5820, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 092, Loss: 0.5787, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 093, Loss: 0.5932, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 094, Loss: 0.5832, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 095, Loss: 0.5774, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 42, Epoch: 096, Loss: 0.5762, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 42, Epoch: 097, Loss: 0.5923, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 098, Loss: 0.6046, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 42, Epoch: 099, Loss: 0.5939, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 100, Loss: 0.5966, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 101, Loss: 0.5846, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 102, Loss: 0.5766, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 103, Loss: 0.5778, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 104, Loss: 0.5736, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 105, Loss: 0.5649, Val Acc: 0.7470, Test Acc: 0.7262
# Seed: 42, Epoch: 106, Loss: 0.5658, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 42, Epoch: 107, Loss: 0.5770, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 42, Epoch: 108, Loss: 0.5628, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 42, Epoch: 109, Loss: 0.5709, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 42, Epoch: 110, Loss: 0.5822, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 111, Loss: 0.6112, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 42, Epoch: 112, Loss: 0.6070, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 42, Epoch: 113, Loss: 0.5971, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 114, Loss: 0.5914, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 115, Loss: 0.5730, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 42, Epoch: 116, Loss: 0.5735, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 42, Epoch: 117, Loss: 0.5777, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 118, Loss: 0.5698, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 119, Loss: 0.5724, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 120, Loss: 0.5663, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 121, Loss: 0.5676, Val Acc: 0.7349, Test Acc: 0.7143
# Seed: 42, Epoch: 122, Loss: 0.5658, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 123, Loss: 0.5670, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 124, Loss: 0.5806, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 125, Loss: 0.5920, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 42, Epoch: 126, Loss: 0.5754, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 127, Loss: 0.5603, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 128, Loss: 0.5587, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 42, Epoch: 129, Loss: 0.5555, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 130, Loss: 0.5572, Val Acc: 0.7349, Test Acc: 0.7143
# Seed: 42, Epoch: 131, Loss: 0.5545, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 132, Loss: 0.5602, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 133, Loss: 0.5620, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 134, Loss: 0.5468, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 135, Loss: 0.5590, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 136, Loss: 0.5539, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 42, Epoch: 137, Loss: 0.5684, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 138, Loss: 0.5638, Val Acc: 0.7530, Test Acc: 0.7440
# Seed: 42, Epoch: 139, Loss: 0.5751, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 42, Epoch: 140, Loss: 0.5689, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 42, Epoch: 141, Loss: 0.5691, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 42, Epoch: 142, Loss: 0.5741, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 42, Epoch: 143, Loss: 0.5703, Val Acc: 0.7410, Test Acc: 0.7560
# Seed: 42, Epoch: 144, Loss: 0.5818, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 145, Loss: 0.5965, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 146, Loss: 0.5958, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 147, Loss: 0.5834, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 148, Loss: 0.5823, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 149, Loss: 0.5676, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 150, Loss: 0.5651, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 151, Loss: 0.5618, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 42, Epoch: 152, Loss: 0.5601, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 153, Loss: 0.5640, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 154, Loss: 0.5718, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 42, Epoch: 155, Loss: 0.5740, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 42, Epoch: 156, Loss: 0.5728, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 157, Loss: 0.5609, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 158, Loss: 0.5544, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 159, Loss: 0.5558, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 160, Loss: 0.5658, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 161, Loss: 0.5603, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 162, Loss: 0.5718, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 163, Loss: 0.5592, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 164, Loss: 0.5753, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 165, Loss: 0.5619, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 42, Epoch: 166, Loss: 0.5826, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 167, Loss: 0.6067, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 42, Epoch: 168, Loss: 0.6557, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 169, Loss: 0.6088, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 170, Loss: 0.5745, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 42, Epoch: 171, Loss: 0.5720, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 172, Loss: 0.5694, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 42, Epoch: 173, Loss: 0.5707, Val Acc: 0.7410, Test Acc: 0.6964
# Seed: 42, Epoch: 174, Loss: 0.5752, Val Acc: 0.7470, Test Acc: 0.7024
# Seed: 42, Epoch: 175, Loss: 0.5626, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 42, Epoch: 176, Loss: 0.5742, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 42, Epoch: 177, Loss: 0.5746, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 178, Loss: 0.6127, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 179, Loss: 0.6099, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 180, Loss: 0.5918, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 42, Epoch: 181, Loss: 0.5820, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 42, Epoch: 182, Loss: 0.5777, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 42, Epoch: 183, Loss: 0.5710, Val Acc: 0.6687, Test Acc: 0.6964
# Seed: 42, Epoch: 184, Loss: 0.5759, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 42, Epoch: 185, Loss: 0.5770, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 42, Epoch: 186, Loss: 0.5679, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 42, Epoch: 187, Loss: 0.5616, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 188, Loss: 0.5737, Val Acc: 0.7289, Test Acc: 0.6905
# Seed: 42, Epoch: 189, Loss: 0.5556, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 42, Epoch: 190, Loss: 0.5949, Val Acc: 0.7229, Test Acc: 0.6845
# Seed: 42, Epoch: 191, Loss: 0.5914, Val Acc: 0.7470, Test Acc: 0.6905
# Seed: 42, Epoch: 192, Loss: 0.5730, Val Acc: 0.7530, Test Acc: 0.7143
# Seed: 42, Epoch: 193, Loss: 0.5548, Val Acc: 0.7771, Test Acc: 0.7202
# Seed: 42, Epoch: 194, Loss: 0.5490, Val Acc: 0.7651, Test Acc: 0.7262
# Seed: 42, Epoch: 195, Loss: 0.5566, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 42, Epoch: 196, Loss: 0.5556, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 42, Epoch: 197, Loss: 0.5513, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 198, Loss: 0.5531, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 199, Loss: 0.5401, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 200, Loss: 0.5464, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 001, Loss: 0.6779, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 002, Loss: 0.6621, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 003, Loss: 0.6562, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 004, Loss: 0.6287, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 005, Loss: 0.6150, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 006, Loss: 0.6161, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 007, Loss: 0.6267, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 008, Loss: 0.6355, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 009, Loss: 0.6438, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 010, Loss: 0.6353, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 011, Loss: 0.6306, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 012, Loss: 0.6270, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 013, Loss: 0.6218, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 43, Epoch: 014, Loss: 0.6125, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 43, Epoch: 015, Loss: 0.6165, Val Acc: 0.6627, Test Acc: 0.6190
# Seed: 43, Epoch: 016, Loss: 0.6270, Val Acc: 0.6807, Test Acc: 0.6548
# Seed: 43, Epoch: 017, Loss: 0.6258, Val Acc: 0.6988, Test Acc: 0.6786
# Seed: 43, Epoch: 018, Loss: 0.6456, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 43, Epoch: 019, Loss: 0.6393, Val Acc: 0.7048, Test Acc: 0.6786
# Seed: 43, Epoch: 020, Loss: 0.6405, Val Acc: 0.7048, Test Acc: 0.6726
# Seed: 43, Epoch: 021, Loss: 0.6303, Val Acc: 0.7048, Test Acc: 0.6786
# Seed: 43, Epoch: 022, Loss: 0.6202, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 43, Epoch: 023, Loss: 0.6372, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 43, Epoch: 024, Loss: 0.6381, Val Acc: 0.7410, Test Acc: 0.7560
# Seed: 43, Epoch: 025, Loss: 0.6560, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 43, Epoch: 026, Loss: 0.6472, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 43, Epoch: 027, Loss: 0.6517, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 028, Loss: 0.6231, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 43, Epoch: 029, Loss: 0.6418, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 43, Epoch: 030, Loss: 0.6237, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 43, Epoch: 031, Loss: 0.6409, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 43, Epoch: 032, Loss: 0.6416, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 43, Epoch: 033, Loss: 0.6451, Val Acc: 0.7590, Test Acc: 0.7381
# Seed: 43, Epoch: 034, Loss: 0.6402, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 035, Loss: 0.6433, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 43, Epoch: 036, Loss: 0.6342, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 43, Epoch: 037, Loss: 0.6328, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 43, Epoch: 038, Loss: 0.6204, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 43, Epoch: 039, Loss: 0.6183, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 43, Epoch: 040, Loss: 0.6058, Val Acc: 0.6867, Test Acc: 0.6667
# Seed: 43, Epoch: 041, Loss: 0.5964, Val Acc: 0.6687, Test Acc: 0.6786
# Seed: 43, Epoch: 042, Loss: 0.6096, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 43, Epoch: 043, Loss: 0.5978, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 044, Loss: 0.6253, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 43, Epoch: 045, Loss: 0.6299, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 046, Loss: 0.6312, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 43, Epoch: 047, Loss: 0.6288, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 43, Epoch: 048, Loss: 0.6348, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 43, Epoch: 049, Loss: 0.6234, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 43, Epoch: 050, Loss: 0.6199, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 43, Epoch: 051, Loss: 0.6224, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 43, Epoch: 052, Loss: 0.6286, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 43, Epoch: 053, Loss: 0.6290, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 43, Epoch: 054, Loss: 0.6405, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 43, Epoch: 055, Loss: 0.6384, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 43, Epoch: 056, Loss: 0.6256, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 43, Epoch: 057, Loss: 0.6368, Val Acc: 0.7590, Test Acc: 0.7321
# Seed: 43, Epoch: 058, Loss: 0.6281, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 059, Loss: 0.6236, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 060, Loss: 0.6288, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 061, Loss: 0.6247, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 43, Epoch: 062, Loss: 0.6244, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 43, Epoch: 063, Loss: 0.6254, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 43, Epoch: 064, Loss: 0.6207, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 065, Loss: 0.6141, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 43, Epoch: 066, Loss: 0.6181, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 43, Epoch: 067, Loss: 0.6067, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 068, Loss: 0.6137, Val Acc: 0.7410, Test Acc: 0.7202
# Seed: 43, Epoch: 069, Loss: 0.6067, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 43, Epoch: 070, Loss: 0.6230, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 43, Epoch: 071, Loss: 0.6310, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 072, Loss: 0.6206, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 43, Epoch: 073, Loss: 0.6232, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 074, Loss: 0.6151, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 075, Loss: 0.6113, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 43, Epoch: 076, Loss: 0.6151, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 077, Loss: 0.6238, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 078, Loss: 0.6299, Val Acc: 0.7590, Test Acc: 0.7440
# Seed: 43, Epoch: 079, Loss: 0.6168, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 43, Epoch: 080, Loss: 0.6220, Val Acc: 0.7711, Test Acc: 0.7202
# Seed: 43, Epoch: 081, Loss: 0.6041, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 43, Epoch: 082, Loss: 0.6067, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 083, Loss: 0.5931, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 43, Epoch: 084, Loss: 0.5900, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 085, Loss: 0.5974, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 43, Epoch: 086, Loss: 0.5787, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 43, Epoch: 087, Loss: 0.5859, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 088, Loss: 0.5807, Val Acc: 0.7530, Test Acc: 0.7440
# Seed: 43, Epoch: 089, Loss: 0.6159, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 43, Epoch: 090, Loss: 0.6416, Val Acc: 0.6566, Test Acc: 0.6250
# Seed: 43, Epoch: 091, Loss: 0.6544, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 092, Loss: 0.6235, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 093, Loss: 0.6118, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 094, Loss: 0.6086, Val Acc: 0.7470, Test Acc: 0.7560
# Seed: 43, Epoch: 095, Loss: 0.6076, Val Acc: 0.7590, Test Acc: 0.7440
# Seed: 43, Epoch: 096, Loss: 0.6017, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 097, Loss: 0.5900, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 43, Epoch: 098, Loss: 0.6020, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 43, Epoch: 099, Loss: 0.6014, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 100, Loss: 0.5979, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 43, Epoch: 101, Loss: 0.6019, Val Acc: 0.7651, Test Acc: 0.7381
# Seed: 43, Epoch: 102, Loss: 0.6042, Val Acc: 0.7651, Test Acc: 0.7500
# Seed: 43, Epoch: 103, Loss: 0.6228, Val Acc: 0.7651, Test Acc: 0.7440
# Seed: 43, Epoch: 104, Loss: 0.6175, Val Acc: 0.7590, Test Acc: 0.7381
# Seed: 43, Epoch: 105, Loss: 0.6007, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 106, Loss: 0.5890, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 107, Loss: 0.5858, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 43, Epoch: 108, Loss: 0.5826, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 43, Epoch: 109, Loss: 0.5804, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 110, Loss: 0.5901, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 111, Loss: 0.5948, Val Acc: 0.7530, Test Acc: 0.7440
# Seed: 43, Epoch: 112, Loss: 0.5979, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 43, Epoch: 113, Loss: 0.5888, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 114, Loss: 0.5909, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 115, Loss: 0.5775, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 43, Epoch: 116, Loss: 0.5762, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 117, Loss: 0.5776, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 43, Epoch: 118, Loss: 0.5680, Val Acc: 0.7530, Test Acc: 0.7262
# Seed: 43, Epoch: 119, Loss: 0.5614, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 43, Epoch: 120, Loss: 0.5723, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 43, Epoch: 121, Loss: 0.5582, Val Acc: 0.7651, Test Acc: 0.7381
# Seed: 43, Epoch: 122, Loss: 0.5681, Val Acc: 0.7590, Test Acc: 0.7560
# Seed: 43, Epoch: 123, Loss: 0.5687, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 43, Epoch: 124, Loss: 0.5817, Val Acc: 0.7169, Test Acc: 0.6905
# Seed: 43, Epoch: 125, Loss: 0.6270, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 43, Epoch: 126, Loss: 0.6172, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 43, Epoch: 127, Loss: 0.6088, Val Acc: 0.7530, Test Acc: 0.7500
# Seed: 43, Epoch: 128, Loss: 0.6197, Val Acc: 0.7651, Test Acc: 0.7440
# Seed: 43, Epoch: 129, Loss: 0.6339, Val Acc: 0.7530, Test Acc: 0.7500
# Seed: 43, Epoch: 130, Loss: 0.6170, Val Acc: 0.7470, Test Acc: 0.7560
# Seed: 43, Epoch: 131, Loss: 0.6100, Val Acc: 0.7651, Test Acc: 0.7381
# Seed: 43, Epoch: 132, Loss: 0.5921, Val Acc: 0.7590, Test Acc: 0.7321
# Seed: 43, Epoch: 133, Loss: 0.5772, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 43, Epoch: 134, Loss: 0.5823, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 43, Epoch: 135, Loss: 0.5864, Val Acc: 0.7470, Test Acc: 0.7083
# Seed: 43, Epoch: 136, Loss: 0.5848, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 43, Epoch: 137, Loss: 0.5886, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 43, Epoch: 138, Loss: 0.5873, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 43, Epoch: 139, Loss: 0.5914, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 140, Loss: 0.6071, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 43, Epoch: 141, Loss: 0.6034, Val Acc: 0.7530, Test Acc: 0.7262
# Seed: 43, Epoch: 142, Loss: 0.5975, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 43, Epoch: 143, Loss: 0.5809, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 43, Epoch: 144, Loss: 0.5849, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 145, Loss: 0.5910, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 43, Epoch: 146, Loss: 0.5892, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 147, Loss: 0.6011, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 43, Epoch: 148, Loss: 0.6122, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 149, Loss: 0.5987, Val Acc: 0.7590, Test Acc: 0.7560
# Seed: 43, Epoch: 150, Loss: 0.6096, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 43, Epoch: 151, Loss: 0.6035, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 43, Epoch: 152, Loss: 0.5994, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 43, Epoch: 153, Loss: 0.5922, Val Acc: 0.7410, Test Acc: 0.7679
# Seed: 43, Epoch: 154, Loss: 0.5851, Val Acc: 0.7410, Test Acc: 0.7798
# Seed: 43, Epoch: 155, Loss: 0.5836, Val Acc: 0.7410, Test Acc: 0.7619
# Seed: 43, Epoch: 156, Loss: 0.5790, Val Acc: 0.7410, Test Acc: 0.7798
# Seed: 43, Epoch: 157, Loss: 0.5846, Val Acc: 0.7530, Test Acc: 0.7679
# Seed: 43, Epoch: 158, Loss: 0.5865, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 43, Epoch: 159, Loss: 0.5848, Val Acc: 0.7530, Test Acc: 0.7560
# Seed: 43, Epoch: 160, Loss: 0.5757, Val Acc: 0.7470, Test Acc: 0.7738
# Seed: 43, Epoch: 161, Loss: 0.5756, Val Acc: 0.7470, Test Acc: 0.7619
# Seed: 43, Epoch: 162, Loss: 0.5738, Val Acc: 0.7590, Test Acc: 0.7738
# Seed: 43, Epoch: 163, Loss: 0.5705, Val Acc: 0.7470, Test Acc: 0.7738
# Seed: 43, Epoch: 164, Loss: 0.5623, Val Acc: 0.7530, Test Acc: 0.7738
# Seed: 43, Epoch: 165, Loss: 0.5712, Val Acc: 0.7470, Test Acc: 0.7619
# Seed: 43, Epoch: 166, Loss: 0.5717, Val Acc: 0.7590, Test Acc: 0.7738
# Seed: 43, Epoch: 167, Loss: 0.5661, Val Acc: 0.7470, Test Acc: 0.7738
# Seed: 43, Epoch: 168, Loss: 0.5677, Val Acc: 0.7470, Test Acc: 0.7619
# Seed: 43, Epoch: 169, Loss: 0.5672, Val Acc: 0.7470, Test Acc: 0.7738
# Seed: 43, Epoch: 170, Loss: 0.5781, Val Acc: 0.7410, Test Acc: 0.7679
# Seed: 43, Epoch: 171, Loss: 0.5770, Val Acc: 0.7410, Test Acc: 0.7560
# Seed: 43, Epoch: 172, Loss: 0.5762, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 173, Loss: 0.5896, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 43, Epoch: 174, Loss: 0.5981, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 43, Epoch: 175, Loss: 0.5954, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 43, Epoch: 176, Loss: 0.6040, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 43, Epoch: 177, Loss: 0.6072, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 43, Epoch: 178, Loss: 0.6082, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 43, Epoch: 179, Loss: 0.5995, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 43, Epoch: 180, Loss: 0.5908, Val Acc: 0.7530, Test Acc: 0.7560
# Seed: 43, Epoch: 181, Loss: 0.5998, Val Acc: 0.7470, Test Acc: 0.7679
# Seed: 43, Epoch: 182, Loss: 0.6009, Val Acc: 0.7470, Test Acc: 0.7679
# Seed: 43, Epoch: 183, Loss: 0.6027, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 184, Loss: 0.5952, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 185, Loss: 0.5942, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 186, Loss: 0.5858, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 187, Loss: 0.5866, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 43, Epoch: 188, Loss: 0.6163, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 43, Epoch: 189, Loss: 0.6188, Val Acc: 0.7470, Test Acc: 0.7619
# Seed: 43, Epoch: 190, Loss: 0.6064, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 191, Loss: 0.5931, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 192, Loss: 0.5874, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 193, Loss: 0.5823, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 43, Epoch: 194, Loss: 0.5827, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 43, Epoch: 195, Loss: 0.5842, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 196, Loss: 0.5785, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 43, Epoch: 197, Loss: 0.5723, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 43, Epoch: 198, Loss: 0.5681, Val Acc: 0.7410, Test Acc: 0.7798
# Seed: 43, Epoch: 199, Loss: 0.5868, Val Acc: 0.7410, Test Acc: 0.7798
# Seed: 43, Epoch: 200, Loss: 0.5774, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 001, Loss: 0.6849, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 002, Loss: 0.6634, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 003, Loss: 0.6264, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 004, Loss: 0.6931, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 005, Loss: 0.6179, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 006, Loss: 0.6126, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 007, Loss: 0.6191, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 44, Epoch: 008, Loss: 0.6294, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 44, Epoch: 009, Loss: 0.6509, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 44, Epoch: 010, Loss: 0.6454, Val Acc: 0.7590, Test Acc: 0.7024
# Seed: 44, Epoch: 011, Loss: 0.6545, Val Acc: 0.7470, Test Acc: 0.7083
# Seed: 44, Epoch: 012, Loss: 0.6522, Val Acc: 0.7410, Test Acc: 0.6964
# Seed: 44, Epoch: 013, Loss: 0.6383, Val Acc: 0.7169, Test Acc: 0.6667
# Seed: 44, Epoch: 014, Loss: 0.6246, Val Acc: 0.7169, Test Acc: 0.6667
# Seed: 44, Epoch: 015, Loss: 0.6348, Val Acc: 0.7410, Test Acc: 0.6905
# Seed: 44, Epoch: 016, Loss: 0.6397, Val Acc: 0.7590, Test Acc: 0.7143
# Seed: 44, Epoch: 017, Loss: 0.6476, Val Acc: 0.7470, Test Acc: 0.7143
# Seed: 44, Epoch: 018, Loss: 0.6426, Val Acc: 0.7470, Test Acc: 0.7143
# Seed: 44, Epoch: 019, Loss: 0.6360, Val Acc: 0.7410, Test Acc: 0.6905
# Seed: 44, Epoch: 020, Loss: 0.6276, Val Acc: 0.7410, Test Acc: 0.6905
# Seed: 44, Epoch: 021, Loss: 0.6159, Val Acc: 0.7169, Test Acc: 0.6786
# Seed: 44, Epoch: 022, Loss: 0.6183, Val Acc: 0.6928, Test Acc: 0.6488
# Seed: 44, Epoch: 023, Loss: 0.6338, Val Acc: 0.7349, Test Acc: 0.6905
# Seed: 44, Epoch: 024, Loss: 0.6048, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 025, Loss: 0.6262, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 026, Loss: 0.6410, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 44, Epoch: 027, Loss: 0.6558, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 028, Loss: 0.6519, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 44, Epoch: 029, Loss: 0.6445, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 030, Loss: 0.6512, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 031, Loss: 0.6378, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 032, Loss: 0.6288, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 44, Epoch: 033, Loss: 0.6310, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 44, Epoch: 034, Loss: 0.6147, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 035, Loss: 0.6170, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 036, Loss: 0.6279, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 037, Loss: 0.6499, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 44, Epoch: 038, Loss: 0.6430, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 44, Epoch: 039, Loss: 0.6427, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 040, Loss: 0.6513, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 44, Epoch: 041, Loss: 0.6444, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 042, Loss: 0.6356, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 043, Loss: 0.6324, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 044, Loss: 0.6222, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 045, Loss: 0.6315, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 046, Loss: 0.6280, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 047, Loss: 0.6321, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 048, Loss: 0.6358, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 44, Epoch: 049, Loss: 0.6339, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 44, Epoch: 050, Loss: 0.6414, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 44, Epoch: 051, Loss: 0.6392, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 052, Loss: 0.6336, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 053, Loss: 0.6296, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 054, Loss: 0.6310, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 055, Loss: 0.6303, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 44, Epoch: 056, Loss: 0.6341, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 44, Epoch: 057, Loss: 0.6375, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 44, Epoch: 058, Loss: 0.6317, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 059, Loss: 0.6192, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 060, Loss: 0.6211, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 061, Loss: 0.6170, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 44, Epoch: 062, Loss: 0.6139, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 44, Epoch: 063, Loss: 0.6045, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 064, Loss: 0.5983, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 065, Loss: 0.5965, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 066, Loss: 0.5958, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 44, Epoch: 067, Loss: 0.5916, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 068, Loss: 0.5823, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 069, Loss: 0.5975, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 070, Loss: 0.5951, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 071, Loss: 0.6243, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 072, Loss: 0.6265, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 44, Epoch: 073, Loss: 0.6061, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 074, Loss: 0.6080, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 075, Loss: 0.6096, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 076, Loss: 0.6054, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 077, Loss: 0.6142, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 078, Loss: 0.6183, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 44, Epoch: 079, Loss: 0.6072, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 44, Epoch: 080, Loss: 0.6211, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 081, Loss: 0.6202, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 082, Loss: 0.6328, Val Acc: 0.6446, Test Acc: 0.7500
# Seed: 44, Epoch: 083, Loss: 0.6472, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 084, Loss: 0.6282, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 085, Loss: 0.6181, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 086, Loss: 0.6141, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 087, Loss: 0.6061, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 088, Loss: 0.6028, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 089, Loss: 0.5961, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 090, Loss: 0.5947, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 091, Loss: 0.5965, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 092, Loss: 0.6019, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 44, Epoch: 093, Loss: 0.6071, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 094, Loss: 0.5832, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 095, Loss: 0.5972, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 44, Epoch: 096, Loss: 0.5917, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 097, Loss: 0.5828, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 098, Loss: 0.5768, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 099, Loss: 0.5842, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 44, Epoch: 100, Loss: 0.6089, Val Acc: 0.6446, Test Acc: 0.7321
# Seed: 44, Epoch: 101, Loss: 0.6326, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 44, Epoch: 102, Loss: 0.6274, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 103, Loss: 0.6064, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 104, Loss: 0.5937, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 105, Loss: 0.5848, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 106, Loss: 0.5870, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 107, Loss: 0.5841, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 44, Epoch: 108, Loss: 0.5753, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 44, Epoch: 109, Loss: 0.5729, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 110, Loss: 0.5723, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 111, Loss: 0.5813, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 112, Loss: 0.5701, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 113, Loss: 0.5749, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 114, Loss: 0.5684, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 44, Epoch: 115, Loss: 0.5676, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 44, Epoch: 116, Loss: 0.5701, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 117, Loss: 0.5846, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 118, Loss: 0.5947, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 119, Loss: 0.5885, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 120, Loss: 0.5950, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 44, Epoch: 121, Loss: 0.5802, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 122, Loss: 0.5715, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 123, Loss: 0.5790, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 124, Loss: 0.5844, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 125, Loss: 0.5804, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 126, Loss: 0.6377, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 44, Epoch: 127, Loss: 0.5785, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 128, Loss: 0.5824, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 129, Loss: 0.5787, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 130, Loss: 0.5898, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 131, Loss: 0.5754, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 44, Epoch: 132, Loss: 0.5786, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 133, Loss: 0.5839, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 44, Epoch: 134, Loss: 0.5853, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 135, Loss: 0.6006, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 44, Epoch: 136, Loss: 0.5934, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 137, Loss: 0.5857, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 44, Epoch: 138, Loss: 0.5899, Val Acc: 0.6566, Test Acc: 0.7560
# Seed: 44, Epoch: 139, Loss: 0.5698, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 44, Epoch: 140, Loss: 0.5603, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 141, Loss: 0.5720, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 142, Loss: 0.5772, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 44, Epoch: 143, Loss: 0.5965, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 44, Epoch: 144, Loss: 0.6120, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 145, Loss: 0.6005, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 146, Loss: 0.5916, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 44, Epoch: 147, Loss: 0.5849, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 44, Epoch: 148, Loss: 0.5874, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 149, Loss: 0.5841, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 150, Loss: 0.5862, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 151, Loss: 0.5763, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 152, Loss: 0.5859, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 44, Epoch: 153, Loss: 0.5921, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 154, Loss: 0.5885, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 44, Epoch: 155, Loss: 0.5812, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 156, Loss: 0.5757, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 157, Loss: 0.5641, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 158, Loss: 0.5636, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 159, Loss: 0.5721, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 160, Loss: 0.5665, Val Acc: 0.7108, Test Acc: 0.7202
# Early stopping at epoch 160 for seed 44
# Seed: 45, Epoch: 001, Loss: 0.7160, Val Acc: 0.3554, Test Acc: 0.3810
# Seed: 45, Epoch: 002, Loss: 0.7012, Val Acc: 0.3735, Test Acc: 0.4524
# Seed: 45, Epoch: 003, Loss: 0.6891, Val Acc: 0.5904, Test Acc: 0.7262
# Seed: 45, Epoch: 004, Loss: 0.6747, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 45, Epoch: 005, Loss: 0.6518, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 45, Epoch: 006, Loss: 0.6369, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 45, Epoch: 007, Loss: 0.6152, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 45, Epoch: 008, Loss: 0.6330, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 45, Epoch: 009, Loss: 0.6443, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 45, Epoch: 010, Loss: 0.6553, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 45, Epoch: 011, Loss: 0.6602, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 45, Epoch: 012, Loss: 0.6661, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 45, Epoch: 013, Loss: 0.6698, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 014, Loss: 0.6626, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 45, Epoch: 015, Loss: 0.6579, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 016, Loss: 0.6480, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 45, Epoch: 017, Loss: 0.6445, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 45, Epoch: 018, Loss: 0.6468, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 45, Epoch: 019, Loss: 0.6454, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 020, Loss: 0.6398, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 021, Loss: 0.6398, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 45, Epoch: 022, Loss: 0.6216, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 45, Epoch: 023, Loss: 0.6262, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 45, Epoch: 024, Loss: 0.6280, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 45, Epoch: 025, Loss: 0.6312, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 026, Loss: 0.6357, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 027, Loss: 0.6462, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 028, Loss: 0.6448, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 029, Loss: 0.6469, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 45, Epoch: 030, Loss: 0.6481, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 45, Epoch: 031, Loss: 0.6475, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 45, Epoch: 032, Loss: 0.6541, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 033, Loss: 0.6473, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 45, Epoch: 034, Loss: 0.6430, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 035, Loss: 0.6407, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 45, Epoch: 036, Loss: 0.6268, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 45, Epoch: 037, Loss: 0.6396, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 038, Loss: 0.6268, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 039, Loss: 0.6310, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 040, Loss: 0.6356, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 041, Loss: 0.6331, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 45, Epoch: 042, Loss: 0.6305, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 45, Epoch: 043, Loss: 0.6257, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 45, Epoch: 044, Loss: 0.6340, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 45, Epoch: 045, Loss: 0.6248, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 45, Epoch: 046, Loss: 0.6263, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 45, Epoch: 047, Loss: 0.6081, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 45, Epoch: 048, Loss: 0.5953, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 45, Epoch: 049, Loss: 0.5957, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 050, Loss: 0.6173, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 051, Loss: 0.6320, Val Acc: 0.6446, Test Acc: 0.7440
# Seed: 45, Epoch: 052, Loss: 0.6632, Val Acc: 0.5843, Test Acc: 0.6964
# Seed: 45, Epoch: 053, Loss: 0.6660, Val Acc: 0.5723, Test Acc: 0.7321
# Seed: 45, Epoch: 054, Loss: 0.6651, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 055, Loss: 0.6529, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 45, Epoch: 056, Loss: 0.6470, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 45, Epoch: 057, Loss: 0.6367, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 45, Epoch: 058, Loss: 0.6263, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 45, Epoch: 059, Loss: 0.6222, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 45, Epoch: 060, Loss: 0.6277, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 45, Epoch: 061, Loss: 0.6204, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 45, Epoch: 062, Loss: 0.6361, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 45, Epoch: 063, Loss: 0.6473, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 45, Epoch: 064, Loss: 0.6376, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 45, Epoch: 065, Loss: 0.6422, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 45, Epoch: 066, Loss: 0.6392, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 45, Epoch: 067, Loss: 0.6350, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 068, Loss: 0.6318, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 45, Epoch: 069, Loss: 0.6245, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 070, Loss: 0.6287, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 071, Loss: 0.6234, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 072, Loss: 0.6170, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 073, Loss: 0.6202, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 074, Loss: 0.6185, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 075, Loss: 0.6157, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 45, Epoch: 076, Loss: 0.6137, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 077, Loss: 0.5982, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 45, Epoch: 078, Loss: 0.6081, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 079, Loss: 0.6081, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 080, Loss: 0.6069, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 081, Loss: 0.5955, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 45, Epoch: 082, Loss: 0.5933, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 45, Epoch: 083, Loss: 0.5976, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 45, Epoch: 084, Loss: 0.5912, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 085, Loss: 0.6008, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 086, Loss: 0.5910, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 45, Epoch: 087, Loss: 0.5987, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 45, Epoch: 088, Loss: 0.5860, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 089, Loss: 0.5899, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 090, Loss: 0.5993, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 45, Epoch: 091, Loss: 0.5951, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 092, Loss: 0.5985, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 093, Loss: 0.5954, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 094, Loss: 0.5824, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 45, Epoch: 095, Loss: 0.5784, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 45, Epoch: 096, Loss: 0.5828, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 45, Epoch: 097, Loss: 0.5915, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 45, Epoch: 098, Loss: 0.5810, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 099, Loss: 0.5957, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 45, Epoch: 100, Loss: 0.6201, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 45, Epoch: 101, Loss: 0.6161, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 102, Loss: 0.5979, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 45, Epoch: 103, Loss: 0.5871, Val Acc: 0.7470, Test Acc: 0.7143
# Seed: 45, Epoch: 104, Loss: 0.5806, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 45, Epoch: 105, Loss: 0.5844, Val Acc: 0.7470, Test Acc: 0.7143
# Seed: 45, Epoch: 106, Loss: 0.5796, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 107, Loss: 0.5881, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 108, Loss: 0.5849, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 45, Epoch: 109, Loss: 0.5978, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 45, Epoch: 110, Loss: 0.5923, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 45, Epoch: 111, Loss: 0.5846, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 112, Loss: 0.5910, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 113, Loss: 0.5935, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 114, Loss: 0.5899, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 115, Loss: 0.5921, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 116, Loss: 0.5896, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 117, Loss: 0.5850, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 45, Epoch: 118, Loss: 0.5774, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 119, Loss: 0.5815, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 45, Epoch: 120, Loss: 0.5803, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 45, Epoch: 121, Loss: 0.5847, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 45, Epoch: 122, Loss: 0.5825, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 45, Epoch: 123, Loss: 0.5885, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 124, Loss: 0.5942, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 45, Epoch: 125, Loss: 0.5823, Val Acc: 0.7169, Test Acc: 0.7440
# ...
# Seed: 45, Epoch: 175, Loss: 0.5907, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 45, Epoch: 176, Loss: 0.5869, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 45, Epoch: 177, Loss: 0.5810, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 178, Loss: 0.5846, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 179, Loss: 0.5879, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 45, Epoch: 180, Loss: 0.5986, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 45, Epoch: 181, Loss: 0.6122, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 45, Epoch: 182, Loss: 0.5813, Val Acc: 0.6506, Test Acc: 0.7321
# Seed: 45, Epoch: 183, Loss: 0.5744, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 184, Loss: 0.5613, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 185, Loss: 0.5548, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 45, Epoch: 186, Loss: 0.5604, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 45, Epoch: 187, Loss: 0.5617, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 188, Loss: 0.5698, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 189, Loss: 0.5651, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 190, Loss: 0.5639, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 45, Epoch: 191, Loss: 0.5737, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 45, Epoch: 192, Loss: 0.6276, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 45, Epoch: 193, Loss: 0.5642, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 194, Loss: 0.5661, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 45, Epoch: 195, Loss: 0.5645, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 45, Epoch: 196, Loss: 0.5709, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 45, Epoch: 197, Loss: 0.5851, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 45, Epoch: 198, Loss: 0.5914, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 45, Epoch: 199, Loss: 0.5799, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 45, Epoch: 200, Loss: 0.5794, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 001, Loss: 0.6790, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 002, Loss: 0.6685, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 003, Loss: 0.6591, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 004, Loss: 0.6547, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 005, Loss: 0.6533, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 006, Loss: 0.6420, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 007, Loss: 0.6353, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 008, Loss: 0.6512, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 009, Loss: 0.6298, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 010, Loss: 0.6316, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 011, Loss: 0.6482, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 012, Loss: 0.6565, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 013, Loss: 0.6585, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 014, Loss: 0.6580, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 015, Loss: 0.6563, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 016, Loss: 0.6552, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 017, Loss: 0.6448, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 018, Loss: 0.6450, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 019, Loss: 0.6275, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 020, Loss: 0.6326, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 021, Loss: 0.6271, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 022, Loss: 0.6251, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 023, Loss: 0.6303, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 024, Loss: 0.6270, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 025, Loss: 0.6350, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 026, Loss: 0.6380, Val Acc: 0.6627, Test Acc: 0.6310
# Seed: 46, Epoch: 027, Loss: 0.6347, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 46, Epoch: 028, Loss: 0.6461, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 46, Epoch: 029, Loss: 0.6552, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 030, Loss: 0.6519, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 46, Epoch: 031, Loss: 0.6514, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 46, Epoch: 032, Loss: 0.6438, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 46, Epoch: 033, Loss: 0.6467, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 46, Epoch: 034, Loss: 0.6431, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 035, Loss: 0.6400, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 036, Loss: 0.6268, Val Acc: 0.7470, Test Acc: 0.6964
# Seed: 46, Epoch: 037, Loss: 0.6207, Val Acc: 0.7410, Test Acc: 0.6964
# Seed: 46, Epoch: 038, Loss: 0.6104, Val Acc: 0.7410, Test Acc: 0.6905
# Seed: 46, Epoch: 039, Loss: 0.6065, Val Acc: 0.7470, Test Acc: 0.6964
# Seed: 46, Epoch: 040, Loss: 0.6103, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 46, Epoch: 041, Loss: 0.6034, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 042, Loss: 0.6132, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 46, Epoch: 043, Loss: 0.6244, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 46, Epoch: 044, Loss: 0.6202, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 045, Loss: 0.6041, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 046, Loss: 0.6068, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 46, Epoch: 047, Loss: 0.5971, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 46, Epoch: 048, Loss: 0.6101, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 46, Epoch: 049, Loss: 0.5977, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 050, Loss: 0.6127, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 051, Loss: 0.6132, Val Acc: 0.7108, Test Acc: 0.7857
# Seed: 46, Epoch: 052, Loss: 0.6171, Val Acc: 0.6446, Test Acc: 0.7619
# Seed: 46, Epoch: 053, Loss: 0.6418, Val Acc: 0.6386, Test Acc: 0.7917
# Seed: 46, Epoch: 054, Loss: 0.6464, Val Acc: 0.6084, Test Acc: 0.7321
# Seed: 46, Epoch: 055, Loss: 0.6501, Val Acc: 0.6084, Test Acc: 0.7321
# Seed: 46, Epoch: 056, Loss: 0.6526, Val Acc: 0.6627, Test Acc: 0.7738
# Seed: 46, Epoch: 057, Loss: 0.6351, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 058, Loss: 0.6277, Val Acc: 0.7108, Test Acc: 0.7917
# Seed: 46, Epoch: 059, Loss: 0.6194, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 060, Loss: 0.6164, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 061, Loss: 0.6022, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 062, Loss: 0.6053, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 063, Loss: 0.5974, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 064, Loss: 0.5962, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 065, Loss: 0.6092, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 46, Epoch: 066, Loss: 0.6164, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 46, Epoch: 067, Loss: 0.6393, Val Acc: 0.6265, Test Acc: 0.7440
# Seed: 46, Epoch: 068, Loss: 0.6588, Val Acc: 0.6205, Test Acc: 0.7440
# Seed: 46, Epoch: 069, Loss: 0.6370, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 070, Loss: 0.6282, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 46, Epoch: 071, Loss: 0.6167, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 072, Loss: 0.6096, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 073, Loss: 0.6044, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 074, Loss: 0.6039, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 075, Loss: 0.6100, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 076, Loss: 0.5993, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 46, Epoch: 077, Loss: 0.5989, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 078, Loss: 0.5939, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 079, Loss: 0.5950, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 46, Epoch: 080, Loss: 0.6057, Val Acc: 0.6566, Test Acc: 0.7738
# Seed: 46, Epoch: 081, Loss: 0.6158, Val Acc: 0.6566, Test Acc: 0.7500
# Seed: 46, Epoch: 082, Loss: 0.6216, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 46, Epoch: 083, Loss: 0.6090, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 084, Loss: 0.6053, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 085, Loss: 0.5925, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 086, Loss: 0.5899, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 087, Loss: 0.5914, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 088, Loss: 0.5873, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 46, Epoch: 089, Loss: 0.5973, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 46, Epoch: 090, Loss: 0.6015, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 091, Loss: 0.6002, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 46, Epoch: 092, Loss: 0.5947, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 093, Loss: 0.5920, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 46, Epoch: 094, Loss: 0.5846, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 095, Loss: 0.5927, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 096, Loss: 0.6205, Val Acc: 0.6506, Test Acc: 0.7262
# Seed: 46, Epoch: 097, Loss: 0.6233, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 098, Loss: 0.6045, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 099, Loss: 0.5975, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 100, Loss: 0.5839, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 101, Loss: 0.5838, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 102, Loss: 0.5820, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 46, Epoch: 103, Loss: 0.5783, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 46, Epoch: 104, Loss: 0.5747, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 105, Loss: 0.5754, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 106, Loss: 0.5932, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 46, Epoch: 107, Loss: 0.6012, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 46, Epoch: 108, Loss: 0.5908, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 46, Epoch: 109, Loss: 0.6046, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 46, Epoch: 110, Loss: 0.5961, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 46, Epoch: 111, Loss: 0.5783, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 46, Epoch: 112, Loss: 0.5773, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 113, Loss: 0.5803, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 114, Loss: 0.5739, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 46, Epoch: 115, Loss: 0.5782, Val Acc: 0.7229, Test Acc: 0.7857
# Seed: 46, Epoch: 116, Loss: 0.5932, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 117, Loss: 0.5914, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 46, Epoch: 118, Loss: 0.5842, Val Acc: 0.7169, Test Acc: 0.7798
# Seed: 46, Epoch: 119, Loss: 0.5771, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 120, Loss: 0.5813, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 121, Loss: 0.5689, Val Acc: 0.7289, Test Acc: 0.7798
# Seed: 46, Epoch: 122, Loss: 0.5799, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 46, Epoch: 123, Loss: 0.6009, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 46, Epoch: 124, Loss: 0.5940, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 125, Loss: 0.5886, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 126, Loss: 0.5859, Val Acc: 0.7530, Test Acc: 0.7560
# Seed: 46, Epoch: 127, Loss: 0.5689, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 46, Epoch: 128, Loss: 0.5755, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 129, Loss: 0.5960, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 130, Loss: 0.5988, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 131, Loss: 0.5883, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 46, Epoch: 132, Loss: 0.5866, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 46, Epoch: 133, Loss: 0.5823, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 46, Epoch: 134, Loss: 0.5836, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 46, Epoch: 135, Loss: 0.5874, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 46, Epoch: 136, Loss: 0.5851, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 46, Epoch: 137, Loss: 0.5853, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 46, Epoch: 138, Loss: 0.5985, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 139, Loss: 0.5940, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 46, Epoch: 140, Loss: 0.5666, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 46, Epoch: 141, Loss: 0.5679, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 142, Loss: 0.5830, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 46, Epoch: 143, Loss: 0.5723, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 144, Loss: 0.5741, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 145, Loss: 0.5764, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 146, Loss: 0.5685, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 147, Loss: 0.5642, Val Acc: 0.7289, Test Acc: 0.7798
# Seed: 46, Epoch: 148, Loss: 0.5689, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 46, Epoch: 149, Loss: 0.5631, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 150, Loss: 0.5591, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 46, Epoch: 151, Loss: 0.5696, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 152, Loss: 0.6253, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 153, Loss: 0.5552, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 154, Loss: 0.5522, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 155, Loss: 0.5552, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 156, Loss: 0.5656, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 157, Loss: 0.5563, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 46, Epoch: 158, Loss: 0.5798, Val Acc: 0.7229, Test Acc: 0.7917
# Seed: 46, Epoch: 159, Loss: 0.5747, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 46, Epoch: 160, Loss: 0.5769, Val Acc: 0.7048, Test Acc: 0.7917
# Seed: 46, Epoch: 161, Loss: 0.5650, Val Acc: 0.7169, Test Acc: 0.7917
# Seed: 46, Epoch: 162, Loss: 0.5701, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 163, Loss: 0.5653, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 164, Loss: 0.5574, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 165, Loss: 0.5503, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 166, Loss: 0.5531, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 167, Loss: 0.5531, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 46, Epoch: 168, Loss: 0.5576, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 46, Epoch: 169, Loss: 0.5644, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 170, Loss: 0.5659, Val Acc: 0.7169, Test Acc: 0.7798
# Seed: 46, Epoch: 171, Loss: 0.5754, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 46, Epoch: 172, Loss: 0.5728, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 173, Loss: 0.5790, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 174, Loss: 0.5719, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 175, Loss: 0.5629, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 46, Epoch: 176, Loss: 0.5575, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 46, Epoch: 177, Loss: 0.5597, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 46, Epoch: 178, Loss: 0.5629, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 179, Loss: 0.5642, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 180, Loss: 0.5703, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 181, Loss: 0.5686, Val Acc: 0.7229, Test Acc: 0.7798
# Seed: 46, Epoch: 182, Loss: 0.5797, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 46, Epoch: 183, Loss: 0.5608, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 46, Epoch: 184, Loss: 0.5610, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 46, Epoch: 185, Loss: 0.5731, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 46, Epoch: 186, Loss: 0.5620, Val Acc: 0.7410, Test Acc: 0.7679
# Seed: 46, Epoch: 187, Loss: 0.5848, Val Acc: 0.6988, Test Acc: 0.7976
# Seed: 46, Epoch: 188, Loss: 0.5845, Val Acc: 0.7108, Test Acc: 0.8036
# Seed: 46, Epoch: 189, Loss: 0.6054, Val Acc: 0.7229, Test Acc: 0.7857
# Seed: 46, Epoch: 190, Loss: 0.5965, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 46, Epoch: 191, Loss: 0.5834, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 192, Loss: 0.5740, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 46, Epoch: 193, Loss: 0.5695, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 46, Epoch: 194, Loss: 0.5625, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 46, Epoch: 195, Loss: 0.5666, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 196, Loss: 0.5607, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 197, Loss: 0.5584, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 46, Epoch: 198, Loss: 0.5523, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 199, Loss: 0.5612, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 200, Loss: 0.5797, Val Acc: 0.7108, Test Acc: 0.7560
# Average Time: 24.72 seconds
# Var Time: 5.23 seconds
# Average Memory: 132.40 MB
# Average Best Val Acc: 0.7614
# Std Best Test Acc: 0.0179
# Average Test Acc: 0.7226

# %% [markdown]
# ## KMISPooling with HierarchicalGCN (2023)

# %%
from typing import Callable, Optional, Tuple, Union

import torch
from torch.nn import Module
from torch_scatter import scatter, scatter_add, scatter_min
from torch_sparse import SparseTensor, remove_diag

from torch_geometric.nn.aggr import Aggregation
from torch_geometric.nn.dense import Linear
from torch_geometric.typing import Adj, OptTensor, PairTensor, Tensor

Scorer = Callable[[Tensor, Adj, OptTensor, OptTensor], Tensor]


import torch
from torch_scatter import scatter_max, scatter_min

from torch_geometric.typing import Adj, OptTensor, SparseTensor, Tensor


def maximal_independent_set(edge_index: Adj, k: int = 1,
                            perm: OptTensor = None) -> Tensor:
    r"""Returns a Maximal :math:`k`-Independent Set of a graph, i.e., a set of
    nodes (as a :class:`ByteTensor`) such that none of them are :math:`k`-hop
    neighbors, and any node in the graph has a :math:`k`-hop neighbor in the
    returned set.
    The algorithm greedily selects the nodes in their canonical order. If a
    permutation :obj:`perm` is provided, the nodes are extracted following
    that permutation instead.
    This method follows `Blelloch's Alogirithm
    <https://arxiv.org/abs/1202.3205>`_ for :math:`k = 1`, and its
    generalization by `Bacciu et al. <https://arxiv.org/abs/2208.03523>`_ for
    higher values of :math:`k`.
    Args:
        edge_index (Tensor or SparseTensor): The graph connectivity.
        k (int): The :math:`k` value (defaults to 1).
        perm (LongTensor, optional): Permutation vector. Must be of size
            :obj:`(n,)` (defaults to :obj:`None`).
    :rtype: :class:`ByteTensor`
    """
    if isinstance(edge_index, SparseTensor):
        row, col, _ = edge_index.coo()
        device = edge_index.device()
        n = edge_index.size(0)
    else:
        row, col = edge_index[0], edge_index[1]
        device = row.device
        n = edge_index.max().item() + 1

    if perm is None:
        rank = torch.arange(n, dtype=torch.long, device=device)
    else:
        rank = torch.zeros_like(perm)
        rank[perm] = torch.arange(n, dtype=torch.long, device=device)

    mis = torch.zeros(n, dtype=torch.bool, device=device)
    mask = mis.clone()
    min_rank = rank.clone()

    while not mask.all():
        for _ in range(k):
            min_neigh = torch.full_like(min_rank, fill_value=n)
            scatter_min(min_rank[row], col, out=min_neigh)
            torch.minimum(min_neigh, min_rank, out=min_rank)  # self-loops

        mis = mis | torch.eq(rank, min_rank)
        mask = mis.clone().byte()

        for _ in range(k):
            max_neigh = torch.full_like(mask, fill_value=0)
            scatter_max(mask[row], col, out=max_neigh)
            torch.maximum(max_neigh, mask, out=mask)  # self-loops

        mask = mask.to(dtype=torch.bool)
        min_rank = rank.clone()
        min_rank[mask] = n

    return mis

def maximal_independent_set_cluster(edge_index: Adj, k: int = 1,
                                    perm: OptTensor = None) -> PairTensor:
    r"""Computes the Maximal :math:`k`-Independent Set (:math:`k`-MIS)
    clustering of a graph, as defined in `"Generalizing Downsampling from
    Regular Data to Graphs" <https://arxiv.org/abs/2208.03523>`_.
    The algorithm greedily selects the nodes in their canonical order. If a
    permutation :obj:`perm` is provided, the nodes are extracted following
    that permutation instead.
    This method returns both the :math:`k`-MIS and the clustering, where the
    :math:`c`-th cluster refers to the :math:`c`-th element of the
    :math:`k`-MIS.
    Args:
        edge_index (Tensor or SparseTensor): The graph connectivity.
        k (int): The :math:`k` value (defaults to 1).
        perm (LongTensor, optional): Permutation vector. Must be of size
            :obj:`(n,)` (defaults to :obj:`None`).
    :rtype: (:class:`ByteTensor`, :class:`LongTensor`)
    """
    mis = maximal_independent_set(edge_index=edge_index, k=k, perm=perm)
    n, device = mis.size(0), mis.device

    if isinstance(edge_index, SparseTensor):
        row, col, _ = edge_index.coo()
    else:
        row, col = edge_index[0], edge_index[1]

    if perm is None:
        rank = torch.arange(n, dtype=torch.long, device=device)
    else:
        rank = torch.zeros_like(perm)
        rank[perm] = torch.arange(n, dtype=torch.long, device=device)

    min_rank = torch.full((n, ), fill_value=n, dtype=torch.long, device=device)
    rank_mis = rank[mis]
    min_rank[mis] = rank_mis

    for _ in range(k):
        min_neigh = torch.full_like(min_rank, fill_value=n)
        scatter_min(min_rank[row], col, out=min_neigh)
        torch.minimum(min_neigh, min_rank, out=min_rank)

    _, clusters = torch.unique(min_rank, return_inverse=True)
    perm = torch.argsort(rank_mis)
    return mis, perm[clusters]


class KMISPooling(Module):

    _heuristics = {None, 'greedy', 'w-greedy'}
    _passthroughs = {None, 'before', 'after'}
    _scorers = {
        'linear',
        'random',
        'constant',
        'canonical',
        'first',
        'last',
    }

    def __init__(self, in_channels: Optional[int] = None, k: int = 1,
                 scorer: Union[Scorer, str] = 'linear',
                 score_heuristic: Optional[str] = 'greedy',
                 score_passthrough: Optional[str] = 'before',
                 aggr_x: Optional[Union[str, Aggregation]] = None,
                 aggr_edge: str = 'sum',
                 aggr_score: Callable[[Tensor, Tensor], Tensor] = torch.mul,
                 remove_self_loops: bool = True) -> None:
        super(KMISPooling, self).__init__()
        assert score_heuristic in self._heuristics, \
            "Unrecognized `score_heuristic` value."
        assert score_passthrough in self._passthroughs, \
            "Unrecognized `score_passthrough` value."

        if not callable(scorer):
            assert scorer in self._scorers, \
                "Unrecognized `scorer` value."

        self.k = k
        self.scorer = scorer
        self.score_heuristic = score_heuristic
        self.score_passthrough = score_passthrough

        self.aggr_x = aggr_x
        self.aggr_edge = aggr_edge
        self.aggr_score = aggr_score
        self.remove_self_loops = remove_self_loops

        if scorer == 'linear':
            assert self.score_passthrough is not None, \
                "`'score_passthrough'` must not be `None`" \
                " when using `'linear'` scorer"

            self.lin = Linear(in_features=in_channels, out_features=1)

    def _apply_heuristic(self, x: Tensor, adj: SparseTensor) -> Tensor:
        if self.score_heuristic is None:
            return x

        row, col, _ = adj.coo()
        x = x.view(-1)

        if self.score_heuristic == 'greedy':
            k_sums = torch.ones_like(x)
        else:
            k_sums = x.clone()

        for _ in range(self.k):
            scatter_add(k_sums[row], col, out=k_sums)

        return x / k_sums

    def _scorer(self, x: Tensor, edge_index: Adj, edge_attr: OptTensor = None,
                batch: OptTensor = None) -> Tensor:
        if self.scorer == 'linear':
            return self.lin(x).sigmoid()

        if self.scorer == 'random':
            return torch.rand((x.size(0), 1), device=x.device)

        if self.scorer == 'constant':
            return torch.ones((x.size(0), 1), device=x.device)

        if self.scorer == 'canonical':
            return -torch.arange(x.size(0), device=x.device).view(-1, 1)

        if self.scorer == 'first':
            return x[..., [0]]

        if self.scorer == 'last':
            return x[..., [-1]]

        return self.scorer(x, edge_index, edge_attr, batch)


    def forward(self, x: Tensor, edge_index: Adj,
                edge_attr: OptTensor = None,
                batch: OptTensor = None) \
            -> Tuple[Tensor, Adj, OptTensor, OptTensor, Tensor, Tensor]:
        """"""
        edge_index = edge_index.long()
        adj, n = edge_index, x.size(0)

        if not isinstance(edge_index, SparseTensor):
            adj = SparseTensor.from_edge_index(edge_index, edge_attr, (n, n))

        score = self._scorer(x, edge_index, edge_attr, batch)
        updated_score = self._apply_heuristic(score, adj)
        perm = torch.argsort(updated_score.view(-1), 0, descending=True)

        mis, cluster = maximal_independent_set_cluster(adj, self.k, perm)

        row, col, val = adj.coo()
        c = mis.sum()

        if val is None:
            val = torch.ones_like(row, dtype=torch.float)

        adj = SparseTensor(row=cluster[row], col=cluster[col], value=val,
                           is_sorted=False,
                           sparse_sizes=(c, c)).coalesce(self.aggr_edge)

        if self.remove_self_loops:
            adj = remove_diag(adj)

        if self.score_passthrough == 'before':
            x = self.aggr_score(x, score)

        if self.aggr_x is None:
            x = x[mis]
        elif isinstance(self.aggr_x, str):
            x = scatter(x, cluster, dim=0, dim_size=mis.sum(),
                        reduce=self.aggr_x)
        else:
            x = self.aggr_x(x, cluster, dim_size=c)

        if self.score_passthrough == 'after':
            x = self.aggr_score(x, score[mis])

        if isinstance(edge_index, SparseTensor):
            edge_index, edge_attr = adj, None

        else:
            row, col, edge_attr = adj.coo()
            edge_index = torch.stack([row, col])

        if batch is not None:
            batch = batch[mis]


        return x, edge_index, edge_attr, batch, mis, cluster

    def __repr__(self):
        if self.scorer == 'linear':
            channels = f"in_channels={self.lin.in_channels}, "
        else:
            channels = ""

        return f'{self.__class__.__name__}({channels}k={self.k})'

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, EdgePooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch
from torch_geometric.nn import BatchNorm

class HierarchicalGCN_KMIS(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_KMIS, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)

        self.pool1 = KMISPooling(64, k=5, aggr_x='sum')
        self.pool2 = KMISPooling(64, k=5, aggr_x='sum')

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, _, batch, _, _ = self.pool1(x, edge_index, batch=batch)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, _, batch, _, _ = self.pool2(x, edge_index, batch=batch)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)



num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_KMIS(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_KMIS(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.7120, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 002, Loss: 0.6870, Val Acc: 0.6386, Test Acc: 0.6250
# Seed: 42, Epoch: 003, Loss: 0.6855, Val Acc: 0.6446, Test Acc: 0.6250
# Seed: 42, Epoch: 004, Loss: 0.6838, Val Acc: 0.6386, Test Acc: 0.6250
# Seed: 42, Epoch: 005, Loss: 0.6812, Val Acc: 0.6325, Test Acc: 0.6429
# Seed: 42, Epoch: 006, Loss: 0.6795, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 42, Epoch: 007, Loss: 0.6788, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 42, Epoch: 008, Loss: 0.6717, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 42, Epoch: 009, Loss: 0.6772, Val Acc: 0.6386, Test Acc: 0.6250
# Seed: 42, Epoch: 010, Loss: 0.6760, Val Acc: 0.6386, Test Acc: 0.6250
# Seed: 42, Epoch: 011, Loss: 0.6756, Val Acc: 0.6446, Test Acc: 0.6250
# Seed: 42, Epoch: 012, Loss: 0.6754, Val Acc: 0.6446, Test Acc: 0.6250
# Seed: 42, Epoch: 013, Loss: 0.6735, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 42, Epoch: 014, Loss: 0.6685, Val Acc: 0.6867, Test Acc: 0.6488
# Seed: 42, Epoch: 015, Loss: 0.6638, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 016, Loss: 0.6598, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 017, Loss: 0.6613, Val Acc: 0.6988, Test Acc: 0.6250
# Seed: 42, Epoch: 018, Loss: 0.6627, Val Acc: 0.6988, Test Acc: 0.6429
# Seed: 42, Epoch: 019, Loss: 0.6560, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 020, Loss: 0.6555, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 021, Loss: 0.6511, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 42, Epoch: 022, Loss: 0.6508, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 023, Loss: 0.6472, Val Acc: 0.7169, Test Acc: 0.6964
# Seed: 42, Epoch: 024, Loss: 0.6505, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 025, Loss: 0.6347, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 026, Loss: 0.6340, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 027, Loss: 0.6277, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 028, Loss: 0.6291, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 42, Epoch: 029, Loss: 0.6208, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 030, Loss: 0.6226, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 031, Loss: 0.6236, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 42, Epoch: 032, Loss: 0.6462, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 033, Loss: 0.6438, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 034, Loss: 0.6332, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 035, Loss: 0.6201, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 036, Loss: 0.6157, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 037, Loss: 0.6149, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 038, Loss: 0.6191, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 42, Epoch: 039, Loss: 0.6210, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 040, Loss: 0.6392, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 42, Epoch: 041, Loss: 0.6539, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 42, Epoch: 042, Loss: 0.6371, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 043, Loss: 0.6368, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 044, Loss: 0.6277, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 045, Loss: 0.7074, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 046, Loss: 0.6648, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 047, Loss: 0.6286, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 048, Loss: 0.6257, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 049, Loss: 0.6184, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 050, Loss: 0.6267, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 42, Epoch: 051, Loss: 0.6277, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 052, Loss: 0.6105, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 053, Loss: 0.6033, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 054, Loss: 0.6140, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 055, Loss: 0.6105, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 056, Loss: 0.6103, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 057, Loss: 0.6099, Val Acc: 0.7349, Test Acc: 0.7143
# Seed: 42, Epoch: 058, Loss: 0.6063, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 059, Loss: 0.6205, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 060, Loss: 0.6273, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 061, Loss: 0.6137, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 42, Epoch: 062, Loss: 0.6004, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 063, Loss: 0.6012, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 42, Epoch: 064, Loss: 0.5987, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 065, Loss: 0.6103, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 42, Epoch: 066, Loss: 0.6142, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 42, Epoch: 067, Loss: 0.6003, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 068, Loss: 0.5953, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 069, Loss: 0.5973, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 070, Loss: 0.6001, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 071, Loss: 0.5996, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 072, Loss: 0.6109, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 073, Loss: 0.6100, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 42, Epoch: 074, Loss: 0.6134, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 075, Loss: 0.6017, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 076, Loss: 0.5938, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 077, Loss: 0.5976, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 078, Loss: 0.5995, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 079, Loss: 0.5991, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 080, Loss: 0.6051, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 081, Loss: 0.6033, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 082, Loss: 0.5943, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 083, Loss: 0.5884, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 084, Loss: 0.5838, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 085, Loss: 0.5841, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 086, Loss: 0.5877, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 087, Loss: 0.5765, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 088, Loss: 0.5773, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 42, Epoch: 089, Loss: 0.5820, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 090, Loss: 0.5884, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 42, Epoch: 091, Loss: 0.5862, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 092, Loss: 0.5891, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 093, Loss: 0.5798, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 094, Loss: 0.5770, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 095, Loss: 0.5800, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 096, Loss: 0.5874, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 097, Loss: 0.5897, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 098, Loss: 0.5882, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 099, Loss: 0.5904, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 100, Loss: 0.5923, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 101, Loss: 0.5992, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 102, Loss: 0.5901, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 42, Epoch: 103, Loss: 0.5896, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 42, Epoch: 104, Loss: 0.5827, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 105, Loss: 0.5912, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 106, Loss: 0.5806, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 107, Loss: 0.5984, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 108, Loss: 0.5947, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 109, Loss: 0.5857, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 110, Loss: 0.5868, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 42, Epoch: 111, Loss: 0.5965, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 42, Epoch: 112, Loss: 0.5855, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 42, Epoch: 113, Loss: 0.5778, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 42, Epoch: 114, Loss: 0.5991, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 115, Loss: 0.5844, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 116, Loss: 0.5867, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 42, Epoch: 117, Loss: 0.5945, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 42, Epoch: 118, Loss: 0.5943, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 119, Loss: 0.5815, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 120, Loss: 0.5774, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 121, Loss: 0.5742, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 122, Loss: 0.5856, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 123, Loss: 0.5807, Val Acc: 0.7410, Test Acc: 0.7619
# Seed: 42, Epoch: 124, Loss: 0.5863, Val Acc: 0.7470, Test Acc: 0.7560
# Seed: 42, Epoch: 125, Loss: 0.5803, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 42, Epoch: 126, Loss: 0.5908, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 127, Loss: 0.5841, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 42, Epoch: 128, Loss: 0.5966, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 42, Epoch: 129, Loss: 0.5979, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 42, Epoch: 130, Loss: 0.6113, Val Acc: 0.7349, Test Acc: 0.7083
# Seed: 42, Epoch: 131, Loss: 0.6163, Val Acc: 0.7470, Test Acc: 0.7083
# Seed: 42, Epoch: 132, Loss: 0.6005, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 42, Epoch: 133, Loss: 0.5882, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 42, Epoch: 134, Loss: 0.5830, Val Acc: 0.7410, Test Acc: 0.7202
# Seed: 42, Epoch: 135, Loss: 0.5752, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 42, Epoch: 136, Loss: 0.5847, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 42, Epoch: 137, Loss: 0.5797, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 138, Loss: 0.5770, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 42, Epoch: 139, Loss: 0.5792, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 140, Loss: 0.5882, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 42, Epoch: 141, Loss: 0.5878, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 42, Epoch: 142, Loss: 0.5939, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 42, Epoch: 143, Loss: 0.5771, Val Acc: 0.7530, Test Acc: 0.7500
# Seed: 42, Epoch: 144, Loss: 0.5812, Val Acc: 0.7530, Test Acc: 0.7619
# Seed: 42, Epoch: 145, Loss: 0.5729, Val Acc: 0.7530, Test Acc: 0.7262
# Seed: 42, Epoch: 146, Loss: 0.5814, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 42, Epoch: 147, Loss: 0.5823, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 148, Loss: 0.5739, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 149, Loss: 0.5842, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 42, Epoch: 150, Loss: 0.5902, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 151, Loss: 0.5777, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 42, Epoch: 152, Loss: 0.5829, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 42, Epoch: 153, Loss: 0.5814, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 154, Loss: 0.5718, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 155, Loss: 0.5727, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 42, Epoch: 156, Loss: 0.5829, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 42, Epoch: 157, Loss: 0.5753, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 158, Loss: 0.5653, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 42, Epoch: 159, Loss: 0.5784, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 160, Loss: 0.5872, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 42, Epoch: 161, Loss: 0.5639, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 162, Loss: 0.5684, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 163, Loss: 0.5685, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 164, Loss: 0.5725, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 42, Epoch: 165, Loss: 0.5854, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 166, Loss: 0.5750, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 42, Epoch: 167, Loss: 0.5707, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 42, Epoch: 168, Loss: 0.5655, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 169, Loss: 0.5671, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 170, Loss: 0.5687, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 171, Loss: 0.5632, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 42, Epoch: 172, Loss: 0.5602, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 173, Loss: 0.5738, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 42, Epoch: 174, Loss: 0.5691, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 42, Epoch: 175, Loss: 0.5553, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 176, Loss: 0.5670, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 177, Loss: 0.5593, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 178, Loss: 0.5999, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 42, Epoch: 179, Loss: 0.6029, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 180, Loss: 0.5852, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 181, Loss: 0.5723, Val Acc: 0.6807, Test Acc: 0.6488
# Seed: 42, Epoch: 182, Loss: 0.5837, Val Acc: 0.6566, Test Acc: 0.6607
# Seed: 42, Epoch: 183, Loss: 0.5807, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 42, Epoch: 184, Loss: 0.5648, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 185, Loss: 0.5572, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 42, Epoch: 186, Loss: 0.5529, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 42, Epoch: 187, Loss: 0.5606, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 188, Loss: 0.5735, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 189, Loss: 0.5734, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 42, Epoch: 190, Loss: 0.5547, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 191, Loss: 0.5582, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 192, Loss: 0.5568, Val Acc: 0.7470, Test Acc: 0.7143
# Seed: 42, Epoch: 193, Loss: 0.5760, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 194, Loss: 0.5848, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 42, Epoch: 195, Loss: 0.5750, Val Acc: 0.7590, Test Acc: 0.7083
# Seed: 42, Epoch: 196, Loss: 0.5636, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 42, Epoch: 197, Loss: 0.5588, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 198, Loss: 0.5620, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 199, Loss: 0.5556, Val Acc: 0.7470, Test Acc: 0.7262
# Seed: 42, Epoch: 200, Loss: 0.5716, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 001, Loss: 0.6539, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 43, Epoch: 002, Loss: 0.6018, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 43, Epoch: 003, Loss: 0.6236, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 43, Epoch: 004, Loss: 0.6308, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 005, Loss: 0.6500, Val Acc: 0.6566, Test Acc: 0.6131
# Seed: 43, Epoch: 006, Loss: 0.6574, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 43, Epoch: 007, Loss: 0.6445, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 43, Epoch: 008, Loss: 0.6141, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 43, Epoch: 009, Loss: 0.6226, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 010, Loss: 0.6034, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 43, Epoch: 011, Loss: 0.6359, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 43, Epoch: 012, Loss: 0.6377, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 43, Epoch: 013, Loss: 0.6224, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 014, Loss: 0.6252, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 015, Loss: 0.6158, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 43, Epoch: 016, Loss: 0.6295, Val Acc: 0.6747, Test Acc: 0.6726
# Seed: 43, Epoch: 017, Loss: 0.6438, Val Acc: 0.6566, Test Acc: 0.6548
# Seed: 43, Epoch: 018, Loss: 0.6427, Val Acc: 0.6566, Test Acc: 0.6310
# Seed: 43, Epoch: 019, Loss: 0.6628, Val Acc: 0.6446, Test Acc: 0.5952
# Seed: 43, Epoch: 020, Loss: 0.6761, Val Acc: 0.6446, Test Acc: 0.6012
# Seed: 43, Epoch: 021, Loss: 0.6704, Val Acc: 0.6386, Test Acc: 0.6548
# Seed: 43, Epoch: 022, Loss: 0.6598, Val Acc: 0.6446, Test Acc: 0.6726
# Seed: 43, Epoch: 023, Loss: 0.6355, Val Acc: 0.6807, Test Acc: 0.6726
# Seed: 43, Epoch: 024, Loss: 0.6253, Val Acc: 0.7410, Test Acc: 0.7202
# Seed: 43, Epoch: 025, Loss: 0.5944, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 43, Epoch: 026, Loss: 0.5982, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 43, Epoch: 027, Loss: 0.5850, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 43, Epoch: 028, Loss: 0.5954, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 43, Epoch: 029, Loss: 0.5905, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 030, Loss: 0.5949, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 031, Loss: 0.5913, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 032, Loss: 0.6003, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 033, Loss: 0.5975, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 034, Loss: 0.6019, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 035, Loss: 0.6117, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 036, Loss: 0.6180, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 43, Epoch: 037, Loss: 0.6122, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 038, Loss: 0.6083, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 039, Loss: 0.5935, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 040, Loss: 0.5892, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 43, Epoch: 041, Loss: 0.5917, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 43, Epoch: 042, Loss: 0.6049, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 043, Loss: 0.6084, Val Acc: 0.6386, Test Acc: 0.6964
# Seed: 43, Epoch: 044, Loss: 0.6210, Val Acc: 0.6566, Test Acc: 0.7024
# Seed: 43, Epoch: 045, Loss: 0.6211, Val Acc: 0.6566, Test Acc: 0.7083
# Seed: 43, Epoch: 046, Loss: 0.6141, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 047, Loss: 0.6135, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 048, Loss: 0.6036, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 049, Loss: 0.6069, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 050, Loss: 0.6036, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 051, Loss: 0.5934, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 052, Loss: 0.5958, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 43, Epoch: 053, Loss: 0.5934, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 054, Loss: 0.5819, Val Acc: 0.6807, Test Acc: 0.7321
# Seed: 43, Epoch: 055, Loss: 0.5725, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 056, Loss: 0.5757, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 057, Loss: 0.5778, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 43, Epoch: 058, Loss: 0.5675, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 059, Loss: 0.5711, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 060, Loss: 0.5779, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 061, Loss: 0.5855, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 062, Loss: 0.5928, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 43, Epoch: 063, Loss: 0.5962, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 064, Loss: 0.6156, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 065, Loss: 0.6053, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 43, Epoch: 066, Loss: 0.6079, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 43, Epoch: 067, Loss: 0.5974, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 068, Loss: 0.5876, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 069, Loss: 0.5797, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 070, Loss: 0.5878, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 071, Loss: 0.5865, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 072, Loss: 0.5980, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 073, Loss: 0.6083, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 074, Loss: 0.5981, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 43, Epoch: 075, Loss: 0.5846, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 076, Loss: 0.5645, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 077, Loss: 0.5794, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 078, Loss: 0.5661, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 079, Loss: 0.5773, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 080, Loss: 0.5809, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 43, Epoch: 081, Loss: 0.5927, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 43, Epoch: 082, Loss: 0.5972, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 083, Loss: 0.5939, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 084, Loss: 0.5792, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 085, Loss: 0.5838, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 086, Loss: 0.5824, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 087, Loss: 0.5799, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 088, Loss: 0.5722, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 089, Loss: 0.5779, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 43, Epoch: 090, Loss: 0.5748, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 43, Epoch: 091, Loss: 0.5782, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 43, Epoch: 092, Loss: 0.5880, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 093, Loss: 0.5823, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 094, Loss: 0.5881, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 095, Loss: 0.5923, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 096, Loss: 0.5879, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 097, Loss: 0.5830, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 098, Loss: 0.5834, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 099, Loss: 0.5774, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 100, Loss: 0.5744, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 101, Loss: 0.5729, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 102, Loss: 0.5666, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 103, Loss: 0.5663, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 104, Loss: 0.5557, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 105, Loss: 0.5611, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 106, Loss: 0.5590, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 107, Loss: 0.5671, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 108, Loss: 0.5608, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 109, Loss: 0.5611, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 110, Loss: 0.5569, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 111, Loss: 0.5513, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 43, Epoch: 112, Loss: 0.5607, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 113, Loss: 0.5652, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 114, Loss: 0.5717, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 115, Loss: 0.5656, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 116, Loss: 0.5687, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 117, Loss: 0.5662, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 118, Loss: 0.5677, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 119, Loss: 0.5605, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 120, Loss: 0.5521, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 121, Loss: 0.5454, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 122, Loss: 0.5422, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 123, Loss: 0.5388, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 124, Loss: 0.5433, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 125, Loss: 0.5430, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 126, Loss: 0.5538, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 127, Loss: 0.5597, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 128, Loss: 0.5601, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 129, Loss: 0.5552, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 43, Epoch: 130, Loss: 0.5373, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 131, Loss: 0.5374, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 132, Loss: 0.5357, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 133, Loss: 0.5470, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 134, Loss: 0.5405, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 135, Loss: 0.5451, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 136, Loss: 0.5500, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 137, Loss: 0.5515, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 43, Epoch: 138, Loss: 0.5427, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 43, Epoch: 139, Loss: 0.5506, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 43, Epoch: 140, Loss: 0.5505, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 43, Epoch: 141, Loss: 0.5526, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 142, Loss: 0.5588, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 143, Loss: 0.5545, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 144, Loss: 0.5548, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 145, Loss: 0.5523, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 146, Loss: 0.5463, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 147, Loss: 0.5488, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 148, Loss: 0.5490, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 149, Loss: 0.5455, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 150, Loss: 0.5505, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 151, Loss: 0.5564, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 152, Loss: 0.5514, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 153, Loss: 0.5524, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 154, Loss: 0.5486, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 43, Epoch: 155, Loss: 0.5444, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 156, Loss: 0.5428, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 157, Loss: 0.5430, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 158, Loss: 0.5363, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 159, Loss: 0.5439, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 160, Loss: 0.5457, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 43, Epoch: 161, Loss: 0.5399, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 43, Epoch: 162, Loss: 0.5411, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 163, Loss: 0.5388, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 43, Epoch: 164, Loss: 0.5330, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 165, Loss: 0.5380, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 166, Loss: 0.5411, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 43, Epoch: 167, Loss: 0.5476, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 43, Epoch: 168, Loss: 0.5504, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 43, Epoch: 169, Loss: 0.5466, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 170, Loss: 0.5368, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 43, Epoch: 171, Loss: 0.5322, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 43, Epoch: 172, Loss: 0.5486, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 43, Epoch: 173, Loss: 0.5333, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 43, Epoch: 174, Loss: 0.5372, Val Acc: 0.7229, Test Acc: 0.7440
# Early stopping at epoch 174 for seed 43
# Seed: 44, Epoch: 001, Loss: 0.5996, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 44, Epoch: 002, Loss: 0.6479, Val Acc: 0.6747, Test Acc: 0.6726
# Seed: 44, Epoch: 003, Loss: 0.6465, Val Acc: 0.6928, Test Acc: 0.6786
# Seed: 44, Epoch: 004, Loss: 0.6342, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 44, Epoch: 005, Loss: 0.6344, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 006, Loss: 0.6419, Val Acc: 0.6325, Test Acc: 0.6250
# Seed: 44, Epoch: 007, Loss: 0.7130, Val Acc: 0.3614, Test Acc: 0.3988
# Seed: 44, Epoch: 008, Loss: 0.6934, Val Acc: 0.3735, Test Acc: 0.4048
# Seed: 44, Epoch: 009, Loss: 0.7144, Val Acc: 0.3675, Test Acc: 0.3810
# Seed: 44, Epoch: 010, Loss: 0.7148, Val Acc: 0.3675, Test Acc: 0.4405
# Seed: 44, Epoch: 011, Loss: 0.7024, Val Acc: 0.5723, Test Acc: 0.6012
# Seed: 44, Epoch: 012, Loss: 0.6694, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 44, Epoch: 013, Loss: 0.6151, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 014, Loss: 0.6077, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 44, Epoch: 015, Loss: 0.6061, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 44, Epoch: 016, Loss: 0.6005, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 017, Loss: 0.6056, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 018, Loss: 0.6238, Val Acc: 0.6687, Test Acc: 0.6845
# Seed: 44, Epoch: 019, Loss: 0.6402, Val Acc: 0.6325, Test Acc: 0.6250
# Seed: 44, Epoch: 020, Loss: 0.6588, Val Acc: 0.5723, Test Acc: 0.6012
# Seed: 44, Epoch: 021, Loss: 0.6708, Val Acc: 0.6024, Test Acc: 0.6131
# Seed: 44, Epoch: 022, Loss: 0.6672, Val Acc: 0.6205, Test Acc: 0.6429
# Seed: 44, Epoch: 023, Loss: 0.6448, Val Acc: 0.6566, Test Acc: 0.7083
# Seed: 44, Epoch: 024, Loss: 0.6350, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 025, Loss: 0.6301, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 026, Loss: 0.6264, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 027, Loss: 0.6177, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 028, Loss: 0.6235, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 029, Loss: 0.6226, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 030, Loss: 0.6122, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 031, Loss: 0.6163, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 032, Loss: 0.6190, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 033, Loss: 0.6206, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 034, Loss: 0.6273, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 035, Loss: 0.6239, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 036, Loss: 0.6260, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 037, Loss: 0.6102, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 038, Loss: 0.6151, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 039, Loss: 0.5943, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 040, Loss: 0.5866, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 041, Loss: 0.5892, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 042, Loss: 0.5840, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 043, Loss: 0.5938, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 044, Loss: 0.5895, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 045, Loss: 0.5942, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 046, Loss: 0.5869, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 047, Loss: 0.5846, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 048, Loss: 0.5926, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 049, Loss: 0.5953, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 050, Loss: 0.5922, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 051, Loss: 0.6024, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 052, Loss: 0.5966, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 053, Loss: 0.5987, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 054, Loss: 0.5833, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 055, Loss: 0.5888, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 056, Loss: 0.5824, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 057, Loss: 0.5729, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 058, Loss: 0.5745, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 059, Loss: 0.5644, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 060, Loss: 0.5697, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 44, Epoch: 061, Loss: 0.5701, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 062, Loss: 0.5709, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 063, Loss: 0.5792, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 44, Epoch: 064, Loss: 0.6020, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 065, Loss: 0.6151, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 066, Loss: 0.6190, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 067, Loss: 0.6287, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 068, Loss: 0.6136, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 069, Loss: 0.6163, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 070, Loss: 0.6028, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 071, Loss: 0.6044, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 072, Loss: 0.6005, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 073, Loss: 0.5851, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 074, Loss: 0.5774, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 075, Loss: 0.5769, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 076, Loss: 0.5782, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 077, Loss: 0.5749, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 078, Loss: 0.5883, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 079, Loss: 0.5766, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 080, Loss: 0.5838, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 081, Loss: 0.5884, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 082, Loss: 0.5867, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 083, Loss: 0.5843, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 084, Loss: 0.5810, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 085, Loss: 0.5821, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 086, Loss: 0.5761, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 087, Loss: 0.5852, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 088, Loss: 0.5899, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 089, Loss: 0.5918, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 090, Loss: 0.5787, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 091, Loss: 0.5797, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 092, Loss: 0.5768, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 093, Loss: 0.5795, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 094, Loss: 0.5768, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 095, Loss: 0.5807, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 096, Loss: 0.5788, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 097, Loss: 0.5773, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 098, Loss: 0.5762, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 099, Loss: 0.5637, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 100, Loss: 0.5590, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 101, Loss: 0.5784, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 102, Loss: 0.5746, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 103, Loss: 0.5751, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 104, Loss: 0.5809, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 105, Loss: 0.5810, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 106, Loss: 0.5832, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 107, Loss: 0.5754, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 44, Epoch: 108, Loss: 0.5755, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 109, Loss: 0.5610, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 110, Loss: 0.5596, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 111, Loss: 0.5552, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 112, Loss: 0.5599, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 113, Loss: 0.5675, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 114, Loss: 0.5646, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 115, Loss: 0.5657, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 44, Epoch: 116, Loss: 0.5755, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 117, Loss: 0.5797, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 44, Epoch: 118, Loss: 0.5853, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 119, Loss: 0.5841, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 120, Loss: 0.5815, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 121, Loss: 0.5771, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 122, Loss: 0.5696, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 123, Loss: 0.5776, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 124, Loss: 0.5704, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 125, Loss: 0.5733, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 126, Loss: 0.5812, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 127, Loss: 0.5708, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 128, Loss: 0.5650, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 129, Loss: 0.5755, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 130, Loss: 0.5703, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 131, Loss: 0.5607, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 132, Loss: 0.5535, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 133, Loss: 0.5719, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 134, Loss: 0.5765, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 135, Loss: 0.5775, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 136, Loss: 0.5768, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 137, Loss: 0.5628, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 138, Loss: 0.5636, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 139, Loss: 0.5635, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 140, Loss: 0.5619, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 141, Loss: 0.5675, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 142, Loss: 0.5724, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 143, Loss: 0.5811, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 144, Loss: 0.5903, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 145, Loss: 0.5918, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 146, Loss: 0.5900, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 147, Loss: 0.5859, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 148, Loss: 0.5841, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 149, Loss: 0.5784, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 150, Loss: 0.5696, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 151, Loss: 0.5670, Val Acc: 0.7108, Test Acc: 0.7321
# Early stopping at epoch 151 for seed 44
# Seed: 45, Epoch: 001, Loss: 0.6525, Val Acc: 0.6747, Test Acc: 0.6250
# Seed: 45, Epoch: 002, Loss: 0.6303, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 45, Epoch: 003, Loss: 0.6533, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 45, Epoch: 004, Loss: 0.6661, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 45, Epoch: 005, Loss: 0.6462, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 006, Loss: 0.6298, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 45, Epoch: 007, Loss: 0.6301, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 008, Loss: 0.6267, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 45, Epoch: 009, Loss: 0.6339, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 010, Loss: 0.6398, Val Acc: 0.6867, Test Acc: 0.7143
# Seed: 45, Epoch: 011, Loss: 0.6695, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 45, Epoch: 012, Loss: 0.6539, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 013, Loss: 0.6320, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 014, Loss: 0.6207, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 015, Loss: 0.6099, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 016, Loss: 0.6037, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 017, Loss: 0.6007, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 018, Loss: 0.6020, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 45, Epoch: 019, Loss: 0.6239, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 020, Loss: 0.6460, Val Acc: 0.4096, Test Acc: 0.4643
# Seed: 45, Epoch: 021, Loss: 0.6843, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 45, Epoch: 022, Loss: 0.6571, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 45, Epoch: 023, Loss: 0.6344, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 45, Epoch: 024, Loss: 0.6150, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 45, Epoch: 025, Loss: 0.6033, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 45, Epoch: 026, Loss: 0.5971, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 027, Loss: 0.6106, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 028, Loss: 0.6468, Val Acc: 0.3795, Test Acc: 0.4107
# Seed: 45, Epoch: 029, Loss: 0.8931, Val Acc: 0.3614, Test Acc: 0.4048
# Seed: 45, Epoch: 030, Loss: 0.6940, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 45, Epoch: 031, Loss: 0.6187, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 032, Loss: 0.6140, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 033, Loss: 0.6172, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 45, Epoch: 034, Loss: 0.6162, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 035, Loss: 0.6159, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 036, Loss: 0.6098, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 037, Loss: 0.6150, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 038, Loss: 0.6190, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 45, Epoch: 039, Loss: 0.6135, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 040, Loss: 0.6299, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 041, Loss: 0.6207, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 45, Epoch: 042, Loss: 0.6380, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 043, Loss: 0.6327, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 45, Epoch: 044, Loss: 0.6233, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 45, Epoch: 045, Loss: 0.6214, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 45, Epoch: 046, Loss: 0.6046, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 047, Loss: 0.6087, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 048, Loss: 0.6046, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 049, Loss: 0.6029, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 45, Epoch: 050, Loss: 0.6142, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 45, Epoch: 051, Loss: 0.6086, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 052, Loss: 0.6095, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 053, Loss: 0.6334, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 054, Loss: 0.6372, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 055, Loss: 0.6438, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 45, Epoch: 056, Loss: 0.6476, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 45, Epoch: 057, Loss: 0.6476, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 45, Epoch: 058, Loss: 0.6306, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 45, Epoch: 059, Loss: 0.6307, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 060, Loss: 0.6164, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 061, Loss: 0.6187, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 062, Loss: 0.6177, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 063, Loss: 0.6185, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 064, Loss: 0.6124, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 065, Loss: 0.6209, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 066, Loss: 0.6027, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 067, Loss: 0.6182, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 068, Loss: 0.6221, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 069, Loss: 0.6290, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 070, Loss: 0.6106, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 071, Loss: 0.6210, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 072, Loss: 0.6190, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 073, Loss: 0.6060, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 074, Loss: 0.6224, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 45, Epoch: 075, Loss: 0.6065, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 45, Epoch: 076, Loss: 0.6222, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 077, Loss: 0.6113, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 078, Loss: 0.6063, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 079, Loss: 0.6280, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 080, Loss: 0.6226, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 081, Loss: 0.6153, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 082, Loss: 0.6160, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 083, Loss: 0.6206, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 084, Loss: 0.6123, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 45, Epoch: 085, Loss: 0.6112, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 086, Loss: 0.6060, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 087, Loss: 0.6129, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 088, Loss: 0.6060, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 089, Loss: 0.6222, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 090, Loss: 0.6083, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 091, Loss: 0.6334, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 092, Loss: 0.6380, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 45, Epoch: 093, Loss: 0.6397, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 094, Loss: 0.6372, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 45, Epoch: 095, Loss: 0.6296, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 45, Epoch: 096, Loss: 0.6162, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 097, Loss: 0.6219, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 098, Loss: 0.6276, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 099, Loss: 0.6169, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 100, Loss: 0.6091, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 101, Loss: 0.6168, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 102, Loss: 0.6110, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 103, Loss: 0.6132, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 104, Loss: 0.6225, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 45, Epoch: 105, Loss: 0.6119, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 106, Loss: 0.6107, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 107, Loss: 0.6132, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 108, Loss: 0.6116, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 109, Loss: 0.6152, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 110, Loss: 0.6050, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 111, Loss: 0.6042, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 112, Loss: 0.5928, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 113, Loss: 0.5940, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 114, Loss: 0.5923, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 115, Loss: 0.5996, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 116, Loss: 0.5961, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 117, Loss: 0.5964, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 118, Loss: 0.6073, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 119, Loss: 0.6060, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 120, Loss: 0.6028, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 121, Loss: 0.5991, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 122, Loss: 0.6018, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 123, Loss: 0.6116, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 124, Loss: 0.6027, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 125, Loss: 0.5918, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 126, Loss: 0.6028, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 127, Loss: 0.5955, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 128, Loss: 0.5994, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 129, Loss: 0.5967, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 130, Loss: 0.5911, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 131, Loss: 0.5922, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 132, Loss: 0.5862, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 133, Loss: 0.5942, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 134, Loss: 0.5903, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 135, Loss: 0.5848, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 136, Loss: 0.5862, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 137, Loss: 0.5850, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 138, Loss: 0.5917, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 45, Epoch: 139, Loss: 0.5900, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 140, Loss: 0.5907, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 141, Loss: 0.5913, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 142, Loss: 0.5987, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 143, Loss: 0.5948, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 144, Loss: 0.5953, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 145, Loss: 0.5932, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 146, Loss: 0.5959, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 147, Loss: 0.5922, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 148, Loss: 0.5873, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 149, Loss: 0.5952, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 150, Loss: 0.5973, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 151, Loss: 0.5869, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 152, Loss: 0.5942, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 153, Loss: 0.5932, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 154, Loss: 0.6017, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 45, Epoch: 155, Loss: 0.5942, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 156, Loss: 0.5966, Val Acc: 0.7169, Test Acc: 0.7262
# Early stopping at epoch 156 for seed 45
# Seed: 46, Epoch: 001, Loss: 0.6545, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 002, Loss: 0.6440, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 003, Loss: 0.6229, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 004, Loss: 0.6426, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 005, Loss: 0.6399, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 006, Loss: 0.6502, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 007, Loss: 0.6511, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 008, Loss: 0.6498, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 009, Loss: 0.6531, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 010, Loss: 0.6491, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 011, Loss: 0.6473, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 012, Loss: 0.6354, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 013, Loss: 0.6314, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 014, Loss: 0.6213, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 015, Loss: 0.6303, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 016, Loss: 0.6303, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 017, Loss: 0.6276, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 018, Loss: 0.6285, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 019, Loss: 0.6130, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 020, Loss: 0.6115, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 46, Epoch: 021, Loss: 0.6155, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 022, Loss: 0.6156, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 023, Loss: 0.6043, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 024, Loss: 0.5998, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 025, Loss: 0.5798, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 026, Loss: 0.5821, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 027, Loss: 0.5902, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 028, Loss: 0.5885, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 029, Loss: 0.5903, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 030, Loss: 0.6067, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 46, Epoch: 031, Loss: 0.6190, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 032, Loss: 0.6464, Val Acc: 0.6687, Test Acc: 0.6607
# Seed: 46, Epoch: 033, Loss: 0.6602, Val Acc: 0.6988, Test Acc: 0.6786
# Seed: 46, Epoch: 034, Loss: 0.6536, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 035, Loss: 0.6414, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 036, Loss: 0.6361, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 037, Loss: 0.6199, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 038, Loss: 0.6132, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 039, Loss: 0.5932, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 040, Loss: 0.5778, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 041, Loss: 0.6204, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 042, Loss: 0.5857, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 043, Loss: 0.5870, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 044, Loss: 0.5911, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 045, Loss: 0.5864, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 046, Loss: 0.5948, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 047, Loss: 0.5946, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 048, Loss: 0.5897, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 049, Loss: 0.5902, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 050, Loss: 0.6062, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 051, Loss: 0.5993, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 052, Loss: 0.5962, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 46, Epoch: 053, Loss: 0.6025, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 054, Loss: 0.6114, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 055, Loss: 0.6167, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 056, Loss: 0.6229, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 057, Loss: 0.6106, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 058, Loss: 0.6084, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 059, Loss: 0.6036, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 060, Loss: 0.5933, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 061, Loss: 0.5878, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 062, Loss: 0.5872, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 063, Loss: 0.5936, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 064, Loss: 0.5967, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 065, Loss: 0.5841, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 066, Loss: 0.5966, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 067, Loss: 0.5860, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 068, Loss: 0.5935, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 46, Epoch: 069, Loss: 0.5911, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 070, Loss: 0.6043, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 071, Loss: 0.6001, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 072, Loss: 0.5983, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 073, Loss: 0.5899, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 074, Loss: 0.5911, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 075, Loss: 0.5866, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 076, Loss: 0.5775, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 077, Loss: 0.5728, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 078, Loss: 0.5685, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 079, Loss: 0.5685, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 080, Loss: 0.5627, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 081, Loss: 0.5578, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 082, Loss: 0.5801, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 083, Loss: 0.5562, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 084, Loss: 0.5787, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 085, Loss: 0.5956, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 086, Loss: 0.6061, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 087, Loss: 0.6004, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 088, Loss: 0.5933, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 089, Loss: 0.5818, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 090, Loss: 0.5831, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 091, Loss: 0.5809, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 092, Loss: 0.5739, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 093, Loss: 0.5655, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 094, Loss: 0.5631, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 095, Loss: 0.5763, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 46, Epoch: 096, Loss: 0.5600, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 097, Loss: 0.5699, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 098, Loss: 0.5864, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 099, Loss: 0.5964, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 100, Loss: 0.5917, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 101, Loss: 0.5800, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 102, Loss: 0.5717, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 103, Loss: 0.5648, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 46, Epoch: 104, Loss: 0.5644, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 105, Loss: 0.5608, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 106, Loss: 0.5668, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 107, Loss: 0.5640, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 108, Loss: 0.5673, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 109, Loss: 0.5638, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 110, Loss: 0.5623, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 111, Loss: 0.5601, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 46, Epoch: 112, Loss: 0.5642, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 46, Epoch: 113, Loss: 0.5642, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 114, Loss: 0.5695, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 46, Epoch: 115, Loss: 0.6088, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 46, Epoch: 116, Loss: 0.6006, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 117, Loss: 0.5660, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 46, Epoch: 118, Loss: 0.5580, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 119, Loss: 0.5562, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 120, Loss: 0.5514, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 46, Epoch: 121, Loss: 0.5521, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 46, Epoch: 122, Loss: 0.5507, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 123, Loss: 0.5487, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 46, Epoch: 124, Loss: 0.5439, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 46, Epoch: 125, Loss: 0.5615, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 46, Epoch: 126, Loss: 0.5467, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 127, Loss: 0.5450, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 128, Loss: 0.5407, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 129, Loss: 0.5516, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 130, Loss: 0.5512, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 131, Loss: 0.5595, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 132, Loss: 0.5812, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 133, Loss: 0.5743, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 134, Loss: 0.5670, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 135, Loss: 0.5642, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 46, Epoch: 136, Loss: 0.5604, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 137, Loss: 0.5578, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 138, Loss: 0.5561, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 139, Loss: 0.5566, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 46, Epoch: 140, Loss: 0.5508, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 141, Loss: 0.5577, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 142, Loss: 0.5661, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 143, Loss: 0.5586, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 144, Loss: 0.5564, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 145, Loss: 0.5565, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 146, Loss: 0.5506, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 147, Loss: 0.5488, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 148, Loss: 0.5502, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 149, Loss: 0.5608, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 150, Loss: 0.5496, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 151, Loss: 0.5506, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 152, Loss: 0.5544, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 153, Loss: 0.5630, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 46, Epoch: 154, Loss: 0.5669, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 46, Epoch: 155, Loss: 0.5737, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 46, Epoch: 156, Loss: 0.5681, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 46, Epoch: 157, Loss: 0.5550, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 46, Epoch: 158, Loss: 0.5618, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 159, Loss: 0.5524, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 160, Loss: 0.5524, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 161, Loss: 0.5543, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 162, Loss: 0.5520, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 163, Loss: 0.5518, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 164, Loss: 0.5588, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 165, Loss: 0.5561, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 166, Loss: 0.5602, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 167, Loss: 0.5538, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 168, Loss: 0.5541, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 169, Loss: 0.5473, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 170, Loss: 0.5466, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 46, Epoch: 171, Loss: 0.5497, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 172, Loss: 0.5546, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 46, Epoch: 173, Loss: 0.5521, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 174, Loss: 0.5785, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 175, Loss: 0.5932, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 176, Loss: 0.5811, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 46, Epoch: 177, Loss: 0.5635, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 178, Loss: 0.5623, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 179, Loss: 0.5516, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 180, Loss: 0.5476, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 181, Loss: 0.5432, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 182, Loss: 0.5444, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 183, Loss: 0.5447, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 184, Loss: 0.5370, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 185, Loss: 0.5409, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 186, Loss: 0.5425, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 187, Loss: 0.5459, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 188, Loss: 0.5540, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 189, Loss: 0.5615, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 190, Loss: 0.5563, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 191, Loss: 0.5531, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 192, Loss: 0.5548, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 193, Loss: 0.5476, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 194, Loss: 0.5282, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 46, Epoch: 195, Loss: 0.5305, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 196, Loss: 0.5306, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 197, Loss: 0.5231, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 198, Loss: 0.5371, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 46, Epoch: 199, Loss: 0.5331, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 200, Loss: 0.5439, Val Acc: 0.7229, Test Acc: 0.7440
# Average Time: 18.96 seconds
# Var Time: 4.39 seconds
# Average Memory: 28.00 MB
# Average Best Val Acc: 0.7373
# Std Best Test Acc: 0.0110
# Average Test Acc: 0.7298

# %% [markdown]
# ## GSAPooling with HierarchicalGCN (2021)

# %%
from torch_geometric.nn import GCNConv
from torch.nn import Parameter
import torch

import torch.nn as nn
import numpy as np

from typing import Union, Optional, Callable
from torch_scatter import scatter_add, scatter_max
from torch_geometric.utils import softmax

import math


import torch.nn.functional as F
from torch_geometric.nn import GCNConv, SAGEConv, GATConv, ChebConv, GraphConv


def uniform(size, tensor):
    if tensor is not None:
        bound = 1.0 / math.sqrt(size)
        tensor.data.uniform_(-bound, bound)


def maybe_num_nodes(edge_index, num_nodes=None):
    if num_nodes is not None:
        return num_nodes
    elif isinstance(edge_index, Tensor):
        return int(edge_index.max()) + 1 if edge_index.numel() > 0 else 0
    else:
        return max(edge_index.size(0), edge_index.size(1))


def topk(x, ratio, batch, min_score=None, tol=1e-7):
    if min_score is not None:
        # Make sure that we do not drop all nodes in a graph.
        scores_max = scatter_max(x, batch)[0][batch] - tol
        scores_min = scores_max.clamp(max=min_score)

        perm = (x > scores_min).nonzero(as_tuple=False).view(-1)
    else:
        num_nodes = scatter_add(batch.new_ones(x.size(0)), batch, dim=0)
        batch_size, max_num_nodes = num_nodes.size(0), num_nodes.max().item()

        cum_num_nodes = torch.cat(
            [num_nodes.new_zeros(1),
             num_nodes.cumsum(dim=0)[:-1]], dim=0)

        index = torch.arange(batch.size(0), dtype=torch.long, device=x.device)
        index = (index - cum_num_nodes[batch]) + (batch * max_num_nodes)

        dense_x = x.new_full((batch_size * max_num_nodes, ),
                             torch.finfo(x.dtype).min)
        dense_x[index] = x
        dense_x = dense_x.view(batch_size, max_num_nodes)

        _, perm = dense_x.sort(dim=-1, descending=True)

        perm = perm + cum_num_nodes.view(-1, 1)
        perm = perm.view(-1)

        if isinstance(ratio, int):
            k = num_nodes.new_full((num_nodes.size(0), ), ratio)
            k = torch.min(k, num_nodes)
        else:
            k = (ratio * num_nodes.to(torch.float)).ceil().to(torch.long)

        mask = [
            torch.arange(k[i], dtype=torch.long, device=x.device) +
            i * max_num_nodes for i in range(batch_size)
        ]
        mask = torch.cat(mask, dim=0)

        perm = perm[mask]

    return perm


def filter_adj(edge_index, edge_attr, perm, num_nodes=None):
    num_nodes = maybe_num_nodes(edge_index, num_nodes)

    mask = perm.new_full((num_nodes, ), -1)
    i = torch.arange(perm.size(0), dtype=torch.long, device=perm.device)
    mask[perm] = i

    row, col = edge_index
    row, col = mask[row], mask[col]
    mask = (row >= 0) & (col >= 0)
    row, col = row[mask], col[mask]

    if edge_attr is not None:
        edge_attr = edge_attr[mask]

    return torch.stack([row, col], dim=0), edge_attr


class GSAPool(torch.nn.Module):

    def __init__(self, in_channels, pooling_ratio=0.5, alpha=0.6,
                        min_score=None, multiplier=1,
                        non_linearity=torch.tanh,
                        cus_drop_ratio =0):
        super(GSAPool,self).__init__()
        self.in_channels = in_channels

        self.ratio = pooling_ratio
        self.alpha = alpha

        self.sbtl_layer = GCNConv(in_channels,1)
        self.fbtl_layer = nn.Linear(in_channels, 1)
        self.fusion = GCNConv(in_channels,in_channels)

        self.min_score = min_score
        self.multiplier = multiplier
        self.fusion_flag = 0
        self.non_linearity = non_linearity

        self.dropout = torch.nn.Dropout(cus_drop_ratio)

    def conv_selection(self, conv, in_channels, conv_type=0):
        if(conv_type == 0):
            out_channels = 1
        elif(conv_type == 1):
            out_channels = in_channels
        if(conv == "GCNConv"):
            return GCNConv(in_channels,out_channels)
        elif(conv == "ChebConv"):
            return ChebConv(in_channels,out_channels,1)
        elif(conv == "SAGEConv"):
            return SAGEConv(in_channels,out_channels)
        elif(conv == "GATConv"):
            return GATConv(in_channels,out_channels, heads=1, concat=True)
        elif(conv == "GraphConv"):
            return GraphConv(in_channels,out_channels)
        else:
            raise ValueError

    def forward(self, x, edge_index, edge_attr=None, batch=None):
        if batch is None:
            batch = edge_index.new_zeros(x.size(0))
        x = x.unsqueeze(-1) if x.dim() == 1 else x

        #SBTL
        score_s = self.sbtl_layer(x,edge_index).squeeze()
        #FBTL
        score_f = self.fbtl_layer(x).squeeze()
        #hyperparametr alpha
        score = score_s*self.alpha + score_f*(1-self.alpha)

        score = score.unsqueeze(-1) if score.dim()==0 else score

        if self.min_score is None:
            score = self.non_linearity(score)
        else:
            score = softmax(score, batch)

        sc = self.dropout(score)
        perm = topk(sc, self.ratio, batch)

        #fusion
        if(self.fusion_flag == 1):
            x = self.fusion(x, edge_index)
        x_ae = x[perm]
        x = x[perm] * score[perm].view(-1, 1)
        x = self.multiplier * x if self.multiplier != 1 else x

        batch = batch[perm]
        edge_index, edge_attr = filter_adj(
            edge_index, edge_attr, perm, num_nodes=score.size(0))

        return x, edge_index, edge_attr, batch, perm, x_ae

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, EdgePooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch
from torch_geometric.nn import BatchNorm

class HierarchicalGCN_GSA(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_GSA, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)

        self.pool1 = GSAPool(64, pooling_ratio=0.5, alpha = 0.6, cus_drop_ratio = 0)
        self.pool2 = GSAPool(64, pooling_ratio=0.5, alpha = 0.6, cus_drop_ratio = 0)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, _, batch, perm_1, x_ae1 = self.pool1(x, edge_index, None, batch)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, _, batch, perm_1, x_ae1 = self.pool1(x, edge_index, None, batch)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)



num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_GSA(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_GSA(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6902, Val Acc: 0.6506, Test Acc: 0.6071
# Seed: 42, Epoch: 002, Loss: 0.6855, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 003, Loss: 0.6810, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 004, Loss: 0.6774, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 005, Loss: 0.6662, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 006, Loss: 0.6637, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 007, Loss: 0.6495, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 008, Loss: 0.6440, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 009, Loss: 0.6408, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 010, Loss: 0.6361, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 011, Loss: 0.6412, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 012, Loss: 0.6453, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 013, Loss: 0.6524, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 014, Loss: 0.6508, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 015, Loss: 0.6528, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 016, Loss: 0.6417, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 017, Loss: 0.6562, Val Acc: 0.6446, Test Acc: 0.6131
# Seed: 42, Epoch: 018, Loss: 0.6494, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 019, Loss: 0.6548, Val Acc: 0.6566, Test Acc: 0.6190
# Seed: 42, Epoch: 020, Loss: 0.6550, Val Acc: 0.6566, Test Acc: 0.6250
# Seed: 42, Epoch: 021, Loss: 0.6484, Val Acc: 0.6807, Test Acc: 0.6548
# Seed: 42, Epoch: 022, Loss: 0.6572, Val Acc: 0.6867, Test Acc: 0.6667
# Seed: 42, Epoch: 023, Loss: 0.6572, Val Acc: 0.6807, Test Acc: 0.6667
# Seed: 42, Epoch: 024, Loss: 0.6482, Val Acc: 0.6807, Test Acc: 0.6667
# Seed: 42, Epoch: 025, Loss: 0.6534, Val Acc: 0.6807, Test Acc: 0.6667
# Seed: 42, Epoch: 026, Loss: 0.6445, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 42, Epoch: 027, Loss: 0.6443, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 42, Epoch: 028, Loss: 0.6445, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 42, Epoch: 029, Loss: 0.6419, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 42, Epoch: 030, Loss: 0.6394, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 42, Epoch: 031, Loss: 0.6317, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 42, Epoch: 032, Loss: 0.6287, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 033, Loss: 0.6324, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 42, Epoch: 034, Loss: 0.6268, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 42, Epoch: 035, Loss: 0.6197, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 42, Epoch: 036, Loss: 0.6231, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 037, Loss: 0.6199, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 038, Loss: 0.6284, Val Acc: 0.7470, Test Acc: 0.7262
# Seed: 42, Epoch: 039, Loss: 0.6241, Val Acc: 0.7530, Test Acc: 0.7440
# Seed: 42, Epoch: 040, Loss: 0.6160, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 041, Loss: 0.6398, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 042, Loss: 0.6479, Val Acc: 0.6506, Test Acc: 0.7202
# Seed: 42, Epoch: 043, Loss: 0.6572, Val Acc: 0.6205, Test Acc: 0.6905
# Seed: 42, Epoch: 044, Loss: 0.6622, Val Acc: 0.6566, Test Acc: 0.7262
# Seed: 42, Epoch: 045, Loss: 0.6531, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 42, Epoch: 046, Loss: 0.6509, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 047, Loss: 0.6517, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 42, Epoch: 048, Loss: 0.6410, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 049, Loss: 0.6428, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 050, Loss: 0.6378, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 051, Loss: 0.6340, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 052, Loss: 0.6393, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 053, Loss: 0.6361, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 054, Loss: 0.6354, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 055, Loss: 0.6343, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 056, Loss: 0.6300, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 057, Loss: 0.6248, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 058, Loss: 0.6208, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 059, Loss: 0.6124, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 060, Loss: 0.6072, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 061, Loss: 0.6151, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 062, Loss: 0.6056, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 063, Loss: 0.6057, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 42, Epoch: 064, Loss: 0.5999, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 065, Loss: 0.5997, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 42, Epoch: 066, Loss: 0.6025, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 42, Epoch: 067, Loss: 0.6022, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 068, Loss: 0.6011, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 069, Loss: 0.6022, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 42, Epoch: 070, Loss: 0.6403, Val Acc: 0.6145, Test Acc: 0.6607
# Seed: 42, Epoch: 071, Loss: 0.6728, Val Acc: 0.6265, Test Acc: 0.6726
# Seed: 42, Epoch: 072, Loss: 0.6699, Val Acc: 0.6506, Test Acc: 0.7262
# Seed: 42, Epoch: 073, Loss: 0.6471, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 074, Loss: 0.6360, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 075, Loss: 0.6193, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 076, Loss: 0.6200, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 42, Epoch: 077, Loss: 0.6134, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 42, Epoch: 078, Loss: 0.6183, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 42, Epoch: 079, Loss: 0.6178, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 42, Epoch: 080, Loss: 0.6292, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 081, Loss: 0.6191, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 082, Loss: 0.6168, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 083, Loss: 0.6156, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 084, Loss: 0.6066, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 42, Epoch: 085, Loss: 0.6154, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 42, Epoch: 086, Loss: 0.6113, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 42, Epoch: 087, Loss: 0.6114, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 42, Epoch: 088, Loss: 0.6122, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 42, Epoch: 089, Loss: 0.6132, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 42, Epoch: 090, Loss: 0.6136, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 42, Epoch: 091, Loss: 0.6086, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 42, Epoch: 092, Loss: 0.5984, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 42, Epoch: 093, Loss: 0.6049, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 094, Loss: 0.6002, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 095, Loss: 0.5981, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 096, Loss: 0.6046, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 097, Loss: 0.5999, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 098, Loss: 0.6173, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 42, Epoch: 099, Loss: 0.6242, Val Acc: 0.6807, Test Acc: 0.7857
# Seed: 42, Epoch: 100, Loss: 0.6339, Val Acc: 0.6807, Test Acc: 0.7857
# Seed: 42, Epoch: 101, Loss: 0.6222, Val Acc: 0.6988, Test Acc: 0.7857
# Seed: 42, Epoch: 102, Loss: 0.6281, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 42, Epoch: 103, Loss: 0.6195, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 104, Loss: 0.6159, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 42, Epoch: 105, Loss: 0.6119, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 106, Loss: 0.6059, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 107, Loss: 0.6049, Val Acc: 0.7169, Test Acc: 0.7024
# Seed: 42, Epoch: 108, Loss: 0.5993, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 42, Epoch: 109, Loss: 0.6027, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 42, Epoch: 110, Loss: 0.5887, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 111, Loss: 0.5934, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 112, Loss: 0.6055, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 113, Loss: 0.6140, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 42, Epoch: 114, Loss: 0.6138, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 115, Loss: 0.6120, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 42, Epoch: 116, Loss: 0.6162, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 117, Loss: 0.6052, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 42, Epoch: 118, Loss: 0.5965, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 119, Loss: 0.6019, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 120, Loss: 0.5963, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 121, Loss: 0.5979, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 122, Loss: 0.5961, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 123, Loss: 0.6028, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 124, Loss: 0.6039, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 42, Epoch: 125, Loss: 0.6160, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 126, Loss: 0.6022, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 127, Loss: 0.6115, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 128, Loss: 0.6056, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 129, Loss: 0.6099, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 130, Loss: 0.6103, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 42, Epoch: 131, Loss: 0.5946, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 132, Loss: 0.6048, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 133, Loss: 0.6052, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 42, Epoch: 134, Loss: 0.6139, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 135, Loss: 0.5996, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 42, Epoch: 136, Loss: 0.6054, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 137, Loss: 0.5967, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 138, Loss: 0.6012, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 139, Loss: 0.5961, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 140, Loss: 0.6013, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 141, Loss: 0.6100, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 42, Epoch: 142, Loss: 0.5977, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 143, Loss: 0.5914, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 42, Epoch: 144, Loss: 0.5948, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 145, Loss: 0.5943, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 146, Loss: 0.5949, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 42, Epoch: 147, Loss: 0.5954, Val Acc: 0.7410, Test Acc: 0.7560
# Seed: 42, Epoch: 148, Loss: 0.5984, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 149, Loss: 0.5971, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 150, Loss: 0.5933, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 151, Loss: 0.6015, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 152, Loss: 0.5984, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 153, Loss: 0.5955, Val Acc: 0.7048, Test Acc: 0.8095
# Seed: 42, Epoch: 154, Loss: 0.6186, Val Acc: 0.7108, Test Acc: 0.8095
# Seed: 42, Epoch: 155, Loss: 0.6107, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 42, Epoch: 156, Loss: 0.6020, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 42, Epoch: 157, Loss: 0.5970, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 158, Loss: 0.5967, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 159, Loss: 0.5878, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 160, Loss: 0.5941, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 161, Loss: 0.5887, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 42, Epoch: 162, Loss: 0.5803, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 163, Loss: 0.5884, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 164, Loss: 0.5949, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 42, Epoch: 165, Loss: 0.5835, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 166, Loss: 0.5939, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 167, Loss: 0.5878, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 168, Loss: 0.5832, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 42, Epoch: 169, Loss: 0.5788, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 170, Loss: 0.5782, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 171, Loss: 0.5771, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 172, Loss: 0.5713, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 173, Loss: 0.5751, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 42, Epoch: 174, Loss: 0.5809, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 175, Loss: 0.5685, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 176, Loss: 0.5785, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 177, Loss: 0.5675, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 178, Loss: 0.5641, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 42, Epoch: 179, Loss: 0.5768, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 42, Epoch: 180, Loss: 0.5821, Val Acc: 0.6988, Test Acc: 0.7917
# Seed: 42, Epoch: 181, Loss: 0.6031, Val Acc: 0.6928, Test Acc: 0.8036
# Seed: 42, Epoch: 182, Loss: 0.6218, Val Acc: 0.7048, Test Acc: 0.7976
# Seed: 42, Epoch: 183, Loss: 0.5952, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 42, Epoch: 184, Loss: 0.5864, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 42, Epoch: 185, Loss: 0.5826, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 186, Loss: 0.5793, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 187, Loss: 0.5827, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 42, Epoch: 188, Loss: 0.5796, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 189, Loss: 0.5910, Val Acc: 0.7108, Test Acc: 0.7381
# Early stopping at epoch 189 for seed 42
# Seed: 43, Epoch: 001, Loss: 0.6975, Val Acc: 0.5783, Test Acc: 0.6488
# Seed: 43, Epoch: 002, Loss: 0.6758, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 43, Epoch: 003, Loss: 0.6649, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 43, Epoch: 004, Loss: 0.6518, Val Acc: 0.6687, Test Acc: 0.6310
# Seed: 43, Epoch: 005, Loss: 0.6501, Val Acc: 0.6687, Test Acc: 0.6310
# Seed: 43, Epoch: 006, Loss: 0.6470, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 43, Epoch: 007, Loss: 0.6494, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 43, Epoch: 008, Loss: 0.6483, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 43, Epoch: 009, Loss: 0.6400, Val Acc: 0.6867, Test Acc: 0.6429
# Seed: 43, Epoch: 010, Loss: 0.6427, Val Acc: 0.6807, Test Acc: 0.6488
# Seed: 43, Epoch: 011, Loss: 0.6380, Val Acc: 0.6928, Test Acc: 0.6667
# Seed: 43, Epoch: 012, Loss: 0.6425, Val Acc: 0.6928, Test Acc: 0.6667
# Seed: 43, Epoch: 013, Loss: 0.6382, Val Acc: 0.6928, Test Acc: 0.6548
# Seed: 43, Epoch: 014, Loss: 0.6429, Val Acc: 0.6988, Test Acc: 0.6548
# Seed: 43, Epoch: 015, Loss: 0.6383, Val Acc: 0.6867, Test Acc: 0.6548
# Seed: 43, Epoch: 016, Loss: 0.6364, Val Acc: 0.6988, Test Acc: 0.6548
# Seed: 43, Epoch: 017, Loss: 0.6329, Val Acc: 0.7349, Test Acc: 0.7083
# Seed: 43, Epoch: 018, Loss: 0.6360, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 019, Loss: 0.6435, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 43, Epoch: 020, Loss: 0.6395, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 43, Epoch: 021, Loss: 0.6367, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 43, Epoch: 022, Loss: 0.6421, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 43, Epoch: 023, Loss: 0.6386, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 024, Loss: 0.6300, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 43, Epoch: 025, Loss: 0.6423, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 43, Epoch: 026, Loss: 0.6405, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 43, Epoch: 027, Loss: 0.6319, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 43, Epoch: 028, Loss: 0.6349, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 43, Epoch: 029, Loss: 0.6353, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 43, Epoch: 030, Loss: 0.6244, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 43, Epoch: 031, Loss: 0.6267, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 43, Epoch: 032, Loss: 0.6322, Val Acc: 0.7349, Test Acc: 0.7083
# Seed: 43, Epoch: 033, Loss: 0.6237, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 034, Loss: 0.6403, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 43, Epoch: 035, Loss: 0.6413, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 036, Loss: 0.6400, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 43, Epoch: 037, Loss: 0.6402, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 43, Epoch: 038, Loss: 0.6502, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 43, Epoch: 039, Loss: 0.6606, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 040, Loss: 0.6464, Val Acc: 0.6867, Test Acc: 0.7202
# Seed: 43, Epoch: 041, Loss: 0.6542, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 43, Epoch: 042, Loss: 0.6492, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 043, Loss: 0.6353, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 43, Epoch: 044, Loss: 0.6394, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 045, Loss: 0.6386, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 046, Loss: 0.6339, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 43, Epoch: 047, Loss: 0.6375, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 43, Epoch: 048, Loss: 0.6337, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 049, Loss: 0.6344, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 050, Loss: 0.6359, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 051, Loss: 0.6337, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 052, Loss: 0.6357, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 053, Loss: 0.6291, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 43, Epoch: 054, Loss: 0.6176, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 055, Loss: 0.6280, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 43, Epoch: 056, Loss: 0.6384, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 43, Epoch: 057, Loss: 0.6281, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 058, Loss: 0.6292, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 059, Loss: 0.6325, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 060, Loss: 0.6348, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 43, Epoch: 061, Loss: 0.6313, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 43, Epoch: 062, Loss: 0.6337, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 063, Loss: 0.6444, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 43, Epoch: 064, Loss: 0.6402, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 43, Epoch: 065, Loss: 0.6358, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 43, Epoch: 066, Loss: 0.6304, Val Acc: 0.7289, Test Acc: 0.6905
# Seed: 43, Epoch: 067, Loss: 0.6330, Val Acc: 0.7169, Test Acc: 0.6845
# Seed: 43, Epoch: 068, Loss: 0.6311, Val Acc: 0.7349, Test Acc: 0.6905
# Seed: 43, Epoch: 069, Loss: 0.6257, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 43, Epoch: 070, Loss: 0.6287, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 43, Epoch: 071, Loss: 0.6320, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 072, Loss: 0.6264, Val Acc: 0.7048, Test Acc: 0.7024
# Seed: 43, Epoch: 073, Loss: 0.6249, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 43, Epoch: 074, Loss: 0.6239, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 43, Epoch: 075, Loss: 0.6231, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 43, Epoch: 076, Loss: 0.6121, Val Acc: 0.7169, Test Acc: 0.6964
# Seed: 43, Epoch: 077, Loss: 0.6188, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 43, Epoch: 078, Loss: 0.6147, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 43, Epoch: 079, Loss: 0.6182, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 43, Epoch: 080, Loss: 0.6153, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 43, Epoch: 081, Loss: 0.6206, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 43, Epoch: 082, Loss: 0.6272, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 083, Loss: 0.6301, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 084, Loss: 0.6529, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 085, Loss: 0.6458, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 086, Loss: 0.6314, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 43, Epoch: 087, Loss: 0.6241, Val Acc: 0.7048, Test Acc: 0.6845
# Seed: 43, Epoch: 088, Loss: 0.6183, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 43, Epoch: 089, Loss: 0.6212, Val Acc: 0.6988, Test Acc: 0.6548
# Seed: 43, Epoch: 090, Loss: 0.6157, Val Acc: 0.7229, Test Acc: 0.6786
# Seed: 43, Epoch: 091, Loss: 0.6196, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 43, Epoch: 092, Loss: 0.6181, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 43, Epoch: 093, Loss: 0.6195, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 43, Epoch: 094, Loss: 0.6155, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 095, Loss: 0.6170, Val Acc: 0.7349, Test Acc: 0.7083
# Seed: 43, Epoch: 096, Loss: 0.6119, Val Acc: 0.7229, Test Acc: 0.6845
# Seed: 43, Epoch: 097, Loss: 0.6135, Val Acc: 0.7289, Test Acc: 0.6845
# Seed: 43, Epoch: 098, Loss: 0.6090, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 43, Epoch: 099, Loss: 0.6126, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 43, Epoch: 100, Loss: 0.6141, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 43, Epoch: 101, Loss: 0.6141, Val Acc: 0.7108, Test Acc: 0.6905
# Seed: 43, Epoch: 102, Loss: 0.6220, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 43, Epoch: 103, Loss: 0.6034, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 43, Epoch: 104, Loss: 0.6144, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 105, Loss: 0.6256, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 43, Epoch: 106, Loss: 0.6200, Val Acc: 0.7590, Test Acc: 0.7381
# Seed: 43, Epoch: 107, Loss: 0.6064, Val Acc: 0.7530, Test Acc: 0.7143
# Seed: 43, Epoch: 108, Loss: 0.6112, Val Acc: 0.7530, Test Acc: 0.7143
# Seed: 43, Epoch: 109, Loss: 0.6088, Val Acc: 0.7349, Test Acc: 0.7083
# Seed: 43, Epoch: 110, Loss: 0.6060, Val Acc: 0.7530, Test Acc: 0.7083
# Seed: 43, Epoch: 111, Loss: 0.6067, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 112, Loss: 0.6188, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 113, Loss: 0.6077, Val Acc: 0.7590, Test Acc: 0.7500
# Seed: 43, Epoch: 114, Loss: 0.6196, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 115, Loss: 0.6069, Val Acc: 0.7590, Test Acc: 0.7679
# Seed: 43, Epoch: 116, Loss: 0.6054, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 43, Epoch: 117, Loss: 0.5926, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 43, Epoch: 118, Loss: 0.5945, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 43, Epoch: 119, Loss: 0.5900, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 120, Loss: 0.5972, Val Acc: 0.7530, Test Acc: 0.7500
# Seed: 43, Epoch: 121, Loss: 0.6049, Val Acc: 0.7651, Test Acc: 0.7440
# Seed: 43, Epoch: 122, Loss: 0.6056, Val Acc: 0.7590, Test Acc: 0.7738
# Seed: 43, Epoch: 123, Loss: 0.5951, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 43, Epoch: 124, Loss: 0.5913, Val Acc: 0.7530, Test Acc: 0.7024
# Seed: 43, Epoch: 125, Loss: 0.5895, Val Acc: 0.7470, Test Acc: 0.6845
# Seed: 43, Epoch: 126, Loss: 0.5888, Val Acc: 0.7349, Test Acc: 0.6607
# Seed: 43, Epoch: 127, Loss: 0.5865, Val Acc: 0.7410, Test Acc: 0.6607
# Seed: 43, Epoch: 128, Loss: 0.5878, Val Acc: 0.7470, Test Acc: 0.6905
# Seed: 43, Epoch: 129, Loss: 0.5807, Val Acc: 0.7530, Test Acc: 0.7440
# Seed: 43, Epoch: 130, Loss: 0.6138, Val Acc: 0.7530, Test Acc: 0.7440
# Seed: 43, Epoch: 131, Loss: 0.5902, Val Acc: 0.7349, Test Acc: 0.6726
# Seed: 43, Epoch: 132, Loss: 0.5868, Val Acc: 0.7349, Test Acc: 0.6667
# Seed: 43, Epoch: 133, Loss: 0.5840, Val Acc: 0.7349, Test Acc: 0.6905
# Seed: 43, Epoch: 134, Loss: 0.5845, Val Acc: 0.7590, Test Acc: 0.7202
# Seed: 43, Epoch: 135, Loss: 0.5846, Val Acc: 0.7590, Test Acc: 0.7202
# Seed: 43, Epoch: 136, Loss: 0.5865, Val Acc: 0.7590, Test Acc: 0.7381
# Seed: 43, Epoch: 137, Loss: 0.5828, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 138, Loss: 0.5910, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 43, Epoch: 139, Loss: 0.5887, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 43, Epoch: 140, Loss: 0.5817, Val Acc: 0.7530, Test Acc: 0.7024
# Seed: 43, Epoch: 141, Loss: 0.5736, Val Acc: 0.7651, Test Acc: 0.7262
# Seed: 43, Epoch: 142, Loss: 0.5773, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 43, Epoch: 143, Loss: 0.6005, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 43, Epoch: 144, Loss: 0.6023, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 43, Epoch: 145, Loss: 0.5822, Val Acc: 0.7651, Test Acc: 0.7143
# Seed: 43, Epoch: 146, Loss: 0.5880, Val Acc: 0.7530, Test Acc: 0.7202
# Seed: 43, Epoch: 147, Loss: 0.6195, Val Acc: 0.7771, Test Acc: 0.7321
# Seed: 43, Epoch: 148, Loss: 0.5866, Val Acc: 0.7530, Test Acc: 0.7024
# Seed: 43, Epoch: 149, Loss: 0.5915, Val Acc: 0.7530, Test Acc: 0.6786
# Seed: 43, Epoch: 150, Loss: 0.6060, Val Acc: 0.7470, Test Acc: 0.7083
# Seed: 43, Epoch: 151, Loss: 0.6069, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 43, Epoch: 152, Loss: 0.6053, Val Acc: 0.7410, Test Acc: 0.7083
# Seed: 43, Epoch: 153, Loss: 0.6024, Val Acc: 0.7410, Test Acc: 0.7202
# Seed: 43, Epoch: 154, Loss: 0.5911, Val Acc: 0.7470, Test Acc: 0.7143
# Seed: 43, Epoch: 155, Loss: 0.5923, Val Acc: 0.7470, Test Acc: 0.7143
# Seed: 43, Epoch: 156, Loss: 0.5880, Val Acc: 0.7410, Test Acc: 0.6845
# Seed: 43, Epoch: 157, Loss: 0.6110, Val Acc: 0.7289, Test Acc: 0.6845
# Seed: 43, Epoch: 158, Loss: 0.5872, Val Acc: 0.7470, Test Acc: 0.6786
# Seed: 43, Epoch: 159, Loss: 0.5837, Val Acc: 0.7651, Test Acc: 0.7440
# Seed: 43, Epoch: 160, Loss: 0.6094, Val Acc: 0.7530, Test Acc: 0.7500
# Seed: 43, Epoch: 161, Loss: 0.6037, Val Acc: 0.7229, Test Acc: 0.6667
# Seed: 43, Epoch: 162, Loss: 0.5786, Val Acc: 0.7169, Test Acc: 0.6429
# Seed: 43, Epoch: 163, Loss: 0.5923, Val Acc: 0.7048, Test Acc: 0.6488
# Seed: 43, Epoch: 164, Loss: 0.5886, Val Acc: 0.7289, Test Acc: 0.6786
# Seed: 43, Epoch: 165, Loss: 0.5868, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 43, Epoch: 166, Loss: 0.5864, Val Acc: 0.7590, Test Acc: 0.7381
# Seed: 43, Epoch: 167, Loss: 0.5955, Val Acc: 0.7711, Test Acc: 0.7321
# Seed: 43, Epoch: 168, Loss: 0.6020, Val Acc: 0.7711, Test Acc: 0.7560
# Seed: 43, Epoch: 169, Loss: 0.5980, Val Acc: 0.7771, Test Acc: 0.7619
# Seed: 43, Epoch: 170, Loss: 0.5987, Val Acc: 0.7771, Test Acc: 0.7619
# Seed: 43, Epoch: 171, Loss: 0.5967, Val Acc: 0.7831, Test Acc: 0.7381
# Seed: 43, Epoch: 172, Loss: 0.5942, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 43, Epoch: 173, Loss: 0.5901, Val Acc: 0.7530, Test Acc: 0.7202
# Seed: 43, Epoch: 174, Loss: 0.5811, Val Acc: 0.7530, Test Acc: 0.7083
# Seed: 43, Epoch: 175, Loss: 0.5901, Val Acc: 0.7771, Test Acc: 0.7500
# Seed: 43, Epoch: 176, Loss: 0.5830, Val Acc: 0.7771, Test Acc: 0.7619
# Seed: 43, Epoch: 177, Loss: 0.5851, Val Acc: 0.7651, Test Acc: 0.7560
# Seed: 43, Epoch: 178, Loss: 0.5866, Val Acc: 0.7651, Test Acc: 0.7381
# Seed: 43, Epoch: 179, Loss: 0.5813, Val Acc: 0.7470, Test Acc: 0.7262
# Seed: 43, Epoch: 180, Loss: 0.5751, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 43, Epoch: 181, Loss: 0.5708, Val Acc: 0.7349, Test Acc: 0.6845
# Seed: 43, Epoch: 182, Loss: 0.5695, Val Acc: 0.7289, Test Acc: 0.6726
# Seed: 43, Epoch: 183, Loss: 0.5858, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 43, Epoch: 184, Loss: 0.5979, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 43, Epoch: 185, Loss: 0.5957, Val Acc: 0.7048, Test Acc: 0.6548
# Seed: 43, Epoch: 186, Loss: 0.5897, Val Acc: 0.7108, Test Acc: 0.6607
# Seed: 43, Epoch: 187, Loss: 0.5936, Val Acc: 0.7470, Test Acc: 0.7083
# Seed: 43, Epoch: 188, Loss: 0.5754, Val Acc: 0.7349, Test Acc: 0.7143
# Seed: 43, Epoch: 189, Loss: 0.5753, Val Acc: 0.7410, Test Acc: 0.7202
# Seed: 43, Epoch: 190, Loss: 0.5789, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 43, Epoch: 191, Loss: 0.5775, Val Acc: 0.7590, Test Acc: 0.7500
# Seed: 43, Epoch: 192, Loss: 0.5871, Val Acc: 0.7530, Test Acc: 0.7619
# Seed: 43, Epoch: 193, Loss: 0.5933, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 43, Epoch: 194, Loss: 0.5695, Val Acc: 0.7048, Test Acc: 0.6548
# Seed: 43, Epoch: 195, Loss: 0.5797, Val Acc: 0.6988, Test Acc: 0.6310
# Seed: 43, Epoch: 196, Loss: 0.6011, Val Acc: 0.6988, Test Acc: 0.6310
# Seed: 43, Epoch: 197, Loss: 0.5895, Val Acc: 0.7108, Test Acc: 0.6369
# Seed: 43, Epoch: 198, Loss: 0.5802, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 43, Epoch: 199, Loss: 0.5888, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 43, Epoch: 200, Loss: 0.6074, Val Acc: 0.7590, Test Acc: 0.7440
# Seed: 44, Epoch: 001, Loss: 0.6928, Val Acc: 0.6566, Test Acc: 0.7202
# Seed: 44, Epoch: 002, Loss: 0.6497, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 003, Loss: 0.6433, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 004, Loss: 0.6279, Val Acc: 0.6867, Test Acc: 0.6786
# Seed: 44, Epoch: 005, Loss: 0.6338, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 44, Epoch: 006, Loss: 0.6277, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 007, Loss: 0.6333, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 008, Loss: 0.6509, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 009, Loss: 0.6552, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 44, Epoch: 010, Loss: 0.6590, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 44, Epoch: 011, Loss: 0.6452, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 012, Loss: 0.6467, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 013, Loss: 0.6498, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 014, Loss: 0.6591, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 44, Epoch: 015, Loss: 0.6560, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 016, Loss: 0.6561, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 017, Loss: 0.6599, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 018, Loss: 0.6394, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 019, Loss: 0.6352, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 020, Loss: 0.6406, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 021, Loss: 0.6380, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 022, Loss: 0.6401, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 023, Loss: 0.6336, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 44, Epoch: 024, Loss: 0.6255, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 025, Loss: 0.6245, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 026, Loss: 0.6312, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 027, Loss: 0.6365, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 028, Loss: 0.6294, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 029, Loss: 0.6323, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 030, Loss: 0.6259, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 031, Loss: 0.6254, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 032, Loss: 0.6256, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 44, Epoch: 033, Loss: 0.6067, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 034, Loss: 0.6189, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 44, Epoch: 035, Loss: 0.6320, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 44, Epoch: 036, Loss: 0.6204, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 037, Loss: 0.6340, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 038, Loss: 0.6298, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 44, Epoch: 039, Loss: 0.6338, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 44, Epoch: 040, Loss: 0.6459, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 44, Epoch: 041, Loss: 0.6368, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 44, Epoch: 042, Loss: 0.6308, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 44, Epoch: 043, Loss: 0.6412, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 044, Loss: 0.6366, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 045, Loss: 0.6268, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 046, Loss: 0.6290, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 047, Loss: 0.6203, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 048, Loss: 0.6249, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 049, Loss: 0.6186, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 050, Loss: 0.6198, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 051, Loss: 0.6180, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 052, Loss: 0.6111, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 44, Epoch: 053, Loss: 0.6104, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 054, Loss: 0.6142, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 055, Loss: 0.6022, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 056, Loss: 0.5999, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 057, Loss: 0.6030, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 44, Epoch: 058, Loss: 0.5961, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 44, Epoch: 059, Loss: 0.6017, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 44, Epoch: 060, Loss: 0.5945, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 44, Epoch: 061, Loss: 0.5971, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 062, Loss: 0.6084, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 063, Loss: 0.6049, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 064, Loss: 0.6011, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 065, Loss: 0.6076, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 066, Loss: 0.6018, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 067, Loss: 0.5984, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 068, Loss: 0.6048, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 44, Epoch: 069, Loss: 0.5955, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 070, Loss: 0.6080, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 44, Epoch: 071, Loss: 0.6145, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 44, Epoch: 072, Loss: 0.6279, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 44, Epoch: 073, Loss: 0.6597, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 44, Epoch: 074, Loss: 0.6429, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 44, Epoch: 075, Loss: 0.6281, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 076, Loss: 0.6193, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 077, Loss: 0.6209, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 44, Epoch: 078, Loss: 0.6199, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 079, Loss: 0.6258, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 080, Loss: 0.6221, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 081, Loss: 0.6235, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 082, Loss: 0.6203, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 083, Loss: 0.6154, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 084, Loss: 0.6138, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 44, Epoch: 085, Loss: 0.6089, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 44, Epoch: 086, Loss: 0.6092, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 087, Loss: 0.6120, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 088, Loss: 0.6012, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 44, Epoch: 089, Loss: 0.6047, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 090, Loss: 0.6127, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 44, Epoch: 091, Loss: 0.6138, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 44, Epoch: 092, Loss: 0.6055, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 44, Epoch: 093, Loss: 0.6087, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 44, Epoch: 094, Loss: 0.6038, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 095, Loss: 0.6009, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 096, Loss: 0.5961, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 44, Epoch: 097, Loss: 0.5939, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 098, Loss: 0.5883, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 099, Loss: 0.5883, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 44, Epoch: 100, Loss: 0.6055, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 101, Loss: 0.6033, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 44, Epoch: 102, Loss: 0.6046, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 44, Epoch: 103, Loss: 0.6304, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 44, Epoch: 104, Loss: 0.6315, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 44, Epoch: 105, Loss: 0.6152, Val Acc: 0.6687, Test Acc: 0.7440
# Seed: 44, Epoch: 106, Loss: 0.6044, Val Acc: 0.6566, Test Acc: 0.7321
# Seed: 44, Epoch: 107, Loss: 0.5985, Val Acc: 0.6627, Test Acc: 0.7143
# Seed: 44, Epoch: 108, Loss: 0.5915, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 44, Epoch: 109, Loss: 0.5950, Val Acc: 0.6747, Test Acc: 0.7083
# Seed: 44, Epoch: 110, Loss: 0.5930, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 44, Epoch: 111, Loss: 0.5875, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 44, Epoch: 112, Loss: 0.5842, Val Acc: 0.6687, Test Acc: 0.7083
# Seed: 44, Epoch: 113, Loss: 0.5890, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 44, Epoch: 114, Loss: 0.5870, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 44, Epoch: 115, Loss: 0.5951, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 44, Epoch: 116, Loss: 0.5855, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 44, Epoch: 117, Loss: 0.5958, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 44, Epoch: 118, Loss: 0.5960, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 44, Epoch: 119, Loss: 0.5998, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 44, Epoch: 120, Loss: 0.5844, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 121, Loss: 0.5774, Val Acc: 0.6566, Test Acc: 0.7143
# Seed: 44, Epoch: 122, Loss: 0.5732, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 44, Epoch: 123, Loss: 0.5779, Val Acc: 0.6687, Test Acc: 0.7083
# Seed: 44, Epoch: 124, Loss: 0.5748, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 44, Epoch: 125, Loss: 0.5825, Val Acc: 0.6687, Test Acc: 0.7143
# Seed: 44, Epoch: 126, Loss: 0.5756, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 44, Epoch: 127, Loss: 0.5843, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 44, Epoch: 128, Loss: 0.6020, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 44, Epoch: 129, Loss: 0.6044, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 130, Loss: 0.5985, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 131, Loss: 0.5952, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 132, Loss: 0.5986, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 44, Epoch: 133, Loss: 0.6040, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 134, Loss: 0.6014, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 135, Loss: 0.5881, Val Acc: 0.6566, Test Acc: 0.7500
# Seed: 44, Epoch: 136, Loss: 0.5987, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 44, Epoch: 137, Loss: 0.5867, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 44, Epoch: 138, Loss: 0.5882, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 44, Epoch: 139, Loss: 0.5859, Val Acc: 0.6566, Test Acc: 0.7083
# Seed: 44, Epoch: 140, Loss: 0.5834, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 44, Epoch: 141, Loss: 0.5857, Val Acc: 0.6566, Test Acc: 0.7083
# Seed: 44, Epoch: 142, Loss: 0.5812, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 44, Epoch: 143, Loss: 0.5767, Val Acc: 0.6566, Test Acc: 0.7321
# Seed: 44, Epoch: 144, Loss: 0.5796, Val Acc: 0.6627, Test Acc: 0.7083
# Seed: 44, Epoch: 145, Loss: 0.5785, Val Acc: 0.6566, Test Acc: 0.7083
# Seed: 44, Epoch: 146, Loss: 0.5781, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 44, Epoch: 147, Loss: 0.5900, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 44, Epoch: 148, Loss: 0.6218, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 44, Epoch: 149, Loss: 0.5911, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 44, Epoch: 150, Loss: 0.5799, Val Acc: 0.6566, Test Acc: 0.7321
# Seed: 44, Epoch: 151, Loss: 0.5741, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 44, Epoch: 152, Loss: 0.5737, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 44, Epoch: 153, Loss: 0.5805, Val Acc: 0.6687, Test Acc: 0.6964
# Seed: 44, Epoch: 154, Loss: 0.5757, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 44, Epoch: 155, Loss: 0.5725, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 44, Epoch: 156, Loss: 0.5810, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 157, Loss: 0.5767, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 44, Epoch: 158, Loss: 0.6105, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 159, Loss: 0.6089, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 160, Loss: 0.5912, Val Acc: 0.6566, Test Acc: 0.7381
# Seed: 44, Epoch: 161, Loss: 0.5879, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 44, Epoch: 162, Loss: 0.5733, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 44, Epoch: 163, Loss: 0.5828, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 164, Loss: 0.5795, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 44, Epoch: 165, Loss: 0.5824, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 44, Epoch: 166, Loss: 0.5639, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 44, Epoch: 167, Loss: 0.5843, Val Acc: 0.6687, Test Acc: 0.7202
# Seed: 44, Epoch: 168, Loss: 0.5833, Val Acc: 0.6446, Test Acc: 0.7500
# Seed: 44, Epoch: 169, Loss: 0.5807, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 44, Epoch: 170, Loss: 0.5784, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 44, Epoch: 171, Loss: 0.5753, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 44, Epoch: 172, Loss: 0.5820, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 44, Epoch: 173, Loss: 0.5812, Val Acc: 0.6687, Test Acc: 0.7321
# Early stopping at epoch 173 for seed 44
# Seed: 45, Epoch: 001, Loss: 0.6880, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 002, Loss: 0.6658, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 003, Loss: 0.6491, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 004, Loss: 0.6415, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 005, Loss: 0.6423, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 006, Loss: 0.6412, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 007, Loss: 0.6489, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 008, Loss: 0.6447, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 009, Loss: 0.6486, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 010, Loss: 0.6437, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 011, Loss: 0.6429, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 45, Epoch: 012, Loss: 0.6536, Val Acc: 0.6747, Test Acc: 0.6310
# Seed: 45, Epoch: 013, Loss: 0.6529, Val Acc: 0.6807, Test Acc: 0.6607
# Seed: 45, Epoch: 014, Loss: 0.6531, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 45, Epoch: 015, Loss: 0.6613, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 45, Epoch: 016, Loss: 0.6559, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 45, Epoch: 017, Loss: 0.6513, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 018, Loss: 0.6534, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 45, Epoch: 019, Loss: 0.6443, Val Acc: 0.6747, Test Acc: 0.6726
# Seed: 45, Epoch: 020, Loss: 0.6414, Val Acc: 0.6807, Test Acc: 0.6607
# Seed: 45, Epoch: 021, Loss: 0.6399, Val Acc: 0.6807, Test Acc: 0.6548
# Seed: 45, Epoch: 022, Loss: 0.6322, Val Acc: 0.6807, Test Acc: 0.6607
# Seed: 45, Epoch: 023, Loss: 0.6343, Val Acc: 0.6747, Test Acc: 0.6726
# Seed: 45, Epoch: 024, Loss: 0.6285, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 025, Loss: 0.6309, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 026, Loss: 0.6230, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 45, Epoch: 027, Loss: 0.6282, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 45, Epoch: 028, Loss: 0.6290, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 45, Epoch: 029, Loss: 0.6277, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 030, Loss: 0.6228, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 45, Epoch: 031, Loss: 0.6253, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 45, Epoch: 032, Loss: 0.6316, Val Acc: 0.6506, Test Acc: 0.7440
# Seed: 45, Epoch: 033, Loss: 0.6243, Val Acc: 0.6566, Test Acc: 0.7857
# Seed: 45, Epoch: 034, Loss: 0.6094, Val Acc: 0.6506, Test Acc: 0.7798
# Seed: 45, Epoch: 035, Loss: 0.6196, Val Acc: 0.6627, Test Acc: 0.7679
# Seed: 45, Epoch: 036, Loss: 0.6119, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 45, Epoch: 037, Loss: 0.6089, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 45, Epoch: 038, Loss: 0.6041, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 039, Loss: 0.5994, Val Acc: 0.6446, Test Acc: 0.7560
# Seed: 45, Epoch: 040, Loss: 0.6189, Val Acc: 0.6145, Test Acc: 0.7440
# Seed: 45, Epoch: 041, Loss: 0.6170, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 45, Epoch: 042, Loss: 0.5930, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 45, Epoch: 043, Loss: 0.5924, Val Acc: 0.6807, Test Acc: 0.7143
# Seed: 45, Epoch: 044, Loss: 0.5965, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 45, Epoch: 045, Loss: 0.5948, Val Acc: 0.6566, Test Acc: 0.7500
# Seed: 45, Epoch: 046, Loss: 0.5930, Val Acc: 0.6807, Test Acc: 0.7202
# Seed: 45, Epoch: 047, Loss: 0.5926, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 45, Epoch: 048, Loss: 0.6108, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 45, Epoch: 049, Loss: 0.6061, Val Acc: 0.6506, Test Acc: 0.7798
# Seed: 45, Epoch: 050, Loss: 0.6202, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 45, Epoch: 051, Loss: 0.6312, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 45, Epoch: 052, Loss: 0.6474, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 45, Epoch: 053, Loss: 0.6331, Val Acc: 0.6446, Test Acc: 0.7560
# Seed: 45, Epoch: 054, Loss: 0.6366, Val Acc: 0.6205, Test Acc: 0.7440
# Seed: 45, Epoch: 055, Loss: 0.6291, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 45, Epoch: 056, Loss: 0.6097, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 45, Epoch: 057, Loss: 0.6099, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 45, Epoch: 058, Loss: 0.5987, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 45, Epoch: 059, Loss: 0.5992, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 45, Epoch: 060, Loss: 0.6107, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 45, Epoch: 061, Loss: 0.5994, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 45, Epoch: 062, Loss: 0.6130, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 063, Loss: 0.6192, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 45, Epoch: 064, Loss: 0.6192, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 45, Epoch: 065, Loss: 0.6286, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 45, Epoch: 066, Loss: 0.6255, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 45, Epoch: 067, Loss: 0.6219, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 45, Epoch: 068, Loss: 0.6140, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 45, Epoch: 069, Loss: 0.6085, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 45, Epoch: 070, Loss: 0.6085, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 45, Epoch: 071, Loss: 0.5960, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 45, Epoch: 072, Loss: 0.6004, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 45, Epoch: 073, Loss: 0.6210, Val Acc: 0.6506, Test Acc: 0.7857
# Seed: 45, Epoch: 074, Loss: 0.6036, Val Acc: 0.6687, Test Acc: 0.7381
# Seed: 45, Epoch: 075, Loss: 0.5907, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 45, Epoch: 076, Loss: 0.5840, Val Acc: 0.6747, Test Acc: 0.7202
# Seed: 45, Epoch: 077, Loss: 0.5868, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 45, Epoch: 078, Loss: 0.6110, Val Acc: 0.5904, Test Acc: 0.7321
# Seed: 45, Epoch: 079, Loss: 0.6490, Val Acc: 0.6506, Test Acc: 0.7679
# Seed: 45, Epoch: 080, Loss: 0.6012, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 45, Epoch: 081, Loss: 0.5863, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 45, Epoch: 082, Loss: 0.5882, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 45, Epoch: 083, Loss: 0.5954, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 45, Epoch: 084, Loss: 0.6152, Val Acc: 0.6265, Test Acc: 0.7619
# Seed: 45, Epoch: 085, Loss: 0.6363, Val Acc: 0.6084, Test Acc: 0.7440
# Seed: 45, Epoch: 086, Loss: 0.6425, Val Acc: 0.6687, Test Acc: 0.7798
# Seed: 45, Epoch: 087, Loss: 0.6172, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 45, Epoch: 088, Loss: 0.5993, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 45, Epoch: 089, Loss: 0.5971, Val Acc: 0.6687, Test Acc: 0.7262
# Seed: 45, Epoch: 090, Loss: 0.5939, Val Acc: 0.6506, Test Acc: 0.7143
# Seed: 45, Epoch: 091, Loss: 0.5911, Val Acc: 0.6566, Test Acc: 0.7143
# Seed: 45, Epoch: 092, Loss: 0.5873, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 45, Epoch: 093, Loss: 0.5856, Val Acc: 0.6687, Test Acc: 0.7321
# Seed: 45, Epoch: 094, Loss: 0.5831, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 45, Epoch: 095, Loss: 0.5767, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 45, Epoch: 096, Loss: 0.5765, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 45, Epoch: 097, Loss: 0.5795, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 45, Epoch: 098, Loss: 0.5985, Val Acc: 0.6506, Test Acc: 0.7798
# Seed: 45, Epoch: 099, Loss: 0.6142, Val Acc: 0.6506, Test Acc: 0.7798
# Seed: 45, Epoch: 100, Loss: 0.6036, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 45, Epoch: 101, Loss: 0.6029, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 45, Epoch: 102, Loss: 0.5908, Val Acc: 0.6747, Test Acc: 0.7321
# Seed: 45, Epoch: 103, Loss: 0.5905, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 104, Loss: 0.5850, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 45, Epoch: 105, Loss: 0.5875, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 45, Epoch: 106, Loss: 0.5807, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 45, Epoch: 107, Loss: 0.5811, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 45, Epoch: 108, Loss: 0.5805, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 45, Epoch: 109, Loss: 0.5805, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 45, Epoch: 110, Loss: 0.5734, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 45, Epoch: 111, Loss: 0.5847, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 112, Loss: 0.5909, Val Acc: 0.6627, Test Acc: 0.7738
# Seed: 45, Epoch: 113, Loss: 0.6079, Val Acc: 0.6506, Test Acc: 0.7738
# Seed: 45, Epoch: 114, Loss: 0.6319, Val Acc: 0.6627, Test Acc: 0.7738
# Seed: 45, Epoch: 115, Loss: 0.6143, Val Acc: 0.6687, Test Acc: 0.7738
# Seed: 45, Epoch: 116, Loss: 0.5922, Val Acc: 0.6687, Test Acc: 0.7500
# Seed: 45, Epoch: 117, Loss: 0.5858, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 118, Loss: 0.5861, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 119, Loss: 0.5911, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 45, Epoch: 120, Loss: 0.5893, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 45, Epoch: 121, Loss: 0.5953, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 45, Epoch: 122, Loss: 0.5922, Val Acc: 0.6807, Test Acc: 0.7560
# ...
# Seed: 45, Epoch: 152, Loss: 0.5760, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 45, Epoch: 153, Loss: 0.5771, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 45, Epoch: 154, Loss: 0.5775, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 155, Loss: 0.5736, Val Acc: 0.6807, Test Acc: 0.7500
# Seed: 45, Epoch: 156, Loss: 0.5733, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 45, Epoch: 157, Loss: 0.5737, Val Acc: 0.6747, Test Acc: 0.7917
# Seed: 45, Epoch: 158, Loss: 0.5822, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 45, Epoch: 159, Loss: 0.5763, Val Acc: 0.6687, Test Acc: 0.7798
# Seed: 45, Epoch: 160, Loss: 0.5731, Val Acc: 0.6687, Test Acc: 0.7738
# Seed: 45, Epoch: 161, Loss: 0.5810, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 45, Epoch: 162, Loss: 0.5816, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 45, Epoch: 163, Loss: 0.5811, Val Acc: 0.6747, Test Acc: 0.7738
# Seed: 45, Epoch: 164, Loss: 0.5797, Val Acc: 0.6747, Test Acc: 0.7679
# Seed: 45, Epoch: 165, Loss: 0.5757, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 45, Epoch: 166, Loss: 0.5732, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 45, Epoch: 167, Loss: 0.5783, Val Acc: 0.6807, Test Acc: 0.7798
# Seed: 45, Epoch: 168, Loss: 0.5749, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 45, Epoch: 169, Loss: 0.5818, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 45, Epoch: 170, Loss: 0.5686, Val Acc: 0.6747, Test Acc: 0.7500
# Seed: 45, Epoch: 171, Loss: 0.5685, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 45, Epoch: 172, Loss: 0.5721, Val Acc: 0.6747, Test Acc: 0.7440
# Seed: 45, Epoch: 173, Loss: 0.5742, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 45, Epoch: 174, Loss: 0.5682, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 175, Loss: 0.5623, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 45, Epoch: 176, Loss: 0.5773, Val Acc: 0.6807, Test Acc: 0.7440
# Early stopping at epoch 176 for seed 45
# Seed: 46, Epoch: 001, Loss: 0.6872, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 002, Loss: 0.6855, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 003, Loss: 0.6837, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 004, Loss: 0.6812, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 005, Loss: 0.6744, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 006, Loss: 0.6723, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 007, Loss: 0.6750, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 008, Loss: 0.6710, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 009, Loss: 0.6716, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 010, Loss: 0.6624, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 011, Loss: 0.6656, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 012, Loss: 0.6624, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 013, Loss: 0.6600, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 014, Loss: 0.6630, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 015, Loss: 0.6570, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 016, Loss: 0.6662, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 017, Loss: 0.6680, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 018, Loss: 0.6651, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 019, Loss: 0.6639, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 020, Loss: 0.6585, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 021, Loss: 0.6542, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 022, Loss: 0.6456, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 023, Loss: 0.6388, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 024, Loss: 0.6337, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 025, Loss: 0.6369, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 026, Loss: 0.6296, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 027, Loss: 0.6289, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 028, Loss: 0.6399, Val Acc: 0.6687, Test Acc: 0.6190
# Seed: 46, Epoch: 029, Loss: 0.6260, Val Acc: 0.7048, Test Acc: 0.6488
# Seed: 46, Epoch: 030, Loss: 0.6404, Val Acc: 0.6988, Test Acc: 0.6726
# Seed: 46, Epoch: 031, Loss: 0.6426, Val Acc: 0.7048, Test Acc: 0.6726
# Seed: 46, Epoch: 032, Loss: 0.6436, Val Acc: 0.7169, Test Acc: 0.6726
# Seed: 46, Epoch: 033, Loss: 0.6296, Val Acc: 0.7169, Test Acc: 0.6786
# Seed: 46, Epoch: 034, Loss: 0.6280, Val Acc: 0.7169, Test Acc: 0.6905
# Seed: 46, Epoch: 035, Loss: 0.6249, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 46, Epoch: 036, Loss: 0.6345, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 46, Epoch: 037, Loss: 0.6299, Val Acc: 0.7349, Test Acc: 0.7143
# Seed: 46, Epoch: 038, Loss: 0.6223, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 46, Epoch: 039, Loss: 0.6325, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 46, Epoch: 040, Loss: 0.6348, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 041, Loss: 0.6300, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 042, Loss: 0.6430, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 043, Loss: 0.6378, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 044, Loss: 0.6498, Val Acc: 0.7410, Test Acc: 0.7619
# Seed: 46, Epoch: 045, Loss: 0.6428, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 46, Epoch: 046, Loss: 0.6293, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 46, Epoch: 047, Loss: 0.6272, Val Acc: 0.7651, Test Acc: 0.7262
# Seed: 46, Epoch: 048, Loss: 0.6188, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 46, Epoch: 049, Loss: 0.6327, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 46, Epoch: 050, Loss: 0.6381, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 46, Epoch: 051, Loss: 0.6478, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 052, Loss: 0.6432, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 053, Loss: 0.6402, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 46, Epoch: 054, Loss: 0.6365, Val Acc: 0.7590, Test Acc: 0.7321
# Seed: 46, Epoch: 055, Loss: 0.6290, Val Acc: 0.7530, Test Acc: 0.7262
# Seed: 46, Epoch: 056, Loss: 0.6211, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 46, Epoch: 057, Loss: 0.6172, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 46, Epoch: 058, Loss: 0.6300, Val Acc: 0.7470, Test Acc: 0.7262
# Seed: 46, Epoch: 059, Loss: 0.6156, Val Acc: 0.7530, Test Acc: 0.7262
# Seed: 46, Epoch: 060, Loss: 0.6179, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 46, Epoch: 061, Loss: 0.6164, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 46, Epoch: 062, Loss: 0.6140, Val Acc: 0.7530, Test Acc: 0.7202
# Seed: 46, Epoch: 063, Loss: 0.6062, Val Acc: 0.7530, Test Acc: 0.7262
# Seed: 46, Epoch: 064, Loss: 0.6191, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 46, Epoch: 065, Loss: 0.6160, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 46, Epoch: 066, Loss: 0.6174, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 46, Epoch: 067, Loss: 0.6198, Val Acc: 0.7349, Test Acc: 0.7202
# Seed: 46, Epoch: 068, Loss: 0.6101, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 46, Epoch: 069, Loss: 0.6079, Val Acc: 0.7289, Test Acc: 0.6845
# Seed: 46, Epoch: 070, Loss: 0.6027, Val Acc: 0.6988, Test Acc: 0.6786
# Seed: 46, Epoch: 071, Loss: 0.5995, Val Acc: 0.7048, Test Acc: 0.6786
# Seed: 46, Epoch: 072, Loss: 0.6014, Val Acc: 0.7229, Test Acc: 0.6845
# Seed: 46, Epoch: 073, Loss: 0.6064, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 074, Loss: 0.6124, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 075, Loss: 0.6245, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 076, Loss: 0.6297, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 077, Loss: 0.6301, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 078, Loss: 0.6157, Val Acc: 0.7410, Test Acc: 0.7321
# Seed: 46, Epoch: 079, Loss: 0.6095, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 46, Epoch: 080, Loss: 0.6073, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 46, Epoch: 081, Loss: 0.6067, Val Acc: 0.7410, Test Acc: 0.7202
# Seed: 46, Epoch: 082, Loss: 0.6063, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 46, Epoch: 083, Loss: 0.6177, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 46, Epoch: 084, Loss: 0.6168, Val Acc: 0.7410, Test Acc: 0.7381
# Seed: 46, Epoch: 085, Loss: 0.6156, Val Acc: 0.7470, Test Acc: 0.7143
# Seed: 46, Epoch: 086, Loss: 0.6132, Val Acc: 0.7410, Test Acc: 0.7083
# Seed: 46, Epoch: 087, Loss: 0.6187, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 088, Loss: 0.6085, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 46, Epoch: 089, Loss: 0.6192, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 46, Epoch: 090, Loss: 0.6221, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 46, Epoch: 091, Loss: 0.6213, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 46, Epoch: 092, Loss: 0.6145, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 093, Loss: 0.6189, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 46, Epoch: 094, Loss: 0.6098, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 095, Loss: 0.6136, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 46, Epoch: 096, Loss: 0.6123, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 46, Epoch: 097, Loss: 0.6053, Val Acc: 0.7530, Test Acc: 0.7381
# Seed: 46, Epoch: 098, Loss: 0.6061, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 46, Epoch: 099, Loss: 0.6053, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 46, Epoch: 100, Loss: 0.6002, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 46, Epoch: 101, Loss: 0.6035, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 46, Epoch: 102, Loss: 0.6020, Val Acc: 0.7289, Test Acc: 0.7262
# Seed: 46, Epoch: 103, Loss: 0.5951, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 46, Epoch: 104, Loss: 0.6009, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 46, Epoch: 105, Loss: 0.6023, Val Acc: 0.7651, Test Acc: 0.7560
# Seed: 46, Epoch: 106, Loss: 0.6046, Val Acc: 0.7530, Test Acc: 0.7440
# Seed: 46, Epoch: 107, Loss: 0.6025, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 46, Epoch: 108, Loss: 0.5980, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 46, Epoch: 109, Loss: 0.5942, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 46, Epoch: 110, Loss: 0.5840, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 46, Epoch: 111, Loss: 0.5878, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 46, Epoch: 112, Loss: 0.5974, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 46, Epoch: 113, Loss: 0.5807, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 46, Epoch: 114, Loss: 0.5967, Val Acc: 0.7470, Test Acc: 0.7679
# Seed: 46, Epoch: 115, Loss: 0.6074, Val Acc: 0.7349, Test Acc: 0.7798
# Seed: 46, Epoch: 116, Loss: 0.6115, Val Acc: 0.7349, Test Acc: 0.7798
# Seed: 46, Epoch: 117, Loss: 0.6089, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 118, Loss: 0.5952, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 46, Epoch: 119, Loss: 0.5902, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 46, Epoch: 120, Loss: 0.5872, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 121, Loss: 0.5895, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 46, Epoch: 122, Loss: 0.5892, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 46, Epoch: 123, Loss: 0.5907, Val Acc: 0.7530, Test Acc: 0.7560
# Seed: 46, Epoch: 124, Loss: 0.5873, Val Acc: 0.7470, Test Acc: 0.7560
# Seed: 46, Epoch: 125, Loss: 0.6124, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 46, Epoch: 126, Loss: 0.6158, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 46, Epoch: 127, Loss: 0.6091, Val Acc: 0.7590, Test Acc: 0.7440
# Seed: 46, Epoch: 128, Loss: 0.5938, Val Acc: 0.7530, Test Acc: 0.7024
# Seed: 46, Epoch: 129, Loss: 0.5887, Val Acc: 0.7048, Test Acc: 0.6905
# Seed: 46, Epoch: 130, Loss: 0.5863, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 46, Epoch: 131, Loss: 0.5917, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 46, Epoch: 132, Loss: 0.5910, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 46, Epoch: 133, Loss: 0.5824, Val Acc: 0.7169, Test Acc: 0.6964
# Seed: 46, Epoch: 134, Loss: 0.5823, Val Acc: 0.7590, Test Acc: 0.7202
# Seed: 46, Epoch: 135, Loss: 0.5893, Val Acc: 0.7651, Test Acc: 0.7381
# Seed: 46, Epoch: 136, Loss: 0.5929, Val Acc: 0.7651, Test Acc: 0.7321
# Seed: 46, Epoch: 137, Loss: 0.5974, Val Acc: 0.7651, Test Acc: 0.7262
# Seed: 46, Epoch: 138, Loss: 0.5928, Val Acc: 0.7651, Test Acc: 0.7143
# Seed: 46, Epoch: 139, Loss: 0.5850, Val Acc: 0.7530, Test Acc: 0.7143
# Seed: 46, Epoch: 140, Loss: 0.5901, Val Acc: 0.7410, Test Acc: 0.7083
# Seed: 46, Epoch: 141, Loss: 0.5858, Val Acc: 0.7530, Test Acc: 0.7143
# Seed: 46, Epoch: 142, Loss: 0.5853, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 46, Epoch: 143, Loss: 0.5869, Val Acc: 0.7590, Test Acc: 0.7321
# Seed: 46, Epoch: 144, Loss: 0.5942, Val Acc: 0.7470, Test Acc: 0.7440
# Seed: 46, Epoch: 145, Loss: 0.6042, Val Acc: 0.7530, Test Acc: 0.7560
# Seed: 46, Epoch: 146, Loss: 0.6074, Val Acc: 0.7590, Test Acc: 0.7440
# Seed: 46, Epoch: 147, Loss: 0.5886, Val Acc: 0.7530, Test Acc: 0.7083
# Seed: 46, Epoch: 148, Loss: 0.5789, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 46, Epoch: 149, Loss: 0.6115, Val Acc: 0.7410, Test Acc: 0.6964
# Seed: 46, Epoch: 150, Loss: 0.5758, Val Acc: 0.7410, Test Acc: 0.7024
# Seed: 46, Epoch: 151, Loss: 0.5765, Val Acc: 0.7410, Test Acc: 0.7143
# Seed: 46, Epoch: 152, Loss: 0.5686, Val Acc: 0.7590, Test Acc: 0.7262
# Seed: 46, Epoch: 153, Loss: 0.5702, Val Acc: 0.7651, Test Acc: 0.7500
# Seed: 46, Epoch: 154, Loss: 0.5863, Val Acc: 0.7410, Test Acc: 0.7500
# Seed: 46, Epoch: 155, Loss: 0.5900, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 156, Loss: 0.6046, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 157, Loss: 0.6316, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 158, Loss: 0.6034, Val Acc: 0.7771, Test Acc: 0.7381
# Seed: 46, Epoch: 159, Loss: 0.5894, Val Acc: 0.7530, Test Acc: 0.7321
# Seed: 46, Epoch: 160, Loss: 0.5846, Val Acc: 0.7530, Test Acc: 0.7202
# Seed: 46, Epoch: 161, Loss: 0.5903, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 46, Epoch: 162, Loss: 0.5893, Val Acc: 0.7349, Test Acc: 0.7321
# Seed: 46, Epoch: 163, Loss: 0.5843, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 164, Loss: 0.5884, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 46, Epoch: 165, Loss: 0.5851, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 46, Epoch: 166, Loss: 0.5832, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 46, Epoch: 167, Loss: 0.5763, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 46, Epoch: 168, Loss: 0.5797, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 169, Loss: 0.5841, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 46, Epoch: 170, Loss: 0.5769, Val Acc: 0.7470, Test Acc: 0.7202
# Seed: 46, Epoch: 171, Loss: 0.5789, Val Acc: 0.7410, Test Acc: 0.7202
# Seed: 46, Epoch: 172, Loss: 0.5811, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 46, Epoch: 173, Loss: 0.5818, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 46, Epoch: 174, Loss: 0.5767, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 175, Loss: 0.5800, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 46, Epoch: 176, Loss: 0.5770, Val Acc: 0.7470, Test Acc: 0.7381
# Seed: 46, Epoch: 177, Loss: 0.5869, Val Acc: 0.7651, Test Acc: 0.7500
# Seed: 46, Epoch: 178, Loss: 0.5911, Val Acc: 0.7590, Test Acc: 0.7440
# Seed: 46, Epoch: 179, Loss: 0.5837, Val Acc: 0.7470, Test Acc: 0.7321
# Seed: 46, Epoch: 180, Loss: 0.5798, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 181, Loss: 0.5734, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 46, Epoch: 182, Loss: 0.5724, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 46, Epoch: 183, Loss: 0.5750, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 46, Epoch: 184, Loss: 0.5852, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 185, Loss: 0.6108, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 46, Epoch: 186, Loss: 0.6280, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 46, Epoch: 187, Loss: 0.5923, Val Acc: 0.7410, Test Acc: 0.7440
# Seed: 46, Epoch: 188, Loss: 0.5815, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 46, Epoch: 189, Loss: 0.5747, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 46, Epoch: 190, Loss: 0.5827, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 46, Epoch: 191, Loss: 0.5775, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 46, Epoch: 192, Loss: 0.5756, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 193, Loss: 0.5691, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 46, Epoch: 194, Loss: 0.5673, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 46, Epoch: 195, Loss: 0.5649, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 196, Loss: 0.5586, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 46, Epoch: 197, Loss: 0.5652, Val Acc: 0.7410, Test Acc: 0.7560
# Seed: 46, Epoch: 198, Loss: 0.5859, Val Acc: 0.7590, Test Acc: 0.7738
# Seed: 46, Epoch: 199, Loss: 0.5953, Val Acc: 0.7410, Test Acc: 0.7619
# Seed: 46, Epoch: 200, Loss: 0.5654, Val Acc: 0.7108, Test Acc: 0.7262
# Average Time: 28.62 seconds
# Var Time: 3.33 seconds
# Average Memory: 54.00 MB
# Average Best Val Acc: 0.7482
# Std Best Test Acc: 0.0190
# Average Test Acc: 0.7250

# %% [markdown]
# ## HGPSLPooling with HierarchicalGCN (2019)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Parameter
from torch_geometric.data import Data
from torch_geometric.nn.conv import MessagePassing
from torch_geometric.utils import softmax, dense_to_sparse, add_remaining_self_loops
from torch_scatter import scatter_add
from torch_sparse import spspmm, coalesce


import torch
import torch.nn as nn
from torch.autograd import Function
from torch_scatter import scatter_add, scatter_max

def topk(x, ratio, batch, min_score=None, tol=1e-7):

    if min_score is not None:
        # Make sure that we do not drop all nodes in a graph.
        scores_max = scatter_max(x, batch)[0][batch] - tol
        scores_min = scores_max.clamp(max=min_score)

        perm = torch.nonzero(x > scores_min).view(-1)
    else:
        num_nodes = scatter_add(batch.new_ones(x.size(0)), batch, dim=0)
        batch_size, max_num_nodes = num_nodes.size(0), num_nodes.max().item()

        cum_num_nodes = torch.cat(
            [num_nodes.new_zeros(1),
            num_nodes.cumsum(dim=0)[:-1]], dim=0)

        index = torch.arange(batch.size(0), dtype=torch.long, device=x.device)
        index = (index - cum_num_nodes[batch]) + (batch * max_num_nodes)

        dense_x = x.new_full((batch_size * max_num_nodes, ), -2)
        dense_x[index] = x
        dense_x = dense_x.view(batch_size, max_num_nodes)

        _, perm = dense_x.sort(dim=-1, descending=True)

        perm = perm + cum_num_nodes.view(-1, 1)
        perm = perm.view(-1)

        k = (ratio * num_nodes.to(torch.float)).ceil().to(torch.long)
        mask = [
            torch.arange(k[i], dtype=torch.long, device=x.device) +
            i * max_num_nodes for i in range(batch_size)
        ]
        mask = torch.cat(mask, dim=0)

        perm = perm[mask]

    return perm

def filter_adj(edge_index, edge_weight, perm, num_nodes=None):

        num_nodes = maybe_num_nodes(edge_index, num_nodes)

        mask = perm.new_full((num_nodes, ), -1)
        i = torch.arange(perm.size(0), dtype=torch.long, device=perm.device)
        mask[perm] = i

        row, col = edge_index
        row, col = mask[row], mask[col]
        mask = (row >= 0) & (col >= 0)
        row, col = row[mask], col[mask]

        if edge_weight is not None:
            edge_weight = edge_weight[mask]

        return torch.stack([row, col], dim=0), edge_weight

def scatter_sort(x, batch, fill_value=-1e16):
    num_nodes = scatter_add(batch.new_ones(x.size(0)), batch, dim=0)
    batch_size, max_num_nodes = num_nodes.size(0), num_nodes.max().item()

    cum_num_nodes = torch.cat([num_nodes.new_zeros(1), num_nodes.cumsum(dim=0)[:-1]], dim=0)

    index = torch.arange(batch.size(0), dtype=torch.long, device=x.device)
    index = (index - cum_num_nodes[batch]) + (batch * max_num_nodes)

    dense_x = x.new_full((batch_size * max_num_nodes,), fill_value)
    dense_x[index] = x
    dense_x = dense_x.view(batch_size, max_num_nodes)

    sorted_x, _ = dense_x.sort(dim=-1, descending=True)
    cumsum_sorted_x = sorted_x.cumsum(dim=-1)
    cumsum_sorted_x = cumsum_sorted_x.view(-1)

    sorted_x = sorted_x.view(-1)
    filled_index = sorted_x != fill_value

    sorted_x = sorted_x[filled_index]
    cumsum_sorted_x = cumsum_sorted_x[filled_index]

    return sorted_x, cumsum_sorted_x


def _make_ix_like(batch):
    num_nodes = scatter_add(batch.new_ones(batch.size(0)), batch, dim=0)
    idx = [torch.arange(1, i + 1, dtype=torch.long, device=batch.device) for i in num_nodes]
    idx = torch.cat(idx, dim=0)

    return idx


def _threshold_and_support(x, batch):
    """Sparsemax building block: compute the threshold
    Args:
        x: input tensor to apply the sparsemax
        batch: group indicators
    Returns:
        the threshold value
    """
    num_nodes = scatter_add(batch.new_ones(x.size(0)), batch, dim=0)
    cum_num_nodes = torch.cat([num_nodes.new_zeros(1), num_nodes.cumsum(dim=0)[:-1]], dim=0)

    sorted_input, input_cumsum = scatter_sort(x, batch)
    input_cumsum = input_cumsum - 1.0
    rhos = _make_ix_like(batch).to(x.dtype)
    support = rhos * sorted_input > input_cumsum

    support_size = scatter_add(support.to(batch.dtype), batch)
    # mask invalid index, for example, if batch is not start from 0 or not continuous, it may result in negative index
    idx = support_size + cum_num_nodes - 1
    mask = idx < 0
    idx[mask] = 0
    tau = input_cumsum.gather(0, idx)
    tau /= support_size.to(x.dtype)

    return tau, support_size


class SparsemaxFunction(Function):

    @staticmethod
    def forward(ctx, x, batch):
        """sparsemax: normalizing sparse transform
        Parameters:
            ctx: context object
            x (Tensor): shape (N, )
            batch: group indicator
        Returns:
            output (Tensor): same shape as input
        """
        max_val, _ = scatter_max(x, batch)
        x -= max_val[batch]
        tau, supp_size = _threshold_and_support(x, batch)
        output = torch.clamp(x - tau[batch], min=0)
        ctx.save_for_backward(supp_size, output, batch)

        return output

    @staticmethod
    def backward(ctx, grad_output):
        supp_size, output, batch = ctx.saved_tensors
        grad_input = grad_output.clone()
        grad_input[output == 0] = 0

        v_hat = scatter_add(grad_input, batch) / supp_size.to(output.dtype)
        grad_input = torch.where(output != 0, grad_input - v_hat[batch], grad_input)

        return grad_input, None


sparsemax = SparsemaxFunction.apply


class Sparsemax(nn.Module):

    def __init__(self):
        super(Sparsemax, self).__init__()

    def forward(self, x, batch):
        return sparsemax(x, batch)


if __name__ == '__main__':
    sparse_attention = Sparsemax()
    input_x = torch.tensor([1.7301, 0.6792, -1.0565, 1.6614, -0.3196, -0.7790, -0.3877, -0.4943, 0.1831, -0.0061])
    input_batch = torch.cat([torch.zeros(4, dtype=torch.long), torch.ones(6, dtype=torch.long)], dim=0)
    res = sparse_attention(input_x, input_batch)
    print(res)

class TwoHopNeighborhood(object):
    def __call__(self, data):
        edge_index, edge_attr = data.edge_index, data.edge_attr
        n = data.num_nodes

        fill = 1e16
        value = edge_index.new_full((edge_index.size(1),), fill, dtype=torch.float)

        index, value = spspmm(edge_index, value, edge_index, value, n, n, n, True)

        edge_index = torch.cat([edge_index, index], dim=1)
        if edge_attr is None:
            data.edge_index, _ = coalesce(edge_index, None, n, n)
        else:
            value = value.view(-1, *[1 for _ in range(edge_attr.dim() - 1)])
            value = value.expand(-1, *list(edge_attr.size())[1:])
            edge_attr = torch.cat([edge_attr, value], dim=0)
            data.edge_index, edge_attr = coalesce(edge_index, edge_attr, n, n, op='min', fill_value=fill)
            edge_attr[edge_attr >= fill] = 0
            data.edge_attr = edge_attr

        return data

    def __repr__(self):
        return '{}()'.format(self.__class__.__name__)


class GCN(MessagePassing):
    def __init__(self, in_channels, out_channels, cached=False, bias=True, **kwargs):
        super(GCN, self).__init__(aggr='add', **kwargs)

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.cached = cached
        self.cached_result = None
        self.cached_num_edges = None

        self.weight = Parameter(torch.Tensor(in_channels, out_channels))
        nn.init.xavier_uniform_(self.weight.data)

        if bias:
            self.bias = Parameter(torch.Tensor(out_channels))
            nn.init.zeros_(self.bias.data)
        else:
            self.register_parameter('bias', None)

        self.reset_parameters()

    def reset_parameters(self):
        self.cached_result = None
        self.cached_num_edges = None

    @staticmethod
    def norm(edge_index, num_nodes, edge_weight, dtype=None):
        if edge_weight is None:
            edge_weight = torch.ones((edge_index.size(1),), dtype=dtype, device=edge_index.device)

        row, col = edge_index
        deg = scatter_add(edge_weight, row, dim=0, dim_size=num_nodes)
        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0

        return edge_index, deg_inv_sqrt[row] * edge_weight * deg_inv_sqrt[col]

    def forward(self, x, edge_index, edge_weight=None):
        x = torch.matmul(x, self.weight)

        if self.cached and self.cached_result is not None:
            if edge_index.size(1) != self.cached_num_edges:
                raise RuntimeError(
                    'Cached {} number of edges, but found {}'.format(self.cached_num_edges, edge_index.size(1)))

        if not self.cached or self.cached_result is None:
            self.cached_num_edges = edge_index.size(1)
            edge_index, norm = self.norm(edge_index, x.size(0), edge_weight, x.dtype)
            self.cached_result = edge_index, norm

        edge_index, norm = self.cached_result

        return self.propagate(edge_index, x=x, norm=norm)

    def message(self, x_j, norm):
        return norm.view(-1, 1) * x_j

    def update(self, aggr_out):
        if self.bias is not None:
            aggr_out = aggr_out + self.bias
        return aggr_out

    def __repr__(self):
        return '{}({}, {})'.format(self.__class__.__name__, self.in_channels, self.out_channels)


class NodeInformationScore(MessagePassing):
    def __init__(self, improved=False, cached=False, **kwargs):
        super(NodeInformationScore, self).__init__(aggr='add', **kwargs)

        self.improved = improved
        self.cached = cached
        self.cached_result = None
        self.cached_num_edges = None

    @staticmethod
    def norm(edge_index, num_nodes, edge_weight, dtype=None):
        if edge_weight is None:
            edge_weight = torch.ones((edge_index.size(1),), dtype=dtype, device=edge_index.device)

        row, col = edge_index
        deg = scatter_add(edge_weight, row, dim=0, dim_size=num_nodes)
        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0

        edge_index, edge_weight = add_remaining_self_loops(edge_index, edge_weight, 0, num_nodes)

        row, col = edge_index
        expand_deg = torch.zeros((edge_weight.size(0),), dtype=dtype, device=edge_index.device)
        expand_deg[-num_nodes:] = torch.ones((num_nodes,), dtype=dtype, device=edge_index.device)

        return edge_index, expand_deg - deg_inv_sqrt[row] * edge_weight * deg_inv_sqrt[col]

    def forward(self, x, edge_index, edge_weight):
        if self.cached and self.cached_result is not None:
            if edge_index.size(1) != self.cached_num_edges:
                raise RuntimeError(
                    'Cached {} number of edges, but found {}'.format(self.cached_num_edges, edge_index.size(1)))

        if not self.cached or self.cached_result is None:
            self.cached_num_edges = edge_index.size(1)
            edge_index, norm = self.norm(edge_index, x.size(0), edge_weight, x.dtype)
            self.cached_result = edge_index, norm

        edge_index, norm = self.cached_result

        return self.propagate(edge_index, x=x, norm=norm)

    def message(self, x_j, norm):
        return norm.view(-1, 1) * x_j

    def update(self, aggr_out):
        return aggr_out


class HGPSLPool(torch.nn.Module):
    def __init__(self, in_channels, ratio=0.5, sample=False, sparse=False, sl=True, lamb=1.0, negative_slop=0.2):
        super(HGPSLPool, self).__init__()
        self.in_channels = in_channels
        self.ratio = ratio
        self.sample = sample
        self.sparse = sparse
        self.sl = sl
        self.negative_slop = negative_slop
        self.lamb = lamb

        self.att = Parameter(torch.Tensor(1, self.in_channels * 2))
        nn.init.xavier_uniform_(self.att.data)
        self.sparse_attention = Sparsemax()
        self.neighbor_augment = TwoHopNeighborhood()
        self.calc_information_score = NodeInformationScore()

    def forward(self, x, edge_index, edge_attr, batch):
        if batch is None:
            batch = edge_index.new_zeros(x.size(0))

        x_information_score = self.calc_information_score(x, edge_index, edge_attr)
        score = torch.sum(torch.abs(x_information_score), dim=1)

        # Graph Pooling
        original_x = x
        perm = topk(score, self.ratio, batch)
        x = x[perm]
        batch = batch[perm]
        induced_edge_index, induced_edge_attr = filter_adj(edge_index, edge_attr, perm, num_nodes=score.size(0))

        # Discard structure learning layer, directly return
        if self.sl is False:
            return x, induced_edge_index, induced_edge_attr, batch

        # Structure Learning
        if self.sample:
            # A fast mode for large graphs.
            # In large graphs, learning the possible edge weights between each pair of nodes is time consuming.
            # To accelerate this process, we sample it's K-Hop neighbors for each node and then learn the
            # edge weights between them.
            k_hop = 3
            if edge_attr is None:
                edge_attr = torch.ones((edge_index.size(1),), dtype=torch.float, device=edge_index.device)

            hop_data = Data(x=original_x, edge_index=edge_index, edge_attr=edge_attr)
            for _ in range(k_hop - 1):
                hop_data = self.neighbor_augment(hop_data)
            hop_edge_index = hop_data.edge_index
            hop_edge_attr = hop_data.edge_attr
            new_edge_index, new_edge_attr = filter_adj(hop_edge_index, hop_edge_attr, perm, num_nodes=score.size(0))

            new_edge_index, new_edge_attr = add_remaining_self_loops(new_edge_index, new_edge_attr, 0, x.size(0))
            row, col = new_edge_index
            weights = (torch.cat([x[row], x[col]], dim=1) * self.att).sum(dim=-1)
            weights = F.leaky_relu(weights, self.negative_slop) + new_edge_attr * self.lamb
            adj = torch.zeros((x.size(0), x.size(0)), dtype=torch.float, device=x.device)
            adj[row, col] = weights
            new_edge_index, weights = dense_to_sparse(adj)
            row, col = new_edge_index
            if self.sparse:
                new_edge_attr = self.sparse_attention(weights, row)
            else:
                new_edge_attr = softmax(weights, row, x.size(0))
            # filter out zero weight edges
            adj[row, col] = new_edge_attr
            new_edge_index, new_edge_attr = dense_to_sparse(adj)
            # release gpu memory
            del adj
            torch.cuda.empty_cache()
        else:
            # Learning the possible edge weights between each pair of nodes in the pooled subgraph, relative slower.
            if edge_attr is None:
                induced_edge_attr = torch.ones((induced_edge_index.size(1),), dtype=x.dtype,
                                               device=induced_edge_index.device)
            num_nodes = scatter_add(batch.new_ones(x.size(0)), batch, dim=0)
            shift_cum_num_nodes = torch.cat([num_nodes.new_zeros(1), num_nodes.cumsum(dim=0)[:-1]], dim=0)
            cum_num_nodes = num_nodes.cumsum(dim=0)
            adj = torch.zeros((x.size(0), x.size(0)), dtype=torch.float, device=x.device)
            # Construct batch fully connected graph in block diagonal matirx format
            for idx_i, idx_j in zip(shift_cum_num_nodes, cum_num_nodes):
                adj[idx_i:idx_j, idx_i:idx_j] = 1.0
            new_edge_index, _ = dense_to_sparse(adj)
            row, col = new_edge_index

            weights = (torch.cat([x[row], x[col]], dim=1) * self.att).sum(dim=-1)
            weights = F.leaky_relu(weights, self.negative_slop)
            adj[row, col] = weights
            induced_row, induced_col = induced_edge_index

            adj[induced_row, induced_col] += induced_edge_attr * self.lamb
            weights = adj[row, col]
            if self.sparse:
                new_edge_attr = self.sparse_attention(weights, row)
            else:
                new_edge_attr = softmax(weights, row, num_nodes=x.size(0))
            # filter out zero weight edges
            adj[row, col] = new_edge_attr
            new_edge_index, new_edge_attr = dense_to_sparse(adj)
            # release gpu memory
            del adj
            torch.cuda.empty_cache()

        return x, new_edge_index, new_edge_attr, batch
# Out:
# tensor([0.5344, 0.0000, 0.0000, 0.4656, 0.0613, 0.0000, 0.0000, 0.0000, 0.5640,
#         0.3748])

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import SAGEConv, EdgePooling
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset
from torch_geometric.transforms import ToUndirected
from torch.nn import Linear
import torch.optim as optim
from torch_geometric.nn import global_mean_pool
from torch_geometric.utils import to_dense_batch
from torch_geometric.nn import BatchNorm

class HierarchicalGCN_HGPSL(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_classes):
        super(HierarchicalGCN_HGPSL, self).__init__()
        self.conv1 = SAGEConv(in_channels, hidden_channels)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = SAGEConv(hidden_channels, hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = SAGEConv(hidden_channels, out_channels)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        self.lin1 = torch.nn.Linear(out_channels, 32)
        self.lin2 = torch.nn.Linear(32, num_classes)

        self.pool1 = HGPSLPool(hidden_channels, ratio=0.5, sample=False, sparse=False, sl=True, lamb=1.0, negative_slop=0.2)
        self.pool2 = HGPSLPool(hidden_channels, ratio=0.5, sample=False, sparse=False, sl=True, lamb=1.0, negative_slop=0.2)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        edge_attr=None
        batch = data.batch

        # First GCN and pooling layer
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        #x = self.bn1(x)
        x, edge_index, _, batch = self.pool1(x, edge_index, edge_attr, batch)

        # Second GCN and pooling layer
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        #x = self.bn2(x)
        x, edge_index, _, batch = self.pool1(x, edge_index, edge_attr, batch)

        # Third GCN layer
        x = self.conv3(x, edge_index)
        x = F.relu(x)
        #x = self.bn3(x)

        # Mean pooling over the nodes
        x, mask = to_dense_batch(x, batch)
        x = x.mean(dim=1)

        # Fully connected layers
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1)



num_classes = dataset_sparse.num_classes
in_channels = dataset_sparse.num_features

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = HierarchicalGCN_HGPSL(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = torch.nn.CrossEntropyLoss()

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        out = model(data)
        loss = F.nll_loss(out, data.y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * data.num_graphs
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        out = model(data)
        pred = out.argmax(dim=1)
        correct += (pred == data.y).sum().item()
    return correct / len(loader.dataset)

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = HierarchicalGCN_HGPSL(in_channels=dataset_sparse.num_features, hidden_channels=64,out_channels=64, num_classes=dataset_sparse.num_classes).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6895, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 002, Loss: 0.6718, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 003, Loss: 0.6640, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 004, Loss: 0.6488, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 005, Loss: 0.6436, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 006, Loss: 0.6437, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 007, Loss: 0.6554, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 008, Loss: 0.6527, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 009, Loss: 0.6497, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 010, Loss: 0.6520, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 011, Loss: 0.6574, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 012, Loss: 0.6444, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 013, Loss: 0.6399, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 014, Loss: 0.6372, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 015, Loss: 0.6351, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 42, Epoch: 016, Loss: 0.6384, Val Acc: 0.6506, Test Acc: 0.6190
# Seed: 42, Epoch: 017, Loss: 0.6315, Val Acc: 0.6627, Test Acc: 0.6131
# Seed: 42, Epoch: 018, Loss: 0.6338, Val Acc: 0.6867, Test Acc: 0.6250
# Seed: 42, Epoch: 019, Loss: 0.6372, Val Acc: 0.6747, Test Acc: 0.6726
# Seed: 42, Epoch: 020, Loss: 0.6393, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 42, Epoch: 021, Loss: 0.6462, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 42, Epoch: 022, Loss: 0.6408, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 42, Epoch: 023, Loss: 0.6445, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 42, Epoch: 024, Loss: 0.6430, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 42, Epoch: 025, Loss: 0.6470, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 42, Epoch: 026, Loss: 0.6270, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 42, Epoch: 027, Loss: 0.6407, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 028, Loss: 0.6383, Val Acc: 0.6928, Test Acc: 0.7143
# Seed: 42, Epoch: 029, Loss: 0.6344, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 030, Loss: 0.6420, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 031, Loss: 0.6385, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 42, Epoch: 032, Loss: 0.6307, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 42, Epoch: 033, Loss: 0.6264, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 42, Epoch: 034, Loss: 0.6224, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 42, Epoch: 035, Loss: 0.6246, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 42, Epoch: 036, Loss: 0.6212, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 42, Epoch: 037, Loss: 0.6236, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 42, Epoch: 038, Loss: 0.6170, Val Acc: 0.6928, Test Acc: 0.6905
# Seed: 42, Epoch: 039, Loss: 0.6208, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 040, Loss: 0.6313, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 041, Loss: 0.6264, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 42, Epoch: 042, Loss: 0.6218, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 043, Loss: 0.6169, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 044, Loss: 0.6268, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 42, Epoch: 045, Loss: 0.6223, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 42, Epoch: 046, Loss: 0.6204, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 047, Loss: 0.6241, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 048, Loss: 0.6251, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 049, Loss: 0.6280, Val Acc: 0.6627, Test Acc: 0.7440
# Seed: 42, Epoch: 050, Loss: 0.6384, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 051, Loss: 0.6503, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 052, Loss: 0.6443, Val Acc: 0.6747, Test Acc: 0.7262
# Seed: 42, Epoch: 053, Loss: 0.6493, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 42, Epoch: 054, Loss: 0.6433, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 42, Epoch: 055, Loss: 0.6387, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 056, Loss: 0.6341, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 057, Loss: 0.6368, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 058, Loss: 0.6343, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 42, Epoch: 059, Loss: 0.6345, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 42, Epoch: 060, Loss: 0.6384, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 42, Epoch: 061, Loss: 0.6387, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 42, Epoch: 062, Loss: 0.6333, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 42, Epoch: 063, Loss: 0.6283, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 064, Loss: 0.6260, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 42, Epoch: 065, Loss: 0.6264, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 42, Epoch: 066, Loss: 0.6167, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 42, Epoch: 067, Loss: 0.6195, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 42, Epoch: 068, Loss: 0.6181, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 42, Epoch: 069, Loss: 0.6095, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 070, Loss: 0.5990, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 071, Loss: 0.6064, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 072, Loss: 0.6007, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 073, Loss: 0.5993, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 42, Epoch: 074, Loss: 0.6059, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 42, Epoch: 075, Loss: 0.6002, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 42, Epoch: 076, Loss: 0.5910, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 42, Epoch: 077, Loss: 0.5866, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 42, Epoch: 078, Loss: 0.5985, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 42, Epoch: 079, Loss: 0.5853, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 080, Loss: 0.5935, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 42, Epoch: 081, Loss: 0.5910, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 42, Epoch: 082, Loss: 0.5933, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 083, Loss: 0.5837, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 084, Loss: 0.5841, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 085, Loss: 0.6023, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 42, Epoch: 086, Loss: 0.6175, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 087, Loss: 0.6105, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 42, Epoch: 088, Loss: 0.5958, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 42, Epoch: 089, Loss: 0.5779, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 090, Loss: 0.5892, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 091, Loss: 0.6010, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 092, Loss: 0.5999, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 42, Epoch: 093, Loss: 0.5937, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 42, Epoch: 094, Loss: 0.5946, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 42, Epoch: 095, Loss: 0.5890, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 096, Loss: 0.5740, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 097, Loss: 0.5833, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 098, Loss: 0.5750, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 099, Loss: 0.5789, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 42, Epoch: 100, Loss: 0.5813, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 42, Epoch: 101, Loss: 0.5801, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 102, Loss: 0.5707, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 103, Loss: 0.5828, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 42, Epoch: 104, Loss: 0.5682, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 42, Epoch: 105, Loss: 0.5683, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 42, Epoch: 106, Loss: 0.5647, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 107, Loss: 0.5631, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 42, Epoch: 108, Loss: 0.5697, Val Acc: 0.6867, Test Acc: 0.7560
# Seed: 42, Epoch: 109, Loss: 0.5953, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 42, Epoch: 110, Loss: 0.6012, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 42, Epoch: 111, Loss: 0.5783, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 42, Epoch: 112, Loss: 0.5930, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 113, Loss: 0.5793, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 42, Epoch: 114, Loss: 0.5925, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 115, Loss: 0.5952, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 42, Epoch: 116, Loss: 0.5838, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 42, Epoch: 117, Loss: 0.5895, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 42, Epoch: 118, Loss: 0.5908, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 119, Loss: 0.5793, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 120, Loss: 0.5854, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 42, Epoch: 121, Loss: 0.5821, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 122, Loss: 0.5775, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 42, Epoch: 123, Loss: 0.5778, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 124, Loss: 0.5818, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 125, Loss: 0.5874, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 126, Loss: 0.5839, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 127, Loss: 0.5740, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 128, Loss: 0.5733, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 42, Epoch: 129, Loss: 0.5699, Val Acc: 0.7229, Test Acc: 0.7381
# Seed: 42, Epoch: 130, Loss: 0.5678, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 131, Loss: 0.5859, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 42, Epoch: 132, Loss: 0.5998, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 42, Epoch: 133, Loss: 0.6148, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 42, Epoch: 134, Loss: 0.5881, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 42, Epoch: 135, Loss: 0.5853, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 136, Loss: 0.5697, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 137, Loss: 0.5807, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 138, Loss: 0.5737, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 139, Loss: 0.5804, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 140, Loss: 0.5798, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 141, Loss: 0.5797, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 142, Loss: 0.5727, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 42, Epoch: 143, Loss: 0.5764, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 42, Epoch: 144, Loss: 0.5702, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 42, Epoch: 145, Loss: 0.5814, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 42, Epoch: 146, Loss: 0.5864, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 42, Epoch: 147, Loss: 0.5950, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 42, Epoch: 148, Loss: 0.5904, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 42, Epoch: 149, Loss: 0.5876, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 42, Epoch: 150, Loss: 0.5981, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 42, Epoch: 151, Loss: 0.5915, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 42, Epoch: 152, Loss: 0.5924, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 153, Loss: 0.5806, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 154, Loss: 0.5851, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 155, Loss: 0.5851, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 156, Loss: 0.5870, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 157, Loss: 0.5896, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 158, Loss: 0.5962, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 42, Epoch: 159, Loss: 0.5874, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 42, Epoch: 160, Loss: 0.5860, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 42, Epoch: 161, Loss: 0.5804, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 42, Epoch: 162, Loss: 0.5872, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 163, Loss: 0.5892, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 164, Loss: 0.5858, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 165, Loss: 0.5778, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 42, Epoch: 166, Loss: 0.5776, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 42, Epoch: 167, Loss: 0.5765, Val Acc: 0.7289, Test Acc: 0.7321
# Seed: 42, Epoch: 168, Loss: 0.5709, Val Acc: 0.7470, Test Acc: 0.7500
# Seed: 42, Epoch: 169, Loss: 0.5780, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 42, Epoch: 170, Loss: 0.5669, Val Acc: 0.7410, Test Acc: 0.7262
# Seed: 42, Epoch: 171, Loss: 0.5713, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 42, Epoch: 172, Loss: 0.5714, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 173, Loss: 0.5795, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 174, Loss: 0.5699, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 42, Epoch: 175, Loss: 0.5701, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 42, Epoch: 176, Loss: 0.5660, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 42, Epoch: 177, Loss: 0.6570, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 42, Epoch: 178, Loss: 0.5870, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 42, Epoch: 179, Loss: 0.5776, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 42, Epoch: 180, Loss: 0.5720, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 42, Epoch: 181, Loss: 0.5783, Val Acc: 0.6807, Test Acc: 0.7083
# Seed: 42, Epoch: 182, Loss: 0.5714, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 183, Loss: 0.5694, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 42, Epoch: 184, Loss: 0.5629, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 42, Epoch: 185, Loss: 0.5701, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 42, Epoch: 186, Loss: 0.5649, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 42, Epoch: 187, Loss: 0.5755, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 42, Epoch: 188, Loss: 0.5979, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 189, Loss: 0.5784, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 190, Loss: 0.5853, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 42, Epoch: 191, Loss: 0.5700, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 42, Epoch: 192, Loss: 0.5842, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 42, Epoch: 193, Loss: 0.5628, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 42, Epoch: 194, Loss: 0.5533, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 42, Epoch: 195, Loss: 0.5592, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 42, Epoch: 196, Loss: 0.5700, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 42, Epoch: 197, Loss: 0.5634, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 42, Epoch: 198, Loss: 0.5616, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 42, Epoch: 199, Loss: 0.5639, Val Acc: 0.7289, Test Acc: 0.7798
# Seed: 42, Epoch: 200, Loss: 0.5743, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 43, Epoch: 001, Loss: 0.6913, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 43, Epoch: 002, Loss: 0.6628, Val Acc: 0.6747, Test Acc: 0.6548
# Seed: 43, Epoch: 003, Loss: 0.6410, Val Acc: 0.6566, Test Acc: 0.6250
# Seed: 43, Epoch: 004, Loss: 0.6340, Val Acc: 0.6627, Test Acc: 0.6250
# Seed: 43, Epoch: 005, Loss: 0.6260, Val Acc: 0.6687, Test Acc: 0.6310
# Seed: 43, Epoch: 006, Loss: 0.6189, Val Acc: 0.6747, Test Acc: 0.6369
# Seed: 43, Epoch: 007, Loss: 0.6303, Val Acc: 0.6807, Test Acc: 0.6369
# Seed: 43, Epoch: 008, Loss: 0.6244, Val Acc: 0.6747, Test Acc: 0.6488
# Seed: 43, Epoch: 009, Loss: 0.6275, Val Acc: 0.6807, Test Acc: 0.6726
# Seed: 43, Epoch: 010, Loss: 0.6215, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 43, Epoch: 011, Loss: 0.6241, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 43, Epoch: 012, Loss: 0.6273, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 43, Epoch: 013, Loss: 0.6205, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 43, Epoch: 014, Loss: 0.6374, Val Acc: 0.7048, Test Acc: 0.6964
# Seed: 43, Epoch: 015, Loss: 0.6350, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 43, Epoch: 016, Loss: 0.6297, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 017, Loss: 0.6445, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 018, Loss: 0.6527, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 019, Loss: 0.6437, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 020, Loss: 0.6419, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 43, Epoch: 021, Loss: 0.6470, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 43, Epoch: 022, Loss: 0.6350, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 43, Epoch: 023, Loss: 0.6433, Val Acc: 0.7108, Test Acc: 0.7024
# Seed: 43, Epoch: 024, Loss: 0.6409, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 43, Epoch: 025, Loss: 0.6381, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 43, Epoch: 026, Loss: 0.6215, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 43, Epoch: 027, Loss: 0.6262, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 43, Epoch: 028, Loss: 0.6176, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 43, Epoch: 029, Loss: 0.6218, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 43, Epoch: 030, Loss: 0.6102, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 43, Epoch: 031, Loss: 0.6195, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 43, Epoch: 032, Loss: 0.6207, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 43, Epoch: 033, Loss: 0.6285, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 43, Epoch: 034, Loss: 0.6231, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 43, Epoch: 035, Loss: 0.6249, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 43, Epoch: 036, Loss: 0.6218, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 43, Epoch: 037, Loss: 0.6285, Val Acc: 0.6807, Test Acc: 0.7381
# Seed: 43, Epoch: 038, Loss: 0.6340, Val Acc: 0.6747, Test Acc: 0.7381
# Seed: 43, Epoch: 039, Loss: 0.6311, Val Acc: 0.6566, Test Acc: 0.7500
# Seed: 43, Epoch: 040, Loss: 0.6439, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 43, Epoch: 041, Loss: 0.6376, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 43, Epoch: 042, Loss: 0.6268, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 43, Epoch: 043, Loss: 0.6199, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 43, Epoch: 044, Loss: 0.6148, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 43, Epoch: 045, Loss: 0.6128, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 43, Epoch: 046, Loss: 0.6143, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 43, Epoch: 047, Loss: 0.6098, Val Acc: 0.6928, Test Acc: 0.6845
# Seed: 43, Epoch: 048, Loss: 0.6097, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 43, Epoch: 049, Loss: 0.6010, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 43, Epoch: 050, Loss: 0.6031, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 43, Epoch: 051, Loss: 0.5928, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 43, Epoch: 052, Loss: 0.5978, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 43, Epoch: 053, Loss: 0.6070, Val Acc: 0.6747, Test Acc: 0.7560
# Seed: 43, Epoch: 054, Loss: 0.6231, Val Acc: 0.6687, Test Acc: 0.7619
# Seed: 43, Epoch: 055, Loss: 0.6108, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 43, Epoch: 056, Loss: 0.6099, Val Acc: 0.6627, Test Acc: 0.7560
# Seed: 43, Epoch: 057, Loss: 0.6107, Val Acc: 0.6506, Test Acc: 0.7500
# Seed: 43, Epoch: 058, Loss: 0.6345, Val Acc: 0.6627, Test Acc: 0.7619
# Seed: 43, Epoch: 059, Loss: 0.6279, Val Acc: 0.6627, Test Acc: 0.7738
# Seed: 43, Epoch: 060, Loss: 0.6281, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 43, Epoch: 061, Loss: 0.6207, Val Acc: 0.6807, Test Acc: 0.7917
# Seed: 43, Epoch: 062, Loss: 0.6232, Val Acc: 0.6807, Test Acc: 0.7798
# Seed: 43, Epoch: 063, Loss: 0.6244, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 064, Loss: 0.6264, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 065, Loss: 0.6231, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 43, Epoch: 066, Loss: 0.6175, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 067, Loss: 0.6136, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 43, Epoch: 068, Loss: 0.6205, Val Acc: 0.6807, Test Acc: 0.7440
# Seed: 43, Epoch: 069, Loss: 0.6133, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 43, Epoch: 070, Loss: 0.6120, Val Acc: 0.6867, Test Acc: 0.7262
# Seed: 43, Epoch: 071, Loss: 0.6128, Val Acc: 0.6928, Test Acc: 0.7262
# Seed: 43, Epoch: 072, Loss: 0.6102, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 073, Loss: 0.6074, Val Acc: 0.6747, Test Acc: 0.7857
# Seed: 43, Epoch: 074, Loss: 0.6134, Val Acc: 0.6627, Test Acc: 0.7857
# Seed: 43, Epoch: 075, Loss: 0.6168, Val Acc: 0.6747, Test Acc: 0.7917
# Seed: 43, Epoch: 076, Loss: 0.6186, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 43, Epoch: 077, Loss: 0.6055, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 43, Epoch: 078, Loss: 0.6089, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 079, Loss: 0.6046, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 43, Epoch: 080, Loss: 0.6062, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 081, Loss: 0.6025, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 43, Epoch: 082, Loss: 0.5993, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 43, Epoch: 083, Loss: 0.6098, Val Acc: 0.6867, Test Acc: 0.7917
# Seed: 43, Epoch: 084, Loss: 0.6104, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 43, Epoch: 085, Loss: 0.6093, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 43, Epoch: 086, Loss: 0.6046, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 43, Epoch: 087, Loss: 0.6006, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 43, Epoch: 088, Loss: 0.5973, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 089, Loss: 0.5948, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 43, Epoch: 090, Loss: 0.6024, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 43, Epoch: 091, Loss: 0.5978, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 43, Epoch: 092, Loss: 0.6010, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 093, Loss: 0.6003, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 094, Loss: 0.5924, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 43, Epoch: 095, Loss: 0.5902, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 43, Epoch: 096, Loss: 0.5889, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 097, Loss: 0.5822, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 098, Loss: 0.5860, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 43, Epoch: 099, Loss: 0.5842, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 100, Loss: 0.5749, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 43, Epoch: 101, Loss: 0.6012, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 43, Epoch: 102, Loss: 0.6046, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 103, Loss: 0.6335, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 104, Loss: 0.6131, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 43, Epoch: 105, Loss: 0.5988, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 43, Epoch: 106, Loss: 0.5993, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 107, Loss: 0.5929, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 43, Epoch: 108, Loss: 0.6038, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 43, Epoch: 109, Loss: 0.5950, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 110, Loss: 0.6080, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 43, Epoch: 111, Loss: 0.5945, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 112, Loss: 0.5912, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 113, Loss: 0.5948, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 43, Epoch: 114, Loss: 0.5875, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 115, Loss: 0.5838, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 116, Loss: 0.5949, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 43, Epoch: 117, Loss: 0.6032, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 118, Loss: 0.5974, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 119, Loss: 0.5879, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 120, Loss: 0.5857, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 121, Loss: 0.5798, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 122, Loss: 0.5844, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 123, Loss: 0.5795, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 124, Loss: 0.5811, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 43, Epoch: 125, Loss: 0.5803, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 43, Epoch: 126, Loss: 0.5761, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 127, Loss: 0.5792, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 128, Loss: 0.5808, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 129, Loss: 0.5791, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 130, Loss: 0.5813, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 131, Loss: 0.5884, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 132, Loss: 0.6038, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 133, Loss: 0.6077, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 134, Loss: 0.6014, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 135, Loss: 0.5817, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 43, Epoch: 136, Loss: 0.5743, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 43, Epoch: 137, Loss: 0.5829, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 43, Epoch: 138, Loss: 0.5835, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 139, Loss: 0.5771, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 43, Epoch: 140, Loss: 0.5846, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 141, Loss: 0.5928, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 43, Epoch: 142, Loss: 0.5965, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 143, Loss: 0.6021, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 144, Loss: 0.5944, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 145, Loss: 0.5903, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 146, Loss: 0.5935, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 43, Epoch: 147, Loss: 0.5743, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 148, Loss: 0.5797, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 43, Epoch: 149, Loss: 0.5717, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 43, Epoch: 150, Loss: 0.5774, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 43, Epoch: 151, Loss: 0.5626, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 43, Epoch: 152, Loss: 0.5792, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 43, Epoch: 153, Loss: 0.5670, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 43, Epoch: 154, Loss: 0.5807, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 155, Loss: 0.5861, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 43, Epoch: 156, Loss: 0.5911, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 43, Epoch: 157, Loss: 0.5868, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 43, Epoch: 158, Loss: 0.5806, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 159, Loss: 0.5814, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 43, Epoch: 160, Loss: 0.5849, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 43, Epoch: 161, Loss: 0.5999, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 43, Epoch: 162, Loss: 0.6071, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 43, Epoch: 163, Loss: 0.5968, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 43, Epoch: 164, Loss: 0.5911, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 43, Epoch: 165, Loss: 0.5804, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 43, Epoch: 166, Loss: 0.5882, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 43, Epoch: 167, Loss: 0.5778, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 43, Epoch: 168, Loss: 0.5921, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 43, Epoch: 169, Loss: 0.5871, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 43, Epoch: 170, Loss: 0.5779, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 43, Epoch: 171, Loss: 0.5848, Val Acc: 0.7048, Test Acc: 0.7619
# Early stopping at epoch 171 for seed 43
# Seed: 44, Epoch: 001, Loss: 0.6884, Val Acc: 0.6446, Test Acc: 0.7738
# Seed: 44, Epoch: 002, Loss: 0.6537, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 003, Loss: 0.6339, Val Acc: 0.6747, Test Acc: 0.6488
# Seed: 44, Epoch: 004, Loss: 0.6313, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 44, Epoch: 005, Loss: 0.6230, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 44, Epoch: 006, Loss: 0.6403, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 007, Loss: 0.6417, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 008, Loss: 0.6456, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 009, Loss: 0.6388, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 44, Epoch: 010, Loss: 0.6412, Val Acc: 0.6928, Test Acc: 0.7083
# Seed: 44, Epoch: 011, Loss: 0.6291, Val Acc: 0.6988, Test Acc: 0.7024
# Seed: 44, Epoch: 012, Loss: 0.6319, Val Acc: 0.6747, Test Acc: 0.6964
# Seed: 44, Epoch: 013, Loss: 0.6215, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 014, Loss: 0.6309, Val Acc: 0.6867, Test Acc: 0.7024
# Seed: 44, Epoch: 015, Loss: 0.6176, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 44, Epoch: 016, Loss: 0.6286, Val Acc: 0.6988, Test Acc: 0.6905
# Seed: 44, Epoch: 017, Loss: 0.6168, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 018, Loss: 0.6282, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 019, Loss: 0.6315, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 44, Epoch: 020, Loss: 0.6187, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 021, Loss: 0.6281, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 022, Loss: 0.6286, Val Acc: 0.7048, Test Acc: 0.7083
# Seed: 44, Epoch: 023, Loss: 0.6303, Val Acc: 0.6867, Test Acc: 0.7083
# Seed: 44, Epoch: 024, Loss: 0.6280, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 025, Loss: 0.6438, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 026, Loss: 0.6366, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 027, Loss: 0.6402, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 028, Loss: 0.6460, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 029, Loss: 0.6357, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 030, Loss: 0.6458, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 031, Loss: 0.6503, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 032, Loss: 0.6517, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 033, Loss: 0.6491, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 034, Loss: 0.6408, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 035, Loss: 0.6389, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 036, Loss: 0.6409, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 037, Loss: 0.6332, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 038, Loss: 0.6386, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 44, Epoch: 039, Loss: 0.6412, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 44, Epoch: 040, Loss: 0.6468, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 041, Loss: 0.6344, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 44, Epoch: 042, Loss: 0.6334, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 44, Epoch: 043, Loss: 0.6285, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 44, Epoch: 044, Loss: 0.6332, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 44, Epoch: 045, Loss: 0.6215, Val Acc: 0.6928, Test Acc: 0.7381
# Seed: 44, Epoch: 046, Loss: 0.6430, Val Acc: 0.6627, Test Acc: 0.7679
# Seed: 44, Epoch: 047, Loss: 0.6485, Val Acc: 0.6566, Test Acc: 0.7619
# Seed: 44, Epoch: 048, Loss: 0.6474, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 44, Epoch: 049, Loss: 0.6462, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 050, Loss: 0.6408, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 051, Loss: 0.6281, Val Acc: 0.7289, Test Acc: 0.7083
# Seed: 44, Epoch: 052, Loss: 0.6289, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 053, Loss: 0.6345, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 44, Epoch: 054, Loss: 0.6250, Val Acc: 0.6988, Test Acc: 0.7202
# Seed: 44, Epoch: 055, Loss: 0.6288, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 056, Loss: 0.6366, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 44, Epoch: 057, Loss: 0.6333, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 058, Loss: 0.6245, Val Acc: 0.7289, Test Acc: 0.7202
# Seed: 44, Epoch: 059, Loss: 0.6207, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 44, Epoch: 060, Loss: 0.6186, Val Acc: 0.6807, Test Acc: 0.6905
# Seed: 44, Epoch: 061, Loss: 0.6144, Val Acc: 0.6747, Test Acc: 0.6905
# Seed: 44, Epoch: 062, Loss: 0.6167, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 44, Epoch: 063, Loss: 0.6205, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 064, Loss: 0.6220, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 065, Loss: 0.6193, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 44, Epoch: 066, Loss: 0.6290, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 067, Loss: 0.6217, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 44, Epoch: 068, Loss: 0.6278, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 069, Loss: 0.6220, Val Acc: 0.7229, Test Acc: 0.7083
# Seed: 44, Epoch: 070, Loss: 0.6236, Val Acc: 0.7289, Test Acc: 0.7143
# Seed: 44, Epoch: 071, Loss: 0.6193, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 44, Epoch: 072, Loss: 0.6168, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 44, Epoch: 073, Loss: 0.6034, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 074, Loss: 0.6070, Val Acc: 0.6988, Test Acc: 0.6964
# Seed: 44, Epoch: 075, Loss: 0.6043, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 076, Loss: 0.5982, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 077, Loss: 0.6027, Val Acc: 0.7289, Test Acc: 0.6964
# Seed: 44, Epoch: 078, Loss: 0.6012, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 079, Loss: 0.5986, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 44, Epoch: 080, Loss: 0.6043, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 44, Epoch: 081, Loss: 0.6009, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 44, Epoch: 082, Loss: 0.5948, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 44, Epoch: 083, Loss: 0.5903, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 44, Epoch: 084, Loss: 0.5971, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 085, Loss: 0.5934, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 44, Epoch: 086, Loss: 0.5945, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 44, Epoch: 087, Loss: 0.5886, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 44, Epoch: 088, Loss: 0.5926, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 089, Loss: 0.6020, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 44, Epoch: 090, Loss: 0.6041, Val Acc: 0.6687, Test Acc: 0.7560
# Seed: 44, Epoch: 091, Loss: 0.6159, Val Acc: 0.6747, Test Acc: 0.7798
# Seed: 44, Epoch: 092, Loss: 0.6050, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 44, Epoch: 093, Loss: 0.6017, Val Acc: 0.7349, Test Acc: 0.7024
# Seed: 44, Epoch: 094, Loss: 0.6068, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 095, Loss: 0.6106, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 096, Loss: 0.6170, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 44, Epoch: 097, Loss: 0.6126, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 098, Loss: 0.6151, Val Acc: 0.7289, Test Acc: 0.7024
# Seed: 44, Epoch: 099, Loss: 0.5997, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 44, Epoch: 100, Loss: 0.6001, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 101, Loss: 0.5976, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 102, Loss: 0.5849, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 103, Loss: 0.6116, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 44, Epoch: 104, Loss: 0.6160, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 44, Epoch: 105, Loss: 0.6237, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 44, Epoch: 106, Loss: 0.6133, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 107, Loss: 0.5996, Val Acc: 0.7229, Test Acc: 0.7024
# Seed: 44, Epoch: 108, Loss: 0.5954, Val Acc: 0.7229, Test Acc: 0.6845
# Seed: 44, Epoch: 109, Loss: 0.6061, Val Acc: 0.7229, Test Acc: 0.6845
# Seed: 44, Epoch: 110, Loss: 0.5926, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 44, Epoch: 111, Loss: 0.5930, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 112, Loss: 0.5998, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 113, Loss: 0.5983, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 114, Loss: 0.6042, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 44, Epoch: 115, Loss: 0.6031, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 44, Epoch: 116, Loss: 0.5966, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 117, Loss: 0.5925, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 44, Epoch: 118, Loss: 0.5867, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 44, Epoch: 119, Loss: 0.5908, Val Acc: 0.7229, Test Acc: 0.6964
# Seed: 44, Epoch: 120, Loss: 0.5836, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 44, Epoch: 121, Loss: 0.5956, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 122, Loss: 0.5915, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 44, Epoch: 123, Loss: 0.5983, Val Acc: 0.6807, Test Acc: 0.7738
# Seed: 44, Epoch: 124, Loss: 0.6076, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 44, Epoch: 125, Loss: 0.5946, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 44, Epoch: 126, Loss: 0.5958, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 44, Epoch: 127, Loss: 0.5987, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 128, Loss: 0.5914, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 129, Loss: 0.5950, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 44, Epoch: 130, Loss: 0.5906, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 44, Epoch: 131, Loss: 0.6020, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 132, Loss: 0.5869, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 133, Loss: 0.5848, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 134, Loss: 0.5892, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 44, Epoch: 135, Loss: 0.5786, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 44, Epoch: 136, Loss: 0.5786, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 137, Loss: 0.5783, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 138, Loss: 0.5771, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 139, Loss: 0.5825, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 44, Epoch: 140, Loss: 0.5905, Val Acc: 0.7108, Test Acc: 0.7798
# Seed: 44, Epoch: 141, Loss: 0.5963, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 142, Loss: 0.5855, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 143, Loss: 0.5778, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 44, Epoch: 144, Loss: 0.5789, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 44, Epoch: 145, Loss: 0.5815, Val Acc: 0.7349, Test Acc: 0.7619
# Seed: 44, Epoch: 146, Loss: 0.5996, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 44, Epoch: 147, Loss: 0.6465, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 148, Loss: 0.5912, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 149, Loss: 0.5876, Val Acc: 0.7108, Test Acc: 0.7083
# Seed: 44, Epoch: 150, Loss: 0.5937, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 44, Epoch: 151, Loss: 0.5892, Val Acc: 0.7048, Test Acc: 0.7262
# Seed: 44, Epoch: 152, Loss: 0.5835, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 44, Epoch: 153, Loss: 0.5807, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 154, Loss: 0.5862, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 155, Loss: 0.5874, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 156, Loss: 0.5909, Val Acc: 0.7289, Test Acc: 0.7440
# Seed: 44, Epoch: 157, Loss: 0.5919, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 158, Loss: 0.6005, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 159, Loss: 0.5888, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 160, Loss: 0.5912, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 161, Loss: 0.5766, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 44, Epoch: 162, Loss: 0.5858, Val Acc: 0.7108, Test Acc: 0.6845
# Seed: 44, Epoch: 163, Loss: 0.5844, Val Acc: 0.7108, Test Acc: 0.6964
# Seed: 44, Epoch: 164, Loss: 0.5771, Val Acc: 0.7048, Test Acc: 0.7500
# Seed: 44, Epoch: 165, Loss: 0.5747, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 166, Loss: 0.5718, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 167, Loss: 0.5807, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 44, Epoch: 168, Loss: 0.5751, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 169, Loss: 0.5683, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 44, Epoch: 170, Loss: 0.5678, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 44, Epoch: 171, Loss: 0.5808, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 44, Epoch: 172, Loss: 0.5678, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 44, Epoch: 173, Loss: 0.5888, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 44, Epoch: 174, Loss: 0.5955, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 44, Epoch: 175, Loss: 0.5797, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 44, Epoch: 176, Loss: 0.5869, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 44, Epoch: 177, Loss: 0.5819, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 178, Loss: 0.5803, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 44, Epoch: 179, Loss: 0.5743, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 44, Epoch: 180, Loss: 0.5726, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 44, Epoch: 181, Loss: 0.5810, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 182, Loss: 0.5790, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 44, Epoch: 183, Loss: 0.5804, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 44, Epoch: 184, Loss: 0.5798, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 185, Loss: 0.5730, Val Acc: 0.7349, Test Acc: 0.7381
# Seed: 44, Epoch: 186, Loss: 0.5608, Val Acc: 0.7169, Test Acc: 0.7262
# Seed: 44, Epoch: 187, Loss: 0.5638, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 44, Epoch: 188, Loss: 0.5651, Val Acc: 0.7349, Test Acc: 0.7440
# Seed: 44, Epoch: 189, Loss: 0.5621, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 44, Epoch: 190, Loss: 0.5635, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 44, Epoch: 191, Loss: 0.5617, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 192, Loss: 0.5578, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 193, Loss: 0.5666, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 44, Epoch: 194, Loss: 0.5533, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 195, Loss: 0.5539, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 44, Epoch: 196, Loss: 0.5589, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 44, Epoch: 197, Loss: 0.5908, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 44, Epoch: 198, Loss: 0.5664, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 44, Epoch: 199, Loss: 0.5591, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 44, Epoch: 200, Loss: 0.5831, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 45, Epoch: 001, Loss: 0.6878, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 002, Loss: 0.6751, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 003, Loss: 0.6697, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 004, Loss: 0.6534, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 005, Loss: 0.6398, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 006, Loss: 0.6339, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 007, Loss: 0.6327, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 008, Loss: 0.6300, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 009, Loss: 0.6437, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 010, Loss: 0.6293, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 45, Epoch: 011, Loss: 0.6395, Val Acc: 0.6687, Test Acc: 0.6250
# Seed: 45, Epoch: 012, Loss: 0.6385, Val Acc: 0.6807, Test Acc: 0.6369
# Seed: 45, Epoch: 013, Loss: 0.6462, Val Acc: 0.6747, Test Acc: 0.6488
# Seed: 45, Epoch: 014, Loss: 0.6481, Val Acc: 0.6747, Test Acc: 0.6488
# Seed: 45, Epoch: 015, Loss: 0.6425, Val Acc: 0.6807, Test Acc: 0.6607
# Seed: 45, Epoch: 016, Loss: 0.6425, Val Acc: 0.6747, Test Acc: 0.6845
# Seed: 45, Epoch: 017, Loss: 0.6470, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 018, Loss: 0.6481, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 019, Loss: 0.6447, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 020, Loss: 0.6432, Val Acc: 0.6867, Test Acc: 0.6964
# Seed: 45, Epoch: 021, Loss: 0.6407, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 45, Epoch: 022, Loss: 0.6367, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 45, Epoch: 023, Loss: 0.6382, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 45, Epoch: 024, Loss: 0.6249, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 45, Epoch: 025, Loss: 0.6345, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 45, Epoch: 026, Loss: 0.6377, Val Acc: 0.6867, Test Acc: 0.6845
# Seed: 45, Epoch: 027, Loss: 0.6324, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 45, Epoch: 028, Loss: 0.6364, Val Acc: 0.7169, Test Acc: 0.6964
# Seed: 45, Epoch: 029, Loss: 0.6340, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 45, Epoch: 030, Loss: 0.6346, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 45, Epoch: 031, Loss: 0.6328, Val Acc: 0.7048, Test Acc: 0.7143
# Seed: 45, Epoch: 032, Loss: 0.6346, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 45, Epoch: 033, Loss: 0.6267, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 45, Epoch: 034, Loss: 0.6379, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 035, Loss: 0.6239, Val Acc: 0.6988, Test Acc: 0.7083
# Seed: 45, Epoch: 036, Loss: 0.6153, Val Acc: 0.6928, Test Acc: 0.6964
# Seed: 45, Epoch: 037, Loss: 0.6240, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 45, Epoch: 038, Loss: 0.6184, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 039, Loss: 0.6115, Val Acc: 0.6807, Test Acc: 0.6964
# Seed: 45, Epoch: 040, Loss: 0.6094, Val Acc: 0.6867, Test Acc: 0.6905
# Seed: 45, Epoch: 041, Loss: 0.6142, Val Acc: 0.7169, Test Acc: 0.7083
# Seed: 45, Epoch: 042, Loss: 0.6154, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 45, Epoch: 043, Loss: 0.6251, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 45, Epoch: 044, Loss: 0.6303, Val Acc: 0.6807, Test Acc: 0.7262
# Seed: 45, Epoch: 045, Loss: 0.6394, Val Acc: 0.6627, Test Acc: 0.7262
# Seed: 45, Epoch: 046, Loss: 0.6416, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 45, Epoch: 047, Loss: 0.6277, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 45, Epoch: 048, Loss: 0.6391, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 45, Epoch: 049, Loss: 0.6309, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 45, Epoch: 050, Loss: 0.6286, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 45, Epoch: 051, Loss: 0.6254, Val Acc: 0.6988, Test Acc: 0.7321
# Seed: 45, Epoch: 052, Loss: 0.6184, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 45, Epoch: 053, Loss: 0.6203, Val Acc: 0.7229, Test Acc: 0.7202
# Seed: 45, Epoch: 054, Loss: 0.6183, Val Acc: 0.7048, Test Acc: 0.7202
# Seed: 45, Epoch: 055, Loss: 0.6074, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 45, Epoch: 056, Loss: 0.6095, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 45, Epoch: 057, Loss: 0.6212, Val Acc: 0.6867, Test Acc: 0.7619
# Seed: 45, Epoch: 058, Loss: 0.6096, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 45, Epoch: 059, Loss: 0.6283, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 45, Epoch: 060, Loss: 0.6161, Val Acc: 0.6867, Test Acc: 0.7738
# Seed: 45, Epoch: 061, Loss: 0.6198, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 45, Epoch: 062, Loss: 0.6224, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 45, Epoch: 063, Loss: 0.6201, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 064, Loss: 0.6116, Val Acc: 0.6988, Test Acc: 0.7500
# Seed: 45, Epoch: 065, Loss: 0.6172, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 066, Loss: 0.6040, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 45, Epoch: 067, Loss: 0.6110, Val Acc: 0.7108, Test Acc: 0.7262
# Seed: 45, Epoch: 068, Loss: 0.6082, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 45, Epoch: 069, Loss: 0.6157, Val Acc: 0.6867, Test Acc: 0.7679
# Seed: 45, Epoch: 070, Loss: 0.6243, Val Acc: 0.6747, Test Acc: 0.7619
# Seed: 45, Epoch: 071, Loss: 0.6260, Val Acc: 0.6867, Test Acc: 0.7798
# Seed: 45, Epoch: 072, Loss: 0.6150, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 45, Epoch: 073, Loss: 0.6156, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 074, Loss: 0.6047, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 45, Epoch: 075, Loss: 0.6085, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 076, Loss: 0.6079, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 45, Epoch: 077, Loss: 0.6106, Val Acc: 0.6807, Test Acc: 0.7619
# Seed: 45, Epoch: 078, Loss: 0.6314, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 45, Epoch: 079, Loss: 0.6097, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 45, Epoch: 080, Loss: 0.6008, Val Acc: 0.6928, Test Acc: 0.7202
# Seed: 45, Epoch: 081, Loss: 0.6067, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 082, Loss: 0.6096, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 45, Epoch: 083, Loss: 0.6227, Val Acc: 0.6867, Test Acc: 0.7857
# Seed: 45, Epoch: 084, Loss: 0.6208, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 45, Epoch: 085, Loss: 0.6102, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 45, Epoch: 086, Loss: 0.6127, Val Acc: 0.6928, Test Acc: 0.7440
# Seed: 45, Epoch: 087, Loss: 0.6086, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 45, Epoch: 088, Loss: 0.6134, Val Acc: 0.6928, Test Acc: 0.7976
# Seed: 45, Epoch: 089, Loss: 0.6279, Val Acc: 0.6988, Test Acc: 0.7917
# Seed: 45, Epoch: 090, Loss: 0.6260, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 45, Epoch: 091, Loss: 0.6236, Val Acc: 0.6928, Test Acc: 0.7619
# Seed: 45, Epoch: 092, Loss: 0.6321, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 45, Epoch: 093, Loss: 0.6202, Val Acc: 0.6988, Test Acc: 0.7798
# Seed: 45, Epoch: 094, Loss: 0.6098, Val Acc: 0.6928, Test Acc: 0.7857
# Seed: 45, Epoch: 095, Loss: 0.6067, Val Acc: 0.6928, Test Acc: 0.7738
# Seed: 45, Epoch: 096, Loss: 0.6107, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 45, Epoch: 097, Loss: 0.6266, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 45, Epoch: 098, Loss: 0.6541, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 45, Epoch: 099, Loss: 0.5998, Val Acc: 0.6988, Test Acc: 0.7143
# Seed: 45, Epoch: 100, Loss: 0.5959, Val Acc: 0.6867, Test Acc: 0.6726
# Seed: 45, Epoch: 101, Loss: 0.6037, Val Acc: 0.6807, Test Acc: 0.6667
# Seed: 45, Epoch: 102, Loss: 0.6041, Val Acc: 0.6807, Test Acc: 0.6726
# Seed: 45, Epoch: 103, Loss: 0.5954, Val Acc: 0.6988, Test Acc: 0.6845
# Seed: 45, Epoch: 104, Loss: 0.5927, Val Acc: 0.7108, Test Acc: 0.7143
# Seed: 45, Epoch: 105, Loss: 0.5923, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 45, Epoch: 106, Loss: 0.5883, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 45, Epoch: 107, Loss: 0.5925, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 45, Epoch: 108, Loss: 0.5950, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 45, Epoch: 109, Loss: 0.5968, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 45, Epoch: 110, Loss: 0.5950, Val Acc: 0.7048, Test Acc: 0.7798
# Seed: 45, Epoch: 111, Loss: 0.6057, Val Acc: 0.6928, Test Acc: 0.7798
# Seed: 45, Epoch: 112, Loss: 0.5959, Val Acc: 0.6988, Test Acc: 0.7679
# Seed: 45, Epoch: 113, Loss: 0.5983, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 45, Epoch: 114, Loss: 0.5909, Val Acc: 0.7108, Test Acc: 0.7560
# ...
# Seed: 45, Epoch: 175, Loss: 0.5784, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 45, Epoch: 176, Loss: 0.5725, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 177, Loss: 0.5884, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 45, Epoch: 178, Loss: 0.5805, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 45, Epoch: 179, Loss: 0.5701, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 45, Epoch: 180, Loss: 0.5766, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 45, Epoch: 181, Loss: 0.5802, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 182, Loss: 0.5676, Val Acc: 0.7048, Test Acc: 0.7619
# Seed: 45, Epoch: 183, Loss: 0.5712, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 45, Epoch: 184, Loss: 0.5622, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 45, Epoch: 185, Loss: 0.5677, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 186, Loss: 0.5580, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 45, Epoch: 187, Loss: 0.5628, Val Acc: 0.7349, Test Acc: 0.7262
# Seed: 45, Epoch: 188, Loss: 0.5516, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 45, Epoch: 189, Loss: 0.5677, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 45, Epoch: 190, Loss: 0.5678, Val Acc: 0.7108, Test Acc: 0.7738
# Seed: 45, Epoch: 191, Loss: 0.5984, Val Acc: 0.7169, Test Acc: 0.7798
# Seed: 45, Epoch: 192, Loss: 0.5908, Val Acc: 0.7048, Test Acc: 0.7738
# Seed: 45, Epoch: 193, Loss: 0.5825, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 45, Epoch: 194, Loss: 0.5711, Val Acc: 0.7108, Test Acc: 0.7202
# Seed: 45, Epoch: 195, Loss: 0.5728, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 45, Epoch: 196, Loss: 0.5712, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 45, Epoch: 197, Loss: 0.5665, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 45, Epoch: 198, Loss: 0.5813, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 45, Epoch: 199, Loss: 0.5832, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 45, Epoch: 200, Loss: 0.5845, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 001, Loss: 0.6781, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 002, Loss: 0.6618, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 003, Loss: 0.6586, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 004, Loss: 0.6425, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 005, Loss: 0.6443, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 006, Loss: 0.6520, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 007, Loss: 0.6467, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 008, Loss: 0.6470, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 009, Loss: 0.6422, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 010, Loss: 0.6385, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 011, Loss: 0.6515, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 012, Loss: 0.6512, Val Acc: 0.6446, Test Acc: 0.6190
# Seed: 46, Epoch: 013, Loss: 0.6472, Val Acc: 0.6687, Test Acc: 0.6190
# Seed: 46, Epoch: 014, Loss: 0.6600, Val Acc: 0.6807, Test Acc: 0.6369
# Seed: 46, Epoch: 015, Loss: 0.6584, Val Acc: 0.6807, Test Acc: 0.6488
# Seed: 46, Epoch: 016, Loss: 0.6584, Val Acc: 0.6867, Test Acc: 0.6250
# Seed: 46, Epoch: 017, Loss: 0.6515, Val Acc: 0.6807, Test Acc: 0.6250
# Seed: 46, Epoch: 018, Loss: 0.6482, Val Acc: 0.6807, Test Acc: 0.6250
# Seed: 46, Epoch: 019, Loss: 0.6448, Val Acc: 0.6867, Test Acc: 0.6250
# Seed: 46, Epoch: 020, Loss: 0.6471, Val Acc: 0.6867, Test Acc: 0.6310
# Seed: 46, Epoch: 021, Loss: 0.6480, Val Acc: 0.6867, Test Acc: 0.6310
# Seed: 46, Epoch: 022, Loss: 0.6473, Val Acc: 0.6807, Test Acc: 0.6607
# Seed: 46, Epoch: 023, Loss: 0.6460, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 46, Epoch: 024, Loss: 0.6520, Val Acc: 0.6807, Test Acc: 0.6845
# Seed: 46, Epoch: 025, Loss: 0.6472, Val Acc: 0.6747, Test Acc: 0.6786
# Seed: 46, Epoch: 026, Loss: 0.6370, Val Acc: 0.6747, Test Acc: 0.6786
# Seed: 46, Epoch: 027, Loss: 0.6386, Val Acc: 0.6747, Test Acc: 0.6667
# Seed: 46, Epoch: 028, Loss: 0.6276, Val Acc: 0.6807, Test Acc: 0.6548
# Seed: 46, Epoch: 029, Loss: 0.6193, Val Acc: 0.6807, Test Acc: 0.6488
# Seed: 46, Epoch: 030, Loss: 0.6284, Val Acc: 0.6867, Test Acc: 0.6667
# Seed: 46, Epoch: 031, Loss: 0.6207, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 46, Epoch: 032, Loss: 0.6142, Val Acc: 0.7229, Test Acc: 0.7262
# Seed: 46, Epoch: 033, Loss: 0.6274, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 034, Loss: 0.6325, Val Acc: 0.7229, Test Acc: 0.7143
# Seed: 46, Epoch: 035, Loss: 0.6178, Val Acc: 0.7169, Test Acc: 0.7202
# Seed: 46, Epoch: 036, Loss: 0.6241, Val Acc: 0.6807, Test Acc: 0.7024
# Seed: 46, Epoch: 037, Loss: 0.6193, Val Acc: 0.6687, Test Acc: 0.6964
# Seed: 46, Epoch: 038, Loss: 0.6142, Val Acc: 0.6928, Test Acc: 0.7024
# Seed: 46, Epoch: 039, Loss: 0.6175, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 040, Loss: 0.6157, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 041, Loss: 0.6216, Val Acc: 0.7169, Test Acc: 0.7143
# Seed: 46, Epoch: 042, Loss: 0.6129, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 043, Loss: 0.6158, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 044, Loss: 0.6202, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 045, Loss: 0.6256, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 046, Loss: 0.6172, Val Acc: 0.6928, Test Acc: 0.7679
# Seed: 46, Epoch: 047, Loss: 0.6165, Val Acc: 0.6687, Test Acc: 0.7679
# Seed: 46, Epoch: 048, Loss: 0.6288, Val Acc: 0.6627, Test Acc: 0.7500
# Seed: 46, Epoch: 049, Loss: 0.6248, Val Acc: 0.6988, Test Acc: 0.7738
# Seed: 46, Epoch: 050, Loss: 0.6281, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 051, Loss: 0.6192, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 052, Loss: 0.6197, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 053, Loss: 0.6184, Val Acc: 0.7048, Test Acc: 0.7321
# Seed: 46, Epoch: 054, Loss: 0.6093, Val Acc: 0.7108, Test Acc: 0.7321
# Seed: 46, Epoch: 055, Loss: 0.6145, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 056, Loss: 0.6198, Val Acc: 0.6867, Test Acc: 0.7500
# Seed: 46, Epoch: 057, Loss: 0.6115, Val Acc: 0.6807, Test Acc: 0.7679
# Seed: 46, Epoch: 058, Loss: 0.6184, Val Acc: 0.6928, Test Acc: 0.7560
# Seed: 46, Epoch: 059, Loss: 0.6111, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 060, Loss: 0.6047, Val Acc: 0.6928, Test Acc: 0.7500
# Seed: 46, Epoch: 061, Loss: 0.6123, Val Acc: 0.6807, Test Acc: 0.7560
# Seed: 46, Epoch: 062, Loss: 0.6021, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 063, Loss: 0.6042, Val Acc: 0.6988, Test Acc: 0.7560
# Seed: 46, Epoch: 064, Loss: 0.6049, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 065, Loss: 0.5967, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 066, Loss: 0.5965, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 067, Loss: 0.5957, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 068, Loss: 0.5948, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 069, Loss: 0.5953, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 46, Epoch: 070, Loss: 0.6004, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 071, Loss: 0.6012, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 072, Loss: 0.5911, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 46, Epoch: 073, Loss: 0.5881, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 074, Loss: 0.5921, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 075, Loss: 0.5912, Val Acc: 0.7108, Test Acc: 0.7679
# Seed: 46, Epoch: 076, Loss: 0.5863, Val Acc: 0.6988, Test Acc: 0.7619
# Seed: 46, Epoch: 077, Loss: 0.6058, Val Acc: 0.6867, Test Acc: 0.7321
# Seed: 46, Epoch: 078, Loss: 0.6425, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 079, Loss: 0.6237, Val Acc: 0.7048, Test Acc: 0.7679
# Seed: 46, Epoch: 080, Loss: 0.6062, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 081, Loss: 0.5954, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 082, Loss: 0.5977, Val Acc: 0.6867, Test Acc: 0.7440
# Seed: 46, Epoch: 083, Loss: 0.5893, Val Acc: 0.6988, Test Acc: 0.7440
# Seed: 46, Epoch: 084, Loss: 0.5907, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 085, Loss: 0.5959, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 086, Loss: 0.5842, Val Acc: 0.7289, Test Acc: 0.7679
# Seed: 46, Epoch: 087, Loss: 0.6020, Val Acc: 0.7229, Test Acc: 0.7679
# Seed: 46, Epoch: 088, Loss: 0.6043, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 089, Loss: 0.5960, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 090, Loss: 0.6108, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 46, Epoch: 091, Loss: 0.6008, Val Acc: 0.7108, Test Acc: 0.7619
# Seed: 46, Epoch: 092, Loss: 0.5975, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 093, Loss: 0.5946, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 094, Loss: 0.5910, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 095, Loss: 0.5920, Val Acc: 0.7108, Test Acc: 0.7440
# Seed: 46, Epoch: 096, Loss: 0.5996, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 097, Loss: 0.5906, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 098, Loss: 0.6178, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 099, Loss: 0.6185, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 100, Loss: 0.6181, Val Acc: 0.7108, Test Acc: 0.7560
# Seed: 46, Epoch: 101, Loss: 0.6086, Val Acc: 0.7169, Test Acc: 0.7738
# Seed: 46, Epoch: 102, Loss: 0.5967, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 46, Epoch: 103, Loss: 0.5881, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 104, Loss: 0.5992, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 105, Loss: 0.5859, Val Acc: 0.7229, Test Acc: 0.7321
# Seed: 46, Epoch: 106, Loss: 0.5835, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 46, Epoch: 107, Loss: 0.5779, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 108, Loss: 0.5811, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 109, Loss: 0.5841, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 110, Loss: 0.5778, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 111, Loss: 0.5753, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 112, Loss: 0.5749, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 46, Epoch: 113, Loss: 0.5853, Val Acc: 0.7048, Test Acc: 0.7560
# Seed: 46, Epoch: 114, Loss: 0.6104, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 115, Loss: 0.5878, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 116, Loss: 0.5720, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 117, Loss: 0.5764, Val Acc: 0.6867, Test Acc: 0.7381
# Seed: 46, Epoch: 118, Loss: 0.5916, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 119, Loss: 0.5785, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 120, Loss: 0.5838, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 46, Epoch: 121, Loss: 0.5957, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 122, Loss: 0.5975, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 123, Loss: 0.6003, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 124, Loss: 0.6016, Val Acc: 0.7349, Test Acc: 0.7679
# Seed: 46, Epoch: 125, Loss: 0.5887, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 126, Loss: 0.5847, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 127, Loss: 0.5839, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 128, Loss: 0.5849, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 129, Loss: 0.5797, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 130, Loss: 0.5811, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 131, Loss: 0.5719, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 132, Loss: 0.5791, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 133, Loss: 0.5769, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 134, Loss: 0.5775, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 135, Loss: 0.5754, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 136, Loss: 0.5751, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 137, Loss: 0.5633, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 138, Loss: 0.5695, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 139, Loss: 0.5675, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 140, Loss: 0.5694, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 141, Loss: 0.5658, Val Acc: 0.7229, Test Acc: 0.7440
# Seed: 46, Epoch: 142, Loss: 0.5633, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 143, Loss: 0.5671, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 46, Epoch: 144, Loss: 0.5814, Val Acc: 0.7410, Test Acc: 0.7738
# Seed: 46, Epoch: 145, Loss: 0.5768, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 146, Loss: 0.6059, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 147, Loss: 0.5983, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 148, Loss: 0.5914, Val Acc: 0.7289, Test Acc: 0.7738
# Seed: 46, Epoch: 149, Loss: 0.5808, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 150, Loss: 0.5747, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 151, Loss: 0.5632, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 152, Loss: 0.5647, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 153, Loss: 0.5674, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 154, Loss: 0.5662, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 155, Loss: 0.5684, Val Acc: 0.7349, Test Acc: 0.7560
# Seed: 46, Epoch: 156, Loss: 0.5671, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 157, Loss: 0.5721, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 158, Loss: 0.5656, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 46, Epoch: 159, Loss: 0.5728, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 46, Epoch: 160, Loss: 0.5792, Val Acc: 0.7169, Test Acc: 0.7679
# Seed: 46, Epoch: 161, Loss: 0.6030, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 162, Loss: 0.6315, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 163, Loss: 0.5808, Val Acc: 0.7169, Test Acc: 0.7560
# Seed: 46, Epoch: 164, Loss: 0.5758, Val Acc: 0.7048, Test Acc: 0.7381
# Seed: 46, Epoch: 165, Loss: 0.5861, Val Acc: 0.7048, Test Acc: 0.7440
# Seed: 46, Epoch: 166, Loss: 0.5730, Val Acc: 0.6988, Test Acc: 0.7381
# Seed: 46, Epoch: 167, Loss: 0.5819, Val Acc: 0.7229, Test Acc: 0.7500
# Seed: 46, Epoch: 168, Loss: 0.5844, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 169, Loss: 0.5824, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 170, Loss: 0.5813, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 171, Loss: 0.5741, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 172, Loss: 0.5732, Val Acc: 0.6988, Test Acc: 0.7262
# Seed: 46, Epoch: 173, Loss: 0.5705, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 174, Loss: 0.5788, Val Acc: 0.6928, Test Acc: 0.7321
# Seed: 46, Epoch: 175, Loss: 0.5716, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 176, Loss: 0.5713, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 46, Epoch: 177, Loss: 0.5851, Val Acc: 0.7229, Test Acc: 0.7738
# Seed: 46, Epoch: 178, Loss: 0.5842, Val Acc: 0.7349, Test Acc: 0.7500
# Seed: 46, Epoch: 179, Loss: 0.5788, Val Acc: 0.7169, Test Acc: 0.7321
# Seed: 46, Epoch: 180, Loss: 0.5822, Val Acc: 0.7108, Test Acc: 0.7381
# Seed: 46, Epoch: 181, Loss: 0.5722, Val Acc: 0.7169, Test Acc: 0.7381
# Seed: 46, Epoch: 182, Loss: 0.5779, Val Acc: 0.7289, Test Acc: 0.7500
# Seed: 46, Epoch: 183, Loss: 0.5801, Val Acc: 0.7410, Test Acc: 0.7679
# Seed: 46, Epoch: 184, Loss: 0.5872, Val Acc: 0.7410, Test Acc: 0.7679
# Seed: 46, Epoch: 185, Loss: 0.5878, Val Acc: 0.7410, Test Acc: 0.7679
# Seed: 46, Epoch: 186, Loss: 0.5767, Val Acc: 0.7349, Test Acc: 0.7738
# Seed: 46, Epoch: 187, Loss: 0.5784, Val Acc: 0.7169, Test Acc: 0.7619
# Seed: 46, Epoch: 188, Loss: 0.5774, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 189, Loss: 0.5635, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 190, Loss: 0.5698, Val Acc: 0.7169, Test Acc: 0.7500
# Seed: 46, Epoch: 191, Loss: 0.5675, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 192, Loss: 0.5739, Val Acc: 0.7169, Test Acc: 0.7440
# Seed: 46, Epoch: 193, Loss: 0.5760, Val Acc: 0.7108, Test Acc: 0.7500
# Seed: 46, Epoch: 194, Loss: 0.5724, Val Acc: 0.7229, Test Acc: 0.7560
# Seed: 46, Epoch: 195, Loss: 0.5802, Val Acc: 0.7289, Test Acc: 0.7560
# Seed: 46, Epoch: 196, Loss: 0.5748, Val Acc: 0.7289, Test Acc: 0.7619
# Seed: 46, Epoch: 197, Loss: 0.5762, Val Acc: 0.7229, Test Acc: 0.7619
# Seed: 46, Epoch: 198, Loss: 0.5719, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 46, Epoch: 199, Loss: 0.5668, Val Acc: 0.7289, Test Acc: 0.7381
# Seed: 46, Epoch: 200, Loss: 0.5789, Val Acc: 0.7289, Test Acc: 0.7440
# Average Time: 56.25 seconds
# Var Time: 11.75 seconds
# Average Memory: 210.80 MB
# Average Best Val Acc: 0.7361
# Std Best Test Acc: 0.0249
# Average Test Acc: 0.7345

# %% [markdown]
# ## Dense AsymCheegerCutPooling with HierarchicalGCN (2023)

# %%
from torch_geometric.datasets import TUDataset
import torch_geometric.transforms as T
from torch_geometric.data import DenseDataLoader
max_nodes = 150
data_path = "/data/zeyu/Pooling/1"

dataset_PROTEINS = TUDataset(
    data_path,
    name="PROTEINS",
    transform=T.ToDense(max_nodes),
    use_node_attr=True,
    pre_filter=lambda data: data.num_nodes <= max_nodes,
)
dataset_PROTEINS = dataset_PROTEINS.shuffle()
dataset_size = len(dataset_PROTEINS)
train_size = int(dataset_size * 0.7)
val_size = int(dataset_size * 0.15)
test_size = dataset_size - train_size - val_size

train_dataset = dataset_PROTEINS[:train_size]
val_dataset = dataset_PROTEINS[train_size:train_size+val_size]
test_dataset = dataset_PROTEINS[train_size+val_size:]

train_loader = DenseDataLoader(train_dataset, batch_size=256, shuffle=True)
valid_loader = DenseDataLoader(val_dataset, batch_size=256, shuffle=False)
test_loader = DenseDataLoader(test_dataset, batch_size=256, shuffle=False)

# %%
from typing import List, Optional, Tuple, Union
import math
import torch
from torch import Tensor
from torch_geometric.nn.models.mlp import Linear
from torch_geometric.nn.resolver import activation_resolver
from torch_geometric.nn import BatchNorm

class AsymCheegerCutPool(torch.nn.Module):
    r"""
    The asymmetric cheeger cut pooling layer from the `"Total Variation Graph Neural Networks"
    <https://arxiv.org/abs/2211.06218>`_ paper.

    Args:
        k (int):
            Number of clusters or output nodes
        mlp_channels (int, list of int):
            Number of hidden units for each hidden layer in the MLP used to
            compute cluster assignments. First integer must match the number
            of input channels.
        mlp_activation (any):
            Activation function between hidden layers of the MLP.
            Must be compatible with `torch_geometric.nn.resolver`.
        return_selection (bool):
            Whether to return selection matrix. Cannot not  be False
            if `return_pooled_graph` is False. (default: :obj:`False`)
        return_pooled_graph (bool):
            Whether to return pooled node features and adjacency.
            Cannot be False if `return_selection` is False. (default: :obj:`True`)
        bias (bool):
            whether to add a bias term to the MLP layers. (default: :obj:`True`)
        totvar_coeff (float):
            Coefficient for graph total variation loss component. (default: :obj:`1.0`)
        balance_coeff (float):
            Coefficient for asymmetric norm loss component. (default: :obj:`1.0`)
    """

    def __init__(self,
                 k: int,
                 mlp_channels: Union[int, List[int]],
                 mlp_activation="relu",
                 return_selection: bool = False,
                 return_pooled_graph: bool = True,
                 bias: bool = True,
                 totvar_coeff: float = 1.0,
                 balance_coeff: float = 1.0,
                 ):
        super().__init__()

        if not return_selection and not return_pooled_graph:
            raise ValueError("return_selection and return_pooled_graph can not both be False")

        if isinstance(mlp_channels, int):
            mlp_channels = [mlp_channels]

        act = activation_resolver(mlp_activation)
        in_channels = mlp_channels[0]
        self.mlp = torch.nn.Sequential()
        for channels in mlp_channels[1:]:
            self.mlp.append(Linear(in_channels, channels, bias=bias))
            in_channels = channels
            self.mlp.append(act)


        self.mlp.append(Linear(in_channels, k))
        self.k = k
        self.return_selection = return_selection
        self.return_pooled_graph = return_pooled_graph
        self.totvar_coeff = totvar_coeff
        self.balance_coeff = balance_coeff

        self.reset_parameters()

    def reset_parameters(self):
        for layer in self.mlp:
            if isinstance(layer, Linear):
                torch.nn.init.xavier_uniform(layer.weight)
                torch.nn.init.zeros_(layer.bias)

    def forward(
        self,
        x: Tensor,
        adj: Tensor,
        mask: Optional[Tensor] = None,
    ) -> Tuple[Tensor, Tensor, Tensor, Tensor, Tensor, Tensor]:
        r"""
        Args:
            x (Tensor):
                Node feature tensor :math:`\mathbf{X} \in \mathbb{R}^{B \times N \times F}`
                with batch-size :math:`B`, (maximum) number of nodes :math:`N` for each graph,
                and feature dimension :math:`F`. Note that the cluster assignment matrix
                :math:`\mathbf{S} \in \mathbb{R}^{B \times N \times C}` is
                being created within this method.
            adj (Tensor):
                Adjacency tensor :math:`\mathbf{A} \in \mathbb{R}^{B \times N \times N}`.
            mask (BoolTensor, optional):
                Mask matrix :math:`\mathbf{M} \in {\{ 0, 1 \}}^{B \times N}`
                indicating the valid nodes for each graph. (default: :obj:`None`)

        :rtype: (:class:`Tensor`, :class:`Tensor`, :class:`Tensor`,
            :class:`Tensor`, :class:`Tensor`, :class:`Tensor`)
        """
        x = x.unsqueeze(0) if x.dim() == 2 else x
        adj = adj.unsqueeze(0) if adj.dim() == 2 else adj

        s = self.mlp(x)
        s = torch.softmax(s, dim=-1)

        batch_size, n_nodes, _ = x.size()

        if mask is not None:
            mask = mask.view(batch_size, n_nodes, 1).to(x.dtype)
            x, s = x * mask, s * mask

        # Pooled features and adjacency
        if self.return_pooled_graph:
            x_pool = torch.matmul(s.transpose(1, 2), x)
            adj_pool = torch.matmul(torch.matmul(s.transpose(1, 2), adj), s)

        # Total variation loss
        tv_loss = self.totvar_coeff*torch.mean(self.totvar_loss(adj, s))

        # Balance loss
        bal_loss = self.balance_coeff*torch.mean(self.balance_loss(s))

        if self.return_selection and self.return_pooled_graph:
            return s, x_pool, adj_pool, tv_loss, bal_loss
        elif self.return_selection and not self.return_pooled_graph:
            return s, tv_loss, bal_loss
        else:
            return x_pool, adj_pool, tv_loss, bal_loss

    def totvar_loss(self, adj, s):
        l1_norm = torch.sum(torch.abs(s[..., None, :] - s[:, None, ...]), dim=-1)

        loss = torch.sum(adj * l1_norm, dim=(-1, -2))

        # Normalize loss
        n_edges = torch.count_nonzero(adj, dim=(-1, -2))
        loss *= 1 / (2 * n_edges)

        return loss

    def balance_loss(self, s):
        n_nodes = s.size()[-2]

        # k-quantile
        idx = int(math.floor(n_nodes / self.k))
        quant = torch.sort(s, dim=-2, descending=True)[0][:, idx, :] # shape [B, K]

        # Asymmetric l1-norm
        loss = s - torch.unsqueeze(quant, dim=1)
        loss = (loss >= 0) * (self.k - 1) * loss + (loss < 0) * loss * -1
        loss = torch.sum(loss, dim=(-1, -2)) # shape [B]
        loss = 1 / (n_nodes * (self.k - 1)) * (n_nodes * (self.k - 1) - loss)

        return loss

# %%
from torch_geometric.nn import SAGEConv

import os.path as osp
import time
from math import ceil

import torch
import torch.nn.functional as F

import torch_geometric.transforms as T
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DenseDataLoader
from torch_geometric.nn import DenseSAGEConv, dense_diff_pool

dataset = dataset_PROTEINS
dataset = dataset.shuffle()
N = 150
mp_layers = 1
mp_channels = 64
mp_activation = "relu"
delta_coeff = 2.0

mlp_hidden_layers = 1
mlp_hidden_channels = 64
mlp_activation = "relu"
totvar_coeff = 0.5
balance_coeff = 0.5

epochs = 100
batch_size = 16
learning_rate = 5e-4
l2_reg_val = 0
patience = 10

class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, normalize=False, lin=True):
        super().__init__()

        self.conv1 = DenseSAGEConv(in_channels, hidden_channels, normalize)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = DenseSAGEConv(hidden_channels, hidden_channels, normalize)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = DenseSAGEConv(hidden_channels, out_channels, normalize)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        if lin:
            self.lin = torch.nn.Linear(out_channels, out_channels)
        else:
            self.lin = None

    def bn(self, i, x):
        batch_size, num_nodes, num_channels = x.size()
        x = x.view(-1, num_channels)
        x = getattr(self, f'bn{i}')(x)
        x = x.view(batch_size, num_nodes, num_channels)
        return x

    def forward(self, x, adj, mask=None):
        x = self.bn(1, self.conv1(x, adj, mask).relu())
        x = self.bn(2, self.conv2(x, adj, mask).relu())
        x = self.bn(3, self.conv3(x, adj, mask).relu())

        if self.lin is not None:
            x = self.lin(x).relu()

        return x


class Net_AsymCheegerCut(torch.nn.Module):
    def __init__(self):
        super().__init__()

        num_nodes = 64
        self.gnn1_pool = GNN(dataset.num_features, 64, num_nodes)
        self.gnn1_embed = DenseSAGEConv(dataset.num_features, 64)

        num_nodes = 64
        self.gnn2_pool = GNN(64, 64, num_nodes)
        self.gnn2_embed = DenseSAGEConv(64, 64)

        self.gnn3_embed = DenseSAGEConv(64, 64)

        self.lin1 = torch.nn.Linear(64, 32)
        self.lin2 = torch.nn.Linear(32, dataset.num_classes)

        self.pool1 = AsymCheegerCutPool(int(N//2),
                           mlp_channels=[mp_channels] +
                                [mlp_hidden_channels for _ in range(mlp_hidden_layers)],
                           mlp_activation=mlp_activation,
                           totvar_coeff=totvar_coeff,
                           balance_coeff=balance_coeff,
                           return_selection=False,
                           return_pooled_graph=True)
        self.pool2 = AsymCheegerCutPool(int(N//2),
                           mlp_channels=[mp_channels] +
                                [mlp_hidden_channels for _ in range(mlp_hidden_layers)],
                           mlp_activation=mlp_activation,
                           totvar_coeff=totvar_coeff,
                           balance_coeff=balance_coeff,
                           return_selection=False,
                           return_pooled_graph=True)


    def forward(self, x, adj, mask=None):
        s = self.gnn1_pool(x, adj, mask)
        x = self.gnn1_embed(x, adj, mask)
        x = F.relu(x)

        x, adj, tv1, bal1 = self.pool1(x, adj, mask=None)
        #x = pool_output1.x_pool
        #adj = pool_output1.adj_pool

        s = self.gnn2_pool(x, adj)
        x = self.gnn2_embed(x, adj)
        x = F.relu(x)

        x, adj, tv1, bal1 = self.pool2(x, adj, mask=None)
        #x = pool_output1.x_pool
        #adj = pool_output1.adj_pool

        x = self.gnn3_embed(x, adj)
        x = F.relu(x)

        x = x.mean(dim=1)
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=1)

if torch.cuda.is_available():
    device = torch.device('cuda')
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

model = Net_AsymCheegerCut().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x, data.adj, data.mask)
        loss = F.nll_loss(output, data.y.view(-1))
        loss.backward()
        total_loss += data.y.size(0) * float(loss)
        optimizer.step()
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        output = model(data.x, data.adj, data.mask)
        pred = output.max(dim=1)[1]
        correct += int(pred.eq(data.y.view(-1)).sum())
    return correct / len(loader.dataset)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = Net_AsymCheegerCut().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6618, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 002, Loss: 0.6240, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 003, Loss: 0.6241, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 004, Loss: 0.6144, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 005, Loss: 0.6109, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 006, Loss: 0.6054, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 42, Epoch: 007, Loss: 0.6003, Val Acc: 0.7037, Test Acc: 0.6463
# Seed: 42, Epoch: 008, Loss: 0.5970, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 42, Epoch: 009, Loss: 0.5940, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 42, Epoch: 010, Loss: 0.5879, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 011, Loss: 0.5783, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 012, Loss: 0.5731, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 42, Epoch: 013, Loss: 0.5676, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 014, Loss: 0.5643, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 015, Loss: 0.5596, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 42, Epoch: 016, Loss: 0.5489, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 42, Epoch: 017, Loss: 0.5471, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 018, Loss: 0.5433, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 019, Loss: 0.5352, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 020, Loss: 0.5344, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 021, Loss: 0.5304, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 022, Loss: 0.5267, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 023, Loss: 0.5324, Val Acc: 0.7284, Test Acc: 0.7683
# Seed: 42, Epoch: 024, Loss: 0.5376, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 42, Epoch: 025, Loss: 0.5261, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 026, Loss: 0.5212, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 027, Loss: 0.5200, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 42, Epoch: 028, Loss: 0.5170, Val Acc: 0.7284, Test Acc: 0.7805
# Seed: 42, Epoch: 029, Loss: 0.5248, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 42, Epoch: 030, Loss: 0.5098, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 42, Epoch: 031, Loss: 0.5027, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 42, Epoch: 032, Loss: 0.5046, Val Acc: 0.7407, Test Acc: 0.7988
# Seed: 42, Epoch: 033, Loss: 0.5074, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 034, Loss: 0.5050, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 035, Loss: 0.4937, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 42, Epoch: 036, Loss: 0.4911, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 42, Epoch: 037, Loss: 0.4946, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 038, Loss: 0.4895, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 42, Epoch: 039, Loss: 0.4865, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 040, Loss: 0.4873, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 041, Loss: 0.4849, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 042, Loss: 0.4855, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 043, Loss: 0.4869, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 044, Loss: 0.4845, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 045, Loss: 0.4806, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 046, Loss: 0.4887, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 047, Loss: 0.4795, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 048, Loss: 0.4765, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 42, Epoch: 049, Loss: 0.4765, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 42, Epoch: 050, Loss: 0.4726, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 051, Loss: 0.4748, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 052, Loss: 0.4898, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 42, Epoch: 053, Loss: 0.4725, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 054, Loss: 0.4827, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 055, Loss: 0.4725, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 056, Loss: 0.4769, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 42, Epoch: 057, Loss: 0.4740, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 058, Loss: 0.4823, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 42, Epoch: 059, Loss: 0.4736, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 060, Loss: 0.4794, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 061, Loss: 0.4679, Val Acc: 0.7407, Test Acc: 0.7866
# Seed: 42, Epoch: 062, Loss: 0.4687, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 063, Loss: 0.4658, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 42, Epoch: 064, Loss: 0.4705, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 42, Epoch: 065, Loss: 0.4725, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 066, Loss: 0.4650, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 067, Loss: 0.4609, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 068, Loss: 0.4629, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 069, Loss: 0.4601, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 42, Epoch: 070, Loss: 0.4580, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 071, Loss: 0.4579, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 072, Loss: 0.4548, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 073, Loss: 0.4545, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 074, Loss: 0.4546, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 075, Loss: 0.4521, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 42, Epoch: 076, Loss: 0.4593, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 42, Epoch: 077, Loss: 0.4512, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 42, Epoch: 078, Loss: 0.4676, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 079, Loss: 0.4587, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 42, Epoch: 080, Loss: 0.4567, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 42, Epoch: 081, Loss: 0.4554, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 42, Epoch: 082, Loss: 0.4603, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 42, Epoch: 083, Loss: 0.4575, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 084, Loss: 0.4608, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 085, Loss: 0.4635, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 42, Epoch: 086, Loss: 0.4502, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 087, Loss: 0.4573, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 088, Loss: 0.4702, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 42, Epoch: 089, Loss: 0.4816, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 090, Loss: 0.4948, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 42, Epoch: 091, Loss: 0.4722, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 42, Epoch: 092, Loss: 0.4641, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 42, Epoch: 093, Loss: 0.4524, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 42, Epoch: 094, Loss: 0.4540, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 095, Loss: 0.4470, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 096, Loss: 0.4471, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 097, Loss: 0.4419, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 098, Loss: 0.4424, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 099, Loss: 0.4408, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 100, Loss: 0.4404, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 101, Loss: 0.4412, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 102, Loss: 0.4438, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 42, Epoch: 103, Loss: 0.4882, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 104, Loss: 0.4705, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 105, Loss: 0.4703, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 106, Loss: 0.4685, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 107, Loss: 0.4574, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 108, Loss: 0.4722, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 109, Loss: 0.4567, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 42, Epoch: 110, Loss: 0.4625, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 42, Epoch: 111, Loss: 0.4486, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 112, Loss: 0.4508, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 42, Epoch: 113, Loss: 0.4393, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 42, Epoch: 114, Loss: 0.4359, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 115, Loss: 0.4325, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 42, Epoch: 116, Loss: 0.4338, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 117, Loss: 0.4319, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 118, Loss: 0.4338, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 119, Loss: 0.4297, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 42, Epoch: 120, Loss: 0.4365, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 42, Epoch: 121, Loss: 0.4441, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 42, Epoch: 122, Loss: 0.4479, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 123, Loss: 0.4427, Val Acc: 0.7840, Test Acc: 0.7744
# Seed: 42, Epoch: 124, Loss: 0.4380, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 125, Loss: 0.4310, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 42, Epoch: 126, Loss: 0.4311, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 42, Epoch: 127, Loss: 0.4325, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 42, Epoch: 128, Loss: 0.4287, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 129, Loss: 0.4245, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 130, Loss: 0.4320, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 131, Loss: 0.4302, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 132, Loss: 0.4281, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 133, Loss: 0.4330, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 42, Epoch: 134, Loss: 0.4291, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 42, Epoch: 135, Loss: 0.4233, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 136, Loss: 0.4267, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 42, Epoch: 137, Loss: 0.4243, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 42, Epoch: 138, Loss: 0.4183, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 42, Epoch: 139, Loss: 0.4194, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 42, Epoch: 140, Loss: 0.4193, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 141, Loss: 0.4199, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 142, Loss: 0.4171, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 42, Epoch: 143, Loss: 0.4315, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 144, Loss: 0.4131, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 42, Epoch: 145, Loss: 0.4174, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 146, Loss: 0.4144, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 147, Loss: 0.4141, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 148, Loss: 0.4316, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 42, Epoch: 149, Loss: 0.4240, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 42, Epoch: 150, Loss: 0.4288, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 42, Epoch: 151, Loss: 0.4321, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 42, Epoch: 152, Loss: 0.4194, Val Acc: 0.7901, Test Acc: 0.7622
# Seed: 42, Epoch: 153, Loss: 0.4192, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 42, Epoch: 154, Loss: 0.4116, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 155, Loss: 0.4200, Val Acc: 0.7963, Test Acc: 0.7805
# Seed: 42, Epoch: 156, Loss: 0.4098, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 42, Epoch: 157, Loss: 0.4136, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 42, Epoch: 158, Loss: 0.4026, Val Acc: 0.7840, Test Acc: 0.7805
# Seed: 42, Epoch: 159, Loss: 0.4076, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 160, Loss: 0.3960, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 161, Loss: 0.4182, Val Acc: 0.7840, Test Acc: 0.7439
# Seed: 42, Epoch: 162, Loss: 0.4326, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 42, Epoch: 163, Loss: 0.4159, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 42, Epoch: 164, Loss: 0.4134, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 42, Epoch: 165, Loss: 0.4149, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 166, Loss: 0.4121, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 167, Loss: 0.4001, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 168, Loss: 0.3992, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 169, Loss: 0.4034, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 42, Epoch: 170, Loss: 0.4008, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 171, Loss: 0.3982, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 172, Loss: 0.4009, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 173, Loss: 0.4044, Val Acc: 0.7593, Test Acc: 0.7866
# Seed: 42, Epoch: 174, Loss: 0.3888, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 42, Epoch: 175, Loss: 0.3929, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 42, Epoch: 176, Loss: 0.3838, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 42, Epoch: 177, Loss: 0.3850, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 178, Loss: 0.3873, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 179, Loss: 0.3902, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 42, Epoch: 180, Loss: 0.3851, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 181, Loss: 0.3801, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 182, Loss: 0.3881, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 183, Loss: 0.3741, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 184, Loss: 0.3828, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 42, Epoch: 185, Loss: 0.3846, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 186, Loss: 0.3861, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 187, Loss: 0.3775, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 42, Epoch: 188, Loss: 0.3708, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 42, Epoch: 189, Loss: 0.3778, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 42, Epoch: 190, Loss: 0.3677, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 191, Loss: 0.3671, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 192, Loss: 0.3640, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 42, Epoch: 193, Loss: 0.3649, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 42, Epoch: 194, Loss: 0.3632, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 195, Loss: 0.3674, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 196, Loss: 0.3680, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 197, Loss: 0.3673, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 198, Loss: 0.3624, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 199, Loss: 0.3576, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 42, Epoch: 200, Loss: 0.3700, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 43, Epoch: 001, Loss: 0.6545, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 002, Loss: 0.6141, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 003, Loss: 0.6129, Val Acc: 0.6914, Test Acc: 0.6341
# Seed: 43, Epoch: 004, Loss: 0.6014, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 43, Epoch: 005, Loss: 0.5970, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 43, Epoch: 006, Loss: 0.5893, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 43, Epoch: 007, Loss: 0.5813, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 008, Loss: 0.5740, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 43, Epoch: 009, Loss: 0.5677, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 43, Epoch: 010, Loss: 0.5591, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 43, Epoch: 011, Loss: 0.5629, Val Acc: 0.6728, Test Acc: 0.7378
# Seed: 43, Epoch: 012, Loss: 0.5788, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 013, Loss: 0.5560, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 43, Epoch: 014, Loss: 0.5563, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 43, Epoch: 015, Loss: 0.5482, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 43, Epoch: 016, Loss: 0.5443, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 43, Epoch: 017, Loss: 0.5414, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 018, Loss: 0.5340, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 43, Epoch: 019, Loss: 0.5268, Val Acc: 0.7840, Test Acc: 0.7805
# Seed: 43, Epoch: 020, Loss: 0.5223, Val Acc: 0.7840, Test Acc: 0.7805
# Seed: 43, Epoch: 021, Loss: 0.5157, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 43, Epoch: 022, Loss: 0.5112, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 43, Epoch: 023, Loss: 0.5091, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 43, Epoch: 024, Loss: 0.5030, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 43, Epoch: 025, Loss: 0.4987, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 43, Epoch: 026, Loss: 0.4999, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 43, Epoch: 027, Loss: 0.4996, Val Acc: 0.7840, Test Acc: 0.7866
# Seed: 43, Epoch: 028, Loss: 0.4901, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 43, Epoch: 029, Loss: 0.5138, Val Acc: 0.7654, Test Acc: 0.7927
# Seed: 43, Epoch: 030, Loss: 0.5009, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 43, Epoch: 031, Loss: 0.4956, Val Acc: 0.7840, Test Acc: 0.7805
# Seed: 43, Epoch: 032, Loss: 0.4956, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 033, Loss: 0.4889, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 43, Epoch: 034, Loss: 0.4891, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 035, Loss: 0.4856, Val Acc: 0.7963, Test Acc: 0.7866
# Seed: 43, Epoch: 036, Loss: 0.4850, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 43, Epoch: 037, Loss: 0.4847, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 038, Loss: 0.4840, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 43, Epoch: 039, Loss: 0.4884, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 43, Epoch: 040, Loss: 0.4845, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 43, Epoch: 041, Loss: 0.4857, Val Acc: 0.7593, Test Acc: 0.7927
# Seed: 43, Epoch: 042, Loss: 0.4829, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 43, Epoch: 043, Loss: 0.4783, Val Acc: 0.7469, Test Acc: 0.8049
# Seed: 43, Epoch: 044, Loss: 0.4794, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 43, Epoch: 045, Loss: 0.4817, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 43, Epoch: 046, Loss: 0.4817, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 047, Loss: 0.4899, Val Acc: 0.7469, Test Acc: 0.7927
# Seed: 43, Epoch: 048, Loss: 0.4779, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 43, Epoch: 049, Loss: 0.4729, Val Acc: 0.7531, Test Acc: 0.7988
# Seed: 43, Epoch: 050, Loss: 0.4713, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 43, Epoch: 051, Loss: 0.4761, Val Acc: 0.7346, Test Acc: 0.7927
# Seed: 43, Epoch: 052, Loss: 0.4785, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 43, Epoch: 053, Loss: 0.4841, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 43, Epoch: 054, Loss: 0.4716, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 43, Epoch: 055, Loss: 0.4665, Val Acc: 0.7407, Test Acc: 0.7927
# Seed: 43, Epoch: 056, Loss: 0.4765, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 43, Epoch: 057, Loss: 0.4679, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 43, Epoch: 058, Loss: 0.4685, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 43, Epoch: 059, Loss: 0.4697, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 43, Epoch: 060, Loss: 0.4802, Val Acc: 0.7593, Test Acc: 0.7927
# Seed: 43, Epoch: 061, Loss: 0.4667, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 43, Epoch: 062, Loss: 0.4649, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 063, Loss: 0.4620, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 43, Epoch: 064, Loss: 0.4648, Val Acc: 0.7284, Test Acc: 0.7866
# Seed: 43, Epoch: 065, Loss: 0.4666, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 43, Epoch: 066, Loss: 0.4749, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 43, Epoch: 067, Loss: 0.4753, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 43, Epoch: 068, Loss: 0.4664, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 43, Epoch: 069, Loss: 0.4611, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 43, Epoch: 070, Loss: 0.4676, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 43, Epoch: 071, Loss: 0.4599, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 43, Epoch: 072, Loss: 0.4697, Val Acc: 0.7840, Test Acc: 0.7500
# Seed: 43, Epoch: 073, Loss: 0.4606, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 074, Loss: 0.4620, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 43, Epoch: 075, Loss: 0.4622, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 43, Epoch: 076, Loss: 0.4609, Val Acc: 0.7840, Test Acc: 0.7500
# Seed: 43, Epoch: 077, Loss: 0.4551, Val Acc: 0.7346, Test Acc: 0.7988
# Seed: 43, Epoch: 078, Loss: 0.4568, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 079, Loss: 0.4671, Val Acc: 0.7284, Test Acc: 0.7805
# Seed: 43, Epoch: 080, Loss: 0.4531, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 43, Epoch: 081, Loss: 0.4596, Val Acc: 0.7284, Test Acc: 0.7866
# Seed: 43, Epoch: 082, Loss: 0.4631, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 083, Loss: 0.4620, Val Acc: 0.7346, Test Acc: 0.7805
# Seed: 43, Epoch: 084, Loss: 0.4559, Val Acc: 0.7901, Test Acc: 0.7561
# Seed: 43, Epoch: 085, Loss: 0.4555, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 43, Epoch: 086, Loss: 0.4554, Val Acc: 0.7901, Test Acc: 0.7744
# Seed: 43, Epoch: 087, Loss: 0.4543, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 43, Epoch: 088, Loss: 0.4540, Val Acc: 0.7407, Test Acc: 0.7866
# Seed: 43, Epoch: 089, Loss: 0.4592, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 43, Epoch: 090, Loss: 0.4582, Val Acc: 0.7901, Test Acc: 0.7561
# Seed: 43, Epoch: 091, Loss: 0.4691, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 43, Epoch: 092, Loss: 0.4594, Val Acc: 0.7963, Test Acc: 0.7683
# Seed: 43, Epoch: 093, Loss: 0.4570, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 43, Epoch: 094, Loss: 0.4518, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 43, Epoch: 095, Loss: 0.4470, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 096, Loss: 0.4471, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 43, Epoch: 097, Loss: 0.4501, Val Acc: 0.7346, Test Acc: 0.7805
# Seed: 43, Epoch: 098, Loss: 0.4454, Val Acc: 0.7901, Test Acc: 0.7500
# Seed: 43, Epoch: 099, Loss: 0.4445, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 43, Epoch: 100, Loss: 0.4534, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 101, Loss: 0.4449, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 43, Epoch: 102, Loss: 0.4608, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 43, Epoch: 103, Loss: 0.4482, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 43, Epoch: 104, Loss: 0.4488, Val Acc: 0.7901, Test Acc: 0.7622
# Seed: 43, Epoch: 105, Loss: 0.4495, Val Acc: 0.7963, Test Acc: 0.7744
# Seed: 43, Epoch: 106, Loss: 0.4411, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 43, Epoch: 107, Loss: 0.4449, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 43, Epoch: 108, Loss: 0.4402, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 43, Epoch: 109, Loss: 0.4369, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 43, Epoch: 110, Loss: 0.4351, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 43, Epoch: 111, Loss: 0.4315, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 43, Epoch: 112, Loss: 0.4389, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 43, Epoch: 113, Loss: 0.4318, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 43, Epoch: 114, Loss: 0.4339, Val Acc: 0.7346, Test Acc: 0.7805
# Seed: 43, Epoch: 115, Loss: 0.4352, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 116, Loss: 0.4601, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 43, Epoch: 117, Loss: 0.4466, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 43, Epoch: 118, Loss: 0.4348, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 43, Epoch: 119, Loss: 0.4324, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 120, Loss: 0.4324, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 43, Epoch: 121, Loss: 0.4256, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 122, Loss: 0.4228, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 43, Epoch: 123, Loss: 0.4263, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 43, Epoch: 124, Loss: 0.4209, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 43, Epoch: 125, Loss: 0.4243, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 43, Epoch: 126, Loss: 0.4266, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 43, Epoch: 127, Loss: 0.4397, Val Acc: 0.7222, Test Acc: 0.7866
# Seed: 43, Epoch: 128, Loss: 0.4305, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 43, Epoch: 129, Loss: 0.4382, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 43, Epoch: 130, Loss: 0.4248, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 43, Epoch: 131, Loss: 0.4237, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 43, Epoch: 132, Loss: 0.4251, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 43, Epoch: 133, Loss: 0.4172, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 43, Epoch: 134, Loss: 0.4223, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 43, Epoch: 135, Loss: 0.4240, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 43, Epoch: 136, Loss: 0.4253, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 43, Epoch: 137, Loss: 0.4199, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 43, Epoch: 138, Loss: 0.4246, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 139, Loss: 0.4170, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 43, Epoch: 140, Loss: 0.4154, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 43, Epoch: 141, Loss: 0.4192, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 142, Loss: 0.4143, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 143, Loss: 0.4271, Val Acc: 0.7099, Test Acc: 0.7561
# Seed: 43, Epoch: 144, Loss: 0.4356, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 43, Epoch: 145, Loss: 0.4412, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 43, Epoch: 146, Loss: 0.4138, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 147, Loss: 0.4157, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 43, Epoch: 148, Loss: 0.4388, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 149, Loss: 0.4212, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 150, Loss: 0.4288, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 43, Epoch: 151, Loss: 0.4473, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 43, Epoch: 152, Loss: 0.4960, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 43, Epoch: 153, Loss: 0.4595, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 43, Epoch: 154, Loss: 0.4600, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 43, Epoch: 155, Loss: 0.4568, Val Acc: 0.7840, Test Acc: 0.7744
# Seed: 43, Epoch: 156, Loss: 0.4482, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 43, Epoch: 157, Loss: 0.4321, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 43, Epoch: 158, Loss: 0.4274, Val Acc: 0.7346, Test Acc: 0.8110
# Seed: 43, Epoch: 159, Loss: 0.4205, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 160, Loss: 0.4170, Val Acc: 0.7469, Test Acc: 0.7988
# Seed: 43, Epoch: 161, Loss: 0.4137, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 162, Loss: 0.4141, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 43, Epoch: 163, Loss: 0.4115, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 43, Epoch: 164, Loss: 0.4159, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 43, Epoch: 165, Loss: 0.4218, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 43, Epoch: 166, Loss: 0.4123, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 167, Loss: 0.4265, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 43, Epoch: 168, Loss: 0.4184, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 43, Epoch: 169, Loss: 0.4143, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 43, Epoch: 170, Loss: 0.4071, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 43, Epoch: 171, Loss: 0.4028, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 43, Epoch: 172, Loss: 0.3930, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 43, Epoch: 173, Loss: 0.3956, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 174, Loss: 0.3931, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 43, Epoch: 175, Loss: 0.3932, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 43, Epoch: 176, Loss: 0.3908, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 177, Loss: 0.3845, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 43, Epoch: 178, Loss: 0.3874, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 43, Epoch: 179, Loss: 0.3860, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 43, Epoch: 180, Loss: 0.3902, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 43, Epoch: 181, Loss: 0.3883, Val Acc: 0.7037, Test Acc: 0.7622
# Seed: 43, Epoch: 182, Loss: 0.3912, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 43, Epoch: 183, Loss: 0.3824, Val Acc: 0.7222, Test Acc: 0.7622
# Seed: 43, Epoch: 184, Loss: 0.3832, Val Acc: 0.7654, Test Acc: 0.7317
# Seed: 43, Epoch: 185, Loss: 0.3949, Val Acc: 0.7778, Test Acc: 0.7622
# Early stopping at epoch 185 for seed 43
# Seed: 44, Epoch: 001, Loss: 0.6635, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 44, Epoch: 002, Loss: 0.6171, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 44, Epoch: 003, Loss: 0.6007, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 44, Epoch: 004, Loss: 0.6015, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 44, Epoch: 005, Loss: 0.5964, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 44, Epoch: 006, Loss: 0.5897, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 44, Epoch: 007, Loss: 0.5891, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 44, Epoch: 008, Loss: 0.5786, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 44, Epoch: 009, Loss: 0.5741, Val Acc: 0.7407, Test Acc: 0.7317
# Seed: 44, Epoch: 010, Loss: 0.5704, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 44, Epoch: 011, Loss: 0.5774, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 44, Epoch: 012, Loss: 0.5649, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 44, Epoch: 013, Loss: 0.5657, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 44, Epoch: 014, Loss: 0.5560, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 44, Epoch: 015, Loss: 0.5546, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 44, Epoch: 016, Loss: 0.5504, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 44, Epoch: 017, Loss: 0.5410, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 44, Epoch: 018, Loss: 0.5355, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 44, Epoch: 019, Loss: 0.5289, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 44, Epoch: 020, Loss: 0.5296, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 44, Epoch: 021, Loss: 0.5299, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 022, Loss: 0.5255, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 44, Epoch: 023, Loss: 0.5300, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 44, Epoch: 024, Loss: 0.5144, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 025, Loss: 0.5117, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 44, Epoch: 026, Loss: 0.5050, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 44, Epoch: 027, Loss: 0.5124, Val Acc: 0.7160, Test Acc: 0.7561
# Seed: 44, Epoch: 028, Loss: 0.5217, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 44, Epoch: 029, Loss: 0.5180, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 44, Epoch: 030, Loss: 0.5104, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 44, Epoch: 031, Loss: 0.5173, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 44, Epoch: 032, Loss: 0.5139, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 44, Epoch: 033, Loss: 0.5101, Val Acc: 0.7531, Test Acc: 0.7134
# Seed: 44, Epoch: 034, Loss: 0.5133, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 44, Epoch: 035, Loss: 0.4999, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 44, Epoch: 036, Loss: 0.5034, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 44, Epoch: 037, Loss: 0.4989, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 44, Epoch: 038, Loss: 0.4971, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 039, Loss: 0.4976, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 44, Epoch: 040, Loss: 0.4908, Val Acc: 0.7778, Test Acc: 0.7317
# Seed: 44, Epoch: 041, Loss: 0.5072, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 44, Epoch: 042, Loss: 0.5020, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 44, Epoch: 043, Loss: 0.4934, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 44, Epoch: 044, Loss: 0.4877, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 44, Epoch: 045, Loss: 0.4876, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 44, Epoch: 046, Loss: 0.4866, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 047, Loss: 0.4841, Val Acc: 0.7160, Test Acc: 0.7622
# Seed: 44, Epoch: 048, Loss: 0.4842, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 44, Epoch: 049, Loss: 0.5011, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 44, Epoch: 050, Loss: 0.4905, Val Acc: 0.7593, Test Acc: 0.7195
# Seed: 44, Epoch: 051, Loss: 0.4829, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 44, Epoch: 052, Loss: 0.4818, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 44, Epoch: 053, Loss: 0.4801, Val Acc: 0.7654, Test Acc: 0.7134
# Seed: 44, Epoch: 054, Loss: 0.4883, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 055, Loss: 0.4812, Val Acc: 0.7284, Test Acc: 0.7683
# Seed: 44, Epoch: 056, Loss: 0.4798, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 44, Epoch: 057, Loss: 0.4756, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 058, Loss: 0.4777, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 44, Epoch: 059, Loss: 0.4722, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 44, Epoch: 060, Loss: 0.4733, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 44, Epoch: 061, Loss: 0.4711, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 44, Epoch: 062, Loss: 0.4698, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 44, Epoch: 063, Loss: 0.4685, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 44, Epoch: 064, Loss: 0.4669, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 065, Loss: 0.4694, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 44, Epoch: 066, Loss: 0.4652, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 067, Loss: 0.4713, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 44, Epoch: 068, Loss: 0.4765, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 44, Epoch: 069, Loss: 0.4967, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 44, Epoch: 070, Loss: 0.5132, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 44, Epoch: 071, Loss: 0.4902, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 44, Epoch: 072, Loss: 0.4752, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 44, Epoch: 073, Loss: 0.4916, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 074, Loss: 0.4766, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 44, Epoch: 075, Loss: 0.4712, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 44, Epoch: 076, Loss: 0.4652, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 44, Epoch: 077, Loss: 0.4647, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 44, Epoch: 078, Loss: 0.4646, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 44, Epoch: 079, Loss: 0.4658, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 44, Epoch: 080, Loss: 0.4609, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 44, Epoch: 081, Loss: 0.4580, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 44, Epoch: 082, Loss: 0.4633, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 44, Epoch: 083, Loss: 0.4614, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 44, Epoch: 084, Loss: 0.4612, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 44, Epoch: 085, Loss: 0.4587, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 44, Epoch: 086, Loss: 0.4634, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 44, Epoch: 087, Loss: 0.4644, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 44, Epoch: 088, Loss: 0.4771, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 44, Epoch: 089, Loss: 0.4633, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 44, Epoch: 090, Loss: 0.4659, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 44, Epoch: 091, Loss: 0.4546, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 44, Epoch: 092, Loss: 0.4661, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 44, Epoch: 093, Loss: 0.4557, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 44, Epoch: 094, Loss: 0.4589, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 44, Epoch: 095, Loss: 0.4555, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 44, Epoch: 096, Loss: 0.4573, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 44, Epoch: 097, Loss: 0.4560, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 098, Loss: 0.4576, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 44, Epoch: 099, Loss: 0.4610, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 100, Loss: 0.4620, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 44, Epoch: 101, Loss: 0.4589, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 44, Epoch: 102, Loss: 0.4518, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 103, Loss: 0.4520, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 104, Loss: 0.4558, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 44, Epoch: 105, Loss: 0.4544, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 44, Epoch: 106, Loss: 0.4518, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 44, Epoch: 107, Loss: 0.4505, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 108, Loss: 0.4480, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 109, Loss: 0.4502, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 44, Epoch: 110, Loss: 0.4471, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 44, Epoch: 111, Loss: 0.4454, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 44, Epoch: 112, Loss: 0.4483, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 44, Epoch: 113, Loss: 0.4453, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 114, Loss: 0.4423, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 44, Epoch: 115, Loss: 0.4452, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 116, Loss: 0.4431, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 117, Loss: 0.4397, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 44, Epoch: 118, Loss: 0.4424, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 44, Epoch: 119, Loss: 0.4512, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 120, Loss: 0.4477, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 44, Epoch: 121, Loss: 0.4638, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 122, Loss: 0.4595, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 44, Epoch: 123, Loss: 0.4512, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 44, Epoch: 124, Loss: 0.4594, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 44, Epoch: 125, Loss: 0.4544, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 44, Epoch: 126, Loss: 0.4599, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 44, Epoch: 127, Loss: 0.4523, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 44, Epoch: 128, Loss: 0.4586, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 44, Epoch: 129, Loss: 0.4601, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 44, Epoch: 130, Loss: 0.4479, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 44, Epoch: 131, Loss: 0.4435, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 44, Epoch: 132, Loss: 0.4501, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 133, Loss: 0.4413, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 44, Epoch: 134, Loss: 0.4468, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 44, Epoch: 135, Loss: 0.4538, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 44, Epoch: 136, Loss: 0.4502, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 137, Loss: 0.4369, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 44, Epoch: 138, Loss: 0.4409, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 139, Loss: 0.4381, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 44, Epoch: 140, Loss: 0.4379, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 44, Epoch: 141, Loss: 0.4506, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 44, Epoch: 142, Loss: 0.4427, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 44, Epoch: 143, Loss: 0.4320, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 44, Epoch: 144, Loss: 0.4329, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 44, Epoch: 145, Loss: 0.4332, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 146, Loss: 0.4328, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 44, Epoch: 147, Loss: 0.4333, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 44, Epoch: 148, Loss: 0.4365, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 44, Epoch: 149, Loss: 0.4443, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 44, Epoch: 150, Loss: 0.4305, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 151, Loss: 0.4322, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 44, Epoch: 152, Loss: 0.4362, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 44, Epoch: 153, Loss: 0.4540, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 44, Epoch: 154, Loss: 0.4399, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 44, Epoch: 155, Loss: 0.4405, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 156, Loss: 0.4444, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 44, Epoch: 157, Loss: 0.4585, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 158, Loss: 0.4352, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 44, Epoch: 159, Loss: 0.4449, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 160, Loss: 0.4521, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 44, Epoch: 161, Loss: 0.4465, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 44, Epoch: 162, Loss: 0.4492, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 44, Epoch: 163, Loss: 0.4349, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 44, Epoch: 164, Loss: 0.4431, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 165, Loss: 0.4378, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 44, Epoch: 166, Loss: 0.4376, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 44, Epoch: 167, Loss: 0.4323, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 44, Epoch: 168, Loss: 0.4356, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 44, Epoch: 169, Loss: 0.4372, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 44, Epoch: 170, Loss: 0.4463, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 44, Epoch: 171, Loss: 0.4383, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 44, Epoch: 172, Loss: 0.4384, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 173, Loss: 0.4317, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 44, Epoch: 174, Loss: 0.4317, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 44, Epoch: 175, Loss: 0.4273, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 44, Epoch: 176, Loss: 0.4417, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 44, Epoch: 177, Loss: 0.4687, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 178, Loss: 0.4488, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 44, Epoch: 179, Loss: 0.4319, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 180, Loss: 0.4369, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 44, Epoch: 181, Loss: 0.4325, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 182, Loss: 0.4327, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 44, Epoch: 183, Loss: 0.4319, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 184, Loss: 0.4279, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 44, Epoch: 185, Loss: 0.4373, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 44, Epoch: 186, Loss: 0.4330, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 44, Epoch: 187, Loss: 0.4291, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 44, Epoch: 188, Loss: 0.4239, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 189, Loss: 0.4260, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 44, Epoch: 190, Loss: 0.4236, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 44, Epoch: 191, Loss: 0.4291, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 192, Loss: 0.4230, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 44, Epoch: 193, Loss: 0.4226, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 44, Epoch: 194, Loss: 0.4215, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 44, Epoch: 195, Loss: 0.4161, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 44, Epoch: 196, Loss: 0.4200, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 197, Loss: 0.4147, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 44, Epoch: 198, Loss: 0.4127, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 44, Epoch: 199, Loss: 0.4124, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 200, Loss: 0.4101, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 45, Epoch: 001, Loss: 0.6344, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 45, Epoch: 002, Loss: 0.5953, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 45, Epoch: 003, Loss: 0.5925, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 45, Epoch: 004, Loss: 0.5891, Val Acc: 0.7469, Test Acc: 0.7012
# Seed: 45, Epoch: 005, Loss: 0.5833, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 45, Epoch: 006, Loss: 0.5807, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 45, Epoch: 007, Loss: 0.5739, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 45, Epoch: 008, Loss: 0.5686, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 009, Loss: 0.5593, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 45, Epoch: 010, Loss: 0.5566, Val Acc: 0.7531, Test Acc: 0.7195
# Seed: 45, Epoch: 011, Loss: 0.5485, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 45, Epoch: 012, Loss: 0.5507, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 45, Epoch: 013, Loss: 0.5536, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 45, Epoch: 014, Loss: 0.5395, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 45, Epoch: 015, Loss: 0.5353, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 45, Epoch: 016, Loss: 0.5283, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 45, Epoch: 017, Loss: 0.5226, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 018, Loss: 0.5232, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 45, Epoch: 019, Loss: 0.5197, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 45, Epoch: 020, Loss: 0.5283, Val Acc: 0.7160, Test Acc: 0.7622
# Seed: 45, Epoch: 021, Loss: 0.5346, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 45, Epoch: 022, Loss: 0.5355, Val Acc: 0.7593, Test Acc: 0.7134
# Seed: 45, Epoch: 023, Loss: 0.5309, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 024, Loss: 0.5158, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 45, Epoch: 025, Loss: 0.5141, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 45, Epoch: 026, Loss: 0.5116, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 45, Epoch: 027, Loss: 0.5101, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 45, Epoch: 028, Loss: 0.5182, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 45, Epoch: 029, Loss: 0.5022, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 030, Loss: 0.5016, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 45, Epoch: 031, Loss: 0.5106, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 45, Epoch: 032, Loss: 0.5140, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 45, Epoch: 033, Loss: 0.5136, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 034, Loss: 0.5164, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 45, Epoch: 035, Loss: 0.5033, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 45, Epoch: 036, Loss: 0.5123, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 037, Loss: 0.4969, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 45, Epoch: 038, Loss: 0.4890, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 45, Epoch: 039, Loss: 0.4913, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 45, Epoch: 040, Loss: 0.4906, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 041, Loss: 0.4854, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 45, Epoch: 042, Loss: 0.4840, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 45, Epoch: 043, Loss: 0.4835, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 45, Epoch: 044, Loss: 0.4830, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 45, Epoch: 045, Loss: 0.4819, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 45, Epoch: 046, Loss: 0.4778, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 047, Loss: 0.4785, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 048, Loss: 0.4783, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 049, Loss: 0.4756, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 050, Loss: 0.4730, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 45, Epoch: 051, Loss: 0.4752, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 052, Loss: 0.4792, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 45, Epoch: 053, Loss: 0.4705, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 45, Epoch: 054, Loss: 0.4722, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 45, Epoch: 055, Loss: 0.4709, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 056, Loss: 0.4800, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 45, Epoch: 057, Loss: 0.4776, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 45, Epoch: 058, Loss: 0.4788, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 45, Epoch: 059, Loss: 0.4802, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 45, Epoch: 060, Loss: 0.4740, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 061, Loss: 0.4760, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 45, Epoch: 062, Loss: 0.4755, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 45, Epoch: 063, Loss: 0.4683, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 45, Epoch: 064, Loss: 0.4730, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 065, Loss: 0.4657, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 45, Epoch: 066, Loss: 0.4697, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 45, Epoch: 067, Loss: 0.4660, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 45, Epoch: 068, Loss: 0.4683, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 45, Epoch: 069, Loss: 0.4658, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 45, Epoch: 070, Loss: 0.4668, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 071, Loss: 0.4680, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 45, Epoch: 072, Loss: 0.4677, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 45, Epoch: 073, Loss: 0.4605, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 45, Epoch: 074, Loss: 0.4681, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 45, Epoch: 075, Loss: 0.4692, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 45, Epoch: 076, Loss: 0.4558, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 45, Epoch: 077, Loss: 0.4598, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 45, Epoch: 078, Loss: 0.4598, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 45, Epoch: 079, Loss: 0.4595, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 45, Epoch: 080, Loss: 0.4574, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 45, Epoch: 081, Loss: 0.4558, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 45, Epoch: 082, Loss: 0.4579, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 083, Loss: 0.4592, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 45, Epoch: 084, Loss: 0.4528, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 45, Epoch: 085, Loss: 0.4507, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 45, Epoch: 086, Loss: 0.4548, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 45, Epoch: 087, Loss: 0.4495, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 45, Epoch: 088, Loss: 0.4565, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 45, Epoch: 089, Loss: 0.4537, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 45, Epoch: 090, Loss: 0.4548, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 45, Epoch: 091, Loss: 0.4545, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 092, Loss: 0.4517, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 45, Epoch: 093, Loss: 0.4487, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 45, Epoch: 094, Loss: 0.4498, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 45, Epoch: 095, Loss: 0.4485, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 45, Epoch: 096, Loss: 0.4650, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 45, Epoch: 097, Loss: 0.4569, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 45, Epoch: 098, Loss: 0.4550, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 45, Epoch: 099, Loss: 0.4517, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 45, Epoch: 100, Loss: 0.4469, Val Acc: 0.7778, Test Acc: 0.7561
# ...
# Seed: 45, Epoch: 149, Loss: 0.4193, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 45, Epoch: 150, Loss: 0.4085, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 45, Epoch: 151, Loss: 0.4040, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 45, Epoch: 152, Loss: 0.4070, Val Acc: 0.7593, Test Acc: 0.7988
# Seed: 45, Epoch: 153, Loss: 0.4088, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 45, Epoch: 154, Loss: 0.4090, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 45, Epoch: 155, Loss: 0.4085, Val Acc: 0.7531, Test Acc: 0.7988
# Seed: 45, Epoch: 156, Loss: 0.4078, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 45, Epoch: 157, Loss: 0.4136, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 45, Epoch: 158, Loss: 0.4053, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 159, Loss: 0.4077, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 45, Epoch: 160, Loss: 0.4113, Val Acc: 0.7407, Test Acc: 0.8049
# Seed: 45, Epoch: 161, Loss: 0.4059, Val Acc: 0.7593, Test Acc: 0.7988
# Seed: 45, Epoch: 162, Loss: 0.4037, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 45, Epoch: 163, Loss: 0.4038, Val Acc: 0.7593, Test Acc: 0.7927
# Seed: 45, Epoch: 164, Loss: 0.4125, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 45, Epoch: 165, Loss: 0.4194, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 166, Loss: 0.4277, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 45, Epoch: 167, Loss: 0.4145, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 45, Epoch: 168, Loss: 0.4047, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 45, Epoch: 169, Loss: 0.4096, Val Acc: 0.7716, Test Acc: 0.7927
# Seed: 45, Epoch: 170, Loss: 0.4042, Val Acc: 0.7654, Test Acc: 0.7927
# Seed: 45, Epoch: 171, Loss: 0.4055, Val Acc: 0.7407, Test Acc: 0.7866
# Seed: 45, Epoch: 172, Loss: 0.4195, Val Acc: 0.7778, Test Acc: 0.7866
# Seed: 45, Epoch: 173, Loss: 0.4178, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 45, Epoch: 174, Loss: 0.4233, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 45, Epoch: 175, Loss: 0.4145, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 45, Epoch: 176, Loss: 0.4207, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 45, Epoch: 177, Loss: 0.4103, Val Acc: 0.7654, Test Acc: 0.7988
# Seed: 45, Epoch: 178, Loss: 0.4154, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 45, Epoch: 179, Loss: 0.4161, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 180, Loss: 0.4167, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 45, Epoch: 181, Loss: 0.4176, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 45, Epoch: 182, Loss: 0.4113, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 45, Epoch: 183, Loss: 0.4159, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 184, Loss: 0.4115, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 45, Epoch: 185, Loss: 0.4234, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 45, Epoch: 186, Loss: 0.4516, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 45, Epoch: 187, Loss: 0.4444, Val Acc: 0.7716, Test Acc: 0.7927
# Seed: 45, Epoch: 188, Loss: 0.4414, Val Acc: 0.7407, Test Acc: 0.7988
# Seed: 45, Epoch: 189, Loss: 0.4267, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 45, Epoch: 190, Loss: 0.4243, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 45, Epoch: 191, Loss: 0.4232, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 45, Epoch: 192, Loss: 0.4278, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 45, Epoch: 193, Loss: 0.4543, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 45, Epoch: 194, Loss: 0.4353, Val Acc: 0.7593, Test Acc: 0.8049
# Seed: 45, Epoch: 195, Loss: 0.4361, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 45, Epoch: 196, Loss: 0.4333, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 45, Epoch: 197, Loss: 0.4151, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 45, Epoch: 198, Loss: 0.4123, Val Acc: 0.7716, Test Acc: 0.7927
# Seed: 45, Epoch: 199, Loss: 0.4171, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 200, Loss: 0.4224, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 46, Epoch: 001, Loss: 0.7128, Val Acc: 0.6790, Test Acc: 0.6341
# Seed: 46, Epoch: 002, Loss: 0.6233, Val Acc: 0.6790, Test Acc: 0.6463
# Seed: 46, Epoch: 003, Loss: 0.6030, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 46, Epoch: 004, Loss: 0.5984, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 46, Epoch: 005, Loss: 0.5948, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 46, Epoch: 006, Loss: 0.5875, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 007, Loss: 0.5838, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 46, Epoch: 008, Loss: 0.5674, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 46, Epoch: 009, Loss: 0.5752, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 010, Loss: 0.5614, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 46, Epoch: 011, Loss: 0.5598, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 46, Epoch: 012, Loss: 0.5580, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 46, Epoch: 013, Loss: 0.5596, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 46, Epoch: 014, Loss: 0.5514, Val Acc: 0.7654, Test Acc: 0.7256
# Seed: 46, Epoch: 015, Loss: 0.5495, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 46, Epoch: 016, Loss: 0.5453, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 46, Epoch: 017, Loss: 0.5387, Val Acc: 0.7407, Test Acc: 0.7317
# Seed: 46, Epoch: 018, Loss: 0.5341, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 46, Epoch: 019, Loss: 0.5310, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 46, Epoch: 020, Loss: 0.5242, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 46, Epoch: 021, Loss: 0.5210, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 46, Epoch: 022, Loss: 0.5184, Val Acc: 0.7654, Test Acc: 0.7317
# Seed: 46, Epoch: 023, Loss: 0.5171, Val Acc: 0.7901, Test Acc: 0.7500
# Seed: 46, Epoch: 024, Loss: 0.5167, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 46, Epoch: 025, Loss: 0.5173, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 026, Loss: 0.5216, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 46, Epoch: 027, Loss: 0.5228, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 46, Epoch: 028, Loss: 0.5235, Val Acc: 0.7778, Test Acc: 0.7256
# Seed: 46, Epoch: 029, Loss: 0.5071, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 46, Epoch: 030, Loss: 0.5189, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 46, Epoch: 031, Loss: 0.5128, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 46, Epoch: 032, Loss: 0.5068, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 033, Loss: 0.5034, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 46, Epoch: 034, Loss: 0.4993, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 035, Loss: 0.4948, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 46, Epoch: 036, Loss: 0.5024, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 037, Loss: 0.4956, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 038, Loss: 0.4903, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 039, Loss: 0.4929, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 040, Loss: 0.4994, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 041, Loss: 0.4881, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 46, Epoch: 042, Loss: 0.4883, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 46, Epoch: 043, Loss: 0.4904, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 46, Epoch: 044, Loss: 0.4892, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 46, Epoch: 045, Loss: 0.4879, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 46, Epoch: 046, Loss: 0.4857, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 46, Epoch: 047, Loss: 0.4788, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 048, Loss: 0.4808, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 46, Epoch: 049, Loss: 0.4833, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 050, Loss: 0.4897, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 051, Loss: 0.4809, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 46, Epoch: 052, Loss: 0.4780, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 46, Epoch: 053, Loss: 0.4761, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 46, Epoch: 054, Loss: 0.4801, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 46, Epoch: 055, Loss: 0.4760, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 46, Epoch: 056, Loss: 0.4763, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 057, Loss: 0.4755, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 46, Epoch: 058, Loss: 0.4725, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 46, Epoch: 059, Loss: 0.4759, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 060, Loss: 0.4788, Val Acc: 0.7840, Test Acc: 0.7378
# Seed: 46, Epoch: 061, Loss: 0.4656, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 062, Loss: 0.4714, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 063, Loss: 0.4729, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 46, Epoch: 064, Loss: 0.4724, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 46, Epoch: 065, Loss: 0.4690, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 46, Epoch: 066, Loss: 0.4700, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 46, Epoch: 067, Loss: 0.4726, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 068, Loss: 0.4924, Val Acc: 0.7654, Test Acc: 0.7317
# Seed: 46, Epoch: 069, Loss: 0.4852, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 46, Epoch: 070, Loss: 0.4763, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 071, Loss: 0.4760, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 072, Loss: 0.4705, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 073, Loss: 0.4673, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 46, Epoch: 074, Loss: 0.4693, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 075, Loss: 0.4708, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 076, Loss: 0.4633, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 46, Epoch: 077, Loss: 0.4616, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 46, Epoch: 078, Loss: 0.4649, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 079, Loss: 0.4654, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 080, Loss: 0.4731, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 46, Epoch: 081, Loss: 0.4692, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 46, Epoch: 082, Loss: 0.4593, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 46, Epoch: 083, Loss: 0.4595, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 084, Loss: 0.4637, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 085, Loss: 0.4589, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 086, Loss: 0.4570, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 46, Epoch: 087, Loss: 0.4553, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 088, Loss: 0.4563, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 46, Epoch: 089, Loss: 0.4617, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 090, Loss: 0.4693, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 46, Epoch: 091, Loss: 0.4716, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 092, Loss: 0.4755, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 093, Loss: 0.4637, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 46, Epoch: 094, Loss: 0.4613, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 095, Loss: 0.4672, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 096, Loss: 0.4576, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 46, Epoch: 097, Loss: 0.4560, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 46, Epoch: 098, Loss: 0.4519, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 099, Loss: 0.4523, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 46, Epoch: 100, Loss: 0.4506, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 46, Epoch: 101, Loss: 0.4479, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 102, Loss: 0.4450, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 103, Loss: 0.4466, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 46, Epoch: 104, Loss: 0.4441, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 105, Loss: 0.4445, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 106, Loss: 0.4480, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 46, Epoch: 107, Loss: 0.4512, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 108, Loss: 0.4423, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 46, Epoch: 109, Loss: 0.4408, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 110, Loss: 0.4505, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 111, Loss: 0.4500, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 112, Loss: 0.4459, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 46, Epoch: 113, Loss: 0.4424, Val Acc: 0.7160, Test Acc: 0.7805
# Seed: 46, Epoch: 114, Loss: 0.4552, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 115, Loss: 0.4553, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 116, Loss: 0.4441, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 117, Loss: 0.4442, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 118, Loss: 0.4407, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 46, Epoch: 119, Loss: 0.4368, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 120, Loss: 0.4361, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 121, Loss: 0.4396, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 122, Loss: 0.4408, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 123, Loss: 0.4426, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 124, Loss: 0.4348, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 125, Loss: 0.4345, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 126, Loss: 0.4340, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 127, Loss: 0.4352, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 128, Loss: 0.4457, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 129, Loss: 0.4334, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 46, Epoch: 130, Loss: 0.4320, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 131, Loss: 0.4301, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 132, Loss: 0.4379, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 46, Epoch: 133, Loss: 0.4451, Val Acc: 0.7222, Test Acc: 0.7622
# Seed: 46, Epoch: 134, Loss: 0.4509, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 135, Loss: 0.4782, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 46, Epoch: 136, Loss: 0.4656, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 137, Loss: 0.4485, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 46, Epoch: 138, Loss: 0.4451, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 139, Loss: 0.4486, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 140, Loss: 0.4463, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 141, Loss: 0.4441, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 142, Loss: 0.4303, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 143, Loss: 0.4314, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 46, Epoch: 144, Loss: 0.4292, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 145, Loss: 0.4276, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 146, Loss: 0.4255, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 147, Loss: 0.4225, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 46, Epoch: 148, Loss: 0.4170, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 46, Epoch: 149, Loss: 0.4229, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 46, Epoch: 150, Loss: 0.4257, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 46, Epoch: 151, Loss: 0.4150, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 46, Epoch: 152, Loss: 0.4505, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 153, Loss: 0.4530, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 154, Loss: 0.4435, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 46, Epoch: 155, Loss: 0.4477, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 46, Epoch: 156, Loss: 0.4395, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 157, Loss: 0.4334, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 158, Loss: 0.4294, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 46, Epoch: 159, Loss: 0.4294, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 160, Loss: 0.4283, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 161, Loss: 0.4235, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 46, Epoch: 162, Loss: 0.4243, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 163, Loss: 0.4203, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 164, Loss: 0.4188, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 165, Loss: 0.4189, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 166, Loss: 0.4157, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 46, Epoch: 167, Loss: 0.4135, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 46, Epoch: 168, Loss: 0.4116, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 46, Epoch: 169, Loss: 0.4109, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 170, Loss: 0.4106, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 171, Loss: 0.4112, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 172, Loss: 0.4098, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 173, Loss: 0.4101, Val Acc: 0.7469, Test Acc: 0.7561
# Early stopping at epoch 173 for seed 46
# Average Time: 46.73 seconds
# Var Time: 6.68 seconds
# Average Memory: 3510.00 MB
# Average Best Val Acc: 0.7889
# Std Best Test Acc: 0.0147
# Average Test Acc: 0.7659

# %% [markdown]
# ## Dense DifferencePooling with HierarchicalGCN (2018)

# %%
import os.path as osp
import time
from math import ceil

import torch
import torch.nn.functional as F

import torch_geometric.transforms as T
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DenseDataLoader
from torch_geometric.nn import DenseSAGEConv, dense_diff_pool
max_nodes = 1500
dataset = dataset_PROTEINS
dataset = dataset.shuffle()

class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, normalize=False, lin=True):
        super().__init__()

        self.conv1 = DenseSAGEConv(in_channels, hidden_channels, normalize)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = DenseSAGEConv(hidden_channels, hidden_channels, normalize)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = DenseSAGEConv(hidden_channels, out_channels, normalize)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        if lin:
            self.lin = torch.nn.Linear(out_channels, out_channels)
        else:
            self.lin = None

    def bn(self, i, x):
        batch_size, num_nodes, num_channels = x.size()
        x = x.view(-1, num_channels)
        x = getattr(self, f'bn{i}')(x)
        x = x.view(batch_size, num_nodes, num_channels)
        return x

    def forward(self, x, adj, mask=None):
        x = self.bn(1, self.conv1(x, adj, mask).relu())
        x = self.bn(2, self.conv2(x, adj, mask).relu())
        x = self.bn(3, self.conv3(x, adj, mask).relu())

        if self.lin is not None:
            x = self.lin(x).relu()

        return x


class Net_Diff(torch.nn.Module):
    def __init__(self):
        super().__init__()

        num_nodes = 64
        self.gnn1_pool = GNN(dataset.num_features, 64, num_nodes)
        self.gnn1_embed = DenseSAGEConv(dataset.num_features, 64)

        num_nodes = 64
        self.gnn2_pool = GNN(64, 64, num_nodes)
        self.gnn2_embed = DenseSAGEConv(64, 64)

        self.gnn3_embed = DenseSAGEConv(64, 64)

        self.lin1 = torch.nn.Linear(64, 32)
        self.lin2 = torch.nn.Linear(32, dataset.num_classes)

    def forward(self, x, adj, mask=None):
        s = self.gnn1_pool(x, adj, mask)
        x = self.gnn1_embed(x, adj, mask)
        x = F.relu(x)

        x, adj, l1, e1 = dense_diff_pool(x, adj, s, mask)

        s = self.gnn2_pool(x, adj)
        x = self.gnn2_embed(x, adj)
        x = F.relu(x)

        x, adj, l2, e2 = dense_diff_pool(x, adj, s)

        x = self.gnn3_embed(x, adj)
        x = F.relu(x)

        x = x.mean(dim=1)
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1), l1 + l2, e1 + e2

if torch.cuda.is_available():
    device = torch.device('cuda')
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

model = Net_Diff().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output, _, _ = model(data.x, data.adj, data.mask)
        loss = F.nll_loss(output, data.y.view(-1))
        loss.backward()
        total_loss += data.y.size(0) * float(loss)
        optimizer.step()
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        output, _, _ = model(data.x, data.adj, data.mask)
        pred = output.max(dim=1)[1]
        correct += int(pred.eq(data.y.view(-1)).sum())
    return correct / len(loader.dataset)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = Net_Diff().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6728, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 002, Loss: 0.6381, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 003, Loss: 0.6271, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 004, Loss: 0.6187, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 005, Loss: 0.6120, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 006, Loss: 0.6044, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 007, Loss: 0.5975, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 008, Loss: 0.5842, Val Acc: 0.7346, Test Acc: 0.6524
# Seed: 42, Epoch: 009, Loss: 0.5758, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 42, Epoch: 010, Loss: 0.5670, Val Acc: 0.7346, Test Acc: 0.6951
# Seed: 42, Epoch: 011, Loss: 0.5603, Val Acc: 0.5062, Test Acc: 0.5549
# Seed: 42, Epoch: 012, Loss: 0.5578, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 42, Epoch: 013, Loss: 0.5522, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 014, Loss: 0.5535, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 42, Epoch: 015, Loss: 0.5484, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 42, Epoch: 016, Loss: 0.5330, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 42, Epoch: 017, Loss: 0.5245, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 42, Epoch: 018, Loss: 0.5138, Val Acc: 0.7778, Test Acc: 0.7378
# Seed: 42, Epoch: 019, Loss: 0.5183, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 42, Epoch: 020, Loss: 0.5056, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 42, Epoch: 021, Loss: 0.4954, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 022, Loss: 0.4842, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 42, Epoch: 023, Loss: 0.4816, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 42, Epoch: 024, Loss: 0.4804, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 42, Epoch: 025, Loss: 0.4756, Val Acc: 0.6296, Test Acc: 0.6524
# Seed: 42, Epoch: 026, Loss: 0.4728, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 42, Epoch: 027, Loss: 0.4579, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 028, Loss: 0.4466, Val Acc: 0.7654, Test Acc: 0.7195
# Seed: 42, Epoch: 029, Loss: 0.4525, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 42, Epoch: 030, Loss: 0.4421, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 42, Epoch: 031, Loss: 0.4492, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 42, Epoch: 032, Loss: 0.4312, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 42, Epoch: 033, Loss: 0.4594, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 42, Epoch: 034, Loss: 0.4648, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 42, Epoch: 035, Loss: 0.4621, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 42, Epoch: 036, Loss: 0.4443, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 42, Epoch: 037, Loss: 0.4305, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 42, Epoch: 038, Loss: 0.4198, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 42, Epoch: 039, Loss: 0.4356, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 040, Loss: 0.4014, Val Acc: 0.7222, Test Acc: 0.7561
# Seed: 42, Epoch: 041, Loss: 0.3843, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 042, Loss: 0.4041, Val Acc: 0.7160, Test Acc: 0.7622
# Seed: 42, Epoch: 043, Loss: 0.3959, Val Acc: 0.7160, Test Acc: 0.7561
# Seed: 42, Epoch: 044, Loss: 0.4159, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 42, Epoch: 045, Loss: 0.3951, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 42, Epoch: 046, Loss: 0.4008, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 42, Epoch: 047, Loss: 0.4074, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 048, Loss: 0.4027, Val Acc: 0.6296, Test Acc: 0.6951
# Seed: 42, Epoch: 049, Loss: 0.3977, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 050, Loss: 0.3916, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 42, Epoch: 051, Loss: 0.4575, Val Acc: 0.6852, Test Acc: 0.7622
# Seed: 42, Epoch: 052, Loss: 0.4177, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 42, Epoch: 053, Loss: 0.4115, Val Acc: 0.6235, Test Acc: 0.6646
# Seed: 42, Epoch: 054, Loss: 0.4093, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 42, Epoch: 055, Loss: 0.3942, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 42, Epoch: 056, Loss: 0.3902, Val Acc: 0.6111, Test Acc: 0.6829
# Seed: 42, Epoch: 057, Loss: 0.3882, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 42, Epoch: 058, Loss: 0.3656, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 42, Epoch: 059, Loss: 0.3654, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 42, Epoch: 060, Loss: 0.3497, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 061, Loss: 0.3341, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 42, Epoch: 062, Loss: 0.3272, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 42, Epoch: 063, Loss: 0.3631, Val Acc: 0.6667, Test Acc: 0.7439
# Seed: 42, Epoch: 064, Loss: 0.3211, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 42, Epoch: 065, Loss: 0.3364, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 42, Epoch: 066, Loss: 0.3365, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 42, Epoch: 067, Loss: 0.3286, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 42, Epoch: 068, Loss: 0.3353, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 42, Epoch: 069, Loss: 0.3310, Val Acc: 0.6790, Test Acc: 0.6768
# Seed: 42, Epoch: 070, Loss: 0.3135, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 42, Epoch: 071, Loss: 0.3191, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 42, Epoch: 072, Loss: 0.3022, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 42, Epoch: 073, Loss: 0.2983, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 42, Epoch: 074, Loss: 0.3248, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 42, Epoch: 075, Loss: 0.3853, Val Acc: 0.6852, Test Acc: 0.7256
# Seed: 42, Epoch: 076, Loss: 0.3686, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 42, Epoch: 077, Loss: 0.3630, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 42, Epoch: 078, Loss: 0.3751, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 42, Epoch: 079, Loss: 0.3804, Val Acc: 0.6790, Test Acc: 0.6585
# Seed: 42, Epoch: 080, Loss: 0.3416, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 42, Epoch: 081, Loss: 0.3539, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 42, Epoch: 082, Loss: 0.3797, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 42, Epoch: 083, Loss: 0.3276, Val Acc: 0.6852, Test Acc: 0.7561
# Seed: 42, Epoch: 084, Loss: 0.3306, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 42, Epoch: 085, Loss: 0.3337, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 42, Epoch: 086, Loss: 0.3389, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 42, Epoch: 087, Loss: 0.3133, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 42, Epoch: 088, Loss: 0.2960, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 42, Epoch: 089, Loss: 0.3130, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 42, Epoch: 090, Loss: 0.2792, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 42, Epoch: 091, Loss: 0.2913, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 42, Epoch: 092, Loss: 0.2897, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 42, Epoch: 093, Loss: 0.2918, Val Acc: 0.5926, Test Acc: 0.6098
# Seed: 42, Epoch: 094, Loss: 0.3718, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 42, Epoch: 095, Loss: 0.2955, Val Acc: 0.6852, Test Acc: 0.6585
# Seed: 42, Epoch: 096, Loss: 0.3332, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 42, Epoch: 097, Loss: 0.2998, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 098, Loss: 0.2873, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 099, Loss: 0.3095, Val Acc: 0.7222, Test Acc: 0.6707
# Seed: 42, Epoch: 100, Loss: 0.2831, Val Acc: 0.6358, Test Acc: 0.6402
# Seed: 42, Epoch: 101, Loss: 0.2537, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 42, Epoch: 102, Loss: 0.2703, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 42, Epoch: 103, Loss: 0.2455, Val Acc: 0.6852, Test Acc: 0.6646
# Seed: 42, Epoch: 104, Loss: 0.2791, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 105, Loss: 0.2596, Val Acc: 0.6914, Test Acc: 0.7378
# Seed: 42, Epoch: 106, Loss: 0.2454, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 42, Epoch: 107, Loss: 0.2231, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 108, Loss: 0.2523, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 42, Epoch: 109, Loss: 0.2381, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 110, Loss: 0.2746, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 42, Epoch: 111, Loss: 0.2826, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 42, Epoch: 112, Loss: 0.2293, Val Acc: 0.6543, Test Acc: 0.6585
# Seed: 42, Epoch: 113, Loss: 0.2452, Val Acc: 0.6790, Test Acc: 0.6524
# Seed: 42, Epoch: 114, Loss: 0.2513, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 42, Epoch: 115, Loss: 0.2099, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 42, Epoch: 116, Loss: 0.2423, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 42, Epoch: 117, Loss: 0.2326, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 42, Epoch: 118, Loss: 0.2192, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 42, Epoch: 119, Loss: 0.1987, Val Acc: 0.6667, Test Acc: 0.6890
# Seed: 42, Epoch: 120, Loss: 0.2314, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 42, Epoch: 121, Loss: 0.2097, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 42, Epoch: 122, Loss: 0.2111, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 42, Epoch: 123, Loss: 0.2383, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 42, Epoch: 124, Loss: 0.2159, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 42, Epoch: 125, Loss: 0.1912, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 42, Epoch: 126, Loss: 0.1721, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 42, Epoch: 127, Loss: 0.1951, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 42, Epoch: 128, Loss: 0.1801, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 42, Epoch: 129, Loss: 0.1906, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 42, Epoch: 130, Loss: 0.1679, Val Acc: 0.6790, Test Acc: 0.6768
# Seed: 42, Epoch: 131, Loss: 0.1816, Val Acc: 0.6543, Test Acc: 0.6402
# Seed: 42, Epoch: 132, Loss: 0.1597, Val Acc: 0.6914, Test Acc: 0.6646
# Seed: 42, Epoch: 133, Loss: 0.1714, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 42, Epoch: 134, Loss: 0.1831, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 135, Loss: 0.1838, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 42, Epoch: 136, Loss: 0.1797, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 137, Loss: 0.1901, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 42, Epoch: 138, Loss: 0.2423, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 139, Loss: 0.1895, Val Acc: 0.7160, Test Acc: 0.6585
# Seed: 42, Epoch: 140, Loss: 0.2580, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 42, Epoch: 141, Loss: 0.1707, Val Acc: 0.7407, Test Acc: 0.7256
# Seed: 42, Epoch: 142, Loss: 0.1670, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 42, Epoch: 143, Loss: 0.1810, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 144, Loss: 0.1633, Val Acc: 0.7099, Test Acc: 0.6646
# Seed: 42, Epoch: 145, Loss: 0.1457, Val Acc: 0.6728, Test Acc: 0.6524
# Seed: 42, Epoch: 146, Loss: 0.1493, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 42, Epoch: 147, Loss: 0.1663, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 42, Epoch: 148, Loss: 0.1479, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 42, Epoch: 149, Loss: 0.1489, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 42, Epoch: 150, Loss: 0.1628, Val Acc: 0.7222, Test Acc: 0.6768
# Seed: 42, Epoch: 151, Loss: 0.1566, Val Acc: 0.7531, Test Acc: 0.6524
# Seed: 42, Epoch: 152, Loss: 0.1677, Val Acc: 0.7469, Test Acc: 0.6829
# Seed: 42, Epoch: 153, Loss: 0.1805, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 42, Epoch: 154, Loss: 0.1700, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 42, Epoch: 155, Loss: 0.2264, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 42, Epoch: 156, Loss: 0.2159, Val Acc: 0.6358, Test Acc: 0.6280
# Seed: 42, Epoch: 157, Loss: 0.2495, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 42, Epoch: 158, Loss: 0.2086, Val Acc: 0.6420, Test Acc: 0.7317
# Seed: 42, Epoch: 159, Loss: 0.2315, Val Acc: 0.6296, Test Acc: 0.6829
# Seed: 42, Epoch: 160, Loss: 0.2320, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 42, Epoch: 161, Loss: 0.1964, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 42, Epoch: 162, Loss: 0.1725, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 42, Epoch: 163, Loss: 0.1757, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 42, Epoch: 164, Loss: 0.1566, Val Acc: 0.6235, Test Acc: 0.6280
# Seed: 42, Epoch: 165, Loss: 0.1403, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 42, Epoch: 166, Loss: 0.1558, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 42, Epoch: 167, Loss: 0.1546, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 42, Epoch: 168, Loss: 0.1211, Val Acc: 0.6914, Test Acc: 0.7256
# Early stopping at epoch 168 for seed 42
# Seed: 43, Epoch: 001, Loss: 0.6719, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 002, Loss: 0.6381, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 003, Loss: 0.6256, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 004, Loss: 0.6221, Val Acc: 0.6605, Test Acc: 0.6098
# Seed: 43, Epoch: 005, Loss: 0.6138, Val Acc: 0.6790, Test Acc: 0.6280
# Seed: 43, Epoch: 006, Loss: 0.6071, Val Acc: 0.6975, Test Acc: 0.6585
# Seed: 43, Epoch: 007, Loss: 0.5965, Val Acc: 0.7284, Test Acc: 0.6707
# Seed: 43, Epoch: 008, Loss: 0.5825, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 43, Epoch: 009, Loss: 0.5673, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 43, Epoch: 010, Loss: 0.5722, Val Acc: 0.6790, Test Acc: 0.6768
# Seed: 43, Epoch: 011, Loss: 0.5535, Val Acc: 0.6543, Test Acc: 0.6768
# Seed: 43, Epoch: 012, Loss: 0.5897, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 43, Epoch: 013, Loss: 0.5485, Val Acc: 0.6420, Test Acc: 0.6463
# Seed: 43, Epoch: 014, Loss: 0.5487, Val Acc: 0.6543, Test Acc: 0.6707
# Seed: 43, Epoch: 015, Loss: 0.5374, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 43, Epoch: 016, Loss: 0.5285, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 43, Epoch: 017, Loss: 0.5251, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 43, Epoch: 018, Loss: 0.5176, Val Acc: 0.5802, Test Acc: 0.5732
# Seed: 43, Epoch: 019, Loss: 0.5178, Val Acc: 0.6605, Test Acc: 0.6951
# Seed: 43, Epoch: 020, Loss: 0.5056, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 43, Epoch: 021, Loss: 0.4912, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 43, Epoch: 022, Loss: 0.4857, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 43, Epoch: 023, Loss: 0.4956, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 024, Loss: 0.4872, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 43, Epoch: 025, Loss: 0.4745, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 026, Loss: 0.4669, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 43, Epoch: 027, Loss: 0.4606, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 43, Epoch: 028, Loss: 0.4638, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 43, Epoch: 029, Loss: 0.4650, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 030, Loss: 0.4623, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 43, Epoch: 031, Loss: 0.4479, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 43, Epoch: 032, Loss: 0.4455, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 43, Epoch: 033, Loss: 0.4411, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 43, Epoch: 034, Loss: 0.4518, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 43, Epoch: 035, Loss: 0.4448, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 036, Loss: 0.4288, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 43, Epoch: 037, Loss: 0.4252, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 43, Epoch: 038, Loss: 0.4220, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 039, Loss: 0.4116, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 43, Epoch: 040, Loss: 0.4186, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 43, Epoch: 041, Loss: 0.4131, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 43, Epoch: 042, Loss: 0.4244, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 43, Epoch: 043, Loss: 0.4212, Val Acc: 0.5741, Test Acc: 0.5854
# Seed: 43, Epoch: 044, Loss: 0.4174, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 43, Epoch: 045, Loss: 0.4268, Val Acc: 0.7407, Test Acc: 0.7256
# Seed: 43, Epoch: 046, Loss: 0.4083, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 43, Epoch: 047, Loss: 0.4012, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 43, Epoch: 048, Loss: 0.4088, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 43, Epoch: 049, Loss: 0.3910, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 43, Epoch: 050, Loss: 0.3886, Val Acc: 0.6235, Test Acc: 0.7012
# Seed: 43, Epoch: 051, Loss: 0.3896, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 43, Epoch: 052, Loss: 0.3878, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 43, Epoch: 053, Loss: 0.3940, Val Acc: 0.7778, Test Acc: 0.7256
# Seed: 43, Epoch: 054, Loss: 0.3718, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 43, Epoch: 055, Loss: 0.3972, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 43, Epoch: 056, Loss: 0.3774, Val Acc: 0.7037, Test Acc: 0.7012
# Seed: 43, Epoch: 057, Loss: 0.3947, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 058, Loss: 0.3604, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 43, Epoch: 059, Loss: 0.3758, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 060, Loss: 0.3668, Val Acc: 0.7778, Test Acc: 0.7073
# Seed: 43, Epoch: 061, Loss: 0.3611, Val Acc: 0.7654, Test Acc: 0.7317
# Seed: 43, Epoch: 062, Loss: 0.3390, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 43, Epoch: 063, Loss: 0.3711, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 43, Epoch: 064, Loss: 0.3399, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 065, Loss: 0.3383, Val Acc: 0.6914, Test Acc: 0.7378
# Seed: 43, Epoch: 066, Loss: 0.3470, Val Acc: 0.6914, Test Acc: 0.7439
# Seed: 43, Epoch: 067, Loss: 0.3182, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 068, Loss: 0.3151, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 43, Epoch: 069, Loss: 0.3278, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 43, Epoch: 070, Loss: 0.3375, Val Acc: 0.7222, Test Acc: 0.6707
# Seed: 43, Epoch: 071, Loss: 0.3449, Val Acc: 0.7284, Test Acc: 0.6951
# Seed: 43, Epoch: 072, Loss: 0.3427, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 43, Epoch: 073, Loss: 0.3213, Val Acc: 0.6852, Test Acc: 0.7378
# Seed: 43, Epoch: 074, Loss: 0.3241, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 43, Epoch: 075, Loss: 0.3102, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 43, Epoch: 076, Loss: 0.3045, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 43, Epoch: 077, Loss: 0.2987, Val Acc: 0.7407, Test Acc: 0.7988
# Seed: 43, Epoch: 078, Loss: 0.2997, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 43, Epoch: 079, Loss: 0.2925, Val Acc: 0.7407, Test Acc: 0.7012
# Seed: 43, Epoch: 080, Loss: 0.3024, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 43, Epoch: 081, Loss: 0.2917, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 43, Epoch: 082, Loss: 0.2900, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 43, Epoch: 083, Loss: 0.2863, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 084, Loss: 0.2857, Val Acc: 0.7222, Test Acc: 0.7134
# Seed: 43, Epoch: 085, Loss: 0.2813, Val Acc: 0.7654, Test Acc: 0.7012
# Seed: 43, Epoch: 086, Loss: 0.2814, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 43, Epoch: 087, Loss: 0.2753, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 43, Epoch: 088, Loss: 0.2852, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 43, Epoch: 089, Loss: 0.2344, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 43, Epoch: 090, Loss: 0.2892, Val Acc: 0.6543, Test Acc: 0.6402
# Seed: 43, Epoch: 091, Loss: 0.2735, Val Acc: 0.7037, Test Acc: 0.7012
# Seed: 43, Epoch: 092, Loss: 0.2477, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 43, Epoch: 093, Loss: 0.2622, Val Acc: 0.7593, Test Acc: 0.6951
# Seed: 43, Epoch: 094, Loss: 0.2414, Val Acc: 0.7099, Test Acc: 0.6707
# Seed: 43, Epoch: 095, Loss: 0.2317, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 43, Epoch: 096, Loss: 0.2218, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 097, Loss: 0.2389, Val Acc: 0.6914, Test Acc: 0.7622
# Seed: 43, Epoch: 098, Loss: 0.2317, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 43, Epoch: 099, Loss: 0.2172, Val Acc: 0.7160, Test Acc: 0.6280
# Seed: 43, Epoch: 100, Loss: 0.2076, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 43, Epoch: 101, Loss: 0.2583, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 43, Epoch: 102, Loss: 0.2625, Val Acc: 0.7037, Test Acc: 0.7012
# Seed: 43, Epoch: 103, Loss: 0.2299, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 104, Loss: 0.2680, Val Acc: 0.7469, Test Acc: 0.6951
# Seed: 43, Epoch: 105, Loss: 0.2251, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 43, Epoch: 106, Loss: 0.2819, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 43, Epoch: 107, Loss: 0.2787, Val Acc: 0.7222, Test Acc: 0.7744
# Seed: 43, Epoch: 108, Loss: 0.2394, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 43, Epoch: 109, Loss: 0.2380, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 43, Epoch: 110, Loss: 0.2593, Val Acc: 0.7654, Test Acc: 0.6768
# Seed: 43, Epoch: 111, Loss: 0.2066, Val Acc: 0.7778, Test Acc: 0.6890
# Seed: 43, Epoch: 112, Loss: 0.2013, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 43, Epoch: 113, Loss: 0.2157, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 43, Epoch: 114, Loss: 0.2197, Val Acc: 0.6420, Test Acc: 0.6280
# Seed: 43, Epoch: 115, Loss: 0.2361, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 43, Epoch: 116, Loss: 0.2104, Val Acc: 0.7469, Test Acc: 0.6951
# Seed: 43, Epoch: 117, Loss: 0.1921, Val Acc: 0.7037, Test Acc: 0.6402
# Seed: 43, Epoch: 118, Loss: 0.2001, Val Acc: 0.7407, Test Acc: 0.6890
# Seed: 43, Epoch: 119, Loss: 0.2118, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 43, Epoch: 120, Loss: 0.1837, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 43, Epoch: 121, Loss: 0.1699, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 43, Epoch: 122, Loss: 0.1708, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 43, Epoch: 123, Loss: 0.1777, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 43, Epoch: 124, Loss: 0.1687, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 125, Loss: 0.1635, Val Acc: 0.7160, Test Acc: 0.7622
# Seed: 43, Epoch: 126, Loss: 0.1993, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 43, Epoch: 127, Loss: 0.1735, Val Acc: 0.7284, Test Acc: 0.6890
# Seed: 43, Epoch: 128, Loss: 0.1597, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 43, Epoch: 129, Loss: 0.1615, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 43, Epoch: 130, Loss: 0.1514, Val Acc: 0.7284, Test Acc: 0.6951
# Seed: 43, Epoch: 131, Loss: 0.1542, Val Acc: 0.7222, Test Acc: 0.6829
# Seed: 43, Epoch: 132, Loss: 0.1620, Val Acc: 0.7284, Test Acc: 0.6524
# Seed: 43, Epoch: 133, Loss: 0.1270, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 43, Epoch: 134, Loss: 0.1280, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 43, Epoch: 135, Loss: 0.1651, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 43, Epoch: 136, Loss: 0.1646, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 43, Epoch: 137, Loss: 0.1732, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 43, Epoch: 138, Loss: 0.1664, Val Acc: 0.6914, Test Acc: 0.6646
# Seed: 43, Epoch: 139, Loss: 0.1962, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 43, Epoch: 140, Loss: 0.1622, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 43, Epoch: 141, Loss: 0.1852, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 43, Epoch: 142, Loss: 0.1653, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 43, Epoch: 143, Loss: 0.1712, Val Acc: 0.6852, Test Acc: 0.6585
# Seed: 43, Epoch: 144, Loss: 0.1447, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 43, Epoch: 145, Loss: 0.1399, Val Acc: 0.7531, Test Acc: 0.6524
# Seed: 43, Epoch: 146, Loss: 0.1457, Val Acc: 0.7531, Test Acc: 0.6707
# Seed: 43, Epoch: 147, Loss: 0.1425, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 43, Epoch: 148, Loss: 0.1362, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 43, Epoch: 149, Loss: 0.1499, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 43, Epoch: 150, Loss: 0.1171, Val Acc: 0.7222, Test Acc: 0.7134
# Seed: 43, Epoch: 151, Loss: 0.1062, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 43, Epoch: 152, Loss: 0.1492, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 43, Epoch: 153, Loss: 0.1296, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 43, Epoch: 154, Loss: 0.1415, Val Acc: 0.6914, Test Acc: 0.6829
# Seed: 43, Epoch: 155, Loss: 0.1435, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 43, Epoch: 156, Loss: 0.1292, Val Acc: 0.7099, Test Acc: 0.6707
# Seed: 43, Epoch: 157, Loss: 0.1295, Val Acc: 0.7160, Test Acc: 0.6402
# Seed: 43, Epoch: 158, Loss: 0.1186, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 43, Epoch: 159, Loss: 0.1209, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 43, Epoch: 160, Loss: 0.1015, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 43, Epoch: 161, Loss: 0.1096, Val Acc: 0.7099, Test Acc: 0.6524
# Seed: 43, Epoch: 162, Loss: 0.0996, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 43, Epoch: 163, Loss: 0.1005, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 43, Epoch: 164, Loss: 0.1096, Val Acc: 0.7222, Test Acc: 0.6829
# Seed: 43, Epoch: 165, Loss: 0.1321, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 43, Epoch: 166, Loss: 0.0989, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 43, Epoch: 167, Loss: 0.1112, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 43, Epoch: 168, Loss: 0.1207, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 43, Epoch: 169, Loss: 0.0680, Val Acc: 0.7593, Test Acc: 0.6829
# Seed: 43, Epoch: 170, Loss: 0.1322, Val Acc: 0.7654, Test Acc: 0.7012
# Seed: 43, Epoch: 171, Loss: 0.0754, Val Acc: 0.7716, Test Acc: 0.6951
# Seed: 43, Epoch: 172, Loss: 0.0859, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 173, Loss: 0.1170, Val Acc: 0.7284, Test Acc: 0.6707
# Seed: 43, Epoch: 174, Loss: 0.1161, Val Acc: 0.6914, Test Acc: 0.6341
# Seed: 43, Epoch: 175, Loss: 0.1207, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 43, Epoch: 176, Loss: 0.1027, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 43, Epoch: 177, Loss: 0.1216, Val Acc: 0.7593, Test Acc: 0.6829
# Seed: 43, Epoch: 178, Loss: 0.1108, Val Acc: 0.7654, Test Acc: 0.6524
# Seed: 43, Epoch: 179, Loss: 0.1656, Val Acc: 0.6975, Test Acc: 0.6646
# Seed: 43, Epoch: 180, Loss: 0.1416, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 43, Epoch: 181, Loss: 0.1067, Val Acc: 0.7284, Test Acc: 0.6768
# Seed: 43, Epoch: 182, Loss: 0.1246, Val Acc: 0.7346, Test Acc: 0.6951
# Seed: 43, Epoch: 183, Loss: 0.1135, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 43, Epoch: 184, Loss: 0.1129, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 43, Epoch: 185, Loss: 0.1099, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 43, Epoch: 186, Loss: 0.1475, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 43, Epoch: 187, Loss: 0.2199, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 43, Epoch: 188, Loss: 0.1547, Val Acc: 0.7531, Test Acc: 0.6524
# Seed: 43, Epoch: 189, Loss: 0.2450, Val Acc: 0.7284, Test Acc: 0.6463
# Seed: 43, Epoch: 190, Loss: 0.2368, Val Acc: 0.7160, Test Acc: 0.6585
# Seed: 43, Epoch: 191, Loss: 0.1727, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 43, Epoch: 192, Loss: 0.1686, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 43, Epoch: 193, Loss: 0.1620, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 43, Epoch: 194, Loss: 0.1134, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 195, Loss: 0.1113, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 43, Epoch: 196, Loss: 0.1104, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 43, Epoch: 197, Loss: 0.1062, Val Acc: 0.7037, Test Acc: 0.6768
# Seed: 43, Epoch: 198, Loss: 0.0774, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 43, Epoch: 199, Loss: 0.0736, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 43, Epoch: 200, Loss: 0.0874, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 44, Epoch: 001, Loss: 0.6589, Val Acc: 0.6790, Test Acc: 0.6280
# Seed: 44, Epoch: 002, Loss: 0.6240, Val Acc: 0.6790, Test Acc: 0.6280
# Seed: 44, Epoch: 003, Loss: 0.6196, Val Acc: 0.7037, Test Acc: 0.6463
# Seed: 44, Epoch: 004, Loss: 0.6083, Val Acc: 0.7284, Test Acc: 0.6890
# Seed: 44, Epoch: 005, Loss: 0.6030, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 44, Epoch: 006, Loss: 0.5925, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 44, Epoch: 007, Loss: 0.5846, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 44, Epoch: 008, Loss: 0.5733, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 44, Epoch: 009, Loss: 0.5621, Val Acc: 0.6605, Test Acc: 0.6951
# Seed: 44, Epoch: 010, Loss: 0.5526, Val Acc: 0.5926, Test Acc: 0.6463
# Seed: 44, Epoch: 011, Loss: 0.5393, Val Acc: 0.5494, Test Acc: 0.5976
# Seed: 44, Epoch: 012, Loss: 0.5318, Val Acc: 0.6296, Test Acc: 0.6585
# Seed: 44, Epoch: 013, Loss: 0.5415, Val Acc: 0.5864, Test Acc: 0.6524
# Seed: 44, Epoch: 014, Loss: 0.5192, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 44, Epoch: 015, Loss: 0.5055, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 44, Epoch: 016, Loss: 0.5025, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 44, Epoch: 017, Loss: 0.4901, Val Acc: 0.6543, Test Acc: 0.7317
# Seed: 44, Epoch: 018, Loss: 0.4763, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 44, Epoch: 019, Loss: 0.4852, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 44, Epoch: 020, Loss: 0.4624, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 44, Epoch: 021, Loss: 0.4581, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 44, Epoch: 022, Loss: 0.4646, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 44, Epoch: 023, Loss: 0.4454, Val Acc: 0.7593, Test Acc: 0.7012
# Seed: 44, Epoch: 024, Loss: 0.4487, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 44, Epoch: 025, Loss: 0.4404, Val Acc: 0.7593, Test Acc: 0.7012
# Seed: 44, Epoch: 026, Loss: 0.4312, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 44, Epoch: 027, Loss: 0.4505, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 44, Epoch: 028, Loss: 0.4174, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 44, Epoch: 029, Loss: 0.4193, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 44, Epoch: 030, Loss: 0.4213, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 44, Epoch: 031, Loss: 0.4073, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 44, Epoch: 032, Loss: 0.4087, Val Acc: 0.7346, Test Acc: 0.6829
# Seed: 44, Epoch: 033, Loss: 0.4095, Val Acc: 0.7407, Test Acc: 0.6829
# Seed: 44, Epoch: 034, Loss: 0.4006, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 44, Epoch: 035, Loss: 0.4088, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 44, Epoch: 036, Loss: 0.3887, Val Acc: 0.7654, Test Acc: 0.6951
# Seed: 44, Epoch: 037, Loss: 0.4210, Val Acc: 0.5988, Test Acc: 0.6341
# Seed: 44, Epoch: 038, Loss: 0.4285, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 44, Epoch: 039, Loss: 0.3886, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 44, Epoch: 040, Loss: 0.4090, Val Acc: 0.6358, Test Acc: 0.6524
# Seed: 44, Epoch: 041, Loss: 0.3948, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 44, Epoch: 042, Loss: 0.3759, Val Acc: 0.6790, Test Acc: 0.6829
# Seed: 44, Epoch: 043, Loss: 0.3743, Val Acc: 0.7346, Test Acc: 0.6951
# Seed: 44, Epoch: 044, Loss: 0.3659, Val Acc: 0.6543, Test Acc: 0.7134
# Seed: 44, Epoch: 045, Loss: 0.3642, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 44, Epoch: 046, Loss: 0.4003, Val Acc: 0.7778, Test Acc: 0.7012
# Seed: 44, Epoch: 047, Loss: 0.3896, Val Acc: 0.6667, Test Acc: 0.6524
# Seed: 44, Epoch: 048, Loss: 0.3834, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 44, Epoch: 049, Loss: 0.3546, Val Acc: 0.7778, Test Acc: 0.7195
# Seed: 44, Epoch: 050, Loss: 0.3883, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 44, Epoch: 051, Loss: 0.3378, Val Acc: 0.6420, Test Acc: 0.7439
# Seed: 44, Epoch: 052, Loss: 0.3595, Val Acc: 0.6049, Test Acc: 0.6707
# Seed: 44, Epoch: 053, Loss: 0.3332, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 44, Epoch: 054, Loss: 0.3551, Val Acc: 0.6296, Test Acc: 0.6646
# Seed: 44, Epoch: 055, Loss: 0.3620, Val Acc: 0.6296, Test Acc: 0.7256
# Seed: 44, Epoch: 056, Loss: 0.3272, Val Acc: 0.7407, Test Acc: 0.7317
# Seed: 44, Epoch: 057, Loss: 0.3137, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 44, Epoch: 058, Loss: 0.3097, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 44, Epoch: 059, Loss: 0.3086, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 44, Epoch: 060, Loss: 0.3073, Val Acc: 0.6420, Test Acc: 0.6524
# Seed: 44, Epoch: 061, Loss: 0.3176, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 44, Epoch: 062, Loss: 0.3366, Val Acc: 0.6605, Test Acc: 0.6159
# Seed: 44, Epoch: 063, Loss: 0.3327, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 44, Epoch: 064, Loss: 0.3218, Val Acc: 0.6790, Test Acc: 0.6098
# Seed: 44, Epoch: 065, Loss: 0.3163, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 44, Epoch: 066, Loss: 0.3057, Val Acc: 0.6543, Test Acc: 0.6646
# Seed: 44, Epoch: 067, Loss: 0.2823, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 44, Epoch: 068, Loss: 0.2824, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 44, Epoch: 069, Loss: 0.3285, Val Acc: 0.5988, Test Acc: 0.6280
# Seed: 44, Epoch: 070, Loss: 0.3278, Val Acc: 0.5679, Test Acc: 0.6341
# Seed: 44, Epoch: 071, Loss: 0.2882, Val Acc: 0.6173, Test Acc: 0.6646
# Seed: 44, Epoch: 072, Loss: 0.2911, Val Acc: 0.5617, Test Acc: 0.6463
# Seed: 44, Epoch: 073, Loss: 0.2999, Val Acc: 0.6296, Test Acc: 0.6585
# Seed: 44, Epoch: 074, Loss: 0.3076, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 44, Epoch: 075, Loss: 0.2813, Val Acc: 0.5617, Test Acc: 0.6402
# Seed: 44, Epoch: 076, Loss: 0.3002, Val Acc: 0.6173, Test Acc: 0.6829
# Seed: 44, Epoch: 077, Loss: 0.2792, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 44, Epoch: 078, Loss: 0.2653, Val Acc: 0.5062, Test Acc: 0.5976
# Seed: 44, Epoch: 079, Loss: 0.2785, Val Acc: 0.7346, Test Acc: 0.6707
# Seed: 44, Epoch: 080, Loss: 0.2632, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 44, Epoch: 081, Loss: 0.2758, Val Acc: 0.5802, Test Acc: 0.6768
# Seed: 44, Epoch: 082, Loss: 0.2649, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 44, Epoch: 083, Loss: 0.3194, Val Acc: 0.6358, Test Acc: 0.7378
# Seed: 44, Epoch: 084, Loss: 0.2800, Val Acc: 0.6358, Test Acc: 0.6768
# Seed: 44, Epoch: 085, Loss: 0.2694, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 44, Epoch: 086, Loss: 0.2748, Val Acc: 0.6173, Test Acc: 0.7012
# Seed: 44, Epoch: 087, Loss: 0.2698, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 44, Epoch: 088, Loss: 0.2605, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 44, Epoch: 089, Loss: 0.2647, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 44, Epoch: 090, Loss: 0.2523, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 44, Epoch: 091, Loss: 0.2450, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 44, Epoch: 092, Loss: 0.2327, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 44, Epoch: 093, Loss: 0.2233, Val Acc: 0.6296, Test Acc: 0.7195
# Seed: 44, Epoch: 094, Loss: 0.2645, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 44, Epoch: 095, Loss: 0.2203, Val Acc: 0.6975, Test Acc: 0.6585
# Seed: 44, Epoch: 096, Loss: 0.2267, Val Acc: 0.6543, Test Acc: 0.6768
# Seed: 44, Epoch: 097, Loss: 0.2221, Val Acc: 0.6605, Test Acc: 0.6768
# Seed: 44, Epoch: 098, Loss: 0.2271, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 44, Epoch: 099, Loss: 0.1971, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 44, Epoch: 100, Loss: 0.1887, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 44, Epoch: 101, Loss: 0.2137, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 44, Epoch: 102, Loss: 0.2153, Val Acc: 0.6235, Test Acc: 0.6159
# Seed: 44, Epoch: 103, Loss: 0.2150, Val Acc: 0.6358, Test Acc: 0.6646
# Seed: 44, Epoch: 104, Loss: 0.2703, Val Acc: 0.6790, Test Acc: 0.7561
# Seed: 44, Epoch: 105, Loss: 0.2472, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 44, Epoch: 106, Loss: 0.2229, Val Acc: 0.6111, Test Acc: 0.7012
# Seed: 44, Epoch: 107, Loss: 0.2502, Val Acc: 0.6235, Test Acc: 0.6890
# Seed: 44, Epoch: 108, Loss: 0.2205, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 44, Epoch: 109, Loss: 0.2215, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 44, Epoch: 110, Loss: 0.2131, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 44, Epoch: 111, Loss: 0.1921, Val Acc: 0.6728, Test Acc: 0.7378
# Seed: 44, Epoch: 112, Loss: 0.2201, Val Acc: 0.6667, Test Acc: 0.7378
# Seed: 44, Epoch: 113, Loss: 0.1899, Val Acc: 0.6914, Test Acc: 0.6585
# Seed: 44, Epoch: 114, Loss: 0.1859, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 44, Epoch: 115, Loss: 0.1749, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 44, Epoch: 116, Loss: 0.2065, Val Acc: 0.6975, Test Acc: 0.7561
# Seed: 44, Epoch: 117, Loss: 0.2478, Val Acc: 0.6358, Test Acc: 0.6768
# Seed: 44, Epoch: 118, Loss: 0.2464, Val Acc: 0.6296, Test Acc: 0.6220
# Seed: 44, Epoch: 119, Loss: 0.2475, Val Acc: 0.6605, Test Acc: 0.6280
# Seed: 44, Epoch: 120, Loss: 0.2603, Val Acc: 0.6111, Test Acc: 0.5976
# Seed: 44, Epoch: 121, Loss: 0.2326, Val Acc: 0.6173, Test Acc: 0.5976
# Seed: 44, Epoch: 122, Loss: 0.2288, Val Acc: 0.6852, Test Acc: 0.6646
# Seed: 44, Epoch: 123, Loss: 0.1938, Val Acc: 0.6728, Test Acc: 0.6585
# Seed: 44, Epoch: 124, Loss: 0.2010, Val Acc: 0.6605, Test Acc: 0.6951
# Seed: 44, Epoch: 125, Loss: 0.2145, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 44, Epoch: 126, Loss: 0.1921, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 44, Epoch: 127, Loss: 0.1954, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 44, Epoch: 128, Loss: 0.1883, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 44, Epoch: 129, Loss: 0.2125, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 44, Epoch: 130, Loss: 0.1865, Val Acc: 0.6605, Test Acc: 0.6829
# Seed: 44, Epoch: 131, Loss: 0.2149, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 44, Epoch: 132, Loss: 0.1742, Val Acc: 0.6543, Test Acc: 0.6707
# Seed: 44, Epoch: 133, Loss: 0.1857, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 44, Epoch: 134, Loss: 0.1715, Val Acc: 0.6481, Test Acc: 0.6707
# Seed: 44, Epoch: 135, Loss: 0.1771, Val Acc: 0.6420, Test Acc: 0.6524
# Seed: 44, Epoch: 136, Loss: 0.1606, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 44, Epoch: 137, Loss: 0.1415, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 44, Epoch: 138, Loss: 0.1415, Val Acc: 0.6852, Test Acc: 0.7256
# Seed: 44, Epoch: 139, Loss: 0.1547, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 44, Epoch: 140, Loss: 0.1458, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 44, Epoch: 141, Loss: 0.1782, Val Acc: 0.6481, Test Acc: 0.7195
# Seed: 44, Epoch: 142, Loss: 0.1604, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 44, Epoch: 143, Loss: 0.1991, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 44, Epoch: 144, Loss: 0.2022, Val Acc: 0.6420, Test Acc: 0.6524
# Seed: 44, Epoch: 145, Loss: 0.2573, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 44, Epoch: 146, Loss: 0.2300, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 44, Epoch: 147, Loss: 0.2100, Val Acc: 0.6296, Test Acc: 0.6707
# Seed: 44, Epoch: 148, Loss: 0.1994, Val Acc: 0.6173, Test Acc: 0.6829
# Seed: 44, Epoch: 149, Loss: 0.2141, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 44, Epoch: 150, Loss: 0.2040, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 44, Epoch: 151, Loss: 0.1829, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 44, Epoch: 152, Loss: 0.1656, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 44, Epoch: 153, Loss: 0.1653, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 44, Epoch: 154, Loss: 0.1518, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 44, Epoch: 155, Loss: 0.1359, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 44, Epoch: 156, Loss: 0.1400, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 44, Epoch: 157, Loss: 0.1620, Val Acc: 0.6173, Test Acc: 0.7073
# Seed: 44, Epoch: 158, Loss: 0.1414, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 44, Epoch: 159, Loss: 0.1339, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 44, Epoch: 160, Loss: 0.1499, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 44, Epoch: 161, Loss: 0.1970, Val Acc: 0.6543, Test Acc: 0.7073
# Seed: 44, Epoch: 162, Loss: 0.1829, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 44, Epoch: 163, Loss: 0.1683, Val Acc: 0.6543, Test Acc: 0.6768
# Seed: 44, Epoch: 164, Loss: 0.1988, Val Acc: 0.6296, Test Acc: 0.6585
# Seed: 44, Epoch: 165, Loss: 0.2335, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 44, Epoch: 166, Loss: 0.2096, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 44, Epoch: 167, Loss: 0.2092, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 44, Epoch: 168, Loss: 0.1922, Val Acc: 0.5864, Test Acc: 0.6646
# Seed: 44, Epoch: 169, Loss: 0.1807, Val Acc: 0.5988, Test Acc: 0.6524
# Seed: 44, Epoch: 170, Loss: 0.1774, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 44, Epoch: 171, Loss: 0.1561, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 44, Epoch: 172, Loss: 0.1458, Val Acc: 0.6543, Test Acc: 0.6829
# Seed: 44, Epoch: 173, Loss: 0.1375, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 44, Epoch: 174, Loss: 0.1553, Val Acc: 0.5926, Test Acc: 0.6707
# Seed: 44, Epoch: 175, Loss: 0.1136, Val Acc: 0.6173, Test Acc: 0.6524
# Seed: 44, Epoch: 176, Loss: 0.1166, Val Acc: 0.6481, Test Acc: 0.6524
# Seed: 44, Epoch: 177, Loss: 0.1279, Val Acc: 0.6481, Test Acc: 0.6280
# Seed: 44, Epoch: 178, Loss: 0.1300, Val Acc: 0.6358, Test Acc: 0.6402
# Seed: 44, Epoch: 179, Loss: 0.1711, Val Acc: 0.6420, Test Acc: 0.6768
# Seed: 44, Epoch: 180, Loss: 0.1217, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 44, Epoch: 181, Loss: 0.1449, Val Acc: 0.6296, Test Acc: 0.7012
# Seed: 44, Epoch: 182, Loss: 0.1274, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 44, Epoch: 183, Loss: 0.1548, Val Acc: 0.6481, Test Acc: 0.6463
# Seed: 44, Epoch: 184, Loss: 0.1217, Val Acc: 0.5988, Test Acc: 0.5671
# Seed: 44, Epoch: 185, Loss: 0.1061, Val Acc: 0.6358, Test Acc: 0.5488
# Seed: 44, Epoch: 186, Loss: 0.1347, Val Acc: 0.6049, Test Acc: 0.5671
# Seed: 44, Epoch: 187, Loss: 0.1260, Val Acc: 0.5494, Test Acc: 0.5671
# Seed: 44, Epoch: 188, Loss: 0.1068, Val Acc: 0.5926, Test Acc: 0.6098
# Seed: 44, Epoch: 189, Loss: 0.1245, Val Acc: 0.6481, Test Acc: 0.6585
# Seed: 44, Epoch: 190, Loss: 0.1017, Val Acc: 0.6420, Test Acc: 0.7073
# Seed: 44, Epoch: 191, Loss: 0.1052, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 44, Epoch: 192, Loss: 0.1143, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 44, Epoch: 193, Loss: 0.1121, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 44, Epoch: 194, Loss: 0.0999, Val Acc: 0.6728, Test Acc: 0.6463
# Seed: 44, Epoch: 195, Loss: 0.1070, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 44, Epoch: 196, Loss: 0.0979, Val Acc: 0.7160, Test Acc: 0.6707
# Early stopping at epoch 196 for seed 44
# Seed: 45, Epoch: 001, Loss: 0.6787, Val Acc: 0.6173, Test Acc: 0.6341
# Seed: 45, Epoch: 002, Loss: 0.6307, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 45, Epoch: 003, Loss: 0.6098, Val Acc: 0.7407, Test Acc: 0.7012
# Seed: 45, Epoch: 004, Loss: 0.6033, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 45, Epoch: 005, Loss: 0.6023, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 45, Epoch: 006, Loss: 0.5917, Val Acc: 0.7284, Test Acc: 0.6951
# Seed: 45, Epoch: 007, Loss: 0.5882, Val Acc: 0.7346, Test Acc: 0.6890
# Seed: 45, Epoch: 008, Loss: 0.5793, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 45, Epoch: 009, Loss: 0.5690, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 45, Epoch: 010, Loss: 0.5626, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 45, Epoch: 011, Loss: 0.5544, Val Acc: 0.6235, Test Acc: 0.6707
# Seed: 45, Epoch: 012, Loss: 0.5337, Val Acc: 0.5926, Test Acc: 0.6402
# Seed: 45, Epoch: 013, Loss: 0.5237, Val Acc: 0.6481, Test Acc: 0.6707
# Seed: 45, Epoch: 014, Loss: 0.5216, Val Acc: 0.5679, Test Acc: 0.6098
# Seed: 45, Epoch: 015, Loss: 0.5120, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 45, Epoch: 016, Loss: 0.4877, Val Acc: 0.5617, Test Acc: 0.6159
# Seed: 45, Epoch: 017, Loss: 0.4867, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 45, Epoch: 018, Loss: 0.4649, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 45, Epoch: 019, Loss: 0.4613, Val Acc: 0.6420, Test Acc: 0.6646
# Seed: 45, Epoch: 020, Loss: 0.4446, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 45, Epoch: 021, Loss: 0.4446, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 45, Epoch: 022, Loss: 0.4571, Val Acc: 0.4753, Test Acc: 0.5549
# Seed: 45, Epoch: 023, Loss: 0.4546, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 45, Epoch: 024, Loss: 0.4630, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 45, Epoch: 025, Loss: 0.4403, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 45, Epoch: 026, Loss: 0.4629, Val Acc: 0.6975, Test Acc: 0.7561
# Seed: 45, Epoch: 027, Loss: 0.4601, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 45, Epoch: 028, Loss: 0.4174, Val Acc: 0.7222, Test Acc: 0.7134
# Seed: 45, Epoch: 029, Loss: 0.4212, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 45, Epoch: 030, Loss: 0.4290, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 45, Epoch: 031, Loss: 0.4054, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 45, Epoch: 032, Loss: 0.4067, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 45, Epoch: 033, Loss: 0.4033, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 45, Epoch: 034, Loss: 0.4107, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 45, Epoch: 035, Loss: 0.4075, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 036, Loss: 0.4020, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 45, Epoch: 037, Loss: 0.3973, Val Acc: 0.7531, Test Acc: 0.6829
# Seed: 45, Epoch: 038, Loss: 0.3894, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 45, Epoch: 039, Loss: 0.3848, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 45, Epoch: 040, Loss: 0.3702, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 45, Epoch: 041, Loss: 0.3921, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 45, Epoch: 042, Loss: 0.3904, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 45, Epoch: 043, Loss: 0.3765, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 45, Epoch: 044, Loss: 0.3703, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 45, Epoch: 045, Loss: 0.3558, Val Acc: 0.7407, Test Acc: 0.7317
# Seed: 45, Epoch: 046, Loss: 0.3617, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 45, Epoch: 047, Loss: 0.3710, Val Acc: 0.6667, Test Acc: 0.7256
# Seed: 45, Epoch: 048, Loss: 0.3544, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 45, Epoch: 049, Loss: 0.3347, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 45, Epoch: 050, Loss: 0.3499, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 45, Epoch: 051, Loss: 0.3480, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 45, Epoch: 052, Loss: 0.3295, Val Acc: 0.6728, Test Acc: 0.7317
# Seed: 45, Epoch: 053, Loss: 0.3598, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 45, Epoch: 054, Loss: 0.3190, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 45, Epoch: 055, Loss: 0.3218, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 45, Epoch: 056, Loss: 0.3206, Val Acc: 0.6358, Test Acc: 0.6646
# Seed: 45, Epoch: 057, Loss: 0.3183, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 45, Epoch: 058, Loss: 0.3411, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 45, Epoch: 059, Loss: 0.3641, Val Acc: 0.6481, Test Acc: 0.7012
# Seed: 45, Epoch: 060, Loss: 0.3528, Val Acc: 0.6975, Test Acc: 0.7683
# Seed: 45, Epoch: 061, Loss: 0.3708, Val Acc: 0.6975, Test Acc: 0.7622
# Seed: 45, Epoch: 062, Loss: 0.3174, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 45, Epoch: 063, Loss: 0.3499, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 45, Epoch: 064, Loss: 0.3051, Val Acc: 0.6420, Test Acc: 0.7012
# Seed: 45, Epoch: 065, Loss: 0.3019, Val Acc: 0.6296, Test Acc: 0.6402
# Seed: 45, Epoch: 066, Loss: 0.3058, Val Acc: 0.6235, Test Acc: 0.6646
# Seed: 45, Epoch: 067, Loss: 0.2798, Val Acc: 0.6728, Test Acc: 0.6646
# Seed: 45, Epoch: 068, Loss: 0.2915, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 45, Epoch: 069, Loss: 0.2850, Val Acc: 0.6111, Test Acc: 0.6585
# Seed: 45, Epoch: 070, Loss: 0.3282, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 45, Epoch: 071, Loss: 0.3190, Val Acc: 0.6852, Test Acc: 0.7561
# Seed: 45, Epoch: 072, Loss: 0.2889, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 45, Epoch: 073, Loss: 0.2930, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 45, Epoch: 074, Loss: 0.2759, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 45, Epoch: 075, Loss: 0.2736, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 45, Epoch: 076, Loss: 0.3469, Val Acc: 0.6481, Test Acc: 0.6829
# Seed: 45, Epoch: 077, Loss: 0.2799, Val Acc: 0.6481, Test Acc: 0.7256
# Seed: 45, Epoch: 078, Loss: 0.2967, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 45, Epoch: 079, Loss: 0.2804, Val Acc: 0.6914, Test Acc: 0.6341
# Seed: 45, Epoch: 080, Loss: 0.2587, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 45, Epoch: 081, Loss: 0.2515, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 45, Epoch: 082, Loss: 0.2382, Val Acc: 0.6296, Test Acc: 0.6646
# Seed: 45, Epoch: 083, Loss: 0.2297, Val Acc: 0.6543, Test Acc: 0.7195
# Seed: 45, Epoch: 084, Loss: 0.2700, Val Acc: 0.6358, Test Acc: 0.7439
# Seed: 45, Epoch: 085, Loss: 0.2385, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 45, Epoch: 086, Loss: 0.2338, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 45, Epoch: 087, Loss: 0.2476, Val Acc: 0.6605, Test Acc: 0.7012
# Seed: 45, Epoch: 088, Loss: 0.2300, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 45, Epoch: 089, Loss: 0.2240, Val Acc: 0.6358, Test Acc: 0.6646
# Seed: 45, Epoch: 090, Loss: 0.2097, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 45, Epoch: 091, Loss: 0.2246, Val Acc: 0.6296, Test Acc: 0.7073
# Seed: 45, Epoch: 092, Loss: 0.2272, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 45, Epoch: 093, Loss: 0.2335, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 45, Epoch: 094, Loss: 0.2246, Val Acc: 0.6358, Test Acc: 0.7378
# Seed: 45, Epoch: 095, Loss: 0.2229, Val Acc: 0.6790, Test Acc: 0.6829
# Seed: 45, Epoch: 096, Loss: 0.2420, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 45, Epoch: 097, Loss: 0.2308, Val Acc: 0.6358, Test Acc: 0.6951
# Seed: 45, Epoch: 098, Loss: 0.2392, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 45, Epoch: 099, Loss: 0.2345, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 45, Epoch: 100, Loss: 0.2413, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 45, Epoch: 101, Loss: 0.2309, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 45, Epoch: 102, Loss: 0.2250, Val Acc: 0.6914, Test Acc: 0.6524
# Seed: 45, Epoch: 103, Loss: 0.2135, Val Acc: 0.6481, Test Acc: 0.6829
# Seed: 45, Epoch: 104, Loss: 0.2060, Val Acc: 0.5370, Test Acc: 0.6585
# Seed: 45, Epoch: 105, Loss: 0.2040, Val Acc: 0.6667, Test Acc: 0.7378
# Seed: 45, Epoch: 106, Loss: 0.2053, Val Acc: 0.6605, Test Acc: 0.6524
# Seed: 45, Epoch: 107, Loss: 0.1915, Val Acc: 0.6420, Test Acc: 0.6768
# Seed: 45, Epoch: 108, Loss: 0.2586, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 45, Epoch: 109, Loss: 0.2701, Val Acc: 0.6358, Test Acc: 0.7256
# Seed: 45, Epoch: 110, Loss: 0.2354, Val Acc: 0.5988, Test Acc: 0.6646
# Seed: 45, Epoch: 111, Loss: 0.2740, Val Acc: 0.6235, Test Acc: 0.6646
# Seed: 45, Epoch: 112, Loss: 0.2071, Val Acc: 0.6667, Test Acc: 0.7256
# Seed: 45, Epoch: 113, Loss: 0.2242, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 45, Epoch: 114, Loss: 0.2261, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 45, Epoch: 115, Loss: 0.2080, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 45, Epoch: 116, Loss: 0.2205, Val Acc: 0.6235, Test Acc: 0.6646
# Seed: 45, Epoch: 117, Loss: 0.1794, Val Acc: 0.6296, Test Acc: 0.6402
# Seed: 45, Epoch: 118, Loss: 0.1882, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 45, Epoch: 119, Loss: 0.1644, Val Acc: 0.6605, Test Acc: 0.6341
# Seed: 45, Epoch: 120, Loss: 0.1671, Val Acc: 0.6852, Test Acc: 0.6829
# ...
# Seed: 45, Epoch: 154, Loss: 0.2189, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 45, Epoch: 155, Loss: 0.1657, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 45, Epoch: 156, Loss: 0.1253, Val Acc: 0.6420, Test Acc: 0.6402
# Seed: 45, Epoch: 157, Loss: 0.1435, Val Acc: 0.6605, Test Acc: 0.6768
# Seed: 45, Epoch: 158, Loss: 0.1047, Val Acc: 0.6296, Test Acc: 0.6829
# Seed: 45, Epoch: 159, Loss: 0.1059, Val Acc: 0.5988, Test Acc: 0.6829
# Seed: 45, Epoch: 160, Loss: 0.1480, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 45, Epoch: 161, Loss: 0.1116, Val Acc: 0.6296, Test Acc: 0.7256
# Seed: 45, Epoch: 162, Loss: 0.1067, Val Acc: 0.6235, Test Acc: 0.7256
# Seed: 45, Epoch: 163, Loss: 0.0841, Val Acc: 0.6543, Test Acc: 0.7378
# Seed: 45, Epoch: 164, Loss: 0.1560, Val Acc: 0.6605, Test Acc: 0.6829
# Seed: 45, Epoch: 165, Loss: 0.1005, Val Acc: 0.6481, Test Acc: 0.6768
# Seed: 45, Epoch: 166, Loss: 0.1024, Val Acc: 0.6173, Test Acc: 0.6524
# Seed: 45, Epoch: 167, Loss: 0.1131, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 45, Epoch: 168, Loss: 0.0930, Val Acc: 0.6667, Test Acc: 0.7073
# Seed: 45, Epoch: 169, Loss: 0.0983, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 45, Epoch: 170, Loss: 0.0952, Val Acc: 0.6728, Test Acc: 0.7317
# Seed: 45, Epoch: 171, Loss: 0.1040, Val Acc: 0.6481, Test Acc: 0.6524
# Seed: 45, Epoch: 172, Loss: 0.1026, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 45, Epoch: 173, Loss: 0.1100, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 45, Epoch: 174, Loss: 0.1255, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 45, Epoch: 175, Loss: 0.0943, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 45, Epoch: 176, Loss: 0.0993, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 45, Epoch: 177, Loss: 0.0863, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 45, Epoch: 178, Loss: 0.1145, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 45, Epoch: 179, Loss: 0.1096, Val Acc: 0.6235, Test Acc: 0.6524
# Seed: 45, Epoch: 180, Loss: 0.1058, Val Acc: 0.6358, Test Acc: 0.6707
# Seed: 45, Epoch: 181, Loss: 0.0955, Val Acc: 0.6358, Test Acc: 0.7439
# Early stopping at epoch 181 for seed 45
# Seed: 46, Epoch: 001, Loss: 0.7039, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 46, Epoch: 002, Loss: 0.6511, Val Acc: 0.6852, Test Acc: 0.6341
# Seed: 46, Epoch: 003, Loss: 0.6250, Val Acc: 0.6605, Test Acc: 0.6220
# Seed: 46, Epoch: 004, Loss: 0.6215, Val Acc: 0.6914, Test Acc: 0.6341
# Seed: 46, Epoch: 005, Loss: 0.6156, Val Acc: 0.7099, Test Acc: 0.6707
# Seed: 46, Epoch: 006, Loss: 0.6108, Val Acc: 0.7222, Test Acc: 0.6829
# Seed: 46, Epoch: 007, Loss: 0.6052, Val Acc: 0.7284, Test Acc: 0.6829
# Seed: 46, Epoch: 008, Loss: 0.5974, Val Acc: 0.7407, Test Acc: 0.6890
# Seed: 46, Epoch: 009, Loss: 0.5884, Val Acc: 0.7346, Test Acc: 0.6890
# Seed: 46, Epoch: 010, Loss: 0.5791, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 46, Epoch: 011, Loss: 0.5696, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 46, Epoch: 012, Loss: 0.5600, Val Acc: 0.6111, Test Acc: 0.6220
# Seed: 46, Epoch: 013, Loss: 0.5560, Val Acc: 0.7222, Test Acc: 0.7134
# Seed: 46, Epoch: 014, Loss: 0.5425, Val Acc: 0.6481, Test Acc: 0.7012
# Seed: 46, Epoch: 015, Loss: 0.5376, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 46, Epoch: 016, Loss: 0.5349, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 46, Epoch: 017, Loss: 0.5203, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 46, Epoch: 018, Loss: 0.5047, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 46, Epoch: 019, Loss: 0.5131, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 020, Loss: 0.5000, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 021, Loss: 0.4949, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 46, Epoch: 022, Loss: 0.4908, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 46, Epoch: 023, Loss: 0.4921, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 46, Epoch: 024, Loss: 0.4768, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 46, Epoch: 025, Loss: 0.4803, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 46, Epoch: 026, Loss: 0.4752, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 46, Epoch: 027, Loss: 0.4618, Val Acc: 0.6914, Test Acc: 0.7378
# Seed: 46, Epoch: 028, Loss: 0.4538, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 46, Epoch: 029, Loss: 0.4701, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 030, Loss: 0.4767, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 46, Epoch: 031, Loss: 0.4661, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 46, Epoch: 032, Loss: 0.4592, Val Acc: 0.6667, Test Acc: 0.7317
# Seed: 46, Epoch: 033, Loss: 0.4715, Val Acc: 0.6481, Test Acc: 0.7012
# Seed: 46, Epoch: 034, Loss: 0.4598, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 46, Epoch: 035, Loss: 0.4458, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 46, Epoch: 036, Loss: 0.4446, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 46, Epoch: 037, Loss: 0.4394, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 038, Loss: 0.4450, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 039, Loss: 0.4356, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 040, Loss: 0.4321, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 041, Loss: 0.4380, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 46, Epoch: 042, Loss: 0.4160, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 46, Epoch: 043, Loss: 0.4191, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 46, Epoch: 044, Loss: 0.4311, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 46, Epoch: 045, Loss: 0.4224, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 46, Epoch: 046, Loss: 0.4145, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 46, Epoch: 047, Loss: 0.4224, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 46, Epoch: 048, Loss: 0.3967, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 46, Epoch: 049, Loss: 0.3923, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 46, Epoch: 050, Loss: 0.4043, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 46, Epoch: 051, Loss: 0.4304, Val Acc: 0.7284, Test Acc: 0.7805
# Seed: 46, Epoch: 052, Loss: 0.4015, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 46, Epoch: 053, Loss: 0.4017, Val Acc: 0.7284, Test Acc: 0.7683
# Seed: 46, Epoch: 054, Loss: 0.3719, Val Acc: 0.7284, Test Acc: 0.7866
# Seed: 46, Epoch: 055, Loss: 0.3822, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 056, Loss: 0.4132, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 46, Epoch: 057, Loss: 0.4000, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 46, Epoch: 058, Loss: 0.4069, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 46, Epoch: 059, Loss: 0.4112, Val Acc: 0.7284, Test Acc: 0.7744
# Seed: 46, Epoch: 060, Loss: 0.4119, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 46, Epoch: 061, Loss: 0.4071, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 062, Loss: 0.3787, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 063, Loss: 0.3604, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 46, Epoch: 064, Loss: 0.3627, Val Acc: 0.7099, Test Acc: 0.7500
# Seed: 46, Epoch: 065, Loss: 0.3640, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 46, Epoch: 066, Loss: 0.3624, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 46, Epoch: 067, Loss: 0.3539, Val Acc: 0.7346, Test Acc: 0.7866
# Seed: 46, Epoch: 068, Loss: 0.3711, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 46, Epoch: 069, Loss: 0.4023, Val Acc: 0.6852, Test Acc: 0.7500
# Seed: 46, Epoch: 070, Loss: 0.3687, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 071, Loss: 0.3739, Val Acc: 0.6790, Test Acc: 0.7561
# Seed: 46, Epoch: 072, Loss: 0.3864, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 46, Epoch: 073, Loss: 0.3888, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 074, Loss: 0.3514, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 075, Loss: 0.3590, Val Acc: 0.7222, Test Acc: 0.7744
# Seed: 46, Epoch: 076, Loss: 0.3444, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 077, Loss: 0.3497, Val Acc: 0.7160, Test Acc: 0.7683
# Seed: 46, Epoch: 078, Loss: 0.3304, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 46, Epoch: 079, Loss: 0.3329, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 080, Loss: 0.3438, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 46, Epoch: 081, Loss: 0.3255, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 46, Epoch: 082, Loss: 0.3131, Val Acc: 0.6420, Test Acc: 0.7561
# Seed: 46, Epoch: 083, Loss: 0.3252, Val Acc: 0.6605, Test Acc: 0.7500
# Seed: 46, Epoch: 084, Loss: 0.3126, Val Acc: 0.6728, Test Acc: 0.7378
# Seed: 46, Epoch: 085, Loss: 0.3110, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 086, Loss: 0.3227, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 087, Loss: 0.3205, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 46, Epoch: 088, Loss: 0.3183, Val Acc: 0.6481, Test Acc: 0.7561
# Seed: 46, Epoch: 089, Loss: 0.3310, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 46, Epoch: 090, Loss: 0.3503, Val Acc: 0.7284, Test Acc: 0.6768
# Seed: 46, Epoch: 091, Loss: 0.3138, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 092, Loss: 0.3125, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 46, Epoch: 093, Loss: 0.3227, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 094, Loss: 0.2894, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 46, Epoch: 095, Loss: 0.3463, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 096, Loss: 0.3381, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 097, Loss: 0.3126, Val Acc: 0.7284, Test Acc: 0.7744
# Seed: 46, Epoch: 098, Loss: 0.3014, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 099, Loss: 0.2978, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 46, Epoch: 100, Loss: 0.2884, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 46, Epoch: 101, Loss: 0.3067, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 46, Epoch: 102, Loss: 0.3255, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 103, Loss: 0.3010, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 104, Loss: 0.3121, Val Acc: 0.7654, Test Acc: 0.7012
# Seed: 46, Epoch: 105, Loss: 0.3012, Val Acc: 0.7222, Test Acc: 0.6951
# Seed: 46, Epoch: 106, Loss: 0.3278, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 46, Epoch: 107, Loss: 0.2969, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 108, Loss: 0.3007, Val Acc: 0.6790, Test Acc: 0.7500
# Seed: 46, Epoch: 109, Loss: 0.2830, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 110, Loss: 0.2868, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 46, Epoch: 111, Loss: 0.2775, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 112, Loss: 0.2785, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 113, Loss: 0.2540, Val Acc: 0.6605, Test Acc: 0.6768
# Seed: 46, Epoch: 114, Loss: 0.3171, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 46, Epoch: 115, Loss: 0.2678, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 46, Epoch: 116, Loss: 0.2749, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 46, Epoch: 117, Loss: 0.2586, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 46, Epoch: 118, Loss: 0.2661, Val Acc: 0.7222, Test Acc: 0.6951
# Seed: 46, Epoch: 119, Loss: 0.2324, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 46, Epoch: 120, Loss: 0.2691, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 46, Epoch: 121, Loss: 0.2604, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 122, Loss: 0.2374, Val Acc: 0.7469, Test Acc: 0.6829
# Seed: 46, Epoch: 123, Loss: 0.2681, Val Acc: 0.7346, Test Acc: 0.6951
# Seed: 46, Epoch: 124, Loss: 0.2265, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 46, Epoch: 125, Loss: 0.2679, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 126, Loss: 0.2554, Val Acc: 0.6790, Test Acc: 0.7378
# Seed: 46, Epoch: 127, Loss: 0.2413, Val Acc: 0.6728, Test Acc: 0.7317
# Seed: 46, Epoch: 128, Loss: 0.2206, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 46, Epoch: 129, Loss: 0.2698, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 46, Epoch: 130, Loss: 0.2026, Val Acc: 0.7284, Test Acc: 0.7744
# Seed: 46, Epoch: 131, Loss: 0.2053, Val Acc: 0.7099, Test Acc: 0.7683
# Seed: 46, Epoch: 132, Loss: 0.2464, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 46, Epoch: 133, Loss: 0.2303, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 46, Epoch: 134, Loss: 0.2362, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 46, Epoch: 135, Loss: 0.2014, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 46, Epoch: 136, Loss: 0.2093, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 46, Epoch: 137, Loss: 0.2112, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 46, Epoch: 138, Loss: 0.1949, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 46, Epoch: 139, Loss: 0.2613, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 46, Epoch: 140, Loss: 0.2590, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 46, Epoch: 141, Loss: 0.2192, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 46, Epoch: 142, Loss: 0.2393, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 46, Epoch: 143, Loss: 0.2499, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 46, Epoch: 144, Loss: 0.2326, Val Acc: 0.6975, Test Acc: 0.6524
# Seed: 46, Epoch: 145, Loss: 0.2295, Val Acc: 0.7593, Test Acc: 0.7195
# Seed: 46, Epoch: 146, Loss: 0.2663, Val Acc: 0.7716, Test Acc: 0.7134
# Seed: 46, Epoch: 147, Loss: 0.1984, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 46, Epoch: 148, Loss: 0.2107, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 46, Epoch: 149, Loss: 0.2198, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 46, Epoch: 150, Loss: 0.2366, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 46, Epoch: 151, Loss: 0.2469, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 46, Epoch: 152, Loss: 0.2610, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 46, Epoch: 153, Loss: 0.2271, Val Acc: 0.6235, Test Acc: 0.7134
# Seed: 46, Epoch: 154, Loss: 0.2331, Val Acc: 0.7654, Test Acc: 0.7073
# Seed: 46, Epoch: 155, Loss: 0.1861, Val Acc: 0.7531, Test Acc: 0.7012
# Seed: 46, Epoch: 156, Loss: 0.1858, Val Acc: 0.6728, Test Acc: 0.6646
# Seed: 46, Epoch: 157, Loss: 0.2357, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 46, Epoch: 158, Loss: 0.2144, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 46, Epoch: 159, Loss: 0.1922, Val Acc: 0.7407, Test Acc: 0.6829
# Seed: 46, Epoch: 160, Loss: 0.2774, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 46, Epoch: 161, Loss: 0.2075, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 46, Epoch: 162, Loss: 0.2271, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 46, Epoch: 163, Loss: 0.1849, Val Acc: 0.6605, Test Acc: 0.6951
# Seed: 46, Epoch: 164, Loss: 0.1866, Val Acc: 0.7284, Test Acc: 0.6890
# Seed: 46, Epoch: 165, Loss: 0.1586, Val Acc: 0.7407, Test Acc: 0.7256
# Seed: 46, Epoch: 166, Loss: 0.2084, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 46, Epoch: 167, Loss: 0.1712, Val Acc: 0.7716, Test Acc: 0.7256
# Seed: 46, Epoch: 168, Loss: 0.1676, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 46, Epoch: 169, Loss: 0.1633, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 46, Epoch: 170, Loss: 0.1431, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 46, Epoch: 171, Loss: 0.1772, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 46, Epoch: 172, Loss: 0.1597, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 46, Epoch: 173, Loss: 0.1520, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 46, Epoch: 174, Loss: 0.1409, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 46, Epoch: 175, Loss: 0.1289, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 46, Epoch: 176, Loss: 0.1429, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 46, Epoch: 177, Loss: 0.1444, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 46, Epoch: 178, Loss: 0.1629, Val Acc: 0.7346, Test Acc: 0.6951
# Seed: 46, Epoch: 179, Loss: 0.1528, Val Acc: 0.7346, Test Acc: 0.6890
# Seed: 46, Epoch: 180, Loss: 0.1719, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 46, Epoch: 181, Loss: 0.1532, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 182, Loss: 0.1897, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 183, Loss: 0.1579, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 46, Epoch: 184, Loss: 0.1180, Val Acc: 0.7160, Test Acc: 0.7561
# Seed: 46, Epoch: 185, Loss: 0.1308, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 46, Epoch: 186, Loss: 0.1783, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 46, Epoch: 187, Loss: 0.1613, Val Acc: 0.7346, Test Acc: 0.6890
# Seed: 46, Epoch: 188, Loss: 0.1117, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 46, Epoch: 189, Loss: 0.1113, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 46, Epoch: 190, Loss: 0.1104, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 46, Epoch: 191, Loss: 0.1261, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 46, Epoch: 192, Loss: 0.1480, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 46, Epoch: 193, Loss: 0.1107, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 46, Epoch: 194, Loss: 0.1454, Val Acc: 0.7284, Test Acc: 0.6768
# Seed: 46, Epoch: 195, Loss: 0.1785, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 46, Epoch: 196, Loss: 0.1646, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 46, Epoch: 197, Loss: 0.1624, Val Acc: 0.7099, Test Acc: 0.7500
# Early stopping at epoch 197 for seed 46
# Average Time: 42.02 seconds
# Var Time: 6.58 seconds
# Average Memory: 744.00 MB
# Average Best Val Acc: 0.7728
# Std Best Test Acc: 0.0198
# Average Test Acc: 0.7305

# %% [markdown]
# ## Dense Mincutpooling with HierarchicalGCN (2020)

# %%
import os.path as osp
import time
from math import ceil

import torch
import torch.nn.functional as F

import torch_geometric.transforms as T
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DenseDataLoader
from torch_geometric.nn import DenseSAGEConv, dense_mincut_pool
dataset = dataset_PROTEINS
dataset = dataset.shuffle()

class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, normalize=False, lin=True):
        super().__init__()

        self.conv1 = DenseSAGEConv(in_channels, hidden_channels, normalize)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = DenseSAGEConv(hidden_channels, hidden_channels, normalize)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = DenseSAGEConv(hidden_channels, out_channels, normalize)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        if lin:
            self.lin = torch.nn.Linear(out_channels, out_channels)
        else:
            self.lin = None

    def bn(self, i, x):
        batch_size, num_nodes, num_channels = x.size()
        x = x.view(-1, num_channels)
        x = getattr(self, f'bn{i}')(x)
        x = x.view(batch_size, num_nodes, num_channels)
        return x

    def forward(self, x, adj, mask=None):
        x = self.bn(1, self.conv1(x, adj, mask).relu())
        x = self.bn(2, self.conv2(x, adj, mask).relu())
        x = self.bn(3, self.conv3(x, adj, mask).relu())

        return x


class Net_mincut(torch.nn.Module):
    def __init__(self):
        super().__init__()

        num_nodes = 64
        self.gnn1_pool = GNN(dataset.num_features, 64, num_nodes)
        self.gnn1_embed = DenseSAGEConv(dataset.num_features, 64)

        num_nodes = 64
        self.gnn2_pool = GNN(64, 64, num_nodes)
        self.gnn2_embed = DenseSAGEConv(64, 64)

        self.gnn3_embed = DenseSAGEConv(64, 64)

        self.lin1 = torch.nn.Linear(64, 32)
        self.lin2 = torch.nn.Linear(32, dataset.num_classes)


    def forward(self, x, adj, mask=None):
        s = self.gnn1_pool(x, adj, mask)
        x = self.gnn1_embed(x, adj, mask)
        x = F.relu(x)

        x, adj, l1, e1 = dense_mincut_pool(x, adj, s, mask)

        s = self.gnn2_pool(x, adj)
        x = self.gnn2_embed(x, adj)
        x = F.relu(x)

        x, adj, l2, e2 = dense_mincut_pool(x, adj, s)

        x = self.gnn3_embed(x, adj)
        x = F.relu(x)

        x = x.mean(dim=1)
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1), l1 + l2, e1 + e2

if torch.cuda.is_available():
    device = torch.device('cuda')
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

model = Net_mincut().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output, _, _ = model(data.x, data.adj, data.mask)
        loss = F.nll_loss(output, data.y.view(-1))
        loss.backward()
        total_loss += data.y.size(0) * float(loss)
        optimizer.step()
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        output, _, _ = model(data.x, data.adj, data.mask)
        pred = output.max(dim=1)[1]
        correct += int(pred.eq(data.y.view(-1)).sum())
    return correct / len(loader.dataset)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = Net_mincut().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6698, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 002, Loss: 0.6449, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 003, Loss: 0.6416, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 004, Loss: 0.6340, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 005, Loss: 0.6267, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 006, Loss: 0.6179, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 007, Loss: 0.6110, Val Acc: 0.6358, Test Acc: 0.5549
# Seed: 42, Epoch: 008, Loss: 0.6007, Val Acc: 0.6358, Test Acc: 0.5549
# Seed: 42, Epoch: 009, Loss: 0.5879, Val Acc: 0.6852, Test Acc: 0.6280
# Seed: 42, Epoch: 010, Loss: 0.5786, Val Acc: 0.7037, Test Acc: 0.6463
# Seed: 42, Epoch: 011, Loss: 0.5501, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 42, Epoch: 012, Loss: 0.5302, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 42, Epoch: 013, Loss: 0.5169, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 42, Epoch: 014, Loss: 0.4988, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 42, Epoch: 015, Loss: 0.4959, Val Acc: 0.6049, Test Acc: 0.6768
# Seed: 42, Epoch: 016, Loss: 0.4875, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 42, Epoch: 017, Loss: 0.4749, Val Acc: 0.6235, Test Acc: 0.6829
# Seed: 42, Epoch: 018, Loss: 0.5050, Val Acc: 0.6111, Test Acc: 0.6707
# Seed: 42, Epoch: 019, Loss: 0.4697, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 42, Epoch: 020, Loss: 0.4831, Val Acc: 0.6111, Test Acc: 0.6646
# Seed: 42, Epoch: 021, Loss: 0.4487, Val Acc: 0.6975, Test Acc: 0.7561
# Seed: 42, Epoch: 022, Loss: 0.4491, Val Acc: 0.7099, Test Acc: 0.7561
# Seed: 42, Epoch: 023, Loss: 0.4433, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 42, Epoch: 024, Loss: 0.4287, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 025, Loss: 0.4248, Val Acc: 0.7099, Test Acc: 0.7500
# Seed: 42, Epoch: 026, Loss: 0.4232, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 42, Epoch: 027, Loss: 0.4064, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 42, Epoch: 028, Loss: 0.3952, Val Acc: 0.7160, Test Acc: 0.7622
# Seed: 42, Epoch: 029, Loss: 0.3857, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 42, Epoch: 030, Loss: 0.3766, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 42, Epoch: 031, Loss: 0.3538, Val Acc: 0.7531, Test Acc: 0.6890
# Seed: 42, Epoch: 032, Loss: 0.3687, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 42, Epoch: 033, Loss: 0.3450, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 42, Epoch: 034, Loss: 0.3587, Val Acc: 0.6296, Test Acc: 0.6402
# Seed: 42, Epoch: 035, Loss: 0.3418, Val Acc: 0.5432, Test Acc: 0.5915
# Seed: 42, Epoch: 036, Loss: 0.3769, Val Acc: 0.7222, Test Acc: 0.7561
# Seed: 42, Epoch: 037, Loss: 0.3515, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 42, Epoch: 038, Loss: 0.3244, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 42, Epoch: 039, Loss: 0.3476, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 040, Loss: 0.3239, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 42, Epoch: 041, Loss: 0.2999, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 42, Epoch: 042, Loss: 0.2708, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 42, Epoch: 043, Loss: 0.2814, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 42, Epoch: 044, Loss: 0.2817, Val Acc: 0.7037, Test Acc: 0.6646
# Seed: 42, Epoch: 045, Loss: 0.2612, Val Acc: 0.5988, Test Acc: 0.6463
# Seed: 42, Epoch: 046, Loss: 0.3064, Val Acc: 0.6049, Test Acc: 0.7073
# Seed: 42, Epoch: 047, Loss: 0.2598, Val Acc: 0.6173, Test Acc: 0.6524
# Seed: 42, Epoch: 048, Loss: 0.2590, Val Acc: 0.5679, Test Acc: 0.5976
# Seed: 42, Epoch: 049, Loss: 0.2549, Val Acc: 0.5988, Test Acc: 0.6402
# Seed: 42, Epoch: 050, Loss: 0.2782, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 42, Epoch: 051, Loss: 0.2744, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 42, Epoch: 052, Loss: 0.2358, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 42, Epoch: 053, Loss: 0.2376, Val Acc: 0.7593, Test Acc: 0.6890
# Seed: 42, Epoch: 054, Loss: 0.2253, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 42, Epoch: 055, Loss: 0.2420, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 42, Epoch: 056, Loss: 0.2544, Val Acc: 0.7346, Test Acc: 0.6890
# Seed: 42, Epoch: 057, Loss: 0.2538, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 42, Epoch: 058, Loss: 0.2423, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 42, Epoch: 059, Loss: 0.2513, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 42, Epoch: 060, Loss: 0.2329, Val Acc: 0.6481, Test Acc: 0.6585
# Seed: 42, Epoch: 061, Loss: 0.2229, Val Acc: 0.6420, Test Acc: 0.6341
# Seed: 42, Epoch: 062, Loss: 0.2238, Val Acc: 0.6605, Test Acc: 0.6707
# Seed: 42, Epoch: 063, Loss: 0.2533, Val Acc: 0.6049, Test Acc: 0.6951
# Seed: 42, Epoch: 064, Loss: 0.2080, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 42, Epoch: 065, Loss: 0.2057, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 42, Epoch: 066, Loss: 0.2252, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 42, Epoch: 067, Loss: 0.1918, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 42, Epoch: 068, Loss: 0.2062, Val Acc: 0.5988, Test Acc: 0.6585
# Seed: 42, Epoch: 069, Loss: 0.1871, Val Acc: 0.6667, Test Acc: 0.6890
# Seed: 42, Epoch: 070, Loss: 0.2197, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 42, Epoch: 071, Loss: 0.2073, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 42, Epoch: 072, Loss: 0.1888, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 42, Epoch: 073, Loss: 0.1826, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 074, Loss: 0.2109, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 42, Epoch: 075, Loss: 0.1904, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 42, Epoch: 076, Loss: 0.2255, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 077, Loss: 0.1985, Val Acc: 0.7037, Test Acc: 0.7500
# Seed: 42, Epoch: 078, Loss: 0.2171, Val Acc: 0.6728, Test Acc: 0.6524
# Seed: 42, Epoch: 079, Loss: 0.2095, Val Acc: 0.7531, Test Acc: 0.7134
# Seed: 42, Epoch: 080, Loss: 0.1949, Val Acc: 0.6790, Test Acc: 0.7561
# Seed: 42, Epoch: 081, Loss: 0.2263, Val Acc: 0.6605, Test Acc: 0.7561
# Seed: 42, Epoch: 082, Loss: 0.1993, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 42, Epoch: 083, Loss: 0.1795, Val Acc: 0.6111, Test Acc: 0.7073
# Seed: 42, Epoch: 084, Loss: 0.1943, Val Acc: 0.6605, Test Acc: 0.7195
# Seed: 42, Epoch: 085, Loss: 0.1814, Val Acc: 0.6605, Test Acc: 0.6768
# Seed: 42, Epoch: 086, Loss: 0.1634, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 42, Epoch: 087, Loss: 0.1461, Val Acc: 0.6111, Test Acc: 0.6890
# Seed: 42, Epoch: 088, Loss: 0.1471, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 42, Epoch: 089, Loss: 0.1676, Val Acc: 0.6358, Test Acc: 0.6890
# Seed: 42, Epoch: 090, Loss: 0.1411, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 42, Epoch: 091, Loss: 0.1450, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 42, Epoch: 092, Loss: 0.1332, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 42, Epoch: 093, Loss: 0.1478, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 42, Epoch: 094, Loss: 0.1445, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 42, Epoch: 095, Loss: 0.1263, Val Acc: 0.6481, Test Acc: 0.7134
# Seed: 42, Epoch: 096, Loss: 0.1365, Val Acc: 0.6049, Test Acc: 0.6707
# Seed: 42, Epoch: 097, Loss: 0.1385, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 42, Epoch: 098, Loss: 0.1365, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 42, Epoch: 099, Loss: 0.1302, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 42, Epoch: 100, Loss: 0.1439, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 42, Epoch: 101, Loss: 0.1060, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 42, Epoch: 102, Loss: 0.1298, Val Acc: 0.7284, Test Acc: 0.7683
# Seed: 42, Epoch: 103, Loss: 0.1074, Val Acc: 0.7160, Test Acc: 0.7744
# Seed: 42, Epoch: 104, Loss: 0.1236, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 42, Epoch: 105, Loss: 0.1453, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 42, Epoch: 106, Loss: 0.1432, Val Acc: 0.6667, Test Acc: 0.7073
# Seed: 42, Epoch: 107, Loss: 0.0963, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 42, Epoch: 108, Loss: 0.1593, Val Acc: 0.7099, Test Acc: 0.6524
# Seed: 42, Epoch: 109, Loss: 0.1490, Val Acc: 0.6358, Test Acc: 0.6707
# Seed: 42, Epoch: 110, Loss: 0.1146, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 42, Epoch: 111, Loss: 0.1692, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 42, Epoch: 112, Loss: 0.1293, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 42, Epoch: 113, Loss: 0.1220, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 42, Epoch: 114, Loss: 0.0851, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 42, Epoch: 115, Loss: 0.0883, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 42, Epoch: 116, Loss: 0.0764, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 117, Loss: 0.1003, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 118, Loss: 0.1146, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 42, Epoch: 119, Loss: 0.0987, Val Acc: 0.6049, Test Acc: 0.6768
# Seed: 42, Epoch: 120, Loss: 0.0883, Val Acc: 0.6296, Test Acc: 0.7073
# Seed: 42, Epoch: 121, Loss: 0.0859, Val Acc: 0.6543, Test Acc: 0.7012
# Seed: 42, Epoch: 122, Loss: 0.0937, Val Acc: 0.6728, Test Acc: 0.6524
# Seed: 42, Epoch: 123, Loss: 0.0968, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 124, Loss: 0.0695, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 42, Epoch: 125, Loss: 0.0790, Val Acc: 0.6914, Test Acc: 0.7561
# Seed: 42, Epoch: 126, Loss: 0.0987, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 127, Loss: 0.0526, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 42, Epoch: 128, Loss: 0.0791, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 42, Epoch: 129, Loss: 0.0962, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 42, Epoch: 130, Loss: 0.0707, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 42, Epoch: 131, Loss: 0.0794, Val Acc: 0.7346, Test Acc: 0.6707
# Seed: 42, Epoch: 132, Loss: 0.0555, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 42, Epoch: 133, Loss: 0.0596, Val Acc: 0.6296, Test Acc: 0.6890
# Seed: 42, Epoch: 134, Loss: 0.0432, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 42, Epoch: 135, Loss: 0.0646, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 42, Epoch: 136, Loss: 0.0740, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 42, Epoch: 137, Loss: 0.0620, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 42, Epoch: 138, Loss: 0.0822, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 42, Epoch: 139, Loss: 0.1306, Val Acc: 0.6358, Test Acc: 0.6341
# Seed: 42, Epoch: 140, Loss: 0.1538, Val Acc: 0.6481, Test Acc: 0.6524
# Seed: 42, Epoch: 141, Loss: 0.0882, Val Acc: 0.7160, Test Acc: 0.6646
# Seed: 42, Epoch: 142, Loss: 0.1206, Val Acc: 0.6605, Test Acc: 0.6585
# Seed: 42, Epoch: 143, Loss: 0.1011, Val Acc: 0.6235, Test Acc: 0.6707
# Seed: 42, Epoch: 144, Loss: 0.0978, Val Acc: 0.5617, Test Acc: 0.6524
# Seed: 42, Epoch: 145, Loss: 0.1335, Val Acc: 0.6481, Test Acc: 0.7134
# Seed: 42, Epoch: 146, Loss: 0.0982, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 147, Loss: 0.1009, Val Acc: 0.7222, Test Acc: 0.7622
# Seed: 42, Epoch: 148, Loss: 0.1155, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 42, Epoch: 149, Loss: 0.0892, Val Acc: 0.7407, Test Acc: 0.6890
# Seed: 42, Epoch: 150, Loss: 0.0811, Val Acc: 0.6914, Test Acc: 0.6829
# Seed: 42, Epoch: 151, Loss: 0.1169, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 152, Loss: 0.0747, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 42, Epoch: 153, Loss: 0.0730, Val Acc: 0.7222, Test Acc: 0.6768
# Seed: 42, Epoch: 154, Loss: 0.0853, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 42, Epoch: 155, Loss: 0.0698, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 42, Epoch: 156, Loss: 0.0434, Val Acc: 0.6914, Test Acc: 0.6646
# Seed: 42, Epoch: 157, Loss: 0.0777, Val Acc: 0.7222, Test Acc: 0.6707
# Seed: 42, Epoch: 158, Loss: 0.0439, Val Acc: 0.7284, Test Acc: 0.6829
# Seed: 42, Epoch: 159, Loss: 0.0777, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 42, Epoch: 160, Loss: 0.0586, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 42, Epoch: 161, Loss: 0.0600, Val Acc: 0.7160, Test Acc: 0.7561
# Seed: 42, Epoch: 162, Loss: 0.0341, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 42, Epoch: 163, Loss: 0.0884, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 164, Loss: 0.0774, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 42, Epoch: 165, Loss: 0.0522, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 42, Epoch: 166, Loss: 0.0733, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 42, Epoch: 167, Loss: 0.0405, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 42, Epoch: 168, Loss: 0.0520, Val Acc: 0.7346, Test Acc: 0.6951
# Seed: 42, Epoch: 169, Loss: 0.0301, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 170, Loss: 0.0574, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 42, Epoch: 171, Loss: 0.0387, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 42, Epoch: 172, Loss: 0.0428, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 42, Epoch: 173, Loss: 0.0389, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 42, Epoch: 174, Loss: 0.0477, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 42, Epoch: 175, Loss: 0.0498, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 42, Epoch: 176, Loss: 0.0306, Val Acc: 0.7284, Test Acc: 0.6890
# Seed: 42, Epoch: 177, Loss: 0.0647, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 178, Loss: 0.0404, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 42, Epoch: 179, Loss: 0.0559, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 42, Epoch: 180, Loss: 0.0429, Val Acc: 0.6543, Test Acc: 0.7195
# Seed: 42, Epoch: 181, Loss: 0.0718, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 42, Epoch: 182, Loss: 0.0531, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 42, Epoch: 183, Loss: 0.0795, Val Acc: 0.6481, Test Acc: 0.6768
# Seed: 42, Epoch: 184, Loss: 0.0787, Val Acc: 0.6111, Test Acc: 0.6951
# Seed: 42, Epoch: 185, Loss: 0.0688, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 42, Epoch: 186, Loss: 0.0879, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 42, Epoch: 187, Loss: 0.0572, Val Acc: 0.6667, Test Acc: 0.6707
# Seed: 42, Epoch: 188, Loss: 0.0541, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 42, Epoch: 189, Loss: 0.0831, Val Acc: 0.7099, Test Acc: 0.7012
# Early stopping at epoch 189 for seed 42
# Seed: 43, Epoch: 001, Loss: 0.6665, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 002, Loss: 0.6353, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 003, Loss: 0.6317, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 004, Loss: 0.6277, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 005, Loss: 0.6217, Val Acc: 0.6543, Test Acc: 0.6037
# Seed: 43, Epoch: 006, Loss: 0.6136, Val Acc: 0.6667, Test Acc: 0.6159
# Seed: 43, Epoch: 007, Loss: 0.6069, Val Acc: 0.6852, Test Acc: 0.6280
# Seed: 43, Epoch: 008, Loss: 0.5988, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 43, Epoch: 009, Loss: 0.5869, Val Acc: 0.7284, Test Acc: 0.6707
# Seed: 43, Epoch: 010, Loss: 0.5735, Val Acc: 0.7222, Test Acc: 0.6768
# Seed: 43, Epoch: 011, Loss: 0.5664, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 43, Epoch: 012, Loss: 0.5378, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 43, Epoch: 013, Loss: 0.5232, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 43, Epoch: 014, Loss: 0.5079, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 43, Epoch: 015, Loss: 0.4999, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 016, Loss: 0.4867, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 43, Epoch: 017, Loss: 0.4756, Val Acc: 0.7407, Test Acc: 0.7073
# Seed: 43, Epoch: 018, Loss: 0.4553, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 43, Epoch: 019, Loss: 0.4622, Val Acc: 0.7531, Test Acc: 0.6951
# Seed: 43, Epoch: 020, Loss: 0.4477, Val Acc: 0.7716, Test Acc: 0.7012
# Seed: 43, Epoch: 021, Loss: 0.4526, Val Acc: 0.7531, Test Acc: 0.7134
# Seed: 43, Epoch: 022, Loss: 0.4413, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 43, Epoch: 023, Loss: 0.4158, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 024, Loss: 0.4090, Val Acc: 0.6790, Test Acc: 0.6768
# Seed: 43, Epoch: 025, Loss: 0.4001, Val Acc: 0.7346, Test Acc: 0.6890
# Seed: 43, Epoch: 026, Loss: 0.3830, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 43, Epoch: 027, Loss: 0.3826, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 43, Epoch: 028, Loss: 0.3996, Val Acc: 0.6481, Test Acc: 0.7256
# Seed: 43, Epoch: 029, Loss: 0.3612, Val Acc: 0.6296, Test Acc: 0.6402
# Seed: 43, Epoch: 030, Loss: 0.3476, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 43, Epoch: 031, Loss: 0.3541, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 43, Epoch: 032, Loss: 0.3534, Val Acc: 0.6728, Test Acc: 0.6890
# Seed: 43, Epoch: 033, Loss: 0.3548, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 43, Epoch: 034, Loss: 0.3777, Val Acc: 0.6728, Test Acc: 0.6646
# Seed: 43, Epoch: 035, Loss: 0.3826, Val Acc: 0.6049, Test Acc: 0.6646
# Seed: 43, Epoch: 036, Loss: 0.3498, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 43, Epoch: 037, Loss: 0.3316, Val Acc: 0.5741, Test Acc: 0.6707
# Seed: 43, Epoch: 038, Loss: 0.3425, Val Acc: 0.5679, Test Acc: 0.6402
# Seed: 43, Epoch: 039, Loss: 0.3421, Val Acc: 0.6358, Test Acc: 0.6829
# Seed: 43, Epoch: 040, Loss: 0.3112, Val Acc: 0.5617, Test Acc: 0.6768
# Seed: 43, Epoch: 041, Loss: 0.3088, Val Acc: 0.6111, Test Acc: 0.6768
# Seed: 43, Epoch: 042, Loss: 0.3098, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 43, Epoch: 043, Loss: 0.2826, Val Acc: 0.7222, Test Acc: 0.6951
# Seed: 43, Epoch: 044, Loss: 0.3106, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 43, Epoch: 045, Loss: 0.3005, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 43, Epoch: 046, Loss: 0.2667, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 43, Epoch: 047, Loss: 0.2827, Val Acc: 0.6543, Test Acc: 0.7012
# Seed: 43, Epoch: 048, Loss: 0.2427, Val Acc: 0.6543, Test Acc: 0.6829
# Seed: 43, Epoch: 049, Loss: 0.2478, Val Acc: 0.6296, Test Acc: 0.6829
# Seed: 43, Epoch: 050, Loss: 0.2856, Val Acc: 0.5864, Test Acc: 0.6341
# Seed: 43, Epoch: 051, Loss: 0.2740, Val Acc: 0.7160, Test Acc: 0.6768
# Seed: 43, Epoch: 052, Loss: 0.2571, Val Acc: 0.6235, Test Acc: 0.6768
# Seed: 43, Epoch: 053, Loss: 0.2621, Val Acc: 0.6173, Test Acc: 0.6890
# Seed: 43, Epoch: 054, Loss: 0.2724, Val Acc: 0.5617, Test Acc: 0.6707
# Seed: 43, Epoch: 055, Loss: 0.2426, Val Acc: 0.6420, Test Acc: 0.6402
# Seed: 43, Epoch: 056, Loss: 0.2678, Val Acc: 0.6296, Test Acc: 0.6098
# Seed: 43, Epoch: 057, Loss: 0.2354, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 43, Epoch: 058, Loss: 0.2545, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 43, Epoch: 059, Loss: 0.2583, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 43, Epoch: 060, Loss: 0.2218, Val Acc: 0.6111, Test Acc: 0.6707
# Seed: 43, Epoch: 061, Loss: 0.2567, Val Acc: 0.6605, Test Acc: 0.6524
# Seed: 43, Epoch: 062, Loss: 0.2228, Val Acc: 0.6543, Test Acc: 0.6829
# Seed: 43, Epoch: 063, Loss: 0.2406, Val Acc: 0.6420, Test Acc: 0.6159
# Seed: 43, Epoch: 064, Loss: 0.2490, Val Acc: 0.6111, Test Acc: 0.6341
# Seed: 43, Epoch: 065, Loss: 0.2166, Val Acc: 0.6481, Test Acc: 0.6707
# Seed: 43, Epoch: 066, Loss: 0.2510, Val Acc: 0.7346, Test Acc: 0.6829
# Seed: 43, Epoch: 067, Loss: 0.2804, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 43, Epoch: 068, Loss: 0.2627, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 43, Epoch: 069, Loss: 0.2519, Val Acc: 0.6296, Test Acc: 0.6951
# Seed: 43, Epoch: 070, Loss: 0.2279, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 43, Epoch: 071, Loss: 0.2413, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 43, Epoch: 072, Loss: 0.2329, Val Acc: 0.6728, Test Acc: 0.6524
# Seed: 43, Epoch: 073, Loss: 0.1906, Val Acc: 0.6420, Test Acc: 0.6463
# Seed: 43, Epoch: 074, Loss: 0.1966, Val Acc: 0.6235, Test Acc: 0.6585
# Seed: 43, Epoch: 075, Loss: 0.2074, Val Acc: 0.5988, Test Acc: 0.7256
# Seed: 43, Epoch: 076, Loss: 0.1776, Val Acc: 0.5679, Test Acc: 0.7317
# Seed: 43, Epoch: 077, Loss: 0.2240, Val Acc: 0.6790, Test Acc: 0.7744
# Seed: 43, Epoch: 078, Loss: 0.2191, Val Acc: 0.5802, Test Acc: 0.6951
# Seed: 43, Epoch: 079, Loss: 0.2304, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 43, Epoch: 080, Loss: 0.2297, Val Acc: 0.6543, Test Acc: 0.6463
# Seed: 43, Epoch: 081, Loss: 0.2262, Val Acc: 0.7407, Test Acc: 0.7256
# Seed: 43, Epoch: 082, Loss: 0.2134, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 43, Epoch: 083, Loss: 0.2059, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 43, Epoch: 084, Loss: 0.1908, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 43, Epoch: 085, Loss: 0.1728, Val Acc: 0.7037, Test Acc: 0.6707
# Seed: 43, Epoch: 086, Loss: 0.1727, Val Acc: 0.6358, Test Acc: 0.6829
# Seed: 43, Epoch: 087, Loss: 0.1788, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 43, Epoch: 088, Loss: 0.1451, Val Acc: 0.6235, Test Acc: 0.7073
# Seed: 43, Epoch: 089, Loss: 0.1484, Val Acc: 0.6358, Test Acc: 0.7195
# Seed: 43, Epoch: 090, Loss: 0.1867, Val Acc: 0.6914, Test Acc: 0.7683
# Seed: 43, Epoch: 091, Loss: 0.1472, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 43, Epoch: 092, Loss: 0.1373, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 43, Epoch: 093, Loss: 0.1296, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 43, Epoch: 094, Loss: 0.1046, Val Acc: 0.7531, Test Acc: 0.6951
# Seed: 43, Epoch: 095, Loss: 0.1082, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 43, Epoch: 096, Loss: 0.0988, Val Acc: 0.7222, Test Acc: 0.6768
# Seed: 43, Epoch: 097, Loss: 0.0990, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 43, Epoch: 098, Loss: 0.0998, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 43, Epoch: 099, Loss: 0.1270, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 43, Epoch: 100, Loss: 0.1042, Val Acc: 0.6173, Test Acc: 0.6829
# Seed: 43, Epoch: 101, Loss: 0.1068, Val Acc: 0.6358, Test Acc: 0.6829
# Seed: 43, Epoch: 102, Loss: 0.0944, Val Acc: 0.5864, Test Acc: 0.6524
# Seed: 43, Epoch: 103, Loss: 0.1287, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 43, Epoch: 104, Loss: 0.1459, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 43, Epoch: 105, Loss: 0.0942, Val Acc: 0.6605, Test Acc: 0.6585
# Seed: 43, Epoch: 106, Loss: 0.1060, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 43, Epoch: 107, Loss: 0.0950, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 43, Epoch: 108, Loss: 0.0848, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 43, Epoch: 109, Loss: 0.0899, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 43, Epoch: 110, Loss: 0.1046, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 43, Epoch: 111, Loss: 0.0984, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 43, Epoch: 112, Loss: 0.1260, Val Acc: 0.7346, Test Acc: 0.6829
# Seed: 43, Epoch: 113, Loss: 0.1042, Val Acc: 0.7531, Test Acc: 0.7134
# Seed: 43, Epoch: 114, Loss: 0.1426, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 43, Epoch: 115, Loss: 0.0776, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 43, Epoch: 116, Loss: 0.1069, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 43, Epoch: 117, Loss: 0.0984, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 43, Epoch: 118, Loss: 0.0968, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 43, Epoch: 119, Loss: 0.1141, Val Acc: 0.7222, Test Acc: 0.6829
# Seed: 43, Epoch: 120, Loss: 0.1007, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 43, Epoch: 121, Loss: 0.0866, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 43, Epoch: 122, Loss: 0.0956, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 43, Epoch: 123, Loss: 0.1410, Val Acc: 0.6358, Test Acc: 0.6463
# Seed: 43, Epoch: 124, Loss: 0.1315, Val Acc: 0.6667, Test Acc: 0.6646
# Seed: 43, Epoch: 125, Loss: 0.1111, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 43, Epoch: 126, Loss: 0.1123, Val Acc: 0.6728, Test Acc: 0.7378
# Seed: 43, Epoch: 127, Loss: 0.0964, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 43, Epoch: 128, Loss: 0.1167, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 43, Epoch: 129, Loss: 0.1165, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 43, Epoch: 130, Loss: 0.0810, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 43, Epoch: 131, Loss: 0.1082, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 43, Epoch: 132, Loss: 0.0864, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 43, Epoch: 133, Loss: 0.0867, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 43, Epoch: 134, Loss: 0.0706, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 43, Epoch: 135, Loss: 0.0713, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 43, Epoch: 136, Loss: 0.0839, Val Acc: 0.6790, Test Acc: 0.6402
# Seed: 43, Epoch: 137, Loss: 0.0691, Val Acc: 0.7037, Test Acc: 0.6341
# Seed: 43, Epoch: 138, Loss: 0.0583, Val Acc: 0.7346, Test Acc: 0.6768
# Seed: 43, Epoch: 139, Loss: 0.0854, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 43, Epoch: 140, Loss: 0.0715, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 43, Epoch: 141, Loss: 0.0622, Val Acc: 0.7531, Test Acc: 0.6768
# Seed: 43, Epoch: 142, Loss: 0.0862, Val Acc: 0.7099, Test Acc: 0.6524
# Seed: 43, Epoch: 143, Loss: 0.1072, Val Acc: 0.7037, Test Acc: 0.6768
# Seed: 43, Epoch: 144, Loss: 0.0638, Val Acc: 0.7160, Test Acc: 0.6646
# Seed: 43, Epoch: 145, Loss: 0.0792, Val Acc: 0.6481, Test Acc: 0.6402
# Seed: 43, Epoch: 146, Loss: 0.0638, Val Acc: 0.6728, Test Acc: 0.6524
# Seed: 43, Epoch: 147, Loss: 0.0705, Val Acc: 0.6975, Test Acc: 0.6341
# Seed: 43, Epoch: 148, Loss: 0.0908, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 43, Epoch: 149, Loss: 0.0926, Val Acc: 0.7284, Test Acc: 0.6707
# Seed: 43, Epoch: 150, Loss: 0.0757, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 43, Epoch: 151, Loss: 0.0713, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 43, Epoch: 152, Loss: 0.0717, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 43, Epoch: 153, Loss: 0.0884, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 43, Epoch: 154, Loss: 0.0926, Val Acc: 0.6296, Test Acc: 0.6585
# Seed: 43, Epoch: 155, Loss: 0.0902, Val Acc: 0.7099, Test Acc: 0.7622
# Seed: 43, Epoch: 156, Loss: 0.0739, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 43, Epoch: 157, Loss: 0.0948, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 43, Epoch: 158, Loss: 0.0732, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 43, Epoch: 159, Loss: 0.0956, Val Acc: 0.6481, Test Acc: 0.6707
# Seed: 43, Epoch: 160, Loss: 0.0830, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 43, Epoch: 161, Loss: 0.0771, Val Acc: 0.6667, Test Acc: 0.7073
# Seed: 43, Epoch: 162, Loss: 0.0997, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 43, Epoch: 163, Loss: 0.0854, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 43, Epoch: 164, Loss: 0.1006, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 43, Epoch: 165, Loss: 0.0917, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 43, Epoch: 166, Loss: 0.0653, Val Acc: 0.6173, Test Acc: 0.7134
# Seed: 43, Epoch: 167, Loss: 0.0597, Val Acc: 0.6420, Test Acc: 0.7134
# Seed: 43, Epoch: 168, Loss: 0.0592, Val Acc: 0.6296, Test Acc: 0.7195
# Early stopping at epoch 168 for seed 43
# Seed: 44, Epoch: 001, Loss: 0.6592, Val Acc: 0.6358, Test Acc: 0.5732
# Seed: 44, Epoch: 002, Loss: 0.6274, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 44, Epoch: 003, Loss: 0.6240, Val Acc: 0.6358, Test Acc: 0.5793
# Seed: 44, Epoch: 004, Loss: 0.6167, Val Acc: 0.6667, Test Acc: 0.6098
# Seed: 44, Epoch: 005, Loss: 0.6134, Val Acc: 0.6852, Test Acc: 0.6341
# Seed: 44, Epoch: 006, Loss: 0.6021, Val Acc: 0.6667, Test Acc: 0.6220
# Seed: 44, Epoch: 007, Loss: 0.5953, Val Acc: 0.6914, Test Acc: 0.6280
# Seed: 44, Epoch: 008, Loss: 0.5754, Val Acc: 0.7099, Test Acc: 0.6524
# Seed: 44, Epoch: 009, Loss: 0.5568, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 44, Epoch: 010, Loss: 0.5347, Val Acc: 0.7099, Test Acc: 0.6646
# Seed: 44, Epoch: 011, Loss: 0.5077, Val Acc: 0.7284, Test Acc: 0.6890
# Seed: 44, Epoch: 012, Loss: 0.4917, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 44, Epoch: 013, Loss: 0.4875, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 44, Epoch: 014, Loss: 0.4758, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 44, Epoch: 015, Loss: 0.4614, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 44, Epoch: 016, Loss: 0.4423, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 44, Epoch: 017, Loss: 0.4339, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 44, Epoch: 018, Loss: 0.4244, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 44, Epoch: 019, Loss: 0.4217, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 44, Epoch: 020, Loss: 0.4199, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 44, Epoch: 021, Loss: 0.4368, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 022, Loss: 0.4174, Val Acc: 0.7778, Test Acc: 0.7378
# Seed: 44, Epoch: 023, Loss: 0.4246, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 44, Epoch: 024, Loss: 0.4055, Val Acc: 0.6296, Test Acc: 0.6341
# Seed: 44, Epoch: 025, Loss: 0.4005, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 44, Epoch: 026, Loss: 0.3948, Val Acc: 0.7531, Test Acc: 0.6707
# Seed: 44, Epoch: 027, Loss: 0.3970, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 44, Epoch: 028, Loss: 0.3952, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 44, Epoch: 029, Loss: 0.3821, Val Acc: 0.7593, Test Acc: 0.7134
# Seed: 44, Epoch: 030, Loss: 0.3779, Val Acc: 0.7037, Test Acc: 0.6768
# Seed: 44, Epoch: 031, Loss: 0.3817, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 44, Epoch: 032, Loss: 0.3517, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 44, Epoch: 033, Loss: 0.3504, Val Acc: 0.6358, Test Acc: 0.7256
# Seed: 44, Epoch: 034, Loss: 0.3600, Val Acc: 0.5432, Test Acc: 0.6220
# Seed: 44, Epoch: 035, Loss: 0.3711, Val Acc: 0.6605, Test Acc: 0.7012
# Seed: 44, Epoch: 036, Loss: 0.3275, Val Acc: 0.6914, Test Acc: 0.7500
# Seed: 44, Epoch: 037, Loss: 0.3298, Val Acc: 0.7222, Test Acc: 0.7683
# Seed: 44, Epoch: 038, Loss: 0.3133, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 44, Epoch: 039, Loss: 0.3023, Val Acc: 0.7284, Test Acc: 0.7866
# Seed: 44, Epoch: 040, Loss: 0.3139, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 44, Epoch: 041, Loss: 0.3021, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 44, Epoch: 042, Loss: 0.3063, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 44, Epoch: 043, Loss: 0.3030, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 44, Epoch: 044, Loss: 0.2946, Val Acc: 0.6173, Test Acc: 0.6829
# Seed: 44, Epoch: 045, Loss: 0.2712, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 44, Epoch: 046, Loss: 0.2906, Val Acc: 0.5864, Test Acc: 0.5061
# Seed: 44, Epoch: 047, Loss: 0.2875, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 44, Epoch: 048, Loss: 0.2546, Val Acc: 0.7778, Test Acc: 0.7256
# Seed: 44, Epoch: 049, Loss: 0.2662, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 44, Epoch: 050, Loss: 0.2322, Val Acc: 0.7407, Test Acc: 0.7317
# Seed: 44, Epoch: 051, Loss: 0.2394, Val Acc: 0.6728, Test Acc: 0.7439
# Seed: 44, Epoch: 052, Loss: 0.2688, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 44, Epoch: 053, Loss: 0.2581, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 44, Epoch: 054, Loss: 0.2592, Val Acc: 0.7160, Test Acc: 0.6768
# Seed: 44, Epoch: 055, Loss: 0.2659, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 44, Epoch: 056, Loss: 0.2496, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 44, Epoch: 057, Loss: 0.2171, Val Acc: 0.5864, Test Acc: 0.6829
# Seed: 44, Epoch: 058, Loss: 0.2074, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 44, Epoch: 059, Loss: 0.2014, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 44, Epoch: 060, Loss: 0.1984, Val Acc: 0.6420, Test Acc: 0.6402
# Seed: 44, Epoch: 061, Loss: 0.1911, Val Acc: 0.7037, Test Acc: 0.6707
# Seed: 44, Epoch: 062, Loss: 0.2041, Val Acc: 0.6728, Test Acc: 0.6402
# Seed: 44, Epoch: 063, Loss: 0.1849, Val Acc: 0.7407, Test Acc: 0.6585
# Seed: 44, Epoch: 064, Loss: 0.1741, Val Acc: 0.6728, Test Acc: 0.6402
# Seed: 44, Epoch: 065, Loss: 0.2110, Val Acc: 0.6420, Test Acc: 0.6220
# Seed: 44, Epoch: 066, Loss: 0.2349, Val Acc: 0.6111, Test Acc: 0.4939
# Seed: 44, Epoch: 067, Loss: 0.2177, Val Acc: 0.6728, Test Acc: 0.5183
# Seed: 44, Epoch: 068, Loss: 0.1913, Val Acc: 0.7099, Test Acc: 0.6037
# Seed: 44, Epoch: 069, Loss: 0.1986, Val Acc: 0.7037, Test Acc: 0.5610
# Seed: 44, Epoch: 070, Loss: 0.2061, Val Acc: 0.7284, Test Acc: 0.6768
# Seed: 44, Epoch: 071, Loss: 0.1690, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 44, Epoch: 072, Loss: 0.1807, Val Acc: 0.6605, Test Acc: 0.6463
# Seed: 44, Epoch: 073, Loss: 0.1606, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 44, Epoch: 074, Loss: 0.1539, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 44, Epoch: 075, Loss: 0.1858, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 44, Epoch: 076, Loss: 0.1765, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 44, Epoch: 077, Loss: 0.1584, Val Acc: 0.7160, Test Acc: 0.6463
# Seed: 44, Epoch: 078, Loss: 0.1757, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 44, Epoch: 079, Loss: 0.1793, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 44, Epoch: 080, Loss: 0.1710, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 44, Epoch: 081, Loss: 0.2077, Val Acc: 0.6481, Test Acc: 0.6585
# Seed: 44, Epoch: 082, Loss: 0.1887, Val Acc: 0.5988, Test Acc: 0.6646
# Seed: 44, Epoch: 083, Loss: 0.1857, Val Acc: 0.6605, Test Acc: 0.7195
# Seed: 44, Epoch: 084, Loss: 0.1536, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 44, Epoch: 085, Loss: 0.1538, Val Acc: 0.7284, Test Acc: 0.7683
# Seed: 44, Epoch: 086, Loss: 0.1563, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 44, Epoch: 087, Loss: 0.1321, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 44, Epoch: 088, Loss: 0.1144, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 44, Epoch: 089, Loss: 0.1135, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 44, Epoch: 090, Loss: 0.1059, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 44, Epoch: 091, Loss: 0.1102, Val Acc: 0.7531, Test Acc: 0.6890
# Seed: 44, Epoch: 092, Loss: 0.1063, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 44, Epoch: 093, Loss: 0.1067, Val Acc: 0.7716, Test Acc: 0.6951
# Seed: 44, Epoch: 094, Loss: 0.1000, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 44, Epoch: 095, Loss: 0.0942, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 44, Epoch: 096, Loss: 0.1030, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 44, Epoch: 097, Loss: 0.1124, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 44, Epoch: 098, Loss: 0.0912, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 44, Epoch: 099, Loss: 0.0789, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 44, Epoch: 100, Loss: 0.0730, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 44, Epoch: 101, Loss: 0.1022, Val Acc: 0.6975, Test Acc: 0.6524
# Seed: 44, Epoch: 102, Loss: 0.0802, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 44, Epoch: 103, Loss: 0.0965, Val Acc: 0.7222, Test Acc: 0.6768
# Seed: 44, Epoch: 104, Loss: 0.1149, Val Acc: 0.6111, Test Acc: 0.6463
# Seed: 44, Epoch: 105, Loss: 0.1266, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 44, Epoch: 106, Loss: 0.1372, Val Acc: 0.6667, Test Acc: 0.6646
# Seed: 44, Epoch: 107, Loss: 0.1124, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 44, Epoch: 108, Loss: 0.1381, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 44, Epoch: 109, Loss: 0.1408, Val Acc: 0.6605, Test Acc: 0.7012
# Seed: 44, Epoch: 110, Loss: 0.1935, Val Acc: 0.6420, Test Acc: 0.7317
# Seed: 44, Epoch: 111, Loss: 0.1944, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 44, Epoch: 112, Loss: 0.1795, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 44, Epoch: 113, Loss: 0.1950, Val Acc: 0.6420, Test Acc: 0.6524
# Seed: 44, Epoch: 114, Loss: 0.1463, Val Acc: 0.7346, Test Acc: 0.6524
# Seed: 44, Epoch: 115, Loss: 0.2298, Val Acc: 0.6914, Test Acc: 0.6341
# Seed: 44, Epoch: 116, Loss: 0.2705, Val Acc: 0.7222, Test Acc: 0.6646
# Seed: 44, Epoch: 117, Loss: 0.2395, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 44, Epoch: 118, Loss: 0.1718, Val Acc: 0.6420, Test Acc: 0.6524
# Seed: 44, Epoch: 119, Loss: 0.1733, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 44, Epoch: 120, Loss: 0.1626, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 44, Epoch: 121, Loss: 0.1442, Val Acc: 0.6605, Test Acc: 0.6220
# Seed: 44, Epoch: 122, Loss: 0.1316, Val Acc: 0.7099, Test Acc: 0.6646
# Seed: 44, Epoch: 123, Loss: 0.1085, Val Acc: 0.7469, Test Acc: 0.6646
# Seed: 44, Epoch: 124, Loss: 0.1122, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 44, Epoch: 125, Loss: 0.1072, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 44, Epoch: 126, Loss: 0.1222, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 44, Epoch: 127, Loss: 0.1275, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 44, Epoch: 128, Loss: 0.1472, Val Acc: 0.7284, Test Acc: 0.6829
# Seed: 44, Epoch: 129, Loss: 0.1440, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 44, Epoch: 130, Loss: 0.1257, Val Acc: 0.6481, Test Acc: 0.6402
# Seed: 44, Epoch: 131, Loss: 0.1223, Val Acc: 0.6358, Test Acc: 0.6220
# Seed: 44, Epoch: 132, Loss: 0.1488, Val Acc: 0.5617, Test Acc: 0.5488
# Seed: 44, Epoch: 133, Loss: 0.1600, Val Acc: 0.6790, Test Acc: 0.5976
# Seed: 44, Epoch: 134, Loss: 0.1087, Val Acc: 0.7160, Test Acc: 0.6768
# Seed: 44, Epoch: 135, Loss: 0.1152, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 44, Epoch: 136, Loss: 0.0892, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 44, Epoch: 137, Loss: 0.0967, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 44, Epoch: 138, Loss: 0.0888, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 44, Epoch: 139, Loss: 0.0789, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 44, Epoch: 140, Loss: 0.0747, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 44, Epoch: 141, Loss: 0.0919, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 44, Epoch: 142, Loss: 0.0797, Val Acc: 0.6975, Test Acc: 0.6463
# Seed: 44, Epoch: 143, Loss: 0.1123, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 44, Epoch: 144, Loss: 0.0858, Val Acc: 0.6852, Test Acc: 0.7561
# Seed: 44, Epoch: 145, Loss: 0.1096, Val Acc: 0.6852, Test Acc: 0.7561
# Seed: 44, Epoch: 146, Loss: 0.0863, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 44, Epoch: 147, Loss: 0.0721, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 44, Epoch: 148, Loss: 0.0819, Val Acc: 0.6728, Test Acc: 0.6890
# Seed: 44, Epoch: 149, Loss: 0.0712, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 44, Epoch: 150, Loss: 0.0529, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 44, Epoch: 151, Loss: 0.0781, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 44, Epoch: 152, Loss: 0.0626, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 44, Epoch: 153, Loss: 0.0713, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 44, Epoch: 154, Loss: 0.0490, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 44, Epoch: 155, Loss: 0.0485, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 44, Epoch: 156, Loss: 0.0692, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 44, Epoch: 157, Loss: 0.0747, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 44, Epoch: 158, Loss: 0.0624, Val Acc: 0.6420, Test Acc: 0.6890
# Seed: 44, Epoch: 159, Loss: 0.0560, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 44, Epoch: 160, Loss: 0.0723, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 44, Epoch: 161, Loss: 0.0618, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 44, Epoch: 162, Loss: 0.0624, Val Acc: 0.6543, Test Acc: 0.7073
# Seed: 44, Epoch: 163, Loss: 0.0400, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 44, Epoch: 164, Loss: 0.0573, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 44, Epoch: 165, Loss: 0.0459, Val Acc: 0.6728, Test Acc: 0.6585
# Seed: 44, Epoch: 166, Loss: 0.0557, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 44, Epoch: 167, Loss: 0.0517, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 44, Epoch: 168, Loss: 0.0350, Val Acc: 0.6914, Test Acc: 0.7439
# Seed: 44, Epoch: 169, Loss: 0.0662, Val Acc: 0.7099, Test Acc: 0.7500
# Seed: 44, Epoch: 170, Loss: 0.0544, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 44, Epoch: 171, Loss: 0.0803, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 44, Epoch: 172, Loss: 0.0555, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 44, Epoch: 173, Loss: 0.0578, Val Acc: 0.6667, Test Acc: 0.6890
# Seed: 44, Epoch: 174, Loss: 0.0653, Val Acc: 0.6543, Test Acc: 0.6646
# Seed: 44, Epoch: 175, Loss: 0.0569, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 44, Epoch: 176, Loss: 0.0583, Val Acc: 0.6667, Test Acc: 0.6890
# Seed: 44, Epoch: 177, Loss: 0.0550, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 44, Epoch: 178, Loss: 0.0467, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 44, Epoch: 179, Loss: 0.0567, Val Acc: 0.6914, Test Acc: 0.7500
# Seed: 44, Epoch: 180, Loss: 0.0652, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 44, Epoch: 181, Loss: 0.0501, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 44, Epoch: 182, Loss: 0.0477, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 44, Epoch: 183, Loss: 0.0523, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 44, Epoch: 184, Loss: 0.0367, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 44, Epoch: 185, Loss: 0.0472, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 44, Epoch: 186, Loss: 0.0394, Val Acc: 0.6543, Test Acc: 0.7134
# Seed: 44, Epoch: 187, Loss: 0.0592, Val Acc: 0.6790, Test Acc: 0.7622
# Seed: 44, Epoch: 188, Loss: 0.0274, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 44, Epoch: 189, Loss: 0.0440, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 44, Epoch: 190, Loss: 0.0447, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 44, Epoch: 191, Loss: 0.0951, Val Acc: 0.6481, Test Acc: 0.6768
# Seed: 44, Epoch: 192, Loss: 0.0588, Val Acc: 0.6296, Test Acc: 0.6707
# Seed: 44, Epoch: 193, Loss: 0.0563, Val Acc: 0.6296, Test Acc: 0.6585
# Seed: 44, Epoch: 194, Loss: 0.0462, Val Acc: 0.6296, Test Acc: 0.6341
# Seed: 44, Epoch: 195, Loss: 0.0571, Val Acc: 0.6914, Test Acc: 0.6646
# Seed: 44, Epoch: 196, Loss: 0.0727, Val Acc: 0.7099, Test Acc: 0.6646
# Seed: 44, Epoch: 197, Loss: 0.0359, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 44, Epoch: 198, Loss: 0.0376, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 44, Epoch: 199, Loss: 0.0434, Val Acc: 0.7222, Test Acc: 0.7256
# Early stopping at epoch 199 for seed 44
# Seed: 45, Epoch: 001, Loss: 0.6855, Val Acc: 0.5988, Test Acc: 0.6098
# Seed: 45, Epoch: 002, Loss: 0.6356, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 45, Epoch: 003, Loss: 0.6180, Val Acc: 0.6852, Test Acc: 0.6402
# Seed: 45, Epoch: 004, Loss: 0.6141, Val Acc: 0.6852, Test Acc: 0.6585
# Seed: 45, Epoch: 005, Loss: 0.6102, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 45, Epoch: 006, Loss: 0.6018, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 45, Epoch: 007, Loss: 0.5942, Val Acc: 0.7160, Test Acc: 0.6646
# Seed: 45, Epoch: 008, Loss: 0.5886, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 45, Epoch: 009, Loss: 0.5766, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 45, Epoch: 010, Loss: 0.5690, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 45, Epoch: 011, Loss: 0.5532, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 45, Epoch: 012, Loss: 0.5423, Val Acc: 0.6605, Test Acc: 0.7195
# Seed: 45, Epoch: 013, Loss: 0.5257, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 45, Epoch: 014, Loss: 0.5164, Val Acc: 0.5988, Test Acc: 0.6524
# Seed: 45, Epoch: 015, Loss: 0.5019, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 45, Epoch: 016, Loss: 0.4866, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 45, Epoch: 017, Loss: 0.4734, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 45, Epoch: 018, Loss: 0.4593, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 45, Epoch: 019, Loss: 0.4422, Val Acc: 0.5679, Test Acc: 0.6402
# Seed: 45, Epoch: 020, Loss: 0.4385, Val Acc: 0.6111, Test Acc: 0.6524
# Seed: 45, Epoch: 021, Loss: 0.4427, Val Acc: 0.6420, Test Acc: 0.6646
# Seed: 45, Epoch: 022, Loss: 0.4457, Val Acc: 0.5988, Test Acc: 0.6098
# Seed: 45, Epoch: 023, Loss: 0.4468, Val Acc: 0.5802, Test Acc: 0.6463
# Seed: 45, Epoch: 024, Loss: 0.4288, Val Acc: 0.7407, Test Acc: 0.7927
# Seed: 45, Epoch: 025, Loss: 0.4224, Val Acc: 0.6049, Test Acc: 0.6707
# Seed: 45, Epoch: 026, Loss: 0.4148, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 45, Epoch: 027, Loss: 0.3868, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 45, Epoch: 028, Loss: 0.3701, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 029, Loss: 0.3535, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 030, Loss: 0.3626, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 45, Epoch: 031, Loss: 0.3644, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 45, Epoch: 032, Loss: 0.3534, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 033, Loss: 0.3394, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 034, Loss: 0.3442, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 45, Epoch: 035, Loss: 0.3236, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 45, Epoch: 036, Loss: 0.3164, Val Acc: 0.7222, Test Acc: 0.6768
# Seed: 45, Epoch: 037, Loss: 0.2891, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 45, Epoch: 038, Loss: 0.2902, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 45, Epoch: 039, Loss: 0.3273, Val Acc: 0.6728, Test Acc: 0.7500
# Seed: 45, Epoch: 040, Loss: 0.3118, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 45, Epoch: 041, Loss: 0.3560, Val Acc: 0.6111, Test Acc: 0.6402
# Seed: 45, Epoch: 042, Loss: 0.3320, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 45, Epoch: 043, Loss: 0.3132, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 45, Epoch: 044, Loss: 0.3312, Val Acc: 0.7778, Test Acc: 0.7256
# Seed: 45, Epoch: 045, Loss: 0.2958, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 45, Epoch: 046, Loss: 0.3091, Val Acc: 0.6914, Test Acc: 0.6646
# Seed: 45, Epoch: 047, Loss: 0.2799, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 45, Epoch: 048, Loss: 0.2687, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 45, Epoch: 049, Loss: 0.2619, Val Acc: 0.6543, Test Acc: 0.7073
# Seed: 45, Epoch: 050, Loss: 0.2492, Val Acc: 0.6667, Test Acc: 0.7256
# Seed: 45, Epoch: 051, Loss: 0.2525, Val Acc: 0.6358, Test Acc: 0.7256
# Seed: 45, Epoch: 052, Loss: 0.2416, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 45, Epoch: 053, Loss: 0.2440, Val Acc: 0.5864, Test Acc: 0.7012
# Seed: 45, Epoch: 054, Loss: 0.2121, Val Acc: 0.6481, Test Acc: 0.6890
# Seed: 45, Epoch: 055, Loss: 0.2543, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 45, Epoch: 056, Loss: 0.2060, Val Acc: 0.6235, Test Acc: 0.7195
# Seed: 45, Epoch: 057, Loss: 0.2403, Val Acc: 0.6605, Test Acc: 0.7378
# Seed: 45, Epoch: 058, Loss: 0.2482, Val Acc: 0.6728, Test Acc: 0.7378
# Seed: 45, Epoch: 059, Loss: 0.2203, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 45, Epoch: 060, Loss: 0.2175, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 45, Epoch: 061, Loss: 0.2168, Val Acc: 0.7407, Test Acc: 0.7256
# Seed: 45, Epoch: 062, Loss: 0.2040, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 45, Epoch: 063, Loss: 0.1877, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 45, Epoch: 064, Loss: 0.1719, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 45, Epoch: 065, Loss: 0.2037, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 066, Loss: 0.1887, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 45, Epoch: 067, Loss: 0.1898, Val Acc: 0.6173, Test Acc: 0.7134
# Seed: 45, Epoch: 068, Loss: 0.2050, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 45, Epoch: 069, Loss: 0.1896, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 45, Epoch: 070, Loss: 0.1847, Val Acc: 0.7222, Test Acc: 0.6829
# Seed: 45, Epoch: 071, Loss: 0.1752, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 45, Epoch: 072, Loss: 0.1830, Val Acc: 0.6420, Test Acc: 0.7073
# Seed: 45, Epoch: 073, Loss: 0.2036, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 45, Epoch: 074, Loss: 0.1658, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 45, Epoch: 075, Loss: 0.1958, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 45, Epoch: 076, Loss: 0.2222, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 077, Loss: 0.1850, Val Acc: 0.6481, Test Acc: 0.6890
# Seed: 45, Epoch: 078, Loss: 0.1678, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 45, Epoch: 079, Loss: 0.1581, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 45, Epoch: 080, Loss: 0.1488, Val Acc: 0.6358, Test Acc: 0.6646
# Seed: 45, Epoch: 081, Loss: 0.1420, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 45, Epoch: 082, Loss: 0.1770, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 45, Epoch: 083, Loss: 0.1552, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 45, Epoch: 084, Loss: 0.1977, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 45, Epoch: 085, Loss: 0.1619, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 45, Epoch: 086, Loss: 0.1668, Val Acc: 0.6852, Test Acc: 0.7256
# Seed: 45, Epoch: 087, Loss: 0.1767, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 45, Epoch: 088, Loss: 0.1300, Val Acc: 0.6543, Test Acc: 0.6829
# Seed: 45, Epoch: 089, Loss: 0.1600, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 45, Epoch: 090, Loss: 0.1705, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 45, Epoch: 091, Loss: 0.1484, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 45, Epoch: 092, Loss: 0.1264, Val Acc: 0.7654, Test Acc: 0.7256
# Seed: 45, Epoch: 093, Loss: 0.1264, Val Acc: 0.7593, Test Acc: 0.7073
# Seed: 45, Epoch: 094, Loss: 0.1354, Val Acc: 0.7284, Test Acc: 0.6890
# Seed: 45, Epoch: 095, Loss: 0.1324, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 45, Epoch: 096, Loss: 0.1148, Val Acc: 0.6543, Test Acc: 0.6585
# Seed: 45, Epoch: 097, Loss: 0.1240, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 45, Epoch: 098, Loss: 0.1316, Val Acc: 0.6728, Test Acc: 0.7500
# Seed: 45, Epoch: 099, Loss: 0.1321, Val Acc: 0.6481, Test Acc: 0.6829
# Seed: 45, Epoch: 100, Loss: 0.1613, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 101, Loss: 0.1426, Val Acc: 0.6111, Test Acc: 0.5793
# Seed: 45, Epoch: 102, Loss: 0.1746, Val Acc: 0.5864, Test Acc: 0.6220
# Seed: 45, Epoch: 103, Loss: 0.1424, Val Acc: 0.5309, Test Acc: 0.6220
# Seed: 45, Epoch: 104, Loss: 0.1571, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 45, Epoch: 105, Loss: 0.1531, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 45, Epoch: 106, Loss: 0.1668, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 45, Epoch: 107, Loss: 0.1245, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 45, Epoch: 108, Loss: 0.1298, Val Acc: 0.6173, Test Acc: 0.6951
# Seed: 45, Epoch: 109, Loss: 0.1663, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 45, Epoch: 110, Loss: 0.1211, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 45, Epoch: 111, Loss: 0.1317, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 45, Epoch: 112, Loss: 0.1045, Val Acc: 0.6790, Test Acc: 0.7378
# Seed: 45, Epoch: 113, Loss: 0.1073, Val Acc: 0.6358, Test Acc: 0.7500
# Seed: 45, Epoch: 114, Loss: 0.1139, Val Acc: 0.6235, Test Acc: 0.6890
# Seed: 45, Epoch: 115, Loss: 0.0868, Val Acc: 0.6914, Test Acc: 0.6585
# Seed: 45, Epoch: 116, Loss: 0.0954, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 45, Epoch: 117, Loss: 0.0821, Val Acc: 0.6420, Test Acc: 0.6402
# Seed: 45, Epoch: 118, Loss: 0.0785, Val Acc: 0.6543, Test Acc: 0.6159
# Seed: 45, Epoch: 119, Loss: 0.0684, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 45, Epoch: 120, Loss: 0.0978, Val Acc: 0.6296, Test Acc: 0.6463
# Seed: 45, Epoch: 121, Loss: 0.0549, Val Acc: 0.6481, Test Acc: 0.6890
# Seed: 45, Epoch: 122, Loss: 0.0695, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 45, Epoch: 123, Loss: 0.0715, Val Acc: 0.7160, Test Acc: 0.6768
# Seed: 45, Epoch: 124, Loss: 0.0710, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 45, Epoch: 125, Loss: 0.0877, Val Acc: 0.6235, Test Acc: 0.7012
# Seed: 45, Epoch: 126, Loss: 0.0825, Val Acc: 0.6481, Test Acc: 0.6829
# Seed: 45, Epoch: 127, Loss: 0.1131, Val Acc: 0.6605, Test Acc: 0.6098
# Seed: 45, Epoch: 128, Loss: 0.1268, Val Acc: 0.6790, Test Acc: 0.6890
# ...
# Seed: 45, Epoch: 170, Loss: 0.0408, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 45, Epoch: 171, Loss: 0.0367, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 45, Epoch: 172, Loss: 0.0649, Val Acc: 0.6728, Test Acc: 0.6646
# Seed: 45, Epoch: 173, Loss: 0.0388, Val Acc: 0.6728, Test Acc: 0.7317
# Seed: 45, Epoch: 174, Loss: 0.0571, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 45, Epoch: 175, Loss: 0.0427, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 45, Epoch: 176, Loss: 0.0493, Val Acc: 0.6605, Test Acc: 0.7012
# Seed: 45, Epoch: 177, Loss: 0.0349, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 45, Epoch: 178, Loss: 0.0682, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 45, Epoch: 179, Loss: 0.0526, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 45, Epoch: 180, Loss: 0.0695, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 181, Loss: 0.0619, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 45, Epoch: 182, Loss: 0.0553, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 45, Epoch: 183, Loss: 0.0500, Val Acc: 0.6296, Test Acc: 0.6707
# Seed: 45, Epoch: 184, Loss: 0.0583, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 45, Epoch: 185, Loss: 0.0322, Val Acc: 0.6728, Test Acc: 0.6524
# Seed: 45, Epoch: 186, Loss: 0.0481, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 45, Epoch: 187, Loss: 0.0393, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 45, Epoch: 188, Loss: 0.0375, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 189, Loss: 0.0342, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 45, Epoch: 190, Loss: 0.0329, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 45, Epoch: 191, Loss: 0.0497, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 45, Epoch: 192, Loss: 0.0605, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 45, Epoch: 193, Loss: 0.0691, Val Acc: 0.5988, Test Acc: 0.6768
# Seed: 45, Epoch: 194, Loss: 0.0429, Val Acc: 0.5926, Test Acc: 0.6585
# Early stopping at epoch 194 for seed 45
# Seed: 46, Epoch: 001, Loss: 0.6938, Val Acc: 0.6667, Test Acc: 0.6098
# Seed: 46, Epoch: 002, Loss: 0.6419, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 46, Epoch: 003, Loss: 0.6241, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 46, Epoch: 004, Loss: 0.6246, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 46, Epoch: 005, Loss: 0.6213, Val Acc: 0.6420, Test Acc: 0.5854
# Seed: 46, Epoch: 006, Loss: 0.6174, Val Acc: 0.6667, Test Acc: 0.6098
# Seed: 46, Epoch: 007, Loss: 0.6138, Val Acc: 0.6667, Test Acc: 0.6159
# Seed: 46, Epoch: 008, Loss: 0.6088, Val Acc: 0.6728, Test Acc: 0.6098
# Seed: 46, Epoch: 009, Loss: 0.6028, Val Acc: 0.6975, Test Acc: 0.6524
# Seed: 46, Epoch: 010, Loss: 0.5935, Val Acc: 0.7037, Test Acc: 0.6524
# Seed: 46, Epoch: 011, Loss: 0.5847, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 46, Epoch: 012, Loss: 0.5713, Val Acc: 0.7284, Test Acc: 0.6951
# Seed: 46, Epoch: 013, Loss: 0.5527, Val Acc: 0.7284, Test Acc: 0.6951
# Seed: 46, Epoch: 014, Loss: 0.5302, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 46, Epoch: 015, Loss: 0.5089, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 46, Epoch: 016, Loss: 0.4931, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 46, Epoch: 017, Loss: 0.4749, Val Acc: 0.6790, Test Acc: 0.7561
# Seed: 46, Epoch: 018, Loss: 0.4681, Val Acc: 0.6914, Test Acc: 0.8171
# Seed: 46, Epoch: 019, Loss: 0.4681, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 46, Epoch: 020, Loss: 0.4562, Val Acc: 0.5802, Test Acc: 0.6280
# Seed: 46, Epoch: 021, Loss: 0.4487, Val Acc: 0.6852, Test Acc: 0.7500
# Seed: 46, Epoch: 022, Loss: 0.4484, Val Acc: 0.6790, Test Acc: 0.7439
# Seed: 46, Epoch: 023, Loss: 0.4423, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 46, Epoch: 024, Loss: 0.4377, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 46, Epoch: 025, Loss: 0.4360, Val Acc: 0.5741, Test Acc: 0.6220
# Seed: 46, Epoch: 026, Loss: 0.4115, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 46, Epoch: 027, Loss: 0.4106, Val Acc: 0.5926, Test Acc: 0.6829
# Seed: 46, Epoch: 028, Loss: 0.4068, Val Acc: 0.6852, Test Acc: 0.7256
# Seed: 46, Epoch: 029, Loss: 0.3915, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 46, Epoch: 030, Loss: 0.3997, Val Acc: 0.6173, Test Acc: 0.6646
# Seed: 46, Epoch: 031, Loss: 0.3659, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 032, Loss: 0.3642, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 46, Epoch: 033, Loss: 0.3796, Val Acc: 0.7037, Test Acc: 0.6707
# Seed: 46, Epoch: 034, Loss: 0.3780, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 46, Epoch: 035, Loss: 0.3498, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 46, Epoch: 036, Loss: 0.3586, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 46, Epoch: 037, Loss: 0.3573, Val Acc: 0.6914, Test Acc: 0.7378
# Seed: 46, Epoch: 038, Loss: 0.3397, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 46, Epoch: 039, Loss: 0.3272, Val Acc: 0.6235, Test Acc: 0.6402
# Seed: 46, Epoch: 040, Loss: 0.3284, Val Acc: 0.6543, Test Acc: 0.7073
# Seed: 46, Epoch: 041, Loss: 0.3140, Val Acc: 0.6296, Test Acc: 0.6707
# Seed: 46, Epoch: 042, Loss: 0.3325, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 46, Epoch: 043, Loss: 0.3187, Val Acc: 0.6728, Test Acc: 0.6463
# Seed: 46, Epoch: 044, Loss: 0.3361, Val Acc: 0.5988, Test Acc: 0.6402
# Seed: 46, Epoch: 045, Loss: 0.2992, Val Acc: 0.5556, Test Acc: 0.5854
# Seed: 46, Epoch: 046, Loss: 0.3053, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 46, Epoch: 047, Loss: 0.2886, Val Acc: 0.6111, Test Acc: 0.7073
# Seed: 46, Epoch: 048, Loss: 0.2640, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 46, Epoch: 049, Loss: 0.2741, Val Acc: 0.6790, Test Acc: 0.6829
# Seed: 46, Epoch: 050, Loss: 0.3036, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 46, Epoch: 051, Loss: 0.3147, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 46, Epoch: 052, Loss: 0.2812, Val Acc: 0.6173, Test Acc: 0.6646
# Seed: 46, Epoch: 053, Loss: 0.2905, Val Acc: 0.5556, Test Acc: 0.6829
# Seed: 46, Epoch: 054, Loss: 0.3165, Val Acc: 0.5741, Test Acc: 0.6402
# Seed: 46, Epoch: 055, Loss: 0.2856, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 46, Epoch: 056, Loss: 0.2691, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 46, Epoch: 057, Loss: 0.2514, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 46, Epoch: 058, Loss: 0.2834, Val Acc: 0.5741, Test Acc: 0.5854
# Seed: 46, Epoch: 059, Loss: 0.2384, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 46, Epoch: 060, Loss: 0.3006, Val Acc: 0.6543, Test Acc: 0.7378
# Seed: 46, Epoch: 061, Loss: 0.2590, Val Acc: 0.6358, Test Acc: 0.7073
# Seed: 46, Epoch: 062, Loss: 0.2275, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 46, Epoch: 063, Loss: 0.2224, Val Acc: 0.6481, Test Acc: 0.7134
# Seed: 46, Epoch: 064, Loss: 0.2292, Val Acc: 0.6420, Test Acc: 0.6585
# Seed: 46, Epoch: 065, Loss: 0.2373, Val Acc: 0.6481, Test Acc: 0.6646
# Seed: 46, Epoch: 066, Loss: 0.2601, Val Acc: 0.6481, Test Acc: 0.6768
# Seed: 46, Epoch: 067, Loss: 0.2261, Val Acc: 0.6358, Test Acc: 0.6951
# Seed: 46, Epoch: 068, Loss: 0.2167, Val Acc: 0.6543, Test Acc: 0.7195
# Seed: 46, Epoch: 069, Loss: 0.2253, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 46, Epoch: 070, Loss: 0.2129, Val Acc: 0.6667, Test Acc: 0.7378
# Seed: 46, Epoch: 071, Loss: 0.2326, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 46, Epoch: 072, Loss: 0.2035, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 46, Epoch: 073, Loss: 0.2517, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 46, Epoch: 074, Loss: 0.2058, Val Acc: 0.5741, Test Acc: 0.5976
# Seed: 46, Epoch: 075, Loss: 0.2189, Val Acc: 0.5864, Test Acc: 0.6341
# Seed: 46, Epoch: 076, Loss: 0.2144, Val Acc: 0.5741, Test Acc: 0.6646
# Seed: 46, Epoch: 077, Loss: 0.2178, Val Acc: 0.5926, Test Acc: 0.6585
# Seed: 46, Epoch: 078, Loss: 0.2206, Val Acc: 0.6728, Test Acc: 0.6585
# Seed: 46, Epoch: 079, Loss: 0.2565, Val Acc: 0.6296, Test Acc: 0.6951
# Seed: 46, Epoch: 080, Loss: 0.2047, Val Acc: 0.6049, Test Acc: 0.6829
# Seed: 46, Epoch: 081, Loss: 0.2212, Val Acc: 0.5988, Test Acc: 0.6524
# Seed: 46, Epoch: 082, Loss: 0.2221, Val Acc: 0.6728, Test Acc: 0.7683
# Seed: 46, Epoch: 083, Loss: 0.1982, Val Acc: 0.6914, Test Acc: 0.7622
# Seed: 46, Epoch: 084, Loss: 0.2304, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 46, Epoch: 085, Loss: 0.2038, Val Acc: 0.7222, Test Acc: 0.6829
# Seed: 46, Epoch: 086, Loss: 0.1812, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 46, Epoch: 087, Loss: 0.1966, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 46, Epoch: 088, Loss: 0.1751, Val Acc: 0.6605, Test Acc: 0.6829
# Seed: 46, Epoch: 089, Loss: 0.1790, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 46, Epoch: 090, Loss: 0.1930, Val Acc: 0.7037, Test Acc: 0.7500
# Seed: 46, Epoch: 091, Loss: 0.1823, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 46, Epoch: 092, Loss: 0.1905, Val Acc: 0.6667, Test Acc: 0.6890
# Seed: 46, Epoch: 093, Loss: 0.2011, Val Acc: 0.6235, Test Acc: 0.6768
# Seed: 46, Epoch: 094, Loss: 0.1828, Val Acc: 0.6543, Test Acc: 0.6707
# Seed: 46, Epoch: 095, Loss: 0.1548, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 46, Epoch: 096, Loss: 0.1804, Val Acc: 0.6481, Test Acc: 0.6707
# Seed: 46, Epoch: 097, Loss: 0.1537, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 46, Epoch: 098, Loss: 0.1517, Val Acc: 0.6173, Test Acc: 0.7012
# Seed: 46, Epoch: 099, Loss: 0.1842, Val Acc: 0.5926, Test Acc: 0.5976
# Seed: 46, Epoch: 100, Loss: 0.1520, Val Acc: 0.5432, Test Acc: 0.5549
# Seed: 46, Epoch: 101, Loss: 0.1808, Val Acc: 0.5370, Test Acc: 0.5183
# Seed: 46, Epoch: 102, Loss: 0.1599, Val Acc: 0.5556, Test Acc: 0.5915
# Seed: 46, Epoch: 103, Loss: 0.1703, Val Acc: 0.6296, Test Acc: 0.6829
# Seed: 46, Epoch: 104, Loss: 0.1579, Val Acc: 0.6481, Test Acc: 0.7012
# Seed: 46, Epoch: 105, Loss: 0.1583, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 46, Epoch: 106, Loss: 0.1450, Val Acc: 0.6605, Test Acc: 0.6341
# Seed: 46, Epoch: 107, Loss: 0.1513, Val Acc: 0.6296, Test Acc: 0.6463
# Seed: 46, Epoch: 108, Loss: 0.1373, Val Acc: 0.5988, Test Acc: 0.6159
# Seed: 46, Epoch: 109, Loss: 0.1234, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 46, Epoch: 110, Loss: 0.1399, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 46, Epoch: 111, Loss: 0.1153, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 46, Epoch: 112, Loss: 0.2237, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 46, Epoch: 113, Loss: 0.1507, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 46, Epoch: 114, Loss: 0.1486, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 46, Epoch: 115, Loss: 0.1437, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 46, Epoch: 116, Loss: 0.1538, Val Acc: 0.6667, Test Acc: 0.7317
# Seed: 46, Epoch: 117, Loss: 0.1482, Val Acc: 0.6543, Test Acc: 0.7134
# Seed: 46, Epoch: 118, Loss: 0.1877, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 46, Epoch: 119, Loss: 0.1388, Val Acc: 0.6481, Test Acc: 0.7927
# Seed: 46, Epoch: 120, Loss: 0.1367, Val Acc: 0.6852, Test Acc: 0.7500
# Seed: 46, Epoch: 121, Loss: 0.1930, Val Acc: 0.6543, Test Acc: 0.7134
# Seed: 46, Epoch: 122, Loss: 0.1308, Val Acc: 0.5988, Test Acc: 0.6890
# Seed: 46, Epoch: 123, Loss: 0.1393, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 46, Epoch: 124, Loss: 0.1360, Val Acc: 0.6605, Test Acc: 0.6707
# Seed: 46, Epoch: 125, Loss: 0.1373, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 46, Epoch: 126, Loss: 0.1365, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 46, Epoch: 127, Loss: 0.1386, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 46, Epoch: 128, Loss: 0.1083, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 46, Epoch: 129, Loss: 0.1123, Val Acc: 0.6111, Test Acc: 0.6585
# Seed: 46, Epoch: 130, Loss: 0.1101, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 46, Epoch: 131, Loss: 0.0916, Val Acc: 0.6543, Test Acc: 0.7195
# Seed: 46, Epoch: 132, Loss: 0.1079, Val Acc: 0.6728, Test Acc: 0.7317
# Seed: 46, Epoch: 133, Loss: 0.1252, Val Acc: 0.6852, Test Acc: 0.6585
# Seed: 46, Epoch: 134, Loss: 0.1038, Val Acc: 0.6852, Test Acc: 0.6646
# Seed: 46, Epoch: 135, Loss: 0.1022, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 46, Epoch: 136, Loss: 0.0839, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 46, Epoch: 137, Loss: 0.0895, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 46, Epoch: 138, Loss: 0.0664, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 46, Epoch: 139, Loss: 0.1084, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 46, Epoch: 140, Loss: 0.0826, Val Acc: 0.6790, Test Acc: 0.7744
# Seed: 46, Epoch: 141, Loss: 0.0730, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 46, Epoch: 142, Loss: 0.1058, Val Acc: 0.6296, Test Acc: 0.6524
# Seed: 46, Epoch: 143, Loss: 0.1455, Val Acc: 0.6358, Test Acc: 0.6585
# Seed: 46, Epoch: 144, Loss: 0.1109, Val Acc: 0.6296, Test Acc: 0.6524
# Seed: 46, Epoch: 145, Loss: 0.0890, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 46, Epoch: 146, Loss: 0.0962, Val Acc: 0.6543, Test Acc: 0.6829
# Seed: 46, Epoch: 147, Loss: 0.1063, Val Acc: 0.6543, Test Acc: 0.6402
# Seed: 46, Epoch: 148, Loss: 0.0723, Val Acc: 0.5926, Test Acc: 0.6341
# Seed: 46, Epoch: 149, Loss: 0.0946, Val Acc: 0.6358, Test Acc: 0.6585
# Seed: 46, Epoch: 150, Loss: 0.0956, Val Acc: 0.6173, Test Acc: 0.7134
# Seed: 46, Epoch: 151, Loss: 0.1268, Val Acc: 0.6420, Test Acc: 0.6890
# Seed: 46, Epoch: 152, Loss: 0.0814, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 46, Epoch: 153, Loss: 0.0908, Val Acc: 0.6728, Test Acc: 0.6341
# Seed: 46, Epoch: 154, Loss: 0.0962, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 46, Epoch: 155, Loss: 0.0846, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 46, Epoch: 156, Loss: 0.0497, Val Acc: 0.6358, Test Acc: 0.6463
# Seed: 46, Epoch: 157, Loss: 0.0966, Val Acc: 0.6481, Test Acc: 0.6768
# Seed: 46, Epoch: 158, Loss: 0.0806, Val Acc: 0.6049, Test Acc: 0.6524
# Seed: 46, Epoch: 159, Loss: 0.1211, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 46, Epoch: 160, Loss: 0.1012, Val Acc: 0.6420, Test Acc: 0.6768
# Seed: 46, Epoch: 161, Loss: 0.0906, Val Acc: 0.6235, Test Acc: 0.6646
# Seed: 46, Epoch: 162, Loss: 0.1360, Val Acc: 0.6605, Test Acc: 0.7012
# Seed: 46, Epoch: 163, Loss: 0.0914, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 46, Epoch: 164, Loss: 0.0638, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 46, Epoch: 165, Loss: 0.0672, Val Acc: 0.6543, Test Acc: 0.7073
# Seed: 46, Epoch: 166, Loss: 0.0998, Val Acc: 0.6605, Test Acc: 0.7378
# Seed: 46, Epoch: 167, Loss: 0.0975, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 46, Epoch: 168, Loss: 0.1037, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 46, Epoch: 169, Loss: 0.0712, Val Acc: 0.6667, Test Acc: 0.6890
# Seed: 46, Epoch: 170, Loss: 0.0673, Val Acc: 0.6481, Test Acc: 0.6707
# Seed: 46, Epoch: 171, Loss: 0.0746, Val Acc: 0.6667, Test Acc: 0.6646
# Seed: 46, Epoch: 172, Loss: 0.0736, Val Acc: 0.6790, Test Acc: 0.6829
# Seed: 46, Epoch: 173, Loss: 0.0788, Val Acc: 0.6111, Test Acc: 0.6463
# Seed: 46, Epoch: 174, Loss: 0.0903, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 46, Epoch: 175, Loss: 0.0750, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 46, Epoch: 176, Loss: 0.0626, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 46, Epoch: 177, Loss: 0.0530, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 46, Epoch: 178, Loss: 0.0506, Val Acc: 0.6605, Test Acc: 0.6707
# Seed: 46, Epoch: 179, Loss: 0.0764, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 46, Epoch: 180, Loss: 0.0667, Val Acc: 0.7160, Test Acc: 0.7012
# Seed: 46, Epoch: 181, Loss: 0.0807, Val Acc: 0.7654, Test Acc: 0.6890
# Seed: 46, Epoch: 182, Loss: 0.0860, Val Acc: 0.7407, Test Acc: 0.6524
# Seed: 46, Epoch: 183, Loss: 0.0535, Val Acc: 0.6111, Test Acc: 0.5976
# Seed: 46, Epoch: 184, Loss: 0.0748, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 46, Epoch: 185, Loss: 0.0636, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 46, Epoch: 186, Loss: 0.0830, Val Acc: 0.6543, Test Acc: 0.7195
# Seed: 46, Epoch: 187, Loss: 0.0661, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 46, Epoch: 188, Loss: 0.0531, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 46, Epoch: 189, Loss: 0.0309, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 46, Epoch: 190, Loss: 0.0375, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 46, Epoch: 191, Loss: 0.0476, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 46, Epoch: 192, Loss: 0.0380, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 46, Epoch: 193, Loss: 0.0572, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 46, Epoch: 194, Loss: 0.0543, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 46, Epoch: 195, Loss: 0.0419, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 46, Epoch: 196, Loss: 0.0634, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 46, Epoch: 197, Loss: 0.0293, Val Acc: 0.6605, Test Acc: 0.7195
# Seed: 46, Epoch: 198, Loss: 0.0544, Val Acc: 0.6111, Test Acc: 0.6890
# Seed: 46, Epoch: 199, Loss: 0.0481, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 46, Epoch: 200, Loss: 0.0420, Val Acc: 0.6111, Test Acc: 0.6646
# Average Time: 43.45 seconds
# Var Time: 8.10 seconds
# Average Memory: 720.00 MB
# Average Best Val Acc: 0.7741
# Std Best Test Acc: 0.0274
# Average Test Acc: 0.7341

# %% [markdown]
# ## Dense DMoNPooling with HierarchicalGCN (2023)

# %%
import os.path as osp
import time
from math import ceil

import torch
import torch.nn.functional as F

import torch_geometric.transforms as T
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DenseDataLoader
from torch_geometric.nn import DenseSAGEConv, DMoNPooling

dataset = dataset_PROTEINS
dataset = dataset.shuffle()

class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, normalize=False, lin=True):
        super().__init__()

        self.conv1 = DenseSAGEConv(in_channels, hidden_channels, normalize)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = DenseSAGEConv(hidden_channels, hidden_channels, normalize)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = DenseSAGEConv(hidden_channels, out_channels, normalize)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        if lin:
            self.lin = torch.nn.Linear(out_channels, out_channels)
        else:
            self.lin = None

    def bn(self, i, x):
        batch_size, num_nodes, num_channels = x.size()
        x = x.view(-1, num_channels)
        x = getattr(self, f'bn{i}')(x)
        x = x.view(batch_size, num_nodes, num_channels)
        return x

    def forward(self, x, adj, mask=None):
        x = self.bn(1, self.conv1(x, adj, mask).relu())
        x = self.bn(2, self.conv2(x, adj, mask).relu())
        x = self.bn(3, self.conv3(x, adj, mask).relu())

        if self.lin is not None:
            x = self.lin(x).relu()

        return x


class Net_DMoN(torch.nn.Module):
    def __init__(self, in_channels=dataset.num_features, out_channels=64, hidden_channels=64):
        super().__init__()

        num_nodes = 64
        self.gnn1_pool = GNN(dataset.num_features, 64, num_nodes)
        self.pool1 = DMoNPooling([hidden_channels, hidden_channels], num_nodes)

        num_nodes = 64
        self.gnn2_pool = GNN(64, 64, num_nodes)
        self.pool2 = DMoNPooling([hidden_channels, hidden_channels], num_nodes)

        self.gnn1_embed = DenseSAGEConv(dataset.num_features, 64)
        self.gnn2_embed = DenseSAGEConv(64, 64)
        self.gnn3_embed = DenseSAGEConv(64, 64)

        self.lin1 = torch.nn.Linear(64, 32)
        self.lin2 = torch.nn.Linear(32, dataset.num_classes)

    def forward(self, x, adj, mask=None):
        s = self.gnn1_pool(x, adj, mask)
        x = self.gnn1_embed(x, adj, mask)
        x = F.relu(x)

        _, x, adj, sp1, o1, c1 = self.pool1(x, adj, mask)

        s = self.gnn2_pool(x, adj)
        x = self.gnn2_embed(x, adj)
        x = F.relu(x)

        _, x, adj, sp2, o2, c2 = self.pool2(x, adj)

        x = self.gnn3_embed(x, adj)
        x = F.relu(x)

        x = x.mean(dim=1)
        x = self.lin1(x).relu()
        x = self.lin2(x)
        return F.log_softmax(x, dim=-1), sp1 + sp2 + o1 + o2 + c1 + c2

if torch.cuda.is_available():
    device = torch.device('cuda')
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

model = Net_DMoN().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output, _ = model(data.x, data.adj, data.mask)
        loss = F.nll_loss(output, data.y.view(-1))
        loss.backward()
        total_loss += data.y.size(0) * float(loss)
        optimizer.step()
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        output, _ = model(data.x, data.adj, data.mask)
        pred = output.max(dim=1)[1]
        correct += int(pred.eq(data.y.view(-1)).sum())
    return correct / len(loader.dataset)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = Net_DMoN().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.7065, Val Acc: 0.6667, Test Acc: 0.6159
# Seed: 42, Epoch: 002, Loss: 0.6543, Val Acc: 0.6543, Test Acc: 0.5915
# Seed: 42, Epoch: 003, Loss: 0.6311, Val Acc: 0.6358, Test Acc: 0.5793
# Seed: 42, Epoch: 004, Loss: 0.6268, Val Acc: 0.6358, Test Acc: 0.5793
# Seed: 42, Epoch: 005, Loss: 0.6212, Val Acc: 0.6667, Test Acc: 0.6098
# Seed: 42, Epoch: 006, Loss: 0.6147, Val Acc: 0.6914, Test Acc: 0.6463
# Seed: 42, Epoch: 007, Loss: 0.6121, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 42, Epoch: 008, Loss: 0.6081, Val Acc: 0.6914, Test Acc: 0.6524
# Seed: 42, Epoch: 009, Loss: 0.6047, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 42, Epoch: 010, Loss: 0.6022, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 42, Epoch: 011, Loss: 0.5980, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 42, Epoch: 012, Loss: 0.5973, Val Acc: 0.7037, Test Acc: 0.6768
# Seed: 42, Epoch: 013, Loss: 0.5962, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 42, Epoch: 014, Loss: 0.5872, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 42, Epoch: 015, Loss: 0.5863, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 42, Epoch: 016, Loss: 0.5867, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 42, Epoch: 017, Loss: 0.5763, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 42, Epoch: 018, Loss: 0.5715, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 42, Epoch: 019, Loss: 0.5681, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 42, Epoch: 020, Loss: 0.5659, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 42, Epoch: 021, Loss: 0.5587, Val Acc: 0.7284, Test Acc: 0.6829
# Seed: 42, Epoch: 022, Loss: 0.5574, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 023, Loss: 0.5507, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 024, Loss: 0.5577, Val Acc: 0.6667, Test Acc: 0.7073
# Seed: 42, Epoch: 025, Loss: 0.5570, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 42, Epoch: 026, Loss: 0.5537, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 42, Epoch: 027, Loss: 0.5432, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 42, Epoch: 028, Loss: 0.5326, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 42, Epoch: 029, Loss: 0.5336, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 42, Epoch: 030, Loss: 0.5229, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 42, Epoch: 031, Loss: 0.5179, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 42, Epoch: 032, Loss: 0.5187, Val Acc: 0.6914, Test Acc: 0.7439
# Seed: 42, Epoch: 033, Loss: 0.5230, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 42, Epoch: 034, Loss: 0.5159, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 035, Loss: 0.5091, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 42, Epoch: 036, Loss: 0.5053, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 42, Epoch: 037, Loss: 0.5083, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 42, Epoch: 038, Loss: 0.5035, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 42, Epoch: 039, Loss: 0.5093, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 040, Loss: 0.5076, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 041, Loss: 0.4992, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 42, Epoch: 042, Loss: 0.4956, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 42, Epoch: 043, Loss: 0.4990, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 42, Epoch: 044, Loss: 0.4895, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 045, Loss: 0.5010, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 42, Epoch: 046, Loss: 0.4987, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 047, Loss: 0.4937, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 048, Loss: 0.4966, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 42, Epoch: 049, Loss: 0.4858, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 050, Loss: 0.4915, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 051, Loss: 0.4898, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 052, Loss: 0.4833, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 42, Epoch: 053, Loss: 0.4963, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 054, Loss: 0.4893, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 055, Loss: 0.4862, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 42, Epoch: 056, Loss: 0.4820, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 057, Loss: 0.4823, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 42, Epoch: 058, Loss: 0.4886, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 059, Loss: 0.4925, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 42, Epoch: 060, Loss: 0.4815, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 061, Loss: 0.4929, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 42, Epoch: 062, Loss: 0.4794, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 063, Loss: 0.4795, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 064, Loss: 0.4774, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 065, Loss: 0.4834, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 42, Epoch: 066, Loss: 0.4761, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 067, Loss: 0.4773, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 068, Loss: 0.4749, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 069, Loss: 0.4732, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 42, Epoch: 070, Loss: 0.4787, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 071, Loss: 0.4710, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 072, Loss: 0.4717, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 073, Loss: 0.4825, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 074, Loss: 0.4789, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 075, Loss: 0.4762, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 42, Epoch: 076, Loss: 0.4781, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 077, Loss: 0.4735, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 42, Epoch: 078, Loss: 0.4727, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 079, Loss: 0.4694, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 080, Loss: 0.4628, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 42, Epoch: 081, Loss: 0.4722, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 082, Loss: 0.4715, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 083, Loss: 0.4651, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 084, Loss: 0.4644, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 085, Loss: 0.4633, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 42, Epoch: 086, Loss: 0.4630, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 087, Loss: 0.4589, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 088, Loss: 0.4590, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 089, Loss: 0.4586, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 090, Loss: 0.4582, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 091, Loss: 0.4634, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 42, Epoch: 092, Loss: 0.4735, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 42, Epoch: 093, Loss: 0.4738, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 094, Loss: 0.4642, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 095, Loss: 0.4623, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 096, Loss: 0.4721, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 097, Loss: 0.4698, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 42, Epoch: 098, Loss: 0.4791, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 42, Epoch: 099, Loss: 0.4806, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 100, Loss: 0.4648, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 101, Loss: 0.4613, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 42, Epoch: 102, Loss: 0.4579, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 42, Epoch: 103, Loss: 0.4571, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 104, Loss: 0.4558, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 105, Loss: 0.4550, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 42, Epoch: 106, Loss: 0.4600, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 107, Loss: 0.4535, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 42, Epoch: 108, Loss: 0.4492, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 109, Loss: 0.4498, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 110, Loss: 0.4486, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 111, Loss: 0.4438, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 42, Epoch: 112, Loss: 0.4435, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 113, Loss: 0.4435, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 114, Loss: 0.4455, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 42, Epoch: 115, Loss: 0.4458, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 116, Loss: 0.4487, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 42, Epoch: 117, Loss: 0.4657, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 42, Epoch: 118, Loss: 0.4602, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 119, Loss: 0.4637, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 120, Loss: 0.4570, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 121, Loss: 0.4629, Val Acc: 0.7901, Test Acc: 0.7500
# Seed: 42, Epoch: 122, Loss: 0.4472, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 123, Loss: 0.4517, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 42, Epoch: 124, Loss: 0.4426, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 42, Epoch: 125, Loss: 0.4496, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 42, Epoch: 126, Loss: 0.4499, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 127, Loss: 0.4499, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 42, Epoch: 128, Loss: 0.4483, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 42, Epoch: 129, Loss: 0.4375, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 130, Loss: 0.4429, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 131, Loss: 0.4408, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 132, Loss: 0.4374, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 133, Loss: 0.4371, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 134, Loss: 0.4409, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 42, Epoch: 135, Loss: 0.4411, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 42, Epoch: 136, Loss: 0.4369, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 137, Loss: 0.4365, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 138, Loss: 0.4311, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 139, Loss: 0.4385, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 42, Epoch: 140, Loss: 0.4308, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 141, Loss: 0.4414, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 42, Epoch: 142, Loss: 0.4416, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 42, Epoch: 143, Loss: 0.4403, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 144, Loss: 0.4456, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 42, Epoch: 145, Loss: 0.4305, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 146, Loss: 0.4282, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 147, Loss: 0.4273, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 42, Epoch: 148, Loss: 0.4250, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 149, Loss: 0.4340, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 42, Epoch: 150, Loss: 0.4441, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 151, Loss: 0.4397, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 152, Loss: 0.4479, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 153, Loss: 0.4331, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 154, Loss: 0.4303, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 155, Loss: 0.4258, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 42, Epoch: 156, Loss: 0.4265, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 42, Epoch: 157, Loss: 0.4247, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 42, Epoch: 158, Loss: 0.4208, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 159, Loss: 0.4189, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 160, Loss: 0.4166, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 42, Epoch: 161, Loss: 0.4192, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 162, Loss: 0.4178, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 163, Loss: 0.4223, Val Acc: 0.7654, Test Acc: 0.7317
# Seed: 42, Epoch: 164, Loss: 0.4199, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 42, Epoch: 165, Loss: 0.4192, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 42, Epoch: 166, Loss: 0.4206, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 42, Epoch: 167, Loss: 0.4495, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 42, Epoch: 168, Loss: 0.4353, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 42, Epoch: 169, Loss: 0.4350, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 42, Epoch: 170, Loss: 0.4218, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 171, Loss: 0.4194, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 42, Epoch: 172, Loss: 0.4226, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 42, Epoch: 173, Loss: 0.4231, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 42, Epoch: 174, Loss: 0.4193, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 42, Epoch: 175, Loss: 0.4183, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 176, Loss: 0.4186, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 177, Loss: 0.4073, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 178, Loss: 0.4113, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 42, Epoch: 179, Loss: 0.4116, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 180, Loss: 0.4156, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 181, Loss: 0.4116, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 182, Loss: 0.4350, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 42, Epoch: 183, Loss: 0.4217, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 42, Epoch: 184, Loss: 0.4138, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 42, Epoch: 185, Loss: 0.4152, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 42, Epoch: 186, Loss: 0.4272, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 42, Epoch: 187, Loss: 0.4174, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 42, Epoch: 188, Loss: 0.4142, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 42, Epoch: 189, Loss: 0.4172, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 42, Epoch: 190, Loss: 0.4066, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 42, Epoch: 191, Loss: 0.4144, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 42, Epoch: 192, Loss: 0.4089, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 42, Epoch: 193, Loss: 0.4019, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 42, Epoch: 194, Loss: 0.4043, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 42, Epoch: 195, Loss: 0.3937, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 42, Epoch: 196, Loss: 0.4086, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 42, Epoch: 197, Loss: 0.3942, Val Acc: 0.7407, Test Acc: 0.8049
# Seed: 42, Epoch: 198, Loss: 0.3938, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 42, Epoch: 199, Loss: 0.3948, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 42, Epoch: 200, Loss: 0.3947, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 43, Epoch: 001, Loss: 0.6712, Val Acc: 0.6728, Test Acc: 0.6037
# Seed: 43, Epoch: 002, Loss: 0.6263, Val Acc: 0.6420, Test Acc: 0.5671
# Seed: 43, Epoch: 003, Loss: 0.6317, Val Acc: 0.6667, Test Acc: 0.6098
# Seed: 43, Epoch: 004, Loss: 0.6202, Val Acc: 0.6914, Test Acc: 0.6524
# Seed: 43, Epoch: 005, Loss: 0.6143, Val Acc: 0.6852, Test Acc: 0.6341
# Seed: 43, Epoch: 006, Loss: 0.6080, Val Acc: 0.6852, Test Acc: 0.6341
# Seed: 43, Epoch: 007, Loss: 0.6018, Val Acc: 0.6975, Test Acc: 0.6524
# Seed: 43, Epoch: 008, Loss: 0.6007, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 43, Epoch: 009, Loss: 0.5939, Val Acc: 0.7099, Test Acc: 0.6341
# Seed: 43, Epoch: 010, Loss: 0.5908, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 43, Epoch: 011, Loss: 0.5806, Val Acc: 0.7593, Test Acc: 0.7134
# Seed: 43, Epoch: 012, Loss: 0.5742, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 43, Epoch: 013, Loss: 0.5787, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 43, Epoch: 014, Loss: 0.5618, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 43, Epoch: 015, Loss: 0.5580, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 016, Loss: 0.5499, Val Acc: 0.6975, Test Acc: 0.7561
# Seed: 43, Epoch: 017, Loss: 0.5615, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 43, Epoch: 018, Loss: 0.5571, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 43, Epoch: 019, Loss: 0.5426, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 43, Epoch: 020, Loss: 0.5487, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 43, Epoch: 021, Loss: 0.5478, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 43, Epoch: 022, Loss: 0.5504, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 43, Epoch: 023, Loss: 0.5376, Val Acc: 0.7654, Test Acc: 0.7317
# Seed: 43, Epoch: 024, Loss: 0.5316, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 43, Epoch: 025, Loss: 0.5286, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 43, Epoch: 026, Loss: 0.5233, Val Acc: 0.7160, Test Acc: 0.7805
# Seed: 43, Epoch: 027, Loss: 0.5286, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 028, Loss: 0.5254, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 43, Epoch: 029, Loss: 0.5184, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 43, Epoch: 030, Loss: 0.5153, Val Acc: 0.7284, Test Acc: 0.7805
# Seed: 43, Epoch: 031, Loss: 0.5143, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 43, Epoch: 032, Loss: 0.5161, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 033, Loss: 0.5103, Val Acc: 0.7284, Test Acc: 0.7683
# Seed: 43, Epoch: 034, Loss: 0.5110, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 035, Loss: 0.5070, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 43, Epoch: 036, Loss: 0.5056, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 037, Loss: 0.5107, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 43, Epoch: 038, Loss: 0.5181, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 43, Epoch: 039, Loss: 0.5059, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 040, Loss: 0.5079, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 43, Epoch: 041, Loss: 0.5007, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 43, Epoch: 042, Loss: 0.5065, Val Acc: 0.7346, Test Acc: 0.7805
# Seed: 43, Epoch: 043, Loss: 0.5042, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 044, Loss: 0.5007, Val Acc: 0.7284, Test Acc: 0.7866
# Seed: 43, Epoch: 045, Loss: 0.5121, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 43, Epoch: 046, Loss: 0.5055, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 43, Epoch: 047, Loss: 0.5068, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 048, Loss: 0.5053, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 049, Loss: 0.4978, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 050, Loss: 0.5052, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 43, Epoch: 051, Loss: 0.4984, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 052, Loss: 0.4960, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 053, Loss: 0.4968, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 43, Epoch: 054, Loss: 0.4974, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 43, Epoch: 055, Loss: 0.4940, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 43, Epoch: 056, Loss: 0.4895, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 057, Loss: 0.4867, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 43, Epoch: 058, Loss: 0.4859, Val Acc: 0.7840, Test Acc: 0.7439
# Seed: 43, Epoch: 059, Loss: 0.4880, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 43, Epoch: 060, Loss: 0.4842, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 43, Epoch: 061, Loss: 0.4828, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 43, Epoch: 062, Loss: 0.4816, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 43, Epoch: 063, Loss: 0.4794, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 43, Epoch: 064, Loss: 0.4783, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 43, Epoch: 065, Loss: 0.4871, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 43, Epoch: 066, Loss: 0.4789, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 067, Loss: 0.4911, Val Acc: 0.7284, Test Acc: 0.7744
# Seed: 43, Epoch: 068, Loss: 0.4847, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 43, Epoch: 069, Loss: 0.5047, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 070, Loss: 0.5111, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 43, Epoch: 071, Loss: 0.5215, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 43, Epoch: 072, Loss: 0.5203, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 073, Loss: 0.4991, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 43, Epoch: 074, Loss: 0.4988, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 43, Epoch: 075, Loss: 0.4988, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 076, Loss: 0.5017, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 43, Epoch: 077, Loss: 0.4885, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 078, Loss: 0.4868, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 43, Epoch: 079, Loss: 0.4824, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 43, Epoch: 080, Loss: 0.4798, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 081, Loss: 0.4765, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 43, Epoch: 082, Loss: 0.4766, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 43, Epoch: 083, Loss: 0.4771, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 43, Epoch: 084, Loss: 0.4770, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 085, Loss: 0.4777, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 086, Loss: 0.5007, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 087, Loss: 0.5195, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 088, Loss: 0.5143, Val Acc: 0.7654, Test Acc: 0.7256
# Seed: 43, Epoch: 089, Loss: 0.5043, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 43, Epoch: 090, Loss: 0.4947, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 091, Loss: 0.4897, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 43, Epoch: 092, Loss: 0.4903, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 093, Loss: 0.4905, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 094, Loss: 0.4889, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 43, Epoch: 095, Loss: 0.4796, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 43, Epoch: 096, Loss: 0.4744, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 097, Loss: 0.4764, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 098, Loss: 0.4750, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 43, Epoch: 099, Loss: 0.4839, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 100, Loss: 0.4925, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 43, Epoch: 101, Loss: 0.4919, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 43, Epoch: 102, Loss: 0.4792, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 43, Epoch: 103, Loss: 0.4858, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 104, Loss: 0.4781, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 43, Epoch: 105, Loss: 0.4900, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 106, Loss: 0.4806, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 43, Epoch: 107, Loss: 0.4811, Val Acc: 0.7840, Test Acc: 0.7439
# Seed: 43, Epoch: 108, Loss: 0.4750, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 109, Loss: 0.4763, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 43, Epoch: 110, Loss: 0.4650, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 43, Epoch: 111, Loss: 0.4691, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 112, Loss: 0.4688, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 43, Epoch: 113, Loss: 0.4699, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 43, Epoch: 114, Loss: 0.4619, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 43, Epoch: 115, Loss: 0.4662, Val Acc: 0.7284, Test Acc: 0.7744
# Seed: 43, Epoch: 116, Loss: 0.4689, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 43, Epoch: 117, Loss: 0.4895, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 43, Epoch: 118, Loss: 0.5048, Val Acc: 0.7901, Test Acc: 0.7744
# Seed: 43, Epoch: 119, Loss: 0.4815, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 120, Loss: 0.4887, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 43, Epoch: 121, Loss: 0.4974, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 43, Epoch: 122, Loss: 0.4788, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 123, Loss: 0.4738, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 124, Loss: 0.4768, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 43, Epoch: 125, Loss: 0.4698, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 126, Loss: 0.4681, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 43, Epoch: 127, Loss: 0.4620, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 43, Epoch: 128, Loss: 0.4758, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 129, Loss: 0.4654, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 130, Loss: 0.4627, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 131, Loss: 0.4654, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 132, Loss: 0.4706, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 43, Epoch: 133, Loss: 0.4648, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 43, Epoch: 134, Loss: 0.4747, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 43, Epoch: 135, Loss: 0.4564, Val Acc: 0.7469, Test Acc: 0.7927
# Seed: 43, Epoch: 136, Loss: 0.4614, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 43, Epoch: 137, Loss: 0.4627, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 138, Loss: 0.4555, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 43, Epoch: 139, Loss: 0.4522, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 43, Epoch: 140, Loss: 0.4521, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 43, Epoch: 141, Loss: 0.4558, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 142, Loss: 0.4542, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 143, Loss: 0.4555, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 43, Epoch: 144, Loss: 0.4629, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 43, Epoch: 145, Loss: 0.4714, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 43, Epoch: 146, Loss: 0.4552, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 43, Epoch: 147, Loss: 0.4539, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 43, Epoch: 148, Loss: 0.4565, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 43, Epoch: 149, Loss: 0.4527, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 43, Epoch: 150, Loss: 0.4492, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 43, Epoch: 151, Loss: 0.4493, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 43, Epoch: 152, Loss: 0.4508, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 43, Epoch: 153, Loss: 0.4522, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 43, Epoch: 154, Loss: 0.4475, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 43, Epoch: 155, Loss: 0.4498, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 43, Epoch: 156, Loss: 0.4426, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 43, Epoch: 157, Loss: 0.4420, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 158, Loss: 0.4464, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 159, Loss: 0.4414, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 43, Epoch: 160, Loss: 0.4390, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 43, Epoch: 161, Loss: 0.4412, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 162, Loss: 0.4499, Val Acc: 0.7778, Test Acc: 0.7866
# Seed: 43, Epoch: 163, Loss: 0.4469, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 43, Epoch: 164, Loss: 0.4532, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 43, Epoch: 165, Loss: 0.4470, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 43, Epoch: 166, Loss: 0.4535, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 43, Epoch: 167, Loss: 0.4570, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 43, Epoch: 168, Loss: 0.4495, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 43, Epoch: 169, Loss: 0.4468, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 170, Loss: 0.4471, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 43, Epoch: 171, Loss: 0.4424, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 43, Epoch: 172, Loss: 0.4407, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 43, Epoch: 173, Loss: 0.4370, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 43, Epoch: 174, Loss: 0.4384, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 43, Epoch: 175, Loss: 0.4334, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 176, Loss: 0.4650, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 43, Epoch: 177, Loss: 0.4490, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 178, Loss: 0.4350, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 179, Loss: 0.4510, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 43, Epoch: 180, Loss: 0.4383, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 181, Loss: 0.4447, Val Acc: 0.7716, Test Acc: 0.7927
# Seed: 43, Epoch: 182, Loss: 0.4359, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 43, Epoch: 183, Loss: 0.4334, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 43, Epoch: 184, Loss: 0.4368, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 185, Loss: 0.4306, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 43, Epoch: 186, Loss: 0.4363, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 43, Epoch: 187, Loss: 0.4414, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 43, Epoch: 188, Loss: 0.4312, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 43, Epoch: 189, Loss: 0.4394, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 43, Epoch: 190, Loss: 0.4303, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 43, Epoch: 191, Loss: 0.4388, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 43, Epoch: 192, Loss: 0.4292, Val Acc: 0.7593, Test Acc: 0.7927
# Seed: 43, Epoch: 193, Loss: 0.4282, Val Acc: 0.7778, Test Acc: 0.7866
# Seed: 43, Epoch: 194, Loss: 0.4273, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 43, Epoch: 195, Loss: 0.4260, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 43, Epoch: 196, Loss: 0.4315, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 43, Epoch: 197, Loss: 0.4419, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 43, Epoch: 198, Loss: 0.4359, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 199, Loss: 0.4472, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 43, Epoch: 200, Loss: 0.4616, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 44, Epoch: 001, Loss: 0.7276, Val Acc: 0.5123, Test Acc: 0.5000
# Seed: 44, Epoch: 002, Loss: 0.6582, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 44, Epoch: 003, Loss: 0.6306, Val Acc: 0.6914, Test Acc: 0.6524
# Seed: 44, Epoch: 004, Loss: 0.6173, Val Acc: 0.6852, Test Acc: 0.6280
# Seed: 44, Epoch: 005, Loss: 0.6206, Val Acc: 0.6852, Test Acc: 0.6341
# Seed: 44, Epoch: 006, Loss: 0.6135, Val Acc: 0.6975, Test Acc: 0.6646
# Seed: 44, Epoch: 007, Loss: 0.6117, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 44, Epoch: 008, Loss: 0.6108, Val Acc: 0.6975, Test Acc: 0.6646
# Seed: 44, Epoch: 009, Loss: 0.6120, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 44, Epoch: 010, Loss: 0.6085, Val Acc: 0.6975, Test Acc: 0.6585
# Seed: 44, Epoch: 011, Loss: 0.6067, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 44, Epoch: 012, Loss: 0.6042, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 44, Epoch: 013, Loss: 0.6013, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 44, Epoch: 014, Loss: 0.5995, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 44, Epoch: 015, Loss: 0.5971, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 44, Epoch: 016, Loss: 0.6087, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 44, Epoch: 017, Loss: 0.5917, Val Acc: 0.6914, Test Acc: 0.6646
# Seed: 44, Epoch: 018, Loss: 0.5990, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 44, Epoch: 019, Loss: 0.5933, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 44, Epoch: 020, Loss: 0.5877, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 44, Epoch: 021, Loss: 0.5956, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 44, Epoch: 022, Loss: 0.5959, Val Acc: 0.6975, Test Acc: 0.6585
# Seed: 44, Epoch: 023, Loss: 0.5933, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 44, Epoch: 024, Loss: 0.5879, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 44, Epoch: 025, Loss: 0.5873, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 44, Epoch: 026, Loss: 0.5815, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 44, Epoch: 027, Loss: 0.5778, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 44, Epoch: 028, Loss: 0.5726, Val Acc: 0.7222, Test Acc: 0.6890
# Seed: 44, Epoch: 029, Loss: 0.5628, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 44, Epoch: 030, Loss: 0.5610, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 44, Epoch: 031, Loss: 0.5527, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 44, Epoch: 032, Loss: 0.5509, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 44, Epoch: 033, Loss: 0.5426, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 44, Epoch: 034, Loss: 0.5395, Val Acc: 0.6852, Test Acc: 0.7256
# Seed: 44, Epoch: 035, Loss: 0.5371, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 44, Epoch: 036, Loss: 0.5250, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 44, Epoch: 037, Loss: 0.5391, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 44, Epoch: 038, Loss: 0.5245, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 44, Epoch: 039, Loss: 0.5147, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 44, Epoch: 040, Loss: 0.5114, Val Acc: 0.6975, Test Acc: 0.7805
# Seed: 44, Epoch: 041, Loss: 0.5360, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 44, Epoch: 042, Loss: 0.5305, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 44, Epoch: 043, Loss: 0.5179, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 44, Epoch: 044, Loss: 0.5121, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 44, Epoch: 045, Loss: 0.5071, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 44, Epoch: 046, Loss: 0.5059, Val Acc: 0.7099, Test Acc: 0.7866
# Seed: 44, Epoch: 047, Loss: 0.5086, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 44, Epoch: 048, Loss: 0.5060, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 44, Epoch: 049, Loss: 0.5008, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 44, Epoch: 050, Loss: 0.5093, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 44, Epoch: 051, Loss: 0.4984, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 052, Loss: 0.4950, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 44, Epoch: 053, Loss: 0.4965, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 44, Epoch: 054, Loss: 0.4930, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 44, Epoch: 055, Loss: 0.4937, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 056, Loss: 0.4890, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 44, Epoch: 057, Loss: 0.4911, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 44, Epoch: 058, Loss: 0.4899, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 44, Epoch: 059, Loss: 0.4849, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 44, Epoch: 060, Loss: 0.4850, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 061, Loss: 0.4884, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 44, Epoch: 062, Loss: 0.4937, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 44, Epoch: 063, Loss: 0.5002, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 44, Epoch: 064, Loss: 0.4929, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 065, Loss: 0.4825, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 44, Epoch: 066, Loss: 0.4832, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 067, Loss: 0.4826, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 44, Epoch: 068, Loss: 0.4807, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 44, Epoch: 069, Loss: 0.4832, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 44, Epoch: 070, Loss: 0.4837, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 44, Epoch: 071, Loss: 0.4805, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 44, Epoch: 072, Loss: 0.4718, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 073, Loss: 0.4811, Val Acc: 0.7407, Test Acc: 0.7866
# Seed: 44, Epoch: 074, Loss: 0.4806, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 44, Epoch: 075, Loss: 0.4975, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 44, Epoch: 076, Loss: 0.4918, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 44, Epoch: 077, Loss: 0.4828, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 44, Epoch: 078, Loss: 0.4872, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 44, Epoch: 079, Loss: 0.4851, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 44, Epoch: 080, Loss: 0.4811, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 44, Epoch: 081, Loss: 0.4757, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 44, Epoch: 082, Loss: 0.4733, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 44, Epoch: 083, Loss: 0.4732, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 44, Epoch: 084, Loss: 0.4798, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 085, Loss: 0.4790, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 086, Loss: 0.4722, Val Acc: 0.7346, Test Acc: 0.7866
# Seed: 44, Epoch: 087, Loss: 0.4654, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 44, Epoch: 088, Loss: 0.4706, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 44, Epoch: 089, Loss: 0.4736, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 44, Epoch: 090, Loss: 0.4755, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 44, Epoch: 091, Loss: 0.4639, Val Acc: 0.7593, Test Acc: 0.7866
# Seed: 44, Epoch: 092, Loss: 0.4712, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 44, Epoch: 093, Loss: 0.4769, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 44, Epoch: 094, Loss: 0.4877, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 44, Epoch: 095, Loss: 0.5034, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 44, Epoch: 096, Loss: 0.4916, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 44, Epoch: 097, Loss: 0.4789, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 44, Epoch: 098, Loss: 0.4773, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 44, Epoch: 099, Loss: 0.4779, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 44, Epoch: 100, Loss: 0.4662, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 44, Epoch: 101, Loss: 0.4710, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 44, Epoch: 102, Loss: 0.4624, Val Acc: 0.7840, Test Acc: 0.7744
# Seed: 44, Epoch: 103, Loss: 0.4631, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 44, Epoch: 104, Loss: 0.4598, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 105, Loss: 0.4600, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 44, Epoch: 106, Loss: 0.4542, Val Acc: 0.7346, Test Acc: 0.7805
# Seed: 44, Epoch: 107, Loss: 0.4640, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 108, Loss: 0.4608, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 109, Loss: 0.4576, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 44, Epoch: 110, Loss: 0.4514, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 44, Epoch: 111, Loss: 0.4500, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 44, Epoch: 112, Loss: 0.4433, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 44, Epoch: 113, Loss: 0.4508, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 44, Epoch: 114, Loss: 0.4404, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 115, Loss: 0.4406, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 44, Epoch: 116, Loss: 0.4407, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 44, Epoch: 117, Loss: 0.4478, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 44, Epoch: 118, Loss: 0.4416, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 44, Epoch: 119, Loss: 0.4440, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 44, Epoch: 120, Loss: 0.4407, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 121, Loss: 0.4419, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 44, Epoch: 122, Loss: 0.4429, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 44, Epoch: 123, Loss: 0.4445, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 44, Epoch: 124, Loss: 0.4445, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 44, Epoch: 125, Loss: 0.4413, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 44, Epoch: 126, Loss: 0.4389, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 44, Epoch: 127, Loss: 0.4292, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 44, Epoch: 128, Loss: 0.4400, Val Acc: 0.7593, Test Acc: 0.7866
# Seed: 44, Epoch: 129, Loss: 0.4363, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 44, Epoch: 130, Loss: 0.4331, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 44, Epoch: 131, Loss: 0.4276, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 44, Epoch: 132, Loss: 0.4249, Val Acc: 0.7407, Test Acc: 0.7866
# Seed: 44, Epoch: 133, Loss: 0.4230, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 134, Loss: 0.4297, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 135, Loss: 0.4282, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 136, Loss: 0.4206, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 44, Epoch: 137, Loss: 0.4260, Val Acc: 0.7840, Test Acc: 0.7805
# Seed: 44, Epoch: 138, Loss: 0.4214, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 44, Epoch: 139, Loss: 0.4255, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 44, Epoch: 140, Loss: 0.4185, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 44, Epoch: 141, Loss: 0.4167, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 142, Loss: 0.4139, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 44, Epoch: 143, Loss: 0.4141, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 44, Epoch: 144, Loss: 0.4158, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 44, Epoch: 145, Loss: 0.4127, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 146, Loss: 0.4152, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 147, Loss: 0.4133, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 148, Loss: 0.4126, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 44, Epoch: 149, Loss: 0.4104, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 44, Epoch: 150, Loss: 0.4115, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 44, Epoch: 151, Loss: 0.4180, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 44, Epoch: 152, Loss: 0.4118, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 44, Epoch: 153, Loss: 0.4093, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 44, Epoch: 154, Loss: 0.4071, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 44, Epoch: 155, Loss: 0.4048, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 44, Epoch: 156, Loss: 0.4046, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 44, Epoch: 157, Loss: 0.4252, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 44, Epoch: 158, Loss: 0.4113, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 44, Epoch: 159, Loss: 0.4379, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 44, Epoch: 160, Loss: 0.4629, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 44, Epoch: 161, Loss: 0.4238, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 44, Epoch: 162, Loss: 0.4234, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 163, Loss: 0.4162, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 44, Epoch: 164, Loss: 0.4225, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 44, Epoch: 165, Loss: 0.4038, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 44, Epoch: 166, Loss: 0.4139, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 44, Epoch: 167, Loss: 0.4060, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 44, Epoch: 168, Loss: 0.4126, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 44, Epoch: 169, Loss: 0.4110, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 44, Epoch: 170, Loss: 0.4010, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 44, Epoch: 171, Loss: 0.3961, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 44, Epoch: 172, Loss: 0.3959, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 173, Loss: 0.3936, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 44, Epoch: 174, Loss: 0.3922, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 44, Epoch: 175, Loss: 0.3915, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 44, Epoch: 176, Loss: 0.3913, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 177, Loss: 0.3887, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 44, Epoch: 178, Loss: 0.3899, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 44, Epoch: 179, Loss: 0.3897, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 44, Epoch: 180, Loss: 0.3869, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 44, Epoch: 181, Loss: 0.3868, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 44, Epoch: 182, Loss: 0.3911, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 44, Epoch: 183, Loss: 0.3924, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 44, Epoch: 184, Loss: 0.3859, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 44, Epoch: 185, Loss: 0.3837, Val Acc: 0.7654, Test Acc: 0.7927
# Seed: 44, Epoch: 186, Loss: 0.3792, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 44, Epoch: 187, Loss: 0.3844, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 44, Epoch: 188, Loss: 0.3824, Val Acc: 0.7593, Test Acc: 0.7927
# Seed: 44, Epoch: 189, Loss: 0.3808, Val Acc: 0.7716, Test Acc: 0.7927
# Seed: 44, Epoch: 190, Loss: 0.3822, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 44, Epoch: 191, Loss: 0.3771, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 44, Epoch: 192, Loss: 0.3775, Val Acc: 0.7593, Test Acc: 0.7927
# Seed: 44, Epoch: 193, Loss: 0.3865, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 44, Epoch: 194, Loss: 0.3832, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 44, Epoch: 195, Loss: 0.3855, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 44, Epoch: 196, Loss: 0.3947, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 44, Epoch: 197, Loss: 0.3919, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 44, Epoch: 198, Loss: 0.3882, Val Acc: 0.7778, Test Acc: 0.7866
# Seed: 44, Epoch: 199, Loss: 0.3868, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 44, Epoch: 200, Loss: 0.3839, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 45, Epoch: 001, Loss: 0.6650, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 45, Epoch: 002, Loss: 0.6323, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 45, Epoch: 003, Loss: 0.6241, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 45, Epoch: 004, Loss: 0.6199, Val Acc: 0.6543, Test Acc: 0.5976
# Seed: 45, Epoch: 005, Loss: 0.6169, Val Acc: 0.6667, Test Acc: 0.6098
# Seed: 45, Epoch: 006, Loss: 0.6158, Val Acc: 0.6790, Test Acc: 0.6098
# Seed: 45, Epoch: 007, Loss: 0.6099, Val Acc: 0.6728, Test Acc: 0.6037
# Seed: 45, Epoch: 008, Loss: 0.6100, Val Acc: 0.6852, Test Acc: 0.6402
# Seed: 45, Epoch: 009, Loss: 0.6047, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 45, Epoch: 010, Loss: 0.6014, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 45, Epoch: 011, Loss: 0.5965, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 45, Epoch: 012, Loss: 0.5937, Val Acc: 0.7099, Test Acc: 0.6707
# Seed: 45, Epoch: 013, Loss: 0.5869, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 45, Epoch: 014, Loss: 0.5905, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 45, Epoch: 015, Loss: 0.5830, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 45, Epoch: 016, Loss: 0.5720, Val Acc: 0.6728, Test Acc: 0.7500
# Seed: 45, Epoch: 017, Loss: 0.5836, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 45, Epoch: 018, Loss: 0.5672, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 45, Epoch: 019, Loss: 0.5621, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 45, Epoch: 020, Loss: 0.5510, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 45, Epoch: 021, Loss: 0.5479, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 45, Epoch: 022, Loss: 0.5432, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 45, Epoch: 023, Loss: 0.5311, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 45, Epoch: 024, Loss: 0.5298, Val Acc: 0.7407, Test Acc: 0.7317
# Seed: 45, Epoch: 025, Loss: 0.5253, Val Acc: 0.7099, Test Acc: 0.7500
# Seed: 45, Epoch: 026, Loss: 0.5328, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 45, Epoch: 027, Loss: 0.5292, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 45, Epoch: 028, Loss: 0.5158, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 45, Epoch: 029, Loss: 0.5135, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 45, Epoch: 030, Loss: 0.5137, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 45, Epoch: 031, Loss: 0.5213, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 45, Epoch: 032, Loss: 0.5161, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 45, Epoch: 033, Loss: 0.5250, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 45, Epoch: 034, Loss: 0.5203, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 45, Epoch: 035, Loss: 0.5052, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 036, Loss: 0.5064, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 45, Epoch: 037, Loss: 0.5095, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 45, Epoch: 038, Loss: 0.5026, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 45, Epoch: 039, Loss: 0.5007, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 45, Epoch: 040, Loss: 0.5105, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 45, Epoch: 041, Loss: 0.5387, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 45, Epoch: 042, Loss: 0.5278, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 45, Epoch: 043, Loss: 0.5269, Val Acc: 0.7593, Test Acc: 0.7378
# Seed: 45, Epoch: 044, Loss: 0.5154, Val Acc: 0.7037, Test Acc: 0.7500
# Seed: 45, Epoch: 045, Loss: 0.5074, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 45, Epoch: 046, Loss: 0.5083, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 45, Epoch: 047, Loss: 0.4989, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 45, Epoch: 048, Loss: 0.5012, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 45, Epoch: 049, Loss: 0.5033, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 45, Epoch: 050, Loss: 0.4976, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 45, Epoch: 051, Loss: 0.5042, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 45, Epoch: 052, Loss: 0.4939, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 45, Epoch: 053, Loss: 0.4923, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 45, Epoch: 054, Loss: 0.4941, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 45, Epoch: 055, Loss: 0.4948, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 45, Epoch: 056, Loss: 0.4942, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 45, Epoch: 057, Loss: 0.4976, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 45, Epoch: 058, Loss: 0.4974, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 059, Loss: 0.4885, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 45, Epoch: 060, Loss: 0.4836, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 45, Epoch: 061, Loss: 0.4906, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 45, Epoch: 062, Loss: 0.4890, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 063, Loss: 0.4919, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 45, Epoch: 064, Loss: 0.4892, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 065, Loss: 0.4911, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 45, Epoch: 066, Loss: 0.4884, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 45, Epoch: 067, Loss: 0.4919, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 45, Epoch: 068, Loss: 0.4972, Val Acc: 0.7840, Test Acc: 0.7683
# Seed: 45, Epoch: 069, Loss: 0.4854, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 45, Epoch: 070, Loss: 0.4841, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 071, Loss: 0.4782, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 45, Epoch: 072, Loss: 0.4896, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 45, Epoch: 073, Loss: 0.4974, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 45, Epoch: 074, Loss: 0.4865, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 45, Epoch: 075, Loss: 0.4983, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 45, Epoch: 076, Loss: 0.4924, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 45, Epoch: 077, Loss: 0.4905, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 45, Epoch: 078, Loss: 0.4831, Val Acc: 0.7284, Test Acc: 0.7805
# Seed: 45, Epoch: 079, Loss: 0.4811, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 45, Epoch: 080, Loss: 0.4806, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 45, Epoch: 081, Loss: 0.4764, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 45, Epoch: 082, Loss: 0.4803, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 45, Epoch: 083, Loss: 0.4805, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 45, Epoch: 084, Loss: 0.4825, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 45, Epoch: 085, Loss: 0.4753, Val Acc: 0.7654, Test Acc: 0.7866
# ...
# Seed: 45, Epoch: 175, Loss: 0.4352, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 45, Epoch: 176, Loss: 0.4260, Val Acc: 0.7716, Test Acc: 0.7500
# Seed: 45, Epoch: 177, Loss: 0.4255, Val Acc: 0.7840, Test Acc: 0.7561
# Seed: 45, Epoch: 178, Loss: 0.4217, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 45, Epoch: 179, Loss: 0.4296, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 45, Epoch: 180, Loss: 0.4144, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 181, Loss: 0.4218, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 182, Loss: 0.4316, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 45, Epoch: 183, Loss: 0.4250, Val Acc: 0.7840, Test Acc: 0.7622
# Seed: 45, Epoch: 184, Loss: 0.4195, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 45, Epoch: 185, Loss: 0.4220, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 45, Epoch: 186, Loss: 0.4129, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 45, Epoch: 187, Loss: 0.4088, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 45, Epoch: 188, Loss: 0.4084, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 45, Epoch: 189, Loss: 0.4067, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 45, Epoch: 190, Loss: 0.4109, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 45, Epoch: 191, Loss: 0.4096, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 45, Epoch: 192, Loss: 0.4071, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 45, Epoch: 193, Loss: 0.4220, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 45, Epoch: 194, Loss: 0.4193, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 45, Epoch: 195, Loss: 0.4232, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 45, Epoch: 196, Loss: 0.4161, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 45, Epoch: 197, Loss: 0.4129, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 45, Epoch: 198, Loss: 0.4037, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 45, Epoch: 199, Loss: 0.4034, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 45, Epoch: 200, Loss: 0.4051, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 001, Loss: 0.6538, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 46, Epoch: 002, Loss: 0.6316, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 46, Epoch: 003, Loss: 0.6268, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 46, Epoch: 004, Loss: 0.6223, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 46, Epoch: 005, Loss: 0.6174, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 46, Epoch: 006, Loss: 0.6108, Val Acc: 0.6481, Test Acc: 0.6098
# Seed: 46, Epoch: 007, Loss: 0.6071, Val Acc: 0.6481, Test Acc: 0.6098
# Seed: 46, Epoch: 008, Loss: 0.5984, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 46, Epoch: 009, Loss: 0.5938, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 46, Epoch: 010, Loss: 0.5857, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 46, Epoch: 011, Loss: 0.5803, Val Acc: 0.7407, Test Acc: 0.6890
# Seed: 46, Epoch: 012, Loss: 0.5746, Val Acc: 0.7160, Test Acc: 0.7561
# Seed: 46, Epoch: 013, Loss: 0.5720, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 46, Epoch: 014, Loss: 0.5692, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 015, Loss: 0.5609, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 46, Epoch: 016, Loss: 0.5574, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 46, Epoch: 017, Loss: 0.5547, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 46, Epoch: 018, Loss: 0.5569, Val Acc: 0.7407, Test Acc: 0.7256
# Seed: 46, Epoch: 019, Loss: 0.5471, Val Acc: 0.7222, Test Acc: 0.7561
# Seed: 46, Epoch: 020, Loss: 0.5398, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 46, Epoch: 021, Loss: 0.5399, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 46, Epoch: 022, Loss: 0.5366, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 46, Epoch: 023, Loss: 0.5283, Val Acc: 0.7222, Test Acc: 0.7744
# Seed: 46, Epoch: 024, Loss: 0.5269, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 46, Epoch: 025, Loss: 0.5239, Val Acc: 0.7222, Test Acc: 0.7622
# Seed: 46, Epoch: 026, Loss: 0.5196, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 027, Loss: 0.5182, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 028, Loss: 0.5246, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 46, Epoch: 029, Loss: 0.5246, Val Acc: 0.7099, Test Acc: 0.7683
# Seed: 46, Epoch: 030, Loss: 0.5155, Val Acc: 0.7778, Test Acc: 0.7561
# Seed: 46, Epoch: 031, Loss: 0.5198, Val Acc: 0.7222, Test Acc: 0.7683
# Seed: 46, Epoch: 032, Loss: 0.5241, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 46, Epoch: 033, Loss: 0.5478, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 034, Loss: 0.5209, Val Acc: 0.6667, Test Acc: 0.7317
# Seed: 46, Epoch: 035, Loss: 0.5239, Val Acc: 0.7778, Test Acc: 0.7500
# Seed: 46, Epoch: 036, Loss: 0.5157, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 46, Epoch: 037, Loss: 0.5155, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 038, Loss: 0.5030, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 46, Epoch: 039, Loss: 0.5054, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 46, Epoch: 040, Loss: 0.5032, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 041, Loss: 0.4999, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 46, Epoch: 042, Loss: 0.5016, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 46, Epoch: 043, Loss: 0.5019, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 46, Epoch: 044, Loss: 0.4935, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 46, Epoch: 045, Loss: 0.4963, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 046, Loss: 0.4937, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 047, Loss: 0.4971, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 048, Loss: 0.4902, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 049, Loss: 0.4937, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 46, Epoch: 050, Loss: 0.4863, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 46, Epoch: 051, Loss: 0.4966, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 46, Epoch: 052, Loss: 0.4920, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 053, Loss: 0.4904, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 054, Loss: 0.4864, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 055, Loss: 0.4870, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 46, Epoch: 056, Loss: 0.4965, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 057, Loss: 0.5036, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 058, Loss: 0.4962, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 46, Epoch: 059, Loss: 0.4902, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 46, Epoch: 060, Loss: 0.4843, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 46, Epoch: 061, Loss: 0.4879, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 46, Epoch: 062, Loss: 0.4797, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 063, Loss: 0.4788, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 064, Loss: 0.4774, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 46, Epoch: 065, Loss: 0.4802, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 066, Loss: 0.4753, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 067, Loss: 0.4725, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 46, Epoch: 068, Loss: 0.4703, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 069, Loss: 0.4684, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 46, Epoch: 070, Loss: 0.4663, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 071, Loss: 0.4728, Val Acc: 0.7531, Test Acc: 0.7988
# Seed: 46, Epoch: 072, Loss: 0.4797, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 073, Loss: 0.4801, Val Acc: 0.7593, Test Acc: 0.7866
# Seed: 46, Epoch: 074, Loss: 0.4987, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 075, Loss: 0.4857, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 46, Epoch: 076, Loss: 0.4767, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 46, Epoch: 077, Loss: 0.4652, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 46, Epoch: 078, Loss: 0.4609, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 079, Loss: 0.4640, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 46, Epoch: 080, Loss: 0.4670, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 081, Loss: 0.4589, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 46, Epoch: 082, Loss: 0.4645, Val Acc: 0.7654, Test Acc: 0.7500
# Seed: 46, Epoch: 083, Loss: 0.4637, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 46, Epoch: 084, Loss: 0.4558, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 085, Loss: 0.4620, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 46, Epoch: 086, Loss: 0.4637, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 46, Epoch: 087, Loss: 0.4630, Val Acc: 0.7407, Test Acc: 0.7927
# Seed: 46, Epoch: 088, Loss: 0.4639, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 089, Loss: 0.4610, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 46, Epoch: 090, Loss: 0.4612, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 091, Loss: 0.4644, Val Acc: 0.7346, Test Acc: 0.7805
# Seed: 46, Epoch: 092, Loss: 0.4683, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 093, Loss: 0.4855, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 094, Loss: 0.4647, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 095, Loss: 0.4620, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 096, Loss: 0.4613, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 46, Epoch: 097, Loss: 0.4667, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 098, Loss: 0.4547, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 46, Epoch: 099, Loss: 0.4451, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 100, Loss: 0.4542, Val Acc: 0.7346, Test Acc: 0.7866
# Seed: 46, Epoch: 101, Loss: 0.4585, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 102, Loss: 0.4666, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 46, Epoch: 103, Loss: 0.4467, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 46, Epoch: 104, Loss: 0.4447, Val Acc: 0.7716, Test Acc: 0.7683
# Seed: 46, Epoch: 105, Loss: 0.4440, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 46, Epoch: 106, Loss: 0.4443, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 46, Epoch: 107, Loss: 0.4408, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 108, Loss: 0.4433, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 46, Epoch: 109, Loss: 0.4376, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 46, Epoch: 110, Loss: 0.4424, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 46, Epoch: 111, Loss: 0.4385, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 46, Epoch: 112, Loss: 0.4406, Val Acc: 0.7531, Test Acc: 0.7805
# Seed: 46, Epoch: 113, Loss: 0.4504, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 46, Epoch: 114, Loss: 0.4441, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 115, Loss: 0.4417, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 46, Epoch: 116, Loss: 0.4388, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 46, Epoch: 117, Loss: 0.4527, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 46, Epoch: 118, Loss: 0.4337, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 46, Epoch: 119, Loss: 0.4320, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 46, Epoch: 120, Loss: 0.4314, Val Acc: 0.7716, Test Acc: 0.7561
# Seed: 46, Epoch: 121, Loss: 0.4371, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 122, Loss: 0.4279, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 46, Epoch: 123, Loss: 0.4217, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 124, Loss: 0.4223, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 46, Epoch: 125, Loss: 0.4181, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 126, Loss: 0.4319, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 127, Loss: 0.4312, Val Acc: 0.7778, Test Acc: 0.7866
# Seed: 46, Epoch: 128, Loss: 0.4260, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 129, Loss: 0.4188, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 130, Loss: 0.4182, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 131, Loss: 0.4181, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 132, Loss: 0.4321, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 133, Loss: 0.4168, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 134, Loss: 0.4196, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 135, Loss: 0.4129, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 46, Epoch: 136, Loss: 0.4209, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 46, Epoch: 137, Loss: 0.4383, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 46, Epoch: 138, Loss: 0.4203, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 46, Epoch: 139, Loss: 0.4348, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 140, Loss: 0.4286, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 141, Loss: 0.4188, Val Acc: 0.7654, Test Acc: 0.7683
# Seed: 46, Epoch: 142, Loss: 0.4181, Val Acc: 0.7654, Test Acc: 0.7805
# Seed: 46, Epoch: 143, Loss: 0.4109, Val Acc: 0.7469, Test Acc: 0.7744
# Seed: 46, Epoch: 144, Loss: 0.4102, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 145, Loss: 0.4094, Val Acc: 0.7654, Test Acc: 0.7866
# Seed: 46, Epoch: 146, Loss: 0.4122, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 147, Loss: 0.4065, Val Acc: 0.7840, Test Acc: 0.7805
# Seed: 46, Epoch: 148, Loss: 0.4323, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 46, Epoch: 149, Loss: 0.4266, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 46, Epoch: 150, Loss: 0.4129, Val Acc: 0.7778, Test Acc: 0.7744
# Seed: 46, Epoch: 151, Loss: 0.4203, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 152, Loss: 0.4214, Val Acc: 0.7284, Test Acc: 0.7744
# Seed: 46, Epoch: 153, Loss: 0.4125, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 46, Epoch: 154, Loss: 0.4094, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 46, Epoch: 155, Loss: 0.4012, Val Acc: 0.7654, Test Acc: 0.7744
# Seed: 46, Epoch: 156, Loss: 0.4132, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 46, Epoch: 157, Loss: 0.4057, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 46, Epoch: 158, Loss: 0.4082, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 159, Loss: 0.4003, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 160, Loss: 0.4182, Val Acc: 0.6975, Test Acc: 0.7622
# Seed: 46, Epoch: 161, Loss: 0.4361, Val Acc: 0.7593, Test Acc: 0.7866
# Seed: 46, Epoch: 162, Loss: 0.4324, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 46, Epoch: 163, Loss: 0.4125, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 46, Epoch: 164, Loss: 0.4242, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 46, Epoch: 165, Loss: 0.4165, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 166, Loss: 0.4074, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 46, Epoch: 167, Loss: 0.4042, Val Acc: 0.7716, Test Acc: 0.7927
# Seed: 46, Epoch: 168, Loss: 0.3966, Val Acc: 0.7778, Test Acc: 0.7805
# Seed: 46, Epoch: 169, Loss: 0.3942, Val Acc: 0.7531, Test Acc: 0.7866
# Seed: 46, Epoch: 170, Loss: 0.3928, Val Acc: 0.7593, Test Acc: 0.7805
# Seed: 46, Epoch: 171, Loss: 0.3947, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 172, Loss: 0.3878, Val Acc: 0.7593, Test Acc: 0.7683
# Seed: 46, Epoch: 173, Loss: 0.3922, Val Acc: 0.7099, Test Acc: 0.7622
# Seed: 46, Epoch: 174, Loss: 0.3870, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 46, Epoch: 175, Loss: 0.3904, Val Acc: 0.7407, Test Acc: 0.7927
# Seed: 46, Epoch: 176, Loss: 0.3791, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 46, Epoch: 177, Loss: 0.3769, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 46, Epoch: 178, Loss: 0.3797, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 46, Epoch: 179, Loss: 0.3764, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 180, Loss: 0.3790, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 181, Loss: 0.3787, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 46, Epoch: 182, Loss: 0.3860, Val Acc: 0.7654, Test Acc: 0.7622
# Seed: 46, Epoch: 183, Loss: 0.3866, Val Acc: 0.7469, Test Acc: 0.7866
# Seed: 46, Epoch: 184, Loss: 0.3791, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 46, Epoch: 185, Loss: 0.3722, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 46, Epoch: 186, Loss: 0.3717, Val Acc: 0.7407, Test Acc: 0.7805
# Seed: 46, Epoch: 187, Loss: 0.3721, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 46, Epoch: 188, Loss: 0.3662, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 189, Loss: 0.3682, Val Acc: 0.7407, Test Acc: 0.7622
# Seed: 46, Epoch: 190, Loss: 0.3817, Val Acc: 0.7531, Test Acc: 0.7683
# Seed: 46, Epoch: 191, Loss: 0.3914, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 46, Epoch: 192, Loss: 0.3722, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 46, Epoch: 193, Loss: 0.3884, Val Acc: 0.7593, Test Acc: 0.7744
# Seed: 46, Epoch: 194, Loss: 0.3708, Val Acc: 0.7716, Test Acc: 0.7805
# Seed: 46, Epoch: 195, Loss: 0.3697, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 196, Loss: 0.3825, Val Acc: 0.7469, Test Acc: 0.7805
# Seed: 46, Epoch: 197, Loss: 0.3797, Val Acc: 0.7531, Test Acc: 0.7744
# Seed: 46, Epoch: 198, Loss: 0.3702, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 46, Epoch: 199, Loss: 0.3623, Val Acc: 0.7407, Test Acc: 0.7744
# Seed: 46, Epoch: 200, Loss: 0.3662, Val Acc: 0.7469, Test Acc: 0.7744
# Average Time: 44.81 seconds
# Var Time: 0.29 seconds
# Average Memory: 842.00 MB
# Average Best Val Acc: 0.7864
# Std Best Test Acc: 0.0118
# Average Test Acc: 0.7671

# %% [markdown]
# ## Dense HoscPooling with HierarchicalGCN (2022)

# %%
import torch

EPS = 1e-15


def dense_hoscpool(
    x,
    adj,
    s,
    mu=0.1,
    alpha=0.5,
    new_ortho=False,
    mask=None,
):
    r"""The highe-order pooling operator (HoscPool) from the paper
    `"Higher-order clustering and pooling for Graph Neural Networks"
    <http://arxiv.org/abs/2209.03473>`_. Based on motif spectral clustering,
    it captures and combines different levels of higher-order connectivity
    patterns when coarsening the graph.
    .. math::
        \mathbf{X}^{\prime} &= {\mathrm{softmax}(\mathbf{S})}^{\top} \cdot
        \mathbf{X}
        \mathbf{A}^{\prime} &= {\mathrm{softmax}(\mathbf{S})}^{\top} \cdot
        \mathbf{A} \cdot \mathrm{softmax}(\mathbf{S})
    based on the learned cluster assignment matrix :math:`\mathbf{S} \in \mathbb{R}^{B
    \times N \times K}`. This function returns the pooled feature matrix, the coarsened
    symmetrically normalised adjacency matrix, the motif spectral clustering loss :math:`\mathcal{L}_{mc}`
    and the orthogonality loss :math:`\mathcal{L}_{o}`.
    .. math::
        \mathcal{L}_{mc} &= - \frac{\alpha_1}{K} \cdot \text{Tr}\bigg(\frac{\mathbf{S}^\top \mathbf{A} \mathbf{S}}
            {\mathbf{S}^\top\mathbf{D}\mathbf{S}}\bigg) - \frac{\alpha_2}{K} \cdot \text{Tr}\bigg(
                \frac{\mathbf{S}^\top\mathbf{A}_{M}\mathbf{S}}{\mathbf{S}^\top\mathbf{D}_{M}\mathbf{S}}\bigg).
        \mathcal{L}_o &= \frac{1}{\sqrt{K}-1} \bigg( \sqrt{K} - \frac{1}{\sqrt{N}}\sum_{j=1}^K ||S_{*j}||_F\bigg)
    Args:
        x (Tensor): Node feature tensor :math:`\mathbf{X} \in \mathbb{R}^{B
            \times N \times F}` with batch-size :math:`B`, (maximum)
            number of nodes :math:`N` for each graph, and feature dimension
            :math:`F`.
        adj (Tensor): adjacency matrix :math:`\mathbf{A} \in \mathbb{R}^{B \times N \times N}`.
        s (Tensor): the learnable cluster assignment matrix :math:`\mathbf{S} \in \mathbb{R}^{B
            \times N \times K}` with number of clusters :math:`K`. The softmax
            does not have to be applied beforehand, since it is executed
            within this method.
        mu (Tensor, optional): scalar that controls the importance given to regularization loss
        alpha (Tensor, optional): scalar in [0,1] controlling the importance granted
            to higher-order information (in loss function).
        new_ortho (BoolTensor, optional): either to use new proposed loss or old one
        mask (BoolTensor, optional): Mask matrix
            :math:`\mathbf{M} \in {\{ 0, 1 \}}^{B \times N}` indicating
            the valid nodes for each graph. (default: :obj:`None`)
    :rtype: (:class:`Tensor`, :class:`Tensor`, :class:`Tensor`,
        :class:`Tensor`)
    """
    x = x.unsqueeze(0) if x.dim() == 2 else x
    adj = adj.unsqueeze(0) if adj.dim() == 2 else adj
    s = s.unsqueeze(0) if s.dim() == 2 else s

    (batch_size, num_nodes, _), k = x.size(), s.size(-1)

    s = torch.softmax(s, dim=-1)

    if mask is not None:
        mask = mask.view(batch_size, num_nodes, 1).to(x.dtype)
        x, s = x * mask, s * mask

    # Output adjacency and feature matrices
    out = torch.matmul(s.transpose(1, 2), x)
    out_adj = torch.matmul(torch.matmul(s.transpose(1, 2), adj), s)

    # Motif adj matrix - not sym. normalised
    motif_adj = torch.mul(torch.matmul(adj, adj), adj)
    motif_out_adj = torch.matmul(torch.matmul(s.transpose(1, 2), motif_adj), s)

    mincut_loss = ho_mincut_loss = 0
    # 1st order MinCUT loss
    if alpha < 1:
        diag_SAS = torch.einsum("ijj->ij", out_adj.clone())
        d_flat = torch.einsum("ijk->ij", adj.clone())
        d = _rank3_diag(d_flat)
        sds = torch.matmul(torch.matmul(s.transpose(1, 2), d), s)
        diag_SDS = torch.einsum("ijk->ij", sds) + EPS
        mincut_loss = -torch.sum(diag_SAS / diag_SDS, axis=1)
        mincut_loss = 1 / k * torch.mean(mincut_loss)

    # Higher order cut
    if alpha > 0:
        diag_SAS = torch.einsum("ijj->ij", motif_out_adj)
        d_flat = torch.einsum("ijk->ij", motif_adj)
        d = _rank3_diag(d_flat)
        diag_SDS = (torch.einsum(
            "ijk->ij", torch.matmul(torch.matmul(s.transpose(1, 2), d), s)) +
                    EPS)
        ho_mincut_loss = -torch.sum(diag_SAS / diag_SDS, axis=1)
        ho_mincut_loss = 1 / k * torch.mean(ho_mincut_loss)

    # Combine ho and fo mincut loss.
    # We do not learn these coefficients yet
    hosc_loss = (1 - alpha) * mincut_loss + alpha * ho_mincut_loss

    # Orthogonality loss
    if mu == 0:
        ortho_loss = torch.tensor(0)
    else:
        if new_ortho:
            if s.shape[0] == 1:
                ortho_loss = ((-torch.sum(torch.norm(s, p="fro", dim=-2)) /
                               (num_nodes**0.5)) + k**0.5) / (k**0.5 - 1)
            elif mask != None:
                ortho_loss = sum([((-torch.sum(
                    torch.norm(
                        s[i][:mask[i].nonzero().shape[0]],
                        p="fro",
                        dim=-2,
                    )) / (mask[i].nonzero().shape[0]**0.5) + k**0.5) /
                                   (k**0.5 - 1)) for i in range(batch_size)
                                  ]) / float(batch_size)
            else:
                ortho_loss = sum(
                    [((-torch.sum(torch.norm(s[i], p="fro", dim=-2)) /
                       (num_nodes**0.5) + k**0.5) / (k**0.5 - 1))
                     for i in range(batch_size)]) / float(batch_size)
        else:
            # Orthogonality regularization.
            ss = torch.matmul(s.transpose(1, 2), s)
            i_s = torch.eye(k).type_as(ss)
            ortho_loss = torch.norm(
                ss / torch.norm(ss, dim=(-1, -2), keepdim=True) -
                i_s / torch.norm(i_s),
                dim=(-1, -2),
            )
            ortho_loss = torch.mean(ortho_loss)

    # Fix and normalize coarsened adjacency matrix.
    ind = torch.arange(k, device=out_adj.device)
    out_adj[:, ind, ind] = 0
    d = torch.einsum("ijk->ij", out_adj)
    d = torch.sqrt(d + EPS)[:, None]
    out_adj = (out_adj / d) / d.transpose(1, 2)

    return out, out_adj, hosc_loss, mu * ortho_loss


def _rank3_diag(x):
    eye = torch.eye(x.size(1)).type_as(x)
    out = eye * x.unsqueeze(2).expand(*x.size(), x.size(1))
    return out

# %%
import os.path as osp
import time
from math import ceil

import torch
import torch.nn.functional as F

import torch_geometric.transforms as T
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DenseDataLoader
from torch_geometric.nn import DenseSAGEConv, dense_diff_pool
max_nodes = 1500
dataset = dataset_PROTEINS
dataset = dataset.shuffle()

class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, normalize=False, lin=True):
        super().__init__()

        self.conv1 = DenseSAGEConv(in_channels, hidden_channels, normalize)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = DenseSAGEConv(hidden_channels, hidden_channels, normalize)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = DenseSAGEConv(hidden_channels, out_channels, normalize)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        if lin:
            self.lin = torch.nn.Linear(out_channels, out_channels)
        else:
            self.lin = None

    def bn(self, i, x):
        batch_size, num_nodes, num_channels = x.size()
        x = x.view(-1, num_channels)
        x = getattr(self, f'bn{i}')(x)
        x = x.view(batch_size, num_nodes, num_channels)
        return x

    def forward(self, x, adj, mask=None):
        x = self.bn(1, self.conv1(x, adj, mask).relu())
        x = self.bn(2, self.conv2(x, adj, mask).relu())
        x = self.bn(3, self.conv3(x, adj, mask).relu())

        if self.lin is not None:
            x = self.lin(x).relu()

        return x


class Net_Hosc(torch.nn.Module):
    def __init__(self):
        super().__init__()

        num_nodes = 64
        self.gnn1_pool = GNN(dataset.num_features, 64, num_nodes)

        num_nodes = 64
        self.gnn2_pool = GNN(64, 64, num_nodes)

        self.gnn1_embed = DenseSAGEConv(dataset.num_features, 64)
        self.gnn2_embed = DenseSAGEConv(64, 64)
        self.gnn3_embed = DenseSAGEConv(64, 64)

        self.lin1 = torch.nn.Linear(64, 32)
        self.lin2 = torch.nn.Linear(32, dataset.num_classes)

    def forward(self, x, adj, mask=None):
        s = self.gnn1_pool(x, adj, mask)
        x = self.gnn1_embed(x, adj, mask)
        x = F.relu(x)

        x, adj, mc, o = dense_hoscpool(x, adj, s, mu=0.1, alpha=0.5, new_ortho=False, mask=mask)

        s = self.gnn2_pool(x, adj)
        x = self.gnn2_embed(x, adj)
        x = F.relu(x)

        x, adj, mc_aux, o_aux = dense_hoscpool(x, adj, s, mu=0.1, alpha=0.5, new_ortho=False)

        x = self.gnn3_embed(x, adj)
        x = F.relu(x)

        x = x.mean(dim=1)
        x = self.lin1(x).relu()
        x = self.lin2(x)
        output = F.log_softmax(x, dim=-1)
        #print(f"Model output shape: {output.shape}")
        return output

if torch.cuda.is_available():
    device = torch.device('cuda')
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

model = Net_Hosc().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x, data.adj, data.mask)
        loss = F.nll_loss(output, data.y.view(-1))
        loss.backward()
        total_loss += data.y.size(0) * float(loss)
        optimizer.step()
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        output = model(data.x, data.adj, data.mask)
        pred = output.max(dim=1)[1]
        correct += int(pred.eq(data.y.view(-1)).sum())
    return correct / len(loader.dataset)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = Net_Hosc().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6501, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 002, Loss: 0.6396, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 003, Loss: 0.6307, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 004, Loss: 0.6245, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 005, Loss: 0.6172, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 006, Loss: 0.6084, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 007, Loss: 0.5985, Val Acc: 0.6790, Test Acc: 0.6280
# Seed: 42, Epoch: 008, Loss: 0.5889, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 42, Epoch: 009, Loss: 0.5787, Val Acc: 0.7407, Test Acc: 0.6890
# Seed: 42, Epoch: 010, Loss: 0.5706, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 42, Epoch: 011, Loss: 0.5584, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 42, Epoch: 012, Loss: 0.5512, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 013, Loss: 0.5494, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 42, Epoch: 014, Loss: 0.5408, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 015, Loss: 0.5416, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 42, Epoch: 016, Loss: 0.5207, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 42, Epoch: 017, Loss: 0.5156, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 018, Loss: 0.5169, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 019, Loss: 0.4956, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 020, Loss: 0.4891, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 42, Epoch: 021, Loss: 0.4794, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 022, Loss: 0.4813, Val Acc: 0.5926, Test Acc: 0.7012
# Seed: 42, Epoch: 023, Loss: 0.4876, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 024, Loss: 0.4936, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 42, Epoch: 025, Loss: 0.4808, Val Acc: 0.6111, Test Acc: 0.6890
# Seed: 42, Epoch: 026, Loss: 0.4740, Val Acc: 0.6543, Test Acc: 0.7134
# Seed: 42, Epoch: 027, Loss: 0.4579, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 42, Epoch: 028, Loss: 0.4441, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 42, Epoch: 029, Loss: 0.4455, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 030, Loss: 0.4385, Val Acc: 0.6975, Test Acc: 0.7561
# Seed: 42, Epoch: 031, Loss: 0.4424, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 42, Epoch: 032, Loss: 0.4235, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 42, Epoch: 033, Loss: 0.4266, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 42, Epoch: 034, Loss: 0.4263, Val Acc: 0.5617, Test Acc: 0.6585
# Seed: 42, Epoch: 035, Loss: 0.4341, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 42, Epoch: 036, Loss: 0.4449, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 037, Loss: 0.4265, Val Acc: 0.6235, Test Acc: 0.6585
# Seed: 42, Epoch: 038, Loss: 0.4210, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 039, Loss: 0.4435, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 42, Epoch: 040, Loss: 0.4122, Val Acc: 0.5988, Test Acc: 0.6341
# Seed: 42, Epoch: 041, Loss: 0.4167, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 42, Epoch: 042, Loss: 0.4076, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 043, Loss: 0.3899, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 42, Epoch: 044, Loss: 0.3948, Val Acc: 0.7099, Test Acc: 0.7500
# Seed: 42, Epoch: 045, Loss: 0.3914, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 42, Epoch: 046, Loss: 0.3922, Val Acc: 0.7037, Test Acc: 0.7561
# Seed: 42, Epoch: 047, Loss: 0.3752, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 42, Epoch: 048, Loss: 0.3639, Val Acc: 0.7222, Test Acc: 0.7866
# Seed: 42, Epoch: 049, Loss: 0.3655, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 42, Epoch: 050, Loss: 0.3823, Val Acc: 0.7222, Test Acc: 0.7744
# Seed: 42, Epoch: 051, Loss: 0.3542, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 42, Epoch: 052, Loss: 0.3562, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 42, Epoch: 053, Loss: 0.3497, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 42, Epoch: 054, Loss: 0.3454, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 42, Epoch: 055, Loss: 0.3458, Val Acc: 0.7222, Test Acc: 0.7805
# Seed: 42, Epoch: 056, Loss: 0.3420, Val Acc: 0.6914, Test Acc: 0.7500
# Seed: 42, Epoch: 057, Loss: 0.3703, Val Acc: 0.7099, Test Acc: 0.7683
# Seed: 42, Epoch: 058, Loss: 0.3566, Val Acc: 0.6358, Test Acc: 0.7134
# Seed: 42, Epoch: 059, Loss: 0.3320, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 060, Loss: 0.3462, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 061, Loss: 0.3263, Val Acc: 0.6605, Test Acc: 0.7195
# Seed: 42, Epoch: 062, Loss: 0.3347, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 42, Epoch: 063, Loss: 0.3244, Val Acc: 0.6358, Test Acc: 0.7012
# Seed: 42, Epoch: 064, Loss: 0.3217, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 065, Loss: 0.3308, Val Acc: 0.6235, Test Acc: 0.7134
# Seed: 42, Epoch: 066, Loss: 0.3338, Val Acc: 0.6852, Test Acc: 0.7622
# Seed: 42, Epoch: 067, Loss: 0.3161, Val Acc: 0.7222, Test Acc: 0.7683
# Seed: 42, Epoch: 068, Loss: 0.3510, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 42, Epoch: 069, Loss: 0.3242, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 42, Epoch: 070, Loss: 0.3036, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 071, Loss: 0.2965, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 42, Epoch: 072, Loss: 0.2824, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 073, Loss: 0.2953, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 42, Epoch: 074, Loss: 0.3065, Val Acc: 0.7099, Test Acc: 0.7744
# Seed: 42, Epoch: 075, Loss: 0.3348, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 42, Epoch: 076, Loss: 0.3286, Val Acc: 0.5802, Test Acc: 0.6463
# Seed: 42, Epoch: 077, Loss: 0.3606, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 42, Epoch: 078, Loss: 0.3528, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 079, Loss: 0.3200, Val Acc: 0.6173, Test Acc: 0.6646
# Seed: 42, Epoch: 080, Loss: 0.3150, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 42, Epoch: 081, Loss: 0.3213, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 42, Epoch: 082, Loss: 0.3098, Val Acc: 0.6790, Test Acc: 0.7439
# Seed: 42, Epoch: 083, Loss: 0.2890, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 42, Epoch: 084, Loss: 0.2655, Val Acc: 0.6914, Test Acc: 0.7561
# Seed: 42, Epoch: 085, Loss: 0.2663, Val Acc: 0.6728, Test Acc: 0.7683
# Seed: 42, Epoch: 086, Loss: 0.2633, Val Acc: 0.7037, Test Acc: 0.7805
# Seed: 42, Epoch: 087, Loss: 0.2600, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 42, Epoch: 088, Loss: 0.2484, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 42, Epoch: 089, Loss: 0.2520, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 42, Epoch: 090, Loss: 0.2308, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 091, Loss: 0.2368, Val Acc: 0.6605, Test Acc: 0.7439
# Seed: 42, Epoch: 092, Loss: 0.2266, Val Acc: 0.6790, Test Acc: 0.7683
# Seed: 42, Epoch: 093, Loss: 0.2143, Val Acc: 0.6358, Test Acc: 0.7012
# Seed: 42, Epoch: 094, Loss: 0.2259, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 095, Loss: 0.2156, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 42, Epoch: 096, Loss: 0.2224, Val Acc: 0.6235, Test Acc: 0.7134
# Seed: 42, Epoch: 097, Loss: 0.2540, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 42, Epoch: 098, Loss: 0.3383, Val Acc: 0.6296, Test Acc: 0.7073
# Seed: 42, Epoch: 099, Loss: 0.2620, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 100, Loss: 0.2459, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 42, Epoch: 101, Loss: 0.2587, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 42, Epoch: 102, Loss: 0.2557, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 42, Epoch: 103, Loss: 0.2650, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 104, Loss: 0.2481, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 105, Loss: 0.2552, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 42, Epoch: 106, Loss: 0.2377, Val Acc: 0.6420, Test Acc: 0.7134
# Seed: 42, Epoch: 107, Loss: 0.2096, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 42, Epoch: 108, Loss: 0.2082, Val Acc: 0.6914, Test Acc: 0.7439
# Seed: 42, Epoch: 109, Loss: 0.2010, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 42, Epoch: 110, Loss: 0.1774, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 111, Loss: 0.1868, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 42, Epoch: 112, Loss: 0.1718, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 42, Epoch: 113, Loss: 0.1592, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 42, Epoch: 114, Loss: 0.1807, Val Acc: 0.6914, Test Acc: 0.7378
# Seed: 42, Epoch: 115, Loss: 0.1573, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 42, Epoch: 116, Loss: 0.1638, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 42, Epoch: 117, Loss: 0.1665, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 42, Epoch: 118, Loss: 0.1894, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 42, Epoch: 119, Loss: 0.1612, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 42, Epoch: 120, Loss: 0.1739, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 42, Epoch: 121, Loss: 0.1982, Val Acc: 0.6111, Test Acc: 0.6829
# Seed: 42, Epoch: 122, Loss: 0.1708, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 42, Epoch: 123, Loss: 0.1905, Val Acc: 0.6852, Test Acc: 0.6524
# Seed: 42, Epoch: 124, Loss: 0.1875, Val Acc: 0.6790, Test Acc: 0.7500
# Seed: 42, Epoch: 125, Loss: 0.1965, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 42, Epoch: 126, Loss: 0.1904, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 42, Epoch: 127, Loss: 0.1850, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 42, Epoch: 128, Loss: 0.1652, Val Acc: 0.6173, Test Acc: 0.6890
# Seed: 42, Epoch: 129, Loss: 0.1681, Val Acc: 0.6358, Test Acc: 0.7317
# Seed: 42, Epoch: 130, Loss: 0.1485, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 42, Epoch: 131, Loss: 0.1360, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 132, Loss: 0.1224, Val Acc: 0.7037, Test Acc: 0.7500
# Seed: 42, Epoch: 133, Loss: 0.1314, Val Acc: 0.6914, Test Acc: 0.7500
# Seed: 42, Epoch: 134, Loss: 0.1223, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 42, Epoch: 135, Loss: 0.1083, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 42, Epoch: 136, Loss: 0.1022, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 42, Epoch: 137, Loss: 0.1115, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 42, Epoch: 138, Loss: 0.0925, Val Acc: 0.6543, Test Acc: 0.7012
# Seed: 42, Epoch: 139, Loss: 0.1016, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 42, Epoch: 140, Loss: 0.1086, Val Acc: 0.6173, Test Acc: 0.6829
# Seed: 42, Epoch: 141, Loss: 0.1165, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 42, Epoch: 142, Loss: 0.1562, Val Acc: 0.5741, Test Acc: 0.6707
# Seed: 42, Epoch: 143, Loss: 0.2260, Val Acc: 0.7284, Test Acc: 0.6585
# Seed: 42, Epoch: 144, Loss: 0.3316, Val Acc: 0.6543, Test Acc: 0.7012
# Seed: 42, Epoch: 145, Loss: 0.3420, Val Acc: 0.5617, Test Acc: 0.6585
# Seed: 42, Epoch: 146, Loss: 0.3045, Val Acc: 0.6358, Test Acc: 0.5976
# Seed: 42, Epoch: 147, Loss: 0.2623, Val Acc: 0.6111, Test Acc: 0.5000
# Seed: 42, Epoch: 148, Loss: 0.2512, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 42, Epoch: 149, Loss: 0.2279, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 42, Epoch: 150, Loss: 0.2070, Val Acc: 0.5864, Test Acc: 0.6402
# Seed: 42, Epoch: 151, Loss: 0.2181, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 42, Epoch: 152, Loss: 0.1843, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 42, Epoch: 153, Loss: 0.1620, Val Acc: 0.6481, Test Acc: 0.6829
# Seed: 42, Epoch: 154, Loss: 0.1627, Val Acc: 0.6420, Test Acc: 0.7195
# Seed: 42, Epoch: 155, Loss: 0.1321, Val Acc: 0.6543, Test Acc: 0.7622
# Seed: 42, Epoch: 156, Loss: 0.1216, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 42, Epoch: 157, Loss: 0.1290, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 42, Epoch: 158, Loss: 0.1213, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 42, Epoch: 159, Loss: 0.1191, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 42, Epoch: 160, Loss: 0.1025, Val Acc: 0.6049, Test Acc: 0.7134
# Seed: 42, Epoch: 161, Loss: 0.0999, Val Acc: 0.6481, Test Acc: 0.7195
# Seed: 42, Epoch: 162, Loss: 0.0939, Val Acc: 0.6852, Test Acc: 0.7317
# Early stopping at epoch 162 for seed 42
# Seed: 43, Epoch: 001, Loss: 0.6685, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 002, Loss: 0.6281, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 003, Loss: 0.6210, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 43, Epoch: 004, Loss: 0.6115, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 43, Epoch: 005, Loss: 0.5969, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 43, Epoch: 006, Loss: 0.5879, Val Acc: 0.6728, Test Acc: 0.6159
# Seed: 43, Epoch: 007, Loss: 0.5841, Val Acc: 0.6728, Test Acc: 0.6220
# Seed: 43, Epoch: 008, Loss: 0.5699, Val Acc: 0.7037, Test Acc: 0.6341
# Seed: 43, Epoch: 009, Loss: 0.5784, Val Acc: 0.7099, Test Acc: 0.6646
# Seed: 43, Epoch: 010, Loss: 0.5591, Val Acc: 0.7099, Test Acc: 0.6463
# Seed: 43, Epoch: 011, Loss: 0.5659, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 012, Loss: 0.5434, Val Acc: 0.7284, Test Acc: 0.6524
# Seed: 43, Epoch: 013, Loss: 0.5448, Val Acc: 0.7407, Test Acc: 0.7256
# Seed: 43, Epoch: 014, Loss: 0.5263, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 43, Epoch: 015, Loss: 0.5180, Val Acc: 0.7593, Test Acc: 0.7134
# Seed: 43, Epoch: 016, Loss: 0.5029, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 017, Loss: 0.5006, Val Acc: 0.7593, Test Acc: 0.7195
# Seed: 43, Epoch: 018, Loss: 0.4830, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 43, Epoch: 019, Loss: 0.4865, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 43, Epoch: 020, Loss: 0.4858, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 43, Epoch: 021, Loss: 0.4950, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 022, Loss: 0.4761, Val Acc: 0.6852, Test Acc: 0.7561
# Seed: 43, Epoch: 023, Loss: 0.4707, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 43, Epoch: 024, Loss: 0.4758, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 025, Loss: 0.4699, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 43, Epoch: 026, Loss: 0.4571, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 43, Epoch: 027, Loss: 0.4612, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 028, Loss: 0.4585, Val Acc: 0.7840, Test Acc: 0.7500
# Seed: 43, Epoch: 029, Loss: 0.4473, Val Acc: 0.7901, Test Acc: 0.7317
# Seed: 43, Epoch: 030, Loss: 0.4397, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 43, Epoch: 031, Loss: 0.4431, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 43, Epoch: 032, Loss: 0.4448, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 033, Loss: 0.4280, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 43, Epoch: 034, Loss: 0.4325, Val Acc: 0.7963, Test Acc: 0.7073
# Seed: 43, Epoch: 035, Loss: 0.4188, Val Acc: 0.7901, Test Acc: 0.7256
# Seed: 43, Epoch: 036, Loss: 0.4258, Val Acc: 0.7840, Test Acc: 0.7500
# Seed: 43, Epoch: 037, Loss: 0.4062, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 43, Epoch: 038, Loss: 0.4173, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 039, Loss: 0.4002, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 040, Loss: 0.3996, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 43, Epoch: 041, Loss: 0.3950, Val Acc: 0.7716, Test Acc: 0.6951
# Seed: 43, Epoch: 042, Loss: 0.3947, Val Acc: 0.7840, Test Acc: 0.7500
# Seed: 43, Epoch: 043, Loss: 0.4007, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 43, Epoch: 044, Loss: 0.3934, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 045, Loss: 0.3940, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 046, Loss: 0.3883, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 43, Epoch: 047, Loss: 0.3914, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 43, Epoch: 048, Loss: 0.3893, Val Acc: 0.7654, Test Acc: 0.7256
# Seed: 43, Epoch: 049, Loss: 0.3672, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 43, Epoch: 050, Loss: 0.3706, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 43, Epoch: 051, Loss: 0.3741, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 43, Epoch: 052, Loss: 0.3769, Val Acc: 0.7037, Test Acc: 0.7561
# Seed: 43, Epoch: 053, Loss: 0.3821, Val Acc: 0.6790, Test Acc: 0.7500
# Seed: 43, Epoch: 054, Loss: 0.3708, Val Acc: 0.7099, Test Acc: 0.7500
# Seed: 43, Epoch: 055, Loss: 0.3675, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 43, Epoch: 056, Loss: 0.3499, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 43, Epoch: 057, Loss: 0.3282, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 43, Epoch: 058, Loss: 0.3488, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 059, Loss: 0.3448, Val Acc: 0.7654, Test Acc: 0.7256
# Seed: 43, Epoch: 060, Loss: 0.3235, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 43, Epoch: 061, Loss: 0.3332, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 062, Loss: 0.3216, Val Acc: 0.7407, Test Acc: 0.7317
# Seed: 43, Epoch: 063, Loss: 0.3314, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 43, Epoch: 064, Loss: 0.3115, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 065, Loss: 0.2985, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 43, Epoch: 066, Loss: 0.2957, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 43, Epoch: 067, Loss: 0.2863, Val Acc: 0.7222, Test Acc: 0.7561
# Seed: 43, Epoch: 068, Loss: 0.2896, Val Acc: 0.7160, Test Acc: 0.7622
# Seed: 43, Epoch: 069, Loss: 0.2825, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 070, Loss: 0.2844, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 43, Epoch: 071, Loss: 0.2965, Val Acc: 0.7654, Test Acc: 0.7195
# Seed: 43, Epoch: 072, Loss: 0.3059, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 43, Epoch: 073, Loss: 0.3172, Val Acc: 0.7407, Test Acc: 0.6890
# Seed: 43, Epoch: 074, Loss: 0.3088, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 43, Epoch: 075, Loss: 0.2831, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 076, Loss: 0.2753, Val Acc: 0.7778, Test Acc: 0.6951
# Seed: 43, Epoch: 077, Loss: 0.2816, Val Acc: 0.7407, Test Acc: 0.6646
# Seed: 43, Epoch: 078, Loss: 0.2760, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 43, Epoch: 079, Loss: 0.2581, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 43, Epoch: 080, Loss: 0.2688, Val Acc: 0.5926, Test Acc: 0.6768
# Seed: 43, Epoch: 081, Loss: 0.2843, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 43, Epoch: 082, Loss: 0.2914, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 43, Epoch: 083, Loss: 0.2698, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 43, Epoch: 084, Loss: 0.2582, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 43, Epoch: 085, Loss: 0.2709, Val Acc: 0.6975, Test Acc: 0.7439
# Seed: 43, Epoch: 086, Loss: 0.2485, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 43, Epoch: 087, Loss: 0.2560, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 43, Epoch: 088, Loss: 0.2455, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 43, Epoch: 089, Loss: 0.2454, Val Acc: 0.7284, Test Acc: 0.6646
# Seed: 43, Epoch: 090, Loss: 0.2343, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 43, Epoch: 091, Loss: 0.2682, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 43, Epoch: 092, Loss: 0.2512, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 43, Epoch: 093, Loss: 0.2369, Val Acc: 0.6975, Test Acc: 0.7439
# Seed: 43, Epoch: 094, Loss: 0.2358, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 43, Epoch: 095, Loss: 0.2220, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 096, Loss: 0.1996, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 43, Epoch: 097, Loss: 0.2119, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 43, Epoch: 098, Loss: 0.2093, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 43, Epoch: 099, Loss: 0.2106, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 43, Epoch: 100, Loss: 0.1938, Val Acc: 0.6049, Test Acc: 0.6341
# Seed: 43, Epoch: 101, Loss: 0.2022, Val Acc: 0.7654, Test Acc: 0.7073
# Seed: 43, Epoch: 102, Loss: 0.2102, Val Acc: 0.7407, Test Acc: 0.7012
# Seed: 43, Epoch: 103, Loss: 0.1824, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 43, Epoch: 104, Loss: 0.1777, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 43, Epoch: 105, Loss: 0.1874, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 43, Epoch: 106, Loss: 0.1844, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 43, Epoch: 107, Loss: 0.2056, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 43, Epoch: 108, Loss: 0.1885, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 43, Epoch: 109, Loss: 0.1807, Val Acc: 0.7778, Test Acc: 0.7317
# Seed: 43, Epoch: 110, Loss: 0.1721, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 43, Epoch: 111, Loss: 0.1704, Val Acc: 0.7901, Test Acc: 0.7073
# Seed: 43, Epoch: 112, Loss: 0.1786, Val Acc: 0.7778, Test Acc: 0.6829
# Seed: 43, Epoch: 113, Loss: 0.1676, Val Acc: 0.7593, Test Acc: 0.6890
# Seed: 43, Epoch: 114, Loss: 0.1665, Val Acc: 0.7346, Test Acc: 0.6951
# Seed: 43, Epoch: 115, Loss: 0.1645, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 43, Epoch: 116, Loss: 0.1864, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 43, Epoch: 117, Loss: 0.1713, Val Acc: 0.6728, Test Acc: 0.6341
# Seed: 43, Epoch: 118, Loss: 0.2140, Val Acc: 0.6975, Test Acc: 0.6585
# Seed: 43, Epoch: 119, Loss: 0.1879, Val Acc: 0.7531, Test Acc: 0.7195
# Seed: 43, Epoch: 120, Loss: 0.2018, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 43, Epoch: 121, Loss: 0.1980, Val Acc: 0.6481, Test Acc: 0.6463
# Seed: 43, Epoch: 122, Loss: 0.1882, Val Acc: 0.6481, Test Acc: 0.6585
# Seed: 43, Epoch: 123, Loss: 0.1671, Val Acc: 0.6728, Test Acc: 0.7378
# Seed: 43, Epoch: 124, Loss: 0.1611, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 43, Epoch: 125, Loss: 0.1506, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 43, Epoch: 126, Loss: 0.1365, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 43, Epoch: 127, Loss: 0.1393, Val Acc: 0.7593, Test Acc: 0.6646
# Seed: 43, Epoch: 128, Loss: 0.1445, Val Acc: 0.7778, Test Acc: 0.6829
# Seed: 43, Epoch: 129, Loss: 0.1464, Val Acc: 0.7531, Test Acc: 0.6951
# Seed: 43, Epoch: 130, Loss: 0.1390, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 43, Epoch: 131, Loss: 0.1571, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 132, Loss: 0.1699, Val Acc: 0.7901, Test Acc: 0.6829
# Seed: 43, Epoch: 133, Loss: 0.1258, Val Acc: 0.7593, Test Acc: 0.7195
# Seed: 43, Epoch: 134, Loss: 0.1256, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 43, Epoch: 135, Loss: 0.1375, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 43, Epoch: 136, Loss: 0.1246, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 43, Epoch: 137, Loss: 0.1331, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 43, Epoch: 138, Loss: 0.1118, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 43, Epoch: 139, Loss: 0.1251, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 43, Epoch: 140, Loss: 0.1240, Val Acc: 0.7407, Test Acc: 0.6707
# Seed: 43, Epoch: 141, Loss: 0.1302, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 43, Epoch: 142, Loss: 0.1208, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 43, Epoch: 143, Loss: 0.2012, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 43, Epoch: 144, Loss: 0.1599, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 43, Epoch: 145, Loss: 0.1441, Val Acc: 0.7346, Test Acc: 0.6768
# Seed: 43, Epoch: 146, Loss: 0.1357, Val Acc: 0.7654, Test Acc: 0.6890
# Seed: 43, Epoch: 147, Loss: 0.1465, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 43, Epoch: 148, Loss: 0.1228, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 43, Epoch: 149, Loss: 0.1398, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 43, Epoch: 150, Loss: 0.1195, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 43, Epoch: 151, Loss: 0.1478, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 43, Epoch: 152, Loss: 0.1271, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 43, Epoch: 153, Loss: 0.1261, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 154, Loss: 0.1113, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 43, Epoch: 155, Loss: 0.1116, Val Acc: 0.6790, Test Acc: 0.6768
# Seed: 43, Epoch: 156, Loss: 0.1228, Val Acc: 0.7346, Test Acc: 0.6829
# Seed: 43, Epoch: 157, Loss: 0.1113, Val Acc: 0.7716, Test Acc: 0.6463
# Seed: 43, Epoch: 158, Loss: 0.1267, Val Acc: 0.7593, Test Acc: 0.6951
# Seed: 43, Epoch: 159, Loss: 0.1084, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 43, Epoch: 160, Loss: 0.1151, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 43, Epoch: 161, Loss: 0.1096, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 43, Epoch: 162, Loss: 0.1068, Val Acc: 0.7099, Test Acc: 0.7561
# Seed: 43, Epoch: 163, Loss: 0.1135, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 164, Loss: 0.1167, Val Acc: 0.7840, Test Acc: 0.7012
# Seed: 43, Epoch: 165, Loss: 0.1239, Val Acc: 0.7531, Test Acc: 0.6829
# Seed: 43, Epoch: 166, Loss: 0.0938, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 43, Epoch: 167, Loss: 0.1197, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 43, Epoch: 168, Loss: 0.1215, Val Acc: 0.7284, Test Acc: 0.6402
# Seed: 43, Epoch: 169, Loss: 0.0945, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 43, Epoch: 170, Loss: 0.1000, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 43, Epoch: 171, Loss: 0.0979, Val Acc: 0.7284, Test Acc: 0.6829
# Seed: 43, Epoch: 172, Loss: 0.0945, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 43, Epoch: 173, Loss: 0.1200, Val Acc: 0.7099, Test Acc: 0.6524
# Seed: 43, Epoch: 174, Loss: 0.0983, Val Acc: 0.7469, Test Acc: 0.6951
# Seed: 43, Epoch: 175, Loss: 0.1025, Val Acc: 0.7469, Test Acc: 0.7012
# Seed: 43, Epoch: 176, Loss: 0.1042, Val Acc: 0.6852, Test Acc: 0.6646
# Seed: 43, Epoch: 177, Loss: 0.1304, Val Acc: 0.7654, Test Acc: 0.6951
# Seed: 43, Epoch: 178, Loss: 0.1089, Val Acc: 0.7407, Test Acc: 0.6829
# Seed: 43, Epoch: 179, Loss: 0.1197, Val Acc: 0.7531, Test Acc: 0.7134
# Seed: 43, Epoch: 180, Loss: 0.1182, Val Acc: 0.7407, Test Acc: 0.7012
# Seed: 43, Epoch: 181, Loss: 0.1147, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 43, Epoch: 182, Loss: 0.1277, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 183, Loss: 0.0820, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 43, Epoch: 184, Loss: 0.1256, Val Acc: 0.6975, Test Acc: 0.7134
# Early stopping at epoch 184 for seed 43
# Seed: 44, Epoch: 001, Loss: 0.6602, Val Acc: 0.6728, Test Acc: 0.6159
# Seed: 44, Epoch: 002, Loss: 0.6209, Val Acc: 0.6728, Test Acc: 0.6098
# Seed: 44, Epoch: 003, Loss: 0.6220, Val Acc: 0.6605, Test Acc: 0.6037
# Seed: 44, Epoch: 004, Loss: 0.6132, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 44, Epoch: 005, Loss: 0.6120, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 44, Epoch: 006, Loss: 0.6057, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 44, Epoch: 007, Loss: 0.6000, Val Acc: 0.7160, Test Acc: 0.6585
# Seed: 44, Epoch: 008, Loss: 0.5931, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 44, Epoch: 009, Loss: 0.5822, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 44, Epoch: 010, Loss: 0.5746, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 44, Epoch: 011, Loss: 0.5605, Val Acc: 0.6235, Test Acc: 0.6524
# Seed: 44, Epoch: 012, Loss: 0.5448, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 44, Epoch: 013, Loss: 0.5364, Val Acc: 0.6358, Test Acc: 0.6463
# Seed: 44, Epoch: 014, Loss: 0.5199, Val Acc: 0.6296, Test Acc: 0.6463
# Seed: 44, Epoch: 015, Loss: 0.5105, Val Acc: 0.6358, Test Acc: 0.6707
# Seed: 44, Epoch: 016, Loss: 0.5054, Val Acc: 0.6358, Test Acc: 0.6890
# Seed: 44, Epoch: 017, Loss: 0.4948, Val Acc: 0.6605, Test Acc: 0.6951
# Seed: 44, Epoch: 018, Loss: 0.4899, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 44, Epoch: 019, Loss: 0.4833, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 44, Epoch: 020, Loss: 0.4734, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 44, Epoch: 021, Loss: 0.4662, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 44, Epoch: 022, Loss: 0.4583, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 44, Epoch: 023, Loss: 0.4534, Val Acc: 0.7037, Test Acc: 0.7012
# Seed: 44, Epoch: 024, Loss: 0.4544, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 44, Epoch: 025, Loss: 0.4617, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 44, Epoch: 026, Loss: 0.4658, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 44, Epoch: 027, Loss: 0.4514, Val Acc: 0.7222, Test Acc: 0.7744
# Seed: 44, Epoch: 028, Loss: 0.4549, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 44, Epoch: 029, Loss: 0.4366, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 44, Epoch: 030, Loss: 0.4438, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 44, Epoch: 031, Loss: 0.4488, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 44, Epoch: 032, Loss: 0.4271, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 44, Epoch: 033, Loss: 0.4158, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 44, Epoch: 034, Loss: 0.4213, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 44, Epoch: 035, Loss: 0.4043, Val Acc: 0.7099, Test Acc: 0.7805
# Seed: 44, Epoch: 036, Loss: 0.3856, Val Acc: 0.7284, Test Acc: 0.7683
# Seed: 44, Epoch: 037, Loss: 0.4076, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 44, Epoch: 038, Loss: 0.3865, Val Acc: 0.6852, Test Acc: 0.7439
# Seed: 44, Epoch: 039, Loss: 0.4085, Val Acc: 0.6481, Test Acc: 0.7378
# Seed: 44, Epoch: 040, Loss: 0.3798, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 44, Epoch: 041, Loss: 0.3629, Val Acc: 0.6975, Test Acc: 0.7683
# Seed: 44, Epoch: 042, Loss: 0.3679, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 44, Epoch: 043, Loss: 0.3657, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 44, Epoch: 044, Loss: 0.3557, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 44, Epoch: 045, Loss: 0.3476, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 44, Epoch: 046, Loss: 0.3708, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 44, Epoch: 047, Loss: 0.3797, Val Acc: 0.6975, Test Acc: 0.7439
# Seed: 44, Epoch: 048, Loss: 0.3673, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 44, Epoch: 049, Loss: 0.3596, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 44, Epoch: 050, Loss: 0.3892, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 44, Epoch: 051, Loss: 0.3628, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 44, Epoch: 052, Loss: 0.3583, Val Acc: 0.6235, Test Acc: 0.6768
# Seed: 44, Epoch: 053, Loss: 0.3813, Val Acc: 0.6543, Test Acc: 0.6585
# Seed: 44, Epoch: 054, Loss: 0.3758, Val Acc: 0.6975, Test Acc: 0.7683
# Seed: 44, Epoch: 055, Loss: 0.3660, Val Acc: 0.6667, Test Acc: 0.7256
# Seed: 44, Epoch: 056, Loss: 0.3326, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 44, Epoch: 057, Loss: 0.3275, Val Acc: 0.6728, Test Acc: 0.7561
# Seed: 44, Epoch: 058, Loss: 0.3088, Val Acc: 0.6358, Test Acc: 0.6524
# Seed: 44, Epoch: 059, Loss: 0.3297, Val Acc: 0.6914, Test Acc: 0.7378
# Seed: 44, Epoch: 060, Loss: 0.2953, Val Acc: 0.6235, Test Acc: 0.6768
# Seed: 44, Epoch: 061, Loss: 0.2948, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 44, Epoch: 062, Loss: 0.3457, Val Acc: 0.6235, Test Acc: 0.6768
# Seed: 44, Epoch: 063, Loss: 0.3133, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 44, Epoch: 064, Loss: 0.3071, Val Acc: 0.6543, Test Acc: 0.6707
# Seed: 44, Epoch: 065, Loss: 0.2945, Val Acc: 0.6728, Test Acc: 0.6585
# Seed: 44, Epoch: 066, Loss: 0.3062, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 44, Epoch: 067, Loss: 0.2926, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 44, Epoch: 068, Loss: 0.2717, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 44, Epoch: 069, Loss: 0.2742, Val Acc: 0.5988, Test Acc: 0.6524
# Seed: 44, Epoch: 070, Loss: 0.3434, Val Acc: 0.6728, Test Acc: 0.6220
# Seed: 44, Epoch: 071, Loss: 0.3167, Val Acc: 0.5802, Test Acc: 0.5244
# Seed: 44, Epoch: 072, Loss: 0.3122, Val Acc: 0.5741, Test Acc: 0.5305
# Seed: 44, Epoch: 073, Loss: 0.2853, Val Acc: 0.6049, Test Acc: 0.6524
# Seed: 44, Epoch: 074, Loss: 0.2763, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 44, Epoch: 075, Loss: 0.2700, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 44, Epoch: 076, Loss: 0.2707, Val Acc: 0.6975, Test Acc: 0.7439
# Seed: 44, Epoch: 077, Loss: 0.2414, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 44, Epoch: 078, Loss: 0.2323, Val Acc: 0.6420, Test Acc: 0.5915
# Seed: 44, Epoch: 079, Loss: 0.2177, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 44, Epoch: 080, Loss: 0.2285, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 44, Epoch: 081, Loss: 0.2336, Val Acc: 0.6481, Test Acc: 0.6159
# Seed: 44, Epoch: 082, Loss: 0.2327, Val Acc: 0.6173, Test Acc: 0.6402
# Seed: 44, Epoch: 083, Loss: 0.2354, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 44, Epoch: 084, Loss: 0.2275, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 44, Epoch: 085, Loss: 0.1884, Val Acc: 0.6358, Test Acc: 0.6646
# Seed: 44, Epoch: 086, Loss: 0.2191, Val Acc: 0.6914, Test Acc: 0.6524
# Seed: 44, Epoch: 087, Loss: 0.1782, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 44, Epoch: 088, Loss: 0.2079, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 44, Epoch: 089, Loss: 0.1679, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 44, Epoch: 090, Loss: 0.1842, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 44, Epoch: 091, Loss: 0.1767, Val Acc: 0.6420, Test Acc: 0.7134
# Seed: 44, Epoch: 092, Loss: 0.1870, Val Acc: 0.6605, Test Acc: 0.7012
# Seed: 44, Epoch: 093, Loss: 0.1686, Val Acc: 0.6605, Test Acc: 0.6585
# Seed: 44, Epoch: 094, Loss: 0.1753, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 44, Epoch: 095, Loss: 0.1865, Val Acc: 0.6296, Test Acc: 0.6585
# Seed: 44, Epoch: 096, Loss: 0.2123, Val Acc: 0.6358, Test Acc: 0.6524
# Seed: 44, Epoch: 097, Loss: 0.2312, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 44, Epoch: 098, Loss: 0.1859, Val Acc: 0.7037, Test Acc: 0.6463
# Seed: 44, Epoch: 099, Loss: 0.1624, Val Acc: 0.6975, Test Acc: 0.6463
# Seed: 44, Epoch: 100, Loss: 0.1532, Val Acc: 0.6728, Test Acc: 0.6707
# Seed: 44, Epoch: 101, Loss: 0.1751, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 44, Epoch: 102, Loss: 0.1750, Val Acc: 0.6543, Test Acc: 0.6646
# Seed: 44, Epoch: 103, Loss: 0.1677, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 44, Epoch: 104, Loss: 0.2252, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 44, Epoch: 105, Loss: 0.1707, Val Acc: 0.7037, Test Acc: 0.6280
# Seed: 44, Epoch: 106, Loss: 0.1689, Val Acc: 0.6049, Test Acc: 0.5610
# Seed: 44, Epoch: 107, Loss: 0.1540, Val Acc: 0.5432, Test Acc: 0.5854
# Seed: 44, Epoch: 108, Loss: 0.1521, Val Acc: 0.6605, Test Acc: 0.6280
# Seed: 44, Epoch: 109, Loss: 0.1574, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 44, Epoch: 110, Loss: 0.1328, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 44, Epoch: 111, Loss: 0.1271, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 44, Epoch: 112, Loss: 0.1565, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 44, Epoch: 113, Loss: 0.1462, Val Acc: 0.6543, Test Acc: 0.6280
# Seed: 44, Epoch: 114, Loss: 0.1220, Val Acc: 0.6728, Test Acc: 0.6280
# Seed: 44, Epoch: 115, Loss: 0.1688, Val Acc: 0.6481, Test Acc: 0.6646
# Seed: 44, Epoch: 116, Loss: 0.2000, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 44, Epoch: 117, Loss: 0.2227, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 44, Epoch: 118, Loss: 0.1978, Val Acc: 0.5864, Test Acc: 0.6402
# Seed: 44, Epoch: 119, Loss: 0.1956, Val Acc: 0.6358, Test Acc: 0.6707
# Seed: 44, Epoch: 120, Loss: 0.1872, Val Acc: 0.6543, Test Acc: 0.6159
# Seed: 44, Epoch: 121, Loss: 0.1462, Val Acc: 0.6605, Test Acc: 0.6463
# Seed: 44, Epoch: 122, Loss: 0.1310, Val Acc: 0.6420, Test Acc: 0.7134
# Seed: 44, Epoch: 123, Loss: 0.1071, Val Acc: 0.6296, Test Acc: 0.7256
# Seed: 44, Epoch: 124, Loss: 0.1013, Val Acc: 0.6358, Test Acc: 0.7195
# Seed: 44, Epoch: 125, Loss: 0.1186, Val Acc: 0.6543, Test Acc: 0.6585
# Seed: 44, Epoch: 126, Loss: 0.1134, Val Acc: 0.6481, Test Acc: 0.6098
# Seed: 44, Epoch: 127, Loss: 0.1081, Val Acc: 0.6728, Test Acc: 0.6280
# Seed: 44, Epoch: 128, Loss: 0.0877, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 44, Epoch: 129, Loss: 0.0909, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 44, Epoch: 130, Loss: 0.1027, Val Acc: 0.6667, Test Acc: 0.6220
# Seed: 44, Epoch: 131, Loss: 0.1030, Val Acc: 0.6049, Test Acc: 0.5976
# Seed: 44, Epoch: 132, Loss: 0.0914, Val Acc: 0.6481, Test Acc: 0.5976
# Seed: 44, Epoch: 133, Loss: 0.1188, Val Acc: 0.6852, Test Acc: 0.6280
# Seed: 44, Epoch: 134, Loss: 0.0829, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 44, Epoch: 135, Loss: 0.1390, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 44, Epoch: 136, Loss: 0.1332, Val Acc: 0.6358, Test Acc: 0.6280
# Seed: 44, Epoch: 137, Loss: 0.1424, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 44, Epoch: 138, Loss: 0.1490, Val Acc: 0.6358, Test Acc: 0.7134
# Seed: 44, Epoch: 139, Loss: 0.1407, Val Acc: 0.5617, Test Acc: 0.6037
# Seed: 44, Epoch: 140, Loss: 0.1176, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 44, Epoch: 141, Loss: 0.1069, Val Acc: 0.6296, Test Acc: 0.6524
# Seed: 44, Epoch: 142, Loss: 0.1011, Val Acc: 0.5926, Test Acc: 0.5915
# Seed: 44, Epoch: 143, Loss: 0.1116, Val Acc: 0.6728, Test Acc: 0.6707
# Seed: 44, Epoch: 144, Loss: 0.0970, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 44, Epoch: 145, Loss: 0.1408, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 44, Epoch: 146, Loss: 0.0908, Val Acc: 0.6914, Test Acc: 0.6402
# Seed: 44, Epoch: 147, Loss: 0.0826, Val Acc: 0.6914, Test Acc: 0.6220
# Seed: 44, Epoch: 148, Loss: 0.0716, Val Acc: 0.6790, Test Acc: 0.6585
# Seed: 44, Epoch: 149, Loss: 0.0900, Val Acc: 0.6852, Test Acc: 0.6646
# Seed: 44, Epoch: 150, Loss: 0.0780, Val Acc: 0.6605, Test Acc: 0.6341
# Seed: 44, Epoch: 151, Loss: 0.1072, Val Acc: 0.6852, Test Acc: 0.5732
# Seed: 44, Epoch: 152, Loss: 0.1287, Val Acc: 0.6543, Test Acc: 0.6098
# Seed: 44, Epoch: 153, Loss: 0.0704, Val Acc: 0.5988, Test Acc: 0.6585
# Seed: 44, Epoch: 154, Loss: 0.1064, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 44, Epoch: 155, Loss: 0.1203, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 44, Epoch: 156, Loss: 0.1633, Val Acc: 0.7222, Test Acc: 0.6463
# Seed: 44, Epoch: 157, Loss: 0.1138, Val Acc: 0.6790, Test Acc: 0.6402
# Seed: 44, Epoch: 158, Loss: 0.1090, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 44, Epoch: 159, Loss: 0.0905, Val Acc: 0.6358, Test Acc: 0.6829
# Seed: 44, Epoch: 160, Loss: 0.0993, Val Acc: 0.6975, Test Acc: 0.6585
# Seed: 44, Epoch: 161, Loss: 0.1107, Val Acc: 0.6605, Test Acc: 0.6341
# Seed: 44, Epoch: 162, Loss: 0.0913, Val Acc: 0.6481, Test Acc: 0.6037
# Seed: 44, Epoch: 163, Loss: 0.0626, Val Acc: 0.6728, Test Acc: 0.6707
# Seed: 44, Epoch: 164, Loss: 0.1209, Val Acc: 0.7037, Test Acc: 0.6646
# Seed: 44, Epoch: 165, Loss: 0.0819, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 44, Epoch: 166, Loss: 0.0732, Val Acc: 0.6605, Test Acc: 0.6341
# Seed: 44, Epoch: 167, Loss: 0.0874, Val Acc: 0.6728, Test Acc: 0.6402
# Seed: 44, Epoch: 168, Loss: 0.0651, Val Acc: 0.6481, Test Acc: 0.6341
# Seed: 44, Epoch: 169, Loss: 0.0537, Val Acc: 0.6358, Test Acc: 0.6463
# Seed: 44, Epoch: 170, Loss: 0.0569, Val Acc: 0.6358, Test Acc: 0.6341
# Seed: 44, Epoch: 171, Loss: 0.0689, Val Acc: 0.6481, Test Acc: 0.6159
# Seed: 44, Epoch: 172, Loss: 0.0462, Val Acc: 0.6296, Test Acc: 0.6524
# Seed: 44, Epoch: 173, Loss: 0.0402, Val Acc: 0.6543, Test Acc: 0.6829
# Seed: 44, Epoch: 174, Loss: 0.0476, Val Acc: 0.6728, Test Acc: 0.6707
# Seed: 44, Epoch: 175, Loss: 0.0367, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 44, Epoch: 176, Loss: 0.0887, Val Acc: 0.6481, Test Acc: 0.6524
# Seed: 44, Epoch: 177, Loss: 0.0680, Val Acc: 0.5988, Test Acc: 0.5915
# Seed: 44, Epoch: 178, Loss: 0.0995, Val Acc: 0.6358, Test Acc: 0.6280
# Seed: 44, Epoch: 179, Loss: 0.0937, Val Acc: 0.6296, Test Acc: 0.6646
# Seed: 44, Epoch: 180, Loss: 0.0628, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 44, Epoch: 181, Loss: 0.0673, Val Acc: 0.6728, Test Acc: 0.6402
# Seed: 44, Epoch: 182, Loss: 0.0621, Val Acc: 0.6914, Test Acc: 0.6402
# Seed: 44, Epoch: 183, Loss: 0.1021, Val Acc: 0.7037, Test Acc: 0.6280
# Seed: 44, Epoch: 184, Loss: 0.0593, Val Acc: 0.6975, Test Acc: 0.6159
# Seed: 44, Epoch: 185, Loss: 0.0553, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 44, Epoch: 186, Loss: 0.0806, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 44, Epoch: 187, Loss: 0.0602, Val Acc: 0.6852, Test Acc: 0.6524
# Seed: 44, Epoch: 188, Loss: 0.0473, Val Acc: 0.5926, Test Acc: 0.5549
# Seed: 44, Epoch: 189, Loss: 0.0589, Val Acc: 0.5617, Test Acc: 0.5976
# Seed: 44, Epoch: 190, Loss: 0.0350, Val Acc: 0.6049, Test Acc: 0.6341
# Seed: 44, Epoch: 191, Loss: 0.0636, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 44, Epoch: 192, Loss: 0.0282, Val Acc: 0.6914, Test Acc: 0.6220
# Seed: 44, Epoch: 193, Loss: 0.0639, Val Acc: 0.6975, Test Acc: 0.6402
# Seed: 44, Epoch: 194, Loss: 0.0307, Val Acc: 0.6728, Test Acc: 0.6402
# Seed: 44, Epoch: 195, Loss: 0.0406, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 44, Epoch: 196, Loss: 0.0215, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 44, Epoch: 197, Loss: 0.0412, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 44, Epoch: 198, Loss: 0.0175, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 44, Epoch: 199, Loss: 0.0235, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 44, Epoch: 200, Loss: 0.0193, Val Acc: 0.6728, Test Acc: 0.6463
# Seed: 45, Epoch: 001, Loss: 0.6648, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 45, Epoch: 002, Loss: 0.6200, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 45, Epoch: 003, Loss: 0.6157, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 45, Epoch: 004, Loss: 0.6099, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 45, Epoch: 005, Loss: 0.6106, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 45, Epoch: 006, Loss: 0.6046, Val Acc: 0.7160, Test Acc: 0.6585
# Seed: 45, Epoch: 007, Loss: 0.6019, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 45, Epoch: 008, Loss: 0.5996, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 45, Epoch: 009, Loss: 0.5959, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 45, Epoch: 010, Loss: 0.5931, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 45, Epoch: 011, Loss: 0.5861, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 45, Epoch: 012, Loss: 0.5775, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 45, Epoch: 013, Loss: 0.5665, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 45, Epoch: 014, Loss: 0.5598, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 45, Epoch: 015, Loss: 0.5461, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 45, Epoch: 016, Loss: 0.5300, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 45, Epoch: 017, Loss: 0.5322, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 45, Epoch: 018, Loss: 0.5171, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 45, Epoch: 019, Loss: 0.5159, Val Acc: 0.7531, Test Acc: 0.7195
# Seed: 45, Epoch: 020, Loss: 0.5076, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 45, Epoch: 021, Loss: 0.5022, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 45, Epoch: 022, Loss: 0.4996, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 45, Epoch: 023, Loss: 0.5032, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 024, Loss: 0.4989, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 45, Epoch: 025, Loss: 0.4889, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 45, Epoch: 026, Loss: 0.4738, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 027, Loss: 0.4741, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 45, Epoch: 028, Loss: 0.4624, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 45, Epoch: 029, Loss: 0.4615, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 45, Epoch: 030, Loss: 0.4546, Val Acc: 0.7160, Test Acc: 0.7561
# Seed: 45, Epoch: 031, Loss: 0.4675, Val Acc: 0.6852, Test Acc: 0.7378
# Seed: 45, Epoch: 032, Loss: 0.4641, Val Acc: 0.7160, Test Acc: 0.7683
# Seed: 45, Epoch: 033, Loss: 0.4654, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 034, Loss: 0.4677, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 035, Loss: 0.4516, Val Acc: 0.6605, Test Acc: 0.7195
# Seed: 45, Epoch: 036, Loss: 0.4441, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 45, Epoch: 037, Loss: 0.4664, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 45, Epoch: 038, Loss: 0.4481, Val Acc: 0.5679, Test Acc: 0.6524
# Seed: 45, Epoch: 039, Loss: 0.4353, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 45, Epoch: 040, Loss: 0.4370, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 45, Epoch: 041, Loss: 0.4222, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 45, Epoch: 042, Loss: 0.4136, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 45, Epoch: 043, Loss: 0.4038, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 45, Epoch: 044, Loss: 0.4205, Val Acc: 0.6667, Test Acc: 0.7378
# Seed: 45, Epoch: 045, Loss: 0.4040, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 45, Epoch: 046, Loss: 0.4162, Val Acc: 0.6543, Test Acc: 0.7073
# Seed: 45, Epoch: 047, Loss: 0.4110, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 45, Epoch: 048, Loss: 0.4111, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 45, Epoch: 049, Loss: 0.3806, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 45, Epoch: 050, Loss: 0.3845, Val Acc: 0.7099, Test Acc: 0.7622
# Seed: 45, Epoch: 051, Loss: 0.3707, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 45, Epoch: 052, Loss: 0.3698, Val Acc: 0.6975, Test Acc: 0.7561
# Seed: 45, Epoch: 053, Loss: 0.3680, Val Acc: 0.7160, Test Acc: 0.7744
# Seed: 45, Epoch: 054, Loss: 0.3517, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 45, Epoch: 055, Loss: 0.3921, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 45, Epoch: 056, Loss: 0.3619, Val Acc: 0.6605, Test Acc: 0.7744
# Seed: 45, Epoch: 057, Loss: 0.3600, Val Acc: 0.7222, Test Acc: 0.7927
# Seed: 45, Epoch: 058, Loss: 0.3939, Val Acc: 0.7346, Test Acc: 0.7988
# Seed: 45, Epoch: 059, Loss: 0.3579, Val Acc: 0.5617, Test Acc: 0.6646
# Seed: 45, Epoch: 060, Loss: 0.3558, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 45, Epoch: 061, Loss: 0.3614, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 45, Epoch: 062, Loss: 0.3433, Val Acc: 0.5679, Test Acc: 0.6463
# Seed: 45, Epoch: 063, Loss: 0.3422, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 45, Epoch: 064, Loss: 0.3345, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 45, Epoch: 065, Loss: 0.3105, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 45, Epoch: 066, Loss: 0.3144, Val Acc: 0.7222, Test Acc: 0.7561
# Seed: 45, Epoch: 067, Loss: 0.3132, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 45, Epoch: 068, Loss: 0.3128, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 45, Epoch: 069, Loss: 0.2949, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 45, Epoch: 070, Loss: 0.2812, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 45, Epoch: 071, Loss: 0.2812, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 45, Epoch: 072, Loss: 0.3161, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 45, Epoch: 073, Loss: 0.2926, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 45, Epoch: 074, Loss: 0.2908, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 45, Epoch: 075, Loss: 0.2825, Val Acc: 0.7099, Test Acc: 0.7683
# Seed: 45, Epoch: 076, Loss: 0.2673, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 45, Epoch: 077, Loss: 0.2626, Val Acc: 0.6235, Test Acc: 0.7195
# Seed: 45, Epoch: 078, Loss: 0.2423, Val Acc: 0.7284, Test Acc: 0.6585
# Seed: 45, Epoch: 079, Loss: 0.2401, Val Acc: 0.6914, Test Acc: 0.6829
# Seed: 45, Epoch: 080, Loss: 0.2406, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 45, Epoch: 081, Loss: 0.2348, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 45, Epoch: 082, Loss: 0.2329, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 45, Epoch: 083, Loss: 0.1960, Val Acc: 0.6049, Test Acc: 0.6707
# Seed: 45, Epoch: 084, Loss: 0.2083, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 45, Epoch: 085, Loss: 0.2223, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 45, Epoch: 086, Loss: 0.2389, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 45, Epoch: 087, Loss: 0.2011, Val Acc: 0.6790, Test Acc: 0.6829
# Seed: 45, Epoch: 088, Loss: 0.1743, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 089, Loss: 0.2141, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 45, Epoch: 090, Loss: 0.2388, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 45, Epoch: 091, Loss: 0.2228, Val Acc: 0.6975, Test Acc: 0.7744
# Seed: 45, Epoch: 092, Loss: 0.1877, Val Acc: 0.6605, Test Acc: 0.6951
# Seed: 45, Epoch: 093, Loss: 0.1871, Val Acc: 0.6667, Test Acc: 0.7256
# Seed: 45, Epoch: 094, Loss: 0.1926, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 45, Epoch: 095, Loss: 0.1844, Val Acc: 0.6235, Test Acc: 0.7012
# Seed: 45, Epoch: 096, Loss: 0.1723, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 45, Epoch: 097, Loss: 0.1735, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 45, Epoch: 098, Loss: 0.1950, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 45, Epoch: 099, Loss: 0.2008, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 45, Epoch: 100, Loss: 0.1954, Val Acc: 0.7222, Test Acc: 0.6951
# Seed: 45, Epoch: 101, Loss: 0.2856, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 45, Epoch: 102, Loss: 0.2188, Val Acc: 0.6667, Test Acc: 0.7317
# Seed: 45, Epoch: 103, Loss: 0.2236, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 45, Epoch: 104, Loss: 0.1584, Val Acc: 0.6049, Test Acc: 0.6463
# Seed: 45, Epoch: 105, Loss: 0.1724, Val Acc: 0.6420, Test Acc: 0.6585
# Seed: 45, Epoch: 106, Loss: 0.1655, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 45, Epoch: 107, Loss: 0.1349, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 45, Epoch: 108, Loss: 0.1241, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 45, Epoch: 109, Loss: 0.1147, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 45, Epoch: 110, Loss: 0.1111, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 45, Epoch: 111, Loss: 0.1282, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 45, Epoch: 112, Loss: 0.1250, Val Acc: 0.6481, Test Acc: 0.7012
# Seed: 45, Epoch: 113, Loss: 0.1359, Val Acc: 0.7222, Test Acc: 0.7988
# Seed: 45, Epoch: 114, Loss: 0.1667, Val Acc: 0.6605, Test Acc: 0.6829
# Seed: 45, Epoch: 115, Loss: 0.1372, Val Acc: 0.6790, Test Acc: 0.6829
# Seed: 45, Epoch: 116, Loss: 0.1423, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 45, Epoch: 117, Loss: 0.1756, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 45, Epoch: 118, Loss: 0.1183, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 45, Epoch: 119, Loss: 0.1251, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 45, Epoch: 120, Loss: 0.1353, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 45, Epoch: 121, Loss: 0.1026, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 45, Epoch: 122, Loss: 0.1357, Val Acc: 0.6728, Test Acc: 0.6646
# Seed: 45, Epoch: 123, Loss: 0.0979, Val Acc: 0.7222, Test Acc: 0.6829
# Seed: 45, Epoch: 124, Loss: 0.0891, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 45, Epoch: 125, Loss: 0.0848, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 45, Epoch: 126, Loss: 0.1187, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 45, Epoch: 127, Loss: 0.1671, Val Acc: 0.6543, Test Acc: 0.6646
# Seed: 45, Epoch: 128, Loss: 0.1037, Val Acc: 0.6790, Test Acc: 0.6341
# Seed: 45, Epoch: 129, Loss: 0.1388, Val Acc: 0.6481, Test Acc: 0.6220
# Seed: 45, Epoch: 130, Loss: 0.0943, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 45, Epoch: 131, Loss: 0.1161, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 45, Epoch: 132, Loss: 0.1204, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 45, Epoch: 133, Loss: 0.1002, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 45, Epoch: 134, Loss: 0.1119, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 135, Loss: 0.1242, Val Acc: 0.6667, Test Acc: 0.6707
# Seed: 45, Epoch: 136, Loss: 0.1283, Val Acc: 0.6605, Test Acc: 0.6280
# Seed: 45, Epoch: 137, Loss: 0.1184, Val Acc: 0.6667, Test Acc: 0.6585
# Seed: 45, Epoch: 138, Loss: 0.1173, Val Acc: 0.6605, Test Acc: 0.6768
# ...
# Seed: 45, Epoch: 175, Loss: 0.0572, Val Acc: 0.6358, Test Acc: 0.6829
# Seed: 45, Epoch: 176, Loss: 0.0609, Val Acc: 0.6481, Test Acc: 0.7256
# Seed: 45, Epoch: 177, Loss: 0.0490, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 45, Epoch: 178, Loss: 0.0542, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 179, Loss: 0.0497, Val Acc: 0.6543, Test Acc: 0.7195
# Seed: 45, Epoch: 180, Loss: 0.0392, Val Acc: 0.6358, Test Acc: 0.7012
# Seed: 45, Epoch: 181, Loss: 0.0429, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 45, Epoch: 182, Loss: 0.0817, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 45, Epoch: 183, Loss: 0.1000, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 45, Epoch: 184, Loss: 0.0381, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 45, Epoch: 185, Loss: 0.0661, Val Acc: 0.6235, Test Acc: 0.6402
# Seed: 45, Epoch: 186, Loss: 0.0337, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 45, Epoch: 187, Loss: 0.0309, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 188, Loss: 0.0346, Val Acc: 0.6667, Test Acc: 0.7073
# Seed: 45, Epoch: 189, Loss: 0.0267, Val Acc: 0.6358, Test Acc: 0.7317
# Seed: 45, Epoch: 190, Loss: 0.0350, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 45, Epoch: 191, Loss: 0.0279, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 45, Epoch: 192, Loss: 0.0173, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 45, Epoch: 193, Loss: 0.0484, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 45, Epoch: 194, Loss: 0.0567, Val Acc: 0.6852, Test Acc: 0.6524
# Seed: 45, Epoch: 195, Loss: 0.0387, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 45, Epoch: 196, Loss: 0.0298, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 45, Epoch: 197, Loss: 0.0496, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 45, Epoch: 198, Loss: 0.0611, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 45, Epoch: 199, Loss: 0.0721, Val Acc: 0.6728, Test Acc: 0.6585
# Seed: 45, Epoch: 200, Loss: 0.0475, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 46, Epoch: 001, Loss: 0.6647, Val Acc: 0.6605, Test Acc: 0.5976
# Seed: 46, Epoch: 002, Loss: 0.6285, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 46, Epoch: 003, Loss: 0.6206, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 46, Epoch: 004, Loss: 0.6195, Val Acc: 0.6420, Test Acc: 0.5854
# Seed: 46, Epoch: 005, Loss: 0.6174, Val Acc: 0.6667, Test Acc: 0.6098
# Seed: 46, Epoch: 006, Loss: 0.6135, Val Acc: 0.6728, Test Acc: 0.6098
# Seed: 46, Epoch: 007, Loss: 0.6107, Val Acc: 0.6852, Test Acc: 0.6280
# Seed: 46, Epoch: 008, Loss: 0.6060, Val Acc: 0.6914, Test Acc: 0.6463
# Seed: 46, Epoch: 009, Loss: 0.6021, Val Acc: 0.7160, Test Acc: 0.6768
# Seed: 46, Epoch: 010, Loss: 0.5917, Val Acc: 0.7099, Test Acc: 0.6524
# Seed: 46, Epoch: 011, Loss: 0.5831, Val Acc: 0.7531, Test Acc: 0.7134
# Seed: 46, Epoch: 012, Loss: 0.5670, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 46, Epoch: 013, Loss: 0.5592, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 46, Epoch: 014, Loss: 0.5402, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 46, Epoch: 015, Loss: 0.5320, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 46, Epoch: 016, Loss: 0.5188, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 46, Epoch: 017, Loss: 0.5053, Val Acc: 0.6728, Test Acc: 0.6890
# Seed: 46, Epoch: 018, Loss: 0.4955, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 46, Epoch: 019, Loss: 0.4911, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 020, Loss: 0.4846, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 021, Loss: 0.4728, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 46, Epoch: 022, Loss: 0.4633, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 023, Loss: 0.4556, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 024, Loss: 0.4517, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 46, Epoch: 025, Loss: 0.4589, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 026, Loss: 0.4566, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 46, Epoch: 027, Loss: 0.4345, Val Acc: 0.6049, Test Acc: 0.6707
# Seed: 46, Epoch: 028, Loss: 0.4417, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 46, Epoch: 029, Loss: 0.4424, Val Acc: 0.7222, Test Acc: 0.7622
# Seed: 46, Epoch: 030, Loss: 0.4291, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 031, Loss: 0.4179, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 46, Epoch: 032, Loss: 0.4088, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 033, Loss: 0.4185, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 034, Loss: 0.4023, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 46, Epoch: 035, Loss: 0.3924, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 036, Loss: 0.3902, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 037, Loss: 0.3810, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 038, Loss: 0.3883, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 039, Loss: 0.3686, Val Acc: 0.7222, Test Acc: 0.7622
# Seed: 46, Epoch: 040, Loss: 0.3704, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 46, Epoch: 041, Loss: 0.3518, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 46, Epoch: 042, Loss: 0.3623, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 46, Epoch: 043, Loss: 0.3389, Val Acc: 0.7531, Test Acc: 0.7195
# Seed: 46, Epoch: 044, Loss: 0.3545, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 46, Epoch: 045, Loss: 0.3448, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 46, Epoch: 046, Loss: 0.3464, Val Acc: 0.7531, Test Acc: 0.6951
# Seed: 46, Epoch: 047, Loss: 0.3439, Val Acc: 0.7160, Test Acc: 0.6768
# Seed: 46, Epoch: 048, Loss: 0.3236, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 049, Loss: 0.3272, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 46, Epoch: 050, Loss: 0.3468, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 46, Epoch: 051, Loss: 0.3154, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 46, Epoch: 052, Loss: 0.3094, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 46, Epoch: 053, Loss: 0.3185, Val Acc: 0.7284, Test Acc: 0.6890
# Seed: 46, Epoch: 054, Loss: 0.3441, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 46, Epoch: 055, Loss: 0.3064, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 46, Epoch: 056, Loss: 0.3005, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 46, Epoch: 057, Loss: 0.2914, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 46, Epoch: 058, Loss: 0.2857, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 059, Loss: 0.2839, Val Acc: 0.6667, Test Acc: 0.6890
# Seed: 46, Epoch: 060, Loss: 0.3014, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 46, Epoch: 061, Loss: 0.3049, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 46, Epoch: 062, Loss: 0.2569, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 46, Epoch: 063, Loss: 0.2573, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 46, Epoch: 064, Loss: 0.2430, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 46, Epoch: 065, Loss: 0.2703, Val Acc: 0.6852, Test Acc: 0.6585
# Seed: 46, Epoch: 066, Loss: 0.2453, Val Acc: 0.7284, Test Acc: 0.6524
# Seed: 46, Epoch: 067, Loss: 0.2780, Val Acc: 0.7593, Test Acc: 0.7073
# Seed: 46, Epoch: 068, Loss: 0.2706, Val Acc: 0.5062, Test Acc: 0.5305
# Seed: 46, Epoch: 069, Loss: 0.2362, Val Acc: 0.7222, Test Acc: 0.7866
# Seed: 46, Epoch: 070, Loss: 0.2721, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 46, Epoch: 071, Loss: 0.2262, Val Acc: 0.7284, Test Acc: 0.6646
# Seed: 46, Epoch: 072, Loss: 0.2393, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 46, Epoch: 073, Loss: 0.2187, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 46, Epoch: 074, Loss: 0.1917, Val Acc: 0.7284, Test Acc: 0.6951
# Seed: 46, Epoch: 075, Loss: 0.1812, Val Acc: 0.7037, Test Acc: 0.6768
# Seed: 46, Epoch: 076, Loss: 0.1832, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 46, Epoch: 077, Loss: 0.1720, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 46, Epoch: 078, Loss: 0.1910, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 46, Epoch: 079, Loss: 0.1977, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 080, Loss: 0.1841, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 46, Epoch: 081, Loss: 0.1787, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 46, Epoch: 082, Loss: 0.1820, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 46, Epoch: 083, Loss: 0.2058, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 46, Epoch: 084, Loss: 0.1644, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 46, Epoch: 085, Loss: 0.1946, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 46, Epoch: 086, Loss: 0.1704, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 46, Epoch: 087, Loss: 0.1521, Val Acc: 0.6543, Test Acc: 0.6707
# Seed: 46, Epoch: 088, Loss: 0.1530, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 46, Epoch: 089, Loss: 0.2224, Val Acc: 0.6049, Test Acc: 0.6280
# Seed: 46, Epoch: 090, Loss: 0.2230, Val Acc: 0.6235, Test Acc: 0.5854
# Seed: 46, Epoch: 091, Loss: 0.2632, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 46, Epoch: 092, Loss: 0.2005, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 46, Epoch: 093, Loss: 0.2213, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 094, Loss: 0.2348, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 46, Epoch: 095, Loss: 0.1768, Val Acc: 0.7963, Test Acc: 0.7500
# Seed: 46, Epoch: 096, Loss: 0.2105, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 097, Loss: 0.1863, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 46, Epoch: 098, Loss: 0.1454, Val Acc: 0.7222, Test Acc: 0.7134
# Seed: 46, Epoch: 099, Loss: 0.1306, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 46, Epoch: 100, Loss: 0.1207, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 46, Epoch: 101, Loss: 0.1576, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 46, Epoch: 102, Loss: 0.1282, Val Acc: 0.7407, Test Acc: 0.7866
# Seed: 46, Epoch: 103, Loss: 0.1019, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 46, Epoch: 104, Loss: 0.1328, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 46, Epoch: 105, Loss: 0.1127, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 106, Loss: 0.1580, Val Acc: 0.7531, Test Acc: 0.6890
# Seed: 46, Epoch: 107, Loss: 0.1281, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 108, Loss: 0.1409, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 109, Loss: 0.1510, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 46, Epoch: 110, Loss: 0.1368, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 46, Epoch: 111, Loss: 0.1729, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 46, Epoch: 112, Loss: 0.1358, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 46, Epoch: 113, Loss: 0.1236, Val Acc: 0.6914, Test Acc: 0.6524
# Seed: 46, Epoch: 114, Loss: 0.1043, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 46, Epoch: 115, Loss: 0.1131, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 46, Epoch: 116, Loss: 0.1486, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 46, Epoch: 117, Loss: 0.1261, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 46, Epoch: 118, Loss: 0.1610, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 46, Epoch: 119, Loss: 0.1272, Val Acc: 0.6605, Test Acc: 0.5610
# Seed: 46, Epoch: 120, Loss: 0.1495, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 46, Epoch: 121, Loss: 0.1097, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 46, Epoch: 122, Loss: 0.1010, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 46, Epoch: 123, Loss: 0.1029, Val Acc: 0.7284, Test Acc: 0.6829
# Seed: 46, Epoch: 124, Loss: 0.0881, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 125, Loss: 0.0959, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 46, Epoch: 126, Loss: 0.0817, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 127, Loss: 0.0755, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 46, Epoch: 128, Loss: 0.0744, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 46, Epoch: 129, Loss: 0.0749, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 46, Epoch: 130, Loss: 0.0506, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 131, Loss: 0.0522, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 46, Epoch: 132, Loss: 0.0509, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 46, Epoch: 133, Loss: 0.0757, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 46, Epoch: 134, Loss: 0.0578, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 46, Epoch: 135, Loss: 0.0664, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 136, Loss: 0.0351, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 137, Loss: 0.0627, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 46, Epoch: 138, Loss: 0.0466, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 46, Epoch: 139, Loss: 0.0462, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 46, Epoch: 140, Loss: 0.0832, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 141, Loss: 0.0454, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 46, Epoch: 142, Loss: 0.0423, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 46, Epoch: 143, Loss: 0.0722, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 46, Epoch: 144, Loss: 0.0606, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 46, Epoch: 145, Loss: 0.0744, Val Acc: 0.6358, Test Acc: 0.6220
# Seed: 46, Epoch: 146, Loss: 0.0686, Val Acc: 0.6852, Test Acc: 0.6098
# Seed: 46, Epoch: 147, Loss: 0.0652, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 46, Epoch: 148, Loss: 0.0476, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 46, Epoch: 149, Loss: 0.0837, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 46, Epoch: 150, Loss: 0.0486, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 151, Loss: 0.0786, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 152, Loss: 0.0553, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 46, Epoch: 153, Loss: 0.0631, Val Acc: 0.7222, Test Acc: 0.7866
# Seed: 46, Epoch: 154, Loss: 0.0363, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 46, Epoch: 155, Loss: 0.0518, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 46, Epoch: 156, Loss: 0.0387, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 46, Epoch: 157, Loss: 0.0528, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 46, Epoch: 158, Loss: 0.0463, Val Acc: 0.7222, Test Acc: 0.7134
# Seed: 46, Epoch: 159, Loss: 0.0396, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 46, Epoch: 160, Loss: 0.0417, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 46, Epoch: 161, Loss: 0.0658, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 46, Epoch: 162, Loss: 0.0714, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 46, Epoch: 163, Loss: 0.0584, Val Acc: 0.7284, Test Acc: 0.6768
# Seed: 46, Epoch: 164, Loss: 0.0867, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 165, Loss: 0.0731, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 46, Epoch: 166, Loss: 0.0701, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 46, Epoch: 167, Loss: 0.0667, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 46, Epoch: 168, Loss: 0.0502, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 46, Epoch: 169, Loss: 0.0554, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 46, Epoch: 170, Loss: 0.0650, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 46, Epoch: 171, Loss: 0.0839, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 172, Loss: 0.0529, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 173, Loss: 0.0786, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 46, Epoch: 174, Loss: 0.0486, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 46, Epoch: 175, Loss: 0.0650, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 46, Epoch: 176, Loss: 0.0904, Val Acc: 0.5864, Test Acc: 0.5549
# Seed: 46, Epoch: 177, Loss: 0.0746, Val Acc: 0.5617, Test Acc: 0.5122
# Seed: 46, Epoch: 178, Loss: 0.0839, Val Acc: 0.6667, Test Acc: 0.5732
# Seed: 46, Epoch: 179, Loss: 0.0869, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 46, Epoch: 180, Loss: 0.0503, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 46, Epoch: 181, Loss: 0.0559, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 46, Epoch: 182, Loss: 0.0520, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 46, Epoch: 183, Loss: 0.0560, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 184, Loss: 0.0358, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 185, Loss: 0.0444, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 46, Epoch: 186, Loss: 0.0367, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 187, Loss: 0.0517, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 46, Epoch: 188, Loss: 0.0369, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 46, Epoch: 189, Loss: 0.0211, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 190, Loss: 0.0208, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 46, Epoch: 191, Loss: 0.0201, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 192, Loss: 0.0409, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 46, Epoch: 193, Loss: 0.0175, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 46, Epoch: 194, Loss: 0.0160, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 46, Epoch: 195, Loss: 0.0275, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 196, Loss: 0.0202, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 46, Epoch: 197, Loss: 0.0115, Val Acc: 0.7160, Test Acc: 0.7805
# Seed: 46, Epoch: 198, Loss: 0.0202, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 46, Epoch: 199, Loss: 0.0217, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 46, Epoch: 200, Loss: 0.0137, Val Acc: 0.7160, Test Acc: 0.7500
# Average Time: 45.02 seconds
# Var Time: 11.69 seconds
# Average Memory: 806.00 MB
# Average Best Val Acc: 0.7716
# Std Best Test Acc: 0.0200
# Average Test Acc: 0.7317

# %% [markdown]
# ## Dense JustBalancePooling with HierarchicalGCN (2023)

# %%
import torch

EPS = 1e-15


def just_balance_pool(x, adj, s, mask=None, normalize=True):
    r"""The Just Balance pooling operator from the `"Simplifying Clustering with
    Graph Neural Networks" <https://arxiv.org/abs/2207.08779>`_ paper

    .. math::
        \mathbf{X}^{\prime} &= {\mathrm{softmax}(\mathbf{S})}^{\top} \cdot
        \mathbf{X}

        \mathbf{A}^{\prime} &= {\mathrm{softmax}(\mathbf{S})}^{\top} \cdot
        \mathbf{A} \cdot \mathrm{softmax}(\mathbf{S})

    based on dense learned assignments :math:`\mathbf{S} \in \mathbb{R}^{B
    \times N \times C}`.
    Returns the pooled node feature matrix, the coarsened and symmetrically
    normalized adjacency matrix and the following auxiliary objective:

    .. math::
        \mathcal{L} = - {\mathrm{Tr}(\sqrt{\mathbf{S}^{\top} \mathbf{S}})}

    Args:
        x (Tensor): Node feature tensor :math:`\mathbf{X} \in \mathbb{R}^{B \times N \times F}`
            with batch-size :math:`B`, (maximum) number of nodes :math:`N`
            for each graph, and feature dimension :math:`F`.
        adj (Tensor): Symmetrically normalized adjacency tensor
            :math:`\mathbf{A} \in \mathbb{R}^{B \times N \times N}`.
        s (Tensor): Assignment tensor :math:`\mathbf{S} \in \mathbb{R}^{B \times N \times C}`
            with number of clusters :math:`C`. The softmax does not have to be
            applied beforehand, since it is executed within this method.
        mask (BoolTensor, optional): Mask matrix
            :math:`\mathbf{M} \in {\{ 0, 1 \}}^{B \times N}` indicating
            the valid nodes for each graph. (default: :obj:`None`)

    :rtype: (:class:`Tensor`, :class:`Tensor`, :class:`Tensor`,
        :class:`Tensor`)
    """

    x = x.unsqueeze(0) if x.dim() == 2 else x
    adj = adj.unsqueeze(0) if adj.dim() == 2 else adj
    s = s.unsqueeze(0) if s.dim() == 2 else s

    (batch_size, num_nodes, _), k = x.size(), s.size(-1)

    s = torch.softmax(s, dim=-1)

    if mask is not None:
        mask = mask.view(batch_size, num_nodes, 1).to(x.dtype)
        x, s = x * mask, s * mask

    out = torch.matmul(s.transpose(1, 2), x)
    out_adj = torch.matmul(torch.matmul(s.transpose(1, 2), adj), s)

    # Loss
    ss = torch.matmul(s.transpose(1, 2), s)
    ss_sqrt = torch.sqrt(ss + EPS)
    loss = torch.mean(-_rank3_trace(ss_sqrt))
    if normalize:
        loss = loss / torch.sqrt(torch.tensor(num_nodes * k))

    # Fix and normalize coarsened adjacency matrix.
    ind = torch.arange(k, device=out_adj.device)
    out_adj[:, ind, ind] = 0
    d = torch.einsum('ijk->ij', out_adj)
    d = torch.sqrt(d)[:, None] + EPS
    out_adj = (out_adj / d) / d.transpose(1, 2)

    return out, out_adj, loss


def _rank3_trace(x):
    return torch.einsum('ijj->i', x)

# %%
import os.path as osp
import time
from math import ceil

import torch
import torch.nn.functional as F

import torch_geometric.transforms as T
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DenseDataLoader
from torch_geometric.nn import DenseSAGEConv, dense_diff_pool

dataset = dataset_PROTEINS
dataset = dataset.shuffle()

class GNN(torch.nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, normalize=False, lin=True):
        super().__init__()

        self.conv1 = DenseSAGEConv(in_channels, hidden_channels, normalize)
        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv2 = DenseSAGEConv(hidden_channels, hidden_channels, normalize)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.conv3 = DenseSAGEConv(hidden_channels, out_channels, normalize)
        self.bn3 = torch.nn.BatchNorm1d(out_channels)

        if lin:
            self.lin = torch.nn.Linear(out_channels, out_channels)
        else:
            self.lin = None

    def bn(self, i, x):
        batch_size, num_nodes, num_channels = x.size()
        x = x.view(-1, num_channels)
        x = getattr(self, f'bn{i}')(x)
        x = x.view(batch_size, num_nodes, num_channels)
        return x

    def forward(self, x, adj, mask=None):
        x = self.bn(1, self.conv1(x, adj, mask).relu())
        x = self.bn(2, self.conv2(x, adj, mask).relu())
        x = self.bn(3, self.conv3(x, adj, mask).relu())

        if self.lin is not None:
            x = self.lin(x).relu()

        return x


class Net_JustBalance(torch.nn.Module):
    def __init__(self):
        super().__init__()

        num_nodes = 64
        self.gnn1_pool = GNN(dataset.num_features, 64, num_nodes)

        num_nodes = 64
        self.gnn2_pool = GNN(64, 64, num_nodes)

        self.gnn1_embed = DenseSAGEConv(dataset.num_features, 64)
        self.gnn2_embed = DenseSAGEConv(64, 64)
        self.gnn3_embed = DenseSAGEConv(64, 64)

        self.lin1 = torch.nn.Linear(64, 32)
        self.lin2 = torch.nn.Linear(32, dataset.num_classes)

    def forward(self, x, adj, mask=None):
        s = self.gnn1_pool(x, adj, mask)
        x = self.gnn1_embed(x, adj, mask)
        x = F.relu(x)

        x, adj, b_loss = just_balance_pool(x, adj, s)

        s = self.gnn2_pool(x, adj)
        x = self.gnn2_embed(x, adj)
        x = F.relu(x)

        x, adj, b_loss = just_balance_pool(x, adj, s)

        x = self.gnn3_embed(x, adj)
        x = F.relu(x)

        x = x.mean(dim=1)
        x = self.lin1(x).relu()
        x = self.lin2(x)
        output = F.log_softmax(x, dim=-1)
        #print(f"Model output shape: {output.shape}")
        return output

if torch.cuda.is_available():
    device = torch.device('cuda')
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available():
    device = torch.device('mps')
else:
    device = torch.device('cpu')

model = Net_JustBalance().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

def train():
    model.train()
    total_loss = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x, data.adj, data.mask)
        loss = F.nll_loss(output, data.y.view(-1))
        loss.backward()
        total_loss += data.y.size(0) * float(loss)
        optimizer.step()
    return total_loss / len(train_loader.dataset)

def test(loader):
    model.eval()
    correct = 0
    for data in loader:
        data = data.to(device)
        output = model(data.x, data.adj, data.mask)
        pred = output.max(dim=1)[1]
        correct += int(pred.eq(data.y.view(-1)).sum())
    return correct / len(loader.dataset)


def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seeds = [42, 43, 44, 45, 46]
times = []
memories = []
best_val_accs = []
best_test_accs = []

early_stop_patience = 150
tolerance = 0.0001

for seed in seeds:
    set_seed(seed)
    model = Net_JustBalance().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

    start_time = time.time()

    best_val_acc = 0
    epochs_no_improve = 0

    for epoch in range(1, 201):
        loss = train()
        val_acc = test(valid_loader)
        test_acc = test(test_loader)
        if val_acc > best_val_acc + tolerance:
            best_val_acc = val_acc
            best_test_acc = test_acc
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        print(f'Seed: {seed}, Epoch: {epoch:03d}, Loss: {loss:.4f}, Val Acc: {val_acc:.4f}, Test Acc: {test_acc:.4f}')

        if epochs_no_improve >= early_stop_patience:
            print(f'Early stopping at epoch {epoch} for seed {seed}')
            break

    end_time = time.time()
    total_time = end_time - start_time
    memory_allocated = torch.cuda.memory_reserved(device) / (1024 ** 2)  # Convert to MB

    times.append(total_time)
    memories.append(memory_allocated)
    best_val_accs.append(best_val_acc)
    best_test_accs.append(best_test_acc)

    torch.cuda.empty_cache()

print(f'Average Time: {np.mean(times):.2f} seconds')
print(f'Var Time: {np.var(times):.2f} seconds')
print(f'Average Memory: {np.mean(memories):.2f} MB')
print(f'Average Best Val Acc: {np.mean(best_val_accs):.4f}')
print(f'Std Best Test Acc: {np.std(best_test_accs):.4f}')
print(f'Average Test Acc: {np.mean(best_test_accs):.4f}')
# Out:
# Seed: 42, Epoch: 001, Loss: 0.6501, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 002, Loss: 0.6396, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 003, Loss: 0.6307, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 004, Loss: 0.6245, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 005, Loss: 0.6172, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 006, Loss: 0.6084, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 42, Epoch: 007, Loss: 0.5985, Val Acc: 0.6790, Test Acc: 0.6280
# Seed: 42, Epoch: 008, Loss: 0.5889, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 42, Epoch: 009, Loss: 0.5787, Val Acc: 0.7407, Test Acc: 0.6890
# Seed: 42, Epoch: 010, Loss: 0.5706, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 42, Epoch: 011, Loss: 0.5584, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 42, Epoch: 012, Loss: 0.5512, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 42, Epoch: 013, Loss: 0.5494, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 42, Epoch: 014, Loss: 0.5408, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 015, Loss: 0.5416, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 42, Epoch: 016, Loss: 0.5207, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 42, Epoch: 017, Loss: 0.5156, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 018, Loss: 0.5169, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 019, Loss: 0.4956, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 42, Epoch: 020, Loss: 0.4891, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 42, Epoch: 021, Loss: 0.4794, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 42, Epoch: 022, Loss: 0.4813, Val Acc: 0.5926, Test Acc: 0.7012
# Seed: 42, Epoch: 023, Loss: 0.4876, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 024, Loss: 0.4936, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 42, Epoch: 025, Loss: 0.4808, Val Acc: 0.6111, Test Acc: 0.6890
# Seed: 42, Epoch: 026, Loss: 0.4740, Val Acc: 0.6543, Test Acc: 0.7134
# Seed: 42, Epoch: 027, Loss: 0.4579, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 42, Epoch: 028, Loss: 0.4441, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 42, Epoch: 029, Loss: 0.4455, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 030, Loss: 0.4385, Val Acc: 0.6975, Test Acc: 0.7561
# Seed: 42, Epoch: 031, Loss: 0.4424, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 42, Epoch: 032, Loss: 0.4235, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 42, Epoch: 033, Loss: 0.4266, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 42, Epoch: 034, Loss: 0.4263, Val Acc: 0.5617, Test Acc: 0.6585
# Seed: 42, Epoch: 035, Loss: 0.4341, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 42, Epoch: 036, Loss: 0.4449, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 037, Loss: 0.4265, Val Acc: 0.6235, Test Acc: 0.6585
# Seed: 42, Epoch: 038, Loss: 0.4210, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 42, Epoch: 039, Loss: 0.4435, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 42, Epoch: 040, Loss: 0.4122, Val Acc: 0.5988, Test Acc: 0.6341
# Seed: 42, Epoch: 041, Loss: 0.4167, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 42, Epoch: 042, Loss: 0.4076, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 043, Loss: 0.3899, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 42, Epoch: 044, Loss: 0.3948, Val Acc: 0.7099, Test Acc: 0.7500
# Seed: 42, Epoch: 045, Loss: 0.3914, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 42, Epoch: 046, Loss: 0.3922, Val Acc: 0.7037, Test Acc: 0.7561
# Seed: 42, Epoch: 047, Loss: 0.3752, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 42, Epoch: 048, Loss: 0.3639, Val Acc: 0.7222, Test Acc: 0.7866
# Seed: 42, Epoch: 049, Loss: 0.3655, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 42, Epoch: 050, Loss: 0.3823, Val Acc: 0.7222, Test Acc: 0.7744
# Seed: 42, Epoch: 051, Loss: 0.3542, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 42, Epoch: 052, Loss: 0.3562, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 42, Epoch: 053, Loss: 0.3497, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 42, Epoch: 054, Loss: 0.3454, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 42, Epoch: 055, Loss: 0.3458, Val Acc: 0.7222, Test Acc: 0.7805
# Seed: 42, Epoch: 056, Loss: 0.3420, Val Acc: 0.6914, Test Acc: 0.7500
# Seed: 42, Epoch: 057, Loss: 0.3703, Val Acc: 0.7099, Test Acc: 0.7683
# Seed: 42, Epoch: 058, Loss: 0.3566, Val Acc: 0.6358, Test Acc: 0.7134
# Seed: 42, Epoch: 059, Loss: 0.3320, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 060, Loss: 0.3462, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 061, Loss: 0.3263, Val Acc: 0.6605, Test Acc: 0.7195
# Seed: 42, Epoch: 062, Loss: 0.3347, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 42, Epoch: 063, Loss: 0.3244, Val Acc: 0.6358, Test Acc: 0.7012
# Seed: 42, Epoch: 064, Loss: 0.3217, Val Acc: 0.7099, Test Acc: 0.7195
# Seed: 42, Epoch: 065, Loss: 0.3308, Val Acc: 0.6235, Test Acc: 0.7134
# Seed: 42, Epoch: 066, Loss: 0.3338, Val Acc: 0.6852, Test Acc: 0.7622
# Seed: 42, Epoch: 067, Loss: 0.3161, Val Acc: 0.7222, Test Acc: 0.7683
# Seed: 42, Epoch: 068, Loss: 0.3510, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 42, Epoch: 069, Loss: 0.3242, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 42, Epoch: 070, Loss: 0.3036, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 42, Epoch: 071, Loss: 0.2965, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 42, Epoch: 072, Loss: 0.2824, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 073, Loss: 0.2953, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 42, Epoch: 074, Loss: 0.3065, Val Acc: 0.7099, Test Acc: 0.7744
# Seed: 42, Epoch: 075, Loss: 0.3348, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 42, Epoch: 076, Loss: 0.3286, Val Acc: 0.5802, Test Acc: 0.6463
# Seed: 42, Epoch: 077, Loss: 0.3606, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 42, Epoch: 078, Loss: 0.3528, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 079, Loss: 0.3200, Val Acc: 0.6173, Test Acc: 0.6646
# Seed: 42, Epoch: 080, Loss: 0.3150, Val Acc: 0.7160, Test Acc: 0.7195
# Seed: 42, Epoch: 081, Loss: 0.3213, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 42, Epoch: 082, Loss: 0.3098, Val Acc: 0.6790, Test Acc: 0.7439
# Seed: 42, Epoch: 083, Loss: 0.2890, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 42, Epoch: 084, Loss: 0.2655, Val Acc: 0.6914, Test Acc: 0.7561
# Seed: 42, Epoch: 085, Loss: 0.2663, Val Acc: 0.6728, Test Acc: 0.7683
# Seed: 42, Epoch: 086, Loss: 0.2633, Val Acc: 0.7037, Test Acc: 0.7805
# Seed: 42, Epoch: 087, Loss: 0.2600, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 42, Epoch: 088, Loss: 0.2484, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 42, Epoch: 089, Loss: 0.2520, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 42, Epoch: 090, Loss: 0.2308, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 42, Epoch: 091, Loss: 0.2368, Val Acc: 0.6605, Test Acc: 0.7439
# Seed: 42, Epoch: 092, Loss: 0.2266, Val Acc: 0.6790, Test Acc: 0.7683
# Seed: 42, Epoch: 093, Loss: 0.2143, Val Acc: 0.6358, Test Acc: 0.7012
# Seed: 42, Epoch: 094, Loss: 0.2259, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 42, Epoch: 095, Loss: 0.2156, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 42, Epoch: 096, Loss: 0.2224, Val Acc: 0.6235, Test Acc: 0.7134
# Seed: 42, Epoch: 097, Loss: 0.2540, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 42, Epoch: 098, Loss: 0.3383, Val Acc: 0.6296, Test Acc: 0.7073
# Seed: 42, Epoch: 099, Loss: 0.2620, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 100, Loss: 0.2459, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 42, Epoch: 101, Loss: 0.2587, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 42, Epoch: 102, Loss: 0.2557, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 42, Epoch: 103, Loss: 0.2650, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 42, Epoch: 104, Loss: 0.2481, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 42, Epoch: 105, Loss: 0.2552, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 42, Epoch: 106, Loss: 0.2377, Val Acc: 0.6420, Test Acc: 0.7134
# Seed: 42, Epoch: 107, Loss: 0.2096, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 42, Epoch: 108, Loss: 0.2082, Val Acc: 0.6914, Test Acc: 0.7439
# Seed: 42, Epoch: 109, Loss: 0.2010, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 42, Epoch: 110, Loss: 0.1774, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 111, Loss: 0.1868, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 42, Epoch: 112, Loss: 0.1718, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 42, Epoch: 113, Loss: 0.1592, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 42, Epoch: 114, Loss: 0.1807, Val Acc: 0.6914, Test Acc: 0.7378
# Seed: 42, Epoch: 115, Loss: 0.1573, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 42, Epoch: 116, Loss: 0.1638, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 42, Epoch: 117, Loss: 0.1665, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 42, Epoch: 118, Loss: 0.1894, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 42, Epoch: 119, Loss: 0.1612, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 42, Epoch: 120, Loss: 0.1739, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 42, Epoch: 121, Loss: 0.1982, Val Acc: 0.6111, Test Acc: 0.6829
# Seed: 42, Epoch: 122, Loss: 0.1708, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 42, Epoch: 123, Loss: 0.1905, Val Acc: 0.6852, Test Acc: 0.6524
# Seed: 42, Epoch: 124, Loss: 0.1875, Val Acc: 0.6790, Test Acc: 0.7500
# Seed: 42, Epoch: 125, Loss: 0.1965, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 42, Epoch: 126, Loss: 0.1904, Val Acc: 0.6852, Test Acc: 0.6829
# Seed: 42, Epoch: 127, Loss: 0.1850, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 42, Epoch: 128, Loss: 0.1652, Val Acc: 0.6173, Test Acc: 0.6890
# Seed: 42, Epoch: 129, Loss: 0.1681, Val Acc: 0.6358, Test Acc: 0.7317
# Seed: 42, Epoch: 130, Loss: 0.1485, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 42, Epoch: 131, Loss: 0.1360, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 42, Epoch: 132, Loss: 0.1224, Val Acc: 0.7037, Test Acc: 0.7500
# Seed: 42, Epoch: 133, Loss: 0.1314, Val Acc: 0.6914, Test Acc: 0.7500
# Seed: 42, Epoch: 134, Loss: 0.1223, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 42, Epoch: 135, Loss: 0.1083, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 42, Epoch: 136, Loss: 0.1022, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 42, Epoch: 137, Loss: 0.1115, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 42, Epoch: 138, Loss: 0.0925, Val Acc: 0.6543, Test Acc: 0.7012
# Seed: 42, Epoch: 139, Loss: 0.1016, Val Acc: 0.7037, Test Acc: 0.7073
# Seed: 42, Epoch: 140, Loss: 0.1086, Val Acc: 0.6173, Test Acc: 0.6829
# Seed: 42, Epoch: 141, Loss: 0.1165, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 42, Epoch: 142, Loss: 0.1562, Val Acc: 0.5741, Test Acc: 0.6707
# Seed: 42, Epoch: 143, Loss: 0.2260, Val Acc: 0.7284, Test Acc: 0.6585
# Seed: 42, Epoch: 144, Loss: 0.3316, Val Acc: 0.6543, Test Acc: 0.7012
# Seed: 42, Epoch: 145, Loss: 0.3420, Val Acc: 0.5617, Test Acc: 0.6585
# Seed: 42, Epoch: 146, Loss: 0.3045, Val Acc: 0.6358, Test Acc: 0.5976
# Seed: 42, Epoch: 147, Loss: 0.2623, Val Acc: 0.6111, Test Acc: 0.5000
# Seed: 42, Epoch: 148, Loss: 0.2512, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 42, Epoch: 149, Loss: 0.2279, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 42, Epoch: 150, Loss: 0.2070, Val Acc: 0.5864, Test Acc: 0.6402
# Seed: 42, Epoch: 151, Loss: 0.2181, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 42, Epoch: 152, Loss: 0.1843, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 42, Epoch: 153, Loss: 0.1620, Val Acc: 0.6481, Test Acc: 0.6829
# Seed: 42, Epoch: 154, Loss: 0.1627, Val Acc: 0.6420, Test Acc: 0.7195
# Seed: 42, Epoch: 155, Loss: 0.1321, Val Acc: 0.6543, Test Acc: 0.7622
# Seed: 42, Epoch: 156, Loss: 0.1216, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 42, Epoch: 157, Loss: 0.1290, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 42, Epoch: 158, Loss: 0.1213, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 42, Epoch: 159, Loss: 0.1191, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 42, Epoch: 160, Loss: 0.1025, Val Acc: 0.6049, Test Acc: 0.7134
# Seed: 42, Epoch: 161, Loss: 0.0999, Val Acc: 0.6481, Test Acc: 0.7195
# Seed: 42, Epoch: 162, Loss: 0.0939, Val Acc: 0.6852, Test Acc: 0.7317
# Early stopping at epoch 162 for seed 42
# Seed: 43, Epoch: 001, Loss: 0.6685, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 002, Loss: 0.6281, Val Acc: 0.6358, Test Acc: 0.5610
# Seed: 43, Epoch: 003, Loss: 0.6210, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 43, Epoch: 004, Loss: 0.6115, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 43, Epoch: 005, Loss: 0.5969, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 43, Epoch: 006, Loss: 0.5879, Val Acc: 0.6728, Test Acc: 0.6159
# Seed: 43, Epoch: 007, Loss: 0.5841, Val Acc: 0.6728, Test Acc: 0.6220
# Seed: 43, Epoch: 008, Loss: 0.5699, Val Acc: 0.7037, Test Acc: 0.6341
# Seed: 43, Epoch: 009, Loss: 0.5784, Val Acc: 0.7099, Test Acc: 0.6646
# Seed: 43, Epoch: 010, Loss: 0.5591, Val Acc: 0.7099, Test Acc: 0.6463
# Seed: 43, Epoch: 011, Loss: 0.5659, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 012, Loss: 0.5434, Val Acc: 0.7284, Test Acc: 0.6524
# Seed: 43, Epoch: 013, Loss: 0.5448, Val Acc: 0.7407, Test Acc: 0.7256
# Seed: 43, Epoch: 014, Loss: 0.5263, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 43, Epoch: 015, Loss: 0.5180, Val Acc: 0.7593, Test Acc: 0.7134
# Seed: 43, Epoch: 016, Loss: 0.5029, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 017, Loss: 0.5006, Val Acc: 0.7593, Test Acc: 0.7195
# Seed: 43, Epoch: 018, Loss: 0.4830, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 43, Epoch: 019, Loss: 0.4865, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 43, Epoch: 020, Loss: 0.4858, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 43, Epoch: 021, Loss: 0.4950, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 022, Loss: 0.4761, Val Acc: 0.6852, Test Acc: 0.7561
# Seed: 43, Epoch: 023, Loss: 0.4707, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 43, Epoch: 024, Loss: 0.4758, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 43, Epoch: 025, Loss: 0.4699, Val Acc: 0.7531, Test Acc: 0.7622
# Seed: 43, Epoch: 026, Loss: 0.4571, Val Acc: 0.7531, Test Acc: 0.7256
# Seed: 43, Epoch: 027, Loss: 0.4612, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 028, Loss: 0.4585, Val Acc: 0.7840, Test Acc: 0.7500
# Seed: 43, Epoch: 029, Loss: 0.4473, Val Acc: 0.7901, Test Acc: 0.7317
# Seed: 43, Epoch: 030, Loss: 0.4397, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 43, Epoch: 031, Loss: 0.4431, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 43, Epoch: 032, Loss: 0.4448, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 033, Loss: 0.4280, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 43, Epoch: 034, Loss: 0.4325, Val Acc: 0.7963, Test Acc: 0.7073
# Seed: 43, Epoch: 035, Loss: 0.4188, Val Acc: 0.7901, Test Acc: 0.7256
# Seed: 43, Epoch: 036, Loss: 0.4258, Val Acc: 0.7840, Test Acc: 0.7500
# Seed: 43, Epoch: 037, Loss: 0.4062, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 43, Epoch: 038, Loss: 0.4173, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 43, Epoch: 039, Loss: 0.4002, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 040, Loss: 0.3996, Val Acc: 0.7716, Test Acc: 0.7378
# Seed: 43, Epoch: 041, Loss: 0.3950, Val Acc: 0.7716, Test Acc: 0.6951
# Seed: 43, Epoch: 042, Loss: 0.3947, Val Acc: 0.7840, Test Acc: 0.7500
# Seed: 43, Epoch: 043, Loss: 0.4007, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 43, Epoch: 044, Loss: 0.3934, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 045, Loss: 0.3940, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 046, Loss: 0.3883, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 43, Epoch: 047, Loss: 0.3914, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 43, Epoch: 048, Loss: 0.3893, Val Acc: 0.7654, Test Acc: 0.7256
# Seed: 43, Epoch: 049, Loss: 0.3672, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 43, Epoch: 050, Loss: 0.3706, Val Acc: 0.7716, Test Acc: 0.7439
# Seed: 43, Epoch: 051, Loss: 0.3741, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 43, Epoch: 052, Loss: 0.3769, Val Acc: 0.7037, Test Acc: 0.7561
# Seed: 43, Epoch: 053, Loss: 0.3821, Val Acc: 0.6790, Test Acc: 0.7500
# Seed: 43, Epoch: 054, Loss: 0.3708, Val Acc: 0.7099, Test Acc: 0.7500
# Seed: 43, Epoch: 055, Loss: 0.3675, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 43, Epoch: 056, Loss: 0.3499, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 43, Epoch: 057, Loss: 0.3282, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 43, Epoch: 058, Loss: 0.3488, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 43, Epoch: 059, Loss: 0.3448, Val Acc: 0.7654, Test Acc: 0.7256
# Seed: 43, Epoch: 060, Loss: 0.3235, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 43, Epoch: 061, Loss: 0.3332, Val Acc: 0.7593, Test Acc: 0.7439
# Seed: 43, Epoch: 062, Loss: 0.3216, Val Acc: 0.7407, Test Acc: 0.7317
# Seed: 43, Epoch: 063, Loss: 0.3314, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 43, Epoch: 064, Loss: 0.3115, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 43, Epoch: 065, Loss: 0.2985, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 43, Epoch: 066, Loss: 0.2957, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 43, Epoch: 067, Loss: 0.2863, Val Acc: 0.7222, Test Acc: 0.7561
# Seed: 43, Epoch: 068, Loss: 0.2896, Val Acc: 0.7160, Test Acc: 0.7622
# Seed: 43, Epoch: 069, Loss: 0.2825, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 43, Epoch: 070, Loss: 0.2844, Val Acc: 0.7037, Test Acc: 0.6829
# Seed: 43, Epoch: 071, Loss: 0.2965, Val Acc: 0.7654, Test Acc: 0.7195
# Seed: 43, Epoch: 072, Loss: 0.3059, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 43, Epoch: 073, Loss: 0.3172, Val Acc: 0.7407, Test Acc: 0.6890
# Seed: 43, Epoch: 074, Loss: 0.3088, Val Acc: 0.6852, Test Acc: 0.7195
# Seed: 43, Epoch: 075, Loss: 0.2831, Val Acc: 0.7593, Test Acc: 0.7256
# Seed: 43, Epoch: 076, Loss: 0.2753, Val Acc: 0.7778, Test Acc: 0.6951
# Seed: 43, Epoch: 077, Loss: 0.2816, Val Acc: 0.7407, Test Acc: 0.6646
# Seed: 43, Epoch: 078, Loss: 0.2760, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 43, Epoch: 079, Loss: 0.2581, Val Acc: 0.6728, Test Acc: 0.7256
# Seed: 43, Epoch: 080, Loss: 0.2688, Val Acc: 0.5926, Test Acc: 0.6768
# Seed: 43, Epoch: 081, Loss: 0.2843, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 43, Epoch: 082, Loss: 0.2914, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 43, Epoch: 083, Loss: 0.2698, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 43, Epoch: 084, Loss: 0.2582, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 43, Epoch: 085, Loss: 0.2709, Val Acc: 0.6975, Test Acc: 0.7439
# Seed: 43, Epoch: 086, Loss: 0.2485, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 43, Epoch: 087, Loss: 0.2560, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 43, Epoch: 088, Loss: 0.2455, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 43, Epoch: 089, Loss: 0.2454, Val Acc: 0.7284, Test Acc: 0.6646
# Seed: 43, Epoch: 090, Loss: 0.2343, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 43, Epoch: 091, Loss: 0.2682, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 43, Epoch: 092, Loss: 0.2512, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 43, Epoch: 093, Loss: 0.2369, Val Acc: 0.6975, Test Acc: 0.7439
# Seed: 43, Epoch: 094, Loss: 0.2358, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 43, Epoch: 095, Loss: 0.2220, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 096, Loss: 0.1996, Val Acc: 0.7469, Test Acc: 0.7256
# Seed: 43, Epoch: 097, Loss: 0.2119, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 43, Epoch: 098, Loss: 0.2093, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 43, Epoch: 099, Loss: 0.2106, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 43, Epoch: 100, Loss: 0.1938, Val Acc: 0.6049, Test Acc: 0.6341
# Seed: 43, Epoch: 101, Loss: 0.2022, Val Acc: 0.7654, Test Acc: 0.7073
# Seed: 43, Epoch: 102, Loss: 0.2102, Val Acc: 0.7407, Test Acc: 0.7012
# Seed: 43, Epoch: 103, Loss: 0.1824, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 43, Epoch: 104, Loss: 0.1777, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 43, Epoch: 105, Loss: 0.1874, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 43, Epoch: 106, Loss: 0.1844, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 43, Epoch: 107, Loss: 0.2056, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 43, Epoch: 108, Loss: 0.1885, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 43, Epoch: 109, Loss: 0.1807, Val Acc: 0.7778, Test Acc: 0.7317
# Seed: 43, Epoch: 110, Loss: 0.1721, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 43, Epoch: 111, Loss: 0.1704, Val Acc: 0.7901, Test Acc: 0.7073
# Seed: 43, Epoch: 112, Loss: 0.1786, Val Acc: 0.7778, Test Acc: 0.6829
# Seed: 43, Epoch: 113, Loss: 0.1676, Val Acc: 0.7593, Test Acc: 0.6890
# Seed: 43, Epoch: 114, Loss: 0.1665, Val Acc: 0.7346, Test Acc: 0.6951
# Seed: 43, Epoch: 115, Loss: 0.1645, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 43, Epoch: 116, Loss: 0.1864, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 43, Epoch: 117, Loss: 0.1713, Val Acc: 0.6728, Test Acc: 0.6341
# Seed: 43, Epoch: 118, Loss: 0.2140, Val Acc: 0.6975, Test Acc: 0.6585
# Seed: 43, Epoch: 119, Loss: 0.1879, Val Acc: 0.7531, Test Acc: 0.7195
# Seed: 43, Epoch: 120, Loss: 0.2018, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 43, Epoch: 121, Loss: 0.1980, Val Acc: 0.6481, Test Acc: 0.6463
# Seed: 43, Epoch: 122, Loss: 0.1882, Val Acc: 0.6481, Test Acc: 0.6585
# Seed: 43, Epoch: 123, Loss: 0.1671, Val Acc: 0.6728, Test Acc: 0.7378
# Seed: 43, Epoch: 124, Loss: 0.1611, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 43, Epoch: 125, Loss: 0.1506, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 43, Epoch: 126, Loss: 0.1365, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 43, Epoch: 127, Loss: 0.1393, Val Acc: 0.7593, Test Acc: 0.6646
# Seed: 43, Epoch: 128, Loss: 0.1445, Val Acc: 0.7778, Test Acc: 0.6829
# Seed: 43, Epoch: 129, Loss: 0.1464, Val Acc: 0.7531, Test Acc: 0.6951
# Seed: 43, Epoch: 130, Loss: 0.1390, Val Acc: 0.7222, Test Acc: 0.7073
# Seed: 43, Epoch: 131, Loss: 0.1571, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 43, Epoch: 132, Loss: 0.1699, Val Acc: 0.7901, Test Acc: 0.6829
# Seed: 43, Epoch: 133, Loss: 0.1258, Val Acc: 0.7593, Test Acc: 0.7195
# Seed: 43, Epoch: 134, Loss: 0.1256, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 43, Epoch: 135, Loss: 0.1375, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 43, Epoch: 136, Loss: 0.1246, Val Acc: 0.7469, Test Acc: 0.7073
# Seed: 43, Epoch: 137, Loss: 0.1331, Val Acc: 0.7346, Test Acc: 0.7073
# Seed: 43, Epoch: 138, Loss: 0.1118, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 43, Epoch: 139, Loss: 0.1251, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 43, Epoch: 140, Loss: 0.1240, Val Acc: 0.7407, Test Acc: 0.6707
# Seed: 43, Epoch: 141, Loss: 0.1302, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 43, Epoch: 142, Loss: 0.1208, Val Acc: 0.6605, Test Acc: 0.7073
# Seed: 43, Epoch: 143, Loss: 0.2012, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 43, Epoch: 144, Loss: 0.1599, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 43, Epoch: 145, Loss: 0.1441, Val Acc: 0.7346, Test Acc: 0.6768
# Seed: 43, Epoch: 146, Loss: 0.1357, Val Acc: 0.7654, Test Acc: 0.6890
# Seed: 43, Epoch: 147, Loss: 0.1465, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 43, Epoch: 148, Loss: 0.1228, Val Acc: 0.6975, Test Acc: 0.6829
# Seed: 43, Epoch: 149, Loss: 0.1398, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 43, Epoch: 150, Loss: 0.1195, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 43, Epoch: 151, Loss: 0.1478, Val Acc: 0.7160, Test Acc: 0.6829
# Seed: 43, Epoch: 152, Loss: 0.1271, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 43, Epoch: 153, Loss: 0.1261, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 43, Epoch: 154, Loss: 0.1113, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 43, Epoch: 155, Loss: 0.1116, Val Acc: 0.6790, Test Acc: 0.6768
# Seed: 43, Epoch: 156, Loss: 0.1228, Val Acc: 0.7346, Test Acc: 0.6829
# Seed: 43, Epoch: 157, Loss: 0.1113, Val Acc: 0.7716, Test Acc: 0.6463
# Seed: 43, Epoch: 158, Loss: 0.1267, Val Acc: 0.7593, Test Acc: 0.6951
# Seed: 43, Epoch: 159, Loss: 0.1084, Val Acc: 0.7654, Test Acc: 0.7378
# Seed: 43, Epoch: 160, Loss: 0.1151, Val Acc: 0.7407, Test Acc: 0.7134
# Seed: 43, Epoch: 161, Loss: 0.1096, Val Acc: 0.7037, Test Acc: 0.7439
# Seed: 43, Epoch: 162, Loss: 0.1068, Val Acc: 0.7099, Test Acc: 0.7561
# Seed: 43, Epoch: 163, Loss: 0.1135, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 43, Epoch: 164, Loss: 0.1167, Val Acc: 0.7840, Test Acc: 0.7012
# Seed: 43, Epoch: 165, Loss: 0.1239, Val Acc: 0.7531, Test Acc: 0.6829
# Seed: 43, Epoch: 166, Loss: 0.0938, Val Acc: 0.6975, Test Acc: 0.7134
# Seed: 43, Epoch: 167, Loss: 0.1197, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 43, Epoch: 168, Loss: 0.1215, Val Acc: 0.7284, Test Acc: 0.6402
# Seed: 43, Epoch: 169, Loss: 0.0945, Val Acc: 0.7037, Test Acc: 0.6585
# Seed: 43, Epoch: 170, Loss: 0.1000, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 43, Epoch: 171, Loss: 0.0979, Val Acc: 0.7284, Test Acc: 0.6829
# Seed: 43, Epoch: 172, Loss: 0.0945, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 43, Epoch: 173, Loss: 0.1200, Val Acc: 0.7099, Test Acc: 0.6524
# Seed: 43, Epoch: 174, Loss: 0.0983, Val Acc: 0.7469, Test Acc: 0.6951
# Seed: 43, Epoch: 175, Loss: 0.1025, Val Acc: 0.7469, Test Acc: 0.7012
# Seed: 43, Epoch: 176, Loss: 0.1042, Val Acc: 0.6852, Test Acc: 0.6646
# Seed: 43, Epoch: 177, Loss: 0.1304, Val Acc: 0.7654, Test Acc: 0.6951
# Seed: 43, Epoch: 178, Loss: 0.1089, Val Acc: 0.7407, Test Acc: 0.6829
# Seed: 43, Epoch: 179, Loss: 0.1197, Val Acc: 0.7531, Test Acc: 0.7134
# Seed: 43, Epoch: 180, Loss: 0.1182, Val Acc: 0.7407, Test Acc: 0.7012
# Seed: 43, Epoch: 181, Loss: 0.1147, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 43, Epoch: 182, Loss: 0.1277, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 43, Epoch: 183, Loss: 0.0820, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 43, Epoch: 184, Loss: 0.1256, Val Acc: 0.6975, Test Acc: 0.7134
# Early stopping at epoch 184 for seed 43
# Seed: 44, Epoch: 001, Loss: 0.6602, Val Acc: 0.6728, Test Acc: 0.6159
# Seed: 44, Epoch: 002, Loss: 0.6209, Val Acc: 0.6728, Test Acc: 0.6098
# Seed: 44, Epoch: 003, Loss: 0.6220, Val Acc: 0.6605, Test Acc: 0.6037
# Seed: 44, Epoch: 004, Loss: 0.6132, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 44, Epoch: 005, Loss: 0.6120, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 44, Epoch: 006, Loss: 0.6057, Val Acc: 0.6975, Test Acc: 0.6768
# Seed: 44, Epoch: 007, Loss: 0.6000, Val Acc: 0.7160, Test Acc: 0.6585
# Seed: 44, Epoch: 008, Loss: 0.5931, Val Acc: 0.7099, Test Acc: 0.6768
# Seed: 44, Epoch: 009, Loss: 0.5822, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 44, Epoch: 010, Loss: 0.5746, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 44, Epoch: 011, Loss: 0.5605, Val Acc: 0.6235, Test Acc: 0.6524
# Seed: 44, Epoch: 012, Loss: 0.5448, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 44, Epoch: 013, Loss: 0.5364, Val Acc: 0.6358, Test Acc: 0.6463
# Seed: 44, Epoch: 014, Loss: 0.5199, Val Acc: 0.6296, Test Acc: 0.6463
# Seed: 44, Epoch: 015, Loss: 0.5105, Val Acc: 0.6358, Test Acc: 0.6707
# Seed: 44, Epoch: 016, Loss: 0.5054, Val Acc: 0.6358, Test Acc: 0.6890
# Seed: 44, Epoch: 017, Loss: 0.4948, Val Acc: 0.6605, Test Acc: 0.6951
# Seed: 44, Epoch: 018, Loss: 0.4899, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 44, Epoch: 019, Loss: 0.4833, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 44, Epoch: 020, Loss: 0.4734, Val Acc: 0.6481, Test Acc: 0.7073
# Seed: 44, Epoch: 021, Loss: 0.4662, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 44, Epoch: 022, Loss: 0.4583, Val Acc: 0.6790, Test Acc: 0.7073
# Seed: 44, Epoch: 023, Loss: 0.4534, Val Acc: 0.7037, Test Acc: 0.7012
# Seed: 44, Epoch: 024, Loss: 0.4544, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 44, Epoch: 025, Loss: 0.4617, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 44, Epoch: 026, Loss: 0.4658, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 44, Epoch: 027, Loss: 0.4514, Val Acc: 0.7222, Test Acc: 0.7744
# Seed: 44, Epoch: 028, Loss: 0.4549, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 44, Epoch: 029, Loss: 0.4366, Val Acc: 0.7037, Test Acc: 0.7195
# Seed: 44, Epoch: 030, Loss: 0.4438, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 44, Epoch: 031, Loss: 0.4488, Val Acc: 0.6914, Test Acc: 0.7012
# Seed: 44, Epoch: 032, Loss: 0.4271, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 44, Epoch: 033, Loss: 0.4158, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 44, Epoch: 034, Loss: 0.4213, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 44, Epoch: 035, Loss: 0.4043, Val Acc: 0.7099, Test Acc: 0.7805
# Seed: 44, Epoch: 036, Loss: 0.3856, Val Acc: 0.7284, Test Acc: 0.7683
# Seed: 44, Epoch: 037, Loss: 0.4076, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 44, Epoch: 038, Loss: 0.3865, Val Acc: 0.6852, Test Acc: 0.7439
# Seed: 44, Epoch: 039, Loss: 0.4085, Val Acc: 0.6481, Test Acc: 0.7378
# Seed: 44, Epoch: 040, Loss: 0.3798, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 44, Epoch: 041, Loss: 0.3629, Val Acc: 0.6975, Test Acc: 0.7683
# Seed: 44, Epoch: 042, Loss: 0.3679, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 44, Epoch: 043, Loss: 0.3657, Val Acc: 0.6975, Test Acc: 0.7256
# Seed: 44, Epoch: 044, Loss: 0.3557, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 44, Epoch: 045, Loss: 0.3476, Val Acc: 0.6543, Test Acc: 0.7256
# Seed: 44, Epoch: 046, Loss: 0.3708, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 44, Epoch: 047, Loss: 0.3797, Val Acc: 0.6975, Test Acc: 0.7439
# Seed: 44, Epoch: 048, Loss: 0.3673, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 44, Epoch: 049, Loss: 0.3596, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 44, Epoch: 050, Loss: 0.3892, Val Acc: 0.7284, Test Acc: 0.7622
# Seed: 44, Epoch: 051, Loss: 0.3628, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 44, Epoch: 052, Loss: 0.3583, Val Acc: 0.6235, Test Acc: 0.6768
# Seed: 44, Epoch: 053, Loss: 0.3813, Val Acc: 0.6543, Test Acc: 0.6585
# Seed: 44, Epoch: 054, Loss: 0.3758, Val Acc: 0.6975, Test Acc: 0.7683
# Seed: 44, Epoch: 055, Loss: 0.3660, Val Acc: 0.6667, Test Acc: 0.7256
# Seed: 44, Epoch: 056, Loss: 0.3326, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 44, Epoch: 057, Loss: 0.3275, Val Acc: 0.6728, Test Acc: 0.7561
# Seed: 44, Epoch: 058, Loss: 0.3088, Val Acc: 0.6358, Test Acc: 0.6524
# Seed: 44, Epoch: 059, Loss: 0.3297, Val Acc: 0.6914, Test Acc: 0.7378
# Seed: 44, Epoch: 060, Loss: 0.2953, Val Acc: 0.6235, Test Acc: 0.6768
# Seed: 44, Epoch: 061, Loss: 0.2948, Val Acc: 0.6481, Test Acc: 0.6951
# Seed: 44, Epoch: 062, Loss: 0.3457, Val Acc: 0.6235, Test Acc: 0.6768
# Seed: 44, Epoch: 063, Loss: 0.3133, Val Acc: 0.6852, Test Acc: 0.7317
# Seed: 44, Epoch: 064, Loss: 0.3071, Val Acc: 0.6543, Test Acc: 0.6707
# Seed: 44, Epoch: 065, Loss: 0.2945, Val Acc: 0.6728, Test Acc: 0.6585
# Seed: 44, Epoch: 066, Loss: 0.3062, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 44, Epoch: 067, Loss: 0.2926, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 44, Epoch: 068, Loss: 0.2717, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 44, Epoch: 069, Loss: 0.2742, Val Acc: 0.5988, Test Acc: 0.6524
# Seed: 44, Epoch: 070, Loss: 0.3434, Val Acc: 0.6728, Test Acc: 0.6220
# Seed: 44, Epoch: 071, Loss: 0.3167, Val Acc: 0.5802, Test Acc: 0.5244
# Seed: 44, Epoch: 072, Loss: 0.3122, Val Acc: 0.5741, Test Acc: 0.5305
# Seed: 44, Epoch: 073, Loss: 0.2853, Val Acc: 0.6049, Test Acc: 0.6524
# Seed: 44, Epoch: 074, Loss: 0.2763, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 44, Epoch: 075, Loss: 0.2700, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 44, Epoch: 076, Loss: 0.2707, Val Acc: 0.6975, Test Acc: 0.7439
# Seed: 44, Epoch: 077, Loss: 0.2414, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 44, Epoch: 078, Loss: 0.2323, Val Acc: 0.6420, Test Acc: 0.5915
# Seed: 44, Epoch: 079, Loss: 0.2177, Val Acc: 0.6667, Test Acc: 0.6768
# Seed: 44, Epoch: 080, Loss: 0.2285, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 44, Epoch: 081, Loss: 0.2336, Val Acc: 0.6481, Test Acc: 0.6159
# Seed: 44, Epoch: 082, Loss: 0.2327, Val Acc: 0.6173, Test Acc: 0.6402
# Seed: 44, Epoch: 083, Loss: 0.2354, Val Acc: 0.6790, Test Acc: 0.6646
# Seed: 44, Epoch: 084, Loss: 0.2275, Val Acc: 0.6728, Test Acc: 0.7134
# Seed: 44, Epoch: 085, Loss: 0.1884, Val Acc: 0.6358, Test Acc: 0.6646
# Seed: 44, Epoch: 086, Loss: 0.2191, Val Acc: 0.6914, Test Acc: 0.6524
# Seed: 44, Epoch: 087, Loss: 0.1782, Val Acc: 0.6975, Test Acc: 0.6951
# Seed: 44, Epoch: 088, Loss: 0.2079, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 44, Epoch: 089, Loss: 0.1679, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 44, Epoch: 090, Loss: 0.1842, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 44, Epoch: 091, Loss: 0.1767, Val Acc: 0.6420, Test Acc: 0.7134
# Seed: 44, Epoch: 092, Loss: 0.1870, Val Acc: 0.6605, Test Acc: 0.7012
# Seed: 44, Epoch: 093, Loss: 0.1686, Val Acc: 0.6605, Test Acc: 0.6585
# Seed: 44, Epoch: 094, Loss: 0.1753, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 44, Epoch: 095, Loss: 0.1865, Val Acc: 0.6296, Test Acc: 0.6585
# Seed: 44, Epoch: 096, Loss: 0.2123, Val Acc: 0.6358, Test Acc: 0.6524
# Seed: 44, Epoch: 097, Loss: 0.2312, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 44, Epoch: 098, Loss: 0.1859, Val Acc: 0.7037, Test Acc: 0.6463
# Seed: 44, Epoch: 099, Loss: 0.1624, Val Acc: 0.6975, Test Acc: 0.6463
# Seed: 44, Epoch: 100, Loss: 0.1532, Val Acc: 0.6728, Test Acc: 0.6707
# Seed: 44, Epoch: 101, Loss: 0.1751, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 44, Epoch: 102, Loss: 0.1750, Val Acc: 0.6543, Test Acc: 0.6646
# Seed: 44, Epoch: 103, Loss: 0.1677, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 44, Epoch: 104, Loss: 0.2252, Val Acc: 0.6852, Test Acc: 0.6768
# Seed: 44, Epoch: 105, Loss: 0.1707, Val Acc: 0.7037, Test Acc: 0.6280
# Seed: 44, Epoch: 106, Loss: 0.1689, Val Acc: 0.6049, Test Acc: 0.5610
# Seed: 44, Epoch: 107, Loss: 0.1540, Val Acc: 0.5432, Test Acc: 0.5854
# Seed: 44, Epoch: 108, Loss: 0.1521, Val Acc: 0.6605, Test Acc: 0.6280
# Seed: 44, Epoch: 109, Loss: 0.1574, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 44, Epoch: 110, Loss: 0.1328, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 44, Epoch: 111, Loss: 0.1271, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 44, Epoch: 112, Loss: 0.1565, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 44, Epoch: 113, Loss: 0.1462, Val Acc: 0.6543, Test Acc: 0.6280
# Seed: 44, Epoch: 114, Loss: 0.1220, Val Acc: 0.6728, Test Acc: 0.6280
# Seed: 44, Epoch: 115, Loss: 0.1688, Val Acc: 0.6481, Test Acc: 0.6646
# Seed: 44, Epoch: 116, Loss: 0.2000, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 44, Epoch: 117, Loss: 0.2227, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 44, Epoch: 118, Loss: 0.1978, Val Acc: 0.5864, Test Acc: 0.6402
# Seed: 44, Epoch: 119, Loss: 0.1956, Val Acc: 0.6358, Test Acc: 0.6707
# Seed: 44, Epoch: 120, Loss: 0.1872, Val Acc: 0.6543, Test Acc: 0.6159
# Seed: 44, Epoch: 121, Loss: 0.1462, Val Acc: 0.6605, Test Acc: 0.6463
# Seed: 44, Epoch: 122, Loss: 0.1310, Val Acc: 0.6420, Test Acc: 0.7134
# Seed: 44, Epoch: 123, Loss: 0.1071, Val Acc: 0.6296, Test Acc: 0.7256
# Seed: 44, Epoch: 124, Loss: 0.1013, Val Acc: 0.6358, Test Acc: 0.7195
# Seed: 44, Epoch: 125, Loss: 0.1186, Val Acc: 0.6543, Test Acc: 0.6585
# Seed: 44, Epoch: 126, Loss: 0.1134, Val Acc: 0.6481, Test Acc: 0.6098
# Seed: 44, Epoch: 127, Loss: 0.1081, Val Acc: 0.6728, Test Acc: 0.6280
# Seed: 44, Epoch: 128, Loss: 0.0877, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 44, Epoch: 129, Loss: 0.0909, Val Acc: 0.6420, Test Acc: 0.6707
# Seed: 44, Epoch: 130, Loss: 0.1027, Val Acc: 0.6667, Test Acc: 0.6220
# Seed: 44, Epoch: 131, Loss: 0.1030, Val Acc: 0.6049, Test Acc: 0.5976
# Seed: 44, Epoch: 132, Loss: 0.0914, Val Acc: 0.6481, Test Acc: 0.5976
# Seed: 44, Epoch: 133, Loss: 0.1188, Val Acc: 0.6852, Test Acc: 0.6280
# Seed: 44, Epoch: 134, Loss: 0.0829, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 44, Epoch: 135, Loss: 0.1390, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 44, Epoch: 136, Loss: 0.1332, Val Acc: 0.6358, Test Acc: 0.6280
# Seed: 44, Epoch: 137, Loss: 0.1424, Val Acc: 0.6728, Test Acc: 0.6829
# Seed: 44, Epoch: 138, Loss: 0.1490, Val Acc: 0.6358, Test Acc: 0.7134
# Seed: 44, Epoch: 139, Loss: 0.1407, Val Acc: 0.5617, Test Acc: 0.6037
# Seed: 44, Epoch: 140, Loss: 0.1176, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 44, Epoch: 141, Loss: 0.1069, Val Acc: 0.6296, Test Acc: 0.6524
# Seed: 44, Epoch: 142, Loss: 0.1011, Val Acc: 0.5926, Test Acc: 0.5915
# Seed: 44, Epoch: 143, Loss: 0.1116, Val Acc: 0.6728, Test Acc: 0.6707
# Seed: 44, Epoch: 144, Loss: 0.0970, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 44, Epoch: 145, Loss: 0.1408, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 44, Epoch: 146, Loss: 0.0908, Val Acc: 0.6914, Test Acc: 0.6402
# Seed: 44, Epoch: 147, Loss: 0.0826, Val Acc: 0.6914, Test Acc: 0.6220
# Seed: 44, Epoch: 148, Loss: 0.0716, Val Acc: 0.6790, Test Acc: 0.6585
# Seed: 44, Epoch: 149, Loss: 0.0900, Val Acc: 0.6852, Test Acc: 0.6646
# Seed: 44, Epoch: 150, Loss: 0.0780, Val Acc: 0.6605, Test Acc: 0.6341
# Seed: 44, Epoch: 151, Loss: 0.1072, Val Acc: 0.6852, Test Acc: 0.5732
# Seed: 44, Epoch: 152, Loss: 0.1287, Val Acc: 0.6543, Test Acc: 0.6098
# Seed: 44, Epoch: 153, Loss: 0.0704, Val Acc: 0.5988, Test Acc: 0.6585
# Seed: 44, Epoch: 154, Loss: 0.1064, Val Acc: 0.6667, Test Acc: 0.6951
# Seed: 44, Epoch: 155, Loss: 0.1203, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 44, Epoch: 156, Loss: 0.1633, Val Acc: 0.7222, Test Acc: 0.6463
# Seed: 44, Epoch: 157, Loss: 0.1138, Val Acc: 0.6790, Test Acc: 0.6402
# Seed: 44, Epoch: 158, Loss: 0.1090, Val Acc: 0.6605, Test Acc: 0.6890
# Seed: 44, Epoch: 159, Loss: 0.0905, Val Acc: 0.6358, Test Acc: 0.6829
# Seed: 44, Epoch: 160, Loss: 0.0993, Val Acc: 0.6975, Test Acc: 0.6585
# Seed: 44, Epoch: 161, Loss: 0.1107, Val Acc: 0.6605, Test Acc: 0.6341
# Seed: 44, Epoch: 162, Loss: 0.0913, Val Acc: 0.6481, Test Acc: 0.6037
# Seed: 44, Epoch: 163, Loss: 0.0626, Val Acc: 0.6728, Test Acc: 0.6707
# Seed: 44, Epoch: 164, Loss: 0.1209, Val Acc: 0.7037, Test Acc: 0.6646
# Seed: 44, Epoch: 165, Loss: 0.0819, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 44, Epoch: 166, Loss: 0.0732, Val Acc: 0.6605, Test Acc: 0.6341
# Seed: 44, Epoch: 167, Loss: 0.0874, Val Acc: 0.6728, Test Acc: 0.6402
# Seed: 44, Epoch: 168, Loss: 0.0651, Val Acc: 0.6481, Test Acc: 0.6341
# Seed: 44, Epoch: 169, Loss: 0.0537, Val Acc: 0.6358, Test Acc: 0.6463
# Seed: 44, Epoch: 170, Loss: 0.0569, Val Acc: 0.6358, Test Acc: 0.6341
# Seed: 44, Epoch: 171, Loss: 0.0689, Val Acc: 0.6481, Test Acc: 0.6159
# Seed: 44, Epoch: 172, Loss: 0.0462, Val Acc: 0.6296, Test Acc: 0.6524
# Seed: 44, Epoch: 173, Loss: 0.0402, Val Acc: 0.6543, Test Acc: 0.6829
# Seed: 44, Epoch: 174, Loss: 0.0476, Val Acc: 0.6728, Test Acc: 0.6707
# Seed: 44, Epoch: 175, Loss: 0.0367, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 44, Epoch: 176, Loss: 0.0887, Val Acc: 0.6481, Test Acc: 0.6524
# Seed: 44, Epoch: 177, Loss: 0.0680, Val Acc: 0.5988, Test Acc: 0.5915
# Seed: 44, Epoch: 178, Loss: 0.0995, Val Acc: 0.6358, Test Acc: 0.6280
# Seed: 44, Epoch: 179, Loss: 0.0937, Val Acc: 0.6296, Test Acc: 0.6646
# Seed: 44, Epoch: 180, Loss: 0.0628, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 44, Epoch: 181, Loss: 0.0673, Val Acc: 0.6728, Test Acc: 0.6402
# Seed: 44, Epoch: 182, Loss: 0.0621, Val Acc: 0.6914, Test Acc: 0.6402
# Seed: 44, Epoch: 183, Loss: 0.1021, Val Acc: 0.7037, Test Acc: 0.6280
# Seed: 44, Epoch: 184, Loss: 0.0593, Val Acc: 0.6975, Test Acc: 0.6159
# Seed: 44, Epoch: 185, Loss: 0.0553, Val Acc: 0.6914, Test Acc: 0.6768
# Seed: 44, Epoch: 186, Loss: 0.0806, Val Acc: 0.6914, Test Acc: 0.6707
# Seed: 44, Epoch: 187, Loss: 0.0602, Val Acc: 0.6852, Test Acc: 0.6524
# Seed: 44, Epoch: 188, Loss: 0.0473, Val Acc: 0.5926, Test Acc: 0.5549
# Seed: 44, Epoch: 189, Loss: 0.0589, Val Acc: 0.5617, Test Acc: 0.5976
# Seed: 44, Epoch: 190, Loss: 0.0350, Val Acc: 0.6049, Test Acc: 0.6341
# Seed: 44, Epoch: 191, Loss: 0.0636, Val Acc: 0.6420, Test Acc: 0.6829
# Seed: 44, Epoch: 192, Loss: 0.0282, Val Acc: 0.6914, Test Acc: 0.6220
# Seed: 44, Epoch: 193, Loss: 0.0639, Val Acc: 0.6975, Test Acc: 0.6402
# Seed: 44, Epoch: 194, Loss: 0.0307, Val Acc: 0.6728, Test Acc: 0.6402
# Seed: 44, Epoch: 195, Loss: 0.0406, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 44, Epoch: 196, Loss: 0.0215, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 44, Epoch: 197, Loss: 0.0412, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 44, Epoch: 198, Loss: 0.0175, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 44, Epoch: 199, Loss: 0.0235, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 44, Epoch: 200, Loss: 0.0193, Val Acc: 0.6728, Test Acc: 0.6463
# Seed: 45, Epoch: 001, Loss: 0.6648, Val Acc: 0.7099, Test Acc: 0.6829
# Seed: 45, Epoch: 002, Loss: 0.6200, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 45, Epoch: 003, Loss: 0.6157, Val Acc: 0.6852, Test Acc: 0.6463
# Seed: 45, Epoch: 004, Loss: 0.6099, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 45, Epoch: 005, Loss: 0.6106, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 45, Epoch: 006, Loss: 0.6046, Val Acc: 0.7160, Test Acc: 0.6585
# Seed: 45, Epoch: 007, Loss: 0.6019, Val Acc: 0.7099, Test Acc: 0.6585
# Seed: 45, Epoch: 008, Loss: 0.5996, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 45, Epoch: 009, Loss: 0.5959, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 45, Epoch: 010, Loss: 0.5931, Val Acc: 0.7037, Test Acc: 0.6951
# Seed: 45, Epoch: 011, Loss: 0.5861, Val Acc: 0.7160, Test Acc: 0.6890
# Seed: 45, Epoch: 012, Loss: 0.5775, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 45, Epoch: 013, Loss: 0.5665, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 45, Epoch: 014, Loss: 0.5598, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 45, Epoch: 015, Loss: 0.5461, Val Acc: 0.7346, Test Acc: 0.7256
# Seed: 45, Epoch: 016, Loss: 0.5300, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 45, Epoch: 017, Loss: 0.5322, Val Acc: 0.6728, Test Acc: 0.7012
# Seed: 45, Epoch: 018, Loss: 0.5171, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 45, Epoch: 019, Loss: 0.5159, Val Acc: 0.7531, Test Acc: 0.7195
# Seed: 45, Epoch: 020, Loss: 0.5076, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 45, Epoch: 021, Loss: 0.5022, Val Acc: 0.6975, Test Acc: 0.7073
# Seed: 45, Epoch: 022, Loss: 0.4996, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 45, Epoch: 023, Loss: 0.5032, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 024, Loss: 0.4989, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 45, Epoch: 025, Loss: 0.4889, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 45, Epoch: 026, Loss: 0.4738, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 45, Epoch: 027, Loss: 0.4741, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 45, Epoch: 028, Loss: 0.4624, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 45, Epoch: 029, Loss: 0.4615, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 45, Epoch: 030, Loss: 0.4546, Val Acc: 0.7160, Test Acc: 0.7561
# Seed: 45, Epoch: 031, Loss: 0.4675, Val Acc: 0.6852, Test Acc: 0.7378
# Seed: 45, Epoch: 032, Loss: 0.4641, Val Acc: 0.7160, Test Acc: 0.7683
# Seed: 45, Epoch: 033, Loss: 0.4654, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 034, Loss: 0.4677, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 035, Loss: 0.4516, Val Acc: 0.6605, Test Acc: 0.7195
# Seed: 45, Epoch: 036, Loss: 0.4441, Val Acc: 0.7160, Test Acc: 0.7500
# Seed: 45, Epoch: 037, Loss: 0.4664, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 45, Epoch: 038, Loss: 0.4481, Val Acc: 0.5679, Test Acc: 0.6524
# Seed: 45, Epoch: 039, Loss: 0.4353, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 45, Epoch: 040, Loss: 0.4370, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 45, Epoch: 041, Loss: 0.4222, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 45, Epoch: 042, Loss: 0.4136, Val Acc: 0.6605, Test Acc: 0.7256
# Seed: 45, Epoch: 043, Loss: 0.4038, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 45, Epoch: 044, Loss: 0.4205, Val Acc: 0.6667, Test Acc: 0.7378
# Seed: 45, Epoch: 045, Loss: 0.4040, Val Acc: 0.7037, Test Acc: 0.7378
# Seed: 45, Epoch: 046, Loss: 0.4162, Val Acc: 0.6543, Test Acc: 0.7073
# Seed: 45, Epoch: 047, Loss: 0.4110, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 45, Epoch: 048, Loss: 0.4111, Val Acc: 0.7284, Test Acc: 0.7317
# Seed: 45, Epoch: 049, Loss: 0.3806, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 45, Epoch: 050, Loss: 0.3845, Val Acc: 0.7099, Test Acc: 0.7622
# Seed: 45, Epoch: 051, Loss: 0.3707, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 45, Epoch: 052, Loss: 0.3698, Val Acc: 0.6975, Test Acc: 0.7561
# Seed: 45, Epoch: 053, Loss: 0.3680, Val Acc: 0.7160, Test Acc: 0.7744
# Seed: 45, Epoch: 054, Loss: 0.3517, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 45, Epoch: 055, Loss: 0.3921, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 45, Epoch: 056, Loss: 0.3619, Val Acc: 0.6605, Test Acc: 0.7744
# Seed: 45, Epoch: 057, Loss: 0.3600, Val Acc: 0.7222, Test Acc: 0.7927
# Seed: 45, Epoch: 058, Loss: 0.3939, Val Acc: 0.7346, Test Acc: 0.7988
# Seed: 45, Epoch: 059, Loss: 0.3579, Val Acc: 0.5617, Test Acc: 0.6646
# Seed: 45, Epoch: 060, Loss: 0.3558, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 45, Epoch: 061, Loss: 0.3614, Val Acc: 0.6667, Test Acc: 0.7195
# Seed: 45, Epoch: 062, Loss: 0.3433, Val Acc: 0.5679, Test Acc: 0.6463
# Seed: 45, Epoch: 063, Loss: 0.3422, Val Acc: 0.7469, Test Acc: 0.7683
# Seed: 45, Epoch: 064, Loss: 0.3345, Val Acc: 0.7469, Test Acc: 0.7500
# Seed: 45, Epoch: 065, Loss: 0.3105, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 45, Epoch: 066, Loss: 0.3144, Val Acc: 0.7222, Test Acc: 0.7561
# Seed: 45, Epoch: 067, Loss: 0.3132, Val Acc: 0.7407, Test Acc: 0.7195
# Seed: 45, Epoch: 068, Loss: 0.3128, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 45, Epoch: 069, Loss: 0.2949, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 45, Epoch: 070, Loss: 0.2812, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 45, Epoch: 071, Loss: 0.2812, Val Acc: 0.7222, Test Acc: 0.7256
# Seed: 45, Epoch: 072, Loss: 0.3161, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 45, Epoch: 073, Loss: 0.2926, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 45, Epoch: 074, Loss: 0.2908, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 45, Epoch: 075, Loss: 0.2825, Val Acc: 0.7099, Test Acc: 0.7683
# Seed: 45, Epoch: 076, Loss: 0.2673, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 45, Epoch: 077, Loss: 0.2626, Val Acc: 0.6235, Test Acc: 0.7195
# Seed: 45, Epoch: 078, Loss: 0.2423, Val Acc: 0.7284, Test Acc: 0.6585
# Seed: 45, Epoch: 079, Loss: 0.2401, Val Acc: 0.6914, Test Acc: 0.6829
# Seed: 45, Epoch: 080, Loss: 0.2406, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 45, Epoch: 081, Loss: 0.2348, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 45, Epoch: 082, Loss: 0.2329, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 45, Epoch: 083, Loss: 0.1960, Val Acc: 0.6049, Test Acc: 0.6707
# Seed: 45, Epoch: 084, Loss: 0.2083, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 45, Epoch: 085, Loss: 0.2223, Val Acc: 0.7160, Test Acc: 0.7317
# Seed: 45, Epoch: 086, Loss: 0.2389, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 45, Epoch: 087, Loss: 0.2011, Val Acc: 0.6790, Test Acc: 0.6829
# Seed: 45, Epoch: 088, Loss: 0.1743, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 089, Loss: 0.2141, Val Acc: 0.6605, Test Acc: 0.6646
# Seed: 45, Epoch: 090, Loss: 0.2388, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 45, Epoch: 091, Loss: 0.2228, Val Acc: 0.6975, Test Acc: 0.7744
# Seed: 45, Epoch: 092, Loss: 0.1877, Val Acc: 0.6605, Test Acc: 0.6951
# Seed: 45, Epoch: 093, Loss: 0.1871, Val Acc: 0.6667, Test Acc: 0.7256
# Seed: 45, Epoch: 094, Loss: 0.1926, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 45, Epoch: 095, Loss: 0.1844, Val Acc: 0.6235, Test Acc: 0.7012
# Seed: 45, Epoch: 096, Loss: 0.1723, Val Acc: 0.6975, Test Acc: 0.7012
# Seed: 45, Epoch: 097, Loss: 0.1735, Val Acc: 0.6605, Test Acc: 0.7134
# Seed: 45, Epoch: 098, Loss: 0.1950, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 45, Epoch: 099, Loss: 0.2008, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 45, Epoch: 100, Loss: 0.1954, Val Acc: 0.7222, Test Acc: 0.6951
# Seed: 45, Epoch: 101, Loss: 0.2856, Val Acc: 0.6543, Test Acc: 0.6524
# Seed: 45, Epoch: 102, Loss: 0.2188, Val Acc: 0.6667, Test Acc: 0.7317
# Seed: 45, Epoch: 103, Loss: 0.2236, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 45, Epoch: 104, Loss: 0.1584, Val Acc: 0.6049, Test Acc: 0.6463
# Seed: 45, Epoch: 105, Loss: 0.1724, Val Acc: 0.6420, Test Acc: 0.6585
# Seed: 45, Epoch: 106, Loss: 0.1655, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 45, Epoch: 107, Loss: 0.1349, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 45, Epoch: 108, Loss: 0.1241, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 45, Epoch: 109, Loss: 0.1147, Val Acc: 0.6914, Test Acc: 0.7317
# Seed: 45, Epoch: 110, Loss: 0.1111, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 45, Epoch: 111, Loss: 0.1282, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 45, Epoch: 112, Loss: 0.1250, Val Acc: 0.6481, Test Acc: 0.7012
# Seed: 45, Epoch: 113, Loss: 0.1359, Val Acc: 0.7222, Test Acc: 0.7988
# Seed: 45, Epoch: 114, Loss: 0.1667, Val Acc: 0.6605, Test Acc: 0.6829
# Seed: 45, Epoch: 115, Loss: 0.1372, Val Acc: 0.6790, Test Acc: 0.6829
# Seed: 45, Epoch: 116, Loss: 0.1423, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 45, Epoch: 117, Loss: 0.1756, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 45, Epoch: 118, Loss: 0.1183, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 45, Epoch: 119, Loss: 0.1251, Val Acc: 0.6852, Test Acc: 0.6951
# Seed: 45, Epoch: 120, Loss: 0.1353, Val Acc: 0.6852, Test Acc: 0.7012
# Seed: 45, Epoch: 121, Loss: 0.1026, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 45, Epoch: 122, Loss: 0.1357, Val Acc: 0.6728, Test Acc: 0.6646
# Seed: 45, Epoch: 123, Loss: 0.0979, Val Acc: 0.7222, Test Acc: 0.6829
# Seed: 45, Epoch: 124, Loss: 0.0891, Val Acc: 0.7222, Test Acc: 0.7012
# Seed: 45, Epoch: 125, Loss: 0.0848, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 45, Epoch: 126, Loss: 0.1187, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 45, Epoch: 127, Loss: 0.1671, Val Acc: 0.6543, Test Acc: 0.6646
# Seed: 45, Epoch: 128, Loss: 0.1037, Val Acc: 0.6790, Test Acc: 0.6341
# Seed: 45, Epoch: 129, Loss: 0.1388, Val Acc: 0.6481, Test Acc: 0.6220
# Seed: 45, Epoch: 130, Loss: 0.0943, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 45, Epoch: 131, Loss: 0.1161, Val Acc: 0.6728, Test Acc: 0.7195
# Seed: 45, Epoch: 132, Loss: 0.1204, Val Acc: 0.6852, Test Acc: 0.7073
# Seed: 45, Epoch: 133, Loss: 0.1002, Val Acc: 0.6790, Test Acc: 0.7012
# Seed: 45, Epoch: 134, Loss: 0.1119, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 135, Loss: 0.1242, Val Acc: 0.6667, Test Acc: 0.6707
# Seed: 45, Epoch: 136, Loss: 0.1283, Val Acc: 0.6605, Test Acc: 0.6280
# Seed: 45, Epoch: 137, Loss: 0.1184, Val Acc: 0.6667, Test Acc: 0.6585
# Seed: 45, Epoch: 138, Loss: 0.1173, Val Acc: 0.6605, Test Acc: 0.6768
# ...
# Seed: 45, Epoch: 175, Loss: 0.0572, Val Acc: 0.6358, Test Acc: 0.6829
# Seed: 45, Epoch: 176, Loss: 0.0609, Val Acc: 0.6481, Test Acc: 0.7256
# Seed: 45, Epoch: 177, Loss: 0.0490, Val Acc: 0.6728, Test Acc: 0.7073
# Seed: 45, Epoch: 178, Loss: 0.0542, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 45, Epoch: 179, Loss: 0.0497, Val Acc: 0.6543, Test Acc: 0.7195
# Seed: 45, Epoch: 180, Loss: 0.0392, Val Acc: 0.6358, Test Acc: 0.7012
# Seed: 45, Epoch: 181, Loss: 0.0429, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 45, Epoch: 182, Loss: 0.0817, Val Acc: 0.7099, Test Acc: 0.7073
# Seed: 45, Epoch: 183, Loss: 0.1000, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 45, Epoch: 184, Loss: 0.0381, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 45, Epoch: 185, Loss: 0.0661, Val Acc: 0.6235, Test Acc: 0.6402
# Seed: 45, Epoch: 186, Loss: 0.0337, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 45, Epoch: 187, Loss: 0.0309, Val Acc: 0.6852, Test Acc: 0.7134
# Seed: 45, Epoch: 188, Loss: 0.0346, Val Acc: 0.6667, Test Acc: 0.7073
# Seed: 45, Epoch: 189, Loss: 0.0267, Val Acc: 0.6358, Test Acc: 0.7317
# Seed: 45, Epoch: 190, Loss: 0.0350, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 45, Epoch: 191, Loss: 0.0279, Val Acc: 0.6914, Test Acc: 0.7073
# Seed: 45, Epoch: 192, Loss: 0.0173, Val Acc: 0.6790, Test Acc: 0.7317
# Seed: 45, Epoch: 193, Loss: 0.0484, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 45, Epoch: 194, Loss: 0.0567, Val Acc: 0.6852, Test Acc: 0.6524
# Seed: 45, Epoch: 195, Loss: 0.0387, Val Acc: 0.6914, Test Acc: 0.7134
# Seed: 45, Epoch: 196, Loss: 0.0298, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 45, Epoch: 197, Loss: 0.0496, Val Acc: 0.7160, Test Acc: 0.7256
# Seed: 45, Epoch: 198, Loss: 0.0611, Val Acc: 0.6914, Test Acc: 0.6890
# Seed: 45, Epoch: 199, Loss: 0.0721, Val Acc: 0.6728, Test Acc: 0.6585
# Seed: 45, Epoch: 200, Loss: 0.0475, Val Acc: 0.6914, Test Acc: 0.6951
# Seed: 46, Epoch: 001, Loss: 0.6647, Val Acc: 0.6605, Test Acc: 0.5976
# Seed: 46, Epoch: 002, Loss: 0.6285, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 46, Epoch: 003, Loss: 0.6206, Val Acc: 0.6358, Test Acc: 0.5671
# Seed: 46, Epoch: 004, Loss: 0.6195, Val Acc: 0.6420, Test Acc: 0.5854
# Seed: 46, Epoch: 005, Loss: 0.6174, Val Acc: 0.6667, Test Acc: 0.6098
# Seed: 46, Epoch: 006, Loss: 0.6135, Val Acc: 0.6728, Test Acc: 0.6098
# Seed: 46, Epoch: 007, Loss: 0.6107, Val Acc: 0.6852, Test Acc: 0.6280
# Seed: 46, Epoch: 008, Loss: 0.6060, Val Acc: 0.6914, Test Acc: 0.6463
# Seed: 46, Epoch: 009, Loss: 0.6021, Val Acc: 0.7160, Test Acc: 0.6768
# Seed: 46, Epoch: 010, Loss: 0.5917, Val Acc: 0.7099, Test Acc: 0.6524
# Seed: 46, Epoch: 011, Loss: 0.5831, Val Acc: 0.7531, Test Acc: 0.7134
# Seed: 46, Epoch: 012, Loss: 0.5670, Val Acc: 0.6420, Test Acc: 0.6951
# Seed: 46, Epoch: 013, Loss: 0.5592, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 46, Epoch: 014, Loss: 0.5402, Val Acc: 0.6790, Test Acc: 0.7256
# Seed: 46, Epoch: 015, Loss: 0.5320, Val Acc: 0.6667, Test Acc: 0.7012
# Seed: 46, Epoch: 016, Loss: 0.5188, Val Acc: 0.7037, Test Acc: 0.7317
# Seed: 46, Epoch: 017, Loss: 0.5053, Val Acc: 0.6728, Test Acc: 0.6890
# Seed: 46, Epoch: 018, Loss: 0.4955, Val Acc: 0.7099, Test Acc: 0.7317
# Seed: 46, Epoch: 019, Loss: 0.4911, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 020, Loss: 0.4846, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 021, Loss: 0.4728, Val Acc: 0.7469, Test Acc: 0.7561
# Seed: 46, Epoch: 022, Loss: 0.4633, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 023, Loss: 0.4556, Val Acc: 0.7531, Test Acc: 0.7500
# Seed: 46, Epoch: 024, Loss: 0.4517, Val Acc: 0.7160, Test Acc: 0.7439
# Seed: 46, Epoch: 025, Loss: 0.4589, Val Acc: 0.7531, Test Acc: 0.7561
# Seed: 46, Epoch: 026, Loss: 0.4566, Val Acc: 0.7469, Test Acc: 0.7439
# Seed: 46, Epoch: 027, Loss: 0.4345, Val Acc: 0.6049, Test Acc: 0.6707
# Seed: 46, Epoch: 028, Loss: 0.4417, Val Acc: 0.7346, Test Acc: 0.7439
# Seed: 46, Epoch: 029, Loss: 0.4424, Val Acc: 0.7222, Test Acc: 0.7622
# Seed: 46, Epoch: 030, Loss: 0.4291, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 031, Loss: 0.4179, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 46, Epoch: 032, Loss: 0.4088, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 033, Loss: 0.4185, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 034, Loss: 0.4023, Val Acc: 0.7346, Test Acc: 0.7683
# Seed: 46, Epoch: 035, Loss: 0.3924, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 036, Loss: 0.3902, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 037, Loss: 0.3810, Val Acc: 0.7654, Test Acc: 0.7561
# Seed: 46, Epoch: 038, Loss: 0.3883, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 039, Loss: 0.3686, Val Acc: 0.7222, Test Acc: 0.7622
# Seed: 46, Epoch: 040, Loss: 0.3704, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 46, Epoch: 041, Loss: 0.3518, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 46, Epoch: 042, Loss: 0.3623, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 46, Epoch: 043, Loss: 0.3389, Val Acc: 0.7531, Test Acc: 0.7195
# Seed: 46, Epoch: 044, Loss: 0.3545, Val Acc: 0.6975, Test Acc: 0.6707
# Seed: 46, Epoch: 045, Loss: 0.3448, Val Acc: 0.7778, Test Acc: 0.7622
# Seed: 46, Epoch: 046, Loss: 0.3464, Val Acc: 0.7531, Test Acc: 0.6951
# Seed: 46, Epoch: 047, Loss: 0.3439, Val Acc: 0.7160, Test Acc: 0.6768
# Seed: 46, Epoch: 048, Loss: 0.3236, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 049, Loss: 0.3272, Val Acc: 0.7469, Test Acc: 0.7134
# Seed: 46, Epoch: 050, Loss: 0.3468, Val Acc: 0.7346, Test Acc: 0.7622
# Seed: 46, Epoch: 051, Loss: 0.3154, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 46, Epoch: 052, Loss: 0.3094, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 46, Epoch: 053, Loss: 0.3185, Val Acc: 0.7284, Test Acc: 0.6890
# Seed: 46, Epoch: 054, Loss: 0.3441, Val Acc: 0.6296, Test Acc: 0.6768
# Seed: 46, Epoch: 055, Loss: 0.3064, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 46, Epoch: 056, Loss: 0.3005, Val Acc: 0.7716, Test Acc: 0.7317
# Seed: 46, Epoch: 057, Loss: 0.2914, Val Acc: 0.7469, Test Acc: 0.7195
# Seed: 46, Epoch: 058, Loss: 0.2857, Val Acc: 0.7593, Test Acc: 0.7622
# Seed: 46, Epoch: 059, Loss: 0.2839, Val Acc: 0.6667, Test Acc: 0.6890
# Seed: 46, Epoch: 060, Loss: 0.3014, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 46, Epoch: 061, Loss: 0.3049, Val Acc: 0.7160, Test Acc: 0.7378
# Seed: 46, Epoch: 062, Loss: 0.2569, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 46, Epoch: 063, Loss: 0.2573, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 46, Epoch: 064, Loss: 0.2430, Val Acc: 0.7160, Test Acc: 0.7073
# Seed: 46, Epoch: 065, Loss: 0.2703, Val Acc: 0.6852, Test Acc: 0.6585
# Seed: 46, Epoch: 066, Loss: 0.2453, Val Acc: 0.7284, Test Acc: 0.6524
# Seed: 46, Epoch: 067, Loss: 0.2780, Val Acc: 0.7593, Test Acc: 0.7073
# Seed: 46, Epoch: 068, Loss: 0.2706, Val Acc: 0.5062, Test Acc: 0.5305
# Seed: 46, Epoch: 069, Loss: 0.2362, Val Acc: 0.7222, Test Acc: 0.7866
# Seed: 46, Epoch: 070, Loss: 0.2721, Val Acc: 0.7716, Test Acc: 0.7744
# Seed: 46, Epoch: 071, Loss: 0.2262, Val Acc: 0.7284, Test Acc: 0.6646
# Seed: 46, Epoch: 072, Loss: 0.2393, Val Acc: 0.7284, Test Acc: 0.7012
# Seed: 46, Epoch: 073, Loss: 0.2187, Val Acc: 0.7099, Test Acc: 0.6890
# Seed: 46, Epoch: 074, Loss: 0.1917, Val Acc: 0.7284, Test Acc: 0.6951
# Seed: 46, Epoch: 075, Loss: 0.1812, Val Acc: 0.7037, Test Acc: 0.6768
# Seed: 46, Epoch: 076, Loss: 0.1832, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 46, Epoch: 077, Loss: 0.1720, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 46, Epoch: 078, Loss: 0.1910, Val Acc: 0.7222, Test Acc: 0.7500
# Seed: 46, Epoch: 079, Loss: 0.1977, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 080, Loss: 0.1841, Val Acc: 0.6605, Test Acc: 0.7317
# Seed: 46, Epoch: 081, Loss: 0.1787, Val Acc: 0.7407, Test Acc: 0.6951
# Seed: 46, Epoch: 082, Loss: 0.1820, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 46, Epoch: 083, Loss: 0.2058, Val Acc: 0.6852, Test Acc: 0.6707
# Seed: 46, Epoch: 084, Loss: 0.1644, Val Acc: 0.7284, Test Acc: 0.7256
# Seed: 46, Epoch: 085, Loss: 0.1946, Val Acc: 0.7099, Test Acc: 0.7378
# Seed: 46, Epoch: 086, Loss: 0.1704, Val Acc: 0.6667, Test Acc: 0.6829
# Seed: 46, Epoch: 087, Loss: 0.1521, Val Acc: 0.6543, Test Acc: 0.6707
# Seed: 46, Epoch: 088, Loss: 0.1530, Val Acc: 0.6543, Test Acc: 0.6951
# Seed: 46, Epoch: 089, Loss: 0.2224, Val Acc: 0.6049, Test Acc: 0.6280
# Seed: 46, Epoch: 090, Loss: 0.2230, Val Acc: 0.6235, Test Acc: 0.5854
# Seed: 46, Epoch: 091, Loss: 0.2632, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 46, Epoch: 092, Loss: 0.2005, Val Acc: 0.7160, Test Acc: 0.7134
# Seed: 46, Epoch: 093, Loss: 0.2213, Val Acc: 0.7716, Test Acc: 0.7622
# Seed: 46, Epoch: 094, Loss: 0.2348, Val Acc: 0.7778, Test Acc: 0.7683
# Seed: 46, Epoch: 095, Loss: 0.1768, Val Acc: 0.7963, Test Acc: 0.7500
# Seed: 46, Epoch: 096, Loss: 0.2105, Val Acc: 0.7407, Test Acc: 0.7500
# Seed: 46, Epoch: 097, Loss: 0.1863, Val Acc: 0.7346, Test Acc: 0.7134
# Seed: 46, Epoch: 098, Loss: 0.1454, Val Acc: 0.7222, Test Acc: 0.7134
# Seed: 46, Epoch: 099, Loss: 0.1306, Val Acc: 0.7284, Test Acc: 0.7378
# Seed: 46, Epoch: 100, Loss: 0.1207, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 46, Epoch: 101, Loss: 0.1576, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 46, Epoch: 102, Loss: 0.1282, Val Acc: 0.7407, Test Acc: 0.7866
# Seed: 46, Epoch: 103, Loss: 0.1019, Val Acc: 0.6975, Test Acc: 0.7378
# Seed: 46, Epoch: 104, Loss: 0.1328, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 46, Epoch: 105, Loss: 0.1127, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 106, Loss: 0.1580, Val Acc: 0.7531, Test Acc: 0.6890
# Seed: 46, Epoch: 107, Loss: 0.1281, Val Acc: 0.7593, Test Acc: 0.7500
# Seed: 46, Epoch: 108, Loss: 0.1409, Val Acc: 0.7593, Test Acc: 0.7561
# Seed: 46, Epoch: 109, Loss: 0.1510, Val Acc: 0.7099, Test Acc: 0.7012
# Seed: 46, Epoch: 110, Loss: 0.1368, Val Acc: 0.7099, Test Acc: 0.7134
# Seed: 46, Epoch: 111, Loss: 0.1729, Val Acc: 0.6790, Test Acc: 0.7195
# Seed: 46, Epoch: 112, Loss: 0.1358, Val Acc: 0.6667, Test Acc: 0.7134
# Seed: 46, Epoch: 113, Loss: 0.1236, Val Acc: 0.6914, Test Acc: 0.6524
# Seed: 46, Epoch: 114, Loss: 0.1043, Val Acc: 0.7160, Test Acc: 0.6951
# Seed: 46, Epoch: 115, Loss: 0.1131, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 46, Epoch: 116, Loss: 0.1486, Val Acc: 0.7037, Test Acc: 0.6890
# Seed: 46, Epoch: 117, Loss: 0.1261, Val Acc: 0.6975, Test Acc: 0.6890
# Seed: 46, Epoch: 118, Loss: 0.1610, Val Acc: 0.6543, Test Acc: 0.6890
# Seed: 46, Epoch: 119, Loss: 0.1272, Val Acc: 0.6605, Test Acc: 0.5610
# Seed: 46, Epoch: 120, Loss: 0.1495, Val Acc: 0.7099, Test Acc: 0.6951
# Seed: 46, Epoch: 121, Loss: 0.1097, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 46, Epoch: 122, Loss: 0.1010, Val Acc: 0.6790, Test Acc: 0.6951
# Seed: 46, Epoch: 123, Loss: 0.1029, Val Acc: 0.7284, Test Acc: 0.6829
# Seed: 46, Epoch: 124, Loss: 0.0881, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 125, Loss: 0.0959, Val Acc: 0.7346, Test Acc: 0.7378
# Seed: 46, Epoch: 126, Loss: 0.0817, Val Acc: 0.7531, Test Acc: 0.7439
# Seed: 46, Epoch: 127, Loss: 0.0755, Val Acc: 0.7531, Test Acc: 0.7317
# Seed: 46, Epoch: 128, Loss: 0.0744, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 46, Epoch: 129, Loss: 0.0749, Val Acc: 0.6790, Test Acc: 0.6890
# Seed: 46, Epoch: 130, Loss: 0.0506, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 131, Loss: 0.0522, Val Acc: 0.7407, Test Acc: 0.7561
# Seed: 46, Epoch: 132, Loss: 0.0509, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 46, Epoch: 133, Loss: 0.0757, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 46, Epoch: 134, Loss: 0.0578, Val Acc: 0.7716, Test Acc: 0.7866
# Seed: 46, Epoch: 135, Loss: 0.0664, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 136, Loss: 0.0351, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 137, Loss: 0.0627, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 46, Epoch: 138, Loss: 0.0466, Val Acc: 0.7037, Test Acc: 0.7256
# Seed: 46, Epoch: 139, Loss: 0.0462, Val Acc: 0.7593, Test Acc: 0.7317
# Seed: 46, Epoch: 140, Loss: 0.0832, Val Acc: 0.7469, Test Acc: 0.7622
# Seed: 46, Epoch: 141, Loss: 0.0454, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 46, Epoch: 142, Loss: 0.0423, Val Acc: 0.6790, Test Acc: 0.6707
# Seed: 46, Epoch: 143, Loss: 0.0722, Val Acc: 0.7346, Test Acc: 0.7317
# Seed: 46, Epoch: 144, Loss: 0.0606, Val Acc: 0.7346, Test Acc: 0.7012
# Seed: 46, Epoch: 145, Loss: 0.0744, Val Acc: 0.6358, Test Acc: 0.6220
# Seed: 46, Epoch: 146, Loss: 0.0686, Val Acc: 0.6852, Test Acc: 0.6098
# Seed: 46, Epoch: 147, Loss: 0.0652, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 46, Epoch: 148, Loss: 0.0476, Val Acc: 0.7284, Test Acc: 0.7073
# Seed: 46, Epoch: 149, Loss: 0.0837, Val Acc: 0.6852, Test Acc: 0.6890
# Seed: 46, Epoch: 150, Loss: 0.0486, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 151, Loss: 0.0786, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 152, Loss: 0.0553, Val Acc: 0.7531, Test Acc: 0.7927
# Seed: 46, Epoch: 153, Loss: 0.0631, Val Acc: 0.7222, Test Acc: 0.7866
# Seed: 46, Epoch: 154, Loss: 0.0363, Val Acc: 0.7099, Test Acc: 0.7439
# Seed: 46, Epoch: 155, Loss: 0.0518, Val Acc: 0.7099, Test Acc: 0.7256
# Seed: 46, Epoch: 156, Loss: 0.0387, Val Acc: 0.6975, Test Acc: 0.7317
# Seed: 46, Epoch: 157, Loss: 0.0528, Val Acc: 0.6728, Test Acc: 0.6951
# Seed: 46, Epoch: 158, Loss: 0.0463, Val Acc: 0.7222, Test Acc: 0.7134
# Seed: 46, Epoch: 159, Loss: 0.0396, Val Acc: 0.7346, Test Acc: 0.7500
# Seed: 46, Epoch: 160, Loss: 0.0417, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 46, Epoch: 161, Loss: 0.0658, Val Acc: 0.7654, Test Acc: 0.7439
# Seed: 46, Epoch: 162, Loss: 0.0714, Val Acc: 0.7778, Test Acc: 0.7439
# Seed: 46, Epoch: 163, Loss: 0.0584, Val Acc: 0.7284, Test Acc: 0.6768
# Seed: 46, Epoch: 164, Loss: 0.0867, Val Acc: 0.6914, Test Acc: 0.7195
# Seed: 46, Epoch: 165, Loss: 0.0731, Val Acc: 0.6975, Test Acc: 0.7195
# Seed: 46, Epoch: 166, Loss: 0.0701, Val Acc: 0.6790, Test Acc: 0.7134
# Seed: 46, Epoch: 167, Loss: 0.0667, Val Acc: 0.7531, Test Acc: 0.7378
# Seed: 46, Epoch: 168, Loss: 0.0502, Val Acc: 0.7284, Test Acc: 0.7195
# Seed: 46, Epoch: 169, Loss: 0.0554, Val Acc: 0.7160, Test Acc: 0.6707
# Seed: 46, Epoch: 170, Loss: 0.0650, Val Acc: 0.7407, Test Acc: 0.7439
# Seed: 46, Epoch: 171, Loss: 0.0839, Val Acc: 0.7222, Test Acc: 0.7439
# Seed: 46, Epoch: 172, Loss: 0.0529, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 173, Loss: 0.0786, Val Acc: 0.7037, Test Acc: 0.7134
# Seed: 46, Epoch: 174, Loss: 0.0486, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 46, Epoch: 175, Loss: 0.0650, Val Acc: 0.7222, Test Acc: 0.7317
# Seed: 46, Epoch: 176, Loss: 0.0904, Val Acc: 0.5864, Test Acc: 0.5549
# Seed: 46, Epoch: 177, Loss: 0.0746, Val Acc: 0.5617, Test Acc: 0.5122
# Seed: 46, Epoch: 178, Loss: 0.0839, Val Acc: 0.6667, Test Acc: 0.5732
# Seed: 46, Epoch: 179, Loss: 0.0869, Val Acc: 0.6728, Test Acc: 0.6768
# Seed: 46, Epoch: 180, Loss: 0.0503, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 46, Epoch: 181, Loss: 0.0559, Val Acc: 0.7531, Test Acc: 0.7073
# Seed: 46, Epoch: 182, Loss: 0.0520, Val Acc: 0.7469, Test Acc: 0.7378
# Seed: 46, Epoch: 183, Loss: 0.0560, Val Acc: 0.7469, Test Acc: 0.7317
# Seed: 46, Epoch: 184, Loss: 0.0358, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 185, Loss: 0.0444, Val Acc: 0.7407, Test Acc: 0.7378
# Seed: 46, Epoch: 186, Loss: 0.0367, Val Acc: 0.7407, Test Acc: 0.7683
# Seed: 46, Epoch: 187, Loss: 0.0517, Val Acc: 0.7346, Test Acc: 0.7195
# Seed: 46, Epoch: 188, Loss: 0.0369, Val Acc: 0.7222, Test Acc: 0.7195
# Seed: 46, Epoch: 189, Loss: 0.0211, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 190, Loss: 0.0208, Val Acc: 0.7284, Test Acc: 0.7500
# Seed: 46, Epoch: 191, Loss: 0.0201, Val Acc: 0.7222, Test Acc: 0.7378
# Seed: 46, Epoch: 192, Loss: 0.0409, Val Acc: 0.7284, Test Acc: 0.7561
# Seed: 46, Epoch: 193, Loss: 0.0175, Val Acc: 0.7284, Test Acc: 0.7439
# Seed: 46, Epoch: 194, Loss: 0.0160, Val Acc: 0.7284, Test Acc: 0.7134
# Seed: 46, Epoch: 195, Loss: 0.0275, Val Acc: 0.7346, Test Acc: 0.7561
# Seed: 46, Epoch: 196, Loss: 0.0202, Val Acc: 0.7346, Test Acc: 0.7744
# Seed: 46, Epoch: 197, Loss: 0.0115, Val Acc: 0.7160, Test Acc: 0.7805
# Seed: 46, Epoch: 198, Loss: 0.0202, Val Acc: 0.6975, Test Acc: 0.7500
# Seed: 46, Epoch: 199, Loss: 0.0217, Val Acc: 0.6914, Test Acc: 0.7256
# Seed: 46, Epoch: 200, Loss: 0.0137, Val Acc: 0.7160, Test Acc: 0.7500
# Average Time: 42.75 seconds
# Var Time: 8.26 seconds
# Average Memory: 638.00 MB
# Average Best Val Acc: 0.7716
# Std Best Test Acc: 0.0200
# Average Test Acc: 0.7317
